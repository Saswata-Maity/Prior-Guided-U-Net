# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-19 16:55:48.133976: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-19 16:55:48.185132: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-19 16:55:48.185193: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-19 16:55:48.189009: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-19 16:55:48.204429: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-19 16:55:48.776756: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-19 16:55:49.682929: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.748697: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.748733: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):

    res = x

    # ============================================================
    # ENCODER BLOCK
    # ============================================================
    if not decoder:


        # -------------------------------
        # Branch 2: Evolutionary Conv
        # -------------------------------
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        # -------------------------------
        # Depthwise Patch Attention
        # -------------------------------

        # Residual projection
        res = layers.Conv2D(filters, 1, padding=padding)(res)

        # Final fusion
        out = layers.Add()([res, x1])

        return out

    # ============================================================
    # DECODER BLOCK
    # ============================================================
    else:

        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class RegionawareAnistropicMeanPool2D(layers.Layer):

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = RegionawareAnistropicMeanPool2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = RegionawareAnistropicMeanPool2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = RegionawareAnistropicMeanPool2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = RegionawareAnistropicMeanPool2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-19 16:55:49.795583: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.795646: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.795663: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.950516: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.950558: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.950565: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-19 16:55:49.950575: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-19 16:55:49.950587: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-19 16:55:49.950641: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5804 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['conv2d[0][0]',
#                                                                      'activation[0][0]']
#
#  geodesic_downsample2d (Geo  (None, 128, 128, 32)         32        ['add[0][0]']
#  desicDownsample2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['geodesic_downsample2d[0][0]'
#                                                                     ]
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         2112      ['gaussian_dropout[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['conv2d_1[0][0]',
#                                                                      'activation_1[0][0]']
#
#  geodesic_downsample2d_1 (G  (None, 64, 64, 64)           64        ['add_1[0][0]']
#  eodesicDownsample2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['geodesic_downsample2d_1[0][0
#                                                                     ]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          8320      ['gaussian_dropout_1[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_2[0][0]',
#                                                                      'activation_2[0][0]']
#
#  geodesic_downsample2d_2 (G  (None, 32, 32, 128)          128       ['add_2[0][0]']
#  eodesicDownsample2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['geodesic_downsample2d_2[0][0
#                                                                     ]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)          33024     ['dropout_2[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 32, 32, 256)          0         ['conv2d_3[0][0]',
#                                                                      'activation_3[0][0]']
#
#  geodesic_downsample2d_3 (G  (None, 16, 16, 256)          256       ['add_3[0][0]']
#  eodesicDownsample2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['geodesic_downsample2d_3[0][0
#                                                                     ]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 384)          98688     ['gaussian_dropout_2[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 16, 16, 384)          0         ['conv2d_4[0][0]',
#                                                                      'activation_4[0][0]']
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['add_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 32, 32, 256)          0         ['add_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add_5[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_6 (Add)                 (None, 64, 64, 128)          0         ['add_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_6[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['add_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_7[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['add[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 1)          33        ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 2975370 (11.35 MB)
# Trainable params: 2972682 (11.34 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../CPM 17 DATA/augmented_dataset/images/*.png"))
train_mask_paths = sorted(glob("../CPM 17 DATA/augmented_dataset/masks/*.png"))

val_img_paths = sorted(
    glob("../CPM 17 DATA/val/images/*.png") +
    glob("../CPM 17 DATA/val/images/*.tif") +
    glob("../CPM 17 DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../CPM 17 DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 341
# Train masks: 341
# Val images: 4
# Val masks: 4
# 2026-09-19 16:55:59.390298: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 86
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-19 16:56:05.574372: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-19 16:56:13.472641: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-19 16:56:13.643478: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-19 16:56:16.449888: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2026-09-19 16:56:17.720560: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2026-09-19 16:56:18.963541: I external/local_xla/xla/service/service.cc:168] XLA service 0x70a4850fa1b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-19 16:56:18.963581: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-19 16:56:18.968015: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789836979.027080  141706 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 86/86 [==============================] - ETA: 0s - loss: 3.1445 - accuracy: 0.8336 - iou_coef: 0.5232 - dice_coef: 0.6771 - f1_score: 0.7054 - aggregated_jaccard_index: 0.5362
# ✅ Saved improved backbone at epoch 1 with val_iou=0.2598
# 86/86 [==============================] - 35s 148ms/step - loss: 3.1332 - accuracy: 0.8336 - iou_coef: 0.5232 - dice_coef: 0.6771 - f1_score: 0.7054 - aggregated_jaccard_index: 0.5362 - val_val_loss: 4.9782 - val_val_accuracy: 0.8477 - val_val_iou_coef: 0.2598 - val_val_dice_coef: 0.3852 - val_val_f1_score: 0.3833 - val_val_aggregated_jaccard_index: 0.2649 - lr: 0.0010
# Epoch 2/150
# 86/86 [==============================] - ETA: 0s - loss: 2.3528 - accuracy: 0.9015 - iou_coef: 0.6248 - dice_coef: 0.7634 - f1_score: 0.7815 - aggregated_jaccard_index: 0.6285
# ✅ Saved improved backbone at epoch 2 with val_iou=0.5022
# 86/86 [==============================] - 17s 122ms/step - loss: 2.3456 - accuracy: 0.9015 - iou_coef: 0.6248 - dice_coef: 0.7634 - f1_score: 0.7815 - aggregated_jaccard_index: 0.6285 - val_val_loss: 2.9106 - val_val_accuracy: 0.9107 - val_val_iou_coef: 0.5022 - val_val_dice_coef: 0.6533 - val_val_f1_score: 0.6937 - val_val_aggregated_jaccard_index: 0.5294 - lr: 0.0010
# Epoch 3/150
# 86/86 [==============================] - ETA: 0s - loss: 2.1154 - accuracy: 0.9134 - iou_coef: 0.6519 - dice_coef: 0.7854 - f1_score: 0.7986 - aggregated_jaccard_index: 0.6549
# ✅ Saved improved backbone at epoch 3 with val_iou=0.6248
# 86/86 [==============================] - 14s 112ms/step - loss: 2.1141 - accuracy: 0.9134 - iou_coef: 0.6519 - dice_coef: 0.7854 - f1_score: 0.7986 - aggregated_jaccard_index: 0.6549 - val_val_loss: 2.1420 - val_val_accuracy: 0.9243 - val_val_iou_coef: 0.6248 - val_val_dice_coef: 0.7652 - val_val_f1_score: 0.7923 - val_val_aggregated_jaccard_index: 0.6402 - lr: 0.0010
# Epoch 4/150
# 86/86 [==============================] - 16s 135ms/step - loss: 2.0259 - accuracy: 0.9148 - iou_coef: 0.6563 - dice_coef: 0.7877 - f1_score: 0.7978 - aggregated_jaccard_index: 0.6612 - val_val_loss: 2.1754 - val_val_accuracy: 0.9198 - val_val_iou_coef: 0.5900 - val_val_dice_coef: 0.7160 - val_val_f1_score: 0.7254 - val_val_aggregated_jaccard_index: 0.6247 - lr: 0.0010
# Epoch 5/150
# 86/86 [==============================] - 14s 110ms/step - loss: 1.9268 - accuracy: 0.9184 - iou_coef: 0.6695 - dice_coef: 0.7986 - f1_score: 0.8071 - aggregated_jaccard_index: 0.6722 - val_val_loss: 2.1817 - val_val_accuracy: 0.9154 - val_val_iou_coef: 0.5878 - val_val_dice_coef: 0.7290 - val_val_f1_score: 0.7436 - val_val_aggregated_jaccard_index: 0.6283 - lr: 0.0010
# Epoch 6/150
# 86/86 [==============================] - 16s 134ms/step - loss: 1.8459 - accuracy: 0.9206 - iou_coef: 0.6745 - dice_coef: 0.8025 - f1_score: 0.8099 - aggregated_jaccard_index: 0.6783 - val_val_loss: 2.2796 - val_val_accuracy: 0.9155 - val_val_iou_coef: 0.5815 - val_val_dice_coef: 0.7201 - val_val_f1_score: 0.7222 - val_val_aggregated_jaccard_index: 0.5986 - lr: 0.0010
# Epoch 7/150
# 86/86 [==============================] - 14s 112ms/step - loss: 1.7648 - accuracy: 0.9221 - iou_coef: 0.6824 - dice_coef: 0.8082 - f1_score: 0.8145 - aggregated_jaccard_index: 0.6847 - val_val_loss: 2.4104 - val_val_accuracy: 0.9090 - val_val_iou_coef: 0.5568 - val_val_dice_coef: 0.6913 - val_val_f1_score: 0.6910 - val_val_aggregated_jaccard_index: 0.5688 - lr: 0.0010
# Epoch 8/150
# 86/86 [==============================] - 14s 111ms/step - loss: 1.7377 - accuracy: 0.9222 - iou_coef: 0.6824 - dice_coef: 0.8084 - f1_score: 0.8141 - aggregated_jaccard_index: 0.6857 - val_val_loss: 2.2312 - val_val_accuracy: 0.9142 - val_val_iou_coef: 0.5774 - val_val_dice_coef: 0.7203 - val_val_f1_score: 0.7214 - val_val_aggregated_jaccard_index: 0.5926 - lr: 0.0010
# Epoch 9/150
# 86/86 [==============================] - ETA: 0s - loss: 1.6478 - accuracy: 0.9243 - iou_coef: 0.6914 - dice_coef: 0.8152 - f1_score: 0.8202 - aggregated_jaccard_index: 0.6938
# ✅ Saved improved backbone at epoch 9 with val_iou=0.6447
# 86/86 [==============================] - 16s 112ms/step - loss: 1.6484 - accuracy: 0.9243 - iou_coef: 0.6914 - dice_coef: 0.8152 - f1_score: 0.8202 - aggregated_jaccard_index: 0.6938 - val_val_loss: 1.8458 - val_val_accuracy: 0.9259 - val_val_iou_coef: 0.6447 - val_val_dice_coef: 0.7788 - val_val_f1_score: 0.7845 - val_val_aggregated_jaccard_index: 0.6514 - lr: 0.0010
# Epoch 10/150
# 86/86 [==============================] - ETA: 0s - loss: 1.5936 - accuracy: 0.9255 - iou_coef: 0.6951 - dice_coef: 0.8176 - f1_score: 0.8220 - aggregated_jaccard_index: 0.6977
# ✅ Saved improved backbone at epoch 10 with val_iou=0.6472
# 86/86 [==============================] - 14s 111ms/step - loss: 1.5949 - accuracy: 0.9255 - iou_coef: 0.6951 - dice_coef: 0.8176 - f1_score: 0.8220 - aggregated_jaccard_index: 0.6977 - val_val_loss: 1.8178 - val_val_accuracy: 0.9253 - val_val_iou_coef: 0.6472 - val_val_dice_coef: 0.7821 - val_val_f1_score: 0.7846 - val_val_aggregated_jaccard_index: 0.6499 - lr: 0.0010
# Epoch 11/150
# 86/86 [==============================] - 16s 135ms/step - loss: 1.5299 - accuracy: 0.9267 - iou_coef: 0.6993 - dice_coef: 0.8208 - f1_score: 0.8249 - aggregated_jaccard_index: 0.7033 - val_val_loss: 2.0129 - val_val_accuracy: 0.9170 - val_val_iou_coef: 0.5882 - val_val_dice_coef: 0.7310 - val_val_f1_score: 0.7316 - val_val_aggregated_jaccard_index: 0.6072 - lr: 0.0010
# Epoch 12/150
# 86/86 [==============================] - 14s 111ms/step - loss: 1.4968 - accuracy: 0.9269 - iou_coef: 0.7005 - dice_coef: 0.8215 - f1_score: 0.8253 - aggregated_jaccard_index: 0.7041 - val_val_loss: 1.8647 - val_val_accuracy: 0.9207 - val_val_iou_coef: 0.6106 - val_val_dice_coef: 0.7442 - val_val_f1_score: 0.7450 - val_val_aggregated_jaccard_index: 0.6265 - lr: 0.0010
# Epoch 13/150
# 86/86 [==============================] - 16s 130ms/step - loss: 1.4407 - accuracy: 0.9274 - iou_coef: 0.7039 - dice_coef: 0.8238 - f1_score: 0.8273 - aggregated_jaccard_index: 0.7067 - val_val_loss: 1.8147 - val_val_accuracy: 0.9209 - val_val_iou_coef: 0.6383 - val_val_dice_coef: 0.7751 - val_val_f1_score: 0.8008 - val_val_aggregated_jaccard_index: 0.6430 - lr: 0.0010
# Epoch 14/150
# 86/86 [==============================] - ETA: 0s - loss: 1.4081 - accuracy: 0.9274 - iou_coef: 0.7051 - dice_coef: 0.8246 - f1_score: 0.8279 - aggregated_jaccard_index: 0.7079
# ✅ Saved improved backbone at epoch 14 with val_iou=0.6645
# 86/86 [==============================] - 14s 112ms/step - loss: 1.4024 - accuracy: 0.9274 - iou_coef: 0.7051 - dice_coef: 0.8246 - f1_score: 0.8279 - aggregated_jaccard_index: 0.7079 - val_val_loss: 1.5648 - val_val_accuracy: 0.9271 - val_val_iou_coef: 0.6645 - val_val_dice_coef: 0.7959 - val_val_f1_score: 0.7998 - val_val_aggregated_jaccard_index: 0.6675 - lr: 0.0010
# Epoch 15/150
# 86/86 [==============================] - ETA: 0s - loss: 1.3437 - accuracy: 0.9298 - iou_coef: 0.7113 - dice_coef: 0.8293 - f1_score: 0.8326 - aggregated_jaccard_index: 0.7143
# ✅ Saved improved backbone at epoch 15 with val_iou=0.6874
# 86/86 [==============================] - 14s 113ms/step - loss: 1.3489 - accuracy: 0.9298 - iou_coef: 0.7113 - dice_coef: 0.8293 - f1_score: 0.8326 - aggregated_jaccard_index: 0.7143 - val_val_loss: 1.4232 - val_val_accuracy: 0.9325 - val_val_iou_coef: 0.6874 - val_val_dice_coef: 0.8135 - val_val_f1_score: 0.8172 - val_val_aggregated_jaccard_index: 0.6912 - lr: 0.0010
# Epoch 16/150
# 86/86 [==============================] - 16s 112ms/step - loss: 1.3318 - accuracy: 0.9291 - iou_coef: 0.7092 - dice_coef: 0.8278 - f1_score: 0.8308 - aggregated_jaccard_index: 0.7116 - val_val_loss: 1.4813 - val_val_accuracy: 0.9299 - val_val_iou_coef: 0.6651 - val_val_dice_coef: 0.7964 - val_val_f1_score: 0.7983 - val_val_aggregated_jaccard_index: 0.6725 - lr: 0.0010
# Epoch 17/150
# 86/86 [==============================] - 14s 110ms/step - loss: 1.2674 - accuracy: 0.9305 - iou_coef: 0.7137 - dice_coef: 0.8309 - f1_score: 0.8338 - aggregated_jaccard_index: 0.7166 - val_val_loss: 1.5401 - val_val_accuracy: 0.9257 - val_val_iou_coef: 0.6462 - val_val_dice_coef: 0.7811 - val_val_f1_score: 0.7825 - val_val_aggregated_jaccard_index: 0.6508 - lr: 0.0010
# Epoch 18/150
# 86/86 [==============================] - 16s 133ms/step - loss: 1.2279 - accuracy: 0.9309 - iou_coef: 0.7171 - dice_coef: 0.8334 - f1_score: 0.8363 - aggregated_jaccard_index: 0.7195 - val_val_loss: 1.3245 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6858 - val_val_dice_coef: 0.8119 - val_val_f1_score: 0.8137 - val_val_aggregated_jaccard_index: 0.6908 - lr: 0.0010
# Epoch 19/150
# 86/86 [==============================] - 14s 114ms/step - loss: 1.1628 - accuracy: 0.9328 - iou_coef: 0.7237 - dice_coef: 0.8380 - f1_score: 0.8406 - aggregated_jaccard_index: 0.7266 - val_val_loss: 1.5418 - val_val_accuracy: 0.9224 - val_val_iou_coef: 0.6259 - val_val_dice_coef: 0.7646 - val_val_f1_score: 0.7655 - val_val_aggregated_jaccard_index: 0.6340 - lr: 0.0010
# Epoch 20/150
# 86/86 [==============================] - ETA: 0s - loss: 1.1468 - accuracy: 0.9323 - iou_coef: 0.7219 - dice_coef: 0.8368 - f1_score: 0.8393 - aggregated_jaccard_index: 0.7236
# ✅ Saved improved backbone at epoch 20 with val_iou=0.7028
# 86/86 [==============================] - 16s 136ms/step - loss: 1.1483 - accuracy: 0.9323 - iou_coef: 0.7219 - dice_coef: 0.8368 - f1_score: 0.8393 - aggregated_jaccard_index: 0.7236 - val_val_loss: 1.2241 - val_val_accuracy: 0.9354 - val_val_iou_coef: 0.7028 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8292 - val_val_aggregated_jaccard_index: 0.7000 - lr: 0.0010
# Epoch 21/150
# 86/86 [==============================] - ETA: 0s - loss: 1.0990 - accuracy: 0.9333 - iou_coef: 0.7257 - dice_coef: 0.8394 - f1_score: 0.8419 - aggregated_jaccard_index: 0.7279
# ✅ Saved improved backbone at epoch 21 with val_iou=0.7164
# 86/86 [==============================] - 14s 114ms/step - loss: 1.1007 - accuracy: 0.9333 - iou_coef: 0.7257 - dice_coef: 0.8394 - f1_score: 0.8419 - aggregated_jaccard_index: 0.7279 - val_val_loss: 1.1452 - val_val_accuracy: 0.9370 - val_val_iou_coef: 0.7164 - val_val_dice_coef: 0.8339 - val_val_f1_score: 0.8372 - val_val_aggregated_jaccard_index: 0.7106 - lr: 0.0010
# Epoch 22/150
# 86/86 [==============================] - 16s 133ms/step - loss: 1.0667 - accuracy: 0.9339 - iou_coef: 0.7266 - dice_coef: 0.8399 - f1_score: 0.8424 - aggregated_jaccard_index: 0.7293 - val_val_loss: 1.1235 - val_val_accuracy: 0.9371 - val_val_iou_coef: 0.7116 - val_val_dice_coef: 0.8310 - val_val_f1_score: 0.8342 - val_val_aggregated_jaccard_index: 0.7087 - lr: 0.0010
# Epoch 23/150
# 86/86 [==============================] - ETA: 0s - loss: 1.0272 - accuracy: 0.9341 - iou_coef: 0.7292 - dice_coef: 0.8417 - f1_score: 0.8442 - aggregated_jaccard_index: 0.7317
# ✅ Saved improved backbone at epoch 23 with val_iou=0.7205
# 86/86 [==============================] - 14s 112ms/step - loss: 1.0232 - accuracy: 0.9341 - iou_coef: 0.7292 - dice_coef: 0.8417 - f1_score: 0.8442 - aggregated_jaccard_index: 0.7317 - val_val_loss: 1.0582 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7205 - val_val_dice_coef: 0.8372 - val_val_f1_score: 0.8406 - val_val_aggregated_jaccard_index: 0.7179 - lr: 0.0010
# Epoch 24/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.9847 - accuracy: 0.9353 - iou_coef: 0.7343 - dice_coef: 0.8452 - f1_score: 0.8476 - aggregated_jaccard_index: 0.7353 - val_val_loss: 1.2990 - val_val_accuracy: 0.9249 - val_val_iou_coef: 0.6384 - val_val_dice_coef: 0.7699 - val_val_f1_score: 0.7707 - val_val_aggregated_jaccard_index: 0.6460 - lr: 0.0010
# Epoch 25/150
# 86/86 [==============================] - 16s 111ms/step - loss: 0.9525 - accuracy: 0.9352 - iou_coef: 0.7338 - dice_coef: 0.8449 - f1_score: 0.8471 - aggregated_jaccard_index: 0.7357 - val_val_loss: 1.1005 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6879 - val_val_dice_coef: 0.8128 - val_val_f1_score: 0.8139 - val_val_aggregated_jaccard_index: 0.6900 - lr: 0.0010
# Epoch 26/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.9132 - accuracy: 0.9367 - iou_coef: 0.7379 - dice_coef: 0.8478 - f1_score: 0.8501 - aggregated_jaccard_index: 0.7403 - val_val_loss: 1.0729 - val_val_accuracy: 0.9335 - val_val_iou_coef: 0.6976 - val_val_dice_coef: 0.8207 - val_val_f1_score: 0.8234 - val_val_aggregated_jaccard_index: 0.6893 - lr: 0.0010
# Epoch 27/150
# 86/86 [==============================] - 16s 132ms/step - loss: 0.8861 - accuracy: 0.9364 - iou_coef: 0.7387 - dice_coef: 0.8481 - f1_score: 0.8503 - aggregated_jaccard_index: 0.7399 - val_val_loss: 1.0689 - val_val_accuracy: 0.9322 - val_val_iou_coef: 0.6877 - val_val_dice_coef: 0.8134 - val_val_f1_score: 0.8154 - val_val_aggregated_jaccard_index: 0.6814 - lr: 0.0010
# Epoch 28/150
# 86/86 [==============================] - ETA: 0s - loss: 0.8673 - accuracy: 0.9363 - iou_coef: 0.7363 - dice_coef: 0.8467 - f1_score: 0.8489 - aggregated_jaccard_index: 0.7384
# ✅ Saved improved backbone at epoch 28 with val_iou=0.7264
# 86/86 [==============================] - 14s 112ms/step - loss: 0.8671 - accuracy: 0.9363 - iou_coef: 0.7363 - dice_coef: 0.8467 - f1_score: 0.8489 - aggregated_jaccard_index: 0.7384 - val_val_loss: 0.9145 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.7264 - val_val_dice_coef: 0.8410 - val_val_f1_score: 0.8443 - val_val_aggregated_jaccard_index: 0.7182 - lr: 0.0010
# Epoch 29/150
# 86/86 [==============================] - 16s 132ms/step - loss: 0.8359 - accuracy: 0.9366 - iou_coef: 0.7381 - dice_coef: 0.8478 - f1_score: 0.8500 - aggregated_jaccard_index: 0.7405 - val_val_loss: 1.0141 - val_val_accuracy: 0.9314 - val_val_iou_coef: 0.6783 - val_val_dice_coef: 0.8057 - val_val_f1_score: 0.8076 - val_val_aggregated_jaccard_index: 0.6792 - lr: 0.0010
# Epoch 30/150
# 86/86 [==============================] - ETA: 0s - loss: 0.8152 - accuracy: 0.9361 - iou_coef: 0.7381 - dice_coef: 0.8478 - f1_score: 0.8499 - aggregated_jaccard_index: 0.7387
# ✅ Saved improved backbone at epoch 30 with val_iou=0.7313
# 86/86 [==============================] - 14s 113ms/step - loss: 0.8121 - accuracy: 0.9361 - iou_coef: 0.7381 - dice_coef: 0.8478 - f1_score: 0.8499 - aggregated_jaccard_index: 0.7387 - val_val_loss: 0.8446 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7313 - val_val_dice_coef: 0.8443 - val_val_f1_score: 0.8467 - val_val_aggregated_jaccard_index: 0.7233 - lr: 0.0010
# Epoch 31/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.7577 - accuracy: 0.9393 - iou_coef: 0.7478 - dice_coef: 0.8544 - f1_score: 0.8565 - aggregated_jaccard_index: 0.7495 - val_val_loss: 0.8816 - val_val_accuracy: 0.9358 - val_val_iou_coef: 0.7071 - val_val_dice_coef: 0.8277 - val_val_f1_score: 0.8298 - val_val_aggregated_jaccard_index: 0.7028 - lr: 0.0010
# Epoch 32/150
# 86/86 [==============================] - 16s 113ms/step - loss: 0.7445 - accuracy: 0.9383 - iou_coef: 0.7437 - dice_coef: 0.8516 - f1_score: 0.8536 - aggregated_jaccard_index: 0.7460 - val_val_loss: 0.8513 - val_val_accuracy: 0.9359 - val_val_iou_coef: 0.7139 - val_val_dice_coef: 0.8321 - val_val_f1_score: 0.8342 - val_val_aggregated_jaccard_index: 0.7027 - lr: 0.0010
# Epoch 33/150
# 86/86 [==============================] - ETA: 0s - loss: 0.7093 - accuracy: 0.9395 - iou_coef: 0.7490 - dice_coef: 0.8552 - f1_score: 0.8572 - aggregated_jaccard_index: 0.7498
# ✅ Saved improved backbone at epoch 33 with val_iou=0.7316
# 86/86 [==============================] - 14s 112ms/step - loss: 0.7119 - accuracy: 0.9395 - iou_coef: 0.7490 - dice_coef: 0.8552 - f1_score: 0.8572 - aggregated_jaccard_index: 0.7498 - val_val_loss: 0.7695 - val_val_accuracy: 0.9401 - val_val_iou_coef: 0.7316 - val_val_dice_coef: 0.8445 - val_val_f1_score: 0.8484 - val_val_aggregated_jaccard_index: 0.7224 - lr: 0.0010
# Epoch 34/150
# 86/86 [==============================] - 16s 132ms/step - loss: 0.6715 - accuracy: 0.9401 - iou_coef: 0.7524 - dice_coef: 0.8574 - f1_score: 0.8594 - aggregated_jaccard_index: 0.7546 - val_val_loss: 0.8979 - val_val_accuracy: 0.9291 - val_val_iou_coef: 0.6750 - val_val_dice_coef: 0.8023 - val_val_f1_score: 0.8030 - val_val_aggregated_jaccard_index: 0.6668 - lr: 0.0010
# Epoch 35/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.6561 - accuracy: 0.9404 - iou_coef: 0.7510 - dice_coef: 0.8566 - f1_score: 0.8585 - aggregated_jaccard_index: 0.7536 - val_val_loss: 0.7866 - val_val_accuracy: 0.9344 - val_val_iou_coef: 0.7032 - val_val_dice_coef: 0.8242 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.6970 - lr: 0.0010
# Epoch 36/150
# 86/86 [==============================] - 16s 133ms/step - loss: 0.6327 - accuracy: 0.9412 - iou_coef: 0.7530 - dice_coef: 0.8579 - f1_score: 0.8598 - aggregated_jaccard_index: 0.7548 - val_val_loss: 0.7812 - val_val_accuracy: 0.9336 - val_val_iou_coef: 0.6983 - val_val_dice_coef: 0.8206 - val_val_f1_score: 0.8225 - val_val_aggregated_jaccard_index: 0.6895 - lr: 0.0010
# Epoch 37/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.6075 - accuracy: 0.9414 - iou_coef: 0.7544 - dice_coef: 0.8587 - f1_score: 0.8606 - aggregated_jaccard_index: 0.7558 - val_val_loss: 0.6933 - val_val_accuracy: 0.9371 - val_val_iou_coef: 0.7302 - val_val_dice_coef: 0.8428 - val_val_f1_score: 0.8453 - val_val_aggregated_jaccard_index: 0.7137 - lr: 0.0010
# Epoch 38/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.5797 - accuracy: 0.9422 - iou_coef: 0.7581 - dice_coef: 0.8612 - f1_score: 0.8632 - aggregated_jaccard_index: 0.7596 - val_val_loss: 0.7383 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6966 - val_val_dice_coef: 0.8198 - val_val_f1_score: 0.8208 - val_val_aggregated_jaccard_index: 0.6867 - lr: 0.0010
# Epoch 39/150
# 86/86 [==============================] - 16s 110ms/step - loss: 0.5609 - accuracy: 0.9419 - iou_coef: 0.7569 - dice_coef: 0.8604 - f1_score: 0.8623 - aggregated_jaccard_index: 0.7579 - val_val_loss: 0.6918 - val_val_accuracy: 0.9347 - val_val_iou_coef: 0.7015 - val_val_dice_coef: 0.8238 - val_val_f1_score: 0.8251 - val_val_aggregated_jaccard_index: 0.6954 - lr: 0.0010
# Epoch 40/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.5440 - accuracy: 0.9418 - iou_coef: 0.7562 - dice_coef: 0.8600 - f1_score: 0.8618 - aggregated_jaccard_index: 0.7573 - val_val_loss: 0.6221 - val_val_accuracy: 0.9376 - val_val_iou_coef: 0.7286 - val_val_dice_coef: 0.8421 - val_val_f1_score: 0.8438 - val_val_aggregated_jaccard_index: 0.7144 - lr: 0.0010
# Epoch 41/150
# 86/86 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.9433 - iou_coef: 0.7636 - dice_coef: 0.8648 - f1_score: 0.8667 - aggregated_jaccard_index: 0.7645
# ✅ Saved improved backbone at epoch 41 with val_iou=0.7336
# 86/86 [==============================] - 16s 135ms/step - loss: 0.5051 - accuracy: 0.9433 - iou_coef: 0.7636 - dice_coef: 0.8648 - f1_score: 0.8667 - aggregated_jaccard_index: 0.7645 - val_val_loss: 0.5810 - val_val_accuracy: 0.9400 - val_val_iou_coef: 0.7336 - val_val_dice_coef: 0.8457 - val_val_f1_score: 0.8477 - val_val_aggregated_jaccard_index: 0.7241 - lr: 0.0010
# Epoch 42/150
# 86/86 [==============================] - 14s 109ms/step - loss: 0.4838 - accuracy: 0.9438 - iou_coef: 0.7652 - dice_coef: 0.8659 - f1_score: 0.8676 - aggregated_jaccard_index: 0.7667 - val_val_loss: 0.6392 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.7008 - val_val_dice_coef: 0.8226 - val_val_f1_score: 0.8238 - val_val_aggregated_jaccard_index: 0.6865 - lr: 0.0010
# Epoch 43/150
# 86/86 [==============================] - 16s 136ms/step - loss: 0.4625 - accuracy: 0.9445 - iou_coef: 0.7668 - dice_coef: 0.8668 - f1_score: 0.8685 - aggregated_jaccard_index: 0.7684 - val_val_loss: 0.5573 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.7292 - val_val_dice_coef: 0.8420 - val_val_f1_score: 0.8436 - val_val_aggregated_jaccard_index: 0.7150 - lr: 0.0010
# Epoch 44/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.4496 - accuracy: 0.9445 - iou_coef: 0.7669 - dice_coef: 0.8670 - f1_score: 0.8687 - aggregated_jaccard_index: 0.7678 - val_val_loss: 0.6052 - val_val_accuracy: 0.9319 - val_val_iou_coef: 0.6941 - val_val_dice_coef: 0.8173 - val_val_f1_score: 0.8186 - val_val_aggregated_jaccard_index: 0.6806 - lr: 0.0010
# Epoch 45/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.4345 - accuracy: 0.9450 - iou_coef: 0.7682 - dice_coef: 0.8677 - f1_score: 0.8695 - aggregated_jaccard_index: 0.7685 - val_val_loss: 0.5354 - val_val_accuracy: 0.9362 - val_val_iou_coef: 0.7170 - val_val_dice_coef: 0.8340 - val_val_f1_score: 0.8355 - val_val_aggregated_jaccard_index: 0.7056 - lr: 0.0010
# Epoch 46/150
# 86/86 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.9445 - iou_coef: 0.7657 - dice_coef: 0.8660 - f1_score: 0.8677 - aggregated_jaccard_index: 0.7669
# ✅ Saved improved backbone at epoch 46 with val_iou=0.7400
# 86/86 [==============================] - 16s 113ms/step - loss: 0.4209 - accuracy: 0.9445 - iou_coef: 0.7657 - dice_coef: 0.8660 - f1_score: 0.8677 - aggregated_jaccard_index: 0.7669 - val_val_loss: 0.4772 - val_val_accuracy: 0.9406 - val_val_iou_coef: 0.7400 - val_val_dice_coef: 0.8497 - val_val_f1_score: 0.8513 - val_val_aggregated_jaccard_index: 0.7269 - lr: 0.0010
# Epoch 47/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.3995 - accuracy: 0.9447 - iou_coef: 0.7677 - dice_coef: 0.8674 - f1_score: 0.8692 - aggregated_jaccard_index: 0.7690 - val_val_loss: 0.5037 - val_val_accuracy: 0.9354 - val_val_iou_coef: 0.6989 - val_val_dice_coef: 0.8210 - val_val_f1_score: 0.8222 - val_val_aggregated_jaccard_index: 0.7014 - lr: 0.0010
# Epoch 48/150
# 86/86 [==============================] - 16s 131ms/step - loss: 0.3748 - accuracy: 0.9462 - iou_coef: 0.7725 - dice_coef: 0.8706 - f1_score: 0.8722 - aggregated_jaccard_index: 0.7744 - val_val_loss: 0.4804 - val_val_accuracy: 0.9364 - val_val_iou_coef: 0.7183 - val_val_dice_coef: 0.8349 - val_val_f1_score: 0.8364 - val_val_aggregated_jaccard_index: 0.7040 - lr: 0.0010
# Epoch 49/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.3585 - accuracy: 0.9460 - iou_coef: 0.7730 - dice_coef: 0.8709 - f1_score: 0.8725 - aggregated_jaccard_index: 0.7745 - val_val_loss: 0.4800 - val_val_accuracy: 0.9333 - val_val_iou_coef: 0.7046 - val_val_dice_coef: 0.8256 - val_val_f1_score: 0.8273 - val_val_aggregated_jaccard_index: 0.6918 - lr: 0.0010
# Epoch 50/150
# 86/86 [==============================] - 16s 130ms/step - loss: 0.3469 - accuracy: 0.9466 - iou_coef: 0.7741 - dice_coef: 0.8717 - f1_score: 0.8732 - aggregated_jaccard_index: 0.7746 - val_val_loss: 0.4260 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.7291 - val_val_dice_coef: 0.8423 - val_val_f1_score: 0.8439 - val_val_aggregated_jaccard_index: 0.7156 - lr: 0.0010
# Epoch 51/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.3286 - accuracy: 0.9470 - iou_coef: 0.7764 - dice_coef: 0.8731 - f1_score: 0.8748 - aggregated_jaccard_index: 0.7776 - val_val_loss: 0.4221 - val_val_accuracy: 0.9367 - val_val_iou_coef: 0.7189 - val_val_dice_coef: 0.8350 - val_val_f1_score: 0.8366 - val_val_aggregated_jaccard_index: 0.7065 - lr: 0.0010
# Epoch 52/150
# 86/86 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.9480 - iou_coef: 0.7792 - dice_coef: 0.8750 - f1_score: 0.8766 - aggregated_jaccard_index: 0.7804
# ✅ Saved improved backbone at epoch 52 with val_iou=0.7413
# 86/86 [==============================] - 16s 135ms/step - loss: 0.3108 - accuracy: 0.9480 - iou_coef: 0.7792 - dice_coef: 0.8750 - f1_score: 0.8766 - aggregated_jaccard_index: 0.7804 - val_val_loss: 0.3777 - val_val_accuracy: 0.9400 - val_val_iou_coef: 0.7413 - val_val_dice_coef: 0.8504 - val_val_f1_score: 0.8524 - val_val_aggregated_jaccard_index: 0.7260 - lr: 0.0010
# Epoch 53/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.3002 - accuracy: 0.9479 - iou_coef: 0.7785 - dice_coef: 0.8745 - f1_score: 0.8761 - aggregated_jaccard_index: 0.7799 - val_val_loss: 0.3867 - val_val_accuracy: 0.9373 - val_val_iou_coef: 0.7253 - val_val_dice_coef: 0.8397 - val_val_f1_score: 0.8409 - val_val_aggregated_jaccard_index: 0.7095 - lr: 0.0010
# Epoch 54/150
# 86/86 [==============================] - 14s 111ms/step - loss: 0.2836 - accuracy: 0.9490 - iou_coef: 0.7830 - dice_coef: 0.8774 - f1_score: 0.8790 - aggregated_jaccard_index: 0.7842 - val_val_loss: 0.3724 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.7256 - val_val_dice_coef: 0.8396 - val_val_f1_score: 0.8409 - val_val_aggregated_jaccard_index: 0.7086 - lr: 0.0010
# Epoch 55/150
# 86/86 [==============================] - 16s 111ms/step - loss: 0.2731 - accuracy: 0.9488 - iou_coef: 0.7824 - dice_coef: 0.8770 - f1_score: 0.8785 - aggregated_jaccard_index: 0.7831 - val_val_loss: 0.3565 - val_val_accuracy: 0.9376 - val_val_iou_coef: 0.7195 - val_val_dice_coef: 0.8357 - val_val_f1_score: 0.8371 - val_val_aggregated_jaccard_index: 0.7098 - lr: 0.0010
# Epoch 56/150
# 86/86 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.9495 - iou_coef: 0.7841 - dice_coef: 0.8780 - f1_score: 0.8795 - aggregated_jaccard_index: 0.7860
# ✅ Saved improved backbone at epoch 56 with val_iou=0.7431
# 86/86 [==============================] - 14s 112ms/step - loss: 0.2591 - accuracy: 0.9495 - iou_coef: 0.7841 - dice_coef: 0.8780 - f1_score: 0.8795 - aggregated_jaccard_index: 0.7860 - val_val_loss: 0.3154 - val_val_accuracy: 0.9407 - val_val_iou_coef: 0.7431 - val_val_dice_coef: 0.8520 - val_val_f1_score: 0.8537 - val_val_aggregated_jaccard_index: 0.7316 - lr: 0.0010
# Epoch 57/150
# 86/86 [==============================] - 16s 134ms/step - loss: 0.2438 - accuracy: 0.9496 - iou_coef: 0.7871 - dice_coef: 0.8800 - f1_score: 0.8815 - aggregated_jaccard_index: 0.7887 - val_val_loss: 0.3876 - val_val_accuracy: 0.9274 - val_val_iou_coef: 0.6637 - val_val_dice_coef: 0.7932 - val_val_f1_score: 0.7938 - val_val_aggregated_jaccard_index: 0.6589 - lr: 0.0010
# Epoch 58/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.2404 - accuracy: 0.9493 - iou_coef: 0.7835 - dice_coef: 0.8776 - f1_score: 0.8791 - aggregated_jaccard_index: 0.7850 - val_val_loss: 0.3262 - val_val_accuracy: 0.9353 - val_val_iou_coef: 0.7198 - val_val_dice_coef: 0.8352 - val_val_f1_score: 0.8363 - val_val_aggregated_jaccard_index: 0.6998 - lr: 0.0010
# Epoch 59/150
# 86/86 [==============================] - ETA: 0s - loss: 0.2270 - accuracy: 0.9497 - iou_coef: 0.7858 - dice_coef: 0.8791 - f1_score: 0.8806 - aggregated_jaccard_index: 0.7875
# ✅ Saved improved backbone at epoch 59 with val_iou=0.7444
# 86/86 [==============================] - 16s 133ms/step - loss: 0.2275 - accuracy: 0.9497 - iou_coef: 0.7858 - dice_coef: 0.8791 - f1_score: 0.8806 - aggregated_jaccard_index: 0.7875 - val_val_loss: 0.2816 - val_val_accuracy: 0.9407 - val_val_iou_coef: 0.7444 - val_val_dice_coef: 0.8525 - val_val_f1_score: 0.8537 - val_val_aggregated_jaccard_index: 0.7290 - lr: 0.0010
# Epoch 60/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.2148 - accuracy: 0.9504 - iou_coef: 0.7886 - dice_coef: 0.8809 - f1_score: 0.8824 - aggregated_jaccard_index: 0.7901 - val_val_loss: 0.2792 - val_val_accuracy: 0.9382 - val_val_iou_coef: 0.7349 - val_val_dice_coef: 0.8464 - val_val_f1_score: 0.8478 - val_val_aggregated_jaccard_index: 0.7203 - lr: 0.0010
# Epoch 61/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.2064 - accuracy: 0.9506 - iou_coef: 0.7889 - dice_coef: 0.8810 - f1_score: 0.8824 - aggregated_jaccard_index: 0.7911 - val_val_loss: 0.2701 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7337 - val_val_dice_coef: 0.8452 - val_val_f1_score: 0.8464 - val_val_aggregated_jaccard_index: 0.7183 - lr: 0.0010
# Epoch 62/150
# 86/86 [==============================] - 16s 114ms/step - loss: 0.1935 - accuracy: 0.9518 - iou_coef: 0.7935 - dice_coef: 0.8840 - f1_score: 0.8854 - aggregated_jaccard_index: 0.7952 - val_val_loss: 0.2611 - val_val_accuracy: 0.9379 - val_val_iou_coef: 0.7353 - val_val_dice_coef: 0.8460 - val_val_f1_score: 0.8472 - val_val_aggregated_jaccard_index: 0.7160 - lr: 0.0010
# Epoch 63/150
# 86/86 [==============================] - 14s 110ms/step - loss: 0.1842 - accuracy: 0.9520 - iou_coef: 0.7949 - dice_coef: 0.8848 - f1_score: 0.8863 - aggregated_jaccard_index: 0.7957 - val_val_loss: 0.2490 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.7384 - val_val_dice_coef: 0.8480 - val_val_f1_score: 0.8492 - val_val_aggregated_jaccard_index: 0.7179 - lr: 0.0010
# Epoch 64/150
# 86/86 [==============================] - 16s 133ms/step - loss: 0.1774 - accuracy: 0.9518 - iou_coef: 0.7942 - dice_coef: 0.8844 - f1_score: 0.8859 - aggregated_jaccard_index: 0.7957 - val_val_loss: 0.2628 - val_val_accuracy: 0.9342 - val_val_iou_coef: 0.7100 - val_val_dice_coef: 0.8284 - val_val_f1_score: 0.8297 - val_val_aggregated_jaccard_index: 0.6914 - lr: 0.0010
# Epoch 65/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1701 - accuracy: 0.9523 - iou_coef: 0.7954 - dice_coef: 0.8852 - f1_score: 0.8867 - aggregated_jaccard_index: 0.7958 - val_val_loss: 0.2243 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7382 - val_val_dice_coef: 0.8485 - val_val_f1_score: 0.8500 - val_val_aggregated_jaccard_index: 0.7241 - lr: 0.0010
# Epoch 66/150
# 86/86 [==============================] - 16s 133ms/step - loss: 0.1634 - accuracy: 0.9524 - iou_coef: 0.7954 - dice_coef: 0.8852 - f1_score: 0.8865 - aggregated_jaccard_index: 0.7968 - val_val_loss: 0.2265 - val_val_accuracy: 0.9371 - val_val_iou_coef: 0.7279 - val_val_dice_coef: 0.8413 - val_val_f1_score: 0.8420 - val_val_aggregated_jaccard_index: 0.7103 - lr: 0.0010
# Epoch 67/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.1551 - accuracy: 0.9527 - iou_coef: 0.7965 - dice_coef: 0.8859 - f1_score: 0.8874 - aggregated_jaccard_index: 0.7983 - val_val_loss: 0.2264 - val_val_accuracy: 0.9353 - val_val_iou_coef: 0.7211 - val_val_dice_coef: 0.8355 - val_val_f1_score: 0.8366 - val_val_aggregated_jaccard_index: 0.6979 - lr: 0.0010
# Epoch 68/150
# 86/86 [==============================] - 14s 115ms/step - loss: 0.1486 - accuracy: 0.9525 - iou_coef: 0.7964 - dice_coef: 0.8858 - f1_score: 0.8872 - aggregated_jaccard_index: 0.7982 - val_val_loss: 0.1992 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7399 - val_val_dice_coef: 0.8492 - val_val_f1_score: 0.8503 - val_val_aggregated_jaccard_index: 0.7220 - lr: 0.0010
# Epoch 69/150
# 86/86 [==============================] - ETA: 0s - loss: 0.1405 - accuracy: 0.9531 - iou_coef: 0.7988 - dice_coef: 0.8873 - f1_score: 0.8888 - aggregated_jaccard_index: 0.8011
# Epoch 69: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 86/86 [==============================] - 17s 130ms/step - loss: 0.1400 - accuracy: 0.9531 - iou_coef: 0.7988 - dice_coef: 0.8873 - f1_score: 0.8888 - aggregated_jaccard_index: 0.8011 - val_val_loss: 0.1953 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7311 - val_val_dice_coef: 0.8438 - val_val_f1_score: 0.8452 - val_val_aggregated_jaccard_index: 0.7180 - lr: 0.0010
# Epoch 70/150
# 86/86 [==============================] - 16s 130ms/step - loss: 0.1350 - accuracy: 0.9545 - iou_coef: 0.8035 - dice_coef: 0.8903 - f1_score: 0.8917 - aggregated_jaccard_index: 0.8046 - val_val_loss: 0.1865 - val_val_accuracy: 0.9411 - val_val_iou_coef: 0.7441 - val_val_dice_coef: 0.8524 - val_val_f1_score: 0.8532 - val_val_aggregated_jaccard_index: 0.7287 - lr: 1.0000e-04
# Epoch 71/150
# 86/86 [==============================] - 17s 131ms/step - loss: 0.1340 - accuracy: 0.9549 - iou_coef: 0.8047 - dice_coef: 0.8910 - f1_score: 0.8924 - aggregated_jaccard_index: 0.8059 - val_val_loss: 0.1915 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7404 - val_val_dice_coef: 0.8491 - val_val_f1_score: 0.8501 - val_val_aggregated_jaccard_index: 0.7196 - lr: 1.0000e-04
# Epoch 72/150
# 86/86 [==============================] - ETA: 0s - loss: 0.1326 - accuracy: 0.9550 - iou_coef: 0.8045 - dice_coef: 0.8909 - f1_score: 0.8922 - aggregated_jaccard_index: 0.8061
# ✅ Saved improved backbone at epoch 72 with val_iou=0.7451
# 86/86 [==============================] - 16s 131ms/step - loss: 0.1332 - accuracy: 0.9550 - iou_coef: 0.8045 - dice_coef: 0.8909 - f1_score: 0.8922 - aggregated_jaccard_index: 0.8061 - val_val_loss: 0.1863 - val_val_accuracy: 0.9406 - val_val_iou_coef: 0.7451 - val_val_dice_coef: 0.8525 - val_val_f1_score: 0.8537 - val_val_aggregated_jaccard_index: 0.7262 - lr: 1.0000e-04
# Epoch 73/150
# 86/86 [==============================] - 17s 127ms/step - loss: 0.1293 - accuracy: 0.9554 - iou_coef: 0.8079 - dice_coef: 0.8929 - f1_score: 0.8943 - aggregated_jaccard_index: 0.8093 - val_val_loss: 0.1854 - val_val_accuracy: 0.9408 - val_val_iou_coef: 0.7438 - val_val_dice_coef: 0.8519 - val_val_f1_score: 0.8536 - val_val_aggregated_jaccard_index: 0.7266 - lr: 1.0000e-04
# Epoch 74/150
# 86/86 [==============================] - 15s 127ms/step - loss: 0.1298 - accuracy: 0.9553 - iou_coef: 0.8068 - dice_coef: 0.8923 - f1_score: 0.8937 - aggregated_jaccard_index: 0.8084 - val_val_loss: 0.1853 - val_val_accuracy: 0.9403 - val_val_iou_coef: 0.7421 - val_val_dice_coef: 0.8508 - val_val_f1_score: 0.8523 - val_val_aggregated_jaccard_index: 0.7253 - lr: 1.0000e-04
# Epoch 75/150
# 86/86 [==============================] - 16s 141ms/step - loss: 0.1285 - accuracy: 0.9557 - iou_coef: 0.8078 - dice_coef: 0.8929 - f1_score: 0.8944 - aggregated_jaccard_index: 0.8097 - val_val_loss: 0.1837 - val_val_accuracy: 0.9405 - val_val_iou_coef: 0.7437 - val_val_dice_coef: 0.8518 - val_val_f1_score: 0.8533 - val_val_aggregated_jaccard_index: 0.7263 - lr: 1.0000e-04
# Epoch 76/150
# 86/86 [==============================] - 14s 109ms/step - loss: 0.1286 - accuracy: 0.9555 - iou_coef: 0.8078 - dice_coef: 0.8930 - f1_score: 0.8944 - aggregated_jaccard_index: 0.8086 - val_val_loss: 0.1858 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7408 - val_val_dice_coef: 0.8497 - val_val_f1_score: 0.8512 - val_val_aggregated_jaccard_index: 0.7220 - lr: 1.0000e-04
# Epoch 77/150
# 86/86 [==============================] - 16s 136ms/step - loss: 0.1275 - accuracy: 0.9557 - iou_coef: 0.8081 - dice_coef: 0.8931 - f1_score: 0.8945 - aggregated_jaccard_index: 0.8100 - val_val_loss: 0.1888 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.7362 - val_val_dice_coef: 0.8464 - val_val_f1_score: 0.8478 - val_val_aggregated_jaccard_index: 0.7162 - lr: 1.0000e-04
# Epoch 78/150
# 86/86 [==============================] - 14s 108ms/step - loss: 0.1274 - accuracy: 0.9555 - iou_coef: 0.8077 - dice_coef: 0.8929 - f1_score: 0.8943 - aggregated_jaccard_index: 0.8087 - val_val_loss: 0.1830 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7414 - val_val_dice_coef: 0.8502 - val_val_f1_score: 0.8518 - val_val_aggregated_jaccard_index: 0.7235 - lr: 1.0000e-04
# Epoch 79/150
# 86/86 [==============================] - 16s 134ms/step - loss: 0.1256 - accuracy: 0.9559 - iou_coef: 0.8089 - dice_coef: 0.8936 - f1_score: 0.8950 - aggregated_jaccard_index: 0.8104 - val_val_loss: 0.1850 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7381 - val_val_dice_coef: 0.8479 - val_val_f1_score: 0.8495 - val_val_aggregated_jaccard_index: 0.7193 - lr: 1.0000e-04
# Epoch 80/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.1252 - accuracy: 0.9559 - iou_coef: 0.8087 - dice_coef: 0.8935 - f1_score: 0.8949 - aggregated_jaccard_index: 0.8101 - val_val_loss: 0.1805 - val_val_accuracy: 0.9399 - val_val_iou_coef: 0.7434 - val_val_dice_coef: 0.8514 - val_val_f1_score: 0.8525 - val_val_aggregated_jaccard_index: 0.7245 - lr: 1.0000e-04
# Epoch 81/150
# 86/86 [==============================] - 15s 120ms/step - loss: 0.1243 - accuracy: 0.9559 - iou_coef: 0.8088 - dice_coef: 0.8935 - f1_score: 0.8949 - aggregated_jaccard_index: 0.8110 - val_val_loss: 0.1781 - val_val_accuracy: 0.9404 - val_val_iou_coef: 0.7451 - val_val_dice_coef: 0.8526 - val_val_f1_score: 0.8542 - val_val_aggregated_jaccard_index: 0.7268 - lr: 1.0000e-04
# Epoch 82/150
# 86/86 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9561 - iou_coef: 0.8106 - dice_coef: 0.8946 - f1_score: 0.8961 - aggregated_jaccard_index: 0.8118
# ✅ Saved improved backbone at epoch 82 with val_iou=0.7462
# 86/86 [==============================] - 18s 131ms/step - loss: 0.1225 - accuracy: 0.9561 - iou_coef: 0.8106 - dice_coef: 0.8946 - f1_score: 0.8961 - aggregated_jaccard_index: 0.8118 - val_val_loss: 0.1756 - val_val_accuracy: 0.9408 - val_val_iou_coef: 0.7462 - val_val_dice_coef: 0.8536 - val_val_f1_score: 0.8550 - val_val_aggregated_jaccard_index: 0.7293 - lr: 1.0000e-04
# Epoch 83/150
# 86/86 [==============================] - 15s 129ms/step - loss: 0.1223 - accuracy: 0.9561 - iou_coef: 0.8099 - dice_coef: 0.8942 - f1_score: 0.8956 - aggregated_jaccard_index: 0.8118 - val_val_loss: 0.1817 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.7376 - val_val_dice_coef: 0.8475 - val_val_f1_score: 0.8486 - val_val_aggregated_jaccard_index: 0.7186 - lr: 1.0000e-04
# Epoch 84/150
# 86/86 [==============================] - 17s 151ms/step - loss: 0.1214 - accuracy: 0.9562 - iou_coef: 0.8109 - dice_coef: 0.8949 - f1_score: 0.8963 - aggregated_jaccard_index: 0.8119 - val_val_loss: 0.1784 - val_val_accuracy: 0.9395 - val_val_iou_coef: 0.7400 - val_val_dice_coef: 0.8493 - val_val_f1_score: 0.8503 - val_val_aggregated_jaccard_index: 0.7223 - lr: 1.0000e-04
# Epoch 85/150
# 86/86 [==============================] - 15s 128ms/step - loss: 0.1211 - accuracy: 0.9562 - iou_coef: 0.8099 - dice_coef: 0.8942 - f1_score: 0.8956 - aggregated_jaccard_index: 0.8115 - val_val_loss: 0.1766 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7420 - val_val_dice_coef: 0.8506 - val_val_f1_score: 0.8521 - val_val_aggregated_jaccard_index: 0.7236 - lr: 1.0000e-04
# Epoch 86/150
# 86/86 [==============================] - 17s 151ms/step - loss: 0.1232 - accuracy: 0.9559 - iou_coef: 0.8078 - dice_coef: 0.8928 - f1_score: 0.8943 - aggregated_jaccard_index: 0.8088 - val_val_loss: 0.1806 - val_val_accuracy: 0.9380 - val_val_iou_coef: 0.7352 - val_val_dice_coef: 0.8459 - val_val_f1_score: 0.8469 - val_val_aggregated_jaccard_index: 0.7158 - lr: 1.0000e-04
# Epoch 87/150
# 86/86 [==============================] - 15s 129ms/step - loss: 0.1184 - accuracy: 0.9563 - iou_coef: 0.8116 - dice_coef: 0.8952 - f1_score: 0.8966 - aggregated_jaccard_index: 0.8129 - val_val_loss: 0.1815 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.7343 - val_val_dice_coef: 0.8450 - val_val_f1_score: 0.8461 - val_val_aggregated_jaccard_index: 0.7131 - lr: 1.0000e-04
# Epoch 88/150
# 86/86 [==============================] - 17s 149ms/step - loss: 0.1203 - accuracy: 0.9562 - iou_coef: 0.8099 - dice_coef: 0.8942 - f1_score: 0.8956 - aggregated_jaccard_index: 0.8113 - val_val_loss: 0.1763 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.7370 - val_val_dice_coef: 0.8473 - val_val_f1_score: 0.8486 - val_val_aggregated_jaccard_index: 0.7195 - lr: 1.0000e-04
# Epoch 89/150
# 86/86 [==============================] - 15s 127ms/step - loss: 0.1201 - accuracy: 0.9561 - iou_coef: 0.8093 - dice_coef: 0.8938 - f1_score: 0.8952 - aggregated_jaccard_index: 0.8102 - val_val_loss: 0.1728 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7400 - val_val_dice_coef: 0.8495 - val_val_f1_score: 0.8505 - val_val_aggregated_jaccard_index: 0.7237 - lr: 1.0000e-04
# Epoch 90/150
# 86/86 [==============================] - 18s 155ms/step - loss: 0.1189 - accuracy: 0.9559 - iou_coef: 0.8087 - dice_coef: 0.8935 - f1_score: 0.8949 - aggregated_jaccard_index: 0.8099 - val_val_loss: 0.1755 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7335 - val_val_dice_coef: 0.8453 - val_val_f1_score: 0.8464 - val_val_aggregated_jaccard_index: 0.7180 - lr: 1.0000e-04
# Epoch 91/150
# 86/86 [==============================] - 15s 128ms/step - loss: 0.1179 - accuracy: 0.9560 - iou_coef: 0.8092 - dice_coef: 0.8938 - f1_score: 0.8951 - aggregated_jaccard_index: 0.8106 - val_val_loss: 0.1707 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7412 - val_val_dice_coef: 0.8501 - val_val_f1_score: 0.8512 - val_val_aggregated_jaccard_index: 0.7236 - lr: 1.0000e-04
# Epoch 92/150
# 86/86 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9563 - iou_coef: 0.8106 - dice_coef: 0.8947 - f1_score: 0.8961 - aggregated_jaccard_index: 0.8119
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 86/86 [==============================] - 18s 155ms/step - loss: 0.1159 - accuracy: 0.9563 - iou_coef: 0.8106 - dice_coef: 0.8947 - f1_score: 0.8961 - aggregated_jaccard_index: 0.8119 - val_val_loss: 0.1742 - val_val_accuracy: 0.9383 - val_val_iou_coef: 0.7351 - val_val_dice_coef: 0.8458 - val_val_f1_score: 0.8467 - val_val_aggregated_jaccard_index: 0.7163 - lr: 1.0000e-04
# Epoch 93/150
# 86/86 [==============================] - 15s 129ms/step - loss: 0.1150 - accuracy: 0.9566 - iou_coef: 0.8115 - dice_coef: 0.8952 - f1_score: 0.8966 - aggregated_jaccard_index: 0.8137 - val_val_loss: 0.1722 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.7376 - val_val_dice_coef: 0.8476 - val_val_f1_score: 0.8487 - val_val_aggregated_jaccard_index: 0.7194 - lr: 1.0000e-05
# Epoch 94/150
# 86/86 [==============================] - 18s 154ms/step - loss: 0.1147 - accuracy: 0.9566 - iou_coef: 0.8124 - dice_coef: 0.8958 - f1_score: 0.8971 - aggregated_jaccard_index: 0.8134 - val_val_loss: 0.1718 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7379 - val_val_dice_coef: 0.8479 - val_val_f1_score: 0.8487 - val_val_aggregated_jaccard_index: 0.7201 - lr: 1.0000e-05
# Epoch 95/150
# 86/86 [==============================] - 16s 130ms/step - loss: 0.1151 - accuracy: 0.9567 - iou_coef: 0.8121 - dice_coef: 0.8956 - f1_score: 0.8969 - aggregated_jaccard_index: 0.8129 - val_val_loss: 0.1718 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7379 - val_val_dice_coef: 0.8479 - val_val_f1_score: 0.8487 - val_val_aggregated_jaccard_index: 0.7200 - lr: 1.0000e-05
# Epoch 96/150
# 86/86 [==============================] - 17s 151ms/step - loss: 0.1144 - accuracy: 0.9567 - iou_coef: 0.8122 - dice_coef: 0.8956 - f1_score: 0.8970 - aggregated_jaccard_index: 0.8141 - val_val_loss: 0.1717 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7379 - val_val_dice_coef: 0.8478 - val_val_f1_score: 0.8488 - val_val_aggregated_jaccard_index: 0.7199 - lr: 1.0000e-05
# Epoch 97/150
# 86/86 [==============================] - 16s 130ms/step - loss: 0.1140 - accuracy: 0.9567 - iou_coef: 0.8124 - dice_coef: 0.8957 - f1_score: 0.8971 - aggregated_jaccard_index: 0.8143 - val_val_loss: 0.1711 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7385 - val_val_dice_coef: 0.8483 - val_val_f1_score: 0.8492 - val_val_aggregated_jaccard_index: 0.7207 - lr: 1.0000e-05
# Epoch 98/150
# 86/86 [==============================] - 17s 151ms/step - loss: 0.1146 - accuracy: 0.9566 - iou_coef: 0.8119 - dice_coef: 0.8954 - f1_score: 0.8968 - aggregated_jaccard_index: 0.8137 - val_val_loss: 0.1710 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7382 - val_val_dice_coef: 0.8481 - val_val_f1_score: 0.8490 - val_val_aggregated_jaccard_index: 0.7206 - lr: 1.0000e-05
# Epoch 99/150
# 86/86 [==============================] - 16s 130ms/step - loss: 0.1146 - accuracy: 0.9568 - iou_coef: 0.8126 - dice_coef: 0.8959 - f1_score: 0.8973 - aggregated_jaccard_index: 0.8139 - val_val_loss: 0.1710 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7383 - val_val_dice_coef: 0.8482 - val_val_f1_score: 0.8491 - val_val_aggregated_jaccard_index: 0.7205 - lr: 1.0000e-05
# Epoch 100/150
# 86/86 [==============================] - 17s 150ms/step - loss: 0.1149 - accuracy: 0.9565 - iou_coef: 0.8118 - dice_coef: 0.8954 - f1_score: 0.8967 - aggregated_jaccard_index: 0.8129 - val_val_loss: 0.1716 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.7372 - val_val_dice_coef: 0.8474 - val_val_f1_score: 0.8483 - val_val_aggregated_jaccard_index: 0.7195 - lr: 1.0000e-05
# Epoch 101/150
# 86/86 [==============================] - 15s 121ms/step - loss: 0.1145 - accuracy: 0.9568 - iou_coef: 0.8122 - dice_coef: 0.8956 - f1_score: 0.8970 - aggregated_jaccard_index: 0.8136 - val_val_loss: 0.1709 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7380 - val_val_dice_coef: 0.8479 - val_val_f1_score: 0.8490 - val_val_aggregated_jaccard_index: 0.7203 - lr: 1.0000e-05
# Epoch 102/150
# 86/86 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9565 - iou_coef: 0.8105 - dice_coef: 0.8945 - f1_score: 0.8959 - aggregated_jaccard_index: 0.8115
# Epoch 102: ReduceLROnPlateau reducing learning rate to 1e-05.
# 86/86 [==============================] - 16s 130ms/step - loss: 0.1164 - accuracy: 0.9565 - iou_coef: 0.8105 - dice_coef: 0.8945 - f1_score: 0.8959 - aggregated_jaccard_index: 0.8115 - val_val_loss: 0.1699 - val_val_accuracy: 0.9395 - val_val_iou_coef: 0.7396 - val_val_dice_coef: 0.8490 - val_val_f1_score: 0.8503 - val_val_aggregated_jaccard_index: 0.7218 - lr: 1.0000e-05
# Epoch 103/150
# 86/86 [==============================] - 16s 116ms/step - loss: 0.1142 - accuracy: 0.9567 - iou_coef: 0.8126 - dice_coef: 0.8959 - f1_score: 0.8973 - aggregated_jaccard_index: 0.8133 - val_val_loss: 0.1700 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7389 - val_val_dice_coef: 0.8486 - val_val_f1_score: 0.8495 - val_val_aggregated_jaccard_index: 0.7214 - lr: 1.0000e-05
# Epoch 104/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1137 - accuracy: 0.9567 - iou_coef: 0.8128 - dice_coef: 0.8960 - f1_score: 0.8974 - aggregated_jaccard_index: 0.8141 - val_val_loss: 0.1704 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7385 - val_val_dice_coef: 0.8483 - val_val_f1_score: 0.8494 - val_val_aggregated_jaccard_index: 0.7208 - lr: 1.0000e-05
# Epoch 105/150
# 86/86 [==============================] - 16s 136ms/step - loss: 0.1140 - accuracy: 0.9567 - iou_coef: 0.8121 - dice_coef: 0.8956 - f1_score: 0.8970 - aggregated_jaccard_index: 0.8136 - val_val_loss: 0.1701 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7388 - val_val_dice_coef: 0.8485 - val_val_f1_score: 0.8494 - val_val_aggregated_jaccard_index: 0.7210 - lr: 1.0000e-05
# Epoch 106/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.1140 - accuracy: 0.9564 - iou_coef: 0.8112 - dice_coef: 0.8950 - f1_score: 0.8963 - aggregated_jaccard_index: 0.8131 - val_val_loss: 0.1695 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7391 - val_val_dice_coef: 0.8488 - val_val_f1_score: 0.8498 - val_val_aggregated_jaccard_index: 0.7219 - lr: 1.0000e-05
# Epoch 107/150
# 86/86 [==============================] - 16s 135ms/step - loss: 0.1138 - accuracy: 0.9568 - iou_coef: 0.8123 - dice_coef: 0.8957 - f1_score: 0.8971 - aggregated_jaccard_index: 0.8140 - val_val_loss: 0.1686 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7404 - val_val_dice_coef: 0.8496 - val_val_f1_score: 0.8508 - val_val_aggregated_jaccard_index: 0.7231 - lr: 1.0000e-05
# Epoch 108/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1131 - accuracy: 0.9568 - iou_coef: 0.8130 - dice_coef: 0.8961 - f1_score: 0.8975 - aggregated_jaccard_index: 0.8141 - val_val_loss: 0.1696 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7388 - val_val_dice_coef: 0.8485 - val_val_f1_score: 0.8496 - val_val_aggregated_jaccard_index: 0.7214 - lr: 1.0000e-05
# Epoch 109/150
# 86/86 [==============================] - 16s 134ms/step - loss: 0.1137 - accuracy: 0.9569 - iou_coef: 0.8125 - dice_coef: 0.8958 - f1_score: 0.8972 - aggregated_jaccard_index: 0.8141 - val_val_loss: 0.1701 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7378 - val_val_dice_coef: 0.8479 - val_val_f1_score: 0.8489 - val_val_aggregated_jaccard_index: 0.7204 - lr: 1.0000e-05
# Epoch 110/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1122 - accuracy: 0.9570 - iou_coef: 0.8142 - dice_coef: 0.8969 - f1_score: 0.8983 - aggregated_jaccard_index: 0.8153 - val_val_loss: 0.1699 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7381 - val_val_dice_coef: 0.8481 - val_val_f1_score: 0.8491 - val_val_aggregated_jaccard_index: 0.7205 - lr: 1.0000e-05
# Epoch 111/150
# 86/86 [==============================] - 14s 112ms/step - loss: 0.1138 - accuracy: 0.9567 - iou_coef: 0.8118 - dice_coef: 0.8954 - f1_score: 0.8968 - aggregated_jaccard_index: 0.8135 - val_val_loss: 0.1692 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7390 - val_val_dice_coef: 0.8486 - val_val_f1_score: 0.8495 - val_val_aggregated_jaccard_index: 0.7214 - lr: 1.0000e-05
# Epoch 112/150
# 86/86 [==============================] - 16s 114ms/step - loss: 0.1129 - accuracy: 0.9568 - iou_coef: 0.8130 - dice_coef: 0.8961 - f1_score: 0.8975 - aggregated_jaccard_index: 0.8145 - val_val_loss: 0.1683 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.7404 - val_val_dice_coef: 0.8496 - val_val_f1_score: 0.8506 - val_val_aggregated_jaccard_index: 0.7227 - lr: 1.0000e-05
# Epoch 113/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1131 - accuracy: 0.9569 - iou_coef: 0.8128 - dice_coef: 0.8960 - f1_score: 0.8974 - aggregated_jaccard_index: 0.8140 - val_val_loss: 0.1678 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7409 - val_val_dice_coef: 0.8499 - val_val_f1_score: 0.8509 - val_val_aggregated_jaccard_index: 0.7233 - lr: 1.0000e-05
# Epoch 114/150
# 86/86 [==============================] - 16s 133ms/step - loss: 0.1140 - accuracy: 0.9568 - iou_coef: 0.8123 - dice_coef: 0.8956 - f1_score: 0.8970 - aggregated_jaccard_index: 0.8135 - val_val_loss: 0.1674 - val_val_accuracy: 0.9399 - val_val_iou_coef: 0.7413 - val_val_dice_coef: 0.8502 - val_val_f1_score: 0.8512 - val_val_aggregated_jaccard_index: 0.7238 - lr: 1.0000e-05
# Epoch 115/150
# 86/86 [==============================] - 14s 113ms/step - loss: 0.1128 - accuracy: 0.9569 - iou_coef: 0.8128 - dice_coef: 0.8960 - f1_score: 0.8974 - aggregated_jaccard_index: 0.8144 - val_val_loss: 0.1689 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7392 - val_val_dice_coef: 0.8487 - val_val_f1_score: 0.8498 - val_val_aggregated_jaccard_index: 0.7212 - lr: 1.0000e-05
# Epoch 116/150
# 86/86 [==============================] - 16s 134ms/step - loss: 0.1138 - accuracy: 0.9568 - iou_coef: 0.8121 - dice_coef: 0.8955 - f1_score: 0.8970 - aggregated_jaccard_index: 0.8133 - val_val_loss: 0.1669 - val_val_accuracy: 0.9401 - val_val_iou_coef: 0.7416 - val_val_dice_coef: 0.8505 - val_val_f1_score: 0.8518 - val_val_aggregated_jaccard_index: 0.7244 - lr: 1.0000e-05
# Epoch 117/150
# 86/86 [==============================] - 14s 114ms/step - loss: 0.1128 - accuracy: 0.9567 - iou_coef: 0.8128 - dice_coef: 0.8960 - f1_score: 0.8974 - aggregated_jaccard_index: 0.8142 - val_val_loss: 0.1668 - val_val_accuracy: 0.9400 - val_val_iou_coef: 0.7414 - val_val_dice_coef: 0.8504 - val_val_f1_score: 0.8515 - val_val_aggregated_jaccard_index: 0.7244 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
###### from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../CPM 17 DATA/test/images"
MSK_DIR = "../CPM 17 DATA/test/masks"
img_size = 256
batch_size = 31

# -----------------------------
# COLLECT PATHS (SAFE)
# -----------------------------
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)

mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# SAFETY CHECK (CRITICAL)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == [stem(p) for p in mask_paths], \
    "❌ Image–mask filename mismatch"

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )

    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.array(img, dtype=np.float32) / 255.0
    mask = (np.array(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:", tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 32
# Masks found : 32
# Validation batches: 2

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8015
# Mean Dice Coefficient: 0.8882
# Mean AJI:              0.8020
# Mean Accuracy:         0.9452
# Mean F1 Score:         0.8884
