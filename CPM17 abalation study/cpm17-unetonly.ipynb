# %%
import os
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"
os.environ.pop("XLA_FLAGS", None)

import tensorflow as tf
tf.config.optimizer.set_jit(False)

# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ----------------------------
# PriorGuidedUpsample2D:
# UpSampling2D-based upsampling + Learnable prior fusion (NO pixelwise maximum)
# ----------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGuidedUpsample2D(layers.Layer):
    """
    UpSampling2D upsampling everywhere (replaces PixelShuffleResize for features/skip and optionally priors)
    PLUS learnable prior fusion:

      GAP(pred) + GAP(prior) -> Dense -> Dense(1) -> project back (B,1,1,1) gate
      fused = gate*prior + (1-gate)*pred
      then DepthwiseConv(act) -> PointwiseConv to produce final map (B,H,W,1)

    Priors influence ONLY the structure maps (center/boundary), then those modulate features as before.
    """

    def __init__(
        self,
        scale=2,
        filters=64,
        method="bilinear",
        attention_kernel=3,
        use_structure_heads=True,
        n_centers=8,
        center_sharpness=9.0,
        boundary_suppress=0.4,
        learnable_temperature=True,
        learnable_prior_resize=True,
        # prior-fusion settings
        prior_fusion_hidden_ratio=4,  # hidden = filters//ratio
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.scale = int(scale)
        self.filters = int(filters)
        self.method = method
        self.attention_kernel = int(attention_kernel)
        self.use_structure_heads = bool(use_structure_heads)
        self.n_centers = int(n_centers)
        self.center_sharpness = float(center_sharpness)
        self.boundary_suppress = float(boundary_suppress)
        self.learnable_temperature = bool(learnable_temperature)

        self.learnable_prior_resize = bool(learnable_prior_resize)
        self.prior_fusion_hidden_ratio = int(prior_fusion_hidden_ratio)

        # ---------------- Projection & Attention ----------------
        self.proj_high = layers.Conv2D(filters, 1, padding="same", activation="selu", name="proj_high")
        self.proj_base = layers.Conv2D(filters, 1, padding="same", activation="linear", name="proj_base")
        self.skip_proj = layers.Conv2D(filters, 1, padding="same", use_bias=False, name="skip_proj")

        self.attention_head = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(attention_kernel, padding="same", activation="selu", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="spatial_attention",
        )

        # ---------------- UpSampling2D-based upsamplers ----------------
        self.up_feat = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_feat")
        self.up_feat_refine = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
            ],
            name="up_feat_refine",
        )

        if self.learnable_prior_resize:
            self.up_prior = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_prior")
            self.up_prior_refine = tf.keras.Sequential(
                [
                    layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                    layers.Conv2D(1, 1, padding="same", activation="selu"),
                ],
                name="up_prior_refine",
            )
        else:
            self.up_prior = None
            self.up_prior_refine = None

        # ---------------- Learned fusion scale ----------------
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(1.0), trainable=True, name="alpha_weight"
        )
        self.beta_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True, name="beta_weight"
        )

        # ---------------- Final projection (refinement step removed) ----------------
        self.final = layers.Conv2D(filters, 1, padding="same", activation="selu", name="final_head")

        # ---------------- Structural Heads ----------------
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding="same", use_bias=True)
        self.center_proj = layers.Conv2D(filters, 1, padding="same", activation=None)

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding="same", use_bias=False, name="laplace_dw")
        self.boundary_refine = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_refine",
        )
        self.boundary_gate_net = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_gate_net",
        )

        self.boundary_gate_scalar = None
        self.center_temp = None
        self.center_sigma = None

        # ---------------- Learnable prior fusion blocks (CENTER) ----------------
        hid = max(4, filters // self.prior_fusion_hidden_ratio)

        self.center_gap = layers.GlobalAveragePooling2D(name="center_prior_gap")
        self.center_fc1 = layers.Dense(hid, activation="selu", name="center_prior_fc1")
        self.center_gate = layers.Dense(1, activation="sigmoid", name="center_prior_gate")  # scalar gate

        self.center_dw = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="center_prior_dw")
        self.center_pw = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="center_prior_pw")

        # ---------------- Learnable prior fusion blocks (BOUNDARY) ----------------
        self.boundary_gap = layers.GlobalAveragePooling2D(name="boundary_prior_gap")
        self.boundary_fc1 = layers.Dense(hid, activation="selu", name="boundary_prior_fc1")
        self.boundary_gate = layers.Dense(1, activation="sigmoid", name="boundary_prior_gate")  # scalar gate

        self.boundary_dw2 = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="boundary_prior_dw")
        self.boundary_pw2 = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="boundary_prior_pw")

    # ---------------- Fusion scale initialization ----------------
    def _init_fusion_scale(self, shape, dtype):
        init = tf.keras.initializers.HeNormal(seed=54)
        w = init(shape=shape, dtype=dtype)
        return tf.clip_by_value(w, 0.0, 1.0)

    # ---------------- Build ----------------
    def build(self, input_shape):
        if not isinstance(input_shape, (list, tuple)) or len(input_shape) not in [2, 4]:
            raise ValueError(
                "PriorGuidedUpsample2D expects [low_res, skip_res] or "
                "[low_res, skip_res, prior_centers, prior_boundaries] inputs."
            )

        fusion_scale_init = self._init_fusion_scale((1, 1, 1, self.filters), tf.float32)
        self.fusion_scale = tf.Variable(
            initial_value=fusion_scale_init, trainable=True, name="fusion_scale", dtype=tf.float32
        )

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True,
            name="boundary_gate_scalar",
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True,
                name="center_temperature",
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness, dtype=tf.float32)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="center_sigma",
        )

        super().build(input_shape)

    # ---------------- Learnable upsample-to-target helper ----------------
    def _upsample_to(self, x, up_layer, refine, target_h, target_w):
        x = up_layer(x)
        if refine is not None:
            x = refine(x)
        # exact match by crop/pad (non-interpolating) for odd input sizes
        x = tf.image.resize_with_crop_or_pad(x, target_h, target_w)
        return x

    # ---------------- Learnable fusion (replaces pixelwise maximum) ----------------
    def _learnable_fuse_prior(self, pred_map, prior_map, gap, fc1, gate_fc, dw, pw):
        """
        pred_map/prior_map: (B,H,W,1)
        gate: scalar per-sample from GAP(pred)+GAP(prior)
        fused map refined by DWConv(act)+PWConv(sigmoid)
        """
        g_pred = gap(pred_map)   # (B,1) effectively after GAP; in TF it's (B,)
        g_prior = gap(prior_map)

        g = tf.concat([g_pred, g_prior], axis=-1)  # (B,2)
        h = fc1(g)
        gate = gate_fc(h)                          # (B,1)
        gate = tf.reshape(gate, [-1, 1, 1, 1])     # project back (broadcast)

        fused = gate * prior_map + (1.0 - gate) * pred_map
        fused = dw(fused)
        fused = pw(fused)
        return fused

    # ---------------- GMM-based Center & Boundary ----------------
    def _compute_soft_centers_gmm(self, feat, prior_centers=None, prior_boundaries=None):
        center_map, boundary_map = self._compute_centers_boundaries(feat)
        target_h, target_w = tf.shape(center_map)[1], tf.shape(center_map)[2]

        # --- learnable prior alignment + learnable fusion (NO tf.maximum) ---
        if prior_centers is not None:
            if self.up_prior is not None:
                prior_centers_up = self._upsample_to(
                    prior_centers, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_centers_up = tf.image.resize(prior_centers, (target_h, target_w), method="bilinear")
            prior_centers_up = tf.clip_by_value(prior_centers_up, 0.0, 1.0)

            center_map = self._learnable_fuse_prior(
                center_map, prior_centers_up,
                self.center_gap, self.center_fc1, self.center_gate,
                self.center_dw, self.center_pw
            )

        if prior_boundaries is not None:
            if self.up_prior is not None:
                prior_boundaries_up = self._upsample_to(
                    prior_boundaries, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_boundaries_up = tf.image.resize(prior_boundaries, (target_h, target_w), method="bilinear")
            prior_boundaries_up = tf.clip_by_value(prior_boundaries_up, 0.0, 1.0)

            boundary_map = self._learnable_fuse_prior(
                boundary_map, prior_boundaries_up,
                self.boundary_gap, self.boundary_fc1, self.boundary_gate,
                self.boundary_dw2, self.boundary_pw2
            )

        return center_map, boundary_map

    def _compute_centers_boundaries(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]

        proj_feat = self.center_proj(feat)
        H, W, C = tf.shape(proj_feat)[1], tf.shape(proj_feat)[2], tf.shape(proj_feat)[3]
        feat_flat = tf.reshape(proj_feat, [B, H * W, C])

        logits = self.assign_logits(proj_feat)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A_flat = tf.nn.softmax(logits_flat, axis=-1)

        A_flat_t = tf.transpose(A_flat, [0, 2, 1])
        denom = tf.reduce_sum(A_flat_t, axis=-1, keepdims=True) + eps
        prototypes = tf.matmul(A_flat_t, feat_flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])

        feat_exp = tf.expand_dims(feat_flat, 2)
        proto_exp = tf.expand_dims(prototypes, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_norm = tf.nn.l2_normalize(feat_flat, axis=-1)
        proto_norm = tf.nn.l2_normalize(prototypes, axis=-1)
        sim = tf.matmul(feat_norm, proto_norm, transpose_b=True)

        weighted_sim = resp * sim
        per_pixel_strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)

        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(per_pixel_strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)
        global_gate = tf.sigmoid(self.boundary_gate_scalar)
        boundary_map = refined_boundary * spatial_gate * global_gate * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ---------------- Forward ----------------
    def call(self, inputs, training=None):
        if len(inputs) == 2:
            low_res, skip_res = inputs
            prior_centers, prior_boundaries = None, None
        elif len(inputs) == 4:
            low_res, skip_res, prior_centers, prior_boundaries = inputs
        else:
            raise ValueError("Expected 2 or 4 inputs: [low_res, skip_res] optionally with priors.")

        high_proj = self.proj_high(low_res)
        base_proj = self.proj_base(low_res)
        alpha = self.attention_head(tf.concat([low_res, high_proj, base_proj], axis=-1))
        fused_low = alpha * high_proj + (1.0 - alpha) * base_proj

        target_h = tf.shape(low_res)[1] * self.scale
        target_w = tf.shape(low_res)[2] * self.scale

        # UpSampling2D-based upsampling (features + skip)
        upsampled = self._upsample_to(fused_low, self.up_feat, self.up_feat_refine, target_h, target_w)
        skip_proj = self.skip_proj(skip_res)
        skip_up = self._upsample_to(skip_proj, self.up_feat, self.up_feat_refine, target_h, target_w)

        fused = (upsampled + skip_up) * self.fusion_scale
        refined = fused

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(refined, prior_centers, prior_boundaries)
            refined = refined * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            out = self.final(refined)
            return out, center_map, boundary_map

        out = self.final(refined)
        return out

    # ---------------- Config ----------------
    def get_config(self):
        cfg = super().get_config()
        cfg.update(
            {
                "scale": self.scale,
                "filters": self.filters,
                "method": self.method,
                "attention_kernel": self.attention_kernel,
                "use_structure_heads": self.use_structure_heads,
                "n_centers": self.n_centers,
                "center_sharpness": self.center_sharpness,
                "boundary_suppress": self.boundary_suppress,
                "learnable_temperature": self.learnable_temperature,
                "learnable_prior_resize": self.learnable_prior_resize,
                "prior_fusion_hidden_ratio": self.prior_fusion_hidden_ratio,
            }
        )
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras.backend as K

# --- 1. Combined Dice + IoU Loss ---
def dice_iou_loss(y_true, y_pred, smooth=1e-5):
    # Flatten
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    # Calculate Intersection and Union
    intersection = K.sum(y_true_f * y_pred_f)
    sum_ = K.sum(y_true_f) + K.sum(y_pred_f)
    
    # Dice
    dice = (2. * intersection + smooth) / (sum_ + smooth)
    dice_loss = 1.0 - dice
    
    # IoU (Jaccard)
    iou = (intersection + smooth) / (sum_ - intersection + smooth)
    iou_loss = 1.0 - iou
    
    # Total combined loss
    return dice_loss + iou_loss

# --- 2. Single Conv Block Helper ---
def single_conv_block(x, filters, kernel_size=3, padding="same", activation="relu"):
    """
    Standard UNet single convolution block: 1 Conv2D -> BatchNorm -> ReLU
    """
    x = layers.Conv2D(filters, kernel_size, padding=padding, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base



# ---------------------------------------------------------
# PriorGeneratingDownsample2D
#
# Changes from the original:
#   1. No more GatedSpatialAttention refinement step.
#   2. No more separate `refine_feat` input tensor. The skip
#      branch is now an average-pooled version of `in_feat`
#      itself, computed inside the layer with tf.nn.avg_pool2d
#      using the same pool_size as the geodesic downsampler.
#   3. call() now takes a single tensor `in_feat` instead of
#      a (in_feat, refine_feat) tuple, and build() expects a
#      single input_shape instead of a tuple of shapes.
#
# This layer produces the `center_map` / `boundary_map` priors
# (alongside the downsampled features) that PriorGuidedUpsample2D
# later consumes as `prior_centers` / `prior_boundaries`.
# ---------------------------------------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGeneratingDownsample2D(layers.Layer):

    def __init__(self,
                 pool_size=2,
                 filters=64,
                 attention_kernel=3,
                 use_structure_heads=True,
                 n_centers=8,
                 center_sharpness=9.0,
                 boundary_suppress=0.4,
                 learnable_temperature=True,
                 **kwargs):

        super().__init__(**kwargs)

        self.pool_size = pool_size
        self.filters = filters
        self.attention_kernel = attention_kernel
        self.use_structure_heads = use_structure_heads
        self.n_centers = n_centers
        self.center_sharpness = center_sharpness
        self.boundary_suppress = boundary_suppress
        self.learnable_temperature = learnable_temperature

        # Replace pooling with geodesic kernel
        self.geo_pool = GeodesicDownsample2D(pool_size=pool_size)

        # Projections
        self.proj_high = layers.Conv2D(filters, 1, padding='same', activation='selu')
        self.proj_base = layers.Conv2D(filters, 1, padding='same')
        self.skip_proj = layers.Conv2D(filters, 1, padding='same')

        # Spatial attention
        self.attention_head = tf.keras.Sequential([
            layers.DepthwiseConv2D(attention_kernel, padding='same', activation='selu'),
            layers.Conv2D(filters, 1, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

        # Fusion scale
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(shape=(1,), initializer='ones', trainable=True)
        self.beta_weight = self.add_weight(shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True)

        # Final projection (refinement step removed)
        self.final = layers.Conv2D(filters, 3, padding='same', activation='selu')

        # Structure heads
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding='same')
        self.center_proj = layers.Conv2D(filters, 1, padding='same')

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding='same')
        self.boundary_refine = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])
        self.boundary_gate_net = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

    def build(self, input_shape):
        # input_shape is now a single tensor shape (in_feat only)
        _, _, _, C = input_shape

        fusion_scale_init = tf.keras.initializers.HeNormal(seed=54)(shape=(1, 1, 1, self.filters))
        self.fusion_scale = tf.Variable(fusion_scale_init, trainable=True, name='fusion_scale')

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer='ones',
            trainable=True
        )

        super().build(input_shape)

    # ------------------------------------------------------
    # GMM structural mask logic (unchanged)
    # ------------------------------------------------------
    def _compute_soft_centers_gmm(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]
        proj = self.center_proj(feat)
        H = tf.shape(proj)[1]
        W = tf.shape(proj)[2]
        C = tf.shape(proj)[3]

        flat = tf.reshape(proj, [B, H * W, C])
        logits = self.assign_logits(proj)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A = tf.nn.softmax(logits_flat, axis=-1)
        A_t = tf.transpose(A, [0, 2, 1])
        denom = tf.reduce_sum(A_t, axis=-1, keepdims=True) + eps
        proto = tf.matmul(A_t, flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])
        feat_exp = tf.expand_dims(flat, 2)
        proto_exp = tf.expand_dims(proto, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_n = tf.nn.l2_normalize(flat, axis=-1)
        proto_n = tf.nn.l2_normalize(proto, axis=-1)
        sim = tf.matmul(feat_n, proto_n, transpose_b=True)

        weighted_sim = resp * sim
        strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)
        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)

        boundary_map = refined_boundary * spatial_gate * tf.sigmoid(self.boundary_gate_scalar) * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ------------------------------------------------------
    # Forward path with geodesic pooling
    #
    # `in_feat` is now the ONLY input. The skip branch is
    # derived internally via average pooling of `in_feat`
    # (replacing the old separate `refine_feat` argument),
    # and the GatedSpatialAttention refinement step has been
    # removed entirely — the merged features flow straight
    # into the structure heads / final projection.
    # ------------------------------------------------------
    def call(self, in_feat):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        pooled = self.geo_pool(in_feat)

        # Average-pooled skip branch, derived directly from in_feat
        pooled_ref = tf.nn.avg_pool2d(
            in_feat,
            ksize=[1, ph, pw, 1],
            strides=[1, ph, pw, 1],
            padding='SAME'
        )

        if tf.shape(pooled_ref)[1] != tf.shape(pooled)[1] or tf.shape(pooled_ref)[2] != tf.shape(pooled)[2]:
            pooled_ref = tf.image.resize(pooled_ref, tf.shape(pooled)[1:3], method='bilinear')

        high = self.proj_high(pooled)
        base = self.proj_base(pooled)
        alpha = self.attention_head(tf.concat([pooled, high, base], axis=-1))
        fused = alpha * high + (1 - alpha) * base

        skip = self.skip_proj(pooled_ref)
        fused = (fused + skip) * self.fusion_scale

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(fused)
            fused = fused * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            return self.final(fused), center_map, boundary_map

        return self.final(fused)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            'pool_size': self.pool_size,
            'filters': self.filters,
            'attention_kernel': self.attention_kernel,
            'use_structure_heads': self.use_structure_heads,
            'n_centers': self.n_centers,
            'center_sharpness': self.center_sharpness,
            'boundary_suppress': self.boundary_suppress,
            'learnable_temperature': self.learnable_temperature
        })
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def split_branch_block(x, filters, dilation_rate=2, l2=1e-4, l1=1e-5):
    c = x.shape[-1]
    assert c % 4 == 0

    reg_k = regularizers.L2(l2)
    reg_b = regularizers.L1(l1)

    # -------------------------------------------------
    # Channel Split + gate
    # -------------------------------------------------
    splits = tf.split(x, num_or_size_splits=4, axis=-1)

    gate_logits = layers.GlobalAveragePooling2D()(x)
    gate_logits = layers.Dense(
        4,
        use_bias=True,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gate_logits)
    gates = layers.Activation("softmax")(gate_logits)

    gated_splits = [
        splits[i] * gates[:, i][:, None, None, None]
        for i in range(4)
    ]

    fpb = filters // 4  # filters per branch, target channel count for every branch

    # -------------------------------------------------
    # Multi-branch convolutions
    # -------------------------------------------------
    b1 = layers.Conv2D(
        fpb, 3, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[0])

    b2 = layers.Conv2D(
        fpb, 3, padding="same",
        dilation_rate=dilation_rate,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[1])

    # depthwise preserves input channel count (c//4), so project with a
    # pointwise conv to fpb after each depthwise so shapes match for concat
    b3 = layers.DepthwiseConv2D(
        3, padding="same",
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[2])
    b3 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b3)

    b4 = layers.DepthwiseConv2D(
        3, padding="same",
        dilation_rate=dilation_rate,
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[3])
    b4 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b4)

    add_1 = layers.Add()([b1, b4])   # fpb channels
    add_2 = layers.Add()([b2, b3])   # fpb channels
    out = layers.Concatenate()([add_1, add_2])  # filters // 2 channels
    return out

# %%
def build_normal_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = single_conv_block(inputs, base_filters)
    
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(f1)
    p1 = layers.Dropout(0.05)(p1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = single_conv_block(p1, base_filters * 2)
    
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(f2)
    p2 = layers.Dropout(0.15)(p2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = single_conv_block(p2, base_filters * 4)
    
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(f3)
    p3 = layers.Dropout(0.2)(p3)

    # -------- Level 4 --------
    f4 = single_conv_block(p3, base_filters * 8)
    
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(f4)
    p4 = layers.Dropout(0.25)(p4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = single_conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # ===================== Decoder =====================

    # -------- Up 4 --------
    # 1. Upsample
    d4 = layers.UpSampling2D(size=(2, 2))(f5)
    
    # 2. Dropouts exactly as specified
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    
    # 3. Conv block reduces channels to match f4 (base_filters * 8)
    d4 = single_conv_block(d4, base_filters * 8)
    
    # 4. Residual Add
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=(2, 2))(d4)
    
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    
    d3 = single_conv_block(d3, base_filters * 4)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=(2, 2))(d3)
    
    d2 = single_conv_block(d2, base_filters * 2)
    d2 = layers.Dropout(0.22)(d2)
    
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=(2, 2))(d2)
    
    d1 = single_conv_block(d1, base_filters)
    d1 = layers.Dropout(0.24)(d1)
    
    d1 = layers.Add()([f1, d1])

    # ===================== Output =====================
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", name="segmentation_output")(d1)

    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Normal_UNet_Add_Upsample")

    return model

# %%
# Create the Normal UNet model
model = build_normal_unet(input_shape=(256, 256, 3), base_filters=32, num_classes=1)

# Compile using your new Dice+IoU single loss
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_iou_loss, 
    metrics=['accuracy']
)

# See the summary of your new network
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789712638.662147      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1789712638.665037      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "Normal_UNet_Add_Upsample"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout    │ (None, 128, 128,  │          0 │ dropout[0][0]     │
# │ (GaussianDropout)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     18,496 │ gaussian_dropout… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_1  │ (None, 64, 64,    │          0 │ dropout_1[0][0]   │
# │ (GaussianDropout)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ gaussian_dropout… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_2  │ (None, 16, 16,    │          0 │ dropout_3[0][0]   │
# │ (GaussianDropout)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    885,120 │ gaussian_dropout… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,536 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 16, 16,    │          0 │ activation_4[0][… │
# │ (SpatialDropout2D)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_3  │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (GaussianDropout)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ gaussian_dropout… │
# │ (UpSampling2D)      │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_4  │ (None, 32, 32,    │          0 │ dropout_4[0][0]   │
# │ (GaussianDropout)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    884,992 │ gaussian_dropout… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │                     │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ add[0][0]         │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_5  │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (GaussianDropout)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ gaussian_dropout… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │    295,040 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ activation_2[0][… │
# │                     │ 128)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ add_1[0][0]       │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │     73,792 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ activation_7[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │                     │ 64)               │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ add_2[0][0]       │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │     18,464 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 32)               │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 256, 256,  │         33 │ add_3[0][0]       │
# │ (Conv2D)            │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,551,233 (9.73 MB)
#  Trainable params: 2,548,545 (9.72 MB)
#  Non-trainable params: 2,688 (10.50 KB)

# %%
# unet_canvas_full.py
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation + Structural (Center/Boundary) loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU
        L_struct = λ_center * CenterAlignment + λ_boundary * BoundaryAlignment

    NOTE: the BCE term (and its weight l1), the canvas consistency
    loss (fg/bg per-pixel-squared-error penalty, and its weights
    lambda_fg/lambda_bg), and the patchwise discriminator loss
    (cosine + SSIM patch error, lambda_patchdisc) have been removed.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {
                "l2": 3.0, "l3": 4.5,
                "lambda_center": 8.5, "lambda_boundary": 6.5
            }

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")
        self.lambda_center = tf.Variable(init_lambdas["lambda_center"], trainable=True, dtype=tf.float32, name="lambda_center")
        self.lambda_boundary = tf.Variable(init_lambdas["lambda_boundary"], trainable=True, dtype=tf.float32, name="lambda_boundary")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [
            self.l2, self.l3,
            self.lambda_center, self.lambda_boundary
        ]

    def call(self, y_true_tuple, y_pred_tuple):
        """
        Args:
            y_true_tuple: (y_true_seg, y_true_center, y_true_boundary)
            y_pred_tuple: (y_pred_seg, y_pred_center, y_pred_boundary)
        """
        if not isinstance(y_true_tuple, (list, tuple)) or not isinstance(y_pred_tuple, (list, tuple)):
            raise ValueError("Expected tuples: (y_true_seg, y_true_center, y_true_boundary) and (y_pred_seg, y_pred_center, y_pred_boundary)")

        y_true, y_true_center, y_true_boundary = map(tf.cast, y_true_tuple, [tf.float32]*3)
        y_pred, y_pred_center, y_pred_boundary = map(tf.cast, y_pred_tuple, [tf.float32]*3)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        # --- Structural Center/Boundary ---
        lam_c, lam_b = tf.nn.softplus(self.lambda_center), tf.nn.softplus(self.lambda_boundary)
        center_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_center, y_pred_center))
        boundary_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_boundary, y_pred_boundary))
        overlap = tf.reduce_mean(y_pred_center * y_pred_boundary)
        struct_overlap = 1.0 - overlap
        struct_loss = lam_c * center_loss + lam_b * boundary_loss + 0.5 * struct_overlap

        return seg_loss + struct_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy()),
                "lambda_center": float(self.lambda_center.numpy()),
                "lambda_boundary": float(self.lambda_boundary.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/augmented_dataset/images/*.png"))
train_mask_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/augmented_dataset/masks/*.png"))

val_img_paths = sorted(
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/val/images/*.png") +
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/val/images/*.tif") +
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -------------------------------------------------------
# SAFETY CHECK
# -------------------------------------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 341
# Train masks: 341
# Val images: 4
# Val masks: 4
# Training batches: 86
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in [
            "l2", "l3",
            "lambda_center", "lambda_boundary"
        ]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            outputs = self.backbone(x, training=True)

            if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
                y_pred, centers, boundaries = outputs
            else:
                raise ValueError("Backbone must return (y_pred, centers, boundaries)")

            last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
            last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

            loss = self.loss_fn(
                (y_true, y_true, y_true),
                (y_pred, last_center, last_boundary)
            )

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        outputs = self.backbone(x, training=False)

        if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
            y_pred, centers, boundaries = outputs
        else:
            raise ValueError("Backbone must return (y_pred, centers, boundaries)")

        last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
        last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

        loss = self.loss_fn(
            (y_true, y_true, y_true),
            (y_pred, last_center, last_boundary)
        )

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
from datetime import datetime
from tensorflow.keras.optimizers import AdamW

# 1️⃣ Optimizer
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 2️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 3️⃣ Compile Model (Directly compiles the UNet model)
model.compile(
    optimizer=optimizer, 
    loss=dice_iou_loss,       # Using the single loss function we defined
    metrics=metrics_list
)

# 4️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveModelCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            # Since there is no StructTrainer wrapper, self.model is the backbone itself
            self.model.save(self.save_path)
            print(f"\n✅ Saved improved model at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_model = SaveModelCallback("normal_unet.keras")

# 5️⃣ Training
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, save_model],
    verbose=1
)
print("\n🎯 Training complete. Model saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-18 06:24:17.426148: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:17.641486: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:19.985099: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:20.326648: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:20.738665: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:20.949558: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:21.244087: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:21.455066: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:22.776197: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:22.934022: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:23.576007: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:23.876302: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1789712680.498787     135 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 84/86 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8619 - aggregated_jaccard_index: 0.4925 - dice_coef: 0.6381 - f1_score: 0.7000 - iou_coef: 0.4832 - loss: 0.8680
# 2026-09-18 06:24:48.794156: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:48.987890: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:50.293976: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:50.624441: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:50.943682: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:51.138150: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:51.399490: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:51.594070: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:52.420066: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:52.568888: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:53.129720: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 06:24:53.414183: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8626 - aggregated_jaccard_index: 0.4942 - dice_coef: 0.6397 - f1_score: 0.7014 - iou_coef: 0.4849 - loss: 0.8646
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_val_iou_coef` which is not available. Available metrics are: accuracy,aggregated_jaccard_index,dice_coef,f1_score,iou_coef,loss,val_accuracy,val_aggregated_jaccard_index,val_dice_coef,val_f1_score,val_iou_coef,val_loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/callback_list.py:171: UserWarning: Learning rate reduction is conditioned on metric `val_val_iou_coef` which is not available. Available metrics are: accuracy,aggregated_jaccard_index,dice_coef,f1_score,iou_coef,loss,val_accuracy,val_aggregated_jaccard_index,val_dice_coef,val_f1_score,val_iou_coef,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# ✅ Saved improved model at epoch 1 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 68s 330ms/step - accuracy: 0.8936 - aggregated_jaccard_index: 0.5674 - dice_coef: 0.7079 - f1_score: 0.7611 - iou_coef: 0.5580 - loss: 0.7220 - val_accuracy: 0.7335 - val_aggregated_jaccard_index: 0.3365 - val_dice_coef: 0.4493 - val_f1_score: 0.5063 - val_iou_coef: 0.3002 - val_loss: 1.2646 - learning_rate: 0.0010
# Epoch 2/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9192 - aggregated_jaccard_index: 0.6481 - dice_coef: 0.7824 - f1_score: 0.8091 - iou_coef: 0.6468 - loss: 0.5686
# ✅ Saved improved model at epoch 2 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9192 - aggregated_jaccard_index: 0.6573 - dice_coef: 0.7877 - f1_score: 0.8097 - iou_coef: 0.6545 - loss: 0.5538 - val_accuracy: 0.9092 - val_aggregated_jaccard_index: 0.5484 - val_dice_coef: 0.6748 - val_f1_score: 0.6924 - val_iou_coef: 0.5321 - val_loss: 0.7329 - learning_rate: 0.0010
# Epoch 3/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9254 - aggregated_jaccard_index: 0.6778 - dice_coef: 0.8031 - f1_score: 0.8191 - iou_coef: 0.6750 - loss: 0.5177
# ✅ Saved improved model at epoch 3 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9242 - aggregated_jaccard_index: 0.6819 - dice_coef: 0.8053 - f1_score: 0.8195 - iou_coef: 0.6781 - loss: 0.5100 - val_accuracy: 0.9138 - val_aggregated_jaccard_index: 0.6135 - val_dice_coef: 0.7375 - val_f1_score: 0.7475 - val_iou_coef: 0.5953 - val_loss: 0.6198 - learning_rate: 0.0010
# Epoch 4/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9275 - aggregated_jaccard_index: 0.6931 - dice_coef: 0.8157 - f1_score: 0.8274 - iou_coef: 0.6919 - loss: 0.4912
# ✅ Saved improved model at epoch 4 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9285 - aggregated_jaccard_index: 0.7004 - dice_coef: 0.8200 - f1_score: 0.8307 - iou_coef: 0.6981 - loss: 0.4789 - val_accuracy: 0.9219 - val_aggregated_jaccard_index: 0.6626 - val_dice_coef: 0.7955 - val_f1_score: 0.8069 - val_iou_coef: 0.6624 - val_loss: 0.5399 - learning_rate: 0.0010
# Epoch 5/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9306 - aggregated_jaccard_index: 0.7054 - dice_coef: 0.8253 - f1_score: 0.8346 - iou_coef: 0.7052 - loss: 0.4704
# ✅ Saved improved model at epoch 5 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9312 - aggregated_jaccard_index: 0.7113 - dice_coef: 0.8283 - f1_score: 0.8367 - iou_coef: 0.7096 - loss: 0.4587 - val_accuracy: 0.9313 - val_aggregated_jaccard_index: 0.6821 - val_dice_coef: 0.8049 - val_f1_score: 0.8128 - val_iou_coef: 0.6787 - val_loss: 0.5019 - learning_rate: 0.0010
# Epoch 6/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9325 - aggregated_jaccard_index: 0.7134 - dice_coef: 0.8279 - f1_score: 0.8350 - iou_coef: 0.7103 - loss: 0.4555
# ✅ Saved improved model at epoch 6 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9326 - aggregated_jaccard_index: 0.7185 - dice_coef: 0.8332 - f1_score: 0.8401 - iou_coef: 0.7172 - loss: 0.4483 - val_accuracy: 0.9388 - val_aggregated_jaccard_index: 0.7300 - val_dice_coef: 0.8460 - val_f1_score: 0.8526 - val_iou_coef: 0.7333 - val_loss: 0.4261 - learning_rate: 0.0010
# Epoch 7/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9312 - aggregated_jaccard_index: 0.7190 - dice_coef: 0.8344 - f1_score: 0.8407 - iou_coef: 0.7184 - loss: 0.4474
# ✅ Saved improved model at epoch 7 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9345 - aggregated_jaccard_index: 0.7267 - dice_coef: 0.8392 - f1_score: 0.8453 - iou_coef: 0.7254 - loss: 0.4334 - val_accuracy: 0.9385 - val_aggregated_jaccard_index: 0.7242 - val_dice_coef: 0.8439 - val_f1_score: 0.8489 - val_iou_coef: 0.7308 - val_loss: 0.4361 - learning_rate: 0.0010
# Epoch 8/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9359 - aggregated_jaccard_index: 0.7365 - dice_coef: 0.8453 - f1_score: 0.8512 - iou_coef: 0.7342 - loss: 0.4184
# ✅ Saved improved model at epoch 8 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9361 - aggregated_jaccard_index: 0.7349 - dice_coef: 0.8451 - f1_score: 0.8506 - iou_coef: 0.7340 - loss: 0.4222 - val_accuracy: 0.9345 - val_aggregated_jaccard_index: 0.7004 - val_dice_coef: 0.8191 - val_f1_score: 0.8209 - val_iou_coef: 0.6971 - val_loss: 0.4727 - learning_rate: 0.0010
# Epoch 9/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9373 - aggregated_jaccard_index: 0.7371 - dice_coef: 0.8475 - f1_score: 0.8526 - iou_coef: 0.7372 - loss: 0.4165
# ✅ Saved improved model at epoch 9 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9377 - aggregated_jaccard_index: 0.7388 - dice_coef: 0.8479 - f1_score: 0.8531 - iou_coef: 0.7379 - loss: 0.4129 - val_accuracy: 0.9330 - val_aggregated_jaccard_index: 0.6886 - val_dice_coef: 0.8030 - val_f1_score: 0.8049 - val_iou_coef: 0.6797 - val_loss: 0.4913 - learning_rate: 0.0010
# Epoch 10/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9379 - aggregated_jaccard_index: 0.7385 - dice_coef: 0.8462 - f1_score: 0.8511 - iou_coef: 0.7354 - loss: 0.4146
# ✅ Saved improved model at epoch 10 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9389 - aggregated_jaccard_index: 0.7443 - dice_coef: 0.8511 - f1_score: 0.8559 - iou_coef: 0.7429 - loss: 0.4054 - val_accuracy: 0.9358 - val_aggregated_jaccard_index: 0.6994 - val_dice_coef: 0.8252 - val_f1_score: 0.8276 - val_iou_coef: 0.7044 - val_loss: 0.4751 - learning_rate: 0.0010
# Epoch 11/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9395 - aggregated_jaccard_index: 0.7485 - dice_coef: 0.8548 - f1_score: 0.8591 - iou_coef: 0.7484 - loss: 0.3982
# ✅ Saved improved model at epoch 11 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9398 - aggregated_jaccard_index: 0.7469 - dice_coef: 0.8534 - f1_score: 0.8577 - iou_coef: 0.7461 - loss: 0.4005 - val_accuracy: 0.9414 - val_aggregated_jaccard_index: 0.7360 - val_dice_coef: 0.8525 - val_f1_score: 0.8550 - val_iou_coef: 0.7434 - val_loss: 0.4141 - learning_rate: 0.0010
# Epoch 12/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9441 - aggregated_jaccard_index: 0.7557 - dice_coef: 0.8586 - f1_score: 0.8627 - iou_coef: 0.7538 - loss: 0.3859
# ✅ Saved improved model at epoch 12 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9418 - aggregated_jaccard_index: 0.7545 - dice_coef: 0.8574 - f1_score: 0.8616 - iou_coef: 0.7522 - loss: 0.3872 - val_accuracy: 0.9353 - val_aggregated_jaccard_index: 0.6969 - val_dice_coef: 0.8210 - val_f1_score: 0.8228 - val_iou_coef: 0.7001 - val_loss: 0.4779 - learning_rate: 0.0010
# Epoch 13/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9427 - aggregated_jaccard_index: 0.7602 - dice_coef: 0.8626 - f1_score: 0.8665 - iou_coef: 0.7605 - loss: 0.3796
# ✅ Saved improved model at epoch 13 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9420 - aggregated_jaccard_index: 0.7559 - dice_coef: 0.8596 - f1_score: 0.8634 - iou_coef: 0.7557 - loss: 0.3867 - val_accuracy: 0.9394 - val_aggregated_jaccard_index: 0.7272 - val_dice_coef: 0.8404 - val_f1_score: 0.8422 - val_iou_coef: 0.7274 - val_loss: 0.4288 - learning_rate: 0.0010
# Epoch 14/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9432 - aggregated_jaccard_index: 0.7597 - dice_coef: 0.8612 - f1_score: 0.8650 - iou_coef: 0.7581 - loss: 0.3795
# ✅ Saved improved model at epoch 14 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9427 - aggregated_jaccard_index: 0.7599 - dice_coef: 0.8614 - f1_score: 0.8650 - iou_coef: 0.7583 - loss: 0.3796 - val_accuracy: 0.9240 - val_aggregated_jaccard_index: 0.6391 - val_dice_coef: 0.7825 - val_f1_score: 0.7839 - val_iou_coef: 0.6492 - val_loss: 0.5764 - learning_rate: 0.0010
# Epoch 15/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9448 - aggregated_jaccard_index: 0.7637 - dice_coef: 0.8637 - f1_score: 0.8671 - iou_coef: 0.7618 - loss: 0.3730
# ✅ Saved improved model at epoch 15 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9442 - aggregated_jaccard_index: 0.7644 - dice_coef: 0.8642 - f1_score: 0.8676 - iou_coef: 0.7625 - loss: 0.3716 - val_accuracy: 0.9403 - val_aggregated_jaccard_index: 0.7232 - val_dice_coef: 0.8445 - val_f1_score: 0.8460 - val_iou_coef: 0.7319 - val_loss: 0.4357 - learning_rate: 0.0010
# Epoch 16/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9439 - aggregated_jaccard_index: 0.7665 - dice_coef: 0.8661 - f1_score: 0.8694 - iou_coef: 0.7656 - loss: 0.3683
# ✅ Saved improved model at epoch 16 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9449 - aggregated_jaccard_index: 0.7675 - dice_coef: 0.8672 - f1_score: 0.8704 - iou_coef: 0.7672 - loss: 0.3675 - val_accuracy: 0.9174 - val_aggregated_jaccard_index: 0.6092 - val_dice_coef: 0.7678 - val_f1_score: 0.7695 - val_iou_coef: 0.6326 - val_loss: 0.6257 - learning_rate: 0.0010
# Epoch 17/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9465 - aggregated_jaccard_index: 0.7721 - dice_coef: 0.8690 - f1_score: 0.8723 - iou_coef: 0.7698 - loss: 0.3588
# ✅ Saved improved model at epoch 17 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9460 - aggregated_jaccard_index: 0.7714 - dice_coef: 0.8687 - f1_score: 0.8719 - iou_coef: 0.7694 - loss: 0.3604 - val_accuracy: 0.9353 - val_aggregated_jaccard_index: 0.6972 - val_dice_coef: 0.8266 - val_f1_score: 0.8284 - val_iou_coef: 0.7070 - val_loss: 0.4776 - learning_rate: 0.0010
# Epoch 18/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9464 - aggregated_jaccard_index: 0.7771 - dice_coef: 0.8718 - f1_score: 0.8747 - iou_coef: 0.7744 - loss: 0.3506
# ✅ Saved improved model at epoch 18 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9471 - aggregated_jaccard_index: 0.7768 - dice_coef: 0.8720 - f1_score: 0.8750 - iou_coef: 0.7746 - loss: 0.3519 - val_accuracy: 0.9363 - val_aggregated_jaccard_index: 0.7017 - val_dice_coef: 0.8297 - val_f1_score: 0.8313 - val_iou_coef: 0.7115 - val_loss: 0.4701 - learning_rate: 0.0010
# Epoch 19/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9476 - aggregated_jaccard_index: 0.7817 - dice_coef: 0.8756 - f1_score: 0.8786 - iou_coef: 0.7801 - loss: 0.3429
# ✅ Saved improved model at epoch 19 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9480 - aggregated_jaccard_index: 0.7785 - dice_coef: 0.8735 - f1_score: 0.8764 - iou_coef: 0.7769 - loss: 0.3474 - val_accuracy: 0.9410 - val_aggregated_jaccard_index: 0.7283 - val_dice_coef: 0.8498 - val_f1_score: 0.8514 - val_iou_coef: 0.7397 - val_loss: 0.4264 - learning_rate: 0.0010
# Epoch 20/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9500 - aggregated_jaccard_index: 0.7878 - dice_coef: 0.8779 - f1_score: 0.8806 - iou_coef: 0.7839 - loss: 0.3330
# ✅ Saved improved model at epoch 20 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9488 - aggregated_jaccard_index: 0.7823 - dice_coef: 0.8756 - f1_score: 0.8784 - iou_coef: 0.7803 - loss: 0.3418 - val_accuracy: 0.9352 - val_aggregated_jaccard_index: 0.6951 - val_dice_coef: 0.8251 - val_f1_score: 0.8262 - val_iou_coef: 0.7056 - val_loss: 0.4809 - learning_rate: 0.0010
# Epoch 21/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9487 - aggregated_jaccard_index: 0.7840 - dice_coef: 0.8774 - f1_score: 0.8802 - iou_coef: 0.7832 - loss: 0.3397
# ✅ Saved improved model at epoch 21 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9490 - aggregated_jaccard_index: 0.7821 - dice_coef: 0.8763 - f1_score: 0.8790 - iou_coef: 0.7813 - loss: 0.3420 - val_accuracy: 0.9424 - val_aggregated_jaccard_index: 0.7331 - val_dice_coef: 0.8530 - val_f1_score: 0.8548 - val_iou_coef: 0.7447 - val_loss: 0.4186 - learning_rate: 0.0010
# Epoch 22/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9509 - aggregated_jaccard_index: 0.7891 - dice_coef: 0.8795 - f1_score: 0.8821 - iou_coef: 0.7864 - loss: 0.3310
# ✅ Saved improved model at epoch 22 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9498 - aggregated_jaccard_index: 0.7869 - dice_coef: 0.8786 - f1_score: 0.8812 - iou_coef: 0.7850 - loss: 0.3353 - val_accuracy: 0.9417 - val_aggregated_jaccard_index: 0.7322 - val_dice_coef: 0.8483 - val_f1_score: 0.8501 - val_iou_coef: 0.7380 - val_loss: 0.4184 - learning_rate: 0.0010
# Epoch 23/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9504 - aggregated_jaccard_index: 0.7905 - dice_coef: 0.8803 - f1_score: 0.8829 - iou_coef: 0.7878 - loss: 0.3287
# ✅ Saved improved model at epoch 23 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9505 - aggregated_jaccard_index: 0.7886 - dice_coef: 0.8796 - f1_score: 0.8821 - iou_coef: 0.7867 - loss: 0.3311 - val_accuracy: 0.9382 - val_aggregated_jaccard_index: 0.7122 - val_dice_coef: 0.8394 - val_f1_score: 0.8409 - val_iou_coef: 0.7254 - val_loss: 0.4518 - learning_rate: 0.0010
# Epoch 24/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9505 - aggregated_jaccard_index: 0.7903 - dice_coef: 0.8811 - f1_score: 0.8836 - iou_coef: 0.7889 - loss: 0.3294
# ✅ Saved improved model at epoch 24 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9508 - aggregated_jaccard_index: 0.7887 - dice_coef: 0.8797 - f1_score: 0.8822 - iou_coef: 0.7870 - loss: 0.3295 - val_accuracy: 0.9311 - val_aggregated_jaccard_index: 0.6756 - val_dice_coef: 0.8152 - val_f1_score: 0.8161 - val_iou_coef: 0.6928 - val_loss: 0.5128 - learning_rate: 0.0010
# Epoch 25/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9524 - aggregated_jaccard_index: 0.7997 - dice_coef: 0.8865 - f1_score: 0.8889 - iou_coef: 0.7976 - loss: 0.3139
# ✅ Saved improved model at epoch 25 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9518 - aggregated_jaccard_index: 0.7941 - dice_coef: 0.8833 - f1_score: 0.8857 - iou_coef: 0.7925 - loss: 0.3224 - val_accuracy: 0.9365 - val_aggregated_jaccard_index: 0.7029 - val_dice_coef: 0.8372 - val_f1_score: 0.8382 - val_iou_coef: 0.7230 - val_loss: 0.4679 - learning_rate: 0.0010
# Epoch 26/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9531 - aggregated_jaccard_index: 0.7937 - dice_coef: 0.8833 - f1_score: 0.8857 - iou_coef: 0.7927 - loss: 0.3237
# ✅ Saved improved model at epoch 26 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 55ms/step - accuracy: 0.9511 - aggregated_jaccard_index: 0.7899 - dice_coef: 0.8810 - f1_score: 0.8833 - iou_coef: 0.7890 - loss: 0.3293 - val_accuracy: 0.9311 - val_aggregated_jaccard_index: 0.6761 - val_dice_coef: 0.8129 - val_f1_score: 0.8143 - val_iou_coef: 0.6881 - val_loss: 0.5129 - learning_rate: 0.0010
# Epoch 27/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9526 - aggregated_jaccard_index: 0.7982 - dice_coef: 0.8862 - f1_score: 0.8886 - iou_coef: 0.7970 - loss: 0.3164
# ✅ Saved improved model at epoch 27 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9528 - aggregated_jaccard_index: 0.7973 - dice_coef: 0.8856 - f1_score: 0.8879 - iou_coef: 0.7960 - loss: 0.3177 - val_accuracy: 0.9395 - val_aggregated_jaccard_index: 0.7216 - val_dice_coef: 0.8488 - val_f1_score: 0.8502 - val_iou_coef: 0.7391 - val_loss: 0.4369 - learning_rate: 0.0010
# Epoch 28/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9543 - aggregated_jaccard_index: 0.8040 - dice_coef: 0.8883 - f1_score: 0.8905 - iou_coef: 0.8004 - loss: 0.3068
# ✅ Saved improved model at epoch 28 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9538 - aggregated_jaccard_index: 0.8017 - dice_coef: 0.8880 - f1_score: 0.8901 - iou_coef: 0.7999 - loss: 0.3100 - val_accuracy: 0.9407 - val_aggregated_jaccard_index: 0.7247 - val_dice_coef: 0.8432 - val_f1_score: 0.8447 - val_iou_coef: 0.7308 - val_loss: 0.4320 - learning_rate: 0.0010
# Epoch 29/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9552 - aggregated_jaccard_index: 0.8008 - dice_coef: 0.8870 - f1_score: 0.8891 - iou_coef: 0.7984 - loss: 0.3116
# ✅ Saved improved model at epoch 29 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9539 - aggregated_jaccard_index: 0.8015 - dice_coef: 0.8878 - f1_score: 0.8899 - iou_coef: 0.7997 - loss: 0.3097 - val_accuracy: 0.9359 - val_aggregated_jaccard_index: 0.7003 - val_dice_coef: 0.8302 - val_f1_score: 0.8310 - val_iou_coef: 0.7127 - val_loss: 0.4723 - learning_rate: 0.0010
# Epoch 30/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9539 - aggregated_jaccard_index: 0.8040 - dice_coef: 0.8900 - f1_score: 0.8922 - iou_coef: 0.8035 - loss: 0.3071
# ✅ Saved improved model at epoch 30 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9541 - aggregated_jaccard_index: 0.8024 - dice_coef: 0.8884 - f1_score: 0.8905 - iou_coef: 0.8007 - loss: 0.3089 - val_accuracy: 0.9414 - val_aggregated_jaccard_index: 0.7298 - val_dice_coef: 0.8536 - val_f1_score: 0.8549 - val_iou_coef: 0.7462 - val_loss: 0.4232 - learning_rate: 0.0010
# Epoch 31/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9570 - aggregated_jaccard_index: 0.8122 - dice_coef: 0.8933 - f1_score: 0.8953 - iou_coef: 0.8087 - loss: 0.2939
# ✅ Saved improved model at epoch 31 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9548 - aggregated_jaccard_index: 0.8053 - dice_coef: 0.8901 - f1_score: 0.8921 - iou_coef: 0.8033 - loss: 0.3047 - val_accuracy: 0.9301 - val_aggregated_jaccard_index: 0.6711 - val_dice_coef: 0.8171 - val_f1_score: 0.8179 - val_iou_coef: 0.6950 - val_loss: 0.5214 - learning_rate: 0.0010
# Epoch 32/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9553 - aggregated_jaccard_index: 0.8087 - dice_coef: 0.8920 - f1_score: 0.8941 - iou_coef: 0.8065 - loss: 0.2992
# ✅ Saved improved model at epoch 32 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9555 - aggregated_jaccard_index: 0.8084 - dice_coef: 0.8921 - f1_score: 0.8941 - iou_coef: 0.8065 - loss: 0.2992 - val_accuracy: 0.9367 - val_aggregated_jaccard_index: 0.7027 - val_dice_coef: 0.8320 - val_f1_score: 0.8330 - val_iou_coef: 0.7143 - val_loss: 0.4693 - learning_rate: 0.0010
# Epoch 33/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9556 - aggregated_jaccard_index: 0.8102 - dice_coef: 0.8933 - f1_score: 0.8953 - iou_coef: 0.8083 - loss: 0.2965
# ✅ Saved improved model at epoch 33 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9552 - aggregated_jaccard_index: 0.8076 - dice_coef: 0.8919 - f1_score: 0.8938 - iou_coef: 0.8062 - loss: 0.3011 - val_accuracy: 0.9382 - val_aggregated_jaccard_index: 0.7107 - val_dice_coef: 0.8305 - val_f1_score: 0.8312 - val_iou_coef: 0.7130 - val_loss: 0.4558 - learning_rate: 0.0010
# Epoch 34/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9537 - aggregated_jaccard_index: 0.8065 - dice_coef: 0.8906 - f1_score: 0.8924 - iou_coef: 0.8043 - loss: 0.3029
# ✅ Saved improved model at epoch 34 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9558 - aggregated_jaccard_index: 0.8088 - dice_coef: 0.8926 - f1_score: 0.8944 - iou_coef: 0.8074 - loss: 0.2976 - val_accuracy: 0.9420 - val_aggregated_jaccard_index: 0.7298 - val_dice_coef: 0.8538 - val_f1_score: 0.8550 - val_iou_coef: 0.7467 - val_loss: 0.4241 - learning_rate: 0.0010
# Epoch 35/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9554 - aggregated_jaccard_index: 0.8104 - dice_coef: 0.8935 - f1_score: 0.8952 - iou_coef: 0.8087 - loss: 0.2961
# ✅ Saved improved model at epoch 35 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9564 - aggregated_jaccard_index: 0.8124 - dice_coef: 0.8942 - f1_score: 0.8961 - iou_coef: 0.8100 - loss: 0.2931 - val_accuracy: 0.9392 - val_aggregated_jaccard_index: 0.7163 - val_dice_coef: 0.8441 - val_f1_score: 0.8452 - val_iou_coef: 0.7321 - val_loss: 0.4458 - learning_rate: 0.0010
# Epoch 36/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9551 - aggregated_jaccard_index: 0.8098 - dice_coef: 0.8932 - f1_score: 0.8951 - iou_coef: 0.8082 - loss: 0.2970
# ✅ Saved improved model at epoch 36 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9567 - aggregated_jaccard_index: 0.8130 - dice_coef: 0.8952 - f1_score: 0.8971 - iou_coef: 0.8116 - loss: 0.2920 - val_accuracy: 0.9344 - val_aggregated_jaccard_index: 0.6913 - val_dice_coef: 0.8224 - val_f1_score: 0.8235 - val_iou_coef: 0.7014 - val_loss: 0.4873 - learning_rate: 0.0010
# Epoch 37/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9567 - aggregated_jaccard_index: 0.8139 - dice_coef: 0.8955 - f1_score: 0.8973 - iou_coef: 0.8120 - loss: 0.2905
# ✅ Saved improved model at epoch 37 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9569 - aggregated_jaccard_index: 0.8132 - dice_coef: 0.8951 - f1_score: 0.8968 - iou_coef: 0.8115 - loss: 0.2909 - val_accuracy: 0.9426 - val_aggregated_jaccard_index: 0.7341 - val_dice_coef: 0.8559 - val_f1_score: 0.8570 - val_iou_coef: 0.7497 - val_loss: 0.4165 - learning_rate: 0.0010
# Epoch 38/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9596 - aggregated_jaccard_index: 0.8225 - dice_coef: 0.9002 - f1_score: 0.9018 - iou_coef: 0.8198 - loss: 0.2769
# ✅ Saved improved model at epoch 38 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9572 - aggregated_jaccard_index: 0.8157 - dice_coef: 0.8966 - f1_score: 0.8983 - iou_coef: 0.8139 - loss: 0.2876 - val_accuracy: 0.9405 - val_aggregated_jaccard_index: 0.7235 - val_dice_coef: 0.8490 - val_f1_score: 0.8501 - val_iou_coef: 0.7396 - val_loss: 0.4337 - learning_rate: 0.0010
# Epoch 39/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9588 - aggregated_jaccard_index: 0.8198 - dice_coef: 0.8999 - f1_score: 0.9016 - iou_coef: 0.8195 - loss: 0.2814
# ✅ Saved improved model at epoch 39 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9581 - aggregated_jaccard_index: 0.8183 - dice_coef: 0.8985 - f1_score: 0.9002 - iou_coef: 0.8170 - loss: 0.2834 - val_accuracy: 0.9453 - val_aggregated_jaccard_index: 0.7529 - val_dice_coef: 0.8657 - val_f1_score: 0.8665 - val_iou_coef: 0.7638 - val_loss: 0.3870 - learning_rate: 0.0010
# Epoch 40/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9576 - aggregated_jaccard_index: 0.8209 - dice_coef: 0.8998 - f1_score: 0.9014 - iou_coef: 0.8191 - loss: 0.2795
# ✅ Saved improved model at epoch 40 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9580 - aggregated_jaccard_index: 0.8178 - dice_coef: 0.8984 - f1_score: 0.9001 - iou_coef: 0.8168 - loss: 0.2844 - val_accuracy: 0.9425 - val_aggregated_jaccard_index: 0.7325 - val_dice_coef: 0.8526 - val_f1_score: 0.8531 - val_iou_coef: 0.7445 - val_loss: 0.4197 - learning_rate: 0.0010
# Epoch 41/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9606 - aggregated_jaccard_index: 0.8216 - dice_coef: 0.8998 - f1_score: 0.9014 - iou_coef: 0.8190 - loss: 0.2779
# ✅ Saved improved model at epoch 41 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9585 - aggregated_jaccard_index: 0.8198 - dice_coef: 0.8994 - f1_score: 0.9011 - iou_coef: 0.8185 - loss: 0.2810 - val_accuracy: 0.9340 - val_aggregated_jaccard_index: 0.6884 - val_dice_coef: 0.8228 - val_f1_score: 0.8236 - val_iou_coef: 0.7017 - val_loss: 0.4935 - learning_rate: 0.0010
# Epoch 42/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9609 - aggregated_jaccard_index: 0.8269 - dice_coef: 0.9030 - f1_score: 0.9046 - iou_coef: 0.8243 - loss: 0.2699
# ✅ Saved improved model at epoch 42 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9591 - aggregated_jaccard_index: 0.8230 - dice_coef: 0.9014 - f1_score: 0.9030 - iou_coef: 0.8216 - loss: 0.2767 - val_accuracy: 0.9370 - val_aggregated_jaccard_index: 0.7077 - val_dice_coef: 0.8325 - val_f1_score: 0.8334 - val_iou_coef: 0.7153 - val_loss: 0.4592 - learning_rate: 0.0010
# Epoch 43/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9585 - aggregated_jaccard_index: 0.8205 - dice_coef: 0.9005 - f1_score: 0.9021 - iou_coef: 0.8202 - loss: 0.2802
# ✅ Saved improved model at epoch 43 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9589 - aggregated_jaccard_index: 0.8226 - dice_coef: 0.9010 - f1_score: 0.9025 - iou_coef: 0.8210 - loss: 0.2770 - val_accuracy: 0.9424 - val_aggregated_jaccard_index: 0.7346 - val_dice_coef: 0.8553 - val_f1_score: 0.8557 - val_iou_coef: 0.7485 - val_loss: 0.4158 - learning_rate: 0.0010
# Epoch 44/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9604 - aggregated_jaccard_index: 0.8260 - dice_coef: 0.9031 - f1_score: 0.9046 - iou_coef: 0.8246 - loss: 0.2713
# ✅ Saved improved model at epoch 44 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9596 - aggregated_jaccard_index: 0.8241 - dice_coef: 0.9021 - f1_score: 0.9037 - iou_coef: 0.8230 - loss: 0.2735 - val_accuracy: 0.9432 - val_aggregated_jaccard_index: 0.7384 - val_dice_coef: 0.8558 - val_f1_score: 0.8567 - val_iou_coef: 0.7489 - val_loss: 0.4102 - learning_rate: 0.0010
# Epoch 45/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9616 - aggregated_jaccard_index: 0.8303 - dice_coef: 0.9052 - f1_score: 0.9067 - iou_coef: 0.8279 - loss: 0.2640
# ✅ Saved improved model at epoch 45 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9597 - aggregated_jaccard_index: 0.8244 - dice_coef: 0.9019 - f1_score: 0.9034 - iou_coef: 0.8226 - loss: 0.2717 - val_accuracy: 0.9387 - val_aggregated_jaccard_index: 0.7128 - val_dice_coef: 0.8433 - val_f1_score: 0.8442 - val_iou_coef: 0.7312 - val_loss: 0.4521 - learning_rate: 0.0010
# Epoch 46/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9606 - aggregated_jaccard_index: 0.8241 - dice_coef: 0.9023 - f1_score: 0.9038 - iou_coef: 0.8230 - loss: 0.2741
# ✅ Saved improved model at epoch 46 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9598 - aggregated_jaccard_index: 0.8249 - dice_coef: 0.9024 - f1_score: 0.9039 - iou_coef: 0.8233 - loss: 0.2727 - val_accuracy: 0.9425 - val_aggregated_jaccard_index: 0.7354 - val_dice_coef: 0.8564 - val_f1_score: 0.8572 - val_iou_coef: 0.7504 - val_loss: 0.4141 - learning_rate: 0.0010
# Epoch 47/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9596 - aggregated_jaccard_index: 0.8253 - dice_coef: 0.9034 - f1_score: 0.9049 - iou_coef: 0.8248 - loss: 0.2722
# ✅ Saved improved model at epoch 47 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9601 - aggregated_jaccard_index: 0.8268 - dice_coef: 0.9038 - f1_score: 0.9053 - iou_coef: 0.8255 - loss: 0.2704 - val_accuracy: 0.9299 - val_aggregated_jaccard_index: 0.6686 - val_dice_coef: 0.8062 - val_f1_score: 0.8072 - val_iou_coef: 0.6807 - val_loss: 0.5263 - learning_rate: 0.0010
# Epoch 48/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9603 - aggregated_jaccard_index: 0.8269 - dice_coef: 0.9037 - f1_score: 0.9052 - iou_coef: 0.8256 - loss: 0.2699
# ✅ Saved improved model at epoch 48 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9609 - aggregated_jaccard_index: 0.8298 - dice_coef: 0.9055 - f1_score: 0.9069 - iou_coef: 0.8285 - loss: 0.2650 - val_accuracy: 0.9426 - val_aggregated_jaccard_index: 0.7353 - val_dice_coef: 0.8577 - val_f1_score: 0.8584 - val_iou_coef: 0.7527 - val_loss: 0.4142 - learning_rate: 0.0010
# Epoch 49/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9618 - aggregated_jaccard_index: 0.8333 - dice_coef: 0.9065 - f1_score: 0.9079 - iou_coef: 0.8301 - loss: 0.2594
# ✅ Saved improved model at epoch 49 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9610 - aggregated_jaccard_index: 0.8308 - dice_coef: 0.9053 - f1_score: 0.9067 - iou_coef: 0.8281 - loss: 0.2633 - val_accuracy: 0.9390 - val_aggregated_jaccard_index: 0.7145 - val_dice_coef: 0.8334 - val_f1_score: 0.8341 - val_iou_coef: 0.7180 - val_loss: 0.4492 - learning_rate: 0.0010
# Epoch 50/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9615 - aggregated_jaccard_index: 0.8308 - dice_coef: 0.9058 - f1_score: 0.9071 - iou_coef: 0.8290 - loss: 0.2634
# ✅ Saved improved model at epoch 50 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9614 - aggregated_jaccard_index: 0.8325 - dice_coef: 0.9067 - f1_score: 0.9081 - iou_coef: 0.8304 - loss: 0.2605 - val_accuracy: 0.9437 - val_aggregated_jaccard_index: 0.7388 - val_dice_coef: 0.8591 - val_f1_score: 0.8599 - val_iou_coef: 0.7547 - val_loss: 0.4086 - learning_rate: 0.0010
# Epoch 51/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9598 - aggregated_jaccard_index: 0.8279 - dice_coef: 0.9041 - f1_score: 0.9055 - iou_coef: 0.8262 - loss: 0.2681
# ✅ Saved improved model at epoch 51 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9610 - aggregated_jaccard_index: 0.8306 - dice_coef: 0.9058 - f1_score: 0.9072 - iou_coef: 0.8290 - loss: 0.2635 - val_accuracy: 0.9397 - val_aggregated_jaccard_index: 0.7209 - val_dice_coef: 0.8440 - val_f1_score: 0.8443 - val_iou_coef: 0.7321 - val_loss: 0.4381 - learning_rate: 0.0010
# Epoch 52/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9602 - aggregated_jaccard_index: 0.8277 - dice_coef: 0.9045 - f1_score: 0.9058 - iou_coef: 0.8271 - loss: 0.2685
# ✅ Saved improved model at epoch 52 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9611 - aggregated_jaccard_index: 0.8304 - dice_coef: 0.9059 - f1_score: 0.9072 - iou_coef: 0.8292 - loss: 0.2631 - val_accuracy: 0.9399 - val_aggregated_jaccard_index: 0.7191 - val_dice_coef: 0.8420 - val_f1_score: 0.8427 - val_iou_coef: 0.7296 - val_loss: 0.4410 - learning_rate: 0.0010
# Epoch 53/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9618 - aggregated_jaccard_index: 0.8333 - dice_coef: 0.9077 - f1_score: 0.9091 - iou_coef: 0.8321 - loss: 0.2593
# ✅ Saved improved model at epoch 53 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9616 - aggregated_jaccard_index: 0.8331 - dice_coef: 0.9073 - f1_score: 0.9086 - iou_coef: 0.8314 - loss: 0.2596 - val_accuracy: 0.9327 - val_aggregated_jaccard_index: 0.6835 - val_dice_coef: 0.8202 - val_f1_score: 0.8207 - val_iou_coef: 0.6981 - val_loss: 0.5003 - learning_rate: 0.0010
# Epoch 54/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9601 - aggregated_jaccard_index: 0.8319 - dice_coef: 0.9065 - f1_score: 0.9078 - iou_coef: 0.8302 - loss: 0.2617
# ✅ Saved improved model at epoch 54 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9618 - aggregated_jaccard_index: 0.8348 - dice_coef: 0.9081 - f1_score: 0.9094 - iou_coef: 0.8329 - loss: 0.2575 - val_accuracy: 0.9413 - val_aggregated_jaccard_index: 0.7288 - val_dice_coef: 0.8516 - val_f1_score: 0.8525 - val_iou_coef: 0.7433 - val_loss: 0.4245 - learning_rate: 0.0010
# Epoch 55/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9632 - aggregated_jaccard_index: 0.8388 - dice_coef: 0.9108 - f1_score: 0.9121 - iou_coef: 0.8373 - loss: 0.2509
# ✅ Saved improved model at epoch 55 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9621 - aggregated_jaccard_index: 0.8353 - dice_coef: 0.9088 - f1_score: 0.9101 - iou_coef: 0.8340 - loss: 0.2570 - val_accuracy: 0.9390 - val_aggregated_jaccard_index: 0.7157 - val_dice_coef: 0.8426 - val_f1_score: 0.8428 - val_iou_coef: 0.7303 - val_loss: 0.4465 - learning_rate: 0.0010
# Epoch 56/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9633 - aggregated_jaccard_index: 0.8387 - dice_coef: 0.9107 - f1_score: 0.9120 - iou_coef: 0.8370 - loss: 0.2506
# ✅ Saved improved model at epoch 56 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9629 - aggregated_jaccard_index: 0.8385 - dice_coef: 0.9107 - f1_score: 0.9119 - iou_coef: 0.8371 - loss: 0.2518 - val_accuracy: 0.9390 - val_aggregated_jaccard_index: 0.7144 - val_dice_coef: 0.8411 - val_f1_score: 0.8418 - val_iou_coef: 0.7280 - val_loss: 0.4490 - learning_rate: 0.0010
# Epoch 57/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9631 - aggregated_jaccard_index: 0.8410 - dice_coef: 0.9117 - f1_score: 0.9129 - iou_coef: 0.8387 - loss: 0.2468
# ✅ Saved improved model at epoch 57 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9629 - aggregated_jaccard_index: 0.8382 - dice_coef: 0.9104 - f1_score: 0.9117 - iou_coef: 0.8366 - loss: 0.2510 - val_accuracy: 0.9407 - val_aggregated_jaccard_index: 0.7230 - val_dice_coef: 0.8462 - val_f1_score: 0.8469 - val_iou_coef: 0.7349 - val_loss: 0.4355 - learning_rate: 0.0010
# Epoch 58/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9621 - aggregated_jaccard_index: 0.8390 - dice_coef: 0.9109 - f1_score: 0.9121 - iou_coef: 0.8374 - loss: 0.2500
# ✅ Saved improved model at epoch 58 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9630 - aggregated_jaccard_index: 0.8382 - dice_coef: 0.9105 - f1_score: 0.9117 - iou_coef: 0.8368 - loss: 0.2507 - val_accuracy: 0.9356 - val_aggregated_jaccard_index: 0.6977 - val_dice_coef: 0.8343 - val_f1_score: 0.8350 - val_iou_coef: 0.7191 - val_loss: 0.4766 - learning_rate: 0.0010
# Epoch 59/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9615 - aggregated_jaccard_index: 0.8379 - dice_coef: 0.9106 - f1_score: 0.9118 - iou_coef: 0.8370 - loss: 0.2520
# ✅ Saved improved model at epoch 59 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9633 - aggregated_jaccard_index: 0.8393 - dice_coef: 0.9111 - f1_score: 0.9123 - iou_coef: 0.8378 - loss: 0.2494 - val_accuracy: 0.9360 - val_aggregated_jaccard_index: 0.6986 - val_dice_coef: 0.8300 - val_f1_score: 0.8308 - val_iou_coef: 0.7119 - val_loss: 0.4763 - learning_rate: 0.0010
# Epoch 60/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9630 - aggregated_jaccard_index: 0.8386 - dice_coef: 0.9110 - f1_score: 0.9121 - iou_coef: 0.8376 - loss: 0.2509
# ✅ Saved improved model at epoch 60 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9631 - aggregated_jaccard_index: 0.8379 - dice_coef: 0.9100 - f1_score: 0.9112 - iou_coef: 0.8360 - loss: 0.2508 - val_accuracy: 0.9393 - val_aggregated_jaccard_index: 0.7163 - val_dice_coef: 0.8383 - val_f1_score: 0.8388 - val_iou_coef: 0.7239 - val_loss: 0.4464 - learning_rate: 0.0010
# Epoch 61/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9637 - aggregated_jaccard_index: 0.8377 - dice_coef: 0.9110 - f1_score: 0.9121 - iou_coef: 0.8375 - loss: 0.2520
# ✅ Saved improved model at epoch 61 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9635 - aggregated_jaccard_index: 0.8399 - dice_coef: 0.9115 - f1_score: 0.9126 - iou_coef: 0.8384 - loss: 0.2482 - val_accuracy: 0.9383 - val_aggregated_jaccard_index: 0.7118 - val_dice_coef: 0.8387 - val_f1_score: 0.8393 - val_iou_coef: 0.7242 - val_loss: 0.4533 - learning_rate: 0.0010
# Epoch 62/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9650 - aggregated_jaccard_index: 0.8475 - dice_coef: 0.9157 - f1_score: 0.9168 - iou_coef: 0.8455 - loss: 0.2366
# ✅ Saved improved model at epoch 62 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9637 - aggregated_jaccard_index: 0.8419 - dice_coef: 0.9125 - f1_score: 0.9137 - iou_coef: 0.8402 - loss: 0.2462 - val_accuracy: 0.9394 - val_aggregated_jaccard_index: 0.7191 - val_dice_coef: 0.8456 - val_f1_score: 0.8458 - val_iou_coef: 0.7347 - val_loss: 0.4407 - learning_rate: 0.0010
# Epoch 63/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9639 - aggregated_jaccard_index: 0.8446 - dice_coef: 0.9140 - f1_score: 0.9152 - iou_coef: 0.8427 - loss: 0.2411
# ✅ Saved improved model at epoch 63 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9643 - aggregated_jaccard_index: 0.8440 - dice_coef: 0.9139 - f1_score: 0.9150 - iou_coef: 0.8424 - loss: 0.2423 - val_accuracy: 0.9354 - val_aggregated_jaccard_index: 0.6959 - val_dice_coef: 0.8271 - val_f1_score: 0.8277 - val_iou_coef: 0.7068 - val_loss: 0.4808 - learning_rate: 0.0010
# Epoch 64/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9641 - aggregated_jaccard_index: 0.8403 - dice_coef: 0.9119 - f1_score: 0.9130 - iou_coef: 0.8390 - loss: 0.2479
# ✅ Saved improved model at epoch 64 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9645 - aggregated_jaccard_index: 0.8443 - dice_coef: 0.9141 - f1_score: 0.9152 - iou_coef: 0.8428 - loss: 0.2413 - val_accuracy: 0.9430 - val_aggregated_jaccard_index: 0.7373 - val_dice_coef: 0.8557 - val_f1_score: 0.8565 - val_iou_coef: 0.7488 - val_loss: 0.4116 - learning_rate: 0.0010
# Epoch 65/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9629 - aggregated_jaccard_index: 0.8406 - dice_coef: 0.9122 - f1_score: 0.9133 - iou_coef: 0.8395 - loss: 0.2475
# ✅ Saved improved model at epoch 65 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9645 - aggregated_jaccard_index: 0.8436 - dice_coef: 0.9139 - f1_score: 0.9150 - iou_coef: 0.8425 - loss: 0.2418 - val_accuracy: 0.9458 - val_aggregated_jaccard_index: 0.7502 - val_dice_coef: 0.8654 - val_f1_score: 0.8662 - val_iou_coef: 0.7638 - val_loss: 0.3902 - learning_rate: 0.0010
# Epoch 66/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9629 - aggregated_jaccard_index: 0.8392 - dice_coef: 0.9113 - f1_score: 0.9125 - iou_coef: 0.8383 - loss: 0.2499
# ✅ Saved improved model at epoch 66 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9644 - aggregated_jaccard_index: 0.8430 - dice_coef: 0.9130 - f1_score: 0.9141 - iou_coef: 0.8412 - loss: 0.2417 - val_accuracy: 0.9350 - val_aggregated_jaccard_index: 0.6935 - val_dice_coef: 0.8256 - val_f1_score: 0.8262 - val_iou_coef: 0.7058 - val_loss: 0.4844 - learning_rate: 0.0010
# Epoch 67/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9622 - aggregated_jaccard_index: 0.8393 - dice_coef: 0.9110 - f1_score: 0.9121 - iou_coef: 0.8377 - loss: 0.2500
# ✅ Saved improved model at epoch 67 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9637 - aggregated_jaccard_index: 0.8417 - dice_coef: 0.9124 - f1_score: 0.9135 - iou_coef: 0.8400 - loss: 0.2460 - val_accuracy: 0.9347 - val_aggregated_jaccard_index: 0.6938 - val_dice_coef: 0.8267 - val_f1_score: 0.8266 - val_iou_coef: 0.7068 - val_loss: 0.4832 - learning_rate: 0.0010
# Epoch 68/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9642 - aggregated_jaccard_index: 0.8455 - dice_coef: 0.9143 - f1_score: 0.9154 - iou_coef: 0.8433 - loss: 0.2403
# ✅ Saved improved model at epoch 68 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9646 - aggregated_jaccard_index: 0.8453 - dice_coef: 0.9143 - f1_score: 0.9153 - iou_coef: 0.8432 - loss: 0.2392 - val_accuracy: 0.9390 - val_aggregated_jaccard_index: 0.7158 - val_dice_coef: 0.8448 - val_f1_score: 0.8450 - val_iou_coef: 0.7338 - val_loss: 0.4468 - learning_rate: 0.0010
# Epoch 69/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9642 - aggregated_jaccard_index: 0.8492 - dice_coef: 0.9172 - f1_score: 0.9182 - iou_coef: 0.8480 - loss: 0.2338
# ✅ Saved improved model at epoch 69 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9649 - aggregated_jaccard_index: 0.8457 - dice_coef: 0.9147 - f1_score: 0.9157 - iou_coef: 0.8438 - loss: 0.2377 - val_accuracy: 0.9422 - val_aggregated_jaccard_index: 0.7328 - val_dice_coef: 0.8544 - val_f1_score: 0.8547 - val_iou_coef: 0.7471 - val_loss: 0.4184 - learning_rate: 0.0010
# Epoch 70/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9651 - aggregated_jaccard_index: 0.8471 - dice_coef: 0.9167 - f1_score: 0.9177 - iou_coef: 0.8471 - loss: 0.2372
# ✅ Saved improved model at epoch 70 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9651 - aggregated_jaccard_index: 0.8470 - dice_coef: 0.9161 - f1_score: 0.9171 - iou_coef: 0.8461 - loss: 0.2379 - val_accuracy: 0.9429 - val_aggregated_jaccard_index: 0.7363 - val_dice_coef: 0.8554 - val_f1_score: 0.8556 - val_iou_coef: 0.7484 - val_loss: 0.4137 - learning_rate: 0.0010
# Epoch 71/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9647 - aggregated_jaccard_index: 0.8452 - dice_coef: 0.9145 - f1_score: 0.9155 - iou_coef: 0.8435 - loss: 0.2402
# ✅ Saved improved model at epoch 71 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - accuracy: 0.9654 - aggregated_jaccard_index: 0.8478 - dice_coef: 0.9163 - f1_score: 0.9172 - iou_coef: 0.8465 - loss: 0.2348 - val_accuracy: 0.9398 - val_aggregated_jaccard_index: 0.7187 - val_dice_coef: 0.8458 - val_f1_score: 0.8462 - val_iou_coef: 0.7346 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 72/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9654 - aggregated_jaccard_index: 0.8474 - dice_coef: 0.9156 - f1_score: 0.9166 - iou_coef: 0.8454 - loss: 0.2367
# ✅ Saved improved model at epoch 72 with val_iou=0.0000
# ...
# Epoch 124/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9709 - aggregated_jaccard_index: 0.8690 - dice_coef: 0.9288 - f1_score: 0.9294 - iou_coef: 0.8677 - loss: 0.2021
# ✅ Saved improved model at epoch 124 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9703 - aggregated_jaccard_index: 0.8686 - dice_coef: 0.9283 - f1_score: 0.9288 - iou_coef: 0.8670 - loss: 0.2020 - val_accuracy: 0.9383 - val_aggregated_jaccard_index: 0.7119 - val_dice_coef: 0.8394 - val_f1_score: 0.8398 - val_iou_coef: 0.7249 - val_loss: 0.4535 - learning_rate: 0.0010
# Epoch 125/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9702 - aggregated_jaccard_index: 0.8673 - dice_coef: 0.9278 - f1_score: 0.9284 - iou_coef: 0.8662 - loss: 0.2048
# ✅ Saved improved model at epoch 125 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9702 - aggregated_jaccard_index: 0.8680 - dice_coef: 0.9283 - f1_score: 0.9288 - iou_coef: 0.8669 - loss: 0.2039 - val_accuracy: 0.9422 - val_aggregated_jaccard_index: 0.7326 - val_dice_coef: 0.8554 - val_f1_score: 0.8556 - val_iou_coef: 0.7490 - val_loss: 0.4189 - learning_rate: 0.0010
# Epoch 126/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9699 - aggregated_jaccard_index: 0.8640 - dice_coef: 0.9262 - f1_score: 0.9268 - iou_coef: 0.8635 - loss: 0.2102
# ✅ Saved improved model at epoch 126 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9706 - aggregated_jaccard_index: 0.8695 - dice_coef: 0.9291 - f1_score: 0.9297 - iou_coef: 0.8684 - loss: 0.2013 - val_accuracy: 0.9438 - val_aggregated_jaccard_index: 0.7429 - val_dice_coef: 0.8601 - val_f1_score: 0.8604 - val_iou_coef: 0.7555 - val_loss: 0.4018 - learning_rate: 0.0010
# Epoch 127/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9715 - aggregated_jaccard_index: 0.8706 - dice_coef: 0.9296 - f1_score: 0.9302 - iou_coef: 0.8693 - loss: 0.2000
# ✅ Saved improved model at epoch 127 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9707 - aggregated_jaccard_index: 0.8700 - dice_coef: 0.9292 - f1_score: 0.9298 - iou_coef: 0.8685 - loss: 0.1999 - val_accuracy: 0.9436 - val_aggregated_jaccard_index: 0.7400 - val_dice_coef: 0.8564 - val_f1_score: 0.8566 - val_iou_coef: 0.7496 - val_loss: 0.4076 - learning_rate: 0.0010
# Epoch 128/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9700 - aggregated_jaccard_index: 0.8637 - dice_coef: 0.9256 - f1_score: 0.9262 - iou_coef: 0.8623 - loss: 0.2108
# ✅ Saved improved model at epoch 128 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9703 - aggregated_jaccard_index: 0.8684 - dice_coef: 0.9285 - f1_score: 0.9290 - iou_coef: 0.8673 - loss: 0.2031 - val_accuracy: 0.9467 - val_aggregated_jaccard_index: 0.7614 - val_dice_coef: 0.8713 - val_f1_score: 0.8714 - val_iou_coef: 0.7725 - val_loss: 0.3728 - learning_rate: 0.0010
# Epoch 129/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9708 - aggregated_jaccard_index: 0.8699 - dice_coef: 0.9289 - f1_score: 0.9294 - iou_coef: 0.8680 - loss: 0.2007
# ✅ Saved improved model at epoch 129 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9703 - aggregated_jaccard_index: 0.8675 - dice_coef: 0.9279 - f1_score: 0.9284 - iou_coef: 0.8663 - loss: 0.2030 - val_accuracy: 0.9435 - val_aggregated_jaccard_index: 0.7389 - val_dice_coef: 0.8579 - val_f1_score: 0.8583 - val_iou_coef: 0.7525 - val_loss: 0.4086 - learning_rate: 0.0010
# Epoch 130/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9705 - aggregated_jaccard_index: 0.8691 - dice_coef: 0.9290 - f1_score: 0.9296 - iou_coef: 0.8682 - loss: 0.2021
# ✅ Saved improved model at epoch 130 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9709 - aggregated_jaccard_index: 0.8710 - dice_coef: 0.9299 - f1_score: 0.9304 - iou_coef: 0.8697 - loss: 0.1989 - val_accuracy: 0.9396 - val_aggregated_jaccard_index: 0.7180 - val_dice_coef: 0.8444 - val_f1_score: 0.8447 - val_iou_coef: 0.7322 - val_loss: 0.4435 - learning_rate: 0.0010
# Epoch 131/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9718 - aggregated_jaccard_index: 0.8735 - dice_coef: 0.9311 - f1_score: 0.9316 - iou_coef: 0.8719 - loss: 0.1952
# ✅ Saved improved model at epoch 131 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9708 - aggregated_jaccard_index: 0.8704 - dice_coef: 0.9296 - f1_score: 0.9301 - iou_coef: 0.8692 - loss: 0.1992 - val_accuracy: 0.9458 - val_aggregated_jaccard_index: 0.7522 - val_dice_coef: 0.8661 - val_f1_score: 0.8663 - val_iou_coef: 0.7647 - val_loss: 0.3871 - learning_rate: 0.0010
# Epoch 132/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9705 - aggregated_jaccard_index: 0.8708 - dice_coef: 0.9288 - f1_score: 0.9293 - iou_coef: 0.8679 - loss: 0.1997
# ✅ Saved improved model at epoch 132 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9706 - aggregated_jaccard_index: 0.8693 - dice_coef: 0.9285 - f1_score: 0.9291 - iou_coef: 0.8675 - loss: 0.2004 - val_accuracy: 0.9406 - val_aggregated_jaccard_index: 0.7243 - val_dice_coef: 0.8482 - val_f1_score: 0.8483 - val_iou_coef: 0.7382 - val_loss: 0.4326 - learning_rate: 0.0010
# Epoch 133/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9711 - aggregated_jaccard_index: 0.8695 - dice_coef: 0.9289 - f1_score: 0.9294 - iou_coef: 0.8680 - loss: 0.2014
# ✅ Saved improved model at epoch 133 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9707 - aggregated_jaccard_index: 0.8701 - dice_coef: 0.9294 - f1_score: 0.9299 - iou_coef: 0.8689 - loss: 0.2000 - val_accuracy: 0.9436 - val_aggregated_jaccard_index: 0.7383 - val_dice_coef: 0.8577 - val_f1_score: 0.8581 - val_iou_coef: 0.7522 - val_loss: 0.4096 - learning_rate: 0.0010
# Epoch 134/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9711 - aggregated_jaccard_index: 0.8687 - dice_coef: 0.9291 - f1_score: 0.9296 - iou_coef: 0.8684 - loss: 0.2027
# ✅ Saved improved model at epoch 134 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9710 - aggregated_jaccard_index: 0.8710 - dice_coef: 0.9302 - f1_score: 0.9307 - iou_coef: 0.8703 - loss: 0.1991 - val_accuracy: 0.9366 - val_aggregated_jaccard_index: 0.7026 - val_dice_coef: 0.8352 - val_f1_score: 0.8356 - val_iou_coef: 0.7198 - val_loss: 0.4689 - learning_rate: 0.0010
# Epoch 135/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9697 - aggregated_jaccard_index: 0.8689 - dice_coef: 0.9287 - f1_score: 0.9293 - iou_coef: 0.8677 - loss: 0.2024
# ✅ Saved improved model at epoch 135 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9709 - aggregated_jaccard_index: 0.8707 - dice_coef: 0.9296 - f1_score: 0.9301 - iou_coef: 0.8692 - loss: 0.1981 - val_accuracy: 0.9402 - val_aggregated_jaccard_index: 0.7232 - val_dice_coef: 0.8480 - val_f1_score: 0.8481 - val_iou_coef: 0.7376 - val_loss: 0.4343 - learning_rate: 0.0010
# Epoch 136/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9713 - aggregated_jaccard_index: 0.8703 - dice_coef: 0.9298 - f1_score: 0.9304 - iou_coef: 0.8695 - loss: 0.2000
# ✅ Saved improved model at epoch 136 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9711 - aggregated_jaccard_index: 0.8707 - dice_coef: 0.9300 - f1_score: 0.9305 - iou_coef: 0.8699 - loss: 0.1982 - val_accuracy: 0.9416 - val_aggregated_jaccard_index: 0.7319 - val_dice_coef: 0.8524 - val_f1_score: 0.8523 - val_iou_coef: 0.7439 - val_loss: 0.4203 - learning_rate: 0.0010
# Epoch 137/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9712 - aggregated_jaccard_index: 0.8724 - dice_coef: 0.9304 - f1_score: 0.9310 - iou_coef: 0.8707 - loss: 0.1969
# ✅ Saved improved model at epoch 137 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9709 - aggregated_jaccard_index: 0.8714 - dice_coef: 0.9297 - f1_score: 0.9303 - iou_coef: 0.8695 - loss: 0.1979 - val_accuracy: 0.9405 - val_aggregated_jaccard_index: 0.7237 - val_dice_coef: 0.8475 - val_f1_score: 0.8478 - val_iou_coef: 0.7367 - val_loss: 0.4337 - learning_rate: 0.0010
# Epoch 138/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9704 - aggregated_jaccard_index: 0.8696 - dice_coef: 0.9287 - f1_score: 0.9292 - iou_coef: 0.8677 - loss: 0.2013
# ✅ Saved improved model at epoch 138 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9708 - aggregated_jaccard_index: 0.8715 - dice_coef: 0.9301 - f1_score: 0.9307 - iou_coef: 0.8702 - loss: 0.1990 - val_accuracy: 0.9424 - val_aggregated_jaccard_index: 0.7345 - val_dice_coef: 0.8560 - val_f1_score: 0.8561 - val_iou_coef: 0.7497 - val_loss: 0.4163 - learning_rate: 0.0010
# Epoch 139/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9724 - aggregated_jaccard_index: 0.8757 - dice_coef: 0.9319 - f1_score: 0.9324 - iou_coef: 0.8733 - loss: 0.1918
# ✅ Saved improved model at epoch 139 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9714 - aggregated_jaccard_index: 0.8737 - dice_coef: 0.9313 - f1_score: 0.9318 - iou_coef: 0.8721 - loss: 0.1951 - val_accuracy: 0.9396 - val_aggregated_jaccard_index: 0.7206 - val_dice_coef: 0.8453 - val_f1_score: 0.8455 - val_iou_coef: 0.7334 - val_loss: 0.4385 - learning_rate: 0.0010
# Epoch 140/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8753 - dice_coef: 0.9317 - f1_score: 0.9322 - iou_coef: 0.8729 - loss: 0.1924
# ✅ Saved improved model at epoch 140 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9713 - aggregated_jaccard_index: 0.8735 - dice_coef: 0.9306 - f1_score: 0.9311 - iou_coef: 0.8711 - loss: 0.1940 - val_accuracy: 0.9414 - val_aggregated_jaccard_index: 0.7281 - val_dice_coef: 0.8507 - val_f1_score: 0.8512 - val_iou_coef: 0.7417 - val_loss: 0.4269 - learning_rate: 0.0010
# Epoch 141/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9710 - aggregated_jaccard_index: 0.8713 - dice_coef: 0.9295 - f1_score: 0.9300 - iou_coef: 0.8691 - loss: 0.1987
# ✅ Saved improved model at epoch 141 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9712 - aggregated_jaccard_index: 0.8730 - dice_coef: 0.9307 - f1_score: 0.9312 - iou_coef: 0.8712 - loss: 0.1960 - val_accuracy: 0.9461 - val_aggregated_jaccard_index: 0.7555 - val_dice_coef: 0.8673 - val_f1_score: 0.8676 - val_iou_coef: 0.7662 - val_loss: 0.3822 - learning_rate: 0.0010
# Epoch 142/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9719 - aggregated_jaccard_index: 0.8753 - dice_coef: 0.9319 - f1_score: 0.9324 - iou_coef: 0.8733 - loss: 0.1922
# ✅ Saved improved model at epoch 142 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9713 - aggregated_jaccard_index: 0.8732 - dice_coef: 0.9311 - f1_score: 0.9316 - iou_coef: 0.8718 - loss: 0.1956 - val_accuracy: 0.9411 - val_aggregated_jaccard_index: 0.7273 - val_dice_coef: 0.8510 - val_f1_score: 0.8514 - val_iou_coef: 0.7421 - val_loss: 0.4277 - learning_rate: 0.0010
# Epoch 143/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8726 - dice_coef: 0.9313 - f1_score: 0.9318 - iou_coef: 0.8722 - loss: 0.1967
# ✅ Saved improved model at epoch 143 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8739 - dice_coef: 0.9314 - f1_score: 0.9319 - iou_coef: 0.8724 - loss: 0.1947 - val_accuracy: 0.9415 - val_aggregated_jaccard_index: 0.7305 - val_dice_coef: 0.8530 - val_f1_score: 0.8533 - val_iou_coef: 0.7452 - val_loss: 0.4224 - learning_rate: 0.0010
# Epoch 144/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8726 - dice_coef: 0.9306 - f1_score: 0.9312 - iou_coef: 0.8711 - loss: 0.1966
# ✅ Saved improved model at epoch 144 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9715 - aggregated_jaccard_index: 0.8729 - dice_coef: 0.9310 - f1_score: 0.9316 - iou_coef: 0.8718 - loss: 0.1950 - val_accuracy: 0.9420 - val_aggregated_jaccard_index: 0.7298 - val_dice_coef: 0.8532 - val_f1_score: 0.8535 - val_iou_coef: 0.7456 - val_loss: 0.4239 - learning_rate: 0.0010
# Epoch 145/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9723 - aggregated_jaccard_index: 0.8762 - dice_coef: 0.9325 - f1_score: 0.9330 - iou_coef: 0.8742 - loss: 0.1908
# ✅ Saved improved model at epoch 145 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8740 - dice_coef: 0.9316 - f1_score: 0.9321 - iou_coef: 0.8728 - loss: 0.1938 - val_accuracy: 0.9409 - val_aggregated_jaccard_index: 0.7256 - val_dice_coef: 0.8473 - val_f1_score: 0.8475 - val_iou_coef: 0.7362 - val_loss: 0.4309 - learning_rate: 0.0010
# Epoch 146/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9719 - aggregated_jaccard_index: 0.8736 - dice_coef: 0.9311 - f1_score: 0.9316 - iou_coef: 0.8718 - loss: 0.1949
# ✅ Saved improved model at epoch 146 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9711 - aggregated_jaccard_index: 0.8723 - dice_coef: 0.9306 - f1_score: 0.9311 - iou_coef: 0.8710 - loss: 0.1978 - val_accuracy: 0.9438 - val_aggregated_jaccard_index: 0.7452 - val_dice_coef: 0.8611 - val_f1_score: 0.8611 - val_iou_coef: 0.7568 - val_loss: 0.3984 - learning_rate: 0.0010
# Epoch 147/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9704 - aggregated_jaccard_index: 0.8727 - dice_coef: 0.9306 - f1_score: 0.9311 - iou_coef: 0.8711 - loss: 0.1964
# ✅ Saved improved model at epoch 147 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9715 - aggregated_jaccard_index: 0.8741 - dice_coef: 0.9315 - f1_score: 0.9319 - iou_coef: 0.8725 - loss: 0.1946 - val_accuracy: 0.9430 - val_aggregated_jaccard_index: 0.7352 - val_dice_coef: 0.8561 - val_f1_score: 0.8563 - val_iou_coef: 0.7498 - val_loss: 0.4151 - learning_rate: 0.0010
# Epoch 148/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9724 - aggregated_jaccard_index: 0.8791 - dice_coef: 0.9339 - f1_score: 0.9344 - iou_coef: 0.8766 - loss: 0.1863
# ✅ Saved improved model at epoch 148 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8746 - dice_coef: 0.9319 - f1_score: 0.9324 - iou_coef: 0.8732 - loss: 0.1941 - val_accuracy: 0.9413 - val_aggregated_jaccard_index: 0.7291 - val_dice_coef: 0.8514 - val_f1_score: 0.8517 - val_iou_coef: 0.7426 - val_loss: 0.4245 - learning_rate: 0.0010
# Epoch 149/150
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9718 - aggregated_jaccard_index: 0.8745 - dice_coef: 0.9309 - f1_score: 0.9313 - iou_coef: 0.8715 - loss: 0.1937
# ✅ Saved improved model at epoch 149 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9715 - aggregated_jaccard_index: 0.8733 - dice_coef: 0.9308 - f1_score: 0.9313 - iou_coef: 0.8713 - loss: 0.1939 - val_accuracy: 0.9441 - val_aggregated_jaccard_index: 0.7414 - val_dice_coef: 0.8585 - val_f1_score: 0.8589 - val_iou_coef: 0.7530 - val_loss: 0.4049 - learning_rate: 0.0010
# Epoch 150/150
# 85/86 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9703 - aggregated_jaccard_index: 0.8707 - dice_coef: 0.9297 - f1_score: 0.9302 - iou_coef: 0.8694 - loss: 0.1994
# ✅ Saved improved model at epoch 150 with val_iou=0.0000
# 86/86 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9716 - aggregated_jaccard_index: 0.8735 - dice_coef: 0.9314 - f1_score: 0.9319 - iou_coef: 0.8724 - loss: 0.1943 - val_accuracy: 0.9412 - val_aggregated_jaccard_index: 0.7274 - val_dice_coef: 0.8477 - val_f1_score: 0.8479 - val_iou_coef: 0.7366 - val_loss: 0.4278 - learning_rate: 0.0010
#
# 🎯 Training complete. Model saved and ready for inference.

# %%
###### from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/test/images"
MSK_DIR = "/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/CPM 17 DATA/CPM 17 DATA/test/masks"
img_size = 256
batch_size = 31

# -----------------------------
# COLLECT PATHS (SAFE)
# -----------------------------
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)

mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# SAFETY CHECK (CRITICAL)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == [stem(p) for p in mask_paths], \
    "❌ Image–mask filename mismatch"

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )

    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.array(img, dtype=np.float32) / 255.0
    mask = (np.array(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:", tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 32
# Masks found : 32
# Validation batches: 2

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from tensorflow.keras.optimizers import AdamW
import os

# ---------------------------------------------------------
# 1️⃣ Import custom layers and metrics (must match training)
# ---------------------------------------------------------
custom_objects = {
    "IoUMetric": IoUMetric,
    "DiceMetric": DiceMetric,
    "F1Metric": F1Metric,
    "AJIMetric": AJIMetric,
    "dice_iou_loss": dice_iou_loss # Make sure to include our custom loss here!
}

# ---------------------------------------------------------
# 2️⃣ Load model
# ---------------------------------------------------------
# Using Kaggle's working directory. Adjust if you saved it elsewhere.
model_path = "/kaggle/working/normal_unet.keras" if os.path.exists("/kaggle/working/") else "./normal_unet.keras"

model = tf.keras.models.load_model(
    model_path,
    custom_objects=custom_objects,
    compile=False, 
    safe_mode=False
)

# Optional: compile with metrics for evaluation
model.compile(
    optimizer=AdamW(1e-4),
    loss=dice_iou_loss,
    metrics=[IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()]
)

# ---------------------------------------------------------
# 3️⃣ Inference + Save Visualizations
# ---------------------------------------------------------
save_dir = "/kaggle/working/results" if os.path.exists("/kaggle/working/") else "./results"
os.makedirs(save_dir, exist_ok=True)

sample_idx = 0  # global counter for filenames

for batch_idx, (images, masks) in enumerate(test_dataset):
    # Model forward pass - standard UNet returns only y_pred
    y_pred = model(images, training=False)

    preds_bin = tf.cast(y_pred > 0.5, tf.float32)
    batch_size = images.shape[0]

    # Convert masks
    if len(masks.shape) == 4 and masks.shape[-1] > 1:
        masks_label = tf.argmax(masks, axis=-1)
    else:
        masks_label = tf.squeeze(masks, axis=-1)

    if preds_bin.shape[-1] > 1:
        preds_label = tf.argmax(preds_bin, axis=-1)
    else:
        preds_label = tf.squeeze(preds_bin, axis=-1)

    # -------------------------
    # Save all samples in batch
    # -------------------------
    for i in range(batch_size):
        sample_idx += 1  # keep global sample numbering

        # 3 subplots since we removed center/boundary maps
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        img_np = images[i].numpy()
        pred_np = preds_label[i].numpy()
        mask_np = masks_label[i].numpy()

        # 1️⃣ Original image
        axes[0].imshow(img_np)
        axes[0].set_title("Original Image")
        axes[0].axis("off")

        # 2️⃣ Predicted segmentation
        axes[1].imshow(label2rgb(pred_np, bg_label=0))
        axes[1].set_title("Predicted Segmentation")
        axes[1].axis("off")

        # 3️⃣ Ground truth
        axes[2].imshow(label2rgb(mask_np, bg_label=0))
        axes[2].set_title("Ground Truth")
        axes[2].axis("off")

        plt.tight_layout()

        save_path = os.path.join(save_dir, f"sample_{sample_idx:04d}.png")
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        plt.close(fig)

        print(f"✅ Saved {save_path}")

print(f"\n🎯 All {sample_idx} test images processed and saved to '{save_dir}'")
# Out:
# ✅ Saved /kaggle/working/results/sample_0001.png
# ✅ Saved /kaggle/working/results/sample_0002.png
# ✅ Saved /kaggle/working/results/sample_0003.png
# ✅ Saved /kaggle/working/results/sample_0004.png
# ✅ Saved /kaggle/working/results/sample_0005.png
# ✅ Saved /kaggle/working/results/sample_0006.png
# ✅ Saved /kaggle/working/results/sample_0007.png
# ✅ Saved /kaggle/working/results/sample_0008.png
# ✅ Saved /kaggle/working/results/sample_0009.png
# ✅ Saved /kaggle/working/results/sample_0010.png
# ✅ Saved /kaggle/working/results/sample_0011.png
# ✅ Saved /kaggle/working/results/sample_0012.png
# ✅ Saved /kaggle/working/results/sample_0013.png
# ✅ Saved /kaggle/working/results/sample_0014.png
# ✅ Saved /kaggle/working/results/sample_0015.png
# ✅ Saved /kaggle/working/results/sample_0016.png
# ✅ Saved /kaggle/working/results/sample_0017.png
# ✅ Saved /kaggle/working/results/sample_0018.png
# ✅ Saved /kaggle/working/results/sample_0019.png
# ✅ Saved /kaggle/working/results/sample_0020.png
# ✅ Saved /kaggle/working/results/sample_0021.png
# ✅ Saved /kaggle/working/results/sample_0022.png
# ✅ Saved /kaggle/working/results/sample_0023.png
# ✅ Saved /kaggle/working/results/sample_0024.png
# ✅ Saved /kaggle/working/results/sample_0025.png
# ✅ Saved /kaggle/working/results/sample_0026.png
# ✅ Saved /kaggle/working/results/sample_0027.png
# ✅ Saved /kaggle/working/results/sample_0028.png
# ✅ Saved /kaggle/working/results/sample_0029.png
# ✅ Saved /kaggle/working/results/sample_0030.png
# ✅ Saved /kaggle/working/results/sample_0031.png
# ✅ Saved /kaggle/working/results/sample_0032.png
#
# 🎯 All 32 test images processed and saved to '/kaggle/working/results'

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# 2026-09-18 07:03:09.320763: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 07:03:09.575114: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 07:03:16.647879: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 07:03:16.876155: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ===== Segmentation Evaluation =====
# Mean IoU:              0.7814
# Mean Dice Coefficient: 0.8761
# Mean AJI:              0.7805
# Mean Accuracy:         0.9372
# Mean F1 Score:         0.8761
