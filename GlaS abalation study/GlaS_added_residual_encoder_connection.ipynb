# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 07:35:14.103637: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 07:35:14.143429: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 07:35:14.143476: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 07:35:14.145376: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 07:35:14.155224: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 07:35:15.269304: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 07:35:19.679933: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.758832: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.758894: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):

    res = x

    # ============================================================
    # ENCODER BLOCK
    # ============================================================
    if not decoder:


        # -------------------------------
        # Branch 2: Evolutionary Conv
        # -------------------------------
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        # -------------------------------
        # Depthwise Patch Attention
        # -------------------------------

        # Residual projection
        res = layers.Conv2D(filters, 1, padding=padding)(res)

        # Final fusion
        out = layers.Add()([res, x1])

        return out

    # ============================================================
    # DECODER BLOCK
    # ============================================================
    else:

        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class RegionawareAnistropicMeanPool2D(layers.Layer):

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = RegionawareAnistropicMeanPool2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = RegionawareAnistropicMeanPool2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = RegionawareAnistropicMeanPool2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = RegionawareAnistropicMeanPool2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 07:35:19.855954: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.856032: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.856052: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.993355: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.993397: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.993404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 07:35:19.993415: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 07:35:19.993427: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 07:35:19.993446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['conv2d[0][0]',
#                                                                      'activation[0][0]']
#
#  regionaware_anistropic_mea  (None, 128, 128, 32)         32        ['add[0][0]']
#  n_pool2d (RegionawareAnist
#  ropicMeanPool2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['regionaware_anistropic_mean_
#                                                                     pool2d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         2112      ['gaussian_dropout[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['conv2d_1[0][0]',
#                                                                      'activation_1[0][0]']
#
#  regionaware_anistropic_mea  (None, 64, 64, 64)           64        ['add_1[0][0]']
#  n_pool2d_1 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['regionaware_anistropic_mean_
#                                                                     pool2d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          8320      ['gaussian_dropout_1[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_2[0][0]',
#                                                                      'activation_2[0][0]']
#
#  regionaware_anistropic_mea  (None, 32, 32, 128)          128       ['add_2[0][0]']
#  n_pool2d_2 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['regionaware_anistropic_mean_
#                                                                     pool2d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)          33024     ['dropout_2[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 32, 32, 256)          0         ['conv2d_3[0][0]',
#                                                                      'activation_3[0][0]']
#
#  regionaware_anistropic_mea  (None, 16, 16, 256)          256       ['add_3[0][0]']
#  n_pool2d_3 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['regionaware_anistropic_mean_
#                                                                     pool2d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 384)          98688     ['gaussian_dropout_2[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 16, 16, 384)          0         ['conv2d_4[0][0]',
#                                                                      'activation_4[0][0]']
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['add_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 32, 32, 256)          0         ['add_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add_5[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_6 (Add)                 (None, 64, 64, 128)          0         ['add_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_6[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['add_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_7[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['add[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 1)          33        ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 2975370 (11.35 MB)
# Trainable params: 2972682 (11.34 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../GLAS_PREPARED_DATA/val/images/*.png") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tif") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 684
# Train masks: 684
# Val images: 9
# Val masks: 9
# 2026-09-20 07:35:30.337838: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 171
# Validation batches: 3

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-20 07:35:34.749197: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 07:35:39.517833: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 07:35:39.697223: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 07:35:43.886798: I external/local_xla/xla/service/service.cc:168] XLA service 0x78e42a9f9170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 07:35:43.886934: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 07:35:43.896396: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789889743.965081   20654 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - ETA: 0s - loss: 3.4499 - accuracy: 0.6139 - iou_coef: 0.4550 - dice_coef: 0.6095 - f1_score: 0.6133 - aggregated_jaccard_index: 0.4835
# ✅ Saved improved backbone at epoch 1 with val_iou=0.5730
# 171/171 [==============================] - 40s 130ms/step - loss: 3.4430 - accuracy: 0.6139 - iou_coef: 0.4550 - dice_coef: 0.6095 - f1_score: 0.6133 - aggregated_jaccard_index: 0.4835 - val_val_loss: 2.7575 - val_val_accuracy: 0.5799 - val_val_iou_coef: 0.5730 - val_val_dice_coef: 0.7235 - val_val_f1_score: 0.7244 - val_val_aggregated_jaccard_index: 0.5897 - lr: 0.0010
# Epoch 2/150
# 171/171 [==============================] - ETA: 0s - loss: 2.7361 - accuracy: 0.6706 - iou_coef: 0.5451 - dice_coef: 0.6924 - f1_score: 0.6993 - aggregated_jaccard_index: 0.5744
# ✅ Saved improved backbone at epoch 2 with val_iou=0.5742
# 171/171 [==============================] - 21s 122ms/step - loss: 2.7338 - accuracy: 0.6706 - iou_coef: 0.5451 - dice_coef: 0.6924 - f1_score: 0.6993 - aggregated_jaccard_index: 0.5744 - val_val_loss: 2.6475 - val_val_accuracy: 0.5799 - val_val_iou_coef: 0.5742 - val_val_dice_coef: 0.7244 - val_val_f1_score: 0.7244 - val_val_aggregated_jaccard_index: 0.5910 - lr: 0.0010
# Epoch 3/150
# 171/171 [==============================] - ETA: 0s - loss: 2.4432 - accuracy: 0.7095 - iou_coef: 0.5778 - dice_coef: 0.7195 - f1_score: 0.7240 - aggregated_jaccard_index: 0.6028
# ✅ Saved improved backbone at epoch 3 with val_iou=0.6455
# 171/171 [==============================] - 18s 107ms/step - loss: 2.4424 - accuracy: 0.7095 - iou_coef: 0.5778 - dice_coef: 0.7195 - f1_score: 0.7240 - aggregated_jaccard_index: 0.6028 - val_val_loss: 1.6558 - val_val_accuracy: 0.6883 - val_val_iou_coef: 0.6455 - val_val_dice_coef: 0.7798 - val_val_f1_score: 0.7807 - val_val_aggregated_jaccard_index: 0.6544 - lr: 0.0010
# Epoch 4/150
# 171/171 [==============================] - ETA: 0s - loss: 2.1904 - accuracy: 0.7393 - iou_coef: 0.6037 - dice_coef: 0.7413 - f1_score: 0.7447 - aggregated_jaccard_index: 0.6268
# ✅ Saved improved backbone at epoch 4 with val_iou=0.7086
# 171/171 [==============================] - 21s 125ms/step - loss: 2.1911 - accuracy: 0.7393 - iou_coef: 0.6037 - dice_coef: 0.7413 - f1_score: 0.7447 - aggregated_jaccard_index: 0.6268 - val_val_loss: 1.0828 - val_val_accuracy: 0.7415 - val_val_iou_coef: 0.7086 - val_val_dice_coef: 0.8238 - val_val_f1_score: 0.8256 - val_val_aggregated_jaccard_index: 0.7158 - lr: 0.0010
# Epoch 5/150
# 171/171 [==============================] - 18s 107ms/step - loss: 1.9725 - accuracy: 0.7625 - iou_coef: 0.6264 - dice_coef: 0.7599 - f1_score: 0.7625 - aggregated_jaccard_index: 0.6469 - val_val_loss: 2.3040 - val_val_accuracy: 0.6074 - val_val_iou_coef: 0.5872 - val_val_dice_coef: 0.7339 - val_val_f1_score: 0.7337 - val_val_aggregated_jaccard_index: 0.6046 - lr: 0.0010
# Epoch 6/150
# 171/171 [==============================] - ETA: 0s - loss: 1.7378 - accuracy: 0.7876 - iou_coef: 0.6557 - dice_coef: 0.7829 - f1_score: 0.7849 - aggregated_jaccard_index: 0.6738
# ✅ Saved improved backbone at epoch 6 with val_iou=0.7523
# 171/171 [==============================] - 20s 120ms/step - loss: 1.7371 - accuracy: 0.7876 - iou_coef: 0.6557 - dice_coef: 0.7829 - f1_score: 0.7849 - aggregated_jaccard_index: 0.6738 - val_val_loss: 0.7722 - val_val_accuracy: 0.8026 - val_val_iou_coef: 0.7523 - val_val_dice_coef: 0.8537 - val_val_f1_score: 0.8549 - val_val_aggregated_jaccard_index: 0.7525 - lr: 0.0010
# Epoch 7/150
# 171/171 [==============================] - 20s 120ms/step - loss: 1.6085 - accuracy: 0.7986 - iou_coef: 0.6655 - dice_coef: 0.7900 - f1_score: 0.7916 - aggregated_jaccard_index: 0.6845 - val_val_loss: 0.8683 - val_val_accuracy: 0.7500 - val_val_iou_coef: 0.7214 - val_val_dice_coef: 0.8314 - val_val_f1_score: 0.8328 - val_val_aggregated_jaccard_index: 0.7306 - lr: 0.0010
# Epoch 8/150
# 171/171 [==============================] - 18s 108ms/step - loss: 1.5044 - accuracy: 0.8064 - iou_coef: 0.6739 - dice_coef: 0.7958 - f1_score: 0.7972 - aggregated_jaccard_index: 0.6919 - val_val_loss: 1.4985 - val_val_accuracy: 0.7012 - val_val_iou_coef: 0.6666 - val_val_dice_coef: 0.7931 - val_val_f1_score: 0.7933 - val_val_aggregated_jaccard_index: 0.6836 - lr: 0.0010
# Epoch 9/150
# 171/171 [==============================] - 21s 121ms/step - loss: 1.3799 - accuracy: 0.8171 - iou_coef: 0.6871 - dice_coef: 0.8066 - f1_score: 0.8079 - aggregated_jaccard_index: 0.7009 - val_val_loss: 1.9818 - val_val_accuracy: 0.5876 - val_val_iou_coef: 0.5781 - val_val_dice_coef: 0.7273 - val_val_f1_score: 0.7272 - val_val_aggregated_jaccard_index: 0.5952 - lr: 0.0010
# Epoch 10/150
# 171/171 [==============================] - 18s 108ms/step - loss: 1.3152 - accuracy: 0.8175 - iou_coef: 0.6884 - dice_coef: 0.8074 - f1_score: 0.8085 - aggregated_jaccard_index: 0.7042 - val_val_loss: 1.8970 - val_val_accuracy: 0.7395 - val_val_iou_coef: 0.5660 - val_val_dice_coef: 0.7083 - val_val_f1_score: 0.7083 - val_val_aggregated_jaccard_index: 0.5623 - lr: 0.0010
# Epoch 11/150
# 171/171 [==============================] - ETA: 0s - loss: 1.1865 - accuracy: 0.8301 - iou_coef: 0.7064 - dice_coef: 0.8204 - f1_score: 0.8215 - aggregated_jaccard_index: 0.7190
# ✅ Saved improved backbone at epoch 11 with val_iou=0.7690
# 171/171 [==============================] - 20s 120ms/step - loss: 1.1847 - accuracy: 0.8301 - iou_coef: 0.7064 - dice_coef: 0.8204 - f1_score: 0.8215 - aggregated_jaccard_index: 0.7190 - val_val_loss: 0.6336 - val_val_accuracy: 0.8409 - val_val_iou_coef: 0.7690 - val_val_dice_coef: 0.8621 - val_val_f1_score: 0.8628 - val_val_aggregated_jaccard_index: 0.7668 - lr: 0.0010
# Epoch 12/150
# 171/171 [==============================] - 19s 109ms/step - loss: 1.0932 - accuracy: 0.8369 - iou_coef: 0.7134 - dice_coef: 0.8252 - f1_score: 0.8263 - aggregated_jaccard_index: 0.7273 - val_val_loss: 1.2681 - val_val_accuracy: 0.7500 - val_val_iou_coef: 0.6018 - val_val_dice_coef: 0.7328 - val_val_f1_score: 0.7334 - val_val_aggregated_jaccard_index: 0.5999 - lr: 0.0010
# Epoch 13/150
# 171/171 [==============================] - 21s 120ms/step - loss: 1.0443 - accuracy: 0.8371 - iou_coef: 0.7158 - dice_coef: 0.8261 - f1_score: 0.8270 - aggregated_jaccard_index: 0.7290 - val_val_loss: 4.2284 - val_val_accuracy: 0.4672 - val_val_iou_coef: 0.0609 - val_val_dice_coef: 0.1056 - val_val_f1_score: 0.1044 - val_val_aggregated_jaccard_index: 0.0651 - lr: 0.0010
# Epoch 14/150
# 171/171 [==============================] - 20s 120ms/step - loss: 0.9537 - accuracy: 0.8439 - iou_coef: 0.7251 - dice_coef: 0.8335 - f1_score: 0.8344 - aggregated_jaccard_index: 0.7366 - val_val_loss: 1.0662 - val_val_accuracy: 0.6844 - val_val_iou_coef: 0.6618 - val_val_dice_coef: 0.7898 - val_val_f1_score: 0.7897 - val_val_aggregated_jaccard_index: 0.6796 - lr: 0.0010
# Epoch 15/150
# 171/171 [==============================] - ETA: 0s - loss: 0.8919 - accuracy: 0.8456 - iou_coef: 0.7287 - dice_coef: 0.8359 - f1_score: 0.8368 - aggregated_jaccard_index: 0.7404
# ✅ Saved improved backbone at epoch 15 with val_iou=0.7763
# 171/171 [==============================] - 19s 109ms/step - loss: 0.8934 - accuracy: 0.8456 - iou_coef: 0.7287 - dice_coef: 0.8359 - f1_score: 0.8368 - aggregated_jaccard_index: 0.7404 - val_val_loss: 0.4557 - val_val_accuracy: 0.8421 - val_val_iou_coef: 0.7763 - val_val_dice_coef: 0.8649 - val_val_f1_score: 0.8653 - val_val_aggregated_jaccard_index: 0.7744 - lr: 0.0010
# Epoch 16/150
# 171/171 [==============================] - ETA: 0s - loss: 0.8319 - accuracy: 0.8490 - iou_coef: 0.7309 - dice_coef: 0.8362 - f1_score: 0.8371 - aggregated_jaccard_index: 0.7449
# ✅ Saved improved backbone at epoch 16 with val_iou=0.8169
# 171/171 [==============================] - 21s 123ms/step - loss: 0.8303 - accuracy: 0.8490 - iou_coef: 0.7309 - dice_coef: 0.8362 - f1_score: 0.8371 - aggregated_jaccard_index: 0.7449 - val_val_loss: 0.3657 - val_val_accuracy: 0.8598 - val_val_iou_coef: 0.8169 - val_val_dice_coef: 0.8950 - val_val_f1_score: 0.8956 - val_val_aggregated_jaccard_index: 0.8160 - lr: 0.0010
# Epoch 17/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.7458 - accuracy: 0.8574 - iou_coef: 0.7437 - dice_coef: 0.8459 - f1_score: 0.8467 - aggregated_jaccard_index: 0.7573 - val_val_loss: 0.4114 - val_val_accuracy: 0.8148 - val_val_iou_coef: 0.7401 - val_val_dice_coef: 0.8403 - val_val_f1_score: 0.8412 - val_val_aggregated_jaccard_index: 0.7411 - lr: 0.0010
# Epoch 18/150
# 171/171 [==============================] - 20s 120ms/step - loss: 0.7074 - accuracy: 0.8563 - iou_coef: 0.7450 - dice_coef: 0.8464 - f1_score: 0.8473 - aggregated_jaccard_index: 0.7566 - val_val_loss: 0.5116 - val_val_accuracy: 0.8120 - val_val_iou_coef: 0.7691 - val_val_dice_coef: 0.8661 - val_val_f1_score: 0.8669 - val_val_aggregated_jaccard_index: 0.7712 - lr: 0.0010
# Epoch 19/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.6365 - accuracy: 0.8639 - iou_coef: 0.7540 - dice_coef: 0.8530 - f1_score: 0.8538 - aggregated_jaccard_index: 0.7670 - val_val_loss: 0.3218 - val_val_accuracy: 0.8372 - val_val_iou_coef: 0.8035 - val_val_dice_coef: 0.8875 - val_val_f1_score: 0.8878 - val_val_aggregated_jaccard_index: 0.8096 - lr: 0.0010
# Epoch 20/150
# 171/171 [==============================] - ETA: 0s - loss: 0.6020 - accuracy: 0.8632 - iou_coef: 0.7544 - dice_coef: 0.8523 - f1_score: 0.8530 - aggregated_jaccard_index: 0.7669
# ✅ Saved improved backbone at epoch 20 with val_iou=0.8340
# 171/171 [==============================] - 21s 121ms/step - loss: 0.6023 - accuracy: 0.8632 - iou_coef: 0.7544 - dice_coef: 0.8523 - f1_score: 0.8530 - aggregated_jaccard_index: 0.7669 - val_val_loss: 0.3130 - val_val_accuracy: 0.8778 - val_val_iou_coef: 0.8340 - val_val_dice_coef: 0.9069 - val_val_f1_score: 0.9073 - val_val_aggregated_jaccard_index: 0.8327 - lr: 0.0010
# Epoch 21/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.5542 - accuracy: 0.8659 - iou_coef: 0.7556 - dice_coef: 0.8537 - f1_score: 0.8544 - aggregated_jaccard_index: 0.7690 - val_val_loss: 0.2648 - val_val_accuracy: 0.8673 - val_val_iou_coef: 0.8112 - val_val_dice_coef: 0.8874 - val_val_f1_score: 0.8883 - val_val_aggregated_jaccard_index: 0.8089 - lr: 0.0010
# Epoch 22/150
# 171/171 [==============================] - 19s 110ms/step - loss: 0.5042 - accuracy: 0.8696 - iou_coef: 0.7624 - dice_coef: 0.8582 - f1_score: 0.8589 - aggregated_jaccard_index: 0.7759 - val_val_loss: 0.2643 - val_val_accuracy: 0.8274 - val_val_iou_coef: 0.8006 - val_val_dice_coef: 0.8848 - val_val_f1_score: 0.8852 - val_val_aggregated_jaccard_index: 0.8035 - lr: 0.0010
# Epoch 23/150
# 171/171 [==============================] - 20s 120ms/step - loss: 0.4604 - accuracy: 0.8736 - iou_coef: 0.7700 - dice_coef: 0.8633 - f1_score: 0.8640 - aggregated_jaccard_index: 0.7824 - val_val_loss: 0.2277 - val_val_accuracy: 0.8745 - val_val_iou_coef: 0.8175 - val_val_dice_coef: 0.8906 - val_val_f1_score: 0.8911 - val_val_aggregated_jaccard_index: 0.8151 - lr: 0.0010
# Epoch 24/150
# 171/171 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8759 - iou_coef: 0.7724 - dice_coef: 0.8648 - f1_score: 0.8655 - aggregated_jaccard_index: 0.7851
# ✅ Saved improved backbone at epoch 24 with val_iou=0.8405
# 171/171 [==============================] - 18s 108ms/step - loss: 0.4260 - accuracy: 0.8759 - iou_coef: 0.7724 - dice_coef: 0.8648 - f1_score: 0.8655 - aggregated_jaccard_index: 0.7851 - val_val_loss: 0.1987 - val_val_accuracy: 0.8900 - val_val_iou_coef: 0.8405 - val_val_dice_coef: 0.9110 - val_val_f1_score: 0.9114 - val_val_aggregated_jaccard_index: 0.8390 - lr: 0.0010
# Epoch 25/150
# 171/171 [==============================] - 20s 120ms/step - loss: 0.3976 - accuracy: 0.8755 - iou_coef: 0.7712 - dice_coef: 0.8638 - f1_score: 0.8644 - aggregated_jaccard_index: 0.7835 - val_val_loss: 0.3710 - val_val_accuracy: 0.8066 - val_val_iou_coef: 0.7047 - val_val_dice_coef: 0.8094 - val_val_f1_score: 0.8100 - val_val_aggregated_jaccard_index: 0.7022 - lr: 0.0010
# Epoch 26/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3544 - accuracy: 0.8816 - iou_coef: 0.7796 - dice_coef: 0.8693 - f1_score: 0.8699 - aggregated_jaccard_index: 0.7923
# ✅ Saved improved backbone at epoch 26 with val_iou=0.8770
# 171/171 [==============================] - 19s 109ms/step - loss: 0.3540 - accuracy: 0.8816 - iou_coef: 0.7796 - dice_coef: 0.8693 - f1_score: 0.8699 - aggregated_jaccard_index: 0.7923 - val_val_loss: 0.1706 - val_val_accuracy: 0.9185 - val_val_iou_coef: 0.8770 - val_val_dice_coef: 0.9338 - val_val_f1_score: 0.9345 - val_val_aggregated_jaccard_index: 0.8758 - lr: 0.0010
# Epoch 27/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.3239 - accuracy: 0.8836 - iou_coef: 0.7842 - dice_coef: 0.8729 - f1_score: 0.8735 - aggregated_jaccard_index: 0.7967 - val_val_loss: 0.1455 - val_val_accuracy: 0.8971 - val_val_iou_coef: 0.8605 - val_val_dice_coef: 0.9234 - val_val_f1_score: 0.9240 - val_val_aggregated_jaccard_index: 0.8597 - lr: 0.0010
# Epoch 28/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.2978 - accuracy: 0.8849 - iou_coef: 0.7851 - dice_coef: 0.8732 - f1_score: 0.8737 - aggregated_jaccard_index: 0.7983 - val_val_loss: 0.1378 - val_val_accuracy: 0.8878 - val_val_iou_coef: 0.8426 - val_val_dice_coef: 0.9104 - val_val_f1_score: 0.9108 - val_val_aggregated_jaccard_index: 0.8426 - lr: 0.0010
# Epoch 29/150
# 171/171 [==============================] - 19s 110ms/step - loss: 0.2703 - accuracy: 0.8880 - iou_coef: 0.7921 - dice_coef: 0.8785 - f1_score: 0.8790 - aggregated_jaccard_index: 0.8035 - val_val_loss: 0.1307 - val_val_accuracy: 0.9040 - val_val_iou_coef: 0.8602 - val_val_dice_coef: 0.9226 - val_val_f1_score: 0.9229 - val_val_aggregated_jaccard_index: 0.8590 - lr: 0.0010
# Epoch 30/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.2580 - accuracy: 0.8852 - iou_coef: 0.7862 - dice_coef: 0.8742 - f1_score: 0.8748 - aggregated_jaccard_index: 0.7975 - val_val_loss: 0.1116 - val_val_accuracy: 0.8638 - val_val_iou_coef: 0.8104 - val_val_dice_coef: 0.8846 - val_val_f1_score: 0.8845 - val_val_aggregated_jaccard_index: 0.8077 - lr: 0.0010
# Epoch 31/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.2265 - accuracy: 0.8916 - iou_coef: 0.7957 - dice_coef: 0.8809 - f1_score: 0.8815 - aggregated_jaccard_index: 0.8075 - val_val_loss: 0.1379 - val_val_accuracy: 0.8939 - val_val_iou_coef: 0.8384 - val_val_dice_coef: 0.9101 - val_val_f1_score: 0.9106 - val_val_aggregated_jaccard_index: 0.8366 - lr: 0.0010
# Epoch 32/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.2078 - accuracy: 0.8929 - iou_coef: 0.7972 - dice_coef: 0.8816 - f1_score: 0.8821 - aggregated_jaccard_index: 0.8094 - val_val_loss: 0.1019 - val_val_accuracy: 0.8765 - val_val_iou_coef: 0.8454 - val_val_dice_coef: 0.9141 - val_val_f1_score: 0.9146 - val_val_aggregated_jaccard_index: 0.8469 - lr: 0.0010
# Epoch 33/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.1908 - accuracy: 0.8937 - iou_coef: 0.7990 - dice_coef: 0.8829 - f1_score: 0.8834 - aggregated_jaccard_index: 0.8114 - val_val_loss: 0.0939 - val_val_accuracy: 0.9036 - val_val_iou_coef: 0.8685 - val_val_dice_coef: 0.9283 - val_val_f1_score: 0.9289 - val_val_aggregated_jaccard_index: 0.8691 - lr: 0.0010
# Epoch 34/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1726 - accuracy: 0.8961 - iou_coef: 0.8035 - dice_coef: 0.8857 - f1_score: 0.8862 - aggregated_jaccard_index: 0.8150 - val_val_loss: 0.0876 - val_val_accuracy: 0.8728 - val_val_iou_coef: 0.8257 - val_val_dice_coef: 0.8993 - val_val_f1_score: 0.8998 - val_val_aggregated_jaccard_index: 0.8253 - lr: 0.0010
# Epoch 35/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.1633 - accuracy: 0.8941 - iou_coef: 0.8005 - dice_coef: 0.8836 - f1_score: 0.8841 - aggregated_jaccard_index: 0.8113 - val_val_loss: 0.1031 - val_val_accuracy: 0.8360 - val_val_iou_coef: 0.8019 - val_val_dice_coef: 0.8864 - val_val_f1_score: 0.8868 - val_val_aggregated_jaccard_index: 0.8116 - lr: 0.0010
# Epoch 36/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1465 - accuracy: 0.8969 - iou_coef: 0.8046 - dice_coef: 0.8864 - f1_score: 0.8869 - aggregated_jaccard_index: 0.8166
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 171/171 [==============================] - 18s 107ms/step - loss: 0.1468 - accuracy: 0.8969 - iou_coef: 0.8046 - dice_coef: 0.8864 - f1_score: 0.8869 - aggregated_jaccard_index: 0.8166 - val_val_loss: 0.2739 - val_val_accuracy: 0.6951 - val_val_iou_coef: 0.6504 - val_val_dice_coef: 0.7815 - val_val_f1_score: 0.7814 - val_val_aggregated_jaccard_index: 0.6651 - lr: 0.0010
# Epoch 37/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9044 - iou_coef: 0.8182 - dice_coef: 0.8954 - f1_score: 0.8958 - aggregated_jaccard_index: 0.8288
# ✅ Saved improved backbone at epoch 37 with val_iou=0.8782
# 171/171 [==============================] - 21s 123ms/step - loss: 0.1304 - accuracy: 0.9044 - iou_coef: 0.8182 - dice_coef: 0.8954 - f1_score: 0.8958 - aggregated_jaccard_index: 0.8288 - val_val_loss: 0.0637 - val_val_accuracy: 0.9174 - val_val_iou_coef: 0.8782 - val_val_dice_coef: 0.9328 - val_val_f1_score: 0.9331 - val_val_aggregated_jaccard_index: 0.8780 - lr: 1.0000e-04
# Epoch 38/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.1272 - accuracy: 0.9072 - iou_coef: 0.8216 - dice_coef: 0.8972 - f1_score: 0.8977 - aggregated_jaccard_index: 0.8324 - val_val_loss: 0.0630 - val_val_accuracy: 0.9172 - val_val_iou_coef: 0.8768 - val_val_dice_coef: 0.9319 - val_val_f1_score: 0.9322 - val_val_aggregated_jaccard_index: 0.8766 - lr: 1.0000e-04
# Epoch 39/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1263 - accuracy: 0.9067 - iou_coef: 0.8216 - dice_coef: 0.8972 - f1_score: 0.8977 - aggregated_jaccard_index: 0.8315
# ✅ Saved improved backbone at epoch 39 with val_iou=0.8817
# 171/171 [==============================] - 21s 123ms/step - loss: 0.1265 - accuracy: 0.9067 - iou_coef: 0.8216 - dice_coef: 0.8972 - f1_score: 0.8977 - aggregated_jaccard_index: 0.8315 - val_val_loss: 0.0615 - val_val_accuracy: 0.9198 - val_val_iou_coef: 0.8817 - val_val_dice_coef: 0.9349 - val_val_f1_score: 0.9352 - val_val_aggregated_jaccard_index: 0.8815 - lr: 1.0000e-04
# Epoch 40/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9095 - iou_coef: 0.8263 - dice_coef: 0.9005 - f1_score: 0.9009 - aggregated_jaccard_index: 0.8365
# ✅ Saved improved backbone at epoch 40 with val_iou=0.8860
# 171/171 [==============================] - 19s 109ms/step - loss: 0.1216 - accuracy: 0.9095 - iou_coef: 0.8263 - dice_coef: 0.9005 - f1_score: 0.9009 - aggregated_jaccard_index: 0.8365 - val_val_loss: 0.0624 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.8860 - val_val_dice_coef: 0.9382 - val_val_f1_score: 0.9385 - val_val_aggregated_jaccard_index: 0.8870 - lr: 1.0000e-04
# Epoch 41/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1209 - accuracy: 0.9089 - iou_coef: 0.8239 - dice_coef: 0.8989 - f1_score: 0.8993 - aggregated_jaccard_index: 0.8355 - val_val_loss: 0.0605 - val_val_accuracy: 0.9122 - val_val_iou_coef: 0.8716 - val_val_dice_coef: 0.9281 - val_val_f1_score: 0.9284 - val_val_aggregated_jaccard_index: 0.8710 - lr: 1.0000e-04
# Epoch 42/150
# 171/171 [==============================] - 21s 122ms/step - loss: 0.1196 - accuracy: 0.9098 - iou_coef: 0.8245 - dice_coef: 0.8992 - f1_score: 0.8997 - aggregated_jaccard_index: 0.8359 - val_val_loss: 0.0587 - val_val_accuracy: 0.9163 - val_val_iou_coef: 0.8778 - val_val_dice_coef: 0.9324 - val_val_f1_score: 0.9327 - val_val_aggregated_jaccard_index: 0.8775 - lr: 1.0000e-04
# Epoch 43/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.1169 - accuracy: 0.9109 - iou_coef: 0.8279 - dice_coef: 0.9015 - f1_score: 0.9020 - aggregated_jaccard_index: 0.8385 - val_val_loss: 0.0598 - val_val_accuracy: 0.9218 - val_val_iou_coef: 0.8833 - val_val_dice_coef: 0.9363 - val_val_f1_score: 0.9366 - val_val_aggregated_jaccard_index: 0.8842 - lr: 1.0000e-04
# Epoch 44/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1182 - accuracy: 0.9095 - iou_coef: 0.8253 - dice_coef: 0.8997 - f1_score: 0.9001 - aggregated_jaccard_index: 0.8363 - val_val_loss: 0.0592 - val_val_accuracy: 0.9197 - val_val_iou_coef: 0.8804 - val_val_dice_coef: 0.9346 - val_val_f1_score: 0.9344 - val_val_aggregated_jaccard_index: 0.8806 - lr: 1.0000e-04
# Epoch 45/150
# 171/171 [==============================] - 18s 105ms/step - loss: 0.1144 - accuracy: 0.9117 - iou_coef: 0.8282 - dice_coef: 0.9016 - f1_score: 0.9021 - aggregated_jaccard_index: 0.8391 - val_val_loss: 0.0567 - val_val_accuracy: 0.9156 - val_val_iou_coef: 0.8768 - val_val_dice_coef: 0.9316 - val_val_f1_score: 0.9319 - val_val_aggregated_jaccard_index: 0.8765 - lr: 1.0000e-04
# Epoch 46/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1132 - accuracy: 0.9117 - iou_coef: 0.8294 - dice_coef: 0.9023 - f1_score: 0.9027 - aggregated_jaccard_index: 0.8395 - val_val_loss: 0.0560 - val_val_accuracy: 0.9136 - val_val_iou_coef: 0.8748 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9304 - val_val_aggregated_jaccard_index: 0.8745 - lr: 1.0000e-04
# Epoch 47/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.1102 - accuracy: 0.9125 - iou_coef: 0.8303 - dice_coef: 0.9031 - f1_score: 0.9036 - aggregated_jaccard_index: 0.8409 - val_val_loss: 0.0571 - val_val_accuracy: 0.9148 - val_val_iou_coef: 0.8745 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8746 - lr: 1.0000e-04
# Epoch 48/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1100 - accuracy: 0.9121 - iou_coef: 0.8286 - dice_coef: 0.9019 - f1_score: 0.9024 - aggregated_jaccard_index: 0.8396 - val_val_loss: 0.0559 - val_val_accuracy: 0.9205 - val_val_iou_coef: 0.8818 - val_val_dice_coef: 0.9350 - val_val_f1_score: 0.9352 - val_val_aggregated_jaccard_index: 0.8828 - lr: 1.0000e-04
# Epoch 49/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1094 - accuracy: 0.9114 - iou_coef: 0.8287 - dice_coef: 0.9019 - f1_score: 0.9024 - aggregated_jaccard_index: 0.8390 - val_val_loss: 0.0545 - val_val_accuracy: 0.9161 - val_val_iou_coef: 0.8776 - val_val_dice_coef: 0.9323 - val_val_f1_score: 0.9325 - val_val_aggregated_jaccard_index: 0.8770 - lr: 1.0000e-04
# Epoch 50/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1076 - accuracy: 0.9124 - iou_coef: 0.8301 - dice_coef: 0.9030 - f1_score: 0.9035 - aggregated_jaccard_index: 0.8401
# ✅ Saved improved backbone at epoch 50 with val_iou=0.8906
# 171/171 [==============================] - 18s 106ms/step - loss: 0.1075 - accuracy: 0.9124 - iou_coef: 0.8301 - dice_coef: 0.9030 - f1_score: 0.9035 - aggregated_jaccard_index: 0.8401 - val_val_loss: 0.0570 - val_val_accuracy: 0.9286 - val_val_iou_coef: 0.8906 - val_val_dice_coef: 0.9412 - val_val_f1_score: 0.9414 - val_val_aggregated_jaccard_index: 0.8918 - lr: 1.0000e-04
# Epoch 51/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.1068 - accuracy: 0.9123 - iou_coef: 0.8304 - dice_coef: 0.9030 - f1_score: 0.9035 - aggregated_jaccard_index: 0.8396 - val_val_loss: 0.0532 - val_val_accuracy: 0.9154 - val_val_iou_coef: 0.8758 - val_val_dice_coef: 0.9307 - val_val_f1_score: 0.9309 - val_val_aggregated_jaccard_index: 0.8759 - lr: 1.0000e-04
# Epoch 52/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.9105 - iou_coef: 0.8274 - dice_coef: 0.9005 - f1_score: 0.9010 - aggregated_jaccard_index: 0.8380
# ✅ Saved improved backbone at epoch 52 with val_iou=0.8913
# 171/171 [==============================] - 18s 107ms/step - loss: 0.1074 - accuracy: 0.9105 - iou_coef: 0.8274 - dice_coef: 0.9005 - f1_score: 0.9010 - aggregated_jaccard_index: 0.8380 - val_val_loss: 0.0554 - val_val_accuracy: 0.9284 - val_val_iou_coef: 0.8913 - val_val_dice_coef: 0.9417 - val_val_f1_score: 0.9419 - val_val_aggregated_jaccard_index: 0.8919 - lr: 1.0000e-04
# Epoch 53/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.1023 - accuracy: 0.9139 - iou_coef: 0.8322 - dice_coef: 0.9043 - f1_score: 0.9048 - aggregated_jaccard_index: 0.8425 - val_val_loss: 0.0523 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8878 - val_val_dice_coef: 0.9395 - val_val_f1_score: 0.9398 - val_val_aggregated_jaccard_index: 0.8884 - lr: 1.0000e-04
# Epoch 54/150
# 171/171 [==============================] - 18s 106ms/step - loss: 0.1024 - accuracy: 0.9133 - iou_coef: 0.8324 - dice_coef: 0.9044 - f1_score: 0.9049 - aggregated_jaccard_index: 0.8411 - val_val_loss: 0.0531 - val_val_accuracy: 0.9224 - val_val_iou_coef: 0.8851 - val_val_dice_coef: 0.9374 - val_val_f1_score: 0.9375 - val_val_aggregated_jaccard_index: 0.8856 - lr: 1.0000e-04
# Epoch 55/150
# 171/171 [==============================] - 20s 120ms/step - loss: 0.0993 - accuracy: 0.9142 - iou_coef: 0.8328 - dice_coef: 0.9046 - f1_score: 0.9051 - aggregated_jaccard_index: 0.8431 - val_val_loss: 0.0519 - val_val_accuracy: 0.9170 - val_val_iou_coef: 0.8779 - val_val_dice_coef: 0.9323 - val_val_f1_score: 0.9326 - val_val_aggregated_jaccard_index: 0.8783 - lr: 1.0000e-04
# Epoch 56/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.0984 - accuracy: 0.9139 - iou_coef: 0.8334 - dice_coef: 0.9050 - f1_score: 0.9054 - aggregated_jaccard_index: 0.8427 - val_val_loss: 0.0536 - val_val_accuracy: 0.9243 - val_val_iou_coef: 0.8852 - val_val_dice_coef: 0.9377 - val_val_f1_score: 0.9379 - val_val_aggregated_jaccard_index: 0.8865 - lr: 1.0000e-04
# Epoch 57/150
# 171/171 [==============================] - 18s 105ms/step - loss: 0.0962 - accuracy: 0.9151 - iou_coef: 0.8348 - dice_coef: 0.9058 - f1_score: 0.9063 - aggregated_jaccard_index: 0.8451 - val_val_loss: 0.0484 - val_val_accuracy: 0.9153 - val_val_iou_coef: 0.8778 - val_val_dice_coef: 0.9321 - val_val_f1_score: 0.9322 - val_val_aggregated_jaccard_index: 0.8774 - lr: 1.0000e-04
# Epoch 58/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.0941 - accuracy: 0.9158 - iou_coef: 0.8362 - dice_coef: 0.9068 - f1_score: 0.9073 - aggregated_jaccard_index: 0.8460 - val_val_loss: 0.0495 - val_val_accuracy: 0.9160 - val_val_iou_coef: 0.8779 - val_val_dice_coef: 0.9324 - val_val_f1_score: 0.9326 - val_val_aggregated_jaccard_index: 0.8775 - lr: 1.0000e-04
# Epoch 59/150
# 171/171 [==============================] - 18s 105ms/step - loss: 0.0938 - accuracy: 0.9153 - iou_coef: 0.8347 - dice_coef: 0.9058 - f1_score: 0.9062 - aggregated_jaccard_index: 0.8455 - val_val_loss: 0.0489 - val_val_accuracy: 0.9090 - val_val_iou_coef: 0.8690 - val_val_dice_coef: 0.9260 - val_val_f1_score: 0.9262 - val_val_aggregated_jaccard_index: 0.8683 - lr: 1.0000e-04
# Epoch 60/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9147 - iou_coef: 0.8333 - dice_coef: 0.9050 - f1_score: 0.9054 - aggregated_jaccard_index: 0.8439
# ✅ Saved improved backbone at epoch 60 with val_iou=0.8925
# 171/171 [==============================] - 21s 124ms/step - loss: 0.0935 - accuracy: 0.9147 - iou_coef: 0.8333 - dice_coef: 0.9050 - f1_score: 0.9054 - aggregated_jaccard_index: 0.8439 - val_val_loss: 0.0495 - val_val_accuracy: 0.9290 - val_val_iou_coef: 0.8925 - val_val_dice_coef: 0.9424 - val_val_f1_score: 0.9427 - val_val_aggregated_jaccard_index: 0.8935 - lr: 1.0000e-04
# Epoch 61/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.0931 - accuracy: 0.9142 - iou_coef: 0.8321 - dice_coef: 0.9041 - f1_score: 0.9046 - aggregated_jaccard_index: 0.8424 - val_val_loss: 0.0465 - val_val_accuracy: 0.9159 - val_val_iou_coef: 0.8776 - val_val_dice_coef: 0.9316 - val_val_f1_score: 0.9318 - val_val_aggregated_jaccard_index: 0.8770 - lr: 1.0000e-04
# Epoch 62/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0921 - accuracy: 0.9142 - iou_coef: 0.8344 - dice_coef: 0.9058 - f1_score: 0.9062 - aggregated_jaccard_index: 0.8430 - val_val_loss: 0.0481 - val_val_accuracy: 0.9203 - val_val_iou_coef: 0.8826 - val_val_dice_coef: 0.9354 - val_val_f1_score: 0.9356 - val_val_aggregated_jaccard_index: 0.8838 - lr: 1.0000e-04
# Epoch 63/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.0896 - accuracy: 0.9153 - iou_coef: 0.8341 - dice_coef: 0.9054 - f1_score: 0.9058 - aggregated_jaccard_index: 0.8445 - val_val_loss: 0.0482 - val_val_accuracy: 0.9113 - val_val_iou_coef: 0.8740 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8752 - lr: 1.0000e-04
# Epoch 64/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.0880 - accuracy: 0.9155 - iou_coef: 0.8360 - dice_coef: 0.9064 - f1_score: 0.9069 - aggregated_jaccard_index: 0.8449 - val_val_loss: 0.0453 - val_val_accuracy: 0.9135 - val_val_iou_coef: 0.8748 - val_val_dice_coef: 0.9302 - val_val_f1_score: 0.9305 - val_val_aggregated_jaccard_index: 0.8743 - lr: 1.0000e-04
# Epoch 65/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.0873 - accuracy: 0.9156 - iou_coef: 0.8358 - dice_coef: 0.9067 - f1_score: 0.9071 - aggregated_jaccard_index: 0.8447 - val_val_loss: 0.0449 - val_val_accuracy: 0.9234 - val_val_iou_coef: 0.8856 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9382 - val_val_aggregated_jaccard_index: 0.8856 - lr: 1.0000e-04
# Epoch 66/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0848 - accuracy: 0.9166 - iou_coef: 0.8374 - dice_coef: 0.9074 - f1_score: 0.9079 - aggregated_jaccard_index: 0.8476 - val_val_loss: 0.0451 - val_val_accuracy: 0.9162 - val_val_iou_coef: 0.8760 - val_val_dice_coef: 0.9321 - val_val_f1_score: 0.9323 - val_val_aggregated_jaccard_index: 0.8758 - lr: 1.0000e-04
# Epoch 67/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.0841 - accuracy: 0.9167 - iou_coef: 0.8369 - dice_coef: 0.9072 - f1_score: 0.9076 - aggregated_jaccard_index: 0.8468 - val_val_loss: 0.0447 - val_val_accuracy: 0.9271 - val_val_iou_coef: 0.8886 - val_val_dice_coef: 0.9397 - val_val_f1_score: 0.9403 - val_val_aggregated_jaccard_index: 0.8890 - lr: 1.0000e-04
# Epoch 68/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.0828 - accuracy: 0.9169 - iou_coef: 0.8375 - dice_coef: 0.9074 - f1_score: 0.9078 - aggregated_jaccard_index: 0.8477 - val_val_loss: 0.0432 - val_val_accuracy: 0.9192 - val_val_iou_coef: 0.8817 - val_val_dice_coef: 0.9355 - val_val_f1_score: 0.9360 - val_val_aggregated_jaccard_index: 0.8819 - lr: 1.0000e-04
# Epoch 69/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0834 - accuracy: 0.9155 - iou_coef: 0.8347 - dice_coef: 0.9056 - f1_score: 0.9060 - aggregated_jaccard_index: 0.8442 - val_val_loss: 0.0464 - val_val_accuracy: 0.9226 - val_val_iou_coef: 0.8830 - val_val_dice_coef: 0.9367 - val_val_f1_score: 0.9370 - val_val_aggregated_jaccard_index: 0.8833 - lr: 1.0000e-04
# Epoch 70/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0800 - accuracy: 0.9169 - iou_coef: 0.8380 - dice_coef: 0.9080 - f1_score: 0.9085 - aggregated_jaccard_index: 0.8482
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 171/171 [==============================] - 18s 108ms/step - loss: 0.0799 - accuracy: 0.9169 - iou_coef: 0.8380 - dice_coef: 0.9080 - f1_score: 0.9085 - aggregated_jaccard_index: 0.8482 - val_val_loss: 0.0439 - val_val_accuracy: 0.9236 - val_val_iou_coef: 0.8860 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8863 - lr: 1.0000e-04
# Epoch 71/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.0795 - accuracy: 0.9178 - iou_coef: 0.8388 - dice_coef: 0.9083 - f1_score: 0.9087 - aggregated_jaccard_index: 0.8482 - val_val_loss: 0.0437 - val_val_accuracy: 0.9255 - val_val_iou_coef: 0.8874 - val_val_dice_coef: 0.9391 - val_val_f1_score: 0.9393 - val_val_aggregated_jaccard_index: 0.8879 - lr: 1.0000e-05
# Epoch 72/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.0771 - accuracy: 0.9199 - iou_coef: 0.8428 - dice_coef: 0.9110 - f1_score: 0.9114 - aggregated_jaccard_index: 0.8526 - val_val_loss: 0.0432 - val_val_accuracy: 0.9250 - val_val_iou_coef: 0.8869 - val_val_dice_coef: 0.9388 - val_val_f1_score: 0.9389 - val_val_aggregated_jaccard_index: 0.8875 - lr: 1.0000e-05
# Epoch 73/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0783 - accuracy: 0.9194 - iou_coef: 0.8421 - dice_coef: 0.9105 - f1_score: 0.9109 - aggregated_jaccard_index: 0.8510 - val_val_loss: 0.0426 - val_val_accuracy: 0.9249 - val_val_iou_coef: 0.8874 - val_val_dice_coef: 0.9391 - val_val_f1_score: 0.9392 - val_val_aggregated_jaccard_index: 0.8876 - lr: 1.0000e-05
# Epoch 74/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.0793 - accuracy: 0.9178 - iou_coef: 0.8386 - dice_coef: 0.9081 - f1_score: 0.9085 - aggregated_jaccard_index: 0.8485 - val_val_loss: 0.0425 - val_val_accuracy: 0.9237 - val_val_iou_coef: 0.8858 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9382 - val_val_aggregated_jaccard_index: 0.8862 - lr: 1.0000e-05
# Epoch 75/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0791 - accuracy: 0.9180 - iou_coef: 0.8393 - dice_coef: 0.9086 - f1_score: 0.9090 - aggregated_jaccard_index: 0.8484 - val_val_loss: 0.0426 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8873 - val_val_dice_coef: 0.9391 - val_val_f1_score: 0.9392 - val_val_aggregated_jaccard_index: 0.8878 - lr: 1.0000e-05
# Epoch 76/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.0782 - accuracy: 0.9187 - iou_coef: 0.8410 - dice_coef: 0.9098 - f1_score: 0.9102 - aggregated_jaccard_index: 0.8499 - val_val_loss: 0.0425 - val_val_accuracy: 0.9257 - val_val_iou_coef: 0.8883 - val_val_dice_coef: 0.9397 - val_val_f1_score: 0.9398 - val_val_aggregated_jaccard_index: 0.8889 - lr: 1.0000e-05
# Epoch 77/150
# 171/171 [==============================] - 21s 108ms/step - loss: 0.0768 - accuracy: 0.9197 - iou_coef: 0.8420 - dice_coef: 0.9103 - f1_score: 0.9107 - aggregated_jaccard_index: 0.8521 - val_val_loss: 0.0424 - val_val_accuracy: 0.9251 - val_val_iou_coef: 0.8877 - val_val_dice_coef: 0.9393 - val_val_f1_score: 0.9394 - val_val_aggregated_jaccard_index: 0.8881 - lr: 1.0000e-05
# Epoch 78/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.0775 - accuracy: 0.9192 - iou_coef: 0.8419 - dice_coef: 0.9101 - f1_score: 0.9105 - aggregated_jaccard_index: 0.8512 - val_val_loss: 0.0419 - val_val_accuracy: 0.9251 - val_val_iou_coef: 0.8880 - val_val_dice_coef: 0.9394 - val_val_f1_score: 0.9396 - val_val_aggregated_jaccard_index: 0.8883 - lr: 1.0000e-05
# Epoch 79/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0773 - accuracy: 0.9192 - iou_coef: 0.8423 - dice_coef: 0.9106 - f1_score: 0.9110 - aggregated_jaccard_index: 0.8512 - val_val_loss: 0.0420 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.8875 - val_val_dice_coef: 0.9392 - val_val_f1_score: 0.9393 - val_val_aggregated_jaccard_index: 0.8879 - lr: 1.0000e-05
# Epoch 80/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9182 - iou_coef: 0.8407 - dice_coef: 0.9096 - f1_score: 0.9100 - aggregated_jaccard_index: 0.8494
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0784 - accuracy: 0.9182 - iou_coef: 0.8407 - dice_coef: 0.9096 - f1_score: 0.9100 - aggregated_jaccard_index: 0.8494 - val_val_loss: 0.0422 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8876 - val_val_dice_coef: 0.9393 - val_val_f1_score: 0.9394 - val_val_aggregated_jaccard_index: 0.8881 - lr: 1.0000e-05
# Epoch 81/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0768 - accuracy: 0.9190 - iou_coef: 0.8421 - dice_coef: 0.9105 - f1_score: 0.9109 - aggregated_jaccard_index: 0.8516 - val_val_loss: 0.0422 - val_val_accuracy: 0.9247 - val_val_iou_coef: 0.8871 - val_val_dice_coef: 0.9389 - val_val_f1_score: 0.9390 - val_val_aggregated_jaccard_index: 0.8875 - lr: 1.0000e-05
# Epoch 82/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0776 - accuracy: 0.9186 - iou_coef: 0.8422 - dice_coef: 0.9105 - f1_score: 0.9109 - aggregated_jaccard_index: 0.8500 - val_val_loss: 0.0414 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.8863 - val_val_dice_coef: 0.9383 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8864 - lr: 1.0000e-05
# Epoch 83/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0757 - accuracy: 0.9200 - iou_coef: 0.8426 - dice_coef: 0.9108 - f1_score: 0.9112 - aggregated_jaccard_index: 0.8532 - val_val_loss: 0.0422 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.8861 - val_val_dice_coef: 0.9383 - val_val_f1_score: 0.9384 - val_val_aggregated_jaccard_index: 0.8862 - lr: 1.0000e-05
# Epoch 84/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0754 - accuracy: 0.9204 - iou_coef: 0.8439 - dice_coef: 0.9117 - f1_score: 0.9121 - aggregated_jaccard_index: 0.8536 - val_val_loss: 0.0422 - val_val_accuracy: 0.9242 - val_val_iou_coef: 0.8865 - val_val_dice_coef: 0.9385 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8869 - lr: 1.0000e-05
# Epoch 85/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0759 - accuracy: 0.9196 - iou_coef: 0.8424 - dice_coef: 0.9106 - f1_score: 0.9110 - aggregated_jaccard_index: 0.8526 - val_val_loss: 0.0417 - val_val_accuracy: 0.9238 - val_val_iou_coef: 0.8862 - val_val_dice_coef: 0.9383 - val_val_f1_score: 0.9384 - val_val_aggregated_jaccard_index: 0.8867 - lr: 1.0000e-05
# Epoch 86/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0760 - accuracy: 0.9200 - iou_coef: 0.8435 - dice_coef: 0.9114 - f1_score: 0.9118 - aggregated_jaccard_index: 0.8527 - val_val_loss: 0.0418 - val_val_accuracy: 0.9245 - val_val_iou_coef: 0.8869 - val_val_dice_coef: 0.9388 - val_val_f1_score: 0.9390 - val_val_aggregated_jaccard_index: 0.8874 - lr: 1.0000e-05
# Epoch 87/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0759 - accuracy: 0.9197 - iou_coef: 0.8425 - dice_coef: 0.9107 - f1_score: 0.9111 - aggregated_jaccard_index: 0.8526 - val_val_loss: 0.0410 - val_val_accuracy: 0.9200 - val_val_iou_coef: 0.8830 - val_val_dice_coef: 0.9358 - val_val_f1_score: 0.9360 - val_val_aggregated_jaccard_index: 0.8829 - lr: 1.0000e-05
# Epoch 88/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0763 - accuracy: 0.9193 - iou_coef: 0.8419 - dice_coef: 0.9104 - f1_score: 0.9108 - aggregated_jaccard_index: 0.8514 - val_val_loss: 0.0421 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8878 - val_val_dice_coef: 0.9393 - val_val_f1_score: 0.9395 - val_val_aggregated_jaccard_index: 0.8881 - lr: 1.0000e-05
# Epoch 89/150
# 171/171 [==============================] - 22s 128ms/step - loss: 0.0753 - accuracy: 0.9201 - iou_coef: 0.8433 - dice_coef: 0.9113 - f1_score: 0.9117 - aggregated_jaccard_index: 0.8530 - val_val_loss: 0.0415 - val_val_accuracy: 0.9235 - val_val_iou_coef: 0.8855 - val_val_dice_coef: 0.9379 - val_val_f1_score: 0.9380 - val_val_aggregated_jaccard_index: 0.8860 - lr: 1.0000e-05
# Epoch 90/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.0763 - accuracy: 0.9190 - iou_coef: 0.8418 - dice_coef: 0.9105 - f1_score: 0.9109 - aggregated_jaccard_index: 0.8505 - val_val_loss: 0.0418 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.8868 - val_val_dice_coef: 0.9387 - val_val_f1_score: 0.9388 - val_val_aggregated_jaccard_index: 0.8872 - lr: 1.0000e-05
# Epoch 91/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.0763 - accuracy: 0.9191 - iou_coef: 0.8407 - dice_coef: 0.9095 - f1_score: 0.9099 - aggregated_jaccard_index: 0.8504 - val_val_loss: 0.0415 - val_val_accuracy: 0.9227 - val_val_iou_coef: 0.8849 - val_val_dice_coef: 0.9375 - val_val_f1_score: 0.9376 - val_val_aggregated_jaccard_index: 0.8852 - lr: 1.0000e-05
# Epoch 92/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.0759 - accuracy: 0.9191 - iou_coef: 0.8411 - dice_coef: 0.9099 - f1_score: 0.9103 - aggregated_jaccard_index: 0.8512 - val_val_loss: 0.0408 - val_val_accuracy: 0.9241 - val_val_iou_coef: 0.8871 - val_val_dice_coef: 0.9389 - val_val_f1_score: 0.9391 - val_val_aggregated_jaccard_index: 0.8873 - lr: 1.0000e-05
# Epoch 93/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.0743 - accuracy: 0.9209 - iou_coef: 0.8444 - dice_coef: 0.9120 - f1_score: 0.9124 - aggregated_jaccard_index: 0.8538 - val_val_loss: 0.0413 - val_val_accuracy: 0.9237 - val_val_iou_coef: 0.8862 - val_val_dice_coef: 0.9383 - val_val_f1_score: 0.9385 - val_val_aggregated_jaccard_index: 0.8865 - lr: 1.0000e-05
# Epoch 94/150
# 171/171 [==============================] - 22s 127ms/step - loss: 0.0740 - accuracy: 0.9208 - iou_coef: 0.8445 - dice_coef: 0.9120 - f1_score: 0.9124 - aggregated_jaccard_index: 0.8538 - val_val_loss: 0.0414 - val_val_accuracy: 0.9245 - val_val_iou_coef: 0.8871 - val_val_dice_coef: 0.9389 - val_val_f1_score: 0.9390 - val_val_aggregated_jaccard_index: 0.8875 - lr: 1.0000e-05
# Epoch 95/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.0758 - accuracy: 0.9190 - iou_coef: 0.8410 - dice_coef: 0.9098 - f1_score: 0.9102 - aggregated_jaccard_index: 0.8504 - val_val_loss: 0.0415 - val_val_accuracy: 0.9242 - val_val_iou_coef: 0.8864 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9385 - val_val_aggregated_jaccard_index: 0.8870 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image
# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size = 256
batch_size = 72

# -----------------------------
# NORMALIZE FILENAMES (ONCE)
# -----------------------------
def lowercase_filenames(dir_path):
    for p in glob(os.path.join(dir_path, "*")):
        base = os.path.basename(p)
        lower = base.lower()
        if base != lower:
            os.rename(p, os.path.join(dir_path, lower))

lowercase_filenames(IMG_DIR)
lowercase_filenames(MSK_DIR)

# -----------------------------
# COLLECT PATHS
# -----------------------------
def valid_name(p):
    return "zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)
mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# KEY-BASED ALIGNMENT (SOURCE OF TRUTH)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

img_map = {stem(p): p for p in image_paths}
msk_map = {stem(p): p for p in mask_paths}

common_keys = sorted(img_map.keys() & msk_map.keys())
assert len(common_keys) > 0, "No aligned image–mask pairs found"

image_paths = [img_map[k] for k in common_keys]
mask_paths  = [msk_map[k] for k in common_keys]

print("Aligned pairs:", len(common_keys))

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )
    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.asarray(img, dtype=np.float32) / 255.0
    mask = (np.asarray(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:",
      tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 80
# Masks found : 80
# Aligned pairs: 80
# Validation batches: 2

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# 2026-09-20 08:18:38.398834: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8173
# Mean Dice Coefficient: 0.8944
# Mean AJI:              0.8227
# Mean Accuracy:         0.8888
# Mean F1 Score:         0.8977
