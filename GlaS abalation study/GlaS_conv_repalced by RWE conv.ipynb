# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-24 03:13:58.622518: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-24 03:13:58.641166: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-24 03:13:58.641192: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-24 03:13:58.641869: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-24 03:13:58.645656: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-24 03:14:03.386743: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-24 03:14:04.200439: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.240309: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.240379: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
import tensorflow as tf
from tensorflow.keras import layers

# conv_block(x, filters, decoder=False) must be defined elsewhere (unchanged)


def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = layers.MaxPooling2D(pool_size=2)(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = layers.MaxPooling2D(pool_size=2)(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = layers.MaxPooling2D(pool_size=2)(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = layers.MaxPooling2D(pool_size=2)(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # ===================== Decoder =====================

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-24 03:14:04.288164: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.288230: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.288246: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.442950: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.442993: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.442999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-24 03:14:04.443010: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-24 03:14:04.443022: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 03:14:04.443041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['activation[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['max_pooling2d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['max_pooling2d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 128)          0         ['activation_2[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['max_pooling2d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 256)          0         ['activation_3[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['max_pooling2d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['activation_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 32, 32, 256)          0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 64, 64, 128)          0         ['activation_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_1[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_2[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['activation[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 1)          33        ['add_3[0][0]']
#
# ==================================================================================================
# Total params: 2832618 (10.81 MB)
# Trainable params: 2829930 (10.80 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../GLAS_PREPARED_DATA/val/images/*.png") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tif") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 684
# Train masks: 684
# Val images: 9
# Val masks: 9
# 2026-09-24 03:14:05.225821: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 171
# Validation batches: 3

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-24 03:14:08.477000: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-24 03:14:12.231381: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-24 03:14:12.571540: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-24 03:14:15.322192: I external/local_xla/xla/service/service.cc:168] XLA service 0x7be162104d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-24 03:14:15.322233: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-24 03:14:15.341569: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790219655.419780     733 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - ETA: 0s - loss: 2.7693 - accuracy: 0.7264 - iou_coef: 0.5531 - dice_coef: 0.6955 - f1_score: 0.6994 - aggregated_jaccard_index: 0.5756
# ✅ Saved improved backbone at epoch 1 with val_iou=0.3146
# 171/171 [==============================] - 28s 82ms/step - loss: 2.7654 - accuracy: 0.7264 - iou_coef: 0.5531 - dice_coef: 0.6955 - f1_score: 0.6994 - aggregated_jaccard_index: 0.5756 - val_val_loss: 5.7522 - val_val_accuracy: 0.6173 - val_val_iou_coef: 0.3146 - val_val_dice_coef: 0.4487 - val_val_f1_score: 0.4337 - val_val_aggregated_jaccard_index: 0.3132 - lr: 0.0010
# Epoch 2/150
# 171/171 [==============================] - ETA: 0s - loss: 2.1676 - accuracy: 0.7790 - iou_coef: 0.6322 - dice_coef: 0.7641 - f1_score: 0.7669 - aggregated_jaccard_index: 0.6510
# ✅ Saved improved backbone at epoch 2 with val_iou=0.6262
# 171/171 [==============================] - 13s 77ms/step - loss: 2.1671 - accuracy: 0.7790 - iou_coef: 0.6322 - dice_coef: 0.7641 - f1_score: 0.7669 - aggregated_jaccard_index: 0.6510 - val_val_loss: 2.1771 - val_val_accuracy: 0.6628 - val_val_iou_coef: 0.6262 - val_val_dice_coef: 0.7650 - val_val_f1_score: 0.7653 - val_val_aggregated_jaccard_index: 0.6416 - lr: 0.0010
# Epoch 3/150
# 171/171 [==============================] - 12s 71ms/step - loss: 1.8883 - accuracy: 0.8029 - iou_coef: 0.6668 - dice_coef: 0.7907 - f1_score: 0.7926 - aggregated_jaccard_index: 0.6835 - val_val_loss: 2.5230 - val_val_accuracy: 0.6087 - val_val_iou_coef: 0.5897 - val_val_dice_coef: 0.7362 - val_val_f1_score: 0.7360 - val_val_aggregated_jaccard_index: 0.6071 - lr: 0.0010
# Epoch 4/150
# 171/171 [==============================] - ETA: 0s - loss: 1.7275 - accuracy: 0.8139 - iou_coef: 0.6848 - dice_coef: 0.8040 - f1_score: 0.8056 - aggregated_jaccard_index: 0.6998
# ✅ Saved improved backbone at epoch 4 with val_iou=0.7224
# 171/171 [==============================] - 15s 89ms/step - loss: 1.7300 - accuracy: 0.8139 - iou_coef: 0.6848 - dice_coef: 0.8040 - f1_score: 0.8056 - aggregated_jaccard_index: 0.6998 - val_val_loss: 0.8803 - val_val_accuracy: 0.8000 - val_val_iou_coef: 0.7224 - val_val_dice_coef: 0.8256 - val_val_f1_score: 0.8266 - val_val_aggregated_jaccard_index: 0.7199 - lr: 0.0010
# Epoch 5/150
# 171/171 [==============================] - 12s 71ms/step - loss: 1.5933 - accuracy: 0.8230 - iou_coef: 0.6960 - dice_coef: 0.8129 - f1_score: 0.8142 - aggregated_jaccard_index: 0.7111 - val_val_loss: 2.1883 - val_val_accuracy: 0.6279 - val_val_iou_coef: 0.6064 - val_val_dice_coef: 0.7486 - val_val_f1_score: 0.7484 - val_val_aggregated_jaccard_index: 0.6245 - lr: 0.0010
# Epoch 6/150
# 171/171 [==============================] - ETA: 0s - loss: 1.4393 - accuracy: 0.8348 - iou_coef: 0.7133 - dice_coef: 0.8253 - f1_score: 0.8264 - aggregated_jaccard_index: 0.7268
# ✅ Saved improved backbone at epoch 6 with val_iou=0.7837
# 171/171 [==============================] - 12s 72ms/step - loss: 1.4385 - accuracy: 0.8348 - iou_coef: 0.7133 - dice_coef: 0.8253 - f1_score: 0.8264 - aggregated_jaccard_index: 0.7268 - val_val_loss: 0.7907 - val_val_accuracy: 0.8291 - val_val_iou_coef: 0.7837 - val_val_dice_coef: 0.8740 - val_val_f1_score: 0.8745 - val_val_aggregated_jaccard_index: 0.7852 - lr: 0.0010
# Epoch 7/150
# 171/171 [==============================] - 15s 89ms/step - loss: 1.3243 - accuracy: 0.8422 - iou_coef: 0.7235 - dice_coef: 0.8326 - f1_score: 0.8335 - aggregated_jaccard_index: 0.7377 - val_val_loss: 0.9434 - val_val_accuracy: 0.8296 - val_val_iou_coef: 0.7623 - val_val_dice_coef: 0.8626 - val_val_f1_score: 0.8632 - val_val_aggregated_jaccard_index: 0.7666 - lr: 0.0010
# Epoch 8/150
# 171/171 [==============================] - 13s 76ms/step - loss: 1.2659 - accuracy: 0.8428 - iou_coef: 0.7251 - dice_coef: 0.8331 - f1_score: 0.8339 - aggregated_jaccard_index: 0.7403 - val_val_loss: 0.8676 - val_val_accuracy: 0.7716 - val_val_iou_coef: 0.7430 - val_val_dice_coef: 0.8463 - val_val_f1_score: 0.8469 - val_val_aggregated_jaccard_index: 0.7567 - lr: 0.0010
# Epoch 9/150
# 171/171 [==============================] - 14s 84ms/step - loss: 1.1822 - accuracy: 0.8475 - iou_coef: 0.7297 - dice_coef: 0.8363 - f1_score: 0.8371 - aggregated_jaccard_index: 0.7429 - val_val_loss: 0.6277 - val_val_accuracy: 0.7976 - val_val_iou_coef: 0.7699 - val_val_dice_coef: 0.8632 - val_val_f1_score: 0.8639 - val_val_aggregated_jaccard_index: 0.7743 - lr: 0.0010
# Epoch 10/150
# 171/171 [==============================] - ETA: 0s - loss: 1.1031 - accuracy: 0.8517 - iou_coef: 0.7368 - dice_coef: 0.8414 - f1_score: 0.8422 - aggregated_jaccard_index: 0.7496
# ✅ Saved improved backbone at epoch 10 with val_iou=0.8099
# 171/171 [==============================] - 13s 74ms/step - loss: 1.1027 - accuracy: 0.8517 - iou_coef: 0.7368 - dice_coef: 0.8414 - f1_score: 0.8422 - aggregated_jaccard_index: 0.7496 - val_val_loss: 0.5571 - val_val_accuracy: 0.8691 - val_val_iou_coef: 0.8099 - val_val_dice_coef: 0.8900 - val_val_f1_score: 0.8913 - val_val_aggregated_jaccard_index: 0.8069 - lr: 0.0010
# Epoch 11/150
# 171/171 [==============================] - 12s 72ms/step - loss: 1.0327 - accuracy: 0.8544 - iou_coef: 0.7398 - dice_coef: 0.8427 - f1_score: 0.8434 - aggregated_jaccard_index: 0.7544 - val_val_loss: 0.5493 - val_val_accuracy: 0.8569 - val_val_iou_coef: 0.8079 - val_val_dice_coef: 0.8886 - val_val_f1_score: 0.8890 - val_val_aggregated_jaccard_index: 0.8062 - lr: 0.0010
# Epoch 12/150
# 171/171 [==============================] - 15s 85ms/step - loss: 0.9464 - accuracy: 0.8606 - iou_coef: 0.7502 - dice_coef: 0.8505 - f1_score: 0.8512 - aggregated_jaccard_index: 0.7621 - val_val_loss: 0.4348 - val_val_accuracy: 0.8598 - val_val_iou_coef: 0.7982 - val_val_dice_coef: 0.8781 - val_val_f1_score: 0.8786 - val_val_aggregated_jaccard_index: 0.7979 - lr: 0.0010
# Epoch 13/150
# 171/171 [==============================] - ETA: 0s - loss: 0.8915 - accuracy: 0.8617 - iou_coef: 0.7521 - dice_coef: 0.8511 - f1_score: 0.8518 - aggregated_jaccard_index: 0.7653
# ✅ Saved improved backbone at epoch 13 with val_iou=0.8129
# 171/171 [==============================] - 12s 72ms/step - loss: 0.8942 - accuracy: 0.8617 - iou_coef: 0.7521 - dice_coef: 0.8511 - f1_score: 0.8518 - aggregated_jaccard_index: 0.7653 - val_val_loss: 0.3978 - val_val_accuracy: 0.8698 - val_val_iou_coef: 0.8129 - val_val_dice_coef: 0.8903 - val_val_f1_score: 0.8905 - val_val_aggregated_jaccard_index: 0.8123 - lr: 0.0010
# Epoch 14/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.8196 - accuracy: 0.8669 - iou_coef: 0.7594 - dice_coef: 0.8568 - f1_score: 0.8574 - aggregated_jaccard_index: 0.7710 - val_val_loss: 0.7226 - val_val_accuracy: 0.7254 - val_val_iou_coef: 0.7118 - val_val_dice_coef: 0.8226 - val_val_f1_score: 0.8231 - val_val_aggregated_jaccard_index: 0.7297 - lr: 0.0010
# Epoch 15/150
# 171/171 [==============================] - ETA: 0s - loss: 0.7792 - accuracy: 0.8661 - iou_coef: 0.7592 - dice_coef: 0.8566 - f1_score: 0.8572 - aggregated_jaccard_index: 0.7703
# ✅ Saved improved backbone at epoch 15 with val_iou=0.8453
# 171/171 [==============================] - 15s 89ms/step - loss: 0.7799 - accuracy: 0.8661 - iou_coef: 0.7592 - dice_coef: 0.8566 - f1_score: 0.8572 - aggregated_jaccard_index: 0.7703 - val_val_loss: 0.3606 - val_val_accuracy: 0.8865 - val_val_iou_coef: 0.8453 - val_val_dice_coef: 0.9139 - val_val_f1_score: 0.9144 - val_val_aggregated_jaccard_index: 0.8429 - lr: 0.0010
# Epoch 16/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.7086 - accuracy: 0.8714 - iou_coef: 0.7656 - dice_coef: 0.8607 - f1_score: 0.8614 - aggregated_jaccard_index: 0.7785 - val_val_loss: 0.3810 - val_val_accuracy: 0.8881 - val_val_iou_coef: 0.8424 - val_val_dice_coef: 0.9131 - val_val_f1_score: 0.9135 - val_val_aggregated_jaccard_index: 0.8422 - lr: 0.0010
# Epoch 17/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.6542 - accuracy: 0.8746 - iou_coef: 0.7699 - dice_coef: 0.8637 - f1_score: 0.8643 - aggregated_jaccard_index: 0.7838 - val_val_loss: 0.3176 - val_val_accuracy: 0.8623 - val_val_iou_coef: 0.7998 - val_val_dice_coef: 0.8804 - val_val_f1_score: 0.8808 - val_val_aggregated_jaccard_index: 0.7997 - lr: 0.0010
# Epoch 18/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5965 - accuracy: 0.8790 - iou_coef: 0.7786 - dice_coef: 0.8697 - f1_score: 0.8703 - aggregated_jaccard_index: 0.7901
# ✅ Saved improved backbone at epoch 18 with val_iou=0.8570
# 171/171 [==============================] - 12s 73ms/step - loss: 0.5970 - accuracy: 0.8790 - iou_coef: 0.7786 - dice_coef: 0.8697 - f1_score: 0.8703 - aggregated_jaccard_index: 0.7901 - val_val_loss: 0.2990 - val_val_accuracy: 0.8978 - val_val_iou_coef: 0.8570 - val_val_dice_coef: 0.9203 - val_val_f1_score: 0.9208 - val_val_aggregated_jaccard_index: 0.8556 - lr: 0.0010
# Epoch 19/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.5582 - accuracy: 0.8796 - iou_coef: 0.7775 - dice_coef: 0.8691 - f1_score: 0.8696 - aggregated_jaccard_index: 0.7912 - val_val_loss: 0.2725 - val_val_accuracy: 0.8762 - val_val_iou_coef: 0.8235 - val_val_dice_coef: 0.9007 - val_val_f1_score: 0.9011 - val_val_aggregated_jaccard_index: 0.8189 - lr: 0.0010
# Epoch 20/150
# 171/171 [==============================] - 15s 90ms/step - loss: 0.5136 - accuracy: 0.8832 - iou_coef: 0.7824 - dice_coef: 0.8714 - f1_score: 0.8719 - aggregated_jaccard_index: 0.7963 - val_val_loss: 0.2605 - val_val_accuracy: 0.8837 - val_val_iou_coef: 0.8303 - val_val_dice_coef: 0.9022 - val_val_f1_score: 0.9026 - val_val_aggregated_jaccard_index: 0.8284 - lr: 0.0010
# Epoch 21/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.4824 - accuracy: 0.8820 - iou_coef: 0.7802 - dice_coef: 0.8701 - f1_score: 0.8707 - aggregated_jaccard_index: 0.7936 - val_val_loss: 0.2351 - val_val_accuracy: 0.8606 - val_val_iou_coef: 0.8298 - val_val_dice_coef: 0.9027 - val_val_f1_score: 0.9030 - val_val_aggregated_jaccard_index: 0.8300 - lr: 0.0010
# Epoch 22/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.4264 - accuracy: 0.8890 - iou_coef: 0.7915 - dice_coef: 0.8778 - f1_score: 0.8784 - aggregated_jaccard_index: 0.8055 - val_val_loss: 0.2085 - val_val_accuracy: 0.8812 - val_val_iou_coef: 0.8368 - val_val_dice_coef: 0.9056 - val_val_f1_score: 0.9059 - val_val_aggregated_jaccard_index: 0.8361 - lr: 0.0010
# Epoch 23/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.3991 - accuracy: 0.8893 - iou_coef: 0.7929 - dice_coef: 0.8786 - f1_score: 0.8791 - aggregated_jaccard_index: 0.8058 - val_val_loss: 0.3675 - val_val_accuracy: 0.8579 - val_val_iou_coef: 0.7815 - val_val_dice_coef: 0.8670 - val_val_f1_score: 0.8675 - val_val_aggregated_jaccard_index: 0.7794 - lr: 0.0010
# Epoch 24/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.3668 - accuracy: 0.8918 - iou_coef: 0.7966 - dice_coef: 0.8811 - f1_score: 0.8816 - aggregated_jaccard_index: 0.8099 - val_val_loss: 0.1699 - val_val_accuracy: 0.8934 - val_val_iou_coef: 0.8461 - val_val_dice_coef: 0.9107 - val_val_f1_score: 0.9110 - val_val_aggregated_jaccard_index: 0.8451 - lr: 0.0010
# Epoch 25/150
# 171/171 [==============================] - 15s 90ms/step - loss: 0.3424 - accuracy: 0.8910 - iou_coef: 0.7947 - dice_coef: 0.8794 - f1_score: 0.8799 - aggregated_jaccard_index: 0.8080 - val_val_loss: 0.1534 - val_val_accuracy: 0.8663 - val_val_iou_coef: 0.8123 - val_val_dice_coef: 0.8801 - val_val_f1_score: 0.8804 - val_val_aggregated_jaccard_index: 0.8111 - lr: 0.0010
# Epoch 26/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3127 - accuracy: 0.8931 - iou_coef: 0.7986 - dice_coef: 0.8823 - f1_score: 0.8827 - aggregated_jaccard_index: 0.8112
# ✅ Saved improved backbone at epoch 26 with val_iou=0.8676
# 171/171 [==============================] - 12s 72ms/step - loss: 0.3124 - accuracy: 0.8931 - iou_coef: 0.7986 - dice_coef: 0.8823 - f1_score: 0.8827 - aggregated_jaccard_index: 0.8112 - val_val_loss: 0.1687 - val_val_accuracy: 0.9117 - val_val_iou_coef: 0.8676 - val_val_dice_coef: 0.9277 - val_val_f1_score: 0.9280 - val_val_aggregated_jaccard_index: 0.8658 - lr: 0.0010
# Epoch 27/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.2821 - accuracy: 0.8965 - iou_coef: 0.8036 - dice_coef: 0.8857 - f1_score: 0.8862 - aggregated_jaccard_index: 0.8166 - val_val_loss: 0.1408 - val_val_accuracy: 0.8941 - val_val_iou_coef: 0.8423 - val_val_dice_coef: 0.9074 - val_val_f1_score: 0.9077 - val_val_aggregated_jaccard_index: 0.8427 - lr: 0.0010
# Epoch 28/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.2556 - accuracy: 0.8989 - iou_coef: 0.8072 - dice_coef: 0.8879 - f1_score: 0.8884 - aggregated_jaccard_index: 0.8200 - val_val_loss: 0.1397 - val_val_accuracy: 0.9059 - val_val_iou_coef: 0.8623 - val_val_dice_coef: 0.9246 - val_val_f1_score: 0.9249 - val_val_aggregated_jaccard_index: 0.8638 - lr: 0.0010
# Epoch 29/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.2317 - accuracy: 0.9020 - iou_coef: 0.8132 - dice_coef: 0.8922 - f1_score: 0.8927 - aggregated_jaccard_index: 0.8245 - val_val_loss: 0.1216 - val_val_accuracy: 0.8720 - val_val_iou_coef: 0.8368 - val_val_dice_coef: 0.9073 - val_val_f1_score: 0.9075 - val_val_aggregated_jaccard_index: 0.8373 - lr: 0.0010
# Epoch 30/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.2206 - accuracy: 0.8994 - iou_coef: 0.8090 - dice_coef: 0.8894 - f1_score: 0.8898 - aggregated_jaccard_index: 0.8201 - val_val_loss: 0.1133 - val_val_accuracy: 0.8714 - val_val_iou_coef: 0.8137 - val_val_dice_coef: 0.8790 - val_val_f1_score: 0.8791 - val_val_aggregated_jaccard_index: 0.8123 - lr: 0.0010
# Epoch 31/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.1951 - accuracy: 0.9043 - iou_coef: 0.8169 - dice_coef: 0.8945 - f1_score: 0.8949 - aggregated_jaccard_index: 0.8279 - val_val_loss: 0.1061 - val_val_accuracy: 0.9031 - val_val_iou_coef: 0.8524 - val_val_dice_coef: 0.9180 - val_val_f1_score: 0.9182 - val_val_aggregated_jaccard_index: 0.8534 - lr: 0.0010
# Epoch 32/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.1780 - accuracy: 0.9056 - iou_coef: 0.8183 - dice_coef: 0.8956 - f1_score: 0.8961 - aggregated_jaccard_index: 0.8290 - val_val_loss: 0.1022 - val_val_accuracy: 0.8206 - val_val_iou_coef: 0.8084 - val_val_dice_coef: 0.8882 - val_val_f1_score: 0.8885 - val_val_aggregated_jaccard_index: 0.8135 - lr: 0.0010
# Epoch 33/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1644 - accuracy: 0.9057 - iou_coef: 0.8191 - dice_coef: 0.8961 - f1_score: 0.8966 - aggregated_jaccard_index: 0.8308 - val_val_loss: 0.1061 - val_val_accuracy: 0.8787 - val_val_iou_coef: 0.8211 - val_val_dice_coef: 0.8929 - val_val_f1_score: 0.8933 - val_val_aggregated_jaccard_index: 0.8197 - lr: 0.0010
# Epoch 34/150
# 171/171 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9071 - iou_coef: 0.8212 - dice_coef: 0.8969 - f1_score: 0.8973 - aggregated_jaccard_index: 0.8331
# ✅ Saved improved backbone at epoch 34 with val_iou=0.8797
# 171/171 [==============================] - 12s 73ms/step - loss: 0.1494 - accuracy: 0.9071 - iou_coef: 0.8212 - dice_coef: 0.8969 - f1_score: 0.8973 - aggregated_jaccard_index: 0.8331 - val_val_loss: 0.0766 - val_val_accuracy: 0.9173 - val_val_iou_coef: 0.8797 - val_val_dice_coef: 0.9346 - val_val_f1_score: 0.9349 - val_val_aggregated_jaccard_index: 0.8799 - lr: 0.0010
# Epoch 35/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.1389 - accuracy: 0.9077 - iou_coef: 0.8216 - dice_coef: 0.8974 - f1_score: 0.8979 - aggregated_jaccard_index: 0.8321 - val_val_loss: 0.0772 - val_val_accuracy: 0.9107 - val_val_iou_coef: 0.8698 - val_val_dice_coef: 0.9288 - val_val_f1_score: 0.9289 - val_val_aggregated_jaccard_index: 0.8705 - lr: 0.0010
# Epoch 36/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.1281 - accuracy: 0.9070 - iou_coef: 0.8213 - dice_coef: 0.8971 - f1_score: 0.8976 - aggregated_jaccard_index: 0.8332 - val_val_loss: 0.0703 - val_val_accuracy: 0.8805 - val_val_iou_coef: 0.8391 - val_val_dice_coef: 0.9086 - val_val_f1_score: 0.9087 - val_val_aggregated_jaccard_index: 0.8462 - lr: 0.0010
# Epoch 37/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.1144 - accuracy: 0.9102 - iou_coef: 0.8264 - dice_coef: 0.9005 - f1_score: 0.9010 - aggregated_jaccard_index: 0.8374 - val_val_loss: 0.0585 - val_val_accuracy: 0.8982 - val_val_iou_coef: 0.8618 - val_val_dice_coef: 0.9207 - val_val_f1_score: 0.9209 - val_val_aggregated_jaccard_index: 0.8591 - lr: 0.0010
# Epoch 38/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.1058 - accuracy: 0.9107 - iou_coef: 0.8267 - dice_coef: 0.9006 - f1_score: 0.9011 - aggregated_jaccard_index: 0.8379 - val_val_loss: 0.0559 - val_val_accuracy: 0.9108 - val_val_iou_coef: 0.8696 - val_val_dice_coef: 0.9283 - val_val_f1_score: 0.9284 - val_val_aggregated_jaccard_index: 0.8676 - lr: 0.0010
# Epoch 39/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0993 - accuracy: 0.9093 - iou_coef: 0.8243 - dice_coef: 0.8992 - f1_score: 0.8996 - aggregated_jaccard_index: 0.8346 - val_val_loss: 0.0533 - val_val_accuracy: 0.9027 - val_val_iou_coef: 0.8641 - val_val_dice_coef: 0.9238 - val_val_f1_score: 0.9239 - val_val_aggregated_jaccard_index: 0.8638 - lr: 0.0010
# Epoch 40/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0886 - accuracy: 0.9117 - iou_coef: 0.8281 - dice_coef: 0.9014 - f1_score: 0.9018 - aggregated_jaccard_index: 0.8399 - val_val_loss: 0.0472 - val_val_accuracy: 0.9063 - val_val_iou_coef: 0.8697 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9273 - val_val_aggregated_jaccard_index: 0.8702 - lr: 0.0010
# Epoch 41/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0799 - accuracy: 0.9141 - iou_coef: 0.8322 - dice_coef: 0.9041 - f1_score: 0.9045 - aggregated_jaccard_index: 0.8437 - val_val_loss: 0.0666 - val_val_accuracy: 0.8419 - val_val_iou_coef: 0.7624 - val_val_dice_coef: 0.8392 - val_val_f1_score: 0.8394 - val_val_aggregated_jaccard_index: 0.7648 - lr: 0.0010
# Epoch 42/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0748 - accuracy: 0.9130 - iou_coef: 0.8296 - dice_coef: 0.9023 - f1_score: 0.9026 - aggregated_jaccard_index: 0.8418 - val_val_loss: 0.0374 - val_val_accuracy: 0.9132 - val_val_iou_coef: 0.8721 - val_val_dice_coef: 0.9292 - val_val_f1_score: 0.9292 - val_val_aggregated_jaccard_index: 0.8716 - lr: 0.0010
# Epoch 43/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0675 - accuracy: 0.9153 - iou_coef: 0.8347 - dice_coef: 0.9056 - f1_score: 0.9060 - aggregated_jaccard_index: 0.8461 - val_val_loss: 0.0382 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.8679 - val_val_dice_coef: 0.9266 - val_val_f1_score: 0.9268 - val_val_aggregated_jaccard_index: 0.8687 - lr: 0.0010
# Epoch 44/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0617 - accuracy: 0.9172 - iou_coef: 0.8382 - dice_coef: 0.9081 - f1_score: 0.9086 - aggregated_jaccard_index: 0.8477
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0619 - accuracy: 0.9172 - iou_coef: 0.8382 - dice_coef: 0.9081 - f1_score: 0.9086 - aggregated_jaccard_index: 0.8477 - val_val_loss: 0.0347 - val_val_accuracy: 0.8999 - val_val_iou_coef: 0.8570 - val_val_dice_coef: 0.9195 - val_val_f1_score: 0.9197 - val_val_aggregated_jaccard_index: 0.8546 - lr: 0.0010
# Epoch 45/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0563 - accuracy: 0.9215 - iou_coef: 0.8436 - dice_coef: 0.9113 - f1_score: 0.9118 - aggregated_jaccard_index: 0.8548 - val_val_loss: 0.0329 - val_val_accuracy: 0.9183 - val_val_iou_coef: 0.8794 - val_val_dice_coef: 0.9337 - val_val_f1_score: 0.9339 - val_val_aggregated_jaccard_index: 0.8799 - lr: 1.0000e-04
# Epoch 46/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0552 - accuracy: 0.9226 - iou_coef: 0.8471 - dice_coef: 0.9134 - f1_score: 0.9138 - aggregated_jaccard_index: 0.8568 - val_val_loss: 0.0326 - val_val_accuracy: 0.9188 - val_val_iou_coef: 0.8789 - val_val_dice_coef: 0.9333 - val_val_f1_score: 0.9335 - val_val_aggregated_jaccard_index: 0.8796 - lr: 1.0000e-04
# Epoch 47/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0530 - accuracy: 0.9245 - iou_coef: 0.8509 - dice_coef: 0.9159 - f1_score: 0.9163 - aggregated_jaccard_index: 0.8605 - val_val_loss: 0.0327 - val_val_accuracy: 0.9174 - val_val_iou_coef: 0.8768 - val_val_dice_coef: 0.9322 - val_val_f1_score: 0.9324 - val_val_aggregated_jaccard_index: 0.8775 - lr: 1.0000e-04
# Epoch 48/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0532 - accuracy: 0.9238 - iou_coef: 0.8484 - dice_coef: 0.9144 - f1_score: 0.9149 - aggregated_jaccard_index: 0.8589
# ✅ Saved improved backbone at epoch 48 with val_iou=0.8813
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0532 - accuracy: 0.9238 - iou_coef: 0.8484 - dice_coef: 0.9144 - f1_score: 0.9149 - aggregated_jaccard_index: 0.8589 - val_val_loss: 0.0322 - val_val_accuracy: 0.9204 - val_val_iou_coef: 0.8813 - val_val_dice_coef: 0.9349 - val_val_f1_score: 0.9352 - val_val_aggregated_jaccard_index: 0.8821 - lr: 1.0000e-04
# Epoch 49/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0532 - accuracy: 0.9233 - iou_coef: 0.8486 - dice_coef: 0.9145 - f1_score: 0.9149 - aggregated_jaccard_index: 0.8578 - val_val_loss: 0.0321 - val_val_accuracy: 0.9166 - val_val_iou_coef: 0.8759 - val_val_dice_coef: 0.9313 - val_val_f1_score: 0.9315 - val_val_aggregated_jaccard_index: 0.8766 - lr: 1.0000e-04
# Epoch 50/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0522 - accuracy: 0.9244 - iou_coef: 0.8501 - dice_coef: 0.9155 - f1_score: 0.9159 - aggregated_jaccard_index: 0.8590
# ✅ Saved improved backbone at epoch 50 with val_iou=0.8849
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0522 - accuracy: 0.9244 - iou_coef: 0.8501 - dice_coef: 0.9155 - f1_score: 0.9159 - aggregated_jaccard_index: 0.8590 - val_val_loss: 0.0321 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.8849 - val_val_dice_coef: 0.9379 - val_val_f1_score: 0.9381 - val_val_aggregated_jaccard_index: 0.8856 - lr: 1.0000e-04
# Epoch 51/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0521 - accuracy: 0.9240 - iou_coef: 0.8496 - dice_coef: 0.9152 - f1_score: 0.9156 - aggregated_jaccard_index: 0.8580 - val_val_loss: 0.0315 - val_val_accuracy: 0.9178 - val_val_iou_coef: 0.8780 - val_val_dice_coef: 0.9328 - val_val_f1_score: 0.9330 - val_val_aggregated_jaccard_index: 0.8789 - lr: 1.0000e-04
# Epoch 52/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0513 - accuracy: 0.9243 - iou_coef: 0.8502 - dice_coef: 0.9153 - f1_score: 0.9157 - aggregated_jaccard_index: 0.8595 - val_val_loss: 0.0307 - val_val_accuracy: 0.9221 - val_val_iou_coef: 0.8837 - val_val_dice_coef: 0.9367 - val_val_f1_score: 0.9368 - val_val_aggregated_jaccard_index: 0.8845 - lr: 1.0000e-04
# Epoch 53/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0504 - accuracy: 0.9245 - iou_coef: 0.8505 - dice_coef: 0.9157 - f1_score: 0.9161 - aggregated_jaccard_index: 0.8600
# ✅ Saved improved backbone at epoch 53 with val_iou=0.8851
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0504 - accuracy: 0.9245 - iou_coef: 0.8505 - dice_coef: 0.9157 - f1_score: 0.9161 - aggregated_jaccard_index: 0.8600 - val_val_loss: 0.0306 - val_val_accuracy: 0.9227 - val_val_iou_coef: 0.8851 - val_val_dice_coef: 0.9375 - val_val_f1_score: 0.9377 - val_val_aggregated_jaccard_index: 0.8862 - lr: 1.0000e-04
# Epoch 54/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0505 - accuracy: 0.9240 - iou_coef: 0.8498 - dice_coef: 0.9153 - f1_score: 0.9157 - aggregated_jaccard_index: 0.8580 - val_val_loss: 0.0301 - val_val_accuracy: 0.9199 - val_val_iou_coef: 0.8808 - val_val_dice_coef: 0.9344 - val_val_f1_score: 0.9345 - val_val_aggregated_jaccard_index: 0.8817 - lr: 1.0000e-04
# Epoch 55/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0486 - accuracy: 0.9254 - iou_coef: 0.8525 - dice_coef: 0.9168 - f1_score: 0.9172 - aggregated_jaccard_index: 0.8617 - val_val_loss: 0.0298 - val_val_accuracy: 0.9193 - val_val_iou_coef: 0.8799 - val_val_dice_coef: 0.9340 - val_val_f1_score: 0.9341 - val_val_aggregated_jaccard_index: 0.8810 - lr: 1.0000e-04
# Epoch 56/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0486 - accuracy: 0.9250 - iou_coef: 0.8515 - dice_coef: 0.9163 - f1_score: 0.9167 - aggregated_jaccard_index: 0.8601 - val_val_loss: 0.0289 - val_val_accuracy: 0.9195 - val_val_iou_coef: 0.8796 - val_val_dice_coef: 0.9336 - val_val_f1_score: 0.9338 - val_val_aggregated_jaccard_index: 0.8807 - lr: 1.0000e-04
# Epoch 57/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0475 - accuracy: 0.9258 - iou_coef: 0.8529 - dice_coef: 0.9172 - f1_score: 0.9175 - aggregated_jaccard_index: 0.8622
# ✅ Saved improved backbone at epoch 57 with val_iou=0.8870
# 171/171 [==============================] - 15s 89ms/step - loss: 0.0475 - accuracy: 0.9258 - iou_coef: 0.8529 - dice_coef: 0.9172 - f1_score: 0.9175 - aggregated_jaccard_index: 0.8622 - val_val_loss: 0.0285 - val_val_accuracy: 0.9243 - val_val_iou_coef: 0.8870 - val_val_dice_coef: 0.9386 - val_val_f1_score: 0.9387 - val_val_aggregated_jaccard_index: 0.8880 - lr: 1.0000e-04
# Epoch 58/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0464 - accuracy: 0.9263 - iou_coef: 0.8535 - dice_coef: 0.9176 - f1_score: 0.9180 - aggregated_jaccard_index: 0.8634 - val_val_loss: 0.0285 - val_val_accuracy: 0.9236 - val_val_iou_coef: 0.8852 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9384 - val_val_aggregated_jaccard_index: 0.8858 - lr: 1.0000e-04
# Epoch 59/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0461 - accuracy: 0.9262 - iou_coef: 0.8532 - dice_coef: 0.9174 - f1_score: 0.9178 - aggregated_jaccard_index: 0.8634 - val_val_loss: 0.0284 - val_val_accuracy: 0.9225 - val_val_iou_coef: 0.8835 - val_val_dice_coef: 0.9367 - val_val_f1_score: 0.9368 - val_val_aggregated_jaccard_index: 0.8841 - lr: 1.0000e-04
# Epoch 60/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9255 - iou_coef: 0.8517 - dice_coef: 0.9165 - f1_score: 0.9169 - aggregated_jaccard_index: 0.8612
# ✅ Saved improved backbone at epoch 60 with val_iou=0.8919
# 171/171 [==============================] - 15s 89ms/step - loss: 0.0461 - accuracy: 0.9255 - iou_coef: 0.8517 - dice_coef: 0.9165 - f1_score: 0.9169 - aggregated_jaccard_index: 0.8612 - val_val_loss: 0.0273 - val_val_accuracy: 0.9292 - val_val_iou_coef: 0.8919 - val_val_dice_coef: 0.9421 - val_val_f1_score: 0.9423 - val_val_aggregated_jaccard_index: 0.8931 - lr: 1.0000e-04
# Epoch 61/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0456 - accuracy: 0.9257 - iou_coef: 0.8516 - dice_coef: 0.9164 - f1_score: 0.9168 - aggregated_jaccard_index: 0.8610 - val_val_loss: 0.0274 - val_val_accuracy: 0.9228 - val_val_iou_coef: 0.8847 - val_val_dice_coef: 0.9372 - val_val_f1_score: 0.9374 - val_val_aggregated_jaccard_index: 0.8851 - lr: 1.0000e-04
# Epoch 62/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0453 - accuracy: 0.9256 - iou_coef: 0.8526 - dice_coef: 0.9171 - f1_score: 0.9175 - aggregated_jaccard_index: 0.8610 - val_val_loss: 0.0266 - val_val_accuracy: 0.9227 - val_val_iou_coef: 0.8850 - val_val_dice_coef: 0.9379 - val_val_f1_score: 0.9380 - val_val_aggregated_jaccard_index: 0.8858 - lr: 1.0000e-04
# Epoch 63/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0438 - accuracy: 0.9268 - iou_coef: 0.8537 - dice_coef: 0.9178 - f1_score: 0.9182 - aggregated_jaccard_index: 0.8627 - val_val_loss: 0.0268 - val_val_accuracy: 0.9243 - val_val_iou_coef: 0.8861 - val_val_dice_coef: 0.9382 - val_val_f1_score: 0.9383 - val_val_aggregated_jaccard_index: 0.8873 - lr: 1.0000e-04
# Epoch 64/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0436 - accuracy: 0.9261 - iou_coef: 0.8527 - dice_coef: 0.9170 - f1_score: 0.9173 - aggregated_jaccard_index: 0.8617 - val_val_loss: 0.0266 - val_val_accuracy: 0.9220 - val_val_iou_coef: 0.8853 - val_val_dice_coef: 0.9376 - val_val_f1_score: 0.9379 - val_val_aggregated_jaccard_index: 0.8862 - lr: 1.0000e-04
# Epoch 65/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0427 - accuracy: 0.9268 - iou_coef: 0.8551 - dice_coef: 0.9186 - f1_score: 0.9190 - aggregated_jaccard_index: 0.8632 - val_val_loss: 0.0256 - val_val_accuracy: 0.9189 - val_val_iou_coef: 0.8790 - val_val_dice_coef: 0.9330 - val_val_f1_score: 0.9332 - val_val_aggregated_jaccard_index: 0.8800 - lr: 1.0000e-04
# Epoch 66/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0417 - accuracy: 0.9272 - iou_coef: 0.8554 - dice_coef: 0.9188 - f1_score: 0.9192 - aggregated_jaccard_index: 0.8644 - val_val_loss: 0.0256 - val_val_accuracy: 0.9220 - val_val_iou_coef: 0.8838 - val_val_dice_coef: 0.9367 - val_val_f1_score: 0.9368 - val_val_aggregated_jaccard_index: 0.8847 - lr: 1.0000e-04
# Epoch 67/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0416 - accuracy: 0.9267 - iou_coef: 0.8546 - dice_coef: 0.9184 - f1_score: 0.9188 - aggregated_jaccard_index: 0.8632 - val_val_loss: 0.0250 - val_val_accuracy: 0.9280 - val_val_iou_coef: 0.8895 - val_val_dice_coef: 0.9405 - val_val_f1_score: 0.9407 - val_val_aggregated_jaccard_index: 0.8906 - lr: 1.0000e-04
# Epoch 68/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0413 - accuracy: 0.9263 - iou_coef: 0.8529 - dice_coef: 0.9169 - f1_score: 0.9173 - aggregated_jaccard_index: 0.8627
# ✅ Saved improved backbone at epoch 68 with val_iou=0.8924
# 171/171 [==============================] - 15s 89ms/step - loss: 0.0413 - accuracy: 0.9263 - iou_coef: 0.8529 - dice_coef: 0.9169 - f1_score: 0.9173 - aggregated_jaccard_index: 0.8627 - val_val_loss: 0.0247 - val_val_accuracy: 0.9284 - val_val_iou_coef: 0.8924 - val_val_dice_coef: 0.9422 - val_val_f1_score: 0.9424 - val_val_aggregated_jaccard_index: 0.8938 - lr: 1.0000e-04
# Epoch 69/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0407 - accuracy: 0.9269 - iou_coef: 0.8541 - dice_coef: 0.9179 - f1_score: 0.9183 - aggregated_jaccard_index: 0.8627 - val_val_loss: 0.0238 - val_val_accuracy: 0.9280 - val_val_iou_coef: 0.8908 - val_val_dice_coef: 0.9415 - val_val_f1_score: 0.9416 - val_val_aggregated_jaccard_index: 0.8921 - lr: 1.0000e-04
# Epoch 70/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0391 - accuracy: 0.9276 - iou_coef: 0.8563 - dice_coef: 0.9194 - f1_score: 0.9198 - aggregated_jaccard_index: 0.8656 - val_val_loss: 0.0246 - val_val_accuracy: 0.9238 - val_val_iou_coef: 0.8843 - val_val_dice_coef: 0.9373 - val_val_f1_score: 0.9375 - val_val_aggregated_jaccard_index: 0.8856 - lr: 1.0000e-04
# Epoch 71/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0395 - accuracy: 0.9268 - iou_coef: 0.8538 - dice_coef: 0.9177 - f1_score: 0.9181 - aggregated_jaccard_index: 0.8629 - val_val_loss: 0.0236 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.8866 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8874 - lr: 1.0000e-04
# Epoch 72/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0379 - accuracy: 0.9285 - iou_coef: 0.8578 - dice_coef: 0.9203 - f1_score: 0.9206 - aggregated_jaccard_index: 0.8668 - val_val_loss: 0.0236 - val_val_accuracy: 0.9260 - val_val_iou_coef: 0.8890 - val_val_dice_coef: 0.9403 - val_val_f1_score: 0.9404 - val_val_aggregated_jaccard_index: 0.8901 - lr: 1.0000e-04
# Epoch 73/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0383 - accuracy: 0.9276 - iou_coef: 0.8565 - dice_coef: 0.9194 - f1_score: 0.9198 - aggregated_jaccard_index: 0.8646 - val_val_loss: 0.0232 - val_val_accuracy: 0.9234 - val_val_iou_coef: 0.8863 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9385 - val_val_aggregated_jaccard_index: 0.8867 - lr: 1.0000e-04
# Epoch 74/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0380 - accuracy: 0.9269 - iou_coef: 0.8543 - dice_coef: 0.9180 - f1_score: 0.9184 - aggregated_jaccard_index: 0.8629 - val_val_loss: 0.0227 - val_val_accuracy: 0.9217 - val_val_iou_coef: 0.8865 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8876 - lr: 1.0000e-04
# Epoch 75/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0370 - accuracy: 0.9279 - iou_coef: 0.8562 - dice_coef: 0.9193 - f1_score: 0.9197 - aggregated_jaccard_index: 0.8646 - val_val_loss: 0.0220 - val_val_accuracy: 0.9256 - val_val_iou_coef: 0.8898 - val_val_dice_coef: 0.9408 - val_val_f1_score: 0.9410 - val_val_aggregated_jaccard_index: 0.8911 - lr: 1.0000e-04
# Epoch 76/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0365 - accuracy: 0.9279 - iou_coef: 0.8562 - dice_coef: 0.9190 - f1_score: 0.9194 - aggregated_jaccard_index: 0.8650 - val_val_loss: 0.0218 - val_val_accuracy: 0.9260 - val_val_iou_coef: 0.8882 - val_val_dice_coef: 0.9396 - val_val_f1_score: 0.9398 - val_val_aggregated_jaccard_index: 0.8887 - lr: 1.0000e-04
# Epoch 77/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0352 - accuracy: 0.9290 - iou_coef: 0.8581 - dice_coef: 0.9204 - f1_score: 0.9208 - aggregated_jaccard_index: 0.8678 - val_val_loss: 0.0216 - val_val_accuracy: 0.9195 - val_val_iou_coef: 0.8827 - val_val_dice_coef: 0.9353 - val_val_f1_score: 0.9354 - val_val_aggregated_jaccard_index: 0.8833 - lr: 1.0000e-04
# Epoch 78/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9292 - iou_coef: 0.8588 - dice_coef: 0.9208 - f1_score: 0.9211 - aggregated_jaccard_index: 0.8673
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 171/171 [==============================] - 15s 89ms/step - loss: 0.0349 - accuracy: 0.9292 - iou_coef: 0.8588 - dice_coef: 0.9208 - f1_score: 0.9211 - aggregated_jaccard_index: 0.8673 - val_val_loss: 0.0216 - val_val_accuracy: 0.9231 - val_val_iou_coef: 0.8860 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9382 - val_val_aggregated_jaccard_index: 0.8871 - lr: 1.0000e-04
# Epoch 79/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0344 - accuracy: 0.9298 - iou_coef: 0.8598 - dice_coef: 0.9215 - f1_score: 0.9219 - aggregated_jaccard_index: 0.8681 - val_val_loss: 0.0211 - val_val_accuracy: 0.9221 - val_val_iou_coef: 0.8848 - val_val_dice_coef: 0.9372 - val_val_f1_score: 0.9374 - val_val_aggregated_jaccard_index: 0.8856 - lr: 1.0000e-05
# Epoch 80/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0344 - accuracy: 0.9298 - iou_coef: 0.8607 - dice_coef: 0.9221 - f1_score: 0.9224 - aggregated_jaccard_index: 0.8684 - val_val_loss: 0.0211 - val_val_accuracy: 0.9232 - val_val_iou_coef: 0.8859 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9381 - val_val_aggregated_jaccard_index: 0.8867 - lr: 1.0000e-05
# Epoch 81/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0342 - accuracy: 0.9294 - iou_coef: 0.8594 - dice_coef: 0.9213 - f1_score: 0.9216 - aggregated_jaccard_index: 0.8683 - val_val_loss: 0.0212 - val_val_accuracy: 0.9227 - val_val_iou_coef: 0.8850 - val_val_dice_coef: 0.9374 - val_val_f1_score: 0.9375 - val_val_aggregated_jaccard_index: 0.8857 - lr: 1.0000e-05
# Epoch 82/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0342 - accuracy: 0.9299 - iou_coef: 0.8604 - dice_coef: 0.9218 - f1_score: 0.9222 - aggregated_jaccard_index: 0.8678 - val_val_loss: 0.0210 - val_val_accuracy: 0.9234 - val_val_iou_coef: 0.8860 - val_val_dice_coef: 0.9381 - val_val_f1_score: 0.9383 - val_val_aggregated_jaccard_index: 0.8865 - lr: 1.0000e-05
# Epoch 83/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0335 - accuracy: 0.9305 - iou_coef: 0.8613 - dice_coef: 0.9224 - f1_score: 0.9228 - aggregated_jaccard_index: 0.8703 - val_val_loss: 0.0211 - val_val_accuracy: 0.9224 - val_val_iou_coef: 0.8846 - val_val_dice_coef: 0.9372 - val_val_f1_score: 0.9374 - val_val_aggregated_jaccard_index: 0.8851 - lr: 1.0000e-05
# Epoch 84/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0335 - accuracy: 0.9309 - iou_coef: 0.8618 - dice_coef: 0.9228 - f1_score: 0.9232 - aggregated_jaccard_index: 0.8704 - val_val_loss: 0.0210 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.8877 - val_val_dice_coef: 0.9393 - val_val_f1_score: 0.9395 - val_val_aggregated_jaccard_index: 0.8884 - lr: 1.0000e-05
# Epoch 85/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0335 - accuracy: 0.9305 - iou_coef: 0.8612 - dice_coef: 0.9223 - f1_score: 0.9226 - aggregated_jaccard_index: 0.8705 - val_val_loss: 0.0210 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.8864 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8871 - lr: 1.0000e-05
# Epoch 86/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0338 - accuracy: 0.9303 - iou_coef: 0.8607 - dice_coef: 0.9219 - f1_score: 0.9223 - aggregated_jaccard_index: 0.8693 - val_val_loss: 0.0210 - val_val_accuracy: 0.9238 - val_val_iou_coef: 0.8865 - val_val_dice_coef: 0.9384 - val_val_f1_score: 0.9385 - val_val_aggregated_jaccard_index: 0.8871 - lr: 1.0000e-05
# Epoch 87/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0336 - accuracy: 0.9304 - iou_coef: 0.8607 - dice_coef: 0.9220 - f1_score: 0.9223 - aggregated_jaccard_index: 0.8699 - val_val_loss: 0.0209 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8878 - val_val_dice_coef: 0.9394 - val_val_f1_score: 0.9395 - val_val_aggregated_jaccard_index: 0.8885 - lr: 1.0000e-05
# Epoch 88/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9297 - iou_coef: 0.8596 - dice_coef: 0.9214 - f1_score: 0.9217 - aggregated_jaccard_index: 0.8680
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0340 - accuracy: 0.9297 - iou_coef: 0.8596 - dice_coef: 0.9214 - f1_score: 0.9217 - aggregated_jaccard_index: 0.8680 - val_val_loss: 0.0209 - val_val_accuracy: 0.9261 - val_val_iou_coef: 0.8893 - val_val_dice_coef: 0.9404 - val_val_f1_score: 0.9407 - val_val_aggregated_jaccard_index: 0.8900 - lr: 1.0000e-05
# Epoch 89/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0334 - accuracy: 0.9306 - iou_coef: 0.8616 - dice_coef: 0.9227 - f1_score: 0.9230 - aggregated_jaccard_index: 0.8697 - val_val_loss: 0.0208 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.8871 - val_val_dice_coef: 0.9389 - val_val_f1_score: 0.9391 - val_val_aggregated_jaccard_index: 0.8879 - lr: 1.0000e-05
# Epoch 90/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0339 - accuracy: 0.9297 - iou_coef: 0.8598 - dice_coef: 0.9215 - f1_score: 0.9219 - aggregated_jaccard_index: 0.8678 - val_val_loss: 0.0208 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.8870 - val_val_dice_coef: 0.9388 - val_val_f1_score: 0.9390 - val_val_aggregated_jaccard_index: 0.8877 - lr: 1.0000e-05
# Epoch 91/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0333 - accuracy: 0.9308 - iou_coef: 0.8613 - dice_coef: 0.9224 - f1_score: 0.9227 - aggregated_jaccard_index: 0.8697 - val_val_loss: 0.0209 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8878 - val_val_dice_coef: 0.9394 - val_val_f1_score: 0.9395 - val_val_aggregated_jaccard_index: 0.8885 - lr: 1.0000e-05
# Epoch 92/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0333 - accuracy: 0.9303 - iou_coef: 0.8608 - dice_coef: 0.9222 - f1_score: 0.9225 - aggregated_jaccard_index: 0.8696 - val_val_loss: 0.0208 - val_val_accuracy: 0.9245 - val_val_iou_coef: 0.8869 - val_val_dice_coef: 0.9387 - val_val_f1_score: 0.9389 - val_val_aggregated_jaccard_index: 0.8876 - lr: 1.0000e-05
# Epoch 93/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0330 - accuracy: 0.9311 - iou_coef: 0.8621 - dice_coef: 0.9227 - f1_score: 0.9230 - aggregated_jaccard_index: 0.8709 - val_val_loss: 0.0208 - val_val_accuracy: 0.9260 - val_val_iou_coef: 0.8889 - val_val_dice_coef: 0.9401 - val_val_f1_score: 0.9403 - val_val_aggregated_jaccard_index: 0.8897 - lr: 1.0000e-05
# Epoch 94/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0331 - accuracy: 0.9306 - iou_coef: 0.8613 - dice_coef: 0.9225 - f1_score: 0.9228 - aggregated_jaccard_index: 0.8699 - val_val_loss: 0.0207 - val_val_accuracy: 0.9268 - val_val_iou_coef: 0.8898 - val_val_dice_coef: 0.9408 - val_val_f1_score: 0.9410 - val_val_aggregated_jaccard_index: 0.8907 - lr: 1.0000e-05
# Epoch 95/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0334 - accuracy: 0.9301 - iou_coef: 0.8603 - dice_coef: 0.9217 - f1_score: 0.9221 - aggregated_jaccard_index: 0.8687 - val_val_loss: 0.0207 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.8868 - val_val_dice_coef: 0.9387 - val_val_f1_score: 0.9388 - val_val_aggregated_jaccard_index: 0.8875 - lr: 1.0000e-05
# Epoch 96/150
# 171/171 [==============================] - 15s 87ms/step - loss: 0.0329 - accuracy: 0.9308 - iou_coef: 0.8622 - dice_coef: 0.9230 - f1_score: 0.9233 - aggregated_jaccard_index: 0.8706 - val_val_loss: 0.0207 - val_val_accuracy: 0.9251 - val_val_iou_coef: 0.8877 - val_val_dice_coef: 0.9395 - val_val_f1_score: 0.9397 - val_val_aggregated_jaccard_index: 0.8885 - lr: 1.0000e-05
# Epoch 97/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0328 - accuracy: 0.9312 - iou_coef: 0.8623 - dice_coef: 0.9230 - f1_score: 0.9234 - aggregated_jaccard_index: 0.8707 - val_val_loss: 0.0206 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.8875 - val_val_dice_coef: 0.9391 - val_val_f1_score: 0.9392 - val_val_aggregated_jaccard_index: 0.8883 - lr: 1.0000e-05
# Epoch 98/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0331 - accuracy: 0.9306 - iou_coef: 0.8608 - dice_coef: 0.9221 - f1_score: 0.9224 - aggregated_jaccard_index: 0.8697 - val_val_loss: 0.0207 - val_val_accuracy: 0.9247 - val_val_iou_coef: 0.8874 - val_val_dice_coef: 0.9391 - val_val_f1_score: 0.9392 - val_val_aggregated_jaccard_index: 0.8879 - lr: 1.0000e-05
# Epoch 99/150
# 171/171 [==============================] - 15s 89ms/step - loss: 0.0329 - accuracy: 0.9309 - iou_coef: 0.8623 - dice_coef: 0.9230 - f1_score: 0.9234 - aggregated_jaccard_index: 0.8701 - val_val_loss: 0.0206 - val_val_accuracy: 0.9256 - val_val_iou_coef: 0.8885 - val_val_dice_coef: 0.9399 - val_val_f1_score: 0.9400 - val_val_aggregated_jaccard_index: 0.8892 - lr: 1.0000e-05
# Epoch 100/150
# 171/171 [==============================] - 12s 70ms/step - loss: 0.0325 - accuracy: 0.9308 - iou_coef: 0.8618 - dice_coef: 0.9227 - f1_score: 0.9230 - aggregated_jaccard_index: 0.8708 - val_val_loss: 0.0206 - val_val_accuracy: 0.9269 - val_val_iou_coef: 0.8900 - val_val_dice_coef: 0.9408 - val_val_f1_score: 0.9409 - val_val_aggregated_jaccard_index: 0.8909 - lr: 1.0000e-05
# Epoch 101/150
# 171/171 [==============================] - 12s 71ms/step - loss: 0.0332 - accuracy: 0.9297 - iou_coef: 0.8597 - dice_coef: 0.9213 - f1_score: 0.9216 - aggregated_jaccard_index: 0.8684 - val_val_loss: 0.0205 - val_val_accuracy: 0.9252 - val_val_iou_coef: 0.8876 - val_val_dice_coef: 0.9392 - val_val_f1_score: 0.9394 - val_val_aggregated_jaccard_index: 0.8883 - lr: 1.0000e-05
# Epoch 102/150
# 171/171 [==============================] - 15s 88ms/step - loss: 0.0326 - accuracy: 0.9308 - iou_coef: 0.8621 - dice_coef: 0.9230 - f1_score: 0.9233 - aggregated_jaccard_index: 0.8704 - val_val_loss: 0.0204 - val_val_accuracy: 0.9271 - val_val_iou_coef: 0.8902 - val_val_dice_coef: 0.9410 - val_val_f1_score: 0.9413 - val_val_aggregated_jaccard_index: 0.8910 - lr: 1.0000e-05
# Epoch 103/150
# 171/171 [==============================] - 12s 72ms/step - loss: 0.0323 - accuracy: 0.9316 - iou_coef: 0.8631 - dice_coef: 0.9236 - f1_score: 0.9239 - aggregated_jaccard_index: 0.8714 - val_val_loss: 0.0204 - val_val_accuracy: 0.9266 - val_val_iou_coef: 0.8895 - val_val_dice_coef: 0.9405 - val_val_f1_score: 0.9406 - val_val_aggregated_jaccard_index: 0.8904 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image
# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size = 256
batch_size = 72

# -----------------------------
# NORMALIZE FILENAMES (ONCE)
# -----------------------------
def lowercase_filenames(dir_path):
    for p in glob(os.path.join(dir_path, "*")):
        base = os.path.basename(p)
        lower = base.lower()
        if base != lower:
            os.rename(p, os.path.join(dir_path, lower))

lowercase_filenames(IMG_DIR)
lowercase_filenames(MSK_DIR)

# -----------------------------
# COLLECT PATHS
# -----------------------------
def valid_name(p):
    return "zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)
mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# KEY-BASED ALIGNMENT (SOURCE OF TRUTH)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

img_map = {stem(p): p for p in image_paths}
msk_map = {stem(p): p for p in mask_paths}

common_keys = sorted(img_map.keys() & msk_map.keys())
assert len(common_keys) > 0, "No aligned image–mask pairs found"

image_paths = [img_map[k] for k in common_keys]
mask_paths  = [msk_map[k] for k in common_keys]

print("Aligned pairs:", len(common_keys))

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )
    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.asarray(img, dtype=np.float32) / 255.0
    mask = (np.asarray(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)
# Out:
# Images found: 80
# Masks found : 80
# Aligned pairs: 80

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8087
# Mean Dice Coefficient: 0.8898
# Mean AJI:              0.8156
# Mean Accuracy:         0.8842
# Mean F1 Score:         0.8917
