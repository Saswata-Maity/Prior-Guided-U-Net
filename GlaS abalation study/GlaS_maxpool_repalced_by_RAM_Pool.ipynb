# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 06:36:23.121791: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 06:36:23.243694: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 06:36:23.243820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 06:36:23.263500: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 06:36:23.322627: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 06:36:24.493115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 06:36:27.003307: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.341334: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.341376: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = GeodesicDownsample2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = GeodesicDownsample2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = GeodesicDownsample2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = GeodesicDownsample2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 06:36:27.428911: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.428989: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.429008: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.605974: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.606014: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.606020: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 06:36:27.606031: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 06:36:27.606042: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 06:36:27.606093: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5811 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  geodesic_downsample2d (Geo  (None, 128, 128, 32)         32        ['activation[0][0]']
#  desicDownsample2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['geodesic_downsample2d[0][0]'
#                                                                     ]
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_1 (G  (None, 64, 64, 64)           64        ['activation_1[0][0]']
#  eodesicDownsample2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['geodesic_downsample2d_1[0][0
#                                                                     ]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_2 (G  (None, 32, 32, 128)          128       ['activation_2[0][0]']
#  eodesicDownsample2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['geodesic_downsample2d_2[0][0
#                                                                     ]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_3 (G  (None, 16, 16, 256)          256       ['activation_3[0][0]']
#  eodesicDownsample2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['geodesic_downsample2d_3[0][0
#                                                                     ]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['activation_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 32, 32, 256)          0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 64, 64, 128)          0         ['activation_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_1[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_2[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['activation[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 1)          33        ['add_3[0][0]']
#
# ==================================================================================================
# Total params: 2833098 (10.81 MB)
# Trainable params: 2830410 (10.80 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../GLAS_PREPARED_DATA/val/images/*.png") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tif") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 684
# Train masks: 684
# Val images: 9
# Val masks: 9
# 2026-09-20 06:36:36.005943: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 171
# Validation batches: 3

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-20 06:36:43.481309: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 06:36:48.561864: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 06:36:48.877988: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 06:36:51.747639: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2026-09-20 06:36:53.053334: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2026-09-20 06:36:56.824072: I external/local_xla/xla/service/service.cc:168] XLA service 0x794ee81332e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 06:36:56.824170: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 06:36:56.883923: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789886217.082202   16078 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - ETA: 0s - loss: 3.3459 - accuracy: 0.6519 - iou_coef: 0.4689 - dice_coef: 0.6206 - f1_score: 0.6249 - aggregated_jaccard_index: 0.4939
# ✅ Saved improved backbone at epoch 1 with val_iou=0.3906
# 171/171 [==============================] - 47s 124ms/step - loss: 3.3411 - accuracy: 0.6519 - iou_coef: 0.4689 - dice_coef: 0.6206 - f1_score: 0.6249 - aggregated_jaccard_index: 0.4939 - val_val_loss: 4.0615 - val_val_accuracy: 0.5847 - val_val_iou_coef: 0.3906 - val_val_dice_coef: 0.5501 - val_val_f1_score: 0.5463 - val_val_aggregated_jaccard_index: 0.3878 - lr: 0.0010
# Epoch 2/150
# 171/171 [==============================] - 21s 121ms/step - loss: 2.4043 - accuracy: 0.7453 - iou_coef: 0.5939 - dice_coef: 0.7318 - f1_score: 0.7354 - aggregated_jaccard_index: 0.6152 - val_val_loss: 6.0314 - val_val_accuracy: 0.6164 - val_val_iou_coef: 0.3034 - val_val_dice_coef: 0.4339 - val_val_f1_score: 0.4318 - val_val_aggregated_jaccard_index: 0.2983 - lr: 0.0010
# Epoch 3/150
# 171/171 [==============================] - ETA: 0s - loss: 2.1755 - accuracy: 0.7618 - iou_coef: 0.6192 - dice_coef: 0.7536 - f1_score: 0.7558 - aggregated_jaccard_index: 0.6384
# ✅ Saved improved backbone at epoch 3 with val_iou=0.7000
# 171/171 [==============================] - 21s 123ms/step - loss: 2.1741 - accuracy: 0.7618 - iou_coef: 0.6192 - dice_coef: 0.7536 - f1_score: 0.7558 - aggregated_jaccard_index: 0.6384 - val_val_loss: 1.1555 - val_val_accuracy: 0.7582 - val_val_iou_coef: 0.7000 - val_val_dice_coef: 0.8169 - val_val_f1_score: 0.8184 - val_val_aggregated_jaccard_index: 0.7017 - lr: 0.0010
# Epoch 4/150
# 171/171 [==============================] - 18s 106ms/step - loss: 1.9459 - accuracy: 0.7826 - iou_coef: 0.6477 - dice_coef: 0.7760 - f1_score: 0.7778 - aggregated_jaccard_index: 0.6652 - val_val_loss: 3.4107 - val_val_accuracy: 0.6734 - val_val_iou_coef: 0.4403 - val_val_dice_coef: 0.6060 - val_val_f1_score: 0.6054 - val_val_aggregated_jaccard_index: 0.4403 - lr: 0.0010
# Epoch 5/150
# 171/171 [==============================] - 21s 124ms/step - loss: 1.8162 - accuracy: 0.7910 - iou_coef: 0.6565 - dice_coef: 0.7828 - f1_score: 0.7843 - aggregated_jaccard_index: 0.6732 - val_val_loss: 2.3785 - val_val_accuracy: 0.7043 - val_val_iou_coef: 0.5208 - val_val_dice_coef: 0.6708 - val_val_f1_score: 0.6713 - val_val_aggregated_jaccard_index: 0.5177 - lr: 0.0010
# Epoch 6/150
# 171/171 [==============================] - 18s 106ms/step - loss: 1.6175 - accuracy: 0.8097 - iou_coef: 0.6797 - dice_coef: 0.8004 - f1_score: 0.8017 - aggregated_jaccard_index: 0.6949 - val_val_loss: 2.4177 - val_val_accuracy: 0.6854 - val_val_iou_coef: 0.4803 - val_val_dice_coef: 0.6314 - val_val_f1_score: 0.6306 - val_val_aggregated_jaccard_index: 0.4829 - lr: 0.0010
# Epoch 7/150
# 171/171 [==============================] - 21s 122ms/step - loss: 1.5253 - accuracy: 0.8146 - iou_coef: 0.6850 - dice_coef: 0.8045 - f1_score: 0.8057 - aggregated_jaccard_index: 0.6995 - val_val_loss: 3.4019 - val_val_accuracy: 0.6264 - val_val_iou_coef: 0.3599 - val_val_dice_coef: 0.5172 - val_val_f1_score: 0.5159 - val_val_aggregated_jaccard_index: 0.3591 - lr: 0.0010
# Epoch 8/150
# 171/171 [==============================] - ETA: 0s - loss: 1.4519 - accuracy: 0.8162 - iou_coef: 0.6880 - dice_coef: 0.8063 - f1_score: 0.8073 - aggregated_jaccard_index: 0.7031
# ✅ Saved improved backbone at epoch 8 with val_iou=0.7736
# 171/171 [==============================] - 18s 108ms/step - loss: 1.4508 - accuracy: 0.8162 - iou_coef: 0.6880 - dice_coef: 0.8063 - f1_score: 0.8073 - aggregated_jaccard_index: 0.7031 - val_val_loss: 0.8119 - val_val_accuracy: 0.8360 - val_val_iou_coef: 0.7736 - val_val_dice_coef: 0.8697 - val_val_f1_score: 0.8706 - val_val_aggregated_jaccard_index: 0.7737 - lr: 0.0010
# Epoch 9/150
# 171/171 [==============================] - 20s 119ms/step - loss: 1.3188 - accuracy: 0.8279 - iou_coef: 0.7006 - dice_coef: 0.8154 - f1_score: 0.8163 - aggregated_jaccard_index: 0.7145 - val_val_loss: 1.3568 - val_val_accuracy: 0.7117 - val_val_iou_coef: 0.6666 - val_val_dice_coef: 0.7952 - val_val_f1_score: 0.7950 - val_val_aggregated_jaccard_index: 0.6778 - lr: 0.0010
# Epoch 10/150
# 171/171 [==============================] - 23s 134ms/step - loss: 1.2653 - accuracy: 0.8267 - iou_coef: 0.7014 - dice_coef: 0.8167 - f1_score: 0.8176 - aggregated_jaccard_index: 0.7155 - val_val_loss: 3.5794 - val_val_accuracy: 0.6699 - val_val_iou_coef: 0.3873 - val_val_dice_coef: 0.5289 - val_val_f1_score: 0.5279 - val_val_aggregated_jaccard_index: 0.3859 - lr: 0.0010
# Epoch 11/150
# 171/171 [==============================] - 20s 118ms/step - loss: 1.1667 - accuracy: 0.8339 - iou_coef: 0.7091 - dice_coef: 0.8218 - f1_score: 0.8227 - aggregated_jaccard_index: 0.7225 - val_val_loss: 0.5451 - val_val_accuracy: 0.8423 - val_val_iou_coef: 0.7735 - val_val_dice_coef: 0.8616 - val_val_f1_score: 0.8622 - val_val_aggregated_jaccard_index: 0.7721 - lr: 0.0010
# Epoch 12/150
# 171/171 [==============================] - 23s 133ms/step - loss: 1.0740 - accuracy: 0.8402 - iou_coef: 0.7188 - dice_coef: 0.8291 - f1_score: 0.8298 - aggregated_jaccard_index: 0.7317 - val_val_loss: 1.9182 - val_val_accuracy: 0.7107 - val_val_iou_coef: 0.5080 - val_val_dice_coef: 0.6491 - val_val_f1_score: 0.6488 - val_val_aggregated_jaccard_index: 0.5106 - lr: 0.0010
# Epoch 13/150
# 171/171 [==============================] - 23s 132ms/step - loss: 1.0439 - accuracy: 0.8363 - iou_coef: 0.7145 - dice_coef: 0.8242 - f1_score: 0.8249 - aggregated_jaccard_index: 0.7272 - val_val_loss: 0.5705 - val_val_accuracy: 0.8259 - val_val_iou_coef: 0.7529 - val_val_dice_coef: 0.8509 - val_val_f1_score: 0.8516 - val_val_aggregated_jaccard_index: 0.7485 - lr: 0.0010
# Epoch 14/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.9547 - accuracy: 0.8426 - iou_coef: 0.7228 - dice_coef: 0.8311 - f1_score: 0.8318 - aggregated_jaccard_index: 0.7353 - val_val_loss: 1.4785 - val_val_accuracy: 0.6223 - val_val_iou_coef: 0.5995 - val_val_dice_coef: 0.7434 - val_val_f1_score: 0.7433 - val_val_aggregated_jaccard_index: 0.6176 - lr: 0.0010
# Epoch 15/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.8933 - accuracy: 0.8448 - iou_coef: 0.7256 - dice_coef: 0.8332 - f1_score: 0.8338 - aggregated_jaccard_index: 0.7381 - val_val_loss: 0.7517 - val_val_accuracy: 0.8122 - val_val_iou_coef: 0.7084 - val_val_dice_coef: 0.8138 - val_val_f1_score: 0.8141 - val_val_aggregated_jaccard_index: 0.7074 - lr: 0.0010
# Epoch 16/150
# 171/171 [==============================] - 19s 108ms/step - loss: 0.8223 - accuracy: 0.8486 - iou_coef: 0.7310 - dice_coef: 0.8365 - f1_score: 0.8372 - aggregated_jaccard_index: 0.7438 - val_val_loss: 0.7918 - val_val_accuracy: 0.7392 - val_val_iou_coef: 0.7073 - val_val_dice_coef: 0.8217 - val_val_f1_score: 0.8218 - val_val_aggregated_jaccard_index: 0.7231 - lr: 0.0010
# Epoch 17/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.7655 - accuracy: 0.8513 - iou_coef: 0.7350 - dice_coef: 0.8395 - f1_score: 0.8401 - aggregated_jaccard_index: 0.7487 - val_val_loss: 0.8618 - val_val_accuracy: 0.7196 - val_val_iou_coef: 0.5668 - val_val_dice_coef: 0.7011 - val_val_f1_score: 0.7015 - val_val_aggregated_jaccard_index: 0.5679 - lr: 0.0010
# Epoch 18/150
# 171/171 [==============================] - ETA: 0s - loss: 0.7152 - accuracy: 0.8519 - iou_coef: 0.7366 - dice_coef: 0.8408 - f1_score: 0.8414 - aggregated_jaccard_index: 0.7494
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 171/171 [==============================] - 24s 138ms/step - loss: 0.7155 - accuracy: 0.8519 - iou_coef: 0.7366 - dice_coef: 0.8408 - f1_score: 0.8414 - aggregated_jaccard_index: 0.7494 - val_val_loss: 0.9919 - val_val_accuracy: 0.6592 - val_val_iou_coef: 0.6316 - val_val_dice_coef: 0.7677 - val_val_f1_score: 0.7676 - val_val_aggregated_jaccard_index: 0.6492 - lr: 0.0010
# Epoch 19/150
# 171/171 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.8664 - iou_coef: 0.7573 - dice_coef: 0.8552 - f1_score: 0.8558 - aggregated_jaccard_index: 0.7698
# ✅ Saved improved backbone at epoch 19 with val_iou=0.8614
# 171/171 [==============================] - 22s 126ms/step - loss: 0.6322 - accuracy: 0.8664 - iou_coef: 0.7573 - dice_coef: 0.8552 - f1_score: 0.8558 - aggregated_jaccard_index: 0.7698 - val_val_loss: 0.2895 - val_val_accuracy: 0.9057 - val_val_iou_coef: 0.8614 - val_val_dice_coef: 0.9240 - val_val_f1_score: 0.9247 - val_val_aggregated_jaccard_index: 0.8605 - lr: 1.0000e-04
# Epoch 20/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.6226 - accuracy: 0.8685 - iou_coef: 0.7598 - dice_coef: 0.8565 - f1_score: 0.8571 - aggregated_jaccard_index: 0.7723 - val_val_loss: 0.2858 - val_val_accuracy: 0.9024 - val_val_iou_coef: 0.8605 - val_val_dice_coef: 0.9231 - val_val_f1_score: 0.9238 - val_val_aggregated_jaccard_index: 0.8591 - lr: 1.0000e-04
# Epoch 21/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.6122 - accuracy: 0.8693 - iou_coef: 0.7609 - dice_coef: 0.8575 - f1_score: 0.8581 - aggregated_jaccard_index: 0.7728 - val_val_loss: 0.2795 - val_val_accuracy: 0.8834 - val_val_iou_coef: 0.8370 - val_val_dice_coef: 0.9081 - val_val_f1_score: 0.9086 - val_val_aggregated_jaccard_index: 0.8358 - lr: 1.0000e-04
# Epoch 22/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.5972 - accuracy: 0.8717 - iou_coef: 0.7647 - dice_coef: 0.8602 - f1_score: 0.8608 - aggregated_jaccard_index: 0.7779 - val_val_loss: 0.2867 - val_val_accuracy: 0.9029 - val_val_iou_coef: 0.8603 - val_val_dice_coef: 0.9228 - val_val_f1_score: 0.9235 - val_val_aggregated_jaccard_index: 0.8590 - lr: 1.0000e-04
# Epoch 23/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.5961 - accuracy: 0.8716 - iou_coef: 0.7651 - dice_coef: 0.8605 - f1_score: 0.8612 - aggregated_jaccard_index: 0.7769 - val_val_loss: 0.2769 - val_val_accuracy: 0.8989 - val_val_iou_coef: 0.8538 - val_val_dice_coef: 0.9180 - val_val_f1_score: 0.9184 - val_val_aggregated_jaccard_index: 0.8519 - lr: 1.0000e-04
# Epoch 24/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5910 - accuracy: 0.8722 - iou_coef: 0.7655 - dice_coef: 0.8608 - f1_score: 0.8615 - aggregated_jaccard_index: 0.7776
# ✅ Saved improved backbone at epoch 24 with val_iou=0.8654
# 171/171 [==============================] - 24s 140ms/step - loss: 0.5937 - accuracy: 0.8722 - iou_coef: 0.7655 - dice_coef: 0.8608 - f1_score: 0.8615 - aggregated_jaccard_index: 0.7776 - val_val_loss: 0.2806 - val_val_accuracy: 0.9062 - val_val_iou_coef: 0.8654 - val_val_dice_coef: 0.9263 - val_val_f1_score: 0.9269 - val_val_aggregated_jaccard_index: 0.8643 - lr: 1.0000e-04
# Epoch 25/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.5927 - accuracy: 0.8707 - iou_coef: 0.7630 - dice_coef: 0.8586 - f1_score: 0.8593 - aggregated_jaccard_index: 0.7762 - val_val_loss: 0.2640 - val_val_accuracy: 0.8987 - val_val_iou_coef: 0.8593 - val_val_dice_coef: 0.9220 - val_val_f1_score: 0.9225 - val_val_aggregated_jaccard_index: 0.8579 - lr: 1.0000e-04
# Epoch 26/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.5751 - accuracy: 0.8736 - iou_coef: 0.7683 - dice_coef: 0.8625 - f1_score: 0.8631 - aggregated_jaccard_index: 0.7804 - val_val_loss: 0.2869 - val_val_accuracy: 0.8704 - val_val_iou_coef: 0.8199 - val_val_dice_coef: 0.8915 - val_val_f1_score: 0.8918 - val_val_aggregated_jaccard_index: 0.8156 - lr: 1.0000e-04
# Epoch 27/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.5650 - accuracy: 0.8757 - iou_coef: 0.7707 - dice_coef: 0.8642 - f1_score: 0.8649 - aggregated_jaccard_index: 0.7832 - val_val_loss: 0.2756 - val_val_accuracy: 0.8930 - val_val_iou_coef: 0.8438 - val_val_dice_coef: 0.9109 - val_val_f1_score: 0.9112 - val_val_aggregated_jaccard_index: 0.8420 - lr: 1.0000e-04
# Epoch 28/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.5590 - accuracy: 0.8756 - iou_coef: 0.7703 - dice_coef: 0.8639 - f1_score: 0.8646 - aggregated_jaccard_index: 0.7831 - val_val_loss: 0.2732 - val_val_accuracy: 0.8972 - val_val_iou_coef: 0.8494 - val_val_dice_coef: 0.9142 - val_val_f1_score: 0.9146 - val_val_aggregated_jaccard_index: 0.8479 - lr: 1.0000e-04
# Epoch 29/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.5550 - accuracy: 0.8760 - iou_coef: 0.7719 - dice_coef: 0.8653 - f1_score: 0.8660 - aggregated_jaccard_index: 0.7832 - val_val_loss: 0.2708 - val_val_accuracy: 0.8858 - val_val_iou_coef: 0.8499 - val_val_dice_coef: 0.9158 - val_val_f1_score: 0.9163 - val_val_aggregated_jaccard_index: 0.8483 - lr: 1.0000e-04
# Epoch 30/150
# 171/171 [==============================] - 22s 127ms/step - loss: 0.5586 - accuracy: 0.8746 - iou_coef: 0.7702 - dice_coef: 0.8641 - f1_score: 0.8648 - aggregated_jaccard_index: 0.7806 - val_val_loss: 0.2524 - val_val_accuracy: 0.8772 - val_val_iou_coef: 0.8315 - val_val_dice_coef: 0.9030 - val_val_f1_score: 0.9034 - val_val_aggregated_jaccard_index: 0.8288 - lr: 1.0000e-04
# Epoch 31/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.5525 - accuracy: 0.8754 - iou_coef: 0.7703 - dice_coef: 0.8641 - f1_score: 0.8648 - aggregated_jaccard_index: 0.7821 - val_val_loss: 0.2546 - val_val_accuracy: 0.8850 - val_val_iou_coef: 0.8311 - val_val_dice_coef: 0.9018 - val_val_f1_score: 0.9022 - val_val_aggregated_jaccard_index: 0.8312 - lr: 1.0000e-04
# Epoch 32/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.5321 - accuracy: 0.8787 - iou_coef: 0.7761 - dice_coef: 0.8681 - f1_score: 0.8688 - aggregated_jaccard_index: 0.7872 - val_val_loss: 0.2556 - val_val_accuracy: 0.8954 - val_val_iou_coef: 0.8579 - val_val_dice_coef: 0.9210 - val_val_f1_score: 0.9215 - val_val_aggregated_jaccard_index: 0.8568 - lr: 1.0000e-04
# Epoch 33/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.5339 - accuracy: 0.8774 - iou_coef: 0.7734 - dice_coef: 0.8663 - f1_score: 0.8670 - aggregated_jaccard_index: 0.7854 - val_val_loss: 0.2623 - val_val_accuracy: 0.8830 - val_val_iou_coef: 0.8405 - val_val_dice_coef: 0.9106 - val_val_f1_score: 0.9111 - val_val_aggregated_jaccard_index: 0.8391 - lr: 1.0000e-04
# Epoch 34/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.8802 - iou_coef: 0.7772 - dice_coef: 0.8685 - f1_score: 0.8692 - aggregated_jaccard_index: 0.7893
# ✅ Saved improved backbone at epoch 34 with val_iou=0.8657
# 171/171 [==============================] - 24s 139ms/step - loss: 0.5180 - accuracy: 0.8802 - iou_coef: 0.7772 - dice_coef: 0.8685 - f1_score: 0.8692 - aggregated_jaccard_index: 0.7893 - val_val_loss: 0.2454 - val_val_accuracy: 0.9048 - val_val_iou_coef: 0.8657 - val_val_dice_coef: 0.9264 - val_val_f1_score: 0.9268 - val_val_aggregated_jaccard_index: 0.8644 - lr: 1.0000e-04
# Epoch 35/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.5274 - accuracy: 0.8774 - iou_coef: 0.7738 - dice_coef: 0.8660 - f1_score: 0.8667 - aggregated_jaccard_index: 0.7851 - val_val_loss: 0.2503 - val_val_accuracy: 0.8872 - val_val_iou_coef: 0.8494 - val_val_dice_coef: 0.9162 - val_val_f1_score: 0.9167 - val_val_aggregated_jaccard_index: 0.8491 - lr: 1.0000e-04
# Epoch 36/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.5162 - accuracy: 0.8790 - iou_coef: 0.7758 - dice_coef: 0.8676 - f1_score: 0.8683 - aggregated_jaccard_index: 0.7880 - val_val_loss: 0.2880 - val_val_accuracy: 0.8487 - val_val_iou_coef: 0.8121 - val_val_dice_coef: 0.8932 - val_val_f1_score: 0.8936 - val_val_aggregated_jaccard_index: 0.8145 - lr: 1.0000e-04
# Epoch 37/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.5106 - accuracy: 0.8788 - iou_coef: 0.7763 - dice_coef: 0.8680 - f1_score: 0.8687 - aggregated_jaccard_index: 0.7885 - val_val_loss: 0.2340 - val_val_accuracy: 0.9003 - val_val_iou_coef: 0.8600 - val_val_dice_coef: 0.9217 - val_val_f1_score: 0.9222 - val_val_aggregated_jaccard_index: 0.8591 - lr: 1.0000e-04
# Epoch 38/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.5062 - accuracy: 0.8797 - iou_coef: 0.7763 - dice_coef: 0.8678 - f1_score: 0.8684 - aggregated_jaccard_index: 0.7889 - val_val_loss: 0.2330 - val_val_accuracy: 0.9015 - val_val_iou_coef: 0.8581 - val_val_dice_coef: 0.9202 - val_val_f1_score: 0.9205 - val_val_aggregated_jaccard_index: 0.8562 - lr: 1.0000e-04
# Epoch 39/150
# 171/171 [==============================] - ETA: 0s - loss: 0.4985 - accuracy: 0.8805 - iou_coef: 0.7781 - dice_coef: 0.8688 - f1_score: 0.8695 - aggregated_jaccard_index: 0.7898
# ✅ Saved improved backbone at epoch 39 with val_iou=0.8689
# 171/171 [==============================] - 21s 125ms/step - loss: 0.4996 - accuracy: 0.8805 - iou_coef: 0.7781 - dice_coef: 0.8688 - f1_score: 0.8695 - aggregated_jaccard_index: 0.7898 - val_val_loss: 0.2273 - val_val_accuracy: 0.9087 - val_val_iou_coef: 0.8689 - val_val_dice_coef: 0.9278 - val_val_f1_score: 0.9283 - val_val_aggregated_jaccard_index: 0.8681 - lr: 1.0000e-04
# Epoch 40/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.4875 - accuracy: 0.8815 - iou_coef: 0.7810 - dice_coef: 0.8711 - f1_score: 0.8717 - aggregated_jaccard_index: 0.7928 - val_val_loss: 0.2201 - val_val_accuracy: 0.9032 - val_val_iou_coef: 0.8629 - val_val_dice_coef: 0.9235 - val_val_f1_score: 0.9239 - val_val_aggregated_jaccard_index: 0.8618 - lr: 1.0000e-04
# Epoch 41/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.4866 - accuracy: 0.8809 - iou_coef: 0.7788 - dice_coef: 0.8694 - f1_score: 0.8700 - aggregated_jaccard_index: 0.7914 - val_val_loss: 0.2271 - val_val_accuracy: 0.9004 - val_val_iou_coef: 0.8572 - val_val_dice_coef: 0.9188 - val_val_f1_score: 0.9195 - val_val_aggregated_jaccard_index: 0.8555 - lr: 1.0000e-04
# Epoch 42/150
# 171/171 [==============================] - 21s 124ms/step - loss: 0.4851 - accuracy: 0.8806 - iou_coef: 0.7773 - dice_coef: 0.8682 - f1_score: 0.8688 - aggregated_jaccard_index: 0.7902 - val_val_loss: 0.2186 - val_val_accuracy: 0.9038 - val_val_iou_coef: 0.8656 - val_val_dice_coef: 0.9258 - val_val_f1_score: 0.9264 - val_val_aggregated_jaccard_index: 0.8646 - lr: 1.0000e-04
# Epoch 43/150
# 171/171 [==============================] - 25s 146ms/step - loss: 0.4725 - accuracy: 0.8828 - iou_coef: 0.7816 - dice_coef: 0.8716 - f1_score: 0.8722 - aggregated_jaccard_index: 0.7941 - val_val_loss: 0.2230 - val_val_accuracy: 0.8977 - val_val_iou_coef: 0.8564 - val_val_dice_coef: 0.9183 - val_val_f1_score: 0.9186 - val_val_aggregated_jaccard_index: 0.8552 - lr: 1.0000e-04
# Epoch 44/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.4747 - accuracy: 0.8819 - iou_coef: 0.7801 - dice_coef: 0.8701 - f1_score: 0.8707 - aggregated_jaccard_index: 0.7932 - val_val_loss: 0.2160 - val_val_accuracy: 0.8943 - val_val_iou_coef: 0.8482 - val_val_dice_coef: 0.9125 - val_val_f1_score: 0.9127 - val_val_aggregated_jaccard_index: 0.8463 - lr: 1.0000e-04
# Epoch 45/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.4662 - accuracy: 0.8832 - iou_coef: 0.7823 - dice_coef: 0.8717 - f1_score: 0.8723 - aggregated_jaccard_index: 0.7942 - val_val_loss: 0.2087 - val_val_accuracy: 0.9057 - val_val_iou_coef: 0.8647 - val_val_dice_coef: 0.9247 - val_val_f1_score: 0.9250 - val_val_aggregated_jaccard_index: 0.8641 - lr: 1.0000e-04
# Epoch 46/150
# 171/171 [==============================] - 21s 126ms/step - loss: 0.4560 - accuracy: 0.8846 - iou_coef: 0.7848 - dice_coef: 0.8736 - f1_score: 0.8742 - aggregated_jaccard_index: 0.7966 - val_val_loss: 0.2059 - val_val_accuracy: 0.9033 - val_val_iou_coef: 0.8638 - val_val_dice_coef: 0.9240 - val_val_f1_score: 0.9243 - val_val_aggregated_jaccard_index: 0.8638 - lr: 1.0000e-04
# Epoch 47/150
# 171/171 [==============================] - ETA: 0s - loss: 0.4471 - accuracy: 0.8856 - iou_coef: 0.7873 - dice_coef: 0.8751 - f1_score: 0.8756 - aggregated_jaccard_index: 0.7991
# ✅ Saved improved backbone at epoch 47 with val_iou=0.8707
# 171/171 [==============================] - 24s 141ms/step - loss: 0.4464 - accuracy: 0.8856 - iou_coef: 0.7873 - dice_coef: 0.8751 - f1_score: 0.8756 - aggregated_jaccard_index: 0.7991 - val_val_loss: 0.2051 - val_val_accuracy: 0.9078 - val_val_iou_coef: 0.8707 - val_val_dice_coef: 0.9293 - val_val_f1_score: 0.9298 - val_val_aggregated_jaccard_index: 0.8702 - lr: 1.0000e-04
# Epoch 48/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.4519 - accuracy: 0.8836 - iou_coef: 0.7821 - dice_coef: 0.8718 - f1_score: 0.8724 - aggregated_jaccard_index: 0.7947 - val_val_loss: 0.2056 - val_val_accuracy: 0.9008 - val_val_iou_coef: 0.8624 - val_val_dice_coef: 0.9237 - val_val_f1_score: 0.9241 - val_val_aggregated_jaccard_index: 0.8624 - lr: 1.0000e-04
# Epoch 49/150
# 171/171 [==============================] - 21s 120ms/step - loss: 0.4500 - accuracy: 0.8826 - iou_coef: 0.7831 - dice_coef: 0.8719 - f1_score: 0.8725 - aggregated_jaccard_index: 0.7947 - val_val_loss: 0.2221 - val_val_accuracy: 0.8971 - val_val_iou_coef: 0.8505 - val_val_dice_coef: 0.9147 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8493 - lr: 1.0000e-04
# Epoch 50/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.4399 - accuracy: 0.8849 - iou_coef: 0.7857 - dice_coef: 0.8742 - f1_score: 0.8748 - aggregated_jaccard_index: 0.7968 - val_val_loss: 0.2071 - val_val_accuracy: 0.8985 - val_val_iou_coef: 0.8602 - val_val_dice_coef: 0.9223 - val_val_f1_score: 0.9228 - val_val_aggregated_jaccard_index: 0.8596 - lr: 1.0000e-04
# Epoch 51/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.4352 - accuracy: 0.8854 - iou_coef: 0.7878 - dice_coef: 0.8754 - f1_score: 0.8759 - aggregated_jaccard_index: 0.7974 - val_val_loss: 0.2002 - val_val_accuracy: 0.9085 - val_val_iou_coef: 0.8677 - val_val_dice_coef: 0.9265 - val_val_f1_score: 0.9269 - val_val_aggregated_jaccard_index: 0.8677 - lr: 1.0000e-04
# Epoch 52/150
# 171/171 [==============================] - 22s 128ms/step - loss: 0.4374 - accuracy: 0.8832 - iou_coef: 0.7831 - dice_coef: 0.8718 - f1_score: 0.8723 - aggregated_jaccard_index: 0.7957 - val_val_loss: 0.2018 - val_val_accuracy: 0.8906 - val_val_iou_coef: 0.8469 - val_val_dice_coef: 0.9108 - val_val_f1_score: 0.9112 - val_val_aggregated_jaccard_index: 0.8439 - lr: 1.0000e-04
# Epoch 53/150
# 171/171 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8869 - iou_coef: 0.7885 - dice_coef: 0.8759 - f1_score: 0.8765 - aggregated_jaccard_index: 0.8001
# ✅ Saved improved backbone at epoch 53 with val_iou=0.8745
# 171/171 [==============================] - 24s 138ms/step - loss: 0.4220 - accuracy: 0.8869 - iou_coef: 0.7885 - dice_coef: 0.8759 - f1_score: 0.8765 - aggregated_jaccard_index: 0.8001 - val_val_loss: 0.1942 - val_val_accuracy: 0.9130 - val_val_iou_coef: 0.8745 - val_val_dice_coef: 0.9317 - val_val_f1_score: 0.9320 - val_val_aggregated_jaccard_index: 0.8748 - lr: 1.0000e-04
# Epoch 54/150
# 171/171 [==============================] - 20s 116ms/step - loss: 0.4268 - accuracy: 0.8851 - iou_coef: 0.7858 - dice_coef: 0.8741 - f1_score: 0.8747 - aggregated_jaccard_index: 0.7968 - val_val_loss: 0.1867 - val_val_accuracy: 0.8972 - val_val_iou_coef: 0.8536 - val_val_dice_coef: 0.9162 - val_val_f1_score: 0.9166 - val_val_aggregated_jaccard_index: 0.8529 - lr: 1.0000e-04
# Epoch 55/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.4115 - accuracy: 0.8873 - iou_coef: 0.7896 - dice_coef: 0.8767 - f1_score: 0.8773 - aggregated_jaccard_index: 0.8007 - val_val_loss: 0.1836 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.8677 - val_val_dice_coef: 0.9262 - val_val_f1_score: 0.9267 - val_val_aggregated_jaccard_index: 0.8672 - lr: 1.0000e-04
# Epoch 56/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.4119 - accuracy: 0.8864 - iou_coef: 0.7881 - dice_coef: 0.8754 - f1_score: 0.8759 - aggregated_jaccard_index: 0.7993 - val_val_loss: 0.1878 - val_val_accuracy: 0.9124 - val_val_iou_coef: 0.8744 - val_val_dice_coef: 0.9315 - val_val_f1_score: 0.9317 - val_val_aggregated_jaccard_index: 0.8747 - lr: 1.0000e-04
# Epoch 57/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.4044 - accuracy: 0.8880 - iou_coef: 0.7910 - dice_coef: 0.8779 - f1_score: 0.8784 - aggregated_jaccard_index: 0.8021 - val_val_loss: 0.1847 - val_val_accuracy: 0.9054 - val_val_iou_coef: 0.8665 - val_val_dice_coef: 0.9258 - val_val_f1_score: 0.9260 - val_val_aggregated_jaccard_index: 0.8664 - lr: 1.0000e-04
# Epoch 58/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.3963 - accuracy: 0.8890 - iou_coef: 0.7927 - dice_coef: 0.8790 - f1_score: 0.8795 - aggregated_jaccard_index: 0.8037 - val_val_loss: 0.1794 - val_val_accuracy: 0.8978 - val_val_iou_coef: 0.8536 - val_val_dice_coef: 0.9158 - val_val_f1_score: 0.9162 - val_val_aggregated_jaccard_index: 0.8526 - lr: 1.0000e-04
# Epoch 59/150
# 171/171 [==============================] - 18s 107ms/step - loss: 0.3956 - accuracy: 0.8887 - iou_coef: 0.7910 - dice_coef: 0.8777 - f1_score: 0.8783 - aggregated_jaccard_index: 0.8034 - val_val_loss: 0.1901 - val_val_accuracy: 0.8837 - val_val_iou_coef: 0.8341 - val_val_dice_coef: 0.8996 - val_val_f1_score: 0.8999 - val_val_aggregated_jaccard_index: 0.8324 - lr: 1.0000e-04
# Epoch 60/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3920 - accuracy: 0.8887 - iou_coef: 0.7917 - dice_coef: 0.8779 - f1_score: 0.8785 - aggregated_jaccard_index: 0.8033 - val_val_loss: 0.1813 - val_val_accuracy: 0.9111 - val_val_iou_coef: 0.8721 - val_val_dice_coef: 0.9297 - val_val_f1_score: 0.9300 - val_val_aggregated_jaccard_index: 0.8724 - lr: 1.0000e-04
# Epoch 61/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.3909 - accuracy: 0.8884 - iou_coef: 0.7910 - dice_coef: 0.8774 - f1_score: 0.8779 - aggregated_jaccard_index: 0.8015 - val_val_loss: 0.1742 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.8666 - val_val_dice_coef: 0.9254 - val_val_f1_score: 0.9256 - val_val_aggregated_jaccard_index: 0.8663 - lr: 1.0000e-04
# Epoch 62/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.3905 - accuracy: 0.8873 - iou_coef: 0.7898 - dice_coef: 0.8768 - f1_score: 0.8774 - aggregated_jaccard_index: 0.8007 - val_val_loss: 0.1845 - val_val_accuracy: 0.8934 - val_val_iou_coef: 0.8561 - val_val_dice_coef: 0.9198 - val_val_f1_score: 0.9201 - val_val_aggregated_jaccard_index: 0.8568 - lr: 1.0000e-04
# Epoch 63/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3787 - accuracy: 0.8900 - iou_coef: 0.7929 - dice_coef: 0.8788 - f1_score: 0.8793 - aggregated_jaccard_index: 0.8049
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 171/171 [==============================] - 21s 122ms/step - loss: 0.3782 - accuracy: 0.8900 - iou_coef: 0.7929 - dice_coef: 0.8788 - f1_score: 0.8793 - aggregated_jaccard_index: 0.8049 - val_val_loss: 0.1691 - val_val_accuracy: 0.8921 - val_val_iou_coef: 0.8451 - val_val_dice_coef: 0.9108 - val_val_f1_score: 0.9111 - val_val_aggregated_jaccard_index: 0.8455 - lr: 1.0000e-04
# Epoch 64/150
# 171/171 [==============================] - 18s 108ms/step - loss: 0.3783 - accuracy: 0.8889 - iou_coef: 0.7921 - dice_coef: 0.8780 - f1_score: 0.8785 - aggregated_jaccard_index: 0.8025 - val_val_loss: 0.1686 - val_val_accuracy: 0.9116 - val_val_iou_coef: 0.8725 - val_val_dice_coef: 0.9295 - val_val_f1_score: 0.9299 - val_val_aggregated_jaccard_index: 0.8728 - lr: 1.0000e-05
# Epoch 65/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.3697 - accuracy: 0.8921 - iou_coef: 0.7976 - dice_coef: 0.8821 - f1_score: 0.8827 - aggregated_jaccard_index: 0.8079 - val_val_loss: 0.1676 - val_val_accuracy: 0.9122 - val_val_iou_coef: 0.8724 - val_val_dice_coef: 0.9293 - val_val_f1_score: 0.9296 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 66/150
# 171/171 [==============================] - 19s 109ms/step - loss: 0.3691 - accuracy: 0.8921 - iou_coef: 0.7961 - dice_coef: 0.8810 - f1_score: 0.8815 - aggregated_jaccard_index: 0.8078 - val_val_loss: 0.1675 - val_val_accuracy: 0.9094 - val_val_iou_coef: 0.8689 - val_val_dice_coef: 0.9267 - val_val_f1_score: 0.9271 - val_val_aggregated_jaccard_index: 0.8689 - lr: 1.0000e-05
# Epoch 67/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3734 - accuracy: 0.8908 - iou_coef: 0.7949 - dice_coef: 0.8799 - f1_score: 0.8804 - aggregated_jaccard_index: 0.8060 - val_val_loss: 0.1675 - val_val_accuracy: 0.9125 - val_val_iou_coef: 0.8729 - val_val_dice_coef: 0.9296 - val_val_f1_score: 0.9299 - val_val_aggregated_jaccard_index: 0.8732 - lr: 1.0000e-05
# Epoch 68/150
# 171/171 [==============================] - 23s 132ms/step - loss: 0.3695 - accuracy: 0.8919 - iou_coef: 0.7965 - dice_coef: 0.8808 - f1_score: 0.8813 - aggregated_jaccard_index: 0.8084 - val_val_loss: 0.1677 - val_val_accuracy: 0.9113 - val_val_iou_coef: 0.8715 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9290 - val_val_aggregated_jaccard_index: 0.8716 - lr: 1.0000e-05
# Epoch 69/150
# 171/171 [==============================] - 19s 110ms/step - loss: 0.3687 - accuracy: 0.8924 - iou_coef: 0.7976 - dice_coef: 0.8818 - f1_score: 0.8823 - aggregated_jaccard_index: 0.8080 - val_val_loss: 0.1677 - val_val_accuracy: 0.9123 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9304 - val_val_aggregated_jaccard_index: 0.8737 - lr: 1.0000e-05
# Epoch 70/150
# 171/171 [==============================] - 20s 119ms/step - loss: 0.3669 - accuracy: 0.8915 - iou_coef: 0.7961 - dice_coef: 0.8810 - f1_score: 0.8816 - aggregated_jaccard_index: 0.8082 - val_val_loss: 0.1663 - val_val_accuracy: 0.9114 - val_val_iou_coef: 0.8713 - val_val_dice_coef: 0.9284 - val_val_f1_score: 0.9288 - val_val_aggregated_jaccard_index: 0.8716 - lr: 1.0000e-05
# Epoch 71/150
# 171/171 [==============================] - 19s 110ms/step - loss: 0.3686 - accuracy: 0.8917 - iou_coef: 0.7969 - dice_coef: 0.8812 - f1_score: 0.8817 - aggregated_jaccard_index: 0.8076 - val_val_loss: 0.1661 - val_val_accuracy: 0.9112 - val_val_iou_coef: 0.8711 - val_val_dice_coef: 0.9283 - val_val_f1_score: 0.9286 - val_val_aggregated_jaccard_index: 0.8713 - lr: 1.0000e-05
# Epoch 72/150
# 171/171 [==============================] - 24s 137ms/step - loss: 0.3605 - accuracy: 0.8937 - iou_coef: 0.8000 - dice_coef: 0.8835 - f1_score: 0.8841 - aggregated_jaccard_index: 0.8123 - val_val_loss: 0.1662 - val_val_accuracy: 0.9127 - val_val_iou_coef: 0.8742 - val_val_dice_coef: 0.9306 - val_val_f1_score: 0.9309 - val_val_aggregated_jaccard_index: 0.8745 - lr: 1.0000e-05
# Epoch 73/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3663 - accuracy: 0.8926 - iou_coef: 0.7979 - dice_coef: 0.8822 - f1_score: 0.8828 - aggregated_jaccard_index: 0.8083
# Epoch 73: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3678 - accuracy: 0.8926 - iou_coef: 0.7979 - dice_coef: 0.8822 - f1_score: 0.8828 - aggregated_jaccard_index: 0.8083 - val_val_loss: 0.1659 - val_val_accuracy: 0.9123 - val_val_iou_coef: 0.8724 - val_val_dice_coef: 0.9292 - val_val_f1_score: 0.9296 - val_val_aggregated_jaccard_index: 0.8727 - lr: 1.0000e-05
# Epoch 74/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3740 - accuracy: 0.8900 - iou_coef: 0.7932 - dice_coef: 0.8786 - f1_score: 0.8792 - aggregated_jaccard_index: 0.8053 - val_val_loss: 0.1654 - val_val_accuracy: 0.9133 - val_val_iou_coef: 0.8739 - val_val_dice_coef: 0.9303 - val_val_f1_score: 0.9306 - val_val_aggregated_jaccard_index: 0.8742 - lr: 1.0000e-05
# Epoch 75/150
# 171/171 [==============================] - 21s 126ms/step - loss: 0.3706 - accuracy: 0.8907 - iou_coef: 0.7954 - dice_coef: 0.8805 - f1_score: 0.8810 - aggregated_jaccard_index: 0.8063 - val_val_loss: 0.1659 - val_val_accuracy: 0.9120 - val_val_iou_coef: 0.8735 - val_val_dice_coef: 0.9302 - val_val_f1_score: 0.9305 - val_val_aggregated_jaccard_index: 0.8739 - lr: 1.0000e-05
# Epoch 76/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3679 - accuracy: 0.8915 - iou_coef: 0.7965 - dice_coef: 0.8810 - f1_score: 0.8815 - aggregated_jaccard_index: 0.8077 - val_val_loss: 0.1658 - val_val_accuracy: 0.9123 - val_val_iou_coef: 0.8738 - val_val_dice_coef: 0.9304 - val_val_f1_score: 0.9308 - val_val_aggregated_jaccard_index: 0.8742 - lr: 1.0000e-05
# Epoch 77/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3614 - accuracy: 0.8930 - iou_coef: 0.7979 - dice_coef: 0.8820 - f1_score: 0.8825 - aggregated_jaccard_index: 0.8098 - val_val_loss: 0.1665 - val_val_accuracy: 0.9125 - val_val_iou_coef: 0.8722 - val_val_dice_coef: 0.9290 - val_val_f1_score: 0.9293 - val_val_aggregated_jaccard_index: 0.8724 - lr: 1.0000e-05
# Epoch 78/150
# 171/171 [==============================] - 23s 135ms/step - loss: 0.3628 - accuracy: 0.8928 - iou_coef: 0.7986 - dice_coef: 0.8825 - f1_score: 0.8831 - aggregated_jaccard_index: 0.8095 - val_val_loss: 0.1647 - val_val_accuracy: 0.9126 - val_val_iou_coef: 0.8729 - val_val_dice_coef: 0.9295 - val_val_f1_score: 0.9298 - val_val_aggregated_jaccard_index: 0.8731 - lr: 1.0000e-05
# Epoch 79/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.3659 - accuracy: 0.8916 - iou_coef: 0.7973 - dice_coef: 0.8816 - f1_score: 0.8821 - aggregated_jaccard_index: 0.8076 - val_val_loss: 0.1646 - val_val_accuracy: 0.9135 - val_val_iou_coef: 0.8741 - val_val_dice_coef: 0.9304 - val_val_f1_score: 0.9308 - val_val_aggregated_jaccard_index: 0.8744 - lr: 1.0000e-05
# Epoch 80/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8926 - iou_coef: 0.7983 - dice_coef: 0.8823 - f1_score: 0.8829 - aggregated_jaccard_index: 0.8092
# ✅ Saved improved backbone at epoch 80 with val_iou=0.8766
# 171/171 [==============================] - 22s 127ms/step - loss: 0.3640 - accuracy: 0.8926 - iou_coef: 0.7983 - dice_coef: 0.8823 - f1_score: 0.8829 - aggregated_jaccard_index: 0.8092 - val_val_loss: 0.1646 - val_val_accuracy: 0.9148 - val_val_iou_coef: 0.8766 - val_val_dice_coef: 0.9324 - val_val_f1_score: 0.9328 - val_val_aggregated_jaccard_index: 0.8771 - lr: 1.0000e-05
# Epoch 81/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3619 - accuracy: 0.8924 - iou_coef: 0.7987 - dice_coef: 0.8827 - f1_score: 0.8833 - aggregated_jaccard_index: 0.8097 - val_val_loss: 0.1653 - val_val_accuracy: 0.9130 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9299 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8737 - lr: 1.0000e-05
# Epoch 82/150
# 171/171 [==============================] - 23s 135ms/step - loss: 0.3628 - accuracy: 0.8922 - iou_coef: 0.7989 - dice_coef: 0.8830 - f1_score: 0.8835 - aggregated_jaccard_index: 0.8082 - val_val_loss: 0.1641 - val_val_accuracy: 0.9120 - val_val_iou_coef: 0.8725 - val_val_dice_coef: 0.9293 - val_val_f1_score: 0.9296 - val_val_aggregated_jaccard_index: 0.8728 - lr: 1.0000e-05
# Epoch 83/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3550 - accuracy: 0.8942 - iou_coef: 0.8003 - dice_coef: 0.8838 - f1_score: 0.8843 - aggregated_jaccard_index: 0.8121 - val_val_loss: 0.1650 - val_val_accuracy: 0.9128 - val_val_iou_coef: 0.8737 - val_val_dice_coef: 0.9302 - val_val_f1_score: 0.9305 - val_val_aggregated_jaccard_index: 0.8740 - lr: 1.0000e-05
# Epoch 84/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3570 - accuracy: 0.8936 - iou_coef: 0.7995 - dice_coef: 0.8837 - f1_score: 0.8843 - aggregated_jaccard_index: 0.8106 - val_val_loss: 0.1645 - val_val_accuracy: 0.9126 - val_val_iou_coef: 0.8733 - val_val_dice_coef: 0.9298 - val_val_f1_score: 0.9301 - val_val_aggregated_jaccard_index: 0.8735 - lr: 1.0000e-05
# Epoch 85/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3560 - accuracy: 0.8936 - iou_coef: 0.7995 - dice_coef: 0.8832 - f1_score: 0.8837 - aggregated_jaccard_index: 0.8114 - val_val_loss: 0.1638 - val_val_accuracy: 0.9109 - val_val_iou_coef: 0.8715 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9288 - val_val_aggregated_jaccard_index: 0.8719 - lr: 1.0000e-05
# Epoch 86/150
# 171/171 [==============================] - 21s 125ms/step - loss: 0.3585 - accuracy: 0.8934 - iou_coef: 0.7993 - dice_coef: 0.8830 - f1_score: 0.8835 - aggregated_jaccard_index: 0.8112 - val_val_loss: 0.1640 - val_val_accuracy: 0.9118 - val_val_iou_coef: 0.8722 - val_val_dice_coef: 0.9290 - val_val_f1_score: 0.9293 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 87/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3561 - accuracy: 0.8935 - iou_coef: 0.8004 - dice_coef: 0.8837 - f1_score: 0.8842 - aggregated_jaccard_index: 0.8118 - val_val_loss: 0.1638 - val_val_accuracy: 0.9138 - val_val_iou_coef: 0.8747 - val_val_dice_coef: 0.9309 - val_val_f1_score: 0.9312 - val_val_aggregated_jaccard_index: 0.8750 - lr: 1.0000e-05
# Epoch 88/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.3580 - accuracy: 0.8934 - iou_coef: 0.7985 - dice_coef: 0.8826 - f1_score: 0.8832 - aggregated_jaccard_index: 0.8102 - val_val_loss: 0.1647 - val_val_accuracy: 0.9115 - val_val_iou_coef: 0.8711 - val_val_dice_coef: 0.9282 - val_val_f1_score: 0.9285 - val_val_aggregated_jaccard_index: 0.8710 - lr: 1.0000e-05
# Epoch 89/150
# 171/171 [==============================] - 22s 127ms/step - loss: 0.3525 - accuracy: 0.8947 - iou_coef: 0.8017 - dice_coef: 0.8848 - f1_score: 0.8854 - aggregated_jaccard_index: 0.8128 - val_val_loss: 0.1628 - val_val_accuracy: 0.9114 - val_val_iou_coef: 0.8724 - val_val_dice_coef: 0.9292 - val_val_f1_score: 0.9295 - val_val_aggregated_jaccard_index: 0.8727 - lr: 1.0000e-05
# Epoch 90/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.3614 - accuracy: 0.8920 - iou_coef: 0.7972 - dice_coef: 0.8818 - f1_score: 0.8823 - aggregated_jaccard_index: 0.8079 - val_val_loss: 0.1631 - val_val_accuracy: 0.9116 - val_val_iou_coef: 0.8722 - val_val_dice_coef: 0.9291 - val_val_f1_score: 0.9294 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 91/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.3599 - accuracy: 0.8927 - iou_coef: 0.7979 - dice_coef: 0.8817 - f1_score: 0.8823 - aggregated_jaccard_index: 0.8093 - val_val_loss: 0.1655 - val_val_accuracy: 0.9091 - val_val_iou_coef: 0.8680 - val_val_dice_coef: 0.9260 - val_val_f1_score: 0.9264 - val_val_aggregated_jaccard_index: 0.8679 - lr: 1.0000e-05
# Epoch 92/150
# 171/171 [==============================] - 22s 127ms/step - loss: 0.3531 - accuracy: 0.8943 - iou_coef: 0.8003 - dice_coef: 0.8839 - f1_score: 0.8844 - aggregated_jaccard_index: 0.8119 - val_val_loss: 0.1615 - val_val_accuracy: 0.9134 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9298 - val_val_f1_score: 0.9300 - val_val_aggregated_jaccard_index: 0.8736 - lr: 1.0000e-05
# Epoch 93/150
# 171/171 [==============================] - 23s 136ms/step - loss: 0.3537 - accuracy: 0.8942 - iou_coef: 0.7993 - dice_coef: 0.8830 - f1_score: 0.8836 - aggregated_jaccard_index: 0.8112 - val_val_loss: 0.1619 - val_val_accuracy: 0.9126 - val_val_iou_coef: 0.8733 - val_val_dice_coef: 0.9299 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8737 - lr: 1.0000e-05
# Epoch 94/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3518 - accuracy: 0.8940 - iou_coef: 0.8007 - dice_coef: 0.8842 - f1_score: 0.8848 - aggregated_jaccard_index: 0.8116 - val_val_loss: 0.1617 - val_val_accuracy: 0.9127 - val_val_iou_coef: 0.8738 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9305 - val_val_aggregated_jaccard_index: 0.8741 - lr: 1.0000e-05
# Epoch 95/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3549 - accuracy: 0.8936 - iou_coef: 0.7996 - dice_coef: 0.8833 - f1_score: 0.8838 - aggregated_jaccard_index: 0.8104 - val_val_loss: 0.1624 - val_val_accuracy: 0.9132 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9298 - val_val_f1_score: 0.9301 - val_val_aggregated_jaccard_index: 0.8737 - lr: 1.0000e-05
# Epoch 96/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.3503 - accuracy: 0.8946 - iou_coef: 0.8008 - dice_coef: 0.8843 - f1_score: 0.8849 - aggregated_jaccard_index: 0.8120 - val_val_loss: 0.1631 - val_val_accuracy: 0.9130 - val_val_iou_coef: 0.8743 - val_val_dice_coef: 0.9306 - val_val_f1_score: 0.9310 - val_val_aggregated_jaccard_index: 0.8746 - lr: 1.0000e-05
# Epoch 97/150
# 171/171 [==============================] - 24s 139ms/step - loss: 0.3541 - accuracy: 0.8936 - iou_coef: 0.7990 - dice_coef: 0.8827 - f1_score: 0.8833 - aggregated_jaccard_index: 0.8100 - val_val_loss: 0.1614 - val_val_accuracy: 0.9135 - val_val_iou_coef: 0.8741 - val_val_dice_coef: 0.9304 - val_val_f1_score: 0.9307 - val_val_aggregated_jaccard_index: 0.8745 - lr: 1.0000e-05
# Epoch 98/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.3488 - accuracy: 0.8951 - iou_coef: 0.8011 - dice_coef: 0.8842 - f1_score: 0.8848 - aggregated_jaccard_index: 0.8136 - val_val_loss: 0.1619 - val_val_accuracy: 0.9108 - val_val_iou_coef: 0.8695 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9272 - val_val_aggregated_jaccard_index: 0.8697 - lr: 1.0000e-05
# Epoch 99/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.3507 - accuracy: 0.8944 - iou_coef: 0.8020 - dice_coef: 0.8850 - f1_score: 0.8856 - aggregated_jaccard_index: 0.8123 - val_val_loss: 0.1612 - val_val_accuracy: 0.9148 - val_val_iou_coef: 0.8759 - val_val_dice_coef: 0.9317 - val_val_f1_score: 0.9321 - val_val_aggregated_jaccard_index: 0.8763 - lr: 1.0000e-05
# Epoch 100/150
# 171/171 [==============================] - 22s 130ms/step - loss: 0.3448 - accuracy: 0.8956 - iou_coef: 0.8031 - dice_coef: 0.8854 - f1_score: 0.8859 - aggregated_jaccard_index: 0.8150 - val_val_loss: 0.1606 - val_val_accuracy: 0.9150 - val_val_iou_coef: 0.8763 - val_val_dice_coef: 0.9319 - val_val_f1_score: 0.9323 - val_val_aggregated_jaccard_index: 0.8767 - lr: 1.0000e-05
# Epoch 101/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.3547 - accuracy: 0.8929 - iou_coef: 0.7985 - dice_coef: 0.8825 - f1_score: 0.8830 - aggregated_jaccard_index: 0.8097 - val_val_loss: 0.1617 - val_val_accuracy: 0.9124 - val_val_iou_coef: 0.8721 - val_val_dice_coef: 0.9288 - val_val_f1_score: 0.9291 - val_val_aggregated_jaccard_index: 0.8721 - lr: 1.0000e-05
# Epoch 102/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3488 - accuracy: 0.8945 - iou_coef: 0.8019 - dice_coef: 0.8848 - f1_score: 0.8853 - aggregated_jaccard_index: 0.8123 - val_val_loss: 0.1614 - val_val_accuracy: 0.9120 - val_val_iou_coef: 0.8715 - val_val_dice_coef: 0.9285 - val_val_f1_score: 0.9287 - val_val_aggregated_jaccard_index: 0.8717 - lr: 1.0000e-05
# Epoch 103/150
# 171/171 [==============================] - 24s 141ms/step - loss: 0.3465 - accuracy: 0.8954 - iou_coef: 0.8022 - dice_coef: 0.8852 - f1_score: 0.8857 - aggregated_jaccard_index: 0.8128 - val_val_loss: 0.1603 - val_val_accuracy: 0.9128 - val_val_iou_coef: 0.8728 - val_val_dice_coef: 0.9294 - val_val_f1_score: 0.9297 - val_val_aggregated_jaccard_index: 0.8731 - lr: 1.0000e-05
# Epoch 104/150
# 171/171 [==============================] - 21s 124ms/step - loss: 0.3491 - accuracy: 0.8944 - iou_coef: 0.7992 - dice_coef: 0.8830 - f1_score: 0.8836 - aggregated_jaccard_index: 0.8114 - val_val_loss: 0.1608 - val_val_accuracy: 0.9133 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9299 - val_val_f1_score: 0.9301 - val_val_aggregated_jaccard_index: 0.8738 - lr: 1.0000e-05
# Epoch 105/150
# 171/171 [==============================] - 23s 137ms/step - loss: 0.3458 - accuracy: 0.8954 - iou_coef: 0.8031 - dice_coef: 0.8858 - f1_score: 0.8864 - aggregated_jaccard_index: 0.8135 - val_val_loss: 0.1605 - val_val_accuracy: 0.9119 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9299 - val_val_f1_score: 0.9302 - val_val_aggregated_jaccard_index: 0.8738 - lr: 1.0000e-05
# Epoch 106/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3462 - accuracy: 0.8948 - iou_coef: 0.8012 - dice_coef: 0.8844 - f1_score: 0.8849 - aggregated_jaccard_index: 0.8126 - val_val_loss: 0.1610 - val_val_accuracy: 0.9082 - val_val_iou_coef: 0.8670 - val_val_dice_coef: 0.9252 - val_val_f1_score: 0.9255 - val_val_aggregated_jaccard_index: 0.8672 - lr: 1.0000e-05
# Epoch 107/150
# 171/171 [==============================] - 21s 121ms/step - loss: 0.3471 - accuracy: 0.8944 - iou_coef: 0.8000 - dice_coef: 0.8835 - f1_score: 0.8840 - aggregated_jaccard_index: 0.8122 - val_val_loss: 0.1596 - val_val_accuracy: 0.9106 - val_val_iou_coef: 0.8706 - val_val_dice_coef: 0.9278 - val_val_f1_score: 0.9281 - val_val_aggregated_jaccard_index: 0.8708 - lr: 1.0000e-05
# Epoch 108/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3489 - accuracy: 0.8936 - iou_coef: 0.7997 - dice_coef: 0.8833 - f1_score: 0.8838 - aggregated_jaccard_index: 0.8119 - val_val_loss: 0.1595 - val_val_accuracy: 0.9133 - val_val_iou_coef: 0.8745 - val_val_dice_coef: 0.9307 - val_val_f1_score: 0.9310 - val_val_aggregated_jaccard_index: 0.8749 - lr: 1.0000e-05
# Epoch 109/150
# 171/171 [==============================] - 24s 140ms/step - loss: 0.3518 - accuracy: 0.8936 - iou_coef: 0.7984 - dice_coef: 0.8824 - f1_score: 0.8829 - aggregated_jaccard_index: 0.8094 - val_val_loss: 0.1586 - val_val_accuracy: 0.9105 - val_val_iou_coef: 0.8707 - val_val_dice_coef: 0.9279 - val_val_f1_score: 0.9282 - val_val_aggregated_jaccard_index: 0.8711 - lr: 1.0000e-05
# Epoch 110/150
# 171/171 [==============================] - 21s 123ms/step - loss: 0.3502 - accuracy: 0.8934 - iou_coef: 0.8005 - dice_coef: 0.8836 - f1_score: 0.8841 - aggregated_jaccard_index: 0.8115 - val_val_loss: 0.1587 - val_val_accuracy: 0.9139 - val_val_iou_coef: 0.8742 - val_val_dice_coef: 0.9303 - val_val_f1_score: 0.9307 - val_val_aggregated_jaccard_index: 0.8744 - lr: 1.0000e-05
# Epoch 111/150
# 171/171 [==============================] - 22s 127ms/step - loss: 0.3479 - accuracy: 0.8942 - iou_coef: 0.8001 - dice_coef: 0.8831 - f1_score: 0.8836 - aggregated_jaccard_index: 0.8121 - val_val_loss: 0.1590 - val_val_accuracy: 0.9134 - val_val_iou_coef: 0.8736 - val_val_dice_coef: 0.9300 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8738 - lr: 1.0000e-05
# Epoch 112/150
# 171/171 [==============================] - 20s 114ms/step - loss: 0.3445 - accuracy: 0.8955 - iou_coef: 0.8024 - dice_coef: 0.8854 - f1_score: 0.8859 - aggregated_jaccard_index: 0.8132 - val_val_loss: 0.1585 - val_val_accuracy: 0.9125 - val_val_iou_coef: 0.8737 - val_val_dice_coef: 0.9301 - val_val_f1_score: 0.9304 - val_val_aggregated_jaccard_index: 0.8741 - lr: 1.0000e-05
# Epoch 113/150
# 171/171 [==============================] - 23s 134ms/step - loss: 0.3455 - accuracy: 0.8943 - iou_coef: 0.8010 - dice_coef: 0.8843 - f1_score: 0.8848 - aggregated_jaccard_index: 0.8127 - val_val_loss: 0.1587 - val_val_accuracy: 0.9120 - val_val_iou_coef: 0.8719 - val_val_dice_coef: 0.9287 - val_val_f1_score: 0.9291 - val_val_aggregated_jaccard_index: 0.8718 - lr: 1.0000e-05
# Epoch 114/150
# 171/171 [==============================] - 24s 138ms/step - loss: 0.3437 - accuracy: 0.8946 - iou_coef: 0.8016 - dice_coef: 0.8846 - f1_score: 0.8851 - aggregated_jaccard_index: 0.8127 - val_val_loss: 0.1573 - val_val_accuracy: 0.9128 - val_val_iou_coef: 0.8730 - val_val_dice_coef: 0.9295 - val_val_f1_score: 0.9298 - val_val_aggregated_jaccard_index: 0.8733 - lr: 1.0000e-05
# Epoch 115/150
# 171/171 [==============================] - 22s 126ms/step - loss: 0.3461 - accuracy: 0.8938 - iou_coef: 0.8005 - dice_coef: 0.8839 - f1_score: 0.8845 - aggregated_jaccard_index: 0.8118 - val_val_loss: 0.1584 - val_val_accuracy: 0.9137 - val_val_iou_coef: 0.8741 - val_val_dice_coef: 0.9302 - val_val_f1_score: 0.9306 - val_val_aggregated_jaccard_index: 0.8744 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image
# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size = 256
batch_size = 72

# -----------------------------
# NORMALIZE FILENAMES (ONCE)
# -----------------------------
def lowercase_filenames(dir_path):
    for p in glob(os.path.join(dir_path, "*")):
        base = os.path.basename(p)
        lower = base.lower()
        if base != lower:
            os.rename(p, os.path.join(dir_path, lower))

lowercase_filenames(IMG_DIR)
lowercase_filenames(MSK_DIR)

# -----------------------------
# COLLECT PATHS
# -----------------------------
def valid_name(p):
    return "zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)
mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# KEY-BASED ALIGNMENT (SOURCE OF TRUTH)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

img_map = {stem(p): p for p in image_paths}
msk_map = {stem(p): p for p in mask_paths}

common_keys = sorted(img_map.keys() & msk_map.keys())
assert len(common_keys) > 0, "No aligned image–mask pairs found"

image_paths = [img_map[k] for k in common_keys]
mask_paths  = [msk_map[k] for k in common_keys]

print("Aligned pairs:", len(common_keys))

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )
    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.asarray(img, dtype=np.float32) / 255.0
    mask = (np.asarray(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:",
      tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 80
# Masks found : 80
# Aligned pairs: 80
# Validation batches: 2

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# 2026-09-20 07:23:16.146899: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-09-20 07:23:16.381334: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 5.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-09-20 07:23:16.720341: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-09-20 07:23:17.477283: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.44GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-09-20 07:23:21.252992: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.64GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2026-09-20 07:23:21.455076: W external/local_tsl/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.64GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8092
# Mean Dice Coefficient: 0.8899
# Mean AJI:              0.8166
# Mean Accuracy:         0.8809
# Mean F1 Score:         0.8926
