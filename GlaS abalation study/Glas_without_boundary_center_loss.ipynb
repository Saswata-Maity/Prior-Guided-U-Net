# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 04:54:55.968543: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 04:54:56.103083: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 04:54:56.103167: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 04:54:56.119948: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 04:54:56.172641: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 04:54:57.369095: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 04:55:02.122159: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:55:02.449087: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:55:02.449155: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ----------------------------
# PriorGuidedUpsample2D:
# UpSampling2D-based upsampling + Learnable prior fusion (NO pixelwise maximum)
# ----------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGuidedUpsample2D(layers.Layer):
    """
    UpSampling2D upsampling everywhere (replaces PixelShuffleResize for features/skip and optionally priors)
    PLUS learnable prior fusion:

      GAP(pred) + GAP(prior) -> Dense -> Dense(1) -> project back (B,1,1,1) gate
      fused = gate*prior + (1-gate)*pred
      then DepthwiseConv(act) -> PointwiseConv to produce final map (B,H,W,1)

    Priors influence ONLY the structure maps (center/boundary), then those modulate features as before.
    """

    def __init__(
        self,
        scale=2,
        filters=64,
        method="bilinear",
        attention_kernel=3,
        use_structure_heads=True,
        n_centers=8,
        center_sharpness=9.0,
        boundary_suppress=0.4,
        learnable_temperature=True,
        learnable_prior_resize=True,
        # prior-fusion settings
        prior_fusion_hidden_ratio=4,  # hidden = filters//ratio
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.scale = int(scale)
        self.filters = int(filters)
        self.method = method
        self.attention_kernel = int(attention_kernel)
        self.use_structure_heads = bool(use_structure_heads)
        self.n_centers = int(n_centers)
        self.center_sharpness = float(center_sharpness)
        self.boundary_suppress = float(boundary_suppress)
        self.learnable_temperature = bool(learnable_temperature)

        self.learnable_prior_resize = bool(learnable_prior_resize)
        self.prior_fusion_hidden_ratio = int(prior_fusion_hidden_ratio)

        # ---------------- Projection & Attention ----------------
        self.proj_high = layers.Conv2D(filters, 1, padding="same", activation="selu", name="proj_high")
        self.proj_base = layers.Conv2D(filters, 1, padding="same", activation="linear", name="proj_base")
        self.skip_proj = layers.Conv2D(filters, 1, padding="same", use_bias=False, name="skip_proj")

        self.attention_head = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(attention_kernel, padding="same", activation="selu", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="spatial_attention",
        )

        # ---------------- UpSampling2D-based upsamplers ----------------
        self.up_feat = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_feat")
        self.up_feat_refine = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
            ],
            name="up_feat_refine",
        )

        if self.learnable_prior_resize:
            self.up_prior = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_prior")
            self.up_prior_refine = tf.keras.Sequential(
                [
                    layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                    layers.Conv2D(1, 1, padding="same", activation="selu"),
                ],
                name="up_prior_refine",
            )
        else:
            self.up_prior = None
            self.up_prior_refine = None

        # ---------------- Learned fusion scale ----------------
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(1.0), trainable=True, name="alpha_weight"
        )
        self.beta_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True, name="beta_weight"
        )

        # ---------------- Final projection (refinement step removed) ----------------
        self.final = layers.Conv2D(filters, 1, padding="same", activation="selu", name="final_head")

        # ---------------- Structural Heads ----------------
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding="same", use_bias=True)
        self.center_proj = layers.Conv2D(filters, 1, padding="same", activation=None)

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding="same", use_bias=False, name="laplace_dw")
        self.boundary_refine = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_refine",
        )
        self.boundary_gate_net = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_gate_net",
        )

        self.boundary_gate_scalar = None
        self.center_temp = None
        self.center_sigma = None

        # ---------------- Learnable prior fusion blocks (CENTER) ----------------
        hid = max(4, filters // self.prior_fusion_hidden_ratio)

        self.center_gap = layers.GlobalAveragePooling2D(name="center_prior_gap")
        self.center_fc1 = layers.Dense(hid, activation="selu", name="center_prior_fc1")
        self.center_gate = layers.Dense(1, activation="sigmoid", name="center_prior_gate")  # scalar gate

        self.center_dw = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="center_prior_dw")
        self.center_pw = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="center_prior_pw")

        # ---------------- Learnable prior fusion blocks (BOUNDARY) ----------------
        self.boundary_gap = layers.GlobalAveragePooling2D(name="boundary_prior_gap")
        self.boundary_fc1 = layers.Dense(hid, activation="selu", name="boundary_prior_fc1")
        self.boundary_gate = layers.Dense(1, activation="sigmoid", name="boundary_prior_gate")  # scalar gate

        self.boundary_dw2 = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="boundary_prior_dw")
        self.boundary_pw2 = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="boundary_prior_pw")

    # ---------------- Fusion scale initialization ----------------
    def _init_fusion_scale(self, shape, dtype):
        init = tf.keras.initializers.HeNormal(seed=54)
        w = init(shape=shape, dtype=dtype)
        return tf.clip_by_value(w, 0.0, 1.0)

    # ---------------- Build ----------------
    def build(self, input_shape):
        if not isinstance(input_shape, (list, tuple)) or len(input_shape) not in [2, 4]:
            raise ValueError(
                "PriorGuidedUpsample2D expects [low_res, skip_res] or "
                "[low_res, skip_res, prior_centers, prior_boundaries] inputs."
            )

        fusion_scale_init = self._init_fusion_scale((1, 1, 1, self.filters), tf.float32)
        self.fusion_scale = tf.Variable(
            initial_value=fusion_scale_init, trainable=True, name="fusion_scale", dtype=tf.float32
        )

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True,
            name="boundary_gate_scalar",
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True,
                name="center_temperature",
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness, dtype=tf.float32)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="center_sigma",
        )

        super().build(input_shape)

    # ---------------- Learnable upsample-to-target helper ----------------
    def _upsample_to(self, x, up_layer, refine, target_h, target_w):
        x = up_layer(x)
        if refine is not None:
            x = refine(x)
        # exact match by crop/pad (non-interpolating) for odd input sizes
        x = tf.image.resize_with_crop_or_pad(x, target_h, target_w)
        return x

    # ---------------- Learnable fusion (replaces pixelwise maximum) ----------------
    def _learnable_fuse_prior(self, pred_map, prior_map, gap, fc1, gate_fc, dw, pw):
        """
        pred_map/prior_map: (B,H,W,1)
        gate: scalar per-sample from GAP(pred)+GAP(prior)
        fused map refined by DWConv(act)+PWConv(sigmoid)
        """
        g_pred = gap(pred_map)   # (B,1) effectively after GAP; in TF it's (B,)
        g_prior = gap(prior_map)

        g = tf.concat([g_pred, g_prior], axis=-1)  # (B,2)
        h = fc1(g)
        gate = gate_fc(h)                          # (B,1)
        gate = tf.reshape(gate, [-1, 1, 1, 1])     # project back (broadcast)

        fused = gate * prior_map + (1.0 - gate) * pred_map
        fused = dw(fused)
        fused = pw(fused)
        return fused

    # ---------------- GMM-based Center & Boundary ----------------
    def _compute_soft_centers_gmm(self, feat, prior_centers=None, prior_boundaries=None):
        center_map, boundary_map = self._compute_centers_boundaries(feat)
        target_h, target_w = tf.shape(center_map)[1], tf.shape(center_map)[2]

        # --- learnable prior alignment + learnable fusion (NO tf.maximum) ---
        if prior_centers is not None:
            if self.up_prior is not None:
                prior_centers_up = self._upsample_to(
                    prior_centers, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_centers_up = tf.image.resize(prior_centers, (target_h, target_w), method="bilinear")
            prior_centers_up = tf.clip_by_value(prior_centers_up, 0.0, 1.0)

            center_map = self._learnable_fuse_prior(
                center_map, prior_centers_up,
                self.center_gap, self.center_fc1, self.center_gate,
                self.center_dw, self.center_pw
            )

        if prior_boundaries is not None:
            if self.up_prior is not None:
                prior_boundaries_up = self._upsample_to(
                    prior_boundaries, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_boundaries_up = tf.image.resize(prior_boundaries, (target_h, target_w), method="bilinear")
            prior_boundaries_up = tf.clip_by_value(prior_boundaries_up, 0.0, 1.0)

            boundary_map = self._learnable_fuse_prior(
                boundary_map, prior_boundaries_up,
                self.boundary_gap, self.boundary_fc1, self.boundary_gate,
                self.boundary_dw2, self.boundary_pw2
            )

        return center_map, boundary_map

    def _compute_centers_boundaries(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]

        proj_feat = self.center_proj(feat)
        H, W, C = tf.shape(proj_feat)[1], tf.shape(proj_feat)[2], tf.shape(proj_feat)[3]
        feat_flat = tf.reshape(proj_feat, [B, H * W, C])

        logits = self.assign_logits(proj_feat)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A_flat = tf.nn.softmax(logits_flat, axis=-1)

        A_flat_t = tf.transpose(A_flat, [0, 2, 1])
        denom = tf.reduce_sum(A_flat_t, axis=-1, keepdims=True) + eps
        prototypes = tf.matmul(A_flat_t, feat_flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])

        feat_exp = tf.expand_dims(feat_flat, 2)
        proto_exp = tf.expand_dims(prototypes, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_norm = tf.nn.l2_normalize(feat_flat, axis=-1)
        proto_norm = tf.nn.l2_normalize(prototypes, axis=-1)
        sim = tf.matmul(feat_norm, proto_norm, transpose_b=True)

        weighted_sim = resp * sim
        per_pixel_strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)

        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(per_pixel_strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)
        global_gate = tf.sigmoid(self.boundary_gate_scalar)
        boundary_map = refined_boundary * spatial_gate * global_gate * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ---------------- Forward ----------------
    def call(self, inputs, training=None):
        if len(inputs) == 2:
            low_res, skip_res = inputs
            prior_centers, prior_boundaries = None, None
        elif len(inputs) == 4:
            low_res, skip_res, prior_centers, prior_boundaries = inputs
        else:
            raise ValueError("Expected 2 or 4 inputs: [low_res, skip_res] optionally with priors.")

        high_proj = self.proj_high(low_res)
        base_proj = self.proj_base(low_res)
        alpha = self.attention_head(tf.concat([low_res, high_proj, base_proj], axis=-1))
        fused_low = alpha * high_proj + (1.0 - alpha) * base_proj

        target_h = tf.shape(low_res)[1] * self.scale
        target_w = tf.shape(low_res)[2] * self.scale

        # UpSampling2D-based upsampling (features + skip)
        upsampled = self._upsample_to(fused_low, self.up_feat, self.up_feat_refine, target_h, target_w)
        skip_proj = self.skip_proj(skip_res)
        skip_up = self._upsample_to(skip_proj, self.up_feat, self.up_feat_refine, target_h, target_w)

        fused = (upsampled + skip_up) * self.fusion_scale
        refined = fused

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(refined, prior_centers, prior_boundaries)
            refined = refined * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            out = self.final(refined)
            return out, center_map, boundary_map

        out = self.final(refined)
        return out

    # ---------------- Config ----------------
    def get_config(self):
        cfg = super().get_config()
        cfg.update(
            {
                "scale": self.scale,
                "filters": self.filters,
                "method": self.method,
                "attention_kernel": self.attention_kernel,
                "use_structure_heads": self.use_structure_heads,
                "n_centers": self.n_centers,
                "center_sharpness": self.center_sharpness,
                "boundary_suppress": self.boundary_suppress,
                "learnable_temperature": self.learnable_temperature,
                "learnable_prior_resize": self.learnable_prior_resize,
                "prior_fusion_hidden_ratio": self.prior_fusion_hidden_ratio,
            }
        )
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):

    res = x

    # ============================================================
    # ENCODER BLOCK
    # ============================================================
    if not decoder:


        # -------------------------------
        # Branch 2: Evolutionary Conv
        # -------------------------------
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        # -------------------------------
        # Depthwise Patch Attention
        # -------------------------------

        # Residual projection
        res = layers.Conv2D(filters, 1, padding=padding)(res)

        # Final fusion
        out = layers.Add()([res, x1])

        return out

    # ============================================================
    # DECODER BLOCK
    # ============================================================
    else:

        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class RegionawareAnisotropicPooling2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base



# ---------------------------------------------------------
# PriorGeneratingDownsample2D
#
# Changes from the original:
#   1. No more GatedSpatialAttention refinement step.
#   2. No more separate `refine_feat` input tensor. The skip
#      branch is now an average-pooled version of `in_feat`
#      itself, computed inside the layer with tf.nn.avg_pool2d
#      using the same pool_size as the geodesic downsampler.
#   3. call() now takes a single tensor `in_feat` instead of
#      a (in_feat, refine_feat) tuple, and build() expects a
#      single input_shape instead of a tuple of shapes.
#
# This layer produces the `center_map` / `boundary_map` priors
# (alongside the downsampled features) that PriorGuidedUpsample2D
# later consumes as `prior_centers` / `prior_boundaries`.
# ---------------------------------------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGeneratingDownsample2D(layers.Layer):

    def __init__(self,
                 pool_size=2,
                 filters=64,
                 attention_kernel=3,
                 use_structure_heads=True,
                 n_centers=8,
                 center_sharpness=9.0,
                 boundary_suppress=0.4,
                 learnable_temperature=True,
                 **kwargs):

        super().__init__(**kwargs)

        self.pool_size = pool_size
        self.filters = filters
        self.attention_kernel = attention_kernel
        self.use_structure_heads = use_structure_heads
        self.n_centers = n_centers
        self.center_sharpness = center_sharpness
        self.boundary_suppress = boundary_suppress
        self.learnable_temperature = learnable_temperature

        # Replace pooling with geodesic kernel
        self.geo_pool = RegionawareAnisotropicPooling2D(pool_size=pool_size)

        # Projections
        self.proj_high = layers.Conv2D(filters, 1, padding='same', activation='selu')
        self.proj_base = layers.Conv2D(filters, 1, padding='same')
        self.skip_proj = layers.Conv2D(filters, 1, padding='same')

        # Spatial attention
        self.attention_head = tf.keras.Sequential([
            layers.DepthwiseConv2D(attention_kernel, padding='same', activation='selu'),
            layers.Conv2D(filters, 1, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

        # Fusion scale
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(shape=(1,), initializer='ones', trainable=True)
        self.beta_weight = self.add_weight(shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True)

        # Final projection (refinement step removed)
        self.final = layers.Conv2D(filters, 3, padding='same', activation='selu')

        # Structure heads
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding='same')
        self.center_proj = layers.Conv2D(filters, 1, padding='same')

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding='same')
        self.boundary_refine = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])
        self.boundary_gate_net = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

    def build(self, input_shape):
        # input_shape is now a single tensor shape (in_feat only)
        _, _, _, C = input_shape

        fusion_scale_init = tf.keras.initializers.HeNormal(seed=54)(shape=(1, 1, 1, self.filters))
        self.fusion_scale = tf.Variable(fusion_scale_init, trainable=True, name='fusion_scale')

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer='ones',
            trainable=True
        )

        super().build(input_shape)

    # ------------------------------------------------------
    # GMM structural mask logic (unchanged)
    # ------------------------------------------------------
    def _compute_soft_centers_gmm(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]
        proj = self.center_proj(feat)
        H = tf.shape(proj)[1]
        W = tf.shape(proj)[2]
        C = tf.shape(proj)[3]

        flat = tf.reshape(proj, [B, H * W, C])
        logits = self.assign_logits(proj)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A = tf.nn.softmax(logits_flat, axis=-1)
        A_t = tf.transpose(A, [0, 2, 1])
        denom = tf.reduce_sum(A_t, axis=-1, keepdims=True) + eps
        proto = tf.matmul(A_t, flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])
        feat_exp = tf.expand_dims(flat, 2)
        proto_exp = tf.expand_dims(proto, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_n = tf.nn.l2_normalize(flat, axis=-1)
        proto_n = tf.nn.l2_normalize(proto, axis=-1)
        sim = tf.matmul(feat_n, proto_n, transpose_b=True)

        weighted_sim = resp * sim
        strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)
        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)

        boundary_map = refined_boundary * spatial_gate * tf.sigmoid(self.boundary_gate_scalar) * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ------------------------------------------------------
    # Forward path with geodesic pooling
    #
    # `in_feat` is now the ONLY input. The skip branch is
    # derived internally via average pooling of `in_feat`
    # (replacing the old separate `refine_feat` argument),
    # and the GatedSpatialAttention refinement step has been
    # removed entirely — the merged features flow straight
    # into the structure heads / final projection.
    # ------------------------------------------------------
    def call(self, in_feat):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        pooled = self.geo_pool(in_feat)

        # Average-pooled skip branch, derived directly from in_feat
        pooled_ref = tf.nn.avg_pool2d(
            in_feat,
            ksize=[1, ph, pw, 1],
            strides=[1, ph, pw, 1],
            padding='SAME'
        )

        if tf.shape(pooled_ref)[1] != tf.shape(pooled)[1] or tf.shape(pooled_ref)[2] != tf.shape(pooled)[2]:
            pooled_ref = tf.image.resize(pooled_ref, tf.shape(pooled)[1:3], method='bilinear')

        high = self.proj_high(pooled)
        base = self.proj_base(pooled)
        alpha = self.attention_head(tf.concat([pooled, high, base], axis=-1))
        fused = alpha * high + (1 - alpha) * base

        skip = self.skip_proj(pooled_ref)
        fused = (fused + skip) * self.fusion_scale

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(fused)
            fused = fused * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            return self.final(fused), center_map, boundary_map

        return self.final(fused)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            'pool_size': self.pool_size,
            'filters': self.filters,
            'attention_kernel': self.attention_kernel,
            'use_structure_heads': self.use_structure_heads,
            'n_centers': self.n_centers,
            'center_sharpness': self.center_sharpness,
            'boundary_suppress': self.boundary_suppress,
            'learnable_temperature': self.learnable_temperature
        })
        return cfg

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)

    s1, c1, b1 = PriorGeneratingDownsample2D()(f1)

    p1 = s1
    p1 = layers.Dropout(0.05)(p1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)

    s2, c2, b2 = PriorGeneratingDownsample2D()(f2)

    p2 = s2
    p2 = layers.Dropout(0.15)(p2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)

    s3, c3, b3 = PriorGeneratingDownsample2D()(f3)

    p3 = s3
    p3 = layers.Dropout(0.2)(p3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)

    s4, c4, b4 = PriorGeneratingDownsample2D()(f4)

    p4 = s4
    p4 = layers.Dropout(0.25)(p4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # ===================== Decoder =====================
    center_maps, boundary_maps = [], []

    # -------- Up 4 --------
    d4, c5, b5 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 8
    )([f5, f4, c4, b4])
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    center_maps.append(c5)
    boundary_maps.append(b5)

    # -------- Up 3 --------
    d3, c6, b6 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 4
    )([d4, f3, c3, b3])
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    center_maps.append(c6)
    boundary_maps.append(b6)

    # -------- Up 2 --------
    d2, c7, b7 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 2
    )([d3, f2, c2, b2])
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    center_maps.append(c7)
    boundary_maps.append(b7)

    # -------- Up 1 --------
    d1, c8, b8 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters
    )([d2, f1, c1, b1])

    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    center_maps.append(c8)
    boundary_maps.append(b8)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        [outputs, center_maps, boundary_maps],
        name="PriorGuidedResidualUNet_Deep5_GatedFusion"
    )

    return model, center_maps, boundary_maps

# %%
model, centers, boundaries = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 04:56:00.071612: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.071702: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.071723: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.578667: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.578788: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.578840: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 04:56:00.578882: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 04:56:00.578917: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 04:56:00.579003: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2026-09-20 04:56:02.292194: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "PriorGuidedResidualUNet_Deep5_GatedFusion"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['conv2d[0][0]',
#                                                                      'activation[0][0]']
#
#  prior_generating_downsampl  ((None, 128, 128, 64),       79511     ['add[0][0]']
#  e2d (PriorGeneratingDownsa   (None, 128, 128, 1),
#  mple2D)                      (None, 128, 128, 1))
#
#  dropout (Dropout)           (None, 128, 128, 64)         0         ['prior_generating_downsample2
#                                                                     d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 64)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         40961     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         4160      ['gaussian_dropout[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['conv2d_13[0][0]',
#                                                                      'activation_1[0][0]']
#
#  prior_generating_downsampl  ((None, 64, 64, 64),         88055     ['add_1[0][0]']
#  e2d_1 (PriorGeneratingDown   (None, 64, 64, 1),
#  sample2D)                    (None, 64, 64, 1))
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['prior_generating_downsample2
#                                                                     d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          8320      ['gaussian_dropout_1[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_26[0][0]',
#                                                                      'activation_2[0][0]']
#
#  prior_generating_downsampl  ((None, 32, 32, 64),         105143    ['add_2[0][0]']
#  e2d_2 (PriorGeneratingDown   (None, 32, 32, 1),
#  sample2D)                    (None, 32, 32, 1))
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['prior_generating_downsample2
#                                                                     d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          163841    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 32, 32, 256)          16640     ['dropout_2[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 32, 32, 256)          0         ['conv2d_39[0][0]',
#                                                                      'activation_3[0][0]']
#
#  prior_generating_downsampl  ((None, 16, 16, 64),         139319    ['add_3[0][0]']
#  e2d_3 (PriorGeneratingDown   (None, 16, 16, 1),
#  sample2D)                    (None, 16, 16, 1))
#
#  dropout_3 (Dropout)         (None, 16, 16, 64)           0         ['prior_generating_downsample2
#                                                                     d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 64)           0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          245761    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 16, 16, 384)          24960     ['gaussian_dropout_2[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 16, 16, 384)          0         ['conv2d_52[0][0]',
#                                                                      'activation_4[0][0]']
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['add_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  prior_guided_upsample2d (P  ((None, 32, 32, 256),        1002044   ['gaussian_dropout_3[0][0]',
#  riorGuidedUpsample2D)        (None, 32, 32, 1),                     'add_3[0][0]',
#                               (None, 32, 32, 1))                     'prior_generating_downsample2
#                                                                     d_3[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_3[0][2]']
#
#  dropout_4 (Dropout)         (None, 32, 32, 256)          0         ['prior_guided_upsample2d[0][0
#                                                                     ]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 256)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          655361    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 32, 32, 256)          0         ['add_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  prior_guided_upsample2d_1   ((None, 64, 64, 128),        280444    ['add_5[0][0]',
#  (PriorGuidedUpsample2D)      (None, 64, 64, 1),                     'add_2[0][0]',
#                               (None, 64, 64, 1))                     'prior_generating_downsample2
#                                                                     d_2[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_2[0][2]']
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 128)          0         ['prior_guided_upsample2d_1[0]
#  anDropout)                                                         [0]']
#
#  dropout_5 (Dropout)         (None, 64, 64, 128)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          163841    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_6 (Add)                 (None, 64, 64, 128)          0         ['add_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  prior_guided_upsample2d_2   ((None, 128, 128, 64),       72668     ['add_6[0][0]',
#  (PriorGuidedUpsample2D)      (None, 128, 128, 1),                   'add_1[0][0]',
#                               (None, 128, 128, 1))                   'prior_generating_downsample2
#                                                                     d_1[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_1[0][2]']
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         40961     ['prior_guided_upsample2d_2[0]
#  onv_7 (RadialWaveEvolution                                         [0]']
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['add_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  prior_guided_upsample2d_3   ((None, 256, 256, 32),       19468     ['add_7[0][0]',
#  (PriorGuidedUpsample2D)      (None, 256, 256, 1),                   'add[0][0]',
#                               (None, 256, 256, 1))                   'prior_generating_downsample2
#                                                                     d[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d[0][2]']
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         10241     ['prior_guided_upsample2d_3[0]
#  onv_8 (RadialWaveEvolution                                         [0]']
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['add[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d_93 (Conv2D)          (None, 256, 256, 1)          33        ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 3250118 (12.40 MB)
# Trainable params: 3247430 (12.39 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
# unet_canvas_full.py
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperCanvasStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation + Structural (Center/Boundary) loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU
        L_struct = λ_center * CenterAlignment + λ_boundary * BoundaryAlignment

    NOTE: the BCE term (and its weight l1), the canvas consistency
    loss (fg/bg per-pixel-squared-error penalty, and its weights
    lambda_fg/lambda_bg), and the patchwise discriminator loss
    (cosine + SSIM patch error, lambda_patchdisc) have been removed.
    """
    def __init__(self, init_lambdas=None, name="hyper_canvas_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {
                "l2": 3.0, "l3": 4.5,
                "lambda_center": 8.5, "lambda_boundary": 6.5
            }

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")
        self.lambda_center = tf.Variable(init_lambdas["lambda_center"], trainable=True, dtype=tf.float32, name="lambda_center")
        self.lambda_boundary = tf.Variable(init_lambdas["lambda_boundary"], trainable=True, dtype=tf.float32, name="lambda_boundary")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [
            self.l2, self.l3,
            self.lambda_center, self.lambda_boundary
        ]

    def call(self, y_true_tuple, y_pred_tuple):
        """
        Args:
            y_true_tuple: (y_true_seg, y_true_center, y_true_boundary)
            y_pred_tuple: (y_pred_seg, y_pred_center, y_pred_boundary)
        """
        if not isinstance(y_true_tuple, (list, tuple)) or not isinstance(y_pred_tuple, (list, tuple)):
            raise ValueError("Expected tuples: (y_true_seg, y_true_center, y_true_boundary) and (y_pred_seg, y_pred_center, y_pred_boundary)")

        y_true, y_true_center, y_true_boundary = map(tf.cast, y_true_tuple, [tf.float32]*3)
        y_pred, y_pred_center, y_pred_boundary = map(tf.cast, y_pred_tuple, [tf.float32]*3)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou


        return seg_loss 

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy()),
                "lambda_center": float(self.lambda_center.numpy()),
                "lambda_boundary": float(self.lambda_boundary.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../GLAS_PREPARED_DATA/val/images/*.png") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tif") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 684
# Train masks: 684
# Val images: 9
# Val masks: 9
# Training batches: 171
# Validation batches: 3

# %%
class CanvasStructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in [
            "l2", "l3",
            "lambda_center", "lambda_boundary"
        ]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            outputs = self.backbone(x, training=True)

            if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
                y_pred, centers, boundaries = outputs
            else:
                raise ValueError("Backbone must return (y_pred, centers, boundaries)")

            last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
            last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

            loss = self.loss_fn(
                (y_true, y_true, y_true),
                (y_pred, last_center, last_boundary)
            )

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        outputs = self.backbone(x, training=False)

        if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
            y_pred, centers, boundaries = outputs
        else:
            raise ValueError("Backbone must return (y_pred, centers, boundaries)")

        last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
        last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

        loss = self.loss_fn(
            (y_true, y_true, y_true),
            (y_pred, last_center, last_boundary)
        )

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperCanvasStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = CanvasStructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("unet_canvas_3v8.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# WARNING:tensorflow:Gradients do not exist for variables ['lambda_center:0', 'lambda_boundary:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lambda_center:0', 'lambda_boundary:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lambda_center:0', 'lambda_boundary:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# WARNING:tensorflow:Gradients do not exist for variables ['lambda_center:0', 'lambda_boundary:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss` argument?
# 2026-09-20 04:56:39.510805: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inPriorGuidedResidualUNet_Deep5_GatedFusion/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 04:56:49.106294: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 04:56:49.329438: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 04:56:54.237038: I external/local_xla/xla/service/service.cc:168] XLA service 0x75e47cff5610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 04:56:54.237076: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 04:56:54.256669: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789880214.346211    7960 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - ETA: 0s - loss: 3.2126 - accuracy: 0.6378 - iou_coef: 0.4947 - dice_coef: 0.6434 - f1_score: 0.6479 - aggregated_jaccard_index: 0.5245
# ✅ Saved improved backbone at epoch 1 with val_iou=0.5747
# 171/171 [==============================] - 118s 410ms/step - loss: 3.2046 - accuracy: 0.6378 - iou_coef: 0.4947 - dice_coef: 0.6434 - f1_score: 0.6479 - aggregated_jaccard_index: 0.5245 - val_val_loss: 2.4798 - val_val_accuracy: 0.7128 - val_val_iou_coef: 0.5747 - val_val_dice_coef: 0.7192 - val_val_f1_score: 0.7219 - val_val_aggregated_jaccard_index: 0.5814 - lr: 0.0010
# Epoch 2/150
# 171/171 [==============================] - ETA: 0s - loss: 2.3455 - accuracy: 0.7442 - iou_coef: 0.6065 - dice_coef: 0.7445 - f1_score: 0.7466 - aggregated_jaccard_index: 0.6296
# ✅ Saved improved backbone at epoch 2 with val_iou=0.7285
# 171/171 [==============================] - 75s 440ms/step - loss: 2.3425 - accuracy: 0.7442 - iou_coef: 0.6065 - dice_coef: 0.7445 - f1_score: 0.7466 - aggregated_jaccard_index: 0.6296 - val_val_loss: 1.2082 - val_val_accuracy: 0.7929 - val_val_iou_coef: 0.7285 - val_val_dice_coef: 0.8397 - val_val_f1_score: 0.8416 - val_val_aggregated_jaccard_index: 0.7314 - lr: 0.0010
# Epoch 3/150
# 171/171 [==============================] - 67s 393ms/step - loss: 1.9249 - accuracy: 0.7971 - iou_coef: 0.6632 - dice_coef: 0.7873 - f1_score: 0.7887 - aggregated_jaccard_index: 0.6812 - val_val_loss: 2.5389 - val_val_accuracy: 0.6036 - val_val_iou_coef: 0.5786 - val_val_dice_coef: 0.7278 - val_val_f1_score: 0.7278 - val_val_aggregated_jaccard_index: 0.5941 - lr: 0.0010
# Epoch 4/150
# 171/171 [==============================] - 53s 310ms/step - loss: 1.6604 - accuracy: 0.8238 - iou_coef: 0.7001 - dice_coef: 0.8146 - f1_score: 0.8154 - aggregated_jaccard_index: 0.7150 - val_val_loss: 1.1225 - val_val_accuracy: 0.7903 - val_val_iou_coef: 0.7252 - val_val_dice_coef: 0.8332 - val_val_f1_score: 0.8341 - val_val_aggregated_jaccard_index: 0.7248 - lr: 0.0010
# Epoch 5/150
# 171/171 [==============================] - 71s 417ms/step - loss: 1.4985 - accuracy: 0.8377 - iou_coef: 0.7177 - dice_coef: 0.8278 - f1_score: 0.8284 - aggregated_jaccard_index: 0.7317 - val_val_loss: 1.5495 - val_val_accuracy: 0.6987 - val_val_iou_coef: 0.6659 - val_val_dice_coef: 0.7926 - val_val_f1_score: 0.7928 - val_val_aggregated_jaccard_index: 0.6789 - lr: 0.0010
# Epoch 6/150
# 171/171 [==============================] - 72s 422ms/step - loss: 1.3545 - accuracy: 0.8489 - iou_coef: 0.7348 - dice_coef: 0.8395 - f1_score: 0.8400 - aggregated_jaccard_index: 0.7464 - val_val_loss: 1.0437 - val_val_accuracy: 0.7845 - val_val_iou_coef: 0.6788 - val_val_dice_coef: 0.7914 - val_val_f1_score: 0.7916 - val_val_aggregated_jaccard_index: 0.6791 - lr: 0.0010
# Epoch 7/150
# 171/171 [==============================] - ETA: 0s - loss: 1.2578 - accuracy: 0.8557 - iou_coef: 0.7435 - dice_coef: 0.8450 - f1_score: 0.8454 - aggregated_jaccard_index: 0.7567
# ✅ Saved improved backbone at epoch 7 with val_iou=0.7938
# 171/171 [==============================] - 72s 423ms/step - loss: 1.2573 - accuracy: 0.8557 - iou_coef: 0.7435 - dice_coef: 0.8450 - f1_score: 0.8454 - aggregated_jaccard_index: 0.7567 - val_val_loss: 0.6619 - val_val_accuracy: 0.8330 - val_val_iou_coef: 0.7938 - val_val_dice_coef: 0.8822 - val_val_f1_score: 0.8826 - val_val_aggregated_jaccard_index: 0.7957 - lr: 0.0010
# Epoch 8/150
# 171/171 [==============================] - ETA: 0s - loss: 1.1897 - accuracy: 0.8577 - iou_coef: 0.7490 - dice_coef: 0.8493 - f1_score: 0.8496 - aggregated_jaccard_index: 0.7615
# ✅ Saved improved backbone at epoch 8 with val_iou=0.8360
# 171/171 [==============================] - 72s 424ms/step - loss: 1.1896 - accuracy: 0.8577 - iou_coef: 0.7490 - dice_coef: 0.8493 - f1_score: 0.8496 - aggregated_jaccard_index: 0.7615 - val_val_loss: 0.4654 - val_val_accuracy: 0.8802 - val_val_iou_coef: 0.8360 - val_val_dice_coef: 0.9071 - val_val_f1_score: 0.9074 - val_val_aggregated_jaccard_index: 0.8363 - lr: 0.0010
# Epoch 9/150
# 171/171 [==============================] - 73s 413ms/step - loss: 1.0866 - accuracy: 0.8661 - iou_coef: 0.7601 - dice_coef: 0.8564 - f1_score: 0.8566 - aggregated_jaccard_index: 0.7712 - val_val_loss: 0.4387 - val_val_accuracy: 0.8382 - val_val_iou_coef: 0.8137 - val_val_dice_coef: 0.8917 - val_val_f1_score: 0.8920 - val_val_aggregated_jaccard_index: 0.8150 - lr: 0.0010
# Epoch 10/150
# 171/171 [==============================] - 68s 400ms/step - loss: 1.0155 - accuracy: 0.8698 - iou_coef: 0.7662 - dice_coef: 0.8602 - f1_score: 0.8605 - aggregated_jaccard_index: 0.7790 - val_val_loss: 0.3963 - val_val_accuracy: 0.8391 - val_val_iou_coef: 0.7837 - val_val_dice_coef: 0.8675 - val_val_f1_score: 0.8677 - val_val_aggregated_jaccard_index: 0.7813 - lr: 0.0010
# Epoch 11/150
# 171/171 [==============================] - ETA: 0s - loss: 0.9534 - accuracy: 0.8731 - iou_coef: 0.7719 - dice_coef: 0.8642 - f1_score: 0.8644 - aggregated_jaccard_index: 0.7821
# ✅ Saved improved backbone at epoch 11 with val_iou=0.8380
# 171/171 [==============================] - 71s 415ms/step - loss: 0.9527 - accuracy: 0.8731 - iou_coef: 0.7719 - dice_coef: 0.8642 - f1_score: 0.8644 - aggregated_jaccard_index: 0.7821 - val_val_loss: 0.4148 - val_val_accuracy: 0.8793 - val_val_iou_coef: 0.8380 - val_val_dice_coef: 0.9069 - val_val_f1_score: 0.9071 - val_val_aggregated_jaccard_index: 0.8373 - lr: 0.0010
# Epoch 12/150
# 171/171 [==============================] - 73s 426ms/step - loss: 0.9107 - accuracy: 0.8727 - iou_coef: 0.7699 - dice_coef: 0.8627 - f1_score: 0.8629 - aggregated_jaccard_index: 0.7815 - val_val_loss: 0.4955 - val_val_accuracy: 0.8322 - val_val_iou_coef: 0.7638 - val_val_dice_coef: 0.8498 - val_val_f1_score: 0.8500 - val_val_aggregated_jaccard_index: 0.7614 - lr: 0.0010
# Epoch 13/150
# 171/171 [==============================] - 72s 420ms/step - loss: 0.8811 - accuracy: 0.8711 - iou_coef: 0.7702 - dice_coef: 0.8619 - f1_score: 0.8621 - aggregated_jaccard_index: 0.7819 - val_val_loss: 0.8635 - val_val_accuracy: 0.7520 - val_val_iou_coef: 0.7214 - val_val_dice_coef: 0.8320 - val_val_f1_score: 0.8321 - val_val_aggregated_jaccard_index: 0.7365 - lr: 0.0010
# Epoch 14/150
# 171/171 [==============================] - 72s 422ms/step - loss: 0.7723 - accuracy: 0.8823 - iou_coef: 0.7849 - dice_coef: 0.8730 - f1_score: 0.8731 - aggregated_jaccard_index: 0.7958 - val_val_loss: 0.3394 - val_val_accuracy: 0.8719 - val_val_iou_coef: 0.8347 - val_val_dice_coef: 0.9047 - val_val_f1_score: 0.9048 - val_val_aggregated_jaccard_index: 0.8340 - lr: 0.0010
# Epoch 15/150
# 171/171 [==============================] - 72s 424ms/step - loss: 0.7602 - accuracy: 0.8773 - iou_coef: 0.7797 - dice_coef: 0.8692 - f1_score: 0.8694 - aggregated_jaccard_index: 0.7892 - val_val_loss: 0.3209 - val_val_accuracy: 0.8486 - val_val_iou_coef: 0.7992 - val_val_dice_coef: 0.8788 - val_val_f1_score: 0.8789 - val_val_aggregated_jaccard_index: 0.7952 - lr: 0.0010
# Epoch 16/150
# 171/171 [==============================] - 72s 419ms/step - loss: 0.6898 - accuracy: 0.8825 - iou_coef: 0.7852 - dice_coef: 0.8729 - f1_score: 0.8730 - aggregated_jaccard_index: 0.7970 - val_val_loss: 0.3723 - val_val_accuracy: 0.8378 - val_val_iou_coef: 0.8053 - val_val_dice_coef: 0.8866 - val_val_f1_score: 0.8867 - val_val_aggregated_jaccard_index: 0.8180 - lr: 0.0010
# Epoch 17/150
# 171/171 [==============================] - 68s 399ms/step - loss: 0.6618 - accuracy: 0.8807 - iou_coef: 0.7843 - dice_coef: 0.8721 - f1_score: 0.8722 - aggregated_jaccard_index: 0.7961 - val_val_loss: 0.3961 - val_val_accuracy: 0.8074 - val_val_iou_coef: 0.7317 - val_val_dice_coef: 0.8233 - val_val_f1_score: 0.8233 - val_val_aggregated_jaccard_index: 0.7252 - lr: 0.0010
# Epoch 18/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5957 - accuracy: 0.8870 - iou_coef: 0.7933 - dice_coef: 0.8785 - f1_score: 0.8786 - aggregated_jaccard_index: 0.8037
# ✅ Saved improved backbone at epoch 18 with val_iou=0.8497
# 171/171 [==============================] - 73s 425ms/step - loss: 0.5955 - accuracy: 0.8870 - iou_coef: 0.7933 - dice_coef: 0.8785 - f1_score: 0.8786 - aggregated_jaccard_index: 0.8037 - val_val_loss: 0.2540 - val_val_accuracy: 0.8908 - val_val_iou_coef: 0.8497 - val_val_dice_coef: 0.9148 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8488 - lr: 0.0010
# Epoch 19/150
# 171/171 [==============================] - 72s 419ms/step - loss: 0.5556 - accuracy: 0.8886 - iou_coef: 0.7942 - dice_coef: 0.8789 - f1_score: 0.8790 - aggregated_jaccard_index: 0.8053 - val_val_loss: 0.2527 - val_val_accuracy: 0.8490 - val_val_iou_coef: 0.7878 - val_val_dice_coef: 0.8630 - val_val_f1_score: 0.8630 - val_val_aggregated_jaccard_index: 0.7871 - lr: 0.0010
# Epoch 20/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8937 - iou_coef: 0.8028 - dice_coef: 0.8844 - f1_score: 0.8845 - aggregated_jaccard_index: 0.8140
# ✅ Saved improved backbone at epoch 20 with val_iou=0.8544
# 171/171 [==============================] - 72s 423ms/step - loss: 0.5016 - accuracy: 0.8937 - iou_coef: 0.8028 - dice_coef: 0.8844 - f1_score: 0.8845 - aggregated_jaccard_index: 0.8140 - val_val_loss: 0.2218 - val_val_accuracy: 0.8989 - val_val_iou_coef: 0.8544 - val_val_dice_coef: 0.9184 - val_val_f1_score: 0.9184 - val_val_aggregated_jaccard_index: 0.8542 - lr: 0.0010
# Epoch 21/150
# 171/171 [==============================] - 74s 431ms/step - loss: 0.4678 - accuracy: 0.8941 - iou_coef: 0.8028 - dice_coef: 0.8845 - f1_score: 0.8845 - aggregated_jaccard_index: 0.8148 - val_val_loss: 0.2229 - val_val_accuracy: 0.8786 - val_val_iou_coef: 0.8355 - val_val_dice_coef: 0.9037 - val_val_f1_score: 0.9039 - val_val_aggregated_jaccard_index: 0.8333 - lr: 0.0010
# Epoch 22/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.4241 - accuracy: 0.8981 - iou_coef: 0.8102 - dice_coef: 0.8894 - f1_score: 0.8895 - aggregated_jaccard_index: 0.8210 - val_val_loss: 0.2344 - val_val_accuracy: 0.8244 - val_val_iou_coef: 0.7956 - val_val_dice_coef: 0.8769 - val_val_f1_score: 0.8769 - val_val_aggregated_jaccard_index: 0.7996 - lr: 0.0010
# Epoch 23/150
# 171/171 [==============================] - ETA: 0s - loss: 0.4063 - accuracy: 0.8958 - iou_coef: 0.8078 - dice_coef: 0.8877 - f1_score: 0.8877 - aggregated_jaccard_index: 0.8177
# ✅ Saved improved backbone at epoch 23 with val_iou=0.8550
# 171/171 [==============================] - 55s 322ms/step - loss: 0.4056 - accuracy: 0.8958 - iou_coef: 0.8078 - dice_coef: 0.8877 - f1_score: 0.8877 - aggregated_jaccard_index: 0.8177 - val_val_loss: 0.2007 - val_val_accuracy: 0.8918 - val_val_iou_coef: 0.8550 - val_val_dice_coef: 0.9188 - val_val_f1_score: 0.9189 - val_val_aggregated_jaccard_index: 0.8532 - lr: 0.0010
# Epoch 24/150
# 171/171 [==============================] - 52s 305ms/step - loss: 0.3792 - accuracy: 0.8961 - iou_coef: 0.8075 - dice_coef: 0.8877 - f1_score: 0.8878 - aggregated_jaccard_index: 0.8176 - val_val_loss: 0.1741 - val_val_accuracy: 0.8803 - val_val_iou_coef: 0.8308 - val_val_dice_coef: 0.8995 - val_val_f1_score: 0.8995 - val_val_aggregated_jaccard_index: 0.8293 - lr: 0.0010
# Epoch 25/150
# 171/171 [==============================] - ETA: 0s - loss: 0.3410 - accuracy: 0.9004 - iou_coef: 0.8139 - dice_coef: 0.8920 - f1_score: 0.8921 - aggregated_jaccard_index: 0.8232
# ✅ Saved improved backbone at epoch 25 with val_iou=0.8664
# 171/171 [==============================] - 55s 322ms/step - loss: 0.3407 - accuracy: 0.9004 - iou_coef: 0.8139 - dice_coef: 0.8920 - f1_score: 0.8921 - aggregated_jaccard_index: 0.8232 - val_val_loss: 0.1681 - val_val_accuracy: 0.8972 - val_val_iou_coef: 0.8664 - val_val_dice_coef: 0.9250 - val_val_f1_score: 0.9251 - val_val_aggregated_jaccard_index: 0.8656 - lr: 0.0010
# Epoch 26/150
# 171/171 [==============================] - 52s 304ms/step - loss: 0.3243 - accuracy: 0.8975 - iou_coef: 0.8087 - dice_coef: 0.8884 - f1_score: 0.8885 - aggregated_jaccard_index: 0.8194 - val_val_loss: 0.1503 - val_val_accuracy: 0.8951 - val_val_iou_coef: 0.8630 - val_val_dice_coef: 0.9231 - val_val_f1_score: 0.9232 - val_val_aggregated_jaccard_index: 0.8622 - lr: 0.0010
# Epoch 27/150
# 171/171 [==============================] - 54s 315ms/step - loss: 0.2778 - accuracy: 0.9064 - iou_coef: 0.8228 - dice_coef: 0.8977 - f1_score: 0.8978 - aggregated_jaccard_index: 0.8335 - val_val_loss: 0.1623 - val_val_accuracy: 0.8947 - val_val_iou_coef: 0.8569 - val_val_dice_coef: 0.9196 - val_val_f1_score: 0.9197 - val_val_aggregated_jaccard_index: 0.8573 - lr: 0.0010
# Epoch 28/150
# 171/171 [==============================] - 55s 320ms/step - loss: 0.2600 - accuracy: 0.9056 - iou_coef: 0.8211 - dice_coef: 0.8965 - f1_score: 0.8966 - aggregated_jaccard_index: 0.8319 - val_val_loss: 0.1222 - val_val_accuracy: 0.8995 - val_val_iou_coef: 0.8631 - val_val_dice_coef: 0.9216 - val_val_f1_score: 0.9217 - val_val_aggregated_jaccard_index: 0.8614 - lr: 0.0010
# Epoch 29/150
# 171/171 [==============================] - 53s 308ms/step - loss: 0.2451 - accuracy: 0.9039 - iou_coef: 0.8208 - dice_coef: 0.8967 - f1_score: 0.8968 - aggregated_jaccard_index: 0.8297 - val_val_loss: 0.1645 - val_val_accuracy: 0.8286 - val_val_iou_coef: 0.7544 - val_val_dice_coef: 0.8441 - val_val_f1_score: 0.8442 - val_val_aggregated_jaccard_index: 0.7535 - lr: 0.0010
# Epoch 30/150
# 171/171 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9026 - iou_coef: 0.8180 - dice_coef: 0.8951 - f1_score: 0.8951 - aggregated_jaccard_index: 0.8270
# ✅ Saved improved backbone at epoch 30 with val_iou=0.8683
# 171/171 [==============================] - 56s 327ms/step - loss: 0.2308 - accuracy: 0.9026 - iou_coef: 0.8180 - dice_coef: 0.8951 - f1_score: 0.8951 - aggregated_jaccard_index: 0.8270 - val_val_loss: 0.1043 - val_val_accuracy: 0.9062 - val_val_iou_coef: 0.8683 - val_val_dice_coef: 0.9249 - val_val_f1_score: 0.9250 - val_val_aggregated_jaccard_index: 0.8665 - lr: 0.0010
# Epoch 31/150
# 171/171 [==============================] - ETA: 0s - loss: 0.2022 - accuracy: 0.9080 - iou_coef: 0.8273 - dice_coef: 0.9009 - f1_score: 0.9010 - aggregated_jaccard_index: 0.8358
# ✅ Saved improved backbone at epoch 31 with val_iou=0.8813
# 171/171 [==============================] - 53s 308ms/step - loss: 0.2025 - accuracy: 0.9080 - iou_coef: 0.8273 - dice_coef: 0.9009 - f1_score: 0.9010 - aggregated_jaccard_index: 0.8358 - val_val_loss: 0.1021 - val_val_accuracy: 0.9182 - val_val_iou_coef: 0.8813 - val_val_dice_coef: 0.9348 - val_val_f1_score: 0.9348 - val_val_aggregated_jaccard_index: 0.8808 - lr: 0.0010
# Epoch 32/150
# 171/171 [==============================] - 54s 317ms/step - loss: 0.1861 - accuracy: 0.9089 - iou_coef: 0.8275 - dice_coef: 0.9005 - f1_score: 0.9006 - aggregated_jaccard_index: 0.8367 - val_val_loss: 0.0967 - val_val_accuracy: 0.8958 - val_val_iou_coef: 0.8474 - val_val_dice_coef: 0.9102 - val_val_f1_score: 0.9102 - val_val_aggregated_jaccard_index: 0.8473 - lr: 0.0010
# Epoch 33/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.1731 - accuracy: 0.9075 - iou_coef: 0.8264 - dice_coef: 0.9001 - f1_score: 0.9002 - aggregated_jaccard_index: 0.8361 - val_val_loss: 0.0891 - val_val_accuracy: 0.8904 - val_val_iou_coef: 0.8526 - val_val_dice_coef: 0.9175 - val_val_f1_score: 0.9175 - val_val_aggregated_jaccard_index: 0.8509 - lr: 0.0010
# Epoch 34/150
# 171/171 [==============================] - 55s 320ms/step - loss: 0.1539 - accuracy: 0.9116 - iou_coef: 0.8320 - dice_coef: 0.9035 - f1_score: 0.9036 - aggregated_jaccard_index: 0.8411 - val_val_loss: 0.1016 - val_val_accuracy: 0.8692 - val_val_iou_coef: 0.8224 - val_val_dice_coef: 0.8959 - val_val_f1_score: 0.8959 - val_val_aggregated_jaccard_index: 0.8229 - lr: 0.0010
# Epoch 35/150
# 171/171 [==============================] - 55s 319ms/step - loss: 0.1483 - accuracy: 0.9081 - iou_coef: 0.8253 - dice_coef: 0.8990 - f1_score: 0.8990 - aggregated_jaccard_index: 0.8353 - val_val_loss: 0.0736 - val_val_accuracy: 0.8892 - val_val_iou_coef: 0.8503 - val_val_dice_coef: 0.9160 - val_val_f1_score: 0.9161 - val_val_aggregated_jaccard_index: 0.8516 - lr: 0.0010
# Epoch 36/150
# 171/171 [==============================] - 53s 310ms/step - loss: 0.1292 - accuracy: 0.9129 - iou_coef: 0.8346 - dice_coef: 0.9053 - f1_score: 0.9054 - aggregated_jaccard_index: 0.8435 - val_val_loss: 0.0621 - val_val_accuracy: 0.8992 - val_val_iou_coef: 0.8637 - val_val_dice_coef: 0.9214 - val_val_f1_score: 0.9214 - val_val_aggregated_jaccard_index: 0.8622 - lr: 0.0010
# Epoch 37/150
# 171/171 [==============================] - 55s 322ms/step - loss: 0.1195 - accuracy: 0.9133 - iou_coef: 0.8339 - dice_coef: 0.9046 - f1_score: 0.9047 - aggregated_jaccard_index: 0.8439 - val_val_loss: 0.0610 - val_val_accuracy: 0.8763 - val_val_iou_coef: 0.8469 - val_val_dice_coef: 0.9121 - val_val_f1_score: 0.9122 - val_val_aggregated_jaccard_index: 0.8423 - lr: 0.0010
# Epoch 38/150
# 171/171 [==============================] - 54s 314ms/step - loss: 0.1188 - accuracy: 0.9058 - iou_coef: 0.8219 - dice_coef: 0.8972 - f1_score: 0.8972 - aggregated_jaccard_index: 0.8321 - val_val_loss: 0.0552 - val_val_accuracy: 0.8869 - val_val_iou_coef: 0.8385 - val_val_dice_coef: 0.9016 - val_val_f1_score: 0.9016 - val_val_aggregated_jaccard_index: 0.8374 - lr: 0.0010
# Epoch 39/150
# 171/171 [==============================] - 55s 323ms/step - loss: 0.1000 - accuracy: 0.9144 - iou_coef: 0.8369 - dice_coef: 0.9068 - f1_score: 0.9068 - aggregated_jaccard_index: 0.8448 - val_val_loss: 0.0500 - val_val_accuracy: 0.9102 - val_val_iou_coef: 0.8769 - val_val_dice_coef: 0.9311 - val_val_f1_score: 0.9311 - val_val_aggregated_jaccard_index: 0.8758 - lr: 0.0010
# Epoch 40/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.0910 - accuracy: 0.9157 - iou_coef: 0.8389 - dice_coef: 0.9082 - f1_score: 0.9083 - aggregated_jaccard_index: 0.8471 - val_val_loss: 0.0440 - val_val_accuracy: 0.8770 - val_val_iou_coef: 0.8528 - val_val_dice_coef: 0.9149 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8503 - lr: 0.0010
# Epoch 41/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9127 - iou_coef: 0.8341 - dice_coef: 0.9050 - f1_score: 0.9051 - aggregated_jaccard_index: 0.8436
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 171/171 [==============================] - 54s 317ms/step - loss: 0.0861 - accuracy: 0.9127 - iou_coef: 0.8341 - dice_coef: 0.9050 - f1_score: 0.9051 - aggregated_jaccard_index: 0.8436 - val_val_loss: 0.0487 - val_val_accuracy: 0.9040 - val_val_iou_coef: 0.8588 - val_val_dice_coef: 0.9180 - val_val_f1_score: 0.9181 - val_val_aggregated_jaccard_index: 0.8570 - lr: 0.0010
# Epoch 42/150
# 171/171 [==============================] - 55s 320ms/step - loss: 0.0756 - accuracy: 0.9211 - iou_coef: 0.8469 - dice_coef: 0.9132 - f1_score: 0.9132 - aggregated_jaccard_index: 0.8555 - val_val_loss: 0.0441 - val_val_accuracy: 0.9124 - val_val_iou_coef: 0.8758 - val_val_dice_coef: 0.9296 - val_val_f1_score: 0.9297 - val_val_aggregated_jaccard_index: 0.8745 - lr: 1.0000e-04
# Epoch 43/150
# 171/171 [==============================] - 53s 308ms/step - loss: 0.0737 - accuracy: 0.9225 - iou_coef: 0.8503 - dice_coef: 0.9153 - f1_score: 0.9153 - aggregated_jaccard_index: 0.8591 - val_val_loss: 0.0433 - val_val_accuracy: 0.9176 - val_val_iou_coef: 0.8794 - val_val_dice_coef: 0.9325 - val_val_f1_score: 0.9326 - val_val_aggregated_jaccard_index: 0.8778 - lr: 1.0000e-04
# Epoch 44/150
# 171/171 [==============================] - 55s 321ms/step - loss: 0.0729 - accuracy: 0.9233 - iou_coef: 0.8517 - dice_coef: 0.9162 - f1_score: 0.9162 - aggregated_jaccard_index: 0.8592 - val_val_loss: 0.0432 - val_val_accuracy: 0.9153 - val_val_iou_coef: 0.8766 - val_val_dice_coef: 0.9300 - val_val_f1_score: 0.9300 - val_val_aggregated_jaccard_index: 0.8753 - lr: 1.0000e-04
# Epoch 45/150
# 171/171 [==============================] - 53s 312ms/step - loss: 0.0708 - accuracy: 0.9245 - iou_coef: 0.8539 - dice_coef: 0.9175 - f1_score: 0.9176 - aggregated_jaccard_index: 0.8618 - val_val_loss: 0.0410 - val_val_accuracy: 0.9157 - val_val_iou_coef: 0.8795 - val_val_dice_coef: 0.9328 - val_val_f1_score: 0.9328 - val_val_aggregated_jaccard_index: 0.8778 - lr: 1.0000e-04
# Epoch 46/150
# 171/171 [==============================] - 69s 403ms/step - loss: 0.0702 - accuracy: 0.9247 - iou_coef: 0.8538 - dice_coef: 0.9175 - f1_score: 0.9175 - aggregated_jaccard_index: 0.8617 - val_val_loss: 0.0411 - val_val_accuracy: 0.9149 - val_val_iou_coef: 0.8784 - val_val_dice_coef: 0.9317 - val_val_f1_score: 0.9317 - val_val_aggregated_jaccard_index: 0.8772 - lr: 1.0000e-04
# Epoch 47/150
# 171/171 [==============================] - 72s 419ms/step - loss: 0.0686 - accuracy: 0.9251 - iou_coef: 0.8552 - dice_coef: 0.9184 - f1_score: 0.9185 - aggregated_jaccard_index: 0.8632 - val_val_loss: 0.0418 - val_val_accuracy: 0.9158 - val_val_iou_coef: 0.8765 - val_val_dice_coef: 0.9308 - val_val_f1_score: 0.9309 - val_val_aggregated_jaccard_index: 0.8752 - lr: 1.0000e-04
# Epoch 48/150
# 171/171 [==============================] - 74s 433ms/step - loss: 0.0681 - accuracy: 0.9253 - iou_coef: 0.8553 - dice_coef: 0.9184 - f1_score: 0.9185 - aggregated_jaccard_index: 0.8632 - val_val_loss: 0.0418 - val_val_accuracy: 0.9131 - val_val_iou_coef: 0.8729 - val_val_dice_coef: 0.9278 - val_val_f1_score: 0.9278 - val_val_aggregated_jaccard_index: 0.8717 - lr: 1.0000e-04
# Epoch 49/150
# 171/171 [==============================] - 68s 398ms/step - loss: 0.0675 - accuracy: 0.9253 - iou_coef: 0.8553 - dice_coef: 0.9185 - f1_score: 0.9186 - aggregated_jaccard_index: 0.8629 - val_val_loss: 0.0389 - val_val_accuracy: 0.9102 - val_val_iou_coef: 0.8766 - val_val_dice_coef: 0.9303 - val_val_f1_score: 0.9303 - val_val_aggregated_jaccard_index: 0.8749 - lr: 1.0000e-04
# Epoch 50/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.0667 - accuracy: 0.9260 - iou_coef: 0.8569 - dice_coef: 0.9194 - f1_score: 0.9195 - aggregated_jaccard_index: 0.8633 - val_val_loss: 0.0398 - val_val_accuracy: 0.9155 - val_val_iou_coef: 0.8790 - val_val_dice_coef: 0.9326 - val_val_f1_score: 0.9326 - val_val_aggregated_jaccard_index: 0.8771 - lr: 1.0000e-04
# Epoch 51/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0662 - accuracy: 0.9260 - iou_coef: 0.8557 - dice_coef: 0.9187 - f1_score: 0.9188 - aggregated_jaccard_index: 0.8627
# ✅ Saved improved backbone at epoch 51 with val_iou=0.8816
# 171/171 [==============================] - 55s 324ms/step - loss: 0.0661 - accuracy: 0.9260 - iou_coef: 0.8557 - dice_coef: 0.9187 - f1_score: 0.9188 - aggregated_jaccard_index: 0.8627 - val_val_loss: 0.0396 - val_val_accuracy: 0.9204 - val_val_iou_coef: 0.8816 - val_val_dice_coef: 0.9342 - val_val_f1_score: 0.9343 - val_val_aggregated_jaccard_index: 0.8804 - lr: 1.0000e-04
# Epoch 52/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.0644 - accuracy: 0.9272 - iou_coef: 0.8581 - dice_coef: 0.9201 - f1_score: 0.9202 - aggregated_jaccard_index: 0.8653 - val_val_loss: 0.0376 - val_val_accuracy: 0.9134 - val_val_iou_coef: 0.8784 - val_val_dice_coef: 0.9319 - val_val_f1_score: 0.9319 - val_val_aggregated_jaccard_index: 0.8764 - lr: 1.0000e-04
# Epoch 53/150
# 171/171 [==============================] - 55s 320ms/step - loss: 0.0636 - accuracy: 0.9270 - iou_coef: 0.8581 - dice_coef: 0.9202 - f1_score: 0.9203 - aggregated_jaccard_index: 0.8653 - val_val_loss: 0.0358 - val_val_accuracy: 0.9140 - val_val_iou_coef: 0.8806 - val_val_dice_coef: 0.9325 - val_val_f1_score: 0.9325 - val_val_aggregated_jaccard_index: 0.8790 - lr: 1.0000e-04
# Epoch 54/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0631 - accuracy: 0.9273 - iou_coef: 0.8584 - dice_coef: 0.9203 - f1_score: 0.9204 - aggregated_jaccard_index: 0.8652
# ✅ Saved improved backbone at epoch 54 with val_iou=0.8858
# 171/171 [==============================] - 54s 314ms/step - loss: 0.0630 - accuracy: 0.9273 - iou_coef: 0.8584 - dice_coef: 0.9203 - f1_score: 0.9204 - aggregated_jaccard_index: 0.8652 - val_val_loss: 0.0373 - val_val_accuracy: 0.9233 - val_val_iou_coef: 0.8858 - val_val_dice_coef: 0.9364 - val_val_f1_score: 0.9365 - val_val_aggregated_jaccard_index: 0.8852 - lr: 1.0000e-04
# Epoch 55/150
# 171/171 [==============================] - 56s 325ms/step - loss: 0.0616 - accuracy: 0.9275 - iou_coef: 0.8583 - dice_coef: 0.9203 - f1_score: 0.9203 - aggregated_jaccard_index: 0.8661 - val_val_loss: 0.0362 - val_val_accuracy: 0.9156 - val_val_iou_coef: 0.8781 - val_val_dice_coef: 0.9306 - val_val_f1_score: 0.9306 - val_val_aggregated_jaccard_index: 0.8770 - lr: 1.0000e-04
# Epoch 56/150
# 171/171 [==============================] - 55s 322ms/step - loss: 0.0613 - accuracy: 0.9273 - iou_coef: 0.8589 - dice_coef: 0.9207 - f1_score: 0.9207 - aggregated_jaccard_index: 0.8654 - val_val_loss: 0.0379 - val_val_accuracy: 0.9142 - val_val_iou_coef: 0.8746 - val_val_dice_coef: 0.9287 - val_val_f1_score: 0.9287 - val_val_aggregated_jaccard_index: 0.8729 - lr: 1.0000e-04
# Epoch 57/150
# 171/171 [==============================] - 53s 308ms/step - loss: 0.0603 - accuracy: 0.9274 - iou_coef: 0.8587 - dice_coef: 0.9206 - f1_score: 0.9206 - aggregated_jaccard_index: 0.8661 - val_val_loss: 0.0378 - val_val_accuracy: 0.9110 - val_val_iou_coef: 0.8707 - val_val_dice_coef: 0.9254 - val_val_f1_score: 0.9254 - val_val_aggregated_jaccard_index: 0.8686 - lr: 1.0000e-04
# Epoch 58/150
# 171/171 [==============================] - 55s 324ms/step - loss: 0.0592 - accuracy: 0.9281 - iou_coef: 0.8597 - dice_coef: 0.9212 - f1_score: 0.9213 - aggregated_jaccard_index: 0.8671 - val_val_loss: 0.0347 - val_val_accuracy: 0.9018 - val_val_iou_coef: 0.8698 - val_val_dice_coef: 0.9244 - val_val_f1_score: 0.9244 - val_val_aggregated_jaccard_index: 0.8673 - lr: 1.0000e-04
# Epoch 59/150
# 171/171 [==============================] - 53s 311ms/step - loss: 0.0583 - accuracy: 0.9284 - iou_coef: 0.8609 - dice_coef: 0.9220 - f1_score: 0.9220 - aggregated_jaccard_index: 0.8683 - val_val_loss: 0.0353 - val_val_accuracy: 0.9073 - val_val_iou_coef: 0.8723 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9270 - val_val_aggregated_jaccard_index: 0.8700 - lr: 1.0000e-04
# Epoch 60/150
# 171/171 [==============================] - 55s 322ms/step - loss: 0.0572 - accuracy: 0.9289 - iou_coef: 0.8614 - dice_coef: 0.9223 - f1_score: 0.9224 - aggregated_jaccard_index: 0.8686 - val_val_loss: 0.0336 - val_val_accuracy: 0.9052 - val_val_iou_coef: 0.8722 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9271 - val_val_aggregated_jaccard_index: 0.8700 - lr: 1.0000e-04
# Epoch 61/150
# 171/171 [==============================] - 55s 323ms/step - loss: 0.0570 - accuracy: 0.9285 - iou_coef: 0.8605 - dice_coef: 0.9218 - f1_score: 0.9218 - aggregated_jaccard_index: 0.8674 - val_val_loss: 0.0333 - val_val_accuracy: 0.9104 - val_val_iou_coef: 0.8736 - val_val_dice_coef: 0.9261 - val_val_f1_score: 0.9262 - val_val_aggregated_jaccard_index: 0.8718 - lr: 1.0000e-04
# Epoch 62/150
# 171/171 [==============================] - 53s 310ms/step - loss: 0.0567 - accuracy: 0.9286 - iou_coef: 0.8614 - dice_coef: 0.9224 - f1_score: 0.9224 - aggregated_jaccard_index: 0.8669 - val_val_loss: 0.0330 - val_val_accuracy: 0.9084 - val_val_iou_coef: 0.8724 - val_val_dice_coef: 0.9260 - val_val_f1_score: 0.9260 - val_val_aggregated_jaccard_index: 0.8700 - lr: 1.0000e-04
# Epoch 63/150
# 171/171 [==============================] - 55s 322ms/step - loss: 0.0552 - accuracy: 0.9291 - iou_coef: 0.8621 - dice_coef: 0.9227 - f1_score: 0.9228 - aggregated_jaccard_index: 0.8684 - val_val_loss: 0.0354 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.8686 - val_val_dice_coef: 0.9241 - val_val_f1_score: 0.9241 - val_val_aggregated_jaccard_index: 0.8658 - lr: 1.0000e-04
# Epoch 64/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.9292 - iou_coef: 0.8619 - dice_coef: 0.9226 - f1_score: 0.9226 - aggregated_jaccard_index: 0.8686
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 171/171 [==============================] - 53s 308ms/step - loss: 0.0543 - accuracy: 0.9292 - iou_coef: 0.8619 - dice_coef: 0.9226 - f1_score: 0.9226 - aggregated_jaccard_index: 0.8686 - val_val_loss: 0.0348 - val_val_accuracy: 0.9101 - val_val_iou_coef: 0.8705 - val_val_dice_coef: 0.9258 - val_val_f1_score: 0.9259 - val_val_aggregated_jaccard_index: 0.8681 - lr: 1.0000e-04
# Epoch 65/150
# 171/171 [==============================] - 54s 317ms/step - loss: 0.0534 - accuracy: 0.9301 - iou_coef: 0.8642 - dice_coef: 0.9241 - f1_score: 0.9241 - aggregated_jaccard_index: 0.8702 - val_val_loss: 0.0336 - val_val_accuracy: 0.9094 - val_val_iou_coef: 0.8720 - val_val_dice_coef: 0.9266 - val_val_f1_score: 0.9267 - val_val_aggregated_jaccard_index: 0.8696 - lr: 1.0000e-05
# Epoch 66/150
# 171/171 [==============================] - 54s 313ms/step - loss: 0.0525 - accuracy: 0.9309 - iou_coef: 0.8652 - dice_coef: 0.9247 - f1_score: 0.9247 - aggregated_jaccard_index: 0.8720 - val_val_loss: 0.0334 - val_val_accuracy: 0.9088 - val_val_iou_coef: 0.8717 - val_val_dice_coef: 0.9264 - val_val_f1_score: 0.9264 - val_val_aggregated_jaccard_index: 0.8693 - lr: 1.0000e-05
# Epoch 67/150
# 171/171 [==============================] - 55s 319ms/step - loss: 0.0530 - accuracy: 0.9302 - iou_coef: 0.8643 - dice_coef: 0.9242 - f1_score: 0.9242 - aggregated_jaccard_index: 0.8708 - val_val_loss: 0.0333 - val_val_accuracy: 0.9087 - val_val_iou_coef: 0.8717 - val_val_dice_coef: 0.9265 - val_val_f1_score: 0.9266 - val_val_aggregated_jaccard_index: 0.8693 - lr: 1.0000e-05
# Epoch 68/150
# 171/171 [==============================] - 53s 311ms/step - loss: 0.0524 - accuracy: 0.9309 - iou_coef: 0.8650 - dice_coef: 0.9245 - f1_score: 0.9246 - aggregated_jaccard_index: 0.8719 - val_val_loss: 0.0334 - val_val_accuracy: 0.9094 - val_val_iou_coef: 0.8724 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9270 - val_val_aggregated_jaccard_index: 0.8701 - lr: 1.0000e-05
# Epoch 69/150
# 171/171 [==============================] - 55s 323ms/step - loss: 0.0526 - accuracy: 0.9311 - iou_coef: 0.8652 - dice_coef: 0.9247 - f1_score: 0.9249 - aggregated_jaccard_index: 0.8715 - val_val_loss: 0.0330 - val_val_accuracy: 0.9088 - val_val_iou_coef: 0.8719 - val_val_dice_coef: 0.9267 - val_val_f1_score: 0.9268 - val_val_aggregated_jaccard_index: 0.8695 - lr: 1.0000e-05
# Epoch 70/150
# 171/171 [==============================] - 53s 310ms/step - loss: 0.0516 - accuracy: 0.9309 - iou_coef: 0.8660 - dice_coef: 0.9252 - f1_score: 0.9253 - aggregated_jaccard_index: 0.8732 - val_val_loss: 0.0328 - val_val_accuracy: 0.9105 - val_val_iou_coef: 0.8737 - val_val_dice_coef: 0.9279 - val_val_f1_score: 0.9278 - val_val_aggregated_jaccard_index: 0.8712 - lr: 1.0000e-05
# Epoch 71/150
# 171/171 [==============================] - 54s 319ms/step - loss: 0.0526 - accuracy: 0.9304 - iou_coef: 0.8646 - dice_coef: 0.9242 - f1_score: 0.9243 - aggregated_jaccard_index: 0.8707 - val_val_loss: 0.0327 - val_val_accuracy: 0.9103 - val_val_iou_coef: 0.8738 - val_val_dice_coef: 0.9280 - val_val_f1_score: 0.9281 - val_val_aggregated_jaccard_index: 0.8714 - lr: 1.0000e-05
# Epoch 72/150
# 171/171 [==============================] - 54s 318ms/step - loss: 0.0516 - accuracy: 0.9314 - iou_coef: 0.8667 - dice_coef: 0.9256 - f1_score: 0.9256 - aggregated_jaccard_index: 0.8733 - val_val_loss: 0.0327 - val_val_accuracy: 0.9103 - val_val_iou_coef: 0.8738 - val_val_dice_coef: 0.9280 - val_val_f1_score: 0.9280 - val_val_aggregated_jaccard_index: 0.8715 - lr: 1.0000e-05
# Epoch 73/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.0525 - accuracy: 0.9310 - iou_coef: 0.8653 - dice_coef: 0.9246 - f1_score: 0.9247 - aggregated_jaccard_index: 0.8719 - val_val_loss: 0.0326 - val_val_accuracy: 0.9104 - val_val_iou_coef: 0.8737 - val_val_dice_coef: 0.9280 - val_val_f1_score: 0.9280 - val_val_aggregated_jaccard_index: 0.8714 - lr: 1.0000e-05
# Epoch 74/150
# 171/171 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9312 - iou_coef: 0.8657 - dice_coef: 0.9249 - f1_score: 0.9250 - aggregated_jaccard_index: 0.8717
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 55s 320ms/step - loss: 0.0520 - accuracy: 0.9312 - iou_coef: 0.8657 - dice_coef: 0.9249 - f1_score: 0.9250 - aggregated_jaccard_index: 0.8717 - val_val_loss: 0.0323 - val_val_accuracy: 0.9099 - val_val_iou_coef: 0.8734 - val_val_dice_coef: 0.9277 - val_val_f1_score: 0.9277 - val_val_aggregated_jaccard_index: 0.8709 - lr: 1.0000e-05
# Epoch 75/150
# 171/171 [==============================] - 52s 305ms/step - loss: 0.0518 - accuracy: 0.9315 - iou_coef: 0.8660 - dice_coef: 0.9251 - f1_score: 0.9252 - aggregated_jaccard_index: 0.8723 - val_val_loss: 0.0326 - val_val_accuracy: 0.9100 - val_val_iou_coef: 0.8730 - val_val_dice_coef: 0.9273 - val_val_f1_score: 0.9274 - val_val_aggregated_jaccard_index: 0.8706 - lr: 1.0000e-05
# Epoch 76/150
# 171/171 [==============================] - 57s 331ms/step - loss: 0.0520 - accuracy: 0.9312 - iou_coef: 0.8657 - dice_coef: 0.9249 - f1_score: 0.9249 - aggregated_jaccard_index: 0.8716 - val_val_loss: 0.0325 - val_val_accuracy: 0.9097 - val_val_iou_coef: 0.8726 - val_val_dice_coef: 0.9270 - val_val_f1_score: 0.9270 - val_val_aggregated_jaccard_index: 0.8702 - lr: 1.0000e-05
# Epoch 77/150
# 171/171 [==============================] - 53s 308ms/step - loss: 0.0510 - accuracy: 0.9319 - iou_coef: 0.8664 - dice_coef: 0.9253 - f1_score: 0.9254 - aggregated_jaccard_index: 0.8741 - val_val_loss: 0.0322 - val_val_accuracy: 0.9094 - val_val_iou_coef: 0.8730 - val_val_dice_coef: 0.9276 - val_val_f1_score: 0.9276 - val_val_aggregated_jaccard_index: 0.8706 - lr: 1.0000e-05
# Epoch 78/150
# 171/171 [==============================] - 54s 318ms/step - loss: 0.0512 - accuracy: 0.9319 - iou_coef: 0.8671 - dice_coef: 0.9258 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8732 - val_val_loss: 0.0323 - val_val_accuracy: 0.9098 - val_val_iou_coef: 0.8730 - val_val_dice_coef: 0.9274 - val_val_f1_score: 0.9274 - val_val_aggregated_jaccard_index: 0.8706 - lr: 1.0000e-05
# Epoch 79/150
# 171/171 [==============================] - 63s 366ms/step - loss: 0.0513 - accuracy: 0.9318 - iou_coef: 0.8668 - dice_coef: 0.9257 - f1_score: 0.9257 - aggregated_jaccard_index: 0.8729 - val_val_loss: 0.0319 - val_val_accuracy: 0.9111 - val_val_iou_coef: 0.8749 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9286 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 80/150
# 171/171 [==============================] - 71s 418ms/step - loss: 0.0515 - accuracy: 0.9316 - iou_coef: 0.8671 - dice_coef: 0.9259 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8727 - val_val_loss: 0.0321 - val_val_accuracy: 0.9118 - val_val_iou_coef: 0.8751 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9287 - val_val_aggregated_jaccard_index: 0.8727 - lr: 1.0000e-05
# Epoch 81/150
# 171/171 [==============================] - 64s 372ms/step - loss: 0.0511 - accuracy: 0.9313 - iou_coef: 0.8669 - dice_coef: 0.9257 - f1_score: 0.9257 - aggregated_jaccard_index: 0.8732 - val_val_loss: 0.0320 - val_val_accuracy: 0.9113 - val_val_iou_coef: 0.8749 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9286 - val_val_aggregated_jaccard_index: 0.8723 - lr: 1.0000e-05
# Epoch 82/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.0511 - accuracy: 0.9318 - iou_coef: 0.8666 - dice_coef: 0.9254 - f1_score: 0.9255 - aggregated_jaccard_index: 0.8723 - val_val_loss: 0.0324 - val_val_accuracy: 0.9119 - val_val_iou_coef: 0.8749 - val_val_dice_coef: 0.9288 - val_val_f1_score: 0.9288 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 83/150
# 171/171 [==============================] - 61s 355ms/step - loss: 0.0505 - accuracy: 0.9317 - iou_coef: 0.8663 - dice_coef: 0.9253 - f1_score: 0.9253 - aggregated_jaccard_index: 0.8738 - val_val_loss: 0.0320 - val_val_accuracy: 0.9098 - val_val_iou_coef: 0.8731 - val_val_dice_coef: 0.9273 - val_val_f1_score: 0.9273 - val_val_aggregated_jaccard_index: 0.8706 - lr: 1.0000e-05
# Epoch 84/150
# 171/171 [==============================] - 70s 412ms/step - loss: 0.0502 - accuracy: 0.9324 - iou_coef: 0.8680 - dice_coef: 0.9264 - f1_score: 0.9264 - aggregated_jaccard_index: 0.8747 - val_val_loss: 0.0318 - val_val_accuracy: 0.9103 - val_val_iou_coef: 0.8737 - val_val_dice_coef: 0.9278 - val_val_f1_score: 0.9278 - val_val_aggregated_jaccard_index: 0.8713 - lr: 1.0000e-05
# Epoch 85/150
# 171/171 [==============================] - 55s 320ms/step - loss: 0.0502 - accuracy: 0.9322 - iou_coef: 0.8672 - dice_coef: 0.9259 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8743 - val_val_loss: 0.0324 - val_val_accuracy: 0.9095 - val_val_iou_coef: 0.8727 - val_val_dice_coef: 0.9272 - val_val_f1_score: 0.9272 - val_val_aggregated_jaccard_index: 0.8703 - lr: 1.0000e-05
# Epoch 86/150
# 171/171 [==============================] - 52s 304ms/step - loss: 0.0507 - accuracy: 0.9318 - iou_coef: 0.8668 - dice_coef: 0.9257 - f1_score: 0.9257 - aggregated_jaccard_index: 0.8733 - val_val_loss: 0.0321 - val_val_accuracy: 0.9117 - val_val_iou_coef: 0.8748 - val_val_dice_coef: 0.9286 - val_val_f1_score: 0.9286 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 87/150
# 171/171 [==============================] - 55s 322ms/step - loss: 0.0505 - accuracy: 0.9318 - iou_coef: 0.8665 - dice_coef: 0.9255 - f1_score: 0.9255 - aggregated_jaccard_index: 0.8735 - val_val_loss: 0.0321 - val_val_accuracy: 0.9118 - val_val_iou_coef: 0.8747 - val_val_dice_coef: 0.9284 - val_val_f1_score: 0.9285 - val_val_aggregated_jaccard_index: 0.8725 - lr: 1.0000e-05
# Epoch 88/150
# 171/171 [==============================] - 65s 380ms/step - loss: 0.0506 - accuracy: 0.9317 - iou_coef: 0.8661 - dice_coef: 0.9251 - f1_score: 0.9252 - aggregated_jaccard_index: 0.8729 - val_val_loss: 0.0324 - val_val_accuracy: 0.9101 - val_val_iou_coef: 0.8733 - val_val_dice_coef: 0.9279 - val_val_f1_score: 0.9279 - val_val_aggregated_jaccard_index: 0.8708 - lr: 1.0000e-05
# Epoch 89/150
# 171/171 [==============================] - 72s 423ms/step - loss: 0.0500 - accuracy: 0.9324 - iou_coef: 0.8678 - dice_coef: 0.9263 - f1_score: 0.9263 - aggregated_jaccard_index: 0.8744 - val_val_loss: 0.0320 - val_val_accuracy: 0.9115 - val_val_iou_coef: 0.8746 - val_val_dice_coef: 0.9288 - val_val_f1_score: 0.9288 - val_val_aggregated_jaccard_index: 0.8724 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image
# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size = 256
batch_size = 72

# -----------------------------
# NORMALIZE FILENAMES (ONCE)
# -----------------------------
def lowercase_filenames(dir_path):
    for p in glob(os.path.join(dir_path, "*")):
        base = os.path.basename(p)
        lower = base.lower()
        if base != lower:
            os.rename(p, os.path.join(dir_path, lower))

lowercase_filenames(IMG_DIR)
lowercase_filenames(MSK_DIR)

# -----------------------------
# COLLECT PATHS
# -----------------------------
def valid_name(p):
    return "zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)
mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# KEY-BASED ALIGNMENT (SOURCE OF TRUTH)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

img_map = {stem(p): p for p in image_paths}
msk_map = {stem(p): p for p in mask_paths}

common_keys = sorted(img_map.keys() & msk_map.keys())
assert len(common_keys) > 0, "No aligned image–mask pairs found"

image_paths = [img_map[k] for k in common_keys]
mask_paths  = [msk_map[k] for k in common_keys]

print("Aligned pairs:", len(common_keys))

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )
    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.asarray(img, dtype=np.float32) / 255.0
    mask = (np.asarray(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:",
      tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 80
# Masks found : 80
# Aligned pairs: 80
# Validation batches: 2

# %%
import gc
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Let TF grow GPU memory instead of grabbing it all upfront ---
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass  # must be set before GPUs are initialized; ignore if already set

CLEAR_EVERY = 10  # clear_session + gc every N batches

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for i, (imgs, masks) in enumerate(test_dataset):
    try:
        preds = model.predict(imgs, verbose=0)
    except tf.errors.ResourceExhaustedError:
        print(f"OOM at batch {i}, retrying after clearing session")
        tf.keras.backend.clear_session()
        gc.collect()
        preds = model.predict(imgs, verbose=0)

    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]
    else:
        seg_preds = preds

    preds_bin = (np.asarray(seg_preds) > 0.5).astype("float32")

    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else np.asarray(masks)
    preds_np = preds_bin

    if masks_np.shape != preds_np.shape:
        # do resize on CPU via numpy path instead of tf.image on GPU
        with tf.device('/CPU:0'):
            preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    masks_flat = np.round(masks_np.reshape(-1)).astype(int)
    preds_flat = np.round(preds_np.reshape(-1)).astype(int)

    # --- Force custom metric ops onto CPU to keep GPU memory free ---
    with tf.device('/CPU:0'):
        iou_val = float(iou_coef(masks_np, preds_np).numpy())
        dice_val = float(dice_coef(masks_np, preds_np).numpy())
        aji_val = float(aggregated_jaccard_index(masks_np, preds_np).numpy())

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

    # --- Explicitly drop references so GPU/host memory can be reclaimed ---
    del preds, seg_preds, preds_bin, masks_np, preds_np, masks_flat, preds_flat

    if (i + 1) % CLEAR_EVERY == 0:
        gc.collect()
        tf.keras.backend.clear_session()
        # NOTE: clear_session() drops the compiled model's session state on
        # some TF versions but keeps the model object usable for .predict();
        # if you see the model "forget" weights after this, remove the
        # clear_session() call and rely on gc.collect() alone.

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8329
# Mean Dice Coefficient: 0.9038
# Mean AJI:              0.8396
# Mean Accuracy:         0.8987
# Mean F1 Score:         0.9067

# %%
import gc
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use("Agg")  # non-interactive backend — avoids figure/backend memory buildup over many saves
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from tensorflow.keras.optimizers import AdamW
import os

# --- Let TF grow GPU memory instead of grabbing it all upfront ---
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass  # must be set before GPUs are initialized; ignore if already set

# ---------------------------------------------------------
# 1️⃣ Import custom layers and metrics (must match training)
# ---------------------------------------------------------
# from your_model_file import (
#     IoUMetric, DiceMetric, F1Metric, AJIMetric,
#     DualBranchCanvasUpsample2D_SpatialGate, conv_block
# )

custom_objects = {
    "DiceMetric": DiceMetric,
    "F1Metric": F1Metric,
    "AJIMetric": AJIMetric,
}

# ---------------------------------------------------------
# 2️⃣ Load model
# ---------------------------------------------------------
model = tf.keras.models.load_model(
    "./unet_canvas_3v8.keras",
    custom_objects=custom_objects,
    compile=False, safe_mode=False
)
print("✅ CanvasAttentionUNet loaded successfully.")

# Optional: compile with metrics for evaluation
model.compile(
    optimizer=AdamW(1e-10),
    loss="binary_crossentropy",
    metrics=[IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()]
)

# ---------------------------------------------------------
# 3️⃣ Chunked inference helper
# ---------------------------------------------------------
# The outer batch size (72) is fixed by test_dataset and can't change.
# Instead, we split each 72-sample batch into smaller GPU-sized sub-chunks
# internally, run the model on each sub-chunk, and concatenate the outputs
# back into full-batch tensors before continuing — so nothing downstream
# needs to know this happened.

INFER_CHUNK = 8  # tune down if still OOMing, up if you have headroom

def infer_in_chunks(model, images, chunk=INFER_CHUNK):
    n = images.shape[0]
    y_preds, centers, boundaries = [], [], []

    for start in range(0, n, chunk):
        sub = images[start:start + chunk]
        try:
            yp, cm, bm = model(sub, training=False)
        except tf.errors.ResourceExhaustedError:
            # halve the sub-chunk once and retry, in case even `chunk` is too big
            gc.collect()
            half = max(1, sub.shape[0] // 2)
            print(f"  OOM on sub-chunk of size {sub.shape[0]}, retrying at {half}")
            yp_parts, cm_parts, bm_parts = [], [], []
            for s2 in range(0, sub.shape[0], half):
                sub2 = sub[s2:s2 + half]
                yp2, cm2, bm2 = model(sub2, training=False)
                yp_parts.append(yp2)
                cm_parts.append(cm2)
                bm_parts.append(bm2)
            yp = tf.concat(yp_parts, axis=0)
            cm = [tf.concat([c[lvl] for c in [cm_parts[i] for i in range(len(cm_parts))]], axis=0)
                  for lvl in range(len(cm_parts[0]))] if isinstance(cm_parts[0], (list, tuple)) else tf.concat(cm_parts, axis=0)
            bm = [tf.concat([b[lvl] for b in [bm_parts[i] for i in range(len(bm_parts))]], axis=0)
                  for lvl in range(len(bm_parts[0]))] if isinstance(bm_parts[0], (list, tuple)) else tf.concat(bm_parts, axis=0)
            del yp_parts, cm_parts, bm_parts

        y_preds.append(yp)
        centers.append(cm)
        boundaries.append(bm)
        del yp, cm, bm, sub

    y_pred_full = tf.concat(y_preds, axis=0)

    # center_maps / boundary_maps are lists-of-levels (you index [-1] later),
    # so concatenate per-level across sub-chunks rather than the outer list.
    if isinstance(centers[0], (list, tuple)):
        n_levels = len(centers[0])
        center_full = [tf.concat([c[lvl] for c in centers], axis=0) for lvl in range(n_levels)]
    else:
        center_full = tf.concat(centers, axis=0)

    if isinstance(boundaries[0], (list, tuple)):
        n_levels = len(boundaries[0])
        boundary_full = [tf.concat([b[lvl] for b in boundaries], axis=0) for lvl in range(n_levels)]
    else:
        boundary_full = tf.concat(boundaries, axis=0)

    del y_preds, centers, boundaries
    return y_pred_full, center_full, boundary_full

# ---------------------------------------------------------
# 4️⃣ Inference + Save Visualizations
# ---------------------------------------------------------
save_dir = "./canvas_results3v8"
os.makedirs(save_dir, exist_ok=True)

CLEAR_EVERY = 20  # gc every N saved samples, to stop slow memory creep

sample_idx = 0  # global counter for filenames

for batch_idx, (images, masks) in enumerate(test_dataset):
    y_pred, center_maps, boundary_maps = infer_in_chunks(model, images, chunk=INFER_CHUNK)

    preds_bin = tf.cast(y_pred > 0.5, tf.float32)
    batch_size = images.shape[0]

    # Convert masks
    if len(masks.shape) == 4 and masks.shape[-1] > 1:
        masks_label = tf.argmax(masks, axis=-1)
    else:
        masks_label = tf.squeeze(masks, axis=-1)

    if preds_bin.shape[-1] > 1:
        preds_label = tf.argmax(preds_bin, axis=-1)
    else:
        preds_label = tf.squeeze(preds_bin, axis=-1)

    # -------------------------
    # Pull everything to numpy ONCE per batch
    # -------------------------
    images_np = images.numpy()
    preds_label_np = preds_label.numpy()
    masks_label_np = masks_label.numpy()
    center_np_batch = center_maps[-1][..., 0].numpy()
    boundary_np_batch = boundary_maps[-1][..., 0].numpy()

    # -------------------------
    # Save all samples in batch
    # -------------------------
    for i in range(batch_size):
        sample_idx += 1  # keep global sample numbering

        fig, axes = plt.subplots(1, 5, figsize=(18, 4))

        img_np = images_np[i]
        pred_np = preds_label_np[i]
        mask_np = masks_label_np[i]
        center_np = center_np_batch[i]
        boundary_np = boundary_np_batch[i]

        # 1️⃣ Original image
        axes[0].imshow(img_np)
        axes[0].set_title("Original Image")
        axes[0].axis("off")

        # 2️⃣ Predicted segmentation
        axes[1].imshow(label2rgb(pred_np, bg_label=0))
        axes[1].set_title("Predicted Segmentation")
        axes[1].axis("off")

        # 3️⃣ Ground truth
        axes[2].imshow(label2rgb(mask_np, bg_label=0))
        axes[2].set_title("Ground Truth")
        axes[2].axis("off")

        # 4️⃣ Center map
        axes[3].imshow(center_np, cmap="magma")
        axes[3].set_title("Center Map (final)")
        axes[3].axis("off")

        # 5️⃣ Boundary map
        axes[4].imshow(boundary_np, cmap="cividis")
        axes[4].set_title("Boundary Map (final)")
        axes[4].axis("off")

        plt.tight_layout()

        save_path = os.path.join(save_dir, f"sample_{sample_idx:04d}.png")
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        plt.close(fig)  # already present — critical, keep it

        print(f"✅ Saved {save_path}")

        if sample_idx % CLEAR_EVERY == 0:
            plt.close('all')  # belt-and-suspenders in case any figure leaked
            gc.collect()

    # --- Explicitly drop batch-level GPU/host refs before next iteration ---
    del (y_pred, center_maps, boundary_maps, preds_bin, masks_label, preds_label,
         images_np, preds_label_np, masks_label_np, center_np_batch, boundary_np_batch)

print(f"\n🎯 All {sample_idx} test images processed and saved to '{save_dir}'")
# Out:
# ✅ CanvasAttentionUNet loaded successfully.
# ✅ Saved ./canvas_results3v8/sample_0001.png
# ✅ Saved ./canvas_results3v8/sample_0002.png
# ✅ Saved ./canvas_results3v8/sample_0003.png
# ✅ Saved ./canvas_results3v8/sample_0004.png
# ✅ Saved ./canvas_results3v8/sample_0005.png
# ✅ Saved ./canvas_results3v8/sample_0006.png
# ✅ Saved ./canvas_results3v8/sample_0007.png
# ✅ Saved ./canvas_results3v8/sample_0008.png
# ✅ Saved ./canvas_results3v8/sample_0009.png
# ✅ Saved ./canvas_results3v8/sample_0010.png
# ✅ Saved ./canvas_results3v8/sample_0011.png
# ✅ Saved ./canvas_results3v8/sample_0012.png
# ✅ Saved ./canvas_results3v8/sample_0013.png
# ✅ Saved ./canvas_results3v8/sample_0014.png
# ✅ Saved ./canvas_results3v8/sample_0015.png
# ✅ Saved ./canvas_results3v8/sample_0016.png
# ✅ Saved ./canvas_results3v8/sample_0017.png
# ✅ Saved ./canvas_results3v8/sample_0018.png
# ✅ Saved ./canvas_results3v8/sample_0019.png
# ✅ Saved ./canvas_results3v8/sample_0020.png
# ✅ Saved ./canvas_results3v8/sample_0021.png
# ✅ Saved ./canvas_results3v8/sample_0022.png
# ✅ Saved ./canvas_results3v8/sample_0023.png
# ✅ Saved ./canvas_results3v8/sample_0024.png
# ✅ Saved ./canvas_results3v8/sample_0025.png
# ✅ Saved ./canvas_results3v8/sample_0026.png
# ✅ Saved ./canvas_results3v8/sample_0027.png
# ✅ Saved ./canvas_results3v8/sample_0028.png
# ✅ Saved ./canvas_results3v8/sample_0029.png
# ✅ Saved ./canvas_results3v8/sample_0030.png
# ✅ Saved ./canvas_results3v8/sample_0031.png
# ✅ Saved ./canvas_results3v8/sample_0032.png
# ✅ Saved ./canvas_results3v8/sample_0033.png
# ✅ Saved ./canvas_results3v8/sample_0034.png
# ✅ Saved ./canvas_results3v8/sample_0035.png
# ✅ Saved ./canvas_results3v8/sample_0036.png
# ✅ Saved ./canvas_results3v8/sample_0037.png
# ✅ Saved ./canvas_results3v8/sample_0038.png
# ✅ Saved ./canvas_results3v8/sample_0039.png
# ✅ Saved ./canvas_results3v8/sample_0040.png
# ✅ Saved ./canvas_results3v8/sample_0041.png
# ✅ Saved ./canvas_results3v8/sample_0042.png
# ✅ Saved ./canvas_results3v8/sample_0043.png
# ✅ Saved ./canvas_results3v8/sample_0044.png
# ✅ Saved ./canvas_results3v8/sample_0045.png
# ✅ Saved ./canvas_results3v8/sample_0046.png
# ✅ Saved ./canvas_results3v8/sample_0047.png
# ✅ Saved ./canvas_results3v8/sample_0048.png
# ✅ Saved ./canvas_results3v8/sample_0049.png
# ✅ Saved ./canvas_results3v8/sample_0050.png
# ✅ Saved ./canvas_results3v8/sample_0051.png
# ✅ Saved ./canvas_results3v8/sample_0052.png
# ✅ Saved ./canvas_results3v8/sample_0053.png
# ✅ Saved ./canvas_results3v8/sample_0054.png
# ✅ Saved ./canvas_results3v8/sample_0055.png
# ✅ Saved ./canvas_results3v8/sample_0056.png
# ✅ Saved ./canvas_results3v8/sample_0057.png
# ✅ Saved ./canvas_results3v8/sample_0058.png
# ✅ Saved ./canvas_results3v8/sample_0059.png
# ✅ Saved ./canvas_results3v8/sample_0060.png
# ✅ Saved ./canvas_results3v8/sample_0061.png
# ✅ Saved ./canvas_results3v8/sample_0062.png
# ✅ Saved ./canvas_results3v8/sample_0063.png
# ✅ Saved ./canvas_results3v8/sample_0064.png
# ✅ Saved ./canvas_results3v8/sample_0065.png
# ✅ Saved ./canvas_results3v8/sample_0066.png
# ✅ Saved ./canvas_results3v8/sample_0067.png
# ✅ Saved ./canvas_results3v8/sample_0068.png
# ✅ Saved ./canvas_results3v8/sample_0069.png
# ✅ Saved ./canvas_results3v8/sample_0070.png
# ✅ Saved ./canvas_results3v8/sample_0071.png
# ✅ Saved ./canvas_results3v8/sample_0072.png
# ✅ Saved ./canvas_results3v8/sample_0073.png
# ✅ Saved ./canvas_results3v8/sample_0074.png
# ✅ Saved ./canvas_results3v8/sample_0075.png
# ✅ Saved ./canvas_results3v8/sample_0076.png
# ✅ Saved ./canvas_results3v8/sample_0077.png
# ✅ Saved ./canvas_results3v8/sample_0078.png
# ✅ Saved ./canvas_results3v8/sample_0079.png
# ✅ Saved ./canvas_results3v8/sample_0080.png
#
# 🎯 All 80 test images processed and saved to './canvas_results3v8'
