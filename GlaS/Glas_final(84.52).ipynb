# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-17 15:45:55.766214: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-17 15:45:55.906136: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-17 15:45:55.906231: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-17 15:45:55.921614: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-17 15:45:55.969113: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-17 15:45:56.888364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-17 15:45:58.548788: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:58.987175: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:58.987209: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ----------------------------
# PriorGuidedUpsample2D:
# UpSampling2D-based upsampling + Learnable prior fusion (NO pixelwise maximum)
# ----------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGuidedUpsample2D(layers.Layer):
    """
    UpSampling2D upsampling everywhere (replaces PixelShuffleResize for features/skip and optionally priors)
    PLUS learnable prior fusion:

      GAP(pred) + GAP(prior) -> Dense -> Dense(1) -> project back (B,1,1,1) gate
      fused = gate*prior + (1-gate)*pred
      then DepthwiseConv(act) -> PointwiseConv to produce final map (B,H,W,1)

    Priors influence ONLY the structure maps (center/boundary), then those modulate features as before.
    """

    def __init__(
        self,
        scale=2,
        filters=64,
        method="bilinear",
        attention_kernel=3,
        use_structure_heads=True,
        n_centers=8,
        center_sharpness=9.0,
        boundary_suppress=0.4,
        learnable_temperature=True,
        learnable_prior_resize=True,
        # prior-fusion settings
        prior_fusion_hidden_ratio=4,  # hidden = filters//ratio
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.scale = int(scale)
        self.filters = int(filters)
        self.method = method
        self.attention_kernel = int(attention_kernel)
        self.use_structure_heads = bool(use_structure_heads)
        self.n_centers = int(n_centers)
        self.center_sharpness = float(center_sharpness)
        self.boundary_suppress = float(boundary_suppress)
        self.learnable_temperature = bool(learnable_temperature)

        self.learnable_prior_resize = bool(learnable_prior_resize)
        self.prior_fusion_hidden_ratio = int(prior_fusion_hidden_ratio)

        # ---------------- Projection & Attention ----------------
        self.proj_high = layers.Conv2D(filters, 1, padding="same", activation="selu", name="proj_high")
        self.proj_base = layers.Conv2D(filters, 1, padding="same", activation="linear", name="proj_base")
        self.skip_proj = layers.Conv2D(filters, 1, padding="same", use_bias=False, name="skip_proj")

        self.attention_head = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(attention_kernel, padding="same", activation="selu", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="spatial_attention",
        )

        # ---------------- UpSampling2D-based upsamplers ----------------
        self.up_feat = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_feat")
        self.up_feat_refine = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
            ],
            name="up_feat_refine",
        )

        if self.learnable_prior_resize:
            self.up_prior = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_prior")
            self.up_prior_refine = tf.keras.Sequential(
                [
                    layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                    layers.Conv2D(1, 1, padding="same", activation="selu"),
                ],
                name="up_prior_refine",
            )
        else:
            self.up_prior = None
            self.up_prior_refine = None

        # ---------------- Learned fusion scale ----------------
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(1.0), trainable=True, name="alpha_weight"
        )
        self.beta_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True, name="beta_weight"
        )

        # ---------------- Final projection (refinement step removed) ----------------
        self.final = layers.Conv2D(filters, 1, padding="same", activation="selu", name="final_head")

        # ---------------- Structural Heads ----------------
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding="same", use_bias=True)
        self.center_proj = layers.Conv2D(filters, 1, padding="same", activation=None)

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding="same", use_bias=False, name="laplace_dw")
        self.boundary_refine = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_refine",
        )
        self.boundary_gate_net = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_gate_net",
        )

        self.boundary_gate_scalar = None
        self.center_temp = None
        self.center_sigma = None

        # ---------------- Learnable prior fusion blocks (CENTER) ----------------
        hid = max(4, filters // self.prior_fusion_hidden_ratio)

        self.center_gap = layers.GlobalAveragePooling2D(name="center_prior_gap")
        self.center_fc1 = layers.Dense(hid, activation="selu", name="center_prior_fc1")
        self.center_gate = layers.Dense(1, activation="sigmoid", name="center_prior_gate")  # scalar gate

        self.center_dw = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="center_prior_dw")
        self.center_pw = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="center_prior_pw")

        # ---------------- Learnable prior fusion blocks (BOUNDARY) ----------------
        self.boundary_gap = layers.GlobalAveragePooling2D(name="boundary_prior_gap")
        self.boundary_fc1 = layers.Dense(hid, activation="selu", name="boundary_prior_fc1")
        self.boundary_gate = layers.Dense(1, activation="sigmoid", name="boundary_prior_gate")  # scalar gate

        self.boundary_dw2 = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="boundary_prior_dw")
        self.boundary_pw2 = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="boundary_prior_pw")

    # ---------------- Fusion scale initialization ----------------
    def _init_fusion_scale(self, shape, dtype):
        init = tf.keras.initializers.HeNormal(seed=54)
        w = init(shape=shape, dtype=dtype)
        return tf.clip_by_value(w, 0.0, 1.0)

    # ---------------- Build ----------------
    def build(self, input_shape):
        if not isinstance(input_shape, (list, tuple)) or len(input_shape) not in [2, 4]:
            raise ValueError(
                "PriorGuidedUpsample2D expects [low_res, skip_res] or "
                "[low_res, skip_res, prior_centers, prior_boundaries] inputs."
            )

        fusion_scale_init = self._init_fusion_scale((1, 1, 1, self.filters), tf.float32)
        self.fusion_scale = tf.Variable(
            initial_value=fusion_scale_init, trainable=True, name="fusion_scale", dtype=tf.float32
        )

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True,
            name="boundary_gate_scalar",
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True,
                name="center_temperature",
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness, dtype=tf.float32)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="center_sigma",
        )

        super().build(input_shape)

    # ---------------- Learnable upsample-to-target helper ----------------
    def _upsample_to(self, x, up_layer, refine, target_h, target_w):
        x = up_layer(x)
        if refine is not None:
            x = refine(x)
        # exact match by crop/pad (non-interpolating) for odd input sizes
        x = tf.image.resize_with_crop_or_pad(x, target_h, target_w)
        return x

    # ---------------- Learnable fusion (replaces pixelwise maximum) ----------------
    def _learnable_fuse_prior(self, pred_map, prior_map, gap, fc1, gate_fc, dw, pw):
        """
        pred_map/prior_map: (B,H,W,1)
        gate: scalar per-sample from GAP(pred)+GAP(prior)
        fused map refined by DWConv(act)+PWConv(sigmoid)
        """
        g_pred = gap(pred_map)   # (B,1) effectively after GAP; in TF it's (B,)
        g_prior = gap(prior_map)

        g = tf.concat([g_pred, g_prior], axis=-1)  # (B,2)
        h = fc1(g)
        gate = gate_fc(h)                          # (B,1)
        gate = tf.reshape(gate, [-1, 1, 1, 1])     # project back (broadcast)

        fused = gate * prior_map + (1.0 - gate) * pred_map
        fused = dw(fused)
        fused = pw(fused)
        return fused

    # ---------------- GMM-based Center & Boundary ----------------
    def _compute_soft_centers_gmm(self, feat, prior_centers=None, prior_boundaries=None):
        center_map, boundary_map = self._compute_centers_boundaries(feat)
        target_h, target_w = tf.shape(center_map)[1], tf.shape(center_map)[2]

        # --- learnable prior alignment + learnable fusion (NO tf.maximum) ---
        if prior_centers is not None:
            if self.up_prior is not None:
                prior_centers_up = self._upsample_to(
                    prior_centers, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_centers_up = tf.image.resize(prior_centers, (target_h, target_w), method="bilinear")
            prior_centers_up = tf.clip_by_value(prior_centers_up, 0.0, 1.0)

            center_map = self._learnable_fuse_prior(
                center_map, prior_centers_up,
                self.center_gap, self.center_fc1, self.center_gate,
                self.center_dw, self.center_pw
            )

        if prior_boundaries is not None:
            if self.up_prior is not None:
                prior_boundaries_up = self._upsample_to(
                    prior_boundaries, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_boundaries_up = tf.image.resize(prior_boundaries, (target_h, target_w), method="bilinear")
            prior_boundaries_up = tf.clip_by_value(prior_boundaries_up, 0.0, 1.0)

            boundary_map = self._learnable_fuse_prior(
                boundary_map, prior_boundaries_up,
                self.boundary_gap, self.boundary_fc1, self.boundary_gate,
                self.boundary_dw2, self.boundary_pw2
            )

        return center_map, boundary_map

    def _compute_centers_boundaries(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]

        proj_feat = self.center_proj(feat)
        H, W, C = tf.shape(proj_feat)[1], tf.shape(proj_feat)[2], tf.shape(proj_feat)[3]
        feat_flat = tf.reshape(proj_feat, [B, H * W, C])

        logits = self.assign_logits(proj_feat)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A_flat = tf.nn.softmax(logits_flat, axis=-1)

        A_flat_t = tf.transpose(A_flat, [0, 2, 1])
        denom = tf.reduce_sum(A_flat_t, axis=-1, keepdims=True) + eps
        prototypes = tf.matmul(A_flat_t, feat_flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])

        feat_exp = tf.expand_dims(feat_flat, 2)
        proto_exp = tf.expand_dims(prototypes, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_norm = tf.nn.l2_normalize(feat_flat, axis=-1)
        proto_norm = tf.nn.l2_normalize(prototypes, axis=-1)
        sim = tf.matmul(feat_norm, proto_norm, transpose_b=True)

        weighted_sim = resp * sim
        per_pixel_strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)

        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(per_pixel_strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)
        global_gate = tf.sigmoid(self.boundary_gate_scalar)
        boundary_map = refined_boundary * spatial_gate * global_gate * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ---------------- Forward ----------------
    def call(self, inputs, training=None):
        if len(inputs) == 2:
            low_res, skip_res = inputs
            prior_centers, prior_boundaries = None, None
        elif len(inputs) == 4:
            low_res, skip_res, prior_centers, prior_boundaries = inputs
        else:
            raise ValueError("Expected 2 or 4 inputs: [low_res, skip_res] optionally with priors.")

        high_proj = self.proj_high(low_res)
        base_proj = self.proj_base(low_res)
        alpha = self.attention_head(tf.concat([low_res, high_proj, base_proj], axis=-1))
        fused_low = alpha * high_proj + (1.0 - alpha) * base_proj

        target_h = tf.shape(low_res)[1] * self.scale
        target_w = tf.shape(low_res)[2] * self.scale

        # UpSampling2D-based upsampling (features + skip)
        upsampled = self._upsample_to(fused_low, self.up_feat, self.up_feat_refine, target_h, target_w)
        skip_proj = self.skip_proj(skip_res)
        skip_up = self._upsample_to(skip_proj, self.up_feat, self.up_feat_refine, target_h, target_w)

        fused = (upsampled + skip_up) * self.fusion_scale
        refined = fused

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(refined, prior_centers, prior_boundaries)
            refined = refined * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            out = self.final(refined)
            return out, center_map, boundary_map

        out = self.final(refined)
        return out

    # ---------------- Config ----------------
    def get_config(self):
        cfg = super().get_config()
        cfg.update(
            {
                "scale": self.scale,
                "filters": self.filters,
                "method": self.method,
                "attention_kernel": self.attention_kernel,
                "use_structure_heads": self.use_structure_heads,
                "n_centers": self.n_centers,
                "center_sharpness": self.center_sharpness,
                "boundary_suppress": self.boundary_suppress,
                "learnable_temperature": self.learnable_temperature,
                "learnable_prior_resize": self.learnable_prior_resize,
                "prior_fusion_hidden_ratio": self.prior_fusion_hidden_ratio,
            }
        )
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):

    res = x

    # ============================================================
    # ENCODER BLOCK
    # ============================================================
    if not decoder:


        # -------------------------------
        # Branch 2: Evolutionary Conv
        # -------------------------------
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        # -------------------------------
        # Depthwise Patch Attention
        # -------------------------------

        # Residual projection
        res = layers.Conv2D(filters, 1, padding=padding)(res)

        # Final fusion
        out = layers.Add()([res, x1])

        return out

    # ============================================================
    # DECODER BLOCK
    # ============================================================
    else:

        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base



# ---------------------------------------------------------
# PriorGeneratingDownsample2D
#
# Changes from the original:
#   1. No more GatedSpatialAttention refinement step.
#   2. No more separate `refine_feat` input tensor. The skip
#      branch is now an average-pooled version of `in_feat`
#      itself, computed inside the layer with tf.nn.avg_pool2d
#      using the same pool_size as the geodesic downsampler.
#   3. call() now takes a single tensor `in_feat` instead of
#      a (in_feat, refine_feat) tuple, and build() expects a
#      single input_shape instead of a tuple of shapes.
#
# This layer produces the `center_map` / `boundary_map` priors
# (alongside the downsampled features) that PriorGuidedUpsample2D
# later consumes as `prior_centers` / `prior_boundaries`.
# ---------------------------------------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGeneratingDownsample2D(layers.Layer):

    def __init__(self,
                 pool_size=2,
                 filters=64,
                 attention_kernel=3,
                 use_structure_heads=True,
                 n_centers=8,
                 center_sharpness=9.0,
                 boundary_suppress=0.4,
                 learnable_temperature=True,
                 **kwargs):

        super().__init__(**kwargs)

        self.pool_size = pool_size
        self.filters = filters
        self.attention_kernel = attention_kernel
        self.use_structure_heads = use_structure_heads
        self.n_centers = n_centers
        self.center_sharpness = center_sharpness
        self.boundary_suppress = boundary_suppress
        self.learnable_temperature = learnable_temperature

        # Replace pooling with geodesic kernel
        self.geo_pool = GeodesicDownsample2D(pool_size=pool_size)

        # Projections
        self.proj_high = layers.Conv2D(filters, 1, padding='same', activation='selu')
        self.proj_base = layers.Conv2D(filters, 1, padding='same')
        self.skip_proj = layers.Conv2D(filters, 1, padding='same')

        # Spatial attention
        self.attention_head = tf.keras.Sequential([
            layers.DepthwiseConv2D(attention_kernel, padding='same', activation='selu'),
            layers.Conv2D(filters, 1, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

        # Fusion scale
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(shape=(1,), initializer='ones', trainable=True)
        self.beta_weight = self.add_weight(shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True)

        # Final projection (refinement step removed)
        self.final = layers.Conv2D(filters, 3, padding='same', activation='selu')

        # Structure heads
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding='same')
        self.center_proj = layers.Conv2D(filters, 1, padding='same')

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding='same')
        self.boundary_refine = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])
        self.boundary_gate_net = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

    def build(self, input_shape):
        # input_shape is now a single tensor shape (in_feat only)
        _, _, _, C = input_shape

        fusion_scale_init = tf.keras.initializers.HeNormal(seed=54)(shape=(1, 1, 1, self.filters))
        self.fusion_scale = tf.Variable(fusion_scale_init, trainable=True, name='fusion_scale')

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer='ones',
            trainable=True
        )

        super().build(input_shape)

    # ------------------------------------------------------
    # GMM structural mask logic (unchanged)
    # ------------------------------------------------------
    def _compute_soft_centers_gmm(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]
        proj = self.center_proj(feat)
        H = tf.shape(proj)[1]
        W = tf.shape(proj)[2]
        C = tf.shape(proj)[3]

        flat = tf.reshape(proj, [B, H * W, C])
        logits = self.assign_logits(proj)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A = tf.nn.softmax(logits_flat, axis=-1)
        A_t = tf.transpose(A, [0, 2, 1])
        denom = tf.reduce_sum(A_t, axis=-1, keepdims=True) + eps
        proto = tf.matmul(A_t, flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])
        feat_exp = tf.expand_dims(flat, 2)
        proto_exp = tf.expand_dims(proto, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_n = tf.nn.l2_normalize(flat, axis=-1)
        proto_n = tf.nn.l2_normalize(proto, axis=-1)
        sim = tf.matmul(feat_n, proto_n, transpose_b=True)

        weighted_sim = resp * sim
        strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)
        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)

        boundary_map = refined_boundary * spatial_gate * tf.sigmoid(self.boundary_gate_scalar) * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ------------------------------------------------------
    # Forward path with geodesic pooling
    #
    # `in_feat` is now the ONLY input. The skip branch is
    # derived internally via average pooling of `in_feat`
    # (replacing the old separate `refine_feat` argument),
    # and the GatedSpatialAttention refinement step has been
    # removed entirely — the merged features flow straight
    # into the structure heads / final projection.
    # ------------------------------------------------------
    def call(self, in_feat):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        pooled = self.geo_pool(in_feat)

        # Average-pooled skip branch, derived directly from in_feat
        pooled_ref = tf.nn.avg_pool2d(
            in_feat,
            ksize=[1, ph, pw, 1],
            strides=[1, ph, pw, 1],
            padding='SAME'
        )

        if tf.shape(pooled_ref)[1] != tf.shape(pooled)[1] or tf.shape(pooled_ref)[2] != tf.shape(pooled)[2]:
            pooled_ref = tf.image.resize(pooled_ref, tf.shape(pooled)[1:3], method='bilinear')

        high = self.proj_high(pooled)
        base = self.proj_base(pooled)
        alpha = self.attention_head(tf.concat([pooled, high, base], axis=-1))
        fused = alpha * high + (1 - alpha) * base

        skip = self.skip_proj(pooled_ref)
        fused = (fused + skip) * self.fusion_scale

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(fused)
            fused = fused * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            return self.final(fused), center_map, boundary_map

        return self.final(fused)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            'pool_size': self.pool_size,
            'filters': self.filters,
            'attention_kernel': self.attention_kernel,
            'use_structure_heads': self.use_structure_heads,
            'n_centers': self.n_centers,
            'center_sharpness': self.center_sharpness,
            'boundary_suppress': self.boundary_suppress,
            'learnable_temperature': self.learnable_temperature
        })
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def split_branch_block(x, filters, dilation_rate=2, l2=1e-4, l1=1e-5):
    c = x.shape[-1]
    assert c % 4 == 0

    reg_k = regularizers.L2(l2)
    reg_b = regularizers.L1(l1)

    # -------------------------------------------------
    # Channel Split + gate
    # -------------------------------------------------
    splits = tf.split(x, num_or_size_splits=4, axis=-1)

    gate_logits = layers.GlobalAveragePooling2D()(x)
    gate_logits = layers.Dense(
        4,
        use_bias=True,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gate_logits)
    gates = layers.Activation("softmax")(gate_logits)

    gated_splits = [
        splits[i] * gates[:, i][:, None, None, None]
        for i in range(4)
    ]

    fpb = filters // 4  # filters per branch, target channel count for every branch

    # -------------------------------------------------
    # Multi-branch convolutions
    # -------------------------------------------------
    b1 = layers.Conv2D(
        fpb, 3, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[0])

    b2 = layers.Conv2D(
        fpb, 3, padding="same",
        dilation_rate=dilation_rate,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[1])

    # depthwise preserves input channel count (c//4), so project with a
    # pointwise conv to fpb after each depthwise so shapes match for concat
    b3 = layers.DepthwiseConv2D(
        3, padding="same",
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[2])
    b3 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b3)

    b4 = layers.DepthwiseConv2D(
        3, padding="same",
        dilation_rate=dilation_rate,
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[3])
    b4 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b4)

    add_1 = layers.Add()([b1, b4])   # fpb channels
    add_2 = layers.Add()([b2, b3])   # fpb channels
    out = layers.Concatenate()([add_1, add_2])  # filters // 2 channels
    return out

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)

    s1, c1, b1 = PriorGeneratingDownsample2D()(f1)

    p1 = s1
    p1 = layers.Dropout(0.05)(p1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)

    s2, c2, b2 = PriorGeneratingDownsample2D()(f2)

    p2 = s2
    p2 = layers.Dropout(0.15)(p2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)

    s3, c3, b3 = PriorGeneratingDownsample2D()(f3)

    p3 = s3
    p3 = layers.Dropout(0.2)(p3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)

    s4, c4, b4 = PriorGeneratingDownsample2D()(f4)

    p4 = s4
    p4 = layers.Dropout(0.25)(p4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # ===================== Decoder =====================
    center_maps, boundary_maps = [], []

    # -------- Up 4 --------
    d4, c5, b5 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 8
    )([f5, f4, c4, b4])
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    dec4 = split_branch_block(d4, base_filters * 8, dilation_rate=2)
    #d4 = layers.Add()([dec4, f4])
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    center_maps.append(c5)
    boundary_maps.append(b5)

    # -------- Up 3 --------
    d3, c6, b6 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 4
    )([d4, f3, c3, b3])
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)

    dec3 = split_branch_block(d3, base_filters * 4, dilation_rate=2)
    #d3 = layers.Add()([dec3, f3])
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    center_maps.append(c6)
    boundary_maps.append(b6)

    # -------- Up 2 --------
    d2, c7, b7 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters * 2
    )([d3, f2, c2, b2])

    dec2 = split_branch_block(d2, base_filters * 2, dilation_rate=2)
    #d2 = layers.Add()([dec2, f2])
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    center_maps.append(c7)
    boundary_maps.append(b7)

    # -------- Up 1 --------
    d1, c8, b8 = PriorGuidedUpsample2D(
        scale=2, filters=base_filters
    )([d2, f1, c1, b1])
    dec1 = split_branch_block(d1, base_filters, dilation_rate=2)
    #d1 = layers.Add()([dec1, f1])
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    center_maps.append(c8)
    boundary_maps.append(b8)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        [outputs, center_maps, boundary_maps],
        name="PriorGuidedResidualUNet_Deep5_GatedFusion"
    )

    return model, center_maps, boundary_maps

# %%
model, centers, boundaries = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-17 15:45:59.083664: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.083729: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.083744: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.479443: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.479485: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.479492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-17 15:45:59.479502: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-17 15:45:59.479513: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-17 15:45:59.479553: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2026-09-17 15:46:00.882718: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Model: "PriorGuidedResidualUNet_Deep5_GatedFusion"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['conv2d[0][0]',
#                                                                      'activation[0][0]']
#
#  prior_generating_downsampl  ((None, 128, 128, 64),       79511     ['add[0][0]']
#  e2d (PriorGeneratingDownsa   (None, 128, 128, 1),
#  mple2D)                      (None, 128, 128, 1))
#
#  dropout (Dropout)           (None, 128, 128, 64)         0         ['prior_generating_downsample2
#                                                                     d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 64)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         40961     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 64)         4160      ['gaussian_dropout[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['conv2d_13[0][0]',
#                                                                      'activation_1[0][0]']
#
#  prior_generating_downsampl  ((None, 64, 64, 64),         88055     ['add_1[0][0]']
#  e2d_1 (PriorGeneratingDown   (None, 64, 64, 1),
#  sample2D)                    (None, 64, 64, 1))
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['prior_generating_downsample2
#                                                                     d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 128)          8320      ['gaussian_dropout_1[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_26[0][0]',
#                                                                      'activation_2[0][0]']
#
#  prior_generating_downsampl  ((None, 32, 32, 64),         105143    ['add_2[0][0]']
#  e2d_2 (PriorGeneratingDown   (None, 32, 32, 1),
#  sample2D)                    (None, 32, 32, 1))
#
#  dropout_2 (Dropout)         (None, 32, 32, 64)           0         ['prior_generating_downsample2
#                                                                     d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          163841    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 32, 32, 256)          16640     ['dropout_2[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 32, 32, 256)          0         ['conv2d_39[0][0]',
#                                                                      'activation_3[0][0]']
#
#  prior_generating_downsampl  ((None, 16, 16, 64),         139319    ['add_3[0][0]']
#  e2d_3 (PriorGeneratingDown   (None, 16, 16, 1),
#  sample2D)                    (None, 16, 16, 1))
#
#  dropout_3 (Dropout)         (None, 16, 16, 64)           0         ['prior_generating_downsample2
#                                                                     d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 64)           0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          245761    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 16, 16, 384)          24960     ['gaussian_dropout_2[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 16, 16, 384)          0         ['conv2d_52[0][0]',
#                                                                      'activation_4[0][0]']
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['add_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  prior_guided_upsample2d (P  ((None, 32, 32, 256),        1002044   ['gaussian_dropout_3[0][0]',
#  riorGuidedUpsample2D)        (None, 32, 32, 1),                     'add_3[0][0]',
#                               (None, 32, 32, 1))                     'prior_generating_downsample2
#                                                                     d_3[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_3[0][2]']
#
#  dropout_4 (Dropout)         (None, 32, 32, 256)          0         ['prior_guided_upsample2d[0][0
#                                                                     ]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 256)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          655361    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_6 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add_7 (Add)                 (None, 32, 32, 256)          0         ['add_3[0][0]',
#                                                                      'activation_6[0][0]']
#
#  prior_guided_upsample2d_1   ((None, 64, 64, 128),        280444    ['add_7[0][0]',
#  (PriorGuidedUpsample2D)      (None, 64, 64, 1),                     'add_2[0][0]',
#                               (None, 64, 64, 1))                     'prior_generating_downsample2
#                                                                     d_2[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_2[0][2]']
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 128)          0         ['prior_guided_upsample2d_1[0]
#  anDropout)                                                         [0]']
#
#  dropout_5 (Dropout)         (None, 64, 64, 128)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          163841    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_8 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_10 (Add)                (None, 64, 64, 128)          0         ['add_2[0][0]',
#                                                                      'activation_8[0][0]']
#
#  prior_guided_upsample2d_2   ((None, 128, 128, 64),       72668     ['add_10[0][0]',
#  (PriorGuidedUpsample2D)      (None, 128, 128, 1),                   'add_1[0][0]',
#                               (None, 128, 128, 1))                   'prior_generating_downsample2
#                                                                     d_1[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d_1[0][2]']
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         40961     ['prior_guided_upsample2d_2[0]
#  onv_7 (RadialWaveEvolution                                         [0]']
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_10 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_10[0][0]']
#
#  add_13 (Add)                (None, 128, 128, 64)         0         ['add_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  prior_guided_upsample2d_3   ((None, 256, 256, 32),       19468     ['add_13[0][0]',
#  (PriorGuidedUpsample2D)      (None, 256, 256, 1),                   'add[0][0]',
#                               (None, 256, 256, 1))                   'prior_generating_downsample2
#                                                                     d[0][1]',
#                                                                      'prior_generating_downsample2
#                                                                     d[0][2]']
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         10241     ['prior_guided_upsample2d_3[0]
#  onv_8 (RadialWaveEvolution                                         [0]']
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_12 (Activation)  (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_12[0][0]']
#
#  add_16 (Add)                (None, 256, 256, 32)         0         ['add[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 256, 256, 1)          33        ['add_16[0][0]']
#
# ==================================================================================================
# Total params: 3250118 (12.40 MB)
# Trainable params: 3247430 (12.39 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
# unet_canvas_full.py
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperCanvasStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation + Structural (Center/Boundary) loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU
        L_struct = λ_center * CenterAlignment + λ_boundary * BoundaryAlignment

    NOTE: the BCE term (and its weight l1), the canvas consistency
    loss (fg/bg per-pixel-squared-error penalty, and its weights
    lambda_fg/lambda_bg), and the patchwise discriminator loss
    (cosine + SSIM patch error, lambda_patchdisc) have been removed.
    """
    def __init__(self, init_lambdas=None, name="hyper_canvas_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {
                "l2": 3.0, "l3": 4.5,
                "lambda_center": 8.5, "lambda_boundary": 6.5
            }

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")
        self.lambda_center = tf.Variable(init_lambdas["lambda_center"], trainable=True, dtype=tf.float32, name="lambda_center")
        self.lambda_boundary = tf.Variable(init_lambdas["lambda_boundary"], trainable=True, dtype=tf.float32, name="lambda_boundary")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [
            self.l2, self.l3,
            self.lambda_center, self.lambda_boundary
        ]

    def call(self, y_true_tuple, y_pred_tuple):
        """
        Args:
            y_true_tuple: (y_true_seg, y_true_center, y_true_boundary)
            y_pred_tuple: (y_pred_seg, y_pred_center, y_pred_boundary)
        """
        if not isinstance(y_true_tuple, (list, tuple)) or not isinstance(y_pred_tuple, (list, tuple)):
            raise ValueError("Expected tuples: (y_true_seg, y_true_center, y_true_boundary) and (y_pred_seg, y_pred_center, y_pred_boundary)")

        y_true, y_true_center, y_true_boundary = map(tf.cast, y_true_tuple, [tf.float32]*3)
        y_pred, y_pred_center, y_pred_boundary = map(tf.cast, y_pred_tuple, [tf.float32]*3)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        # --- Structural Center/Boundary ---
        lam_c, lam_b = tf.nn.softplus(self.lambda_center), tf.nn.softplus(self.lambda_boundary)
        center_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_center, y_pred_center))
        boundary_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_boundary, y_pred_boundary))
        overlap = tf.reduce_mean(y_pred_center * y_pred_boundary)
        struct_overlap = 1.0 - overlap
        struct_loss = lam_c * center_loss + lam_b * boundary_loss + 0.5 * struct_overlap

        return seg_loss + struct_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy()),
                "lambda_center": float(self.lambda_center.numpy()),
                "lambda_boundary": float(self.lambda_boundary.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../GLAS_PREPARED_DATA/val/images/*.png") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tif") +
    glob("../GLAS_PREPARED_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("../GLAS_PREPARED_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# SAFETY CHECK
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 684
# Train masks: 684
# Val images: 9
# Val masks: 9
# Training batches: 171
# Validation batches: 3

# %%
class CanvasStructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in [
            "l2", "l3",
            "lambda_center", "lambda_boundary"
        ]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            outputs = self.backbone(x, training=True)

            if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
                y_pred, centers, boundaries = outputs
            else:
                raise ValueError("Backbone must return (y_pred, centers, boundaries)")

            last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
            last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

            loss = self.loss_fn(
                (y_true, y_true, y_true),
                (y_pred, last_center, last_boundary)
            )

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        outputs = self.backbone(x, training=False)

        if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
            y_pred, centers, boundaries = outputs
        else:
            raise ValueError("Backbone must return (y_pred, centers, boundaries)")

        last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
        last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

        loss = self.loss_fn(
            (y_true, y_true, y_true),
            (y_pred, last_center, last_boundary)
        )

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperCanvasStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = CanvasStructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("unet_canvas_3v8.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-17 15:46:43.387866: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inPriorGuidedResidualUNet_Deep5_GatedFusion/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-17 15:46:50.635742: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-17 15:46:50.834497: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-17 15:46:57.930612: I external/local_xla/xla/service/service.cc:168] XLA service 0x70a280bbc080 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-17 15:46:57.930647: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-17 15:46:57.948609: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789660018.029501   74173 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 171/171 [==============================] - ETA: 0s - loss: 12.7132 - accuracy: 0.6865 - iou_coef: 0.5320 - dice_coef: 0.6792 - f1_score: 0.6839 - aggregated_jaccard_index: 0.5600
# ✅ Saved improved backbone at epoch 1 with val_iou=0.5942
# 171/171 [==============================] - 108s 352ms/step - loss: 12.7015 - accuracy: 0.6865 - iou_coef: 0.5320 - dice_coef: 0.6792 - f1_score: 0.6839 - aggregated_jaccard_index: 0.5600 - val_val_loss: 11.9586 - val_val_accuracy: 0.6196 - val_val_iou_coef: 0.5942 - val_val_dice_coef: 0.7409 - val_val_f1_score: 0.7412 - val_val_aggregated_jaccard_index: 0.6102 - lr: 0.0010
# Epoch 2/150
# 171/171 [==============================] - 53s 310ms/step - loss: 10.3405 - accuracy: 0.7734 - iou_coef: 0.6321 - dice_coef: 0.7647 - f1_score: 0.7672 - aggregated_jaccard_index: 0.6537 - val_val_loss: 13.9398 - val_val_accuracy: 0.5775 - val_val_iou_coef: 0.5718 - val_val_dice_coef: 0.7225 - val_val_f1_score: 0.7226 - val_val_aggregated_jaccard_index: 0.5885 - lr: 0.0010
# Epoch 3/150
# 171/171 [==============================] - ETA: 0s - loss: 9.0587 - accuracy: 0.8056 - iou_coef: 0.6677 - dice_coef: 0.7908 - f1_score: 0.7925 - aggregated_jaccard_index: 0.6827
# ✅ Saved improved backbone at epoch 3 with val_iou=0.6010
# 171/171 [==============================] - 56s 329ms/step - loss: 9.0509 - accuracy: 0.8056 - iou_coef: 0.6677 - dice_coef: 0.7908 - f1_score: 0.7925 - aggregated_jaccard_index: 0.6827 - val_val_loss: 8.6248 - val_val_accuracy: 0.6287 - val_val_iou_coef: 0.6010 - val_val_dice_coef: 0.7465 - val_val_f1_score: 0.7463 - val_val_aggregated_jaccard_index: 0.6166 - lr: 0.0010
# Epoch 4/150
# 171/171 [==============================] - ETA: 0s - loss: 8.4562 - accuracy: 0.8111 - iou_coef: 0.6789 - dice_coef: 0.7986 - f1_score: 0.7997 - aggregated_jaccard_index: 0.6950
# ✅ Saved improved backbone at epoch 4 with val_iou=0.6740
# 171/171 [==============================] - 53s 308ms/step - loss: 8.4654 - accuracy: 0.8111 - iou_coef: 0.6789 - dice_coef: 0.7986 - f1_score: 0.7997 - aggregated_jaccard_index: 0.6950 - val_val_loss: 7.0506 - val_val_accuracy: 0.6982 - val_val_iou_coef: 0.6740 - val_val_dice_coef: 0.7990 - val_val_f1_score: 0.7995 - val_val_aggregated_jaccard_index: 0.6889 - lr: 0.0010
# Epoch 5/150
# 171/171 [==============================] - 56s 329ms/step - loss: 7.6638 - accuracy: 0.8300 - iou_coef: 0.7036 - dice_coef: 0.8169 - f1_score: 0.8178 - aggregated_jaccard_index: 0.7190 - val_val_loss: 8.7252 - val_val_accuracy: 0.7702 - val_val_iou_coef: 0.6476 - val_val_dice_coef: 0.7758 - val_val_f1_score: 0.7767 - val_val_aggregated_jaccard_index: 0.6406 - lr: 0.0010
# Epoch 6/150
# 171/171 [==============================] - ETA: 0s - loss: 6.9448 - accuracy: 0.8446 - iou_coef: 0.7255 - dice_coef: 0.8337 - f1_score: 0.8344 - aggregated_jaccard_index: 0.7380
# ✅ Saved improved backbone at epoch 6 with val_iou=0.8175
# 171/171 [==============================] - 53s 308ms/step - loss: 6.9375 - accuracy: 0.8446 - iou_coef: 0.7255 - dice_coef: 0.8337 - f1_score: 0.8344 - aggregated_jaccard_index: 0.7380 - val_val_loss: 3.9147 - val_val_accuracy: 0.8691 - val_val_iou_coef: 0.8175 - val_val_dice_coef: 0.8958 - val_val_f1_score: 0.8967 - val_val_aggregated_jaccard_index: 0.8160 - lr: 0.0010
# Epoch 7/150
# 171/171 [==============================] - 57s 334ms/step - loss: 6.3328 - accuracy: 0.8574 - iou_coef: 0.7441 - dice_coef: 0.8460 - f1_score: 0.8466 - aggregated_jaccard_index: 0.7576 - val_val_loss: 3.6590 - val_val_accuracy: 0.8436 - val_val_iou_coef: 0.8018 - val_val_dice_coef: 0.8862 - val_val_f1_score: 0.8873 - val_val_aggregated_jaccard_index: 0.8030 - lr: 0.0010
# Epoch 8/150
# 171/171 [==============================] - 53s 309ms/step - loss: 6.0442 - accuracy: 0.8589 - iou_coef: 0.7470 - dice_coef: 0.8479 - f1_score: 0.8484 - aggregated_jaccard_index: 0.7603 - val_val_loss: 3.3263 - val_val_accuracy: 0.8589 - val_val_iou_coef: 0.8152 - val_val_dice_coef: 0.8917 - val_val_f1_score: 0.8927 - val_val_aggregated_jaccard_index: 0.8104 - lr: 0.0010
# Epoch 9/150
# 171/171 [==============================] - 56s 328ms/step - loss: 5.5848 - accuracy: 0.8683 - iou_coef: 0.7608 - dice_coef: 0.8568 - f1_score: 0.8573 - aggregated_jaccard_index: 0.7731 - val_val_loss: 3.3488 - val_val_accuracy: 0.8427 - val_val_iou_coef: 0.7913 - val_val_dice_coef: 0.8714 - val_val_f1_score: 0.8717 - val_val_aggregated_jaccard_index: 0.7866 - lr: 0.0010
# Epoch 10/150
# 171/171 [==============================] - 52s 307ms/step - loss: 5.3231 - accuracy: 0.8713 - iou_coef: 0.7654 - dice_coef: 0.8592 - f1_score: 0.8596 - aggregated_jaccard_index: 0.7785 - val_val_loss: 3.1173 - val_val_accuracy: 0.8695 - val_val_iou_coef: 0.8157 - val_val_dice_coef: 0.8918 - val_val_f1_score: 0.8922 - val_val_aggregated_jaccard_index: 0.8144 - lr: 0.0010
# Epoch 11/150
# 171/171 [==============================] - ETA: 0s - loss: 5.1053 - accuracy: 0.8736 - iou_coef: 0.7699 - dice_coef: 0.8624 - f1_score: 0.8629 - aggregated_jaccard_index: 0.7820
# ✅ Saved improved backbone at epoch 11 with val_iou=0.8185
# 171/171 [==============================] - 57s 331ms/step - loss: 5.1009 - accuracy: 0.8736 - iou_coef: 0.7699 - dice_coef: 0.8624 - f1_score: 0.8629 - aggregated_jaccard_index: 0.7820 - val_val_loss: 3.0192 - val_val_accuracy: 0.8714 - val_val_iou_coef: 0.8185 - val_val_dice_coef: 0.8955 - val_val_f1_score: 0.8958 - val_val_aggregated_jaccard_index: 0.8191 - lr: 0.0010
# Epoch 12/150
# 171/171 [==============================] - 53s 310ms/step - loss: 4.7938 - accuracy: 0.8781 - iou_coef: 0.7766 - dice_coef: 0.8675 - f1_score: 0.8680 - aggregated_jaccard_index: 0.7887 - val_val_loss: 5.3977 - val_val_accuracy: 0.7993 - val_val_iou_coef: 0.7423 - val_val_dice_coef: 0.8494 - val_val_f1_score: 0.8495 - val_val_aggregated_jaccard_index: 0.7527 - lr: 0.0010
# Epoch 13/150
# 171/171 [==============================] - ETA: 0s - loss: 4.6444 - accuracy: 0.8783 - iou_coef: 0.7785 - dice_coef: 0.8677 - f1_score: 0.8681 - aggregated_jaccard_index: 0.7909
# ✅ Saved improved backbone at epoch 13 with val_iou=0.8476
# 171/171 [==============================] - 58s 342ms/step - loss: 4.6606 - accuracy: 0.8783 - iou_coef: 0.7785 - dice_coef: 0.8677 - f1_score: 0.8681 - aggregated_jaccard_index: 0.7909 - val_val_loss: 2.4382 - val_val_accuracy: 0.8932 - val_val_iou_coef: 0.8476 - val_val_dice_coef: 0.9127 - val_val_f1_score: 0.9129 - val_val_aggregated_jaccard_index: 0.8475 - lr: 0.0010
# Epoch 14/150
# 171/171 [==============================] - 52s 306ms/step - loss: 4.3368 - accuracy: 0.8856 - iou_coef: 0.7871 - dice_coef: 0.8740 - f1_score: 0.8744 - aggregated_jaccard_index: 0.7998 - val_val_loss: 2.4315 - val_val_accuracy: 0.8662 - val_val_iou_coef: 0.8241 - val_val_dice_coef: 0.8951 - val_val_f1_score: 0.8955 - val_val_aggregated_jaccard_index: 0.8218 - lr: 0.0010
# Epoch 15/150
# 171/171 [==============================] - 56s 330ms/step - loss: 4.2169 - accuracy: 0.8839 - iou_coef: 0.7870 - dice_coef: 0.8740 - f1_score: 0.8744 - aggregated_jaccard_index: 0.7981 - val_val_loss: 2.4826 - val_val_accuracy: 0.8516 - val_val_iou_coef: 0.7951 - val_val_dice_coef: 0.8672 - val_val_f1_score: 0.8674 - val_val_aggregated_jaccard_index: 0.7903 - lr: 0.0010
# Epoch 16/150
# 171/171 [==============================] - 53s 309ms/step - loss: 4.0469 - accuracy: 0.8847 - iou_coef: 0.7869 - dice_coef: 0.8734 - f1_score: 0.8738 - aggregated_jaccard_index: 0.7997 - val_val_loss: 2.4156 - val_val_accuracy: 0.8388 - val_val_iou_coef: 0.8016 - val_val_dice_coef: 0.8873 - val_val_f1_score: 0.8873 - val_val_aggregated_jaccard_index: 0.8089 - lr: 0.0010
# Epoch 17/150
# 171/171 [==============================] - 57s 333ms/step - loss: 3.7614 - accuracy: 0.8913 - iou_coef: 0.7974 - dice_coef: 0.8811 - f1_score: 0.8815 - aggregated_jaccard_index: 0.8095 - val_val_loss: 2.2843 - val_val_accuracy: 0.8647 - val_val_iou_coef: 0.8111 - val_val_dice_coef: 0.8903 - val_val_f1_score: 0.8907 - val_val_aggregated_jaccard_index: 0.8105 - lr: 0.0010
# Epoch 18/150
# 171/171 [==============================] - ETA: 0s - loss: 3.7069 - accuracy: 0.8889 - iou_coef: 0.7943 - dice_coef: 0.8790 - f1_score: 0.8793 - aggregated_jaccard_index: 0.8057
# ✅ Saved improved backbone at epoch 18 with val_iou=0.8621
# 171/171 [==============================] - 53s 309ms/step - loss: 3.7065 - accuracy: 0.8889 - iou_coef: 0.7943 - dice_coef: 0.8790 - f1_score: 0.8793 - aggregated_jaccard_index: 0.8057 - val_val_loss: 2.0542 - val_val_accuracy: 0.9032 - val_val_iou_coef: 0.8621 - val_val_dice_coef: 0.9215 - val_val_f1_score: 0.9217 - val_val_aggregated_jaccard_index: 0.8618 - lr: 0.0010
# Epoch 19/150
# 171/171 [==============================] - 54s 317ms/step - loss: 3.4071 - accuracy: 0.8960 - iou_coef: 0.8049 - dice_coef: 0.8862 - f1_score: 0.8865 - aggregated_jaccard_index: 0.8162 - val_val_loss: 2.1735 - val_val_accuracy: 0.8817 - val_val_iou_coef: 0.8377 - val_val_dice_coef: 0.9067 - val_val_f1_score: 0.9069 - val_val_aggregated_jaccard_index: 0.8362 - lr: 0.0010
# Epoch 20/150
# 171/171 [==============================] - ETA: 0s - loss: 3.2402 - accuracy: 0.8983 - iou_coef: 0.8085 - dice_coef: 0.8879 - f1_score: 0.8882 - aggregated_jaccard_index: 0.8202
# ✅ Saved improved backbone at epoch 20 with val_iou=0.8661
# 171/171 [==============================] - 56s 330ms/step - loss: 3.2438 - accuracy: 0.8983 - iou_coef: 0.8085 - dice_coef: 0.8879 - f1_score: 0.8882 - aggregated_jaccard_index: 0.8202 - val_val_loss: 1.9204 - val_val_accuracy: 0.9133 - val_val_iou_coef: 0.8661 - val_val_dice_coef: 0.9244 - val_val_f1_score: 0.9246 - val_val_aggregated_jaccard_index: 0.8676 - lr: 0.0010
# Epoch 21/150
# 171/171 [==============================] - 52s 306ms/step - loss: 3.2690 - accuracy: 0.8925 - iou_coef: 0.7978 - dice_coef: 0.8807 - f1_score: 0.8811 - aggregated_jaccard_index: 0.8105 - val_val_loss: 1.8626 - val_val_accuracy: 0.8472 - val_val_iou_coef: 0.7885 - val_val_dice_coef: 0.8684 - val_val_f1_score: 0.8686 - val_val_aggregated_jaccard_index: 0.7860 - lr: 0.0010
# Epoch 22/150
# 171/171 [==============================] - 57s 331ms/step - loss: 3.0160 - accuracy: 0.8989 - iou_coef: 0.8096 - dice_coef: 0.8886 - f1_score: 0.8889 - aggregated_jaccard_index: 0.8218 - val_val_loss: 1.7381 - val_val_accuracy: 0.8976 - val_val_iou_coef: 0.8538 - val_val_dice_coef: 0.9146 - val_val_f1_score: 0.9148 - val_val_aggregated_jaccard_index: 0.8509 - lr: 0.0010
# Epoch 23/150
# 171/171 [==============================] - 52s 305ms/step - loss: 2.8626 - accuracy: 0.9005 - iou_coef: 0.8134 - dice_coef: 0.8912 - f1_score: 0.8914 - aggregated_jaccard_index: 0.8237 - val_val_loss: 1.7804 - val_val_accuracy: 0.8996 - val_val_iou_coef: 0.8501 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9140 - val_val_aggregated_jaccard_index: 0.8505 - lr: 0.0010
# Epoch 24/150
# 171/171 [==============================] - 57s 332ms/step - loss: 2.7121 - accuracy: 0.9034 - iou_coef: 0.8180 - dice_coef: 0.8942 - f1_score: 0.8945 - aggregated_jaccard_index: 0.8289 - val_val_loss: 2.0228 - val_val_accuracy: 0.8449 - val_val_iou_coef: 0.7867 - val_val_dice_coef: 0.8706 - val_val_f1_score: 0.8709 - val_val_aggregated_jaccard_index: 0.7829 - lr: 0.0010
# Epoch 25/150
# 171/171 [==============================] - 52s 305ms/step - loss: 2.6392 - accuracy: 0.9028 - iou_coef: 0.8157 - dice_coef: 0.8926 - f1_score: 0.8928 - aggregated_jaccard_index: 0.8263 - val_val_loss: 1.4882 - val_val_accuracy: 0.9002 - val_val_iou_coef: 0.8630 - val_val_dice_coef: 0.9212 - val_val_f1_score: 0.9213 - val_val_aggregated_jaccard_index: 0.8614 - lr: 0.0010
# Epoch 26/150
# 171/171 [==============================] - 56s 326ms/step - loss: 2.4598 - accuracy: 0.9065 - iou_coef: 0.8219 - dice_coef: 0.8967 - f1_score: 0.8969 - aggregated_jaccard_index: 0.8326 - val_val_loss: 1.4046 - val_val_accuracy: 0.8841 - val_val_iou_coef: 0.8370 - val_val_dice_coef: 0.8985 - val_val_f1_score: 0.8986 - val_val_aggregated_jaccard_index: 0.8345 - lr: 0.0010
# Epoch 27/150
# 171/171 [==============================] - 53s 309ms/step - loss: 2.2962 - accuracy: 0.9105 - iou_coef: 0.8281 - dice_coef: 0.9008 - f1_score: 0.9011 - aggregated_jaccard_index: 0.8387 - val_val_loss: 1.3543 - val_val_accuracy: 0.8953 - val_val_iou_coef: 0.8553 - val_val_dice_coef: 0.9155 - val_val_f1_score: 0.9159 - val_val_aggregated_jaccard_index: 0.8511 - lr: 0.0010
# Epoch 28/150
# 171/171 [==============================] - 56s 327ms/step - loss: 2.1641 - accuracy: 0.9130 - iou_coef: 0.8321 - dice_coef: 0.9033 - f1_score: 0.9035 - aggregated_jaccard_index: 0.8431 - val_val_loss: 1.2634 - val_val_accuracy: 0.8817 - val_val_iou_coef: 0.8368 - val_val_dice_coef: 0.9028 - val_val_f1_score: 0.9029 - val_val_aggregated_jaccard_index: 0.8332 - lr: 0.0010
# Epoch 29/150
# 171/171 [==============================] - ETA: 0s - loss: 2.1456 - accuracy: 0.9088 - iou_coef: 0.8260 - dice_coef: 0.8994 - f1_score: 0.8996 - aggregated_jaccard_index: 0.8366
# ✅ Saved improved backbone at epoch 29 with val_iou=0.8822
# 171/171 [==============================] - 55s 319ms/step - loss: 2.1413 - accuracy: 0.9088 - iou_coef: 0.8260 - dice_coef: 0.8994 - f1_score: 0.8996 - aggregated_jaccard_index: 0.8366 - val_val_loss: 1.2720 - val_val_accuracy: 0.9183 - val_val_iou_coef: 0.8822 - val_val_dice_coef: 0.9361 - val_val_f1_score: 0.9362 - val_val_aggregated_jaccard_index: 0.8792 - lr: 0.0010
# Epoch 30/150
# 171/171 [==============================] - 53s 307ms/step - loss: 2.0999 - accuracy: 0.9068 - iou_coef: 0.8223 - dice_coef: 0.8972 - f1_score: 0.8974 - aggregated_jaccard_index: 0.8323 - val_val_loss: 1.2621 - val_val_accuracy: 0.8601 - val_val_iou_coef: 0.8062 - val_val_dice_coef: 0.8821 - val_val_f1_score: 0.8822 - val_val_aggregated_jaccard_index: 0.8043 - lr: 0.0010
# Epoch 31/150
# 171/171 [==============================] - 56s 329ms/step - loss: 1.9913 - accuracy: 0.9083 - iou_coef: 0.8249 - dice_coef: 0.8989 - f1_score: 0.8991 - aggregated_jaccard_index: 0.8348 - val_val_loss: 1.2349 - val_val_accuracy: 0.8665 - val_val_iou_coef: 0.8142 - val_val_dice_coef: 0.8742 - val_val_f1_score: 0.8742 - val_val_aggregated_jaccard_index: 0.8105 - lr: 0.0010
# Epoch 32/150
# 171/171 [==============================] - 52s 306ms/step - loss: 1.7868 - accuracy: 0.9163 - iou_coef: 0.8378 - dice_coef: 0.9070 - f1_score: 0.9072 - aggregated_jaccard_index: 0.8475 - val_val_loss: 1.2439 - val_val_accuracy: 0.8886 - val_val_iou_coef: 0.8427 - val_val_dice_coef: 0.9058 - val_val_f1_score: 0.9058 - val_val_aggregated_jaccard_index: 0.8409 - lr: 0.0010
# Epoch 33/150
# 171/171 [==============================] - 53s 310ms/step - loss: 1.7425 - accuracy: 0.9137 - iou_coef: 0.8339 - dice_coef: 0.9047 - f1_score: 0.9049 - aggregated_jaccard_index: 0.8441 - val_val_loss: 1.2633 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.8588 - val_val_dice_coef: 0.9214 - val_val_f1_score: 0.9215 - val_val_aggregated_jaccard_index: 0.8588 - lr: 0.0010
# Epoch 34/150
# 171/171 [==============================] - 58s 338ms/step - loss: 1.6249 - accuracy: 0.9172 - iou_coef: 0.8400 - dice_coef: 0.9085 - f1_score: 0.9087 - aggregated_jaccard_index: 0.8495 - val_val_loss: 1.0765 - val_val_accuracy: 0.9071 - val_val_iou_coef: 0.8617 - val_val_dice_coef: 0.9190 - val_val_f1_score: 0.9191 - val_val_aggregated_jaccard_index: 0.8612 - lr: 0.0010
# Epoch 35/150
# 171/171 [==============================] - ETA: 0s - loss: 1.5988 - accuracy: 0.9146 - iou_coef: 0.8346 - dice_coef: 0.9049 - f1_score: 0.9050 - aggregated_jaccard_index: 0.8445
# ✅ Saved improved backbone at epoch 35 with val_iou=0.8866
# 171/171 [==============================] - 53s 312ms/step - loss: 1.5974 - accuracy: 0.9146 - iou_coef: 0.8346 - dice_coef: 0.9049 - f1_score: 0.9050 - aggregated_jaccard_index: 0.8445 - val_val_loss: 1.0017 - val_val_accuracy: 0.9225 - val_val_iou_coef: 0.8866 - val_val_dice_coef: 0.9385 - val_val_f1_score: 0.9386 - val_val_aggregated_jaccard_index: 0.8863 - lr: 0.0010
# Epoch 36/150
# 171/171 [==============================] - ETA: 0s - loss: 1.4308 - accuracy: 0.9224 - iou_coef: 0.8475 - dice_coef: 0.9133 - f1_score: 0.9134 - aggregated_jaccard_index: 0.8573
# ✅ Saved improved backbone at epoch 36 with val_iou=0.8951
# 171/171 [==============================] - 57s 331ms/step - loss: 1.4306 - accuracy: 0.9224 - iou_coef: 0.8475 - dice_coef: 0.9133 - f1_score: 0.9134 - aggregated_jaccard_index: 0.8573 - val_val_loss: 0.9198 - val_val_accuracy: 0.9322 - val_val_iou_coef: 0.8951 - val_val_dice_coef: 0.9441 - val_val_f1_score: 0.9442 - val_val_aggregated_jaccard_index: 0.8955 - lr: 0.0010
# Epoch 37/150
# 171/171 [==============================] - 53s 309ms/step - loss: 1.3610 - accuracy: 0.9233 - iou_coef: 0.8502 - dice_coef: 0.9149 - f1_score: 0.9150 - aggregated_jaccard_index: 0.8594 - val_val_loss: 0.8928 - val_val_accuracy: 0.9167 - val_val_iou_coef: 0.8800 - val_val_dice_coef: 0.9329 - val_val_f1_score: 0.9330 - val_val_aggregated_jaccard_index: 0.8792 - lr: 0.0010
# Epoch 38/150
# 171/171 [==============================] - 56s 327ms/step - loss: 1.2997 - accuracy: 0.9239 - iou_coef: 0.8497 - dice_coef: 0.9146 - f1_score: 0.9148 - aggregated_jaccard_index: 0.8596 - val_val_loss: 0.9114 - val_val_accuracy: 0.8711 - val_val_iou_coef: 0.8154 - val_val_dice_coef: 0.8859 - val_val_f1_score: 0.8860 - val_val_aggregated_jaccard_index: 0.8131 - lr: 0.0010
# Epoch 39/150
# 171/171 [==============================] - ETA: 0s - loss: 1.2308 - accuracy: 0.9243 - iou_coef: 0.8518 - dice_coef: 0.9158 - f1_score: 0.9159 - aggregated_jaccard_index: 0.8606
# ✅ Saved improved backbone at epoch 39 with val_iou=0.9011
# 171/171 [==============================] - 56s 331ms/step - loss: 1.2316 - accuracy: 0.9243 - iou_coef: 0.8518 - dice_coef: 0.9158 - f1_score: 0.9159 - aggregated_jaccard_index: 0.8606 - val_val_loss: 0.8289 - val_val_accuracy: 0.9360 - val_val_iou_coef: 0.9011 - val_val_dice_coef: 0.9474 - val_val_f1_score: 0.9475 - val_val_aggregated_jaccard_index: 0.9016 - lr: 0.0010
# Epoch 40/150
# 171/171 [==============================] - 53s 308ms/step - loss: 1.1598 - accuracy: 0.9262 - iou_coef: 0.8550 - dice_coef: 0.9179 - f1_score: 0.9180 - aggregated_jaccard_index: 0.8636 - val_val_loss: 0.8050 - val_val_accuracy: 0.8901 - val_val_iou_coef: 0.8394 - val_val_dice_coef: 0.8981 - val_val_f1_score: 0.8981 - val_val_aggregated_jaccard_index: 0.8383 - lr: 0.0010
# Epoch 41/150
# 171/171 [==============================] - 56s 330ms/step - loss: 1.1220 - accuracy: 0.9248 - iou_coef: 0.8508 - dice_coef: 0.9147 - f1_score: 0.9148 - aggregated_jaccard_index: 0.8620 - val_val_loss: 0.7795 - val_val_accuracy: 0.9109 - val_val_iou_coef: 0.8657 - val_val_dice_coef: 0.9227 - val_val_f1_score: 0.9229 - val_val_aggregated_jaccard_index: 0.8663 - lr: 0.0010
# Epoch 42/150
# 171/171 [==============================] - 53s 311ms/step - loss: 1.0277 - accuracy: 0.9301 - iou_coef: 0.8611 - dice_coef: 0.9218 - f1_score: 0.9219 - aggregated_jaccard_index: 0.8696 - val_val_loss: 0.7431 - val_val_accuracy: 0.9306 - val_val_iou_coef: 0.8912 - val_val_dice_coef: 0.9418 - val_val_f1_score: 0.9418 - val_val_aggregated_jaccard_index: 0.8932 - lr: 0.0010
# Epoch 43/150
# 171/171 [==============================] - 56s 329ms/step - loss: 1.0493 - accuracy: 0.9225 - iou_coef: 0.8479 - dice_coef: 0.9132 - f1_score: 0.9134 - aggregated_jaccard_index: 0.8580 - val_val_loss: 0.7322 - val_val_accuracy: 0.9062 - val_val_iou_coef: 0.8699 - val_val_dice_coef: 0.9285 - val_val_f1_score: 0.9285 - val_val_aggregated_jaccard_index: 0.8709 - lr: 0.0010
# Epoch 44/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.9792 - accuracy: 0.9248 - iou_coef: 0.8523 - dice_coef: 0.9161 - f1_score: 0.9162 - aggregated_jaccard_index: 0.8610 - val_val_loss: 0.6683 - val_val_accuracy: 0.9194 - val_val_iou_coef: 0.8780 - val_val_dice_coef: 0.9332 - val_val_f1_score: 0.9333 - val_val_aggregated_jaccard_index: 0.8772 - lr: 0.0010
# Epoch 45/150
# 171/171 [==============================] - 56s 330ms/step - loss: 0.9163 - accuracy: 0.9273 - iou_coef: 0.8555 - dice_coef: 0.9181 - f1_score: 0.9183 - aggregated_jaccard_index: 0.8652 - val_val_loss: 0.6557 - val_val_accuracy: 0.9179 - val_val_iou_coef: 0.8773 - val_val_dice_coef: 0.9336 - val_val_f1_score: 0.9336 - val_val_aggregated_jaccard_index: 0.8755 - lr: 0.0010
# Epoch 46/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.8525 - accuracy: 0.9296 - iou_coef: 0.8594 - dice_coef: 0.9202 - f1_score: 0.9203 - aggregated_jaccard_index: 0.8694 - val_val_loss: 0.5943 - val_val_accuracy: 0.8977 - val_val_iou_coef: 0.8530 - val_val_dice_coef: 0.9101 - val_val_f1_score: 0.9102 - val_val_aggregated_jaccard_index: 0.8518 - lr: 0.0010
# Epoch 47/150
# 171/171 [==============================] - 56s 328ms/step - loss: 0.8042 - accuracy: 0.9317 - iou_coef: 0.8636 - dice_coef: 0.9235 - f1_score: 0.9236 - aggregated_jaccard_index: 0.8723 - val_val_loss: 0.5929 - val_val_accuracy: 0.9122 - val_val_iou_coef: 0.8675 - val_val_dice_coef: 0.9227 - val_val_f1_score: 0.9228 - val_val_aggregated_jaccard_index: 0.8678 - lr: 0.0010
# Epoch 48/150
# 171/171 [==============================] - 53s 310ms/step - loss: 0.7628 - accuracy: 0.9329 - iou_coef: 0.8666 - dice_coef: 0.9253 - f1_score: 0.9254 - aggregated_jaccard_index: 0.8748 - val_val_loss: 0.5860 - val_val_accuracy: 0.9009 - val_val_iou_coef: 0.8597 - val_val_dice_coef: 0.9197 - val_val_f1_score: 0.9197 - val_val_aggregated_jaccard_index: 0.8574 - lr: 0.0010
# Epoch 49/150
# 171/171 [==============================] - ETA: 0s - loss: 0.7236 - accuracy: 0.9337 - iou_coef: 0.8679 - dice_coef: 0.9258 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8760
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 171/171 [==============================] - 56s 327ms/step - loss: 0.7237 - accuracy: 0.9337 - iou_coef: 0.8679 - dice_coef: 0.9258 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8760 - val_val_loss: 0.5196 - val_val_accuracy: 0.9340 - val_val_iou_coef: 0.8994 - val_val_dice_coef: 0.9464 - val_val_f1_score: 0.9464 - val_val_aggregated_jaccard_index: 0.9011 - lr: 0.0010
# Epoch 50/150
# 171/171 [==============================] - 53s 307ms/step - loss: 0.6951 - accuracy: 0.9352 - iou_coef: 0.8712 - dice_coef: 0.9280 - f1_score: 0.9281 - aggregated_jaccard_index: 0.8790 - val_val_loss: 0.5205 - val_val_accuracy: 0.9322 - val_val_iou_coef: 0.8953 - val_val_dice_coef: 0.9435 - val_val_f1_score: 0.9435 - val_val_aggregated_jaccard_index: 0.8962 - lr: 1.0000e-04
# Epoch 51/150
# 171/171 [==============================] - 56s 329ms/step - loss: 0.6699 - accuracy: 0.9391 - iou_coef: 0.8774 - dice_coef: 0.9319 - f1_score: 0.9320 - aggregated_jaccard_index: 0.8839 - val_val_loss: 0.5187 - val_val_accuracy: 0.9225 - val_val_iou_coef: 0.8840 - val_val_dice_coef: 0.9348 - val_val_f1_score: 0.9349 - val_val_aggregated_jaccard_index: 0.8845 - lr: 1.0000e-04
# Epoch 52/150
# 171/171 [==============================] - ETA: 0s - loss: 0.6612 - accuracy: 0.9402 - iou_coef: 0.8790 - dice_coef: 0.9327 - f1_score: 0.9329 - aggregated_jaccard_index: 0.8860
# ✅ Saved improved backbone at epoch 52 with val_iou=0.9018
# 171/171 [==============================] - 53s 311ms/step - loss: 0.6618 - accuracy: 0.9402 - iou_coef: 0.8790 - dice_coef: 0.9327 - f1_score: 0.9329 - aggregated_jaccard_index: 0.8860 - val_val_loss: 0.5193 - val_val_accuracy: 0.9377 - val_val_iou_coef: 0.9018 - val_val_dice_coef: 0.9476 - val_val_f1_score: 0.9476 - val_val_aggregated_jaccard_index: 0.9031 - lr: 1.0000e-04
# Epoch 53/150
# 171/171 [==============================] - 56s 327ms/step - loss: 0.6596 - accuracy: 0.9400 - iou_coef: 0.8794 - dice_coef: 0.9331 - f1_score: 0.9332 - aggregated_jaccard_index: 0.8864 - val_val_loss: 0.5131 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.8860 - val_val_dice_coef: 0.9361 - val_val_f1_score: 0.9361 - val_val_aggregated_jaccard_index: 0.8872 - lr: 1.0000e-04
# Epoch 54/150
# 171/171 [==============================] - 54s 316ms/step - loss: 0.6512 - accuracy: 0.9409 - iou_coef: 0.8815 - dice_coef: 0.9344 - f1_score: 0.9345 - aggregated_jaccard_index: 0.8873 - val_val_loss: 0.5129 - val_val_accuracy: 0.9260 - val_val_iou_coef: 0.8877 - val_val_dice_coef: 0.9375 - val_val_f1_score: 0.9376 - val_val_aggregated_jaccard_index: 0.8887 - lr: 1.0000e-04
# Epoch 55/150
# 171/171 [==============================] - 72s 423ms/step - loss: 0.6469 - accuracy: 0.9411 - iou_coef: 0.8811 - dice_coef: 0.9340 - f1_score: 0.9342 - aggregated_jaccard_index: 0.8882 - val_val_loss: 0.5128 - val_val_accuracy: 0.9379 - val_val_iou_coef: 0.9007 - val_val_dice_coef: 0.9469 - val_val_f1_score: 0.9470 - val_val_aggregated_jaccard_index: 0.9022 - lr: 1.0000e-04
# Epoch 56/150
# 171/171 [==============================] - 73s 429ms/step - loss: 0.6424 - accuracy: 0.9413 - iou_coef: 0.8818 - dice_coef: 0.9345 - f1_score: 0.9346 - aggregated_jaccard_index: 0.8880 - val_val_loss: 0.5111 - val_val_accuracy: 0.9261 - val_val_iou_coef: 0.8870 - val_val_dice_coef: 0.9370 - val_val_f1_score: 0.9370 - val_val_aggregated_jaccard_index: 0.8876 - lr: 1.0000e-04
# Epoch 57/150
# 171/171 [==============================] - 73s 424ms/step - loss: 0.6358 - accuracy: 0.9418 - iou_coef: 0.8827 - dice_coef: 0.9351 - f1_score: 0.9351 - aggregated_jaccard_index: 0.8897 - val_val_loss: 0.5040 - val_val_accuracy: 0.9233 - val_val_iou_coef: 0.8845 - val_val_dice_coef: 0.9349 - val_val_f1_score: 0.9349 - val_val_aggregated_jaccard_index: 0.8847 - lr: 1.0000e-04
# Epoch 58/150
# 171/171 [==============================] - 57s 333ms/step - loss: 0.6303 - accuracy: 0.9422 - iou_coef: 0.8838 - dice_coef: 0.9357 - f1_score: 0.9358 - aggregated_jaccard_index: 0.8903 - val_val_loss: 0.5102 - val_val_accuracy: 0.9234 - val_val_iou_coef: 0.8838 - val_val_dice_coef: 0.9349 - val_val_f1_score: 0.9350 - val_val_aggregated_jaccard_index: 0.8839 - lr: 1.0000e-04
# Epoch 59/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.6313 - accuracy: 0.9418 - iou_coef: 0.8826 - dice_coef: 0.9350 - f1_score: 0.9351 - aggregated_jaccard_index: 0.8896 - val_val_loss: 0.5020 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.9000 - val_val_dice_coef: 0.9464 - val_val_f1_score: 0.9464 - val_val_aggregated_jaccard_index: 0.9013 - lr: 1.0000e-04
# Epoch 60/150
# 171/171 [==============================] - ETA: 0s - loss: 0.6261 - accuracy: 0.9420 - iou_coef: 0.8832 - dice_coef: 0.9353 - f1_score: 0.9354 - aggregated_jaccard_index: 0.8899
# ✅ Saved improved backbone at epoch 60 with val_iou=0.9020
# 171/171 [==============================] - 56s 329ms/step - loss: 0.6259 - accuracy: 0.9420 - iou_coef: 0.8832 - dice_coef: 0.9353 - f1_score: 0.9354 - aggregated_jaccard_index: 0.8899 - val_val_loss: 0.4996 - val_val_accuracy: 0.9380 - val_val_iou_coef: 0.9020 - val_val_dice_coef: 0.9476 - val_val_f1_score: 0.9476 - val_val_aggregated_jaccard_index: 0.9034 - lr: 1.0000e-04
# Epoch 61/150
# 171/171 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.9417 - iou_coef: 0.8822 - dice_coef: 0.9347 - f1_score: 0.9349 - aggregated_jaccard_index: 0.8893
# ✅ Saved improved backbone at epoch 61 with val_iou=0.9056
# 171/171 [==============================] - 53s 311ms/step - loss: 0.6241 - accuracy: 0.9417 - iou_coef: 0.8822 - dice_coef: 0.9347 - f1_score: 0.9349 - aggregated_jaccard_index: 0.8893 - val_val_loss: 0.4927 - val_val_accuracy: 0.9406 - val_val_iou_coef: 0.9056 - val_val_dice_coef: 0.9497 - val_val_f1_score: 0.9498 - val_val_aggregated_jaccard_index: 0.9069 - lr: 1.0000e-04
# Epoch 62/150
# 171/171 [==============================] - 56s 327ms/step - loss: 0.6222 - accuracy: 0.9418 - iou_coef: 0.8828 - dice_coef: 0.9351 - f1_score: 0.9352 - aggregated_jaccard_index: 0.8883 - val_val_loss: 0.4950 - val_val_accuracy: 0.9363 - val_val_iou_coef: 0.8998 - val_val_dice_coef: 0.9463 - val_val_f1_score: 0.9464 - val_val_aggregated_jaccard_index: 0.9006 - lr: 1.0000e-04
# Epoch 63/150
# 171/171 [==============================] - 53s 312ms/step - loss: 0.6133 - accuracy: 0.9425 - iou_coef: 0.8841 - dice_coef: 0.9359 - f1_score: 0.9360 - aggregated_jaccard_index: 0.8900 - val_val_loss: 0.4870 - val_val_accuracy: 0.9358 - val_val_iou_coef: 0.8998 - val_val_dice_coef: 0.9461 - val_val_f1_score: 0.9461 - val_val_aggregated_jaccard_index: 0.9008 - lr: 1.0000e-04
# Epoch 64/150
# 171/171 [==============================] - 56s 330ms/step - loss: 0.6115 - accuracy: 0.9425 - iou_coef: 0.8842 - dice_coef: 0.9359 - f1_score: 0.9360 - aggregated_jaccard_index: 0.8901 - val_val_loss: 0.4933 - val_val_accuracy: 0.9370 - val_val_iou_coef: 0.9009 - val_val_dice_coef: 0.9468 - val_val_f1_score: 0.9468 - val_val_aggregated_jaccard_index: 0.9024 - lr: 1.0000e-04
# Epoch 65/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.6052 - accuracy: 0.9429 - iou_coef: 0.8847 - dice_coef: 0.9362 - f1_score: 0.9363 - aggregated_jaccard_index: 0.8907 - val_val_loss: 0.4930 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.9010 - val_val_dice_coef: 0.9471 - val_val_f1_score: 0.9472 - val_val_aggregated_jaccard_index: 0.9023 - lr: 1.0000e-04
# Epoch 66/150
# 171/171 [==============================] - 58s 342ms/step - loss: 0.6013 - accuracy: 0.9431 - iou_coef: 0.8848 - dice_coef: 0.9362 - f1_score: 0.9363 - aggregated_jaccard_index: 0.8918 - val_val_loss: 0.4876 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.9017 - val_val_dice_coef: 0.9477 - val_val_f1_score: 0.9478 - val_val_aggregated_jaccard_index: 0.9032 - lr: 1.0000e-04
# Epoch 67/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.5984 - accuracy: 0.9428 - iou_coef: 0.8846 - dice_coef: 0.9362 - f1_score: 0.9363 - aggregated_jaccard_index: 0.8911 - val_val_loss: 0.4993 - val_val_accuracy: 0.9303 - val_val_iou_coef: 0.8925 - val_val_dice_coef: 0.9419 - val_val_f1_score: 0.9419 - val_val_aggregated_jaccard_index: 0.8923 - lr: 1.0000e-04
# Epoch 68/150
# 171/171 [==============================] - 56s 327ms/step - loss: 0.5985 - accuracy: 0.9425 - iou_coef: 0.8834 - dice_coef: 0.9353 - f1_score: 0.9354 - aggregated_jaccard_index: 0.8907 - val_val_loss: 0.4892 - val_val_accuracy: 0.9369 - val_val_iou_coef: 0.8992 - val_val_dice_coef: 0.9458 - val_val_f1_score: 0.9459 - val_val_aggregated_jaccard_index: 0.9004 - lr: 1.0000e-04
# Epoch 69/150
# 171/171 [==============================] - 53s 309ms/step - loss: 0.5920 - accuracy: 0.9429 - iou_coef: 0.8843 - dice_coef: 0.9359 - f1_score: 0.9361 - aggregated_jaccard_index: 0.8906 - val_val_loss: 0.4893 - val_val_accuracy: 0.9360 - val_val_iou_coef: 0.8985 - val_val_dice_coef: 0.9454 - val_val_f1_score: 0.9454 - val_val_aggregated_jaccard_index: 0.8996 - lr: 1.0000e-04
# Epoch 70/150
# 171/171 [==============================] - 55s 323ms/step - loss: 0.5854 - accuracy: 0.9434 - iou_coef: 0.8860 - dice_coef: 0.9371 - f1_score: 0.9372 - aggregated_jaccard_index: 0.8929 - val_val_loss: 0.4886 - val_val_accuracy: 0.9366 - val_val_iou_coef: 0.8989 - val_val_dice_coef: 0.9459 - val_val_f1_score: 0.9459 - val_val_aggregated_jaccard_index: 0.9002 - lr: 1.0000e-04
# Epoch 71/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.9436 - iou_coef: 0.8864 - dice_coef: 0.9373 - f1_score: 0.9374 - aggregated_jaccard_index: 0.8922
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 171/171 [==============================] - 53s 311ms/step - loss: 0.5820 - accuracy: 0.9436 - iou_coef: 0.8864 - dice_coef: 0.9373 - f1_score: 0.9374 - aggregated_jaccard_index: 0.8922 - val_val_loss: 0.4780 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.8963 - val_val_dice_coef: 0.9439 - val_val_f1_score: 0.9440 - val_val_aggregated_jaccard_index: 0.8973 - lr: 1.0000e-04
# Epoch 72/150
# 171/171 [==============================] - 56s 329ms/step - loss: 0.5766 - accuracy: 0.9446 - iou_coef: 0.8879 - dice_coef: 0.9382 - f1_score: 0.9383 - aggregated_jaccard_index: 0.8944 - val_val_loss: 0.4799 - val_val_accuracy: 0.9333 - val_val_iou_coef: 0.8956 - val_val_dice_coef: 0.9435 - val_val_f1_score: 0.9435 - val_val_aggregated_jaccard_index: 0.8965 - lr: 1.0000e-05
# Epoch 73/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.5797 - accuracy: 0.9443 - iou_coef: 0.8877 - dice_coef: 0.9381 - f1_score: 0.9382 - aggregated_jaccard_index: 0.8932 - val_val_loss: 0.4775 - val_val_accuracy: 0.9381 - val_val_iou_coef: 0.9012 - val_val_dice_coef: 0.9472 - val_val_f1_score: 0.9473 - val_val_aggregated_jaccard_index: 0.9023 - lr: 1.0000e-05
# Epoch 74/150
# 171/171 [==============================] - 57s 331ms/step - loss: 0.5764 - accuracy: 0.9444 - iou_coef: 0.8877 - dice_coef: 0.9381 - f1_score: 0.9382 - aggregated_jaccard_index: 0.8935 - val_val_loss: 0.4780 - val_val_accuracy: 0.9379 - val_val_iou_coef: 0.9008 - val_val_dice_coef: 0.9469 - val_val_f1_score: 0.9470 - val_val_aggregated_jaccard_index: 0.9020 - lr: 1.0000e-05
# Epoch 75/150
# 171/171 [==============================] - 52s 302ms/step - loss: 0.5747 - accuracy: 0.9445 - iou_coef: 0.8883 - dice_coef: 0.9385 - f1_score: 0.9386 - aggregated_jaccard_index: 0.8937 - val_val_loss: 0.4761 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.9016 - val_val_dice_coef: 0.9474 - val_val_f1_score: 0.9474 - val_val_aggregated_jaccard_index: 0.9028 - lr: 1.0000e-05
# Epoch 76/150
# 171/171 [==============================] - 56s 328ms/step - loss: 0.5742 - accuracy: 0.9449 - iou_coef: 0.8884 - dice_coef: 0.9385 - f1_score: 0.9385 - aggregated_jaccard_index: 0.8941 - val_val_loss: 0.4766 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.9008 - val_val_dice_coef: 0.9469 - val_val_f1_score: 0.9469 - val_val_aggregated_jaccard_index: 0.9020 - lr: 1.0000e-05
# Epoch 77/150
# 171/171 [==============================] - 54s 318ms/step - loss: 0.5764 - accuracy: 0.9445 - iou_coef: 0.8882 - dice_coef: 0.9383 - f1_score: 0.9384 - aggregated_jaccard_index: 0.8949 - val_val_loss: 0.4798 - val_val_accuracy: 0.9368 - val_val_iou_coef: 0.8992 - val_val_dice_coef: 0.9460 - val_val_f1_score: 0.9461 - val_val_aggregated_jaccard_index: 0.9004 - lr: 1.0000e-05
# Epoch 78/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.5734 - accuracy: 0.9451 - iou_coef: 0.8893 - dice_coef: 0.9391 - f1_score: 0.9392 - aggregated_jaccard_index: 0.8949 - val_val_loss: 0.4763 - val_val_accuracy: 0.9383 - val_val_iou_coef: 0.9015 - val_val_dice_coef: 0.9473 - val_val_f1_score: 0.9474 - val_val_aggregated_jaccard_index: 0.9026 - lr: 1.0000e-05
# Epoch 79/150
# 171/171 [==============================] - 56s 326ms/step - loss: 0.5746 - accuracy: 0.9448 - iou_coef: 0.8885 - dice_coef: 0.9385 - f1_score: 0.9386 - aggregated_jaccard_index: 0.8942 - val_val_loss: 0.4775 - val_val_accuracy: 0.9381 - val_val_iou_coef: 0.9011 - val_val_dice_coef: 0.9471 - val_val_f1_score: 0.9471 - val_val_aggregated_jaccard_index: 0.9023 - lr: 1.0000e-05
# Epoch 80/150
# 171/171 [==============================] - 53s 307ms/step - loss: 0.5728 - accuracy: 0.9449 - iou_coef: 0.8890 - dice_coef: 0.9389 - f1_score: 0.9389 - aggregated_jaccard_index: 0.8949 - val_val_loss: 0.4758 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.9014 - val_val_dice_coef: 0.9473 - val_val_f1_score: 0.9474 - val_val_aggregated_jaccard_index: 0.9027 - lr: 1.0000e-05
# Epoch 81/150
# 171/171 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.9450 - iou_coef: 0.8891 - dice_coef: 0.9389 - f1_score: 0.9390 - aggregated_jaccard_index: 0.8950
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1e-05.
# 171/171 [==============================] - 56s 329ms/step - loss: 0.5716 - accuracy: 0.9450 - iou_coef: 0.8891 - dice_coef: 0.9389 - f1_score: 0.9390 - aggregated_jaccard_index: 0.8950 - val_val_loss: 0.4750 - val_val_accuracy: 0.9386 - val_val_iou_coef: 0.9017 - val_val_dice_coef: 0.9475 - val_val_f1_score: 0.9476 - val_val_aggregated_jaccard_index: 0.9029 - lr: 1.0000e-05
# Epoch 82/150
# 171/171 [==============================] - 53s 308ms/step - loss: 0.5709 - accuracy: 0.9452 - iou_coef: 0.8896 - dice_coef: 0.9392 - f1_score: 0.9393 - aggregated_jaccard_index: 0.8945 - val_val_loss: 0.4753 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.9015 - val_val_dice_coef: 0.9473 - val_val_f1_score: 0.9474 - val_val_aggregated_jaccard_index: 0.9026 - lr: 1.0000e-05
# Epoch 83/150
# 171/171 [==============================] - 56s 327ms/step - loss: 0.5694 - accuracy: 0.9453 - iou_coef: 0.8894 - dice_coef: 0.9391 - f1_score: 0.9391 - aggregated_jaccard_index: 0.8960 - val_val_loss: 0.4772 - val_val_accuracy: 0.9382 - val_val_iou_coef: 0.9009 - val_val_dice_coef: 0.9470 - val_val_f1_score: 0.9470 - val_val_aggregated_jaccard_index: 0.9021 - lr: 1.0000e-05
# Epoch 84/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.5697 - accuracy: 0.9452 - iou_coef: 0.8892 - dice_coef: 0.9390 - f1_score: 0.9391 - aggregated_jaccard_index: 0.8954 - val_val_loss: 0.4725 - val_val_accuracy: 0.9386 - val_val_iou_coef: 0.9020 - val_val_dice_coef: 0.9476 - val_val_f1_score: 0.9476 - val_val_aggregated_jaccard_index: 0.9032 - lr: 1.0000e-05
# Epoch 85/150
# 171/171 [==============================] - 56s 330ms/step - loss: 0.5689 - accuracy: 0.9451 - iou_coef: 0.8890 - dice_coef: 0.9388 - f1_score: 0.9389 - aggregated_jaccard_index: 0.8959 - val_val_loss: 0.4730 - val_val_accuracy: 0.9379 - val_val_iou_coef: 0.9011 - val_val_dice_coef: 0.9471 - val_val_f1_score: 0.9472 - val_val_aggregated_jaccard_index: 0.9022 - lr: 1.0000e-05
# Epoch 86/150
# 171/171 [==============================] - 52s 305ms/step - loss: 0.5706 - accuracy: 0.9450 - iou_coef: 0.8888 - dice_coef: 0.9388 - f1_score: 0.9388 - aggregated_jaccard_index: 0.8949 - val_val_loss: 0.4731 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.9010 - val_val_dice_coef: 0.9470 - val_val_f1_score: 0.9471 - val_val_aggregated_jaccard_index: 0.9022 - lr: 1.0000e-05
# Epoch 87/150
# 171/171 [==============================] - 56s 330ms/step - loss: 0.5697 - accuracy: 0.9450 - iou_coef: 0.8887 - dice_coef: 0.9387 - f1_score: 0.9388 - aggregated_jaccard_index: 0.8951 - val_val_loss: 0.4710 - val_val_accuracy: 0.9382 - val_val_iou_coef: 0.9016 - val_val_dice_coef: 0.9474 - val_val_f1_score: 0.9475 - val_val_aggregated_jaccard_index: 0.9028 - lr: 1.0000e-05
# Epoch 88/150
# 171/171 [==============================] - 54s 318ms/step - loss: 0.5703 - accuracy: 0.9450 - iou_coef: 0.8884 - dice_coef: 0.9385 - f1_score: 0.9386 - aggregated_jaccard_index: 0.8949 - val_val_loss: 0.4710 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.9021 - val_val_dice_coef: 0.9477 - val_val_f1_score: 0.9478 - val_val_aggregated_jaccard_index: 0.9033 - lr: 1.0000e-05
# Epoch 89/150
# 171/171 [==============================] - 52s 307ms/step - loss: 0.5692 - accuracy: 0.9449 - iou_coef: 0.8890 - dice_coef: 0.9389 - f1_score: 0.9390 - aggregated_jaccard_index: 0.8947 - val_val_loss: 0.4736 - val_val_accuracy: 0.9377 - val_val_iou_coef: 0.9005 - val_val_dice_coef: 0.9467 - val_val_f1_score: 0.9468 - val_val_aggregated_jaccard_index: 0.9017 - lr: 1.0000e-05
# Epoch 90/150
# 171/171 [==============================] - 56s 327ms/step - loss: 0.5685 - accuracy: 0.9448 - iou_coef: 0.8890 - dice_coef: 0.9389 - f1_score: 0.9390 - aggregated_jaccard_index: 0.8941 - val_val_loss: 0.4739 - val_val_accuracy: 0.9382 - val_val_iou_coef: 0.9008 - val_val_dice_coef: 0.9469 - val_val_f1_score: 0.9469 - val_val_aggregated_jaccard_index: 0.9020 - lr: 1.0000e-05
# Epoch 91/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.5669 - accuracy: 0.9453 - iou_coef: 0.8895 - dice_coef: 0.9392 - f1_score: 0.9392 - aggregated_jaccard_index: 0.8956 - val_val_loss: 0.4721 - val_val_accuracy: 0.9375 - val_val_iou_coef: 0.9006 - val_val_dice_coef: 0.9468 - val_val_f1_score: 0.9468 - val_val_aggregated_jaccard_index: 0.9018 - lr: 1.0000e-05
# Epoch 92/150
# 171/171 [==============================] - 56s 330ms/step - loss: 0.5659 - accuracy: 0.9452 - iou_coef: 0.8896 - dice_coef: 0.9392 - f1_score: 0.9394 - aggregated_jaccard_index: 0.8958 - val_val_loss: 0.4731 - val_val_accuracy: 0.9375 - val_val_iou_coef: 0.9004 - val_val_dice_coef: 0.9466 - val_val_f1_score: 0.9466 - val_val_aggregated_jaccard_index: 0.9015 - lr: 1.0000e-05
# Epoch 93/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.5652 - accuracy: 0.9454 - iou_coef: 0.8897 - dice_coef: 0.9393 - f1_score: 0.9394 - aggregated_jaccard_index: 0.8956 - val_val_loss: 0.4725 - val_val_accuracy: 0.9373 - val_val_iou_coef: 0.9000 - val_val_dice_coef: 0.9464 - val_val_f1_score: 0.9464 - val_val_aggregated_jaccard_index: 0.9012 - lr: 1.0000e-05
# Epoch 94/150
# 171/171 [==============================] - 56s 329ms/step - loss: 0.5643 - accuracy: 0.9454 - iou_coef: 0.8900 - dice_coef: 0.9395 - f1_score: 0.9396 - aggregated_jaccard_index: 0.8958 - val_val_loss: 0.4714 - val_val_accuracy: 0.9374 - val_val_iou_coef: 0.9002 - val_val_dice_coef: 0.9465 - val_val_f1_score: 0.9464 - val_val_aggregated_jaccard_index: 0.9013 - lr: 1.0000e-05
# Epoch 95/150
# 171/171 [==============================] - 52s 306ms/step - loss: 0.5655 - accuracy: 0.9453 - iou_coef: 0.8894 - dice_coef: 0.9391 - f1_score: 0.9392 - aggregated_jaccard_index: 0.8953 - val_val_loss: 0.4717 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.9017 - val_val_dice_coef: 0.9475 - val_val_f1_score: 0.9475 - val_val_aggregated_jaccard_index: 0.9029 - lr: 1.0000e-05
# Epoch 96/150
# 171/171 [==============================] - 52s 305ms/step - loss: 0.5643 - accuracy: 0.9457 - iou_coef: 0.8902 - dice_coef: 0.9396 - f1_score: 0.9397 - aggregated_jaccard_index: 0.8962 - val_val_loss: 0.4689 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.9024 - val_val_dice_coef: 0.9478 - val_val_f1_score: 0.9479 - val_val_aggregated_jaccard_index: 0.9036 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image
# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size = 256
batch_size = 72

# -----------------------------
# NORMALIZE FILENAMES (ONCE)
# -----------------------------
def lowercase_filenames(dir_path):
    for p in glob(os.path.join(dir_path, "*")):
        base = os.path.basename(p)
        lower = base.lower()
        if base != lower:
            os.rename(p, os.path.join(dir_path, lower))

lowercase_filenames(IMG_DIR)
lowercase_filenames(MSK_DIR)

# -----------------------------
# COLLECT PATHS
# -----------------------------
def valid_name(p):
    return "zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)
mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# KEY-BASED ALIGNMENT (SOURCE OF TRUTH)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

img_map = {stem(p): p for p in image_paths}
msk_map = {stem(p): p for p in mask_paths}

common_keys = sorted(img_map.keys() & msk_map.keys())
assert len(common_keys) > 0, "No aligned image–mask pairs found"

image_paths = [img_map[k] for k in common_keys]
mask_paths  = [msk_map[k] for k in common_keys]

print("Aligned pairs:", len(common_keys))

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )
    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.asarray(img, dtype=np.float32) / 255.0
    mask = (np.asarray(mask) > 127).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:",
      tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 80
# Masks found : 80
# Aligned pairs: 80
# Validation batches: 2

# %%
import gc
import numpy as np
import tensorflow as tf
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Let TF grow GPU memory instead of grabbing it all upfront ---
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass  # must be set before GPUs are initialized; ignore if already set

CLEAR_EVERY = 10  # clear_session + gc every N batches

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for i, (imgs, masks) in enumerate(test_dataset):
    try:
        preds = model.predict(imgs, verbose=0)
    except tf.errors.ResourceExhaustedError:
        print(f"OOM at batch {i}, retrying after clearing session")
        tf.keras.backend.clear_session()
        gc.collect()
        preds = model.predict(imgs, verbose=0)

    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]
    else:
        seg_preds = preds

    preds_bin = (np.asarray(seg_preds) > 0.5).astype("float32")

    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else np.asarray(masks)
    preds_np = preds_bin

    if masks_np.shape != preds_np.shape:
        # do resize on CPU via numpy path instead of tf.image on GPU
        with tf.device('/CPU:0'):
            preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    masks_flat = np.round(masks_np.reshape(-1)).astype(int)
    preds_flat = np.round(preds_np.reshape(-1)).astype(int)

    # --- Force custom metric ops onto CPU to keep GPU memory free ---
    with tf.device('/CPU:0'):
        iou_val = float(iou_coef(masks_np, preds_np).numpy())
        dice_val = float(dice_coef(masks_np, preds_np).numpy())
        aji_val = float(aggregated_jaccard_index(masks_np, preds_np).numpy())

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

    # --- Explicitly drop references so GPU/host memory can be reclaimed ---
    del preds, seg_preds, preds_bin, masks_np, preds_np, masks_flat, preds_flat

    if (i + 1) % CLEAR_EVERY == 0:
        gc.collect()
        tf.keras.backend.clear_session()
        # NOTE: clear_session() drops the compiled model's session state on
        # some TF versions but keeps the model object usable for .predict();
        # if you see the model "forget" weights after this, remove the
        # clear_session() call and rely on gc.collect() alone.

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.8452
# Mean Dice Coefficient: 0.9106
# Mean AJI:              0.8527
# Mean Accuracy:         0.9122
# Mean F1 Score:         0.9175

# %%
import gc
import tensorflow as tf
import numpy as np
import matplotlib
matplotlib.use("Agg")  # non-interactive backend — avoids figure/backend memory buildup over many saves
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from tensorflow.keras.optimizers import AdamW
import os

# --- Let TF grow GPU memory instead of grabbing it all upfront ---
gpus = tf.config.list_physical_devices('GPU')
for gpu in gpus:
    try:
        tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError:
        pass  # must be set before GPUs are initialized; ignore if already set

# ---------------------------------------------------------
# 1️⃣ Import custom layers and metrics (must match training)
# ---------------------------------------------------------
# from your_model_file import (
#     IoUMetric, DiceMetric, F1Metric, AJIMetric,
#     DualBranchCanvasUpsample2D_SpatialGate, conv_block
# )

custom_objects = {
    "DiceMetric": DiceMetric,
    "F1Metric": F1Metric,
    "AJIMetric": AJIMetric,
}

# ---------------------------------------------------------
# 2️⃣ Load model
# ---------------------------------------------------------
model = tf.keras.models.load_model(
    "./unet_canvas_3v8.keras",
    custom_objects=custom_objects,
    compile=False, safe_mode=False
)
print("✅ CanvasAttentionUNet loaded successfully.")

# Optional: compile with metrics for evaluation
model.compile(
    optimizer=AdamW(1e-10),
    loss="binary_crossentropy",
    metrics=[IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()]
)

# ---------------------------------------------------------
# 3️⃣ Chunked inference helper
# ---------------------------------------------------------
# The outer batch size (72) is fixed by test_dataset and can't change.
# Instead, we split each 72-sample batch into smaller GPU-sized sub-chunks
# internally, run the model on each sub-chunk, and concatenate the outputs
# back into full-batch tensors before continuing — so nothing downstream
# needs to know this happened.

INFER_CHUNK = 8  # tune down if still OOMing, up if you have headroom

def infer_in_chunks(model, images, chunk=INFER_CHUNK):
    n = images.shape[0]
    y_preds, centers, boundaries = [], [], []

    for start in range(0, n, chunk):
        sub = images[start:start + chunk]
        try:
            yp, cm, bm = model(sub, training=False)
        except tf.errors.ResourceExhaustedError:
            # halve the sub-chunk once and retry, in case even `chunk` is too big
            gc.collect()
            half = max(1, sub.shape[0] // 2)
            print(f"  OOM on sub-chunk of size {sub.shape[0]}, retrying at {half}")
            yp_parts, cm_parts, bm_parts = [], [], []
            for s2 in range(0, sub.shape[0], half):
                sub2 = sub[s2:s2 + half]
                yp2, cm2, bm2 = model(sub2, training=False)
                yp_parts.append(yp2)
                cm_parts.append(cm2)
                bm_parts.append(bm2)
            yp = tf.concat(yp_parts, axis=0)
            cm = [tf.concat([c[lvl] for c in [cm_parts[i] for i in range(len(cm_parts))]], axis=0)
                  for lvl in range(len(cm_parts[0]))] if isinstance(cm_parts[0], (list, tuple)) else tf.concat(cm_parts, axis=0)
            bm = [tf.concat([b[lvl] for b in [bm_parts[i] for i in range(len(bm_parts))]], axis=0)
                  for lvl in range(len(bm_parts[0]))] if isinstance(bm_parts[0], (list, tuple)) else tf.concat(bm_parts, axis=0)
            del yp_parts, cm_parts, bm_parts

        y_preds.append(yp)
        centers.append(cm)
        boundaries.append(bm)
        del yp, cm, bm, sub

    y_pred_full = tf.concat(y_preds, axis=0)

    # center_maps / boundary_maps are lists-of-levels (you index [-1] later),
    # so concatenate per-level across sub-chunks rather than the outer list.
    if isinstance(centers[0], (list, tuple)):
        n_levels = len(centers[0])
        center_full = [tf.concat([c[lvl] for c in centers], axis=0) for lvl in range(n_levels)]
    else:
        center_full = tf.concat(centers, axis=0)

    if isinstance(boundaries[0], (list, tuple)):
        n_levels = len(boundaries[0])
        boundary_full = [tf.concat([b[lvl] for b in boundaries], axis=0) for lvl in range(n_levels)]
    else:
        boundary_full = tf.concat(boundaries, axis=0)

    del y_preds, centers, boundaries
    return y_pred_full, center_full, boundary_full

# ---------------------------------------------------------
# 4️⃣ Inference + Save Visualizations
# ---------------------------------------------------------
save_dir = "./canvas_results3v8"
os.makedirs(save_dir, exist_ok=True)

CLEAR_EVERY = 20  # gc every N saved samples, to stop slow memory creep

sample_idx = 0  # global counter for filenames

for batch_idx, (images, masks) in enumerate(test_dataset):
    y_pred, center_maps, boundary_maps = infer_in_chunks(model, images, chunk=INFER_CHUNK)

    preds_bin = tf.cast(y_pred > 0.5, tf.float32)
    batch_size = images.shape[0]

    # Convert masks
    if len(masks.shape) == 4 and masks.shape[-1] > 1:
        masks_label = tf.argmax(masks, axis=-1)
    else:
        masks_label = tf.squeeze(masks, axis=-1)

    if preds_bin.shape[-1] > 1:
        preds_label = tf.argmax(preds_bin, axis=-1)
    else:
        preds_label = tf.squeeze(preds_bin, axis=-1)

    # -------------------------
    # Pull everything to numpy ONCE per batch
    # -------------------------
    images_np = images.numpy()
    preds_label_np = preds_label.numpy()
    masks_label_np = masks_label.numpy()
    center_np_batch = center_maps[-1][..., 0].numpy()
    boundary_np_batch = boundary_maps[-1][..., 0].numpy()

    # -------------------------
    # Save all samples in batch
    # -------------------------
    for i in range(batch_size):
        sample_idx += 1  # keep global sample numbering

        fig, axes = plt.subplots(1, 5, figsize=(18, 4))

        img_np = images_np[i]
        pred_np = preds_label_np[i]
        mask_np = masks_label_np[i]
        center_np = center_np_batch[i]
        boundary_np = boundary_np_batch[i]

        # 1️⃣ Original image
        axes[0].imshow(img_np)
        axes[0].set_title("Original Image")
        axes[0].axis("off")

        # 2️⃣ Predicted segmentation
        axes[1].imshow(label2rgb(pred_np, bg_label=0))
        axes[1].set_title("Predicted Segmentation")
        axes[1].axis("off")

        # 3️⃣ Ground truth
        axes[2].imshow(label2rgb(mask_np, bg_label=0))
        axes[2].set_title("Ground Truth")
        axes[2].axis("off")

        # 4️⃣ Center map
        axes[3].imshow(center_np, cmap="magma")
        axes[3].set_title("Center Map (final)")
        axes[3].axis("off")

        # 5️⃣ Boundary map
        axes[4].imshow(boundary_np, cmap="cividis")
        axes[4].set_title("Boundary Map (final)")
        axes[4].axis("off")

        plt.tight_layout()

        save_path = os.path.join(save_dir, f"sample_{sample_idx:04d}.png")
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        plt.close(fig)  # already present — critical, keep it

        print(f"✅ Saved {save_path}")

        if sample_idx % CLEAR_EVERY == 0:
            plt.close('all')  # belt-and-suspenders in case any figure leaked
            gc.collect()

    # --- Explicitly drop batch-level GPU/host refs before next iteration ---
    del (y_pred, center_maps, boundary_maps, preds_bin, masks_label, preds_label,
         images_np, preds_label_np, masks_label_np, center_np_batch, boundary_np_batch)

print(f"\n🎯 All {sample_idx} test images processed and saved to '{save_dir}'")
# Out:
# ✅ CanvasAttentionUNet loaded successfully.
# ✅ Saved ./canvas_results3v8/sample_0001.png
# ✅ Saved ./canvas_results3v8/sample_0002.png
# ✅ Saved ./canvas_results3v8/sample_0003.png
# ✅ Saved ./canvas_results3v8/sample_0004.png
# ✅ Saved ./canvas_results3v8/sample_0005.png
# ✅ Saved ./canvas_results3v8/sample_0006.png
# ✅ Saved ./canvas_results3v8/sample_0007.png
# ✅ Saved ./canvas_results3v8/sample_0008.png
# ✅ Saved ./canvas_results3v8/sample_0009.png
# ✅ Saved ./canvas_results3v8/sample_0010.png
# ✅ Saved ./canvas_results3v8/sample_0011.png
# ✅ Saved ./canvas_results3v8/sample_0012.png
# ✅ Saved ./canvas_results3v8/sample_0013.png
# ✅ Saved ./canvas_results3v8/sample_0014.png
# ✅ Saved ./canvas_results3v8/sample_0015.png
# ✅ Saved ./canvas_results3v8/sample_0016.png
# ✅ Saved ./canvas_results3v8/sample_0017.png
# ✅ Saved ./canvas_results3v8/sample_0018.png
# ✅ Saved ./canvas_results3v8/sample_0019.png
# ✅ Saved ./canvas_results3v8/sample_0020.png
# ✅ Saved ./canvas_results3v8/sample_0021.png
# ✅ Saved ./canvas_results3v8/sample_0022.png
# ✅ Saved ./canvas_results3v8/sample_0023.png
# ✅ Saved ./canvas_results3v8/sample_0024.png
# ✅ Saved ./canvas_results3v8/sample_0025.png
# ✅ Saved ./canvas_results3v8/sample_0026.png
# ✅ Saved ./canvas_results3v8/sample_0027.png
# ✅ Saved ./canvas_results3v8/sample_0028.png
# ✅ Saved ./canvas_results3v8/sample_0029.png
# ✅ Saved ./canvas_results3v8/sample_0030.png
# ✅ Saved ./canvas_results3v8/sample_0031.png
# ✅ Saved ./canvas_results3v8/sample_0032.png
# ✅ Saved ./canvas_results3v8/sample_0033.png
# ✅ Saved ./canvas_results3v8/sample_0034.png
# ✅ Saved ./canvas_results3v8/sample_0035.png
# ✅ Saved ./canvas_results3v8/sample_0036.png
# ✅ Saved ./canvas_results3v8/sample_0037.png
# ✅ Saved ./canvas_results3v8/sample_0038.png
# ✅ Saved ./canvas_results3v8/sample_0039.png
# ✅ Saved ./canvas_results3v8/sample_0040.png
# ✅ Saved ./canvas_results3v8/sample_0041.png
# ✅ Saved ./canvas_results3v8/sample_0042.png
# ✅ Saved ./canvas_results3v8/sample_0043.png
# ✅ Saved ./canvas_results3v8/sample_0044.png
# ✅ Saved ./canvas_results3v8/sample_0045.png
# ✅ Saved ./canvas_results3v8/sample_0046.png
# ✅ Saved ./canvas_results3v8/sample_0047.png
# ✅ Saved ./canvas_results3v8/sample_0048.png
# ✅ Saved ./canvas_results3v8/sample_0049.png
# ✅ Saved ./canvas_results3v8/sample_0050.png
# ✅ Saved ./canvas_results3v8/sample_0051.png
# ✅ Saved ./canvas_results3v8/sample_0052.png
# ✅ Saved ./canvas_results3v8/sample_0053.png
# ✅ Saved ./canvas_results3v8/sample_0054.png
# ✅ Saved ./canvas_results3v8/sample_0055.png
# ✅ Saved ./canvas_results3v8/sample_0056.png
# ✅ Saved ./canvas_results3v8/sample_0057.png
# ✅ Saved ./canvas_results3v8/sample_0058.png
# ✅ Saved ./canvas_results3v8/sample_0059.png
# ✅ Saved ./canvas_results3v8/sample_0060.png
# ✅ Saved ./canvas_results3v8/sample_0061.png
# ✅ Saved ./canvas_results3v8/sample_0062.png
# ✅ Saved ./canvas_results3v8/sample_0063.png
# ✅ Saved ./canvas_results3v8/sample_0064.png
# ✅ Saved ./canvas_results3v8/sample_0065.png
# ✅ Saved ./canvas_results3v8/sample_0066.png
# ✅ Saved ./canvas_results3v8/sample_0067.png
# ✅ Saved ./canvas_results3v8/sample_0068.png
# ✅ Saved ./canvas_results3v8/sample_0069.png
# ✅ Saved ./canvas_results3v8/sample_0070.png
# ✅ Saved ./canvas_results3v8/sample_0071.png
# ✅ Saved ./canvas_results3v8/sample_0072.png
# ✅ Saved ./canvas_results3v8/sample_0073.png
# ✅ Saved ./canvas_results3v8/sample_0074.png
# ✅ Saved ./canvas_results3v8/sample_0075.png
# ✅ Saved ./canvas_results3v8/sample_0076.png
# ✅ Saved ./canvas_results3v8/sample_0077.png
# ✅ Saved ./canvas_results3v8/sample_0078.png
# ✅ Saved ./canvas_results3v8/sample_0079.png
# ✅ Saved ./canvas_results3v8/sample_0080.png
#
# 🎯 All 80 test images processed and saved to './canvas_results3v8'

# %%
"""
For every PriorGeneratingDownsample2D stage in build_prior_guided_unet, plot:
  (row 1) the stage's feature map for one example image (channel-averaged heatmap)
  (row 2) a 2D UMAP embedding of that stage's pooled features across the dataset

Additionally, for every GeodesicDownsample2D sub-layer (the geodesic pooling
step nested inside each PriorGeneratingDownsample2D stage), produce the same
pair of plots using its raw pooled output (before the spatial-gate fusion /
skip merge / structure heads), so you can inspect what the geodesic kernel
itself is doing at each stage independent of the rest of the block.

Usage:
    python plot_stage_feature_maps_and_umap.py

Assumes:
    - `build_prior_guided_unet` and all custom layers (PriorGeneratingDownsample2D,
      PriorGuidedUpsample2D, GeodesicDownsample2D, conv_block, split_branch_block,
      etc.) are importable from your model module.
    - You have a batch of images (X) to run through the encoder, and optionally
      labels (y) for coloring the UMAP scatter plots (here: per-image nucleus density).
"""

import os
import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

try:
    import umap
except ImportError as e:
    raise ImportError(
        "umap-learn not installed. Run: pip install umap-learn --break-system-packages"
    ) from e

# -----------------------------------------------------------------------
# 1. Import your model builder (edit this import to match your project)
# -----------------------------------------------------------------------

def get_stage_extractor(model):
    """
    Build a sub-model that outputs the 's' (spatial / `final(fused)`) tensor from
    every PriorGeneratingDownsample2D call in the model, in encoder order
    (stage 1 -> stage 4). Each downsample layer returns
    (final(fused), center_map, boundary_map) when use_structure_heads=True; we
    take the first element, since that's what actually feeds the next conv_block
    (i.e. p1..p4 in build_prior_guided_unet).
    """
    stage_outputs = []
    stage_names = []
    for layer in model.layers:
        if layer.__class__.__name__ == "PriorGeneratingDownsample2D":
            out = layer.output
            s = out[0] if isinstance(out, (list, tuple)) else out
            stage_outputs.append(s)
            stage_names.append(layer.name)

    if not stage_outputs:
        raise ValueError(
            "No PriorGeneratingDownsample2D layers found on model. "
            "Check the class name matches your layer definition exactly."
        )

    print(f"Found {len(stage_outputs)} downsample stages:")
    for i, (name, t) in enumerate(zip(stage_names, stage_outputs), start=1):
        print(f"  stage {i}: layer='{name}', shape={t.shape}")

    return tf.keras.Model(inputs=model.input, outputs=stage_outputs, name="stage_extractor")


def get_geodesic_extractor(model):
    """
    Build a sub-model that outputs the raw pooled tensor from every
    GeodesicDownsample2D sub-layer nested inside each PriorGeneratingDownsample2D
    stage, in encoder order (stage 1 -> stage 4). This is the intrinsic-mean
    output of the geodesic pooling itself (`self.geo_pool(in_feat)`), taken
    BEFORE the proj_high/proj_base spatial-gate fusion, the average-pool skip
    merge, and the structure heads — i.e. purely what the robust/geodesic
    kernel produced for that pooling window.

    Note: GeodesicDownsample2D is never instantiated directly in
    build_prior_guided_unet — it only exists as `self.geo_pool` inside each
    PriorGeneratingDownsample2D instance, and it's invoked from *inside* that
    layer's own `call()` method (a plain Python-level sublayer call), not as a
    top-level call against the model's functional graph. Because of that, Keras
    never gives it its own node in `model.layers` — nested sublayer calls made
    inside another layer's `call()` aren't tracked as separate graph nodes, so
    searching `model.layers` for the class name will always come back empty.

    Instead, we find each PriorGeneratingDownsample2D instance (that part *is*
    a top-level call, so it works), grab its own input tensor via `layer.input`
    (the real KerasTensor from the outer graph, e.g. f1/f2/f3/f4), and invoke
    the already-built `layer.geo_pool` sublayer on that tensor ourselves. Since
    `geo_pool` was already built during the original forward pass, this reuses
    its existing weights (metric_raw) rather than creating new ones — it just
    re-wires the same computation into a node we can read as an output.
    """
    stage_outputs = []
    stage_names = []
    for layer in model.layers:
        if layer.__class__.__name__ == "PriorGeneratingDownsample2D":
            stage_input = layer.input  # KerasTensor feeding this stage, e.g. f1
            geo_out = layer.geo_pool(stage_input)  # re-invoke the built sublayer
            stage_outputs.append(geo_out)
            stage_names.append(layer.geo_pool.name)

    if not stage_outputs:
        raise ValueError(
            "No PriorGeneratingDownsample2D layers found on model (so no "
            "nested geo_pool sublayers to extract). Check that the class name "
            "matches your layer definition exactly."
        )

    print(f"Found {len(stage_outputs)} geodesic pooling stages:")
    for i, (name, t) in enumerate(zip(stage_names, stage_outputs), start=1):
        print(f"  geo stage {i}: layer='{name}', shape={t.shape}")

    return tf.keras.Model(inputs=model.input, outputs=stage_outputs, name="geodesic_extractor")


def pool_bottleneck(feat_maps, mode="avg"):
    """
    feat_maps: (N, h, w, c) -> (N, c) per-sample vector.
    mode: 'avg' (global average pool) or 'avgmax' (concat avg+max pool, more discriminative).
    """
    if mode == "avg":
        return feat_maps.mean(axis=(1, 2))
    elif mode == "avgmax":
        avg = feat_maps.mean(axis=(1, 2))
        mx = feat_maps.max(axis=(1, 2))
        return np.concatenate([avg, mx], axis=-1)
    else:
        raise ValueError("mode must be 'avg' or 'avgmax'")


def plot_stage_feature_maps_and_umap(
    stage_feats_list,
    stage_vecs_list,
    example_idx=0,
    labels=None,
    n_neighbors=4,
    title="Per-stage feature maps and UMAP embeddings",
):
    """
    stage_feats_list: list of (N, h, w, c) raw feature-map arrays, one per stage.
    stage_vecs_list:  list of (N, D_i) pooled feature arrays, one per stage
                       (same order as stage_feats_list).
    example_idx: which sample in the batch to visualize the feature map for.
    """
    n_stages = len(stage_feats_list)
    fig, axes = plt.subplots(2, n_stages, figsize=(5.5 * n_stages, 10.5), squeeze=False)

    last_sc = None
    for i in range(n_stages):
        feats = stage_feats_list[i]
        vecs = stage_vecs_list[i]

        # ---- Row 1: channel-averaged feature map for one example image ----
        fmap = feats[example_idx].mean(axis=-1)  # (h, w)
        ax_fm = axes[0, i]
        im = ax_fm.imshow(fmap, cmap="magma")
        ax_fm.set_title(f"Stage {i + 1} feature map\n(h={feats.shape[1]}, w={feats.shape[2]}, c={feats.shape[3]})")
        ax_fm.set_xticks([])
        ax_fm.set_yticks([])
        fig.colorbar(im, ax=ax_fm, fraction=0.046, pad=0.04)

        # ---- Row 2: 2D UMAP of pooled features across the dataset ----
        nn = min(n_neighbors, vecs.shape[0] - 1)
        reducer = umap.UMAP(n_neighbors=nn, min_dist=0.1, n_components=2, random_state=42)
        emb = reducer.fit_transform(vecs)

        ax_um = axes[1, i]
        if labels is not None:
            sc = ax_um.scatter(emb[:, 0], emb[:, 1], c=labels, cmap="viridis", s=18, alpha=0.85)
            last_sc = sc
        else:
            ax_um.scatter(emb[:, 0], emb[:, 1], s=18, alpha=0.85)
        ax_um.set_title(f"Stage {i + 1} UMAP (D={vecs.shape[1]})")
        ax_um.set_xlabel("dim 1")
        ax_um.set_ylabel("dim 2")

    if labels is not None and last_sc is not None:
        fig.colorbar(last_sc, ax=axes[1, :].tolist(), fraction=0.02, pad=0.02, label="nucleus density")

    fig.suptitle(title)
    return fig


def main():
    # -------------------------------------------------------------------
    # 2. Build model + extractors
    # -------------------------------------------------------------------
    input_shape = (256, 256, 3)
    model, _, _ = build_prior_guided_unet(input_shape=input_shape, base_filters=64, num_classes=1)
    stage_extractor = get_stage_extractor(model)
    geodesic_extractor = get_geodesic_extractor(model)

    # -------------------------------------------------------------------
    # 3. Load CPM17 test set via tf.data
    # -------------------------------------------------------------------
    from glob import glob
    from PIL import Image

    IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
    MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
    ds_batch_size = 72
    img_size = input_shape[0]

    def valid_name(p):
        return "Zone" not in os.path.basename(p)

    def stem(p):
        return os.path.splitext(os.path.basename(p))[0]

    image_paths = sorted(p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p))
    mask_paths = sorted(p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p))
    assert [stem(p) for p in image_paths] == [stem(p) for p in mask_paths], \
        "Image-mask filename mismatch"
    print("Images found:", len(image_paths))

    def _load_numpy(img_path, mask_path):
        img_path = img_path.numpy().decode("utf-8")
        mask_path = mask_path.numpy().decode("utf-8")
        img = Image.open(img_path).convert("RGB").resize((img_size, img_size), Image.BILINEAR)
        mask = Image.open(mask_path).convert("L").resize((img_size, img_size), Image.NEAREST)
        img = np.array(img, dtype=np.float32) / 255.0
        mask = (np.array(mask) > 127).astype(np.float32)[..., None]
        return img, mask

    def load_image_mask(img_path, mask_path):
        img, mask = tf.py_function(_load_numpy, [img_path, mask_path], [tf.float32, tf.float32])
        img.set_shape([img_size, img_size, 3])
        mask.set_shape([img_size, img_size, 1])
        return img, mask

    test_dataset = (
        tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
        .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(ds_batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )

    # Materialize images (for extractor.predict) and per-image mask density (for coloring)
    X_list, density_list = [], []
    for imgs, masks in test_dataset:
        X_list.append(imgs.numpy())
        density_list.append(masks.numpy().mean(axis=(1, 2, 3)))  # fraction of positive pixels
    X = np.concatenate(X_list, axis=0)
    y = np.concatenate(density_list, axis=0)  # continuous "label" = nucleus density per image
    print("Loaded images:", X.shape, "| density range:", y.min(), "-", y.max())

    # -------------------------------------------------------------------
    # 4a. Extract per-stage PriorGeneratingDownsample2D outputs + pool
    # -------------------------------------------------------------------
    stage_feats = stage_extractor.predict(X, batch_size=ds_batch_size, verbose=1)
    if not isinstance(stage_feats, (list, tuple)):
        stage_feats = [stage_feats]

    stage_vecs = [pool_bottleneck(f, mode="avgmax") for f in stage_feats]
    for i, (f, v) in enumerate(zip(stage_feats, stage_vecs), start=1):
        print(f"Stage {i}: feature map shape={f.shape}, pooled vector shape={v.shape}")

    # -------------------------------------------------------------------
    # 4b. Extract per-stage GeodesicDownsample2D (raw geodesic pooling) outputs + pool
    # -------------------------------------------------------------------
    geo_feats = geodesic_extractor.predict(X, batch_size=ds_batch_size, verbose=1)
    if not isinstance(geo_feats, (list, tuple)):
        geo_feats = [geo_feats]

    geo_vecs = [pool_bottleneck(f, mode="avgmax") for f in geo_feats]
    for i, (f, v) in enumerate(zip(geo_feats, geo_vecs), start=1):
        print(f"Geodesic stage {i}: feature map shape={f.shape}, pooled vector shape={v.shape}")

    # -------------------------------------------------------------------
    # 5. Plot feature maps (top row) + UMAP embeddings (bottom row)
    # -------------------------------------------------------------------
    fig_stage = plot_stage_feature_maps_and_umap(
        stage_feats,
        stage_vecs,
        example_idx=0,
        labels=y,
        title="Per-stage feature maps and UMAP embeddings (PriorGeneratingDownsample2D output)",
    )
    fig_stage.savefig("stage_feature_maps_and_umap.png", dpi=150, bbox_inches="tight")

    fig_geo = plot_stage_feature_maps_and_umap(
        geo_feats,
        geo_vecs,
        example_idx=0,
        labels=y,
        title="Per-stage feature maps and UMAP embeddings (raw GeodesicDownsample2D pooling)",
    )
    fig_geo.savefig("geodesic_feature_maps_and_umap.png", dpi=150, bbox_inches="tight")

    plt.show()


if __name__ == "__main__":
    main()
# Out:
# Found 4 downsample stages:
#   stage 1: layer='prior_generating_downsample2d_4', shape=(None, 128, 128, 64)
#   stage 2: layer='prior_generating_downsample2d_5', shape=(None, 64, 64, 64)
#   stage 3: layer='prior_generating_downsample2d_6', shape=(None, 32, 32, 64)
#   stage 4: layer='prior_generating_downsample2d_7', shape=(None, 16, 16, 64)
# Found 4 geodesic pooling stages:
#   geo stage 1: layer='geodesic_downsample2d_8', shape=(None, 128, 128, 64)
#   geo stage 2: layer='geodesic_downsample2d_9', shape=(None, 64, 64, 128)
#   geo stage 3: layer='geodesic_downsample2d_10', shape=(None, 32, 32, 256)
#   geo stage 4: layer='geodesic_downsample2d_11', shape=(None, 16, 16, 512)
# Images found: 80
# Loaded images: (80, 256, 256, 3) | density range: 0.12145996 - 0.85920715
# 2026-09-17 17:17:09.308238: W external/local_tsl/tsl/framework/bfc_allocator.cc:366] Garbage collection: deallocate free memory regions (i.e., allocations) so that we can re-allocate a larger region to avoid OOM due to memory fragmentation. If you see this message frequently, you are running near the threshold of the available device memory and re-allocation may incur great performance overhead. You may try smaller batch sizes to observe the performance impact. Set TF_ENABLE_GPU_GARBAGE_COLLECTION=false if you'd like to disable this feature.
# 2/2 [==============================] - 15s 1s/step
# Stage 1: feature map shape=(80, 128, 128, 64), pooled vector shape=(80, 128)
# Stage 2: feature map shape=(80, 64, 64, 64), pooled vector shape=(80, 128)
# Stage 3: feature map shape=(80, 32, 32, 64), pooled vector shape=(80, 128)
# Stage 4: feature map shape=(80, 16, 16, 64), pooled vector shape=(80, 128)
# 2/2 [==============================] - 1s 115ms/step
# Geodesic stage 1: feature map shape=(80, 128, 128, 64), pooled vector shape=(80, 128)
# Geodesic stage 2: feature map shape=(80, 64, 64, 128), pooled vector shape=(80, 256)
# Geodesic stage 3: feature map shape=(80, 32, 32, 256), pooled vector shape=(80, 512)
# Geodesic stage 4: feature map shape=(80, 16, 16, 512), pooled vector shape=(80, 1024)
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /home/stark24/miniconda3/envs/tf_new/lib/python3.10/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# /tmp/ipykernel_74114/4112652998.py:295: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# =========================================================
# CONFIG  -- edit these to match your machine
# =========================================================
IMG_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/images"
MSK_DIR = "../GLAS_PREPARED_DATA/test_combined_ab/masks"
img_size   = 256
batch_size = 71
AUTOTUNE = tf.data.AUTOTUNE
MASK_SUFFIX = "_lesion"


def _valid_name(p):
    return "Zone" not in os.path.basename(p)


def _image_stem(p):
    return os.path.splitext(os.path.basename(p))[0]


def _mask_stem(p):
    name = os.path.splitext(os.path.basename(p))[0]
    if name.endswith(MASK_SUFFIX):
        name = name[: -len(MASK_SUFFIX)]
    return name


def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB")
    img = img.resize((img_size, img_size), Image.BILINEAR)
    img = np.array(img, dtype=np.float32) / 255.0

    mask = Image.open(mask_path).convert("L")
    mask = mask.resize((img_size, img_size), Image.NEAREST)
    mask = np.array(mask, dtype=np.float32)
    mask = (mask > 127).astype(np.float32)
    mask = np.expand_dims(mask, axis=-1)

    return img, mask


def _load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(_load_numpy, [img_path, mask_path], [tf.float32, tf.float32])
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, {"segmentation": mask}


def build_test_dataset(img_dir=IMG_DIR, msk_dir=MSK_DIR):
    image_paths = sorted([p for p in glob(os.path.join(img_dir, "*")) if _valid_name(p)])
    mask_paths = sorted([p for p in glob(os.path.join(msk_dir, "*")) if _valid_name(p)])

    mask_lookup = {_mask_stem(p): p for p in mask_paths}
    paired_images, paired_masks, missing = [], [], []

    for img_p in image_paths:
        key = _image_stem(img_p)
        if key in mask_lookup:
            paired_images.append(img_p)
            paired_masks.append(mask_lookup[key])
        else:
            missing.append(img_p)

    if missing:
        raise AssertionError(f"{len(missing)} image(s) have no matching mask, e.g.: {missing[:5]}")

    print("Paired samples:", len(paired_images))

    ds = (
        tf.data.Dataset
        .from_tensor_slices((paired_images, paired_masks))
        .map(_load_image_mask, num_parallel_calls=AUTOTUNE)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
    )
    return ds


def get_sample_batch(n_images=8, img_dir=IMG_DIR, msk_dir=MSK_DIR):
    """Convenience: pull `n_images` real images from the test set as a numpy array (N,H,W,3) in [0,1]."""
    ds = build_test_dataset(img_dir, msk_dir)
    images_batch, _ = next(iter(ds.take(1)))
    images_batch = images_batch.numpy()
    return images_batch[:n_images]


if __name__ == "__main__":
    batch = get_sample_batch(4)
    print("Sample batch shape:", batch.shape)
# Out:
# Paired samples: 80
# Sample batch shape: (4, 256, 256, 3)

# %%
import numpy as np
import tensorflow as tf
from skimage.metrics import structural_similarity as ssim

def _minmax(x, eps=1e-8):
    lo, hi = np.min(x), np.max(x)
    return (x - lo) / (hi - lo + eps)

def shannon_entropy(x, bins=64):
    hist, _ = np.histogram(x.flatten(), bins=bins, density=False)
    p = hist / (hist.sum() + 1e-12)
    p = p[p > 0]
    return float(-np.sum(p * np.log2(p)))

def effective_rank(x):
    # x: (H, W, C) -> flatten spatial, treat channels as variables
    H, W, C = x.shape
    flat = x.reshape(H * W, C).astype(np.float64)
    flat = flat - flat.mean(axis=0, keepdims=True)
    if flat.shape[0] < 2 or C < 2:
        return 1.0
    cov = np.cov(flat, rowvar=False)
    eigvals = np.linalg.eigvalsh(cov)
    eigvals = np.clip(eigvals, 0, None)
    s = eigvals.sum()
    if s <= 1e-12:
        return 1.0
    p = eigvals / s
    p = p[p > 1e-12]
    H_shannon = -np.sum(p * np.log(p))
    return float(np.exp(H_shannon))  # Roy & Vetterli effective rank

def energy_ratio(x_in, x_out):
    return float(np.mean(x_out ** 2) / (np.mean(x_in ** 2) + 1e-12))

def variance_ratio(x_in, x_out):
    return float(np.var(x_out) / (np.var(x_in) + 1e-12))

def upsample_to(x_out, target_hw):
    """Bilinear-upsample x_out (H,W,C) back to target_hw. This IS the 'reconstructed' image."""
    x_out_t = tf.convert_to_tensor(x_out[None, ...], dtype=tf.float32)
    up = tf.image.resize(x_out_t, target_hw, method="bilinear")[0].numpy()
    return up

def reconstruction_error(x_in, x_out, recon=None):
    """Upsample x_out back to x_in's spatial size and compare. Pass a precomputed
    `recon` (from upsample_to) to avoid resizing twice when you also want to plot it."""
    if recon is None:
        recon = upsample_to(x_out, x_in.shape[:2])

    a = _minmax(x_in)
    b = _minmax(recon)

    mse = float(np.mean((a - b) ** 2))
    # channel-averaged SSIM (skimage needs 2D or multichannel-aware call)
    try:
        s = ssim(a, b, channel_axis=-1, data_range=1.0)
    except TypeError:
        s = ssim(a, b, multichannel=True, data_range=1.0)
    return mse, float(s)

def stage_metrics(x_in, x_out):
    """x_in, x_out: numpy arrays (H, W, C) for a single sample."""
    mse, ssim_val = reconstruction_error(x_in, x_out)
    return {
        "entropy_in": shannon_entropy(x_in),
        "entropy_out": shannon_entropy(x_out),
        "eff_rank_in": effective_rank(x_in),
        "eff_rank_out": effective_rank(x_out),
        "energy_ratio": energy_ratio(x_in, x_out),
        "variance_ratio": variance_ratio(x_in, x_out),
        "recon_mse": mse,
        "recon_ssim": ssim_val,
    }

# %%
"""
Compare MaxPooling vs GeodesicDownsample2D across consecutive pooling
stages, on real images pulled from your test set.

Outputs (saved next to this script):
  - feature_maps.png     : visual grid, one column per stage, input vs both pools
  - metric_curves.png    : per-stage information-loss metrics, mean over the batch
  - metrics_table.csv    : the raw numbers behind the plot

Run:
    python compare_pooling.py
"""

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import csv


# ---------------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------------
N_STAGES = 4          # how many consecutive poolings to apply
N_IMAGES = 8           # how many real test-set images to average metrics over
VIS_IMAGE_IDX = 0      # which of those images to draw in the feature-map grid


def run_stages(x, n_stages, make_layer):
    """x: (1,H,W,C) tensor. Returns list of tensors, index 0 = input, index i = after stage i."""
    outs = [x]
    cur = x
    for _ in range(n_stages):
        cur = make_layer()(cur)
        outs.append(cur)
    return outs


def compare_on_image(x_single):
    """x_single: (1,H,W,3) tensor for ONE image. Returns stage outputs + per-stage metrics."""
    max_stages = run_stages(x_single, N_STAGES, lambda: tf.keras.layers.MaxPool2D(2))
    geo_stages = run_stages(x_single, N_STAGES, lambda: GeodesicDownsample2D(pool_size=2))

    max_metrics, geo_metrics = [], []
    for i in range(1, N_STAGES + 1):
        max_metrics.append(stage_metrics(max_stages[i - 1][0].numpy(), max_stages[i][0].numpy()))
        geo_metrics.append(stage_metrics(geo_stages[i - 1][0].numpy(), geo_stages[i][0].numpy()))

    return max_stages, geo_stages, max_metrics, geo_metrics


def plot_feature_maps(max_stages, geo_stages, out_path="feature_maps.png"):
    n_stages = len(max_stages) - 1
    fig, axes = plt.subplots(2, n_stages + 1, figsize=(3.2 * (n_stages + 1), 6.4))
    for col in range(n_stages + 1):
        m_img = max_stages[col][0].numpy()
        g_img = geo_stages[col][0].numpy()
        m_disp = (m_img - m_img.min()) / (m_img.max() - m_img.min() + 1e-8)
        g_disp = (g_img - g_img.min()) / (g_img.max() - g_img.min() + 1e-8)
        axes[0, col].imshow(m_disp[..., :3])
        axes[0, col].set_title("Input" if col == 0 else f"MaxPool  stage {col}")
        axes[0, col].axis("off")
        axes[1, col].imshow(g_disp[..., :3])
        axes[1, col].set_title("Input" if col == 0 else f"Geodesic  stage {col}")
        axes[1, col].axis("off")
    plt.tight_layout()
    plt.savefig(out_path, dpi=130)
    plt.close()
    print("saved", out_path)


def _disp(x):
    """min-max normalize a (H,W,C) array to [0,1] for imshow, keep only first 3 channels."""
    x = x[..., :3]
    return (x - x.min()) / (x.max() - x.min() + 1e-8)


def plot_stage_details(max_stages, geo_stages, max_metrics, geo_metrics, out_path="stage_details.png"):
    """
    One row per stage, per method: Input | Downsampled | Reconstructed (upsampled back),
    with MSE/SSIM annotated under the reconstructed image.
    MaxPool rows and Geodesic rows are interleaved so each stage is easy to compare.
    """
    n_stages = len(max_stages) - 1
    fig, axes = plt.subplots(2 * n_stages, 3, figsize=(9, 3.1 * 2 * n_stages))
    if n_stages == 1:
        axes = axes.reshape(2, 3)

    for s in range(1, n_stages + 1):
        for row_offset, (label, stages, mlist) in enumerate([
            ("MaxPool", max_stages, max_metrics),
            ("Geodesic", geo_stages, geo_metrics),
        ]):
            row = 2 * (s - 1) + row_offset
            x_in = stages[s - 1][0].numpy()
            x_out = stages[s][0].numpy()
            recon = upsample_to(x_out, x_in.shape[:2])
            m = mlist[s - 1]

            axes[row, 0].imshow(_disp(x_in))
            axes[row, 0].set_title(f"{label} stage {s} — input\n{x_in.shape[0]}x{x_in.shape[1]}")
            axes[row, 0].axis("off")

            axes[row, 1].imshow(_disp(x_out))
            axes[row, 1].set_title(f"downsampled\n{x_out.shape[0]}x{x_out.shape[1]}")
            axes[row, 1].axis("off")

            axes[row, 2].imshow(_disp(recon))
            axes[row, 2].set_title(
                f"reconstructed (upsampled back)\nMSE={m['recon_mse']:.4f}  SSIM={m['recon_ssim']:.3f}  "
                f"H={m['entropy_out']:.2f}b"
            )
            axes[row, 2].axis("off")

    plt.tight_layout()
    plt.savefig(out_path, dpi=130)
    plt.close()
    print("saved", out_path)


def aggregate(metrics_per_image, key):
    """metrics_per_image: list (over images) of list (over stages) of dicts."""
    n_stages = len(metrics_per_image[0])
    means, stds = [], []
    for s in range(n_stages):
        vals = [img_metrics[s][key] for img_metrics in metrics_per_image]
        means.append(np.mean(vals))
        stds.append(np.std(vals))
    return np.array(means), np.array(stds)


def plot_metric_curves(all_max_metrics, all_geo_metrics, out_path="metric_curves.png"):
    keys = ["recon_mse", "recon_ssim", "eff_rank_out", "entropy_out", "energy_ratio", "variance_ratio"]
    titles = ["Reconstruction MSE\n(lower = less info lost)",
              "Reconstruction SSIM\n(higher = less info lost)",
              "Effective rank\n(channel diversity retained)",
              "Entropy (bits)\n(value diversity retained)",
              "Energy ratio (out / in)",
              "Variance ratio (out / in)"]
    n_stages = len(all_max_metrics[0])
    stages = list(range(1, n_stages + 1))

    fig, axes = plt.subplots(2, 3, figsize=(16, 8))
    for ax, k, t in zip(axes.flat, keys, titles):
        m_mean, m_std = aggregate(all_max_metrics, k)
        g_mean, g_std = aggregate(all_geo_metrics, k)
        ax.errorbar(stages, m_mean, yerr=m_std, marker="o", capsize=3, label="MaxPool")
        ax.errorbar(stages, g_mean, yerr=g_std, marker="s", capsize=3, label="Geodesic")
        ax.set_title(t)
        ax.set_xlabel("Pooling stage")
        ax.set_xticks(stages)
        ax.legend()
        ax.grid(alpha=0.3)
    plt.tight_layout()
    plt.savefig(out_path, dpi=130)
    plt.close()
    print("saved", out_path)


def save_csv(all_max_metrics, all_geo_metrics, out_path="metrics_table.csv"):
    keys = list(all_max_metrics[0][0].keys())
    n_stages = len(all_max_metrics[0])
    with open(out_path, "w", newline="") as f:
        writer = csv.writer(f)
        writer.writerow(["stage", "pool_type"] + keys)
        for s in range(n_stages):
            m_row = ["mean_" + k for k in keys]
            m_vals = [np.mean([img[s][k] for img in all_max_metrics]) for k in keys]
            g_vals = [np.mean([img[s][k] for img in all_geo_metrics]) for k in keys]
            writer.writerow([s + 1, "maxpool"] + [round(v, 5) for v in m_vals])
            writer.writerow([s + 1, "geodesic"] + [round(v, 5) for v in g_vals])
    print("saved", out_path)


if __name__ == "__main__":
    print(f"Loading {N_IMAGES} images from {IMG_DIR} ...")
    batch = get_sample_batch(N_IMAGES)  # (N, H, W, 3) numpy, values in [0,1]
    print("Batch shape:", batch.shape)

    all_max_metrics, all_geo_metrics = [], []
    vis_max_stages, vis_geo_stages = None, None

    for i in range(batch.shape[0]):
        x = tf.convert_to_tensor(batch[i:i + 1], dtype=tf.float32)
        max_stages, geo_stages, max_metrics, geo_metrics = compare_on_image(x)
        all_max_metrics.append(max_metrics)
        all_geo_metrics.append(geo_metrics)
        if i == VIS_IMAGE_IDX:
            vis_max_stages, vis_geo_stages = max_stages, geo_stages

    plot_feature_maps(vis_max_stages, vis_geo_stages)
    plot_stage_details(vis_max_stages, vis_geo_stages, all_max_metrics[VIS_IMAGE_IDX], all_geo_metrics[VIS_IMAGE_IDX])
    plot_metric_curves(all_max_metrics, all_geo_metrics)
    save_csv(all_max_metrics, all_geo_metrics)

    print(f"\nAveraged over {batch.shape[0]} images, per-stage summary:")
    for s in range(N_STAGES):
        print(f"\n-- Stage {s + 1} --")
        for k in all_max_metrics[0][0].keys():
            m_mean, _ = aggregate(all_max_metrics, k)
            g_mean, _ = aggregate(all_geo_metrics, k)
            print(f"  {k:15s}  MaxPool={m_mean[s]:.4f}   Geodesic={g_mean[s]:.4f}")
# Out:
# Loading 8 images from ../GLAS_PREPARED_DATA/test_combined_ab/images ...
# Paired samples: 80
# Batch shape: (8, 256, 256, 3)
# saved feature_maps.png
# saved stage_details.png
# saved metric_curves.png
# saved metrics_table.csv
#
# Averaged over 8 images, per-stage summary:
#
# -- Stage 1 --
#   entropy_in       MaxPool=5.4284   Geodesic=5.4284
#   entropy_out      MaxPool=5.3265   Geodesic=5.4429
#   eff_rank_in      MaxPool=1.2500   Geodesic=1.2500
#   eff_rank_out     MaxPool=1.2471   Geodesic=1.2268
#   energy_ratio     MaxPool=1.1158   Geodesic=0.9952
#   variance_ratio   MaxPool=0.8693   Geodesic=0.9469
#   recon_mse        MaxPool=0.0043   Geodesic=0.0024
#   recon_ssim       MaxPool=0.8278   Geodesic=0.8634
#
# -- Stage 2 --
#   entropy_in       MaxPool=5.3265   Geodesic=5.4429
#   entropy_out      MaxPool=5.2014   Geodesic=5.4598
#   eff_rank_in      MaxPool=1.2471   Geodesic=1.2268
#   eff_rank_out     MaxPool=1.2214   Geodesic=1.2007
#   energy_ratio     MaxPool=1.1443   Geodesic=0.9917
#   variance_ratio   MaxPool=0.7632   Geodesic=0.9065
#   recon_mse        MaxPool=0.0089   Geodesic=0.0064
#   recon_ssim       MaxPool=0.6874   Geodesic=0.7623
#
# -- Stage 3 --
#   entropy_in       MaxPool=5.2014   Geodesic=5.4598
#   entropy_out      MaxPool=4.9412   Geodesic=5.4379
#   eff_rank_in      MaxPool=1.2214   Geodesic=1.2007
#   eff_rank_out     MaxPool=1.1868   Geodesic=1.1836
#   energy_ratio     MaxPool=1.1409   Geodesic=0.9901
#   variance_ratio   MaxPool=0.6446   Geodesic=0.8847
#   recon_mse        MaxPool=0.0128   Geodesic=0.0075
#   recon_ssim       MaxPool=0.6173   Geodesic=0.7063
#
# -- Stage 4 --
#   entropy_in       MaxPool=4.9412   Geodesic=5.4379
#   entropy_out      MaxPool=4.6673   Geodesic=5.3593
#   eff_rank_in      MaxPool=1.1868   Geodesic=1.1836
#   eff_rank_out     MaxPool=1.1641   Geodesic=1.1819
#   energy_ratio     MaxPool=1.1240   Geodesic=0.9898
#   variance_ratio   MaxPool=0.4849   Geodesic=0.8771
#   recon_mse        MaxPool=0.0139   Geodesic=0.0089
#   recon_ssim       MaxPool=0.5624   Geodesic=0.7018
