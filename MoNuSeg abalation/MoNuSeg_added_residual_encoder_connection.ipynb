# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 17:41:45.318200: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 17:41:45.346345: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 17:41:45.346388: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 17:41:45.348106: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 17:41:45.355599: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 17:41:45.928903: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 17:41:46.796662: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:46.853835: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:46.853870: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):

    res = x

    # ============================================================
    # ENCODER BLOCK
    # ============================================================
    if not decoder:


        # -------------------------------
        # Branch 2: Evolutionary Conv
        # -------------------------------
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        # -------------------------------
        # Depthwise Patch Attention
        # -------------------------------

        # Residual projection
        res = layers.Conv2D(filters, 1, padding=padding)(res)

        # Final fusion
        out = layers.Add()([res, x1])

        return out

    # ============================================================
    # DECODER BLOCK
    # ============================================================
    else:

        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class RegionawareAnistropicMeanPool2D(layers.Layer):

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = RegionawareAnistropicMeanPool2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = RegionawareAnistropicMeanPool2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = RegionawareAnistropicMeanPool2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = RegionawareAnistropicMeanPool2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 17:41:46.897607: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:46.897675: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:46.897690: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:47.017406: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:47.017448: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:47.017454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 17:41:47.017464: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 17:41:47.017475: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:41:47.017493: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 32)         128       ['input_1[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  add (Add)                   (None, 256, 256, 32)         0         ['conv2d[0][0]',
#                                                                      'activation[0][0]']
#
#  regionaware_anistropic_mea  (None, 128, 128, 32)         32        ['add[0][0]']
#  n_pool2d (RegionawareAnist
#  ropicMeanPool2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['regionaware_anistropic_mean_
#                                                                     pool2d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)         2112      ['gaussian_dropout[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['conv2d_1[0][0]',
#                                                                      'activation_1[0][0]']
#
#  regionaware_anistropic_mea  (None, 64, 64, 64)           64        ['add_1[0][0]']
#  n_pool2d_1 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['regionaware_anistropic_mean_
#                                                                     pool2d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)          8320      ['gaussian_dropout_1[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  add_2 (Add)                 (None, 64, 64, 128)          0         ['conv2d_2[0][0]',
#                                                                      'activation_2[0][0]']
#
#  regionaware_anistropic_mea  (None, 32, 32, 128)          128       ['add_2[0][0]']
#  n_pool2d_2 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['regionaware_anistropic_mean_
#                                                                     pool2d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 256)          33024     ['dropout_2[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  add_3 (Add)                 (None, 32, 32, 256)          0         ['conv2d_3[0][0]',
#                                                                      'activation_3[0][0]']
#
#  regionaware_anistropic_mea  (None, 16, 16, 256)          256       ['add_3[0][0]']
#  n_pool2d_3 (RegionawareAni
#  stropicMeanPool2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['regionaware_anistropic_mean_
#                                                                     pool2d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 384)          98688     ['gaussian_dropout_2[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  add_4 (Add)                 (None, 16, 16, 384)          0         ['conv2d_4[0][0]',
#                                                                      'activation_4[0][0]']
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['add_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add_5 (Add)                 (None, 32, 32, 256)          0         ['add_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add_5[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_6 (Add)                 (None, 64, 64, 128)          0         ['add_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_6[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_7 (Add)                 (None, 128, 128, 64)         0         ['add_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_7[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_8 (Add)                 (None, 256, 256, 32)         0         ['add[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 256, 256, 1)          33        ['add_8[0][0]']
#
# ==================================================================================================
# Total params: 2975370 (11.35 MB)
# Trainable params: 2972682 (11.34 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../MONUSEG_DATA/aug_tune/images/*.png"))
train_mask_paths = sorted(glob("../MONUSEG_DATA/aug_tune/masks/*.png"))
val_img_paths   = sorted(glob("../MONUSEG_DATA/val/images/*.png"))
val_mask_paths  = sorted(glob("../MONUSEG_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# --- Loader ---
def load_image_mask(img_path, mask_path):
    img = np.array(Image.open(img_path.numpy().decode("utf-8")).convert("RGB").resize((img_size, img_size))) / 255.0
    mask = np.array(Image.open(mask_path.numpy().decode("utf-8")).convert("L").resize((img_size, img_size)))
    mask = (mask > 127).astype(np.float32)[..., None]  # binarize mask
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(load_image_mask, [img_path, mask_path], [tf.float32, tf.float32])
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# --- Build train & validation datasets ---
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", len(list(train_dataset)))
print("Validation batches:", len(list(val_dataset)))
# Out:
# Train images: 350
# Train masks: 350
# Val images: 2
# Val masks: 2
# 2026-09-20 17:42:02.994830: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 88
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-20 17:42:09.350911: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 17:42:15.081524: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 17:42:15.234170: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 17:42:17.659906: I external/local_xla/xla/service/service.cc:168] XLA service 0x78135b3d6e00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 17:42:17.659943: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 17:42:17.668708: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789926137.723777   15628 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 [==============================] - ETA: 0s - loss: 3.3169 - accuracy: 0.7707 - iou_coef: 0.4833 - dice_coef: 0.6433 - f1_score: 0.6569 - aggregated_jaccard_index: 0.4997
# ✅ Saved improved backbone at epoch 1 with val_iou=0.3205
# 88/88 [==============================] - 29s 143ms/step - loss: 3.3077 - accuracy: 0.7707 - iou_coef: 0.4833 - dice_coef: 0.6433 - f1_score: 0.6569 - aggregated_jaccard_index: 0.4997 - val_val_loss: 4.5552 - val_val_accuracy: 0.7546 - val_val_iou_coef: 0.3205 - val_val_dice_coef: 0.4806 - val_val_f1_score: 0.5530 - val_val_aggregated_jaccard_index: 0.3400 - lr: 0.0010
# Epoch 2/150
# 88/88 [==============================] - ETA: 0s - loss: 2.6730 - accuracy: 0.8460 - iou_coef: 0.5663 - dice_coef: 0.7195 - f1_score: 0.7330 - aggregated_jaccard_index: 0.5777
# ✅ Saved improved backbone at epoch 2 with val_iou=0.4184
# 88/88 [==============================] - 10s 105ms/step - loss: 2.6709 - accuracy: 0.8460 - iou_coef: 0.5663 - dice_coef: 0.7195 - f1_score: 0.7330 - aggregated_jaccard_index: 0.5777 - val_val_loss: 3.7352 - val_val_accuracy: 0.8375 - val_val_iou_coef: 0.4184 - val_val_dice_coef: 0.5850 - val_val_f1_score: 0.6420 - val_val_aggregated_jaccard_index: 0.4405 - lr: 0.0010
# Epoch 3/150
# 88/88 [==============================] - ETA: 0s - loss: 2.5036 - accuracy: 0.8570 - iou_coef: 0.5850 - dice_coef: 0.7354 - f1_score: 0.7454 - aggregated_jaccard_index: 0.5944
# ✅ Saved improved backbone at epoch 3 with val_iou=0.5181
# 88/88 [==============================] - 14s 144ms/step - loss: 2.5045 - accuracy: 0.8570 - iou_coef: 0.5850 - dice_coef: 0.7354 - f1_score: 0.7454 - aggregated_jaccard_index: 0.5944 - val_val_loss: 2.9127 - val_val_accuracy: 0.8751 - val_val_iou_coef: 0.5181 - val_val_dice_coef: 0.6805 - val_val_f1_score: 0.7031 - val_val_aggregated_jaccard_index: 0.5341 - lr: 0.0010
# Epoch 4/150
# 88/88 [==============================] - ETA: 0s - loss: 2.3768 - accuracy: 0.8627 - iou_coef: 0.5960 - dice_coef: 0.7442 - f1_score: 0.7525 - aggregated_jaccard_index: 0.6055
# ✅ Saved improved backbone at epoch 4 with val_iou=0.6088
# 88/88 [==============================] - 12s 121ms/step - loss: 2.3782 - accuracy: 0.8627 - iou_coef: 0.5960 - dice_coef: 0.7442 - f1_score: 0.7525 - aggregated_jaccard_index: 0.6055 - val_val_loss: 2.3277 - val_val_accuracy: 0.9199 - val_val_iou_coef: 0.6088 - val_val_dice_coef: 0.7567 - val_val_f1_score: 0.7693 - val_val_aggregated_jaccard_index: 0.6054 - lr: 0.0010
# Epoch 5/150
# 88/88 [==============================] - 12s 122ms/step - loss: 2.2946 - accuracy: 0.8647 - iou_coef: 0.6028 - dice_coef: 0.7497 - f1_score: 0.7567 - aggregated_jaccard_index: 0.6108 - val_val_loss: 2.3545 - val_val_accuracy: 0.9159 - val_val_iou_coef: 0.5952 - val_val_dice_coef: 0.7463 - val_val_f1_score: 0.7568 - val_val_aggregated_jaccard_index: 0.5940 - lr: 0.0010
# Epoch 6/150
# 88/88 [==============================] - 16s 124ms/step - loss: 2.2188 - accuracy: 0.8657 - iou_coef: 0.6055 - dice_coef: 0.7518 - f1_score: 0.7581 - aggregated_jaccard_index: 0.6144 - val_val_loss: 2.2356 - val_val_accuracy: 0.9075 - val_val_iou_coef: 0.6012 - val_val_dice_coef: 0.7506 - val_val_f1_score: 0.7585 - val_val_aggregated_jaccard_index: 0.6081 - lr: 0.0010
# Epoch 7/150
# 88/88 [==============================] - 12s 122ms/step - loss: 2.1523 - accuracy: 0.8684 - iou_coef: 0.6101 - dice_coef: 0.7555 - f1_score: 0.7614 - aggregated_jaccard_index: 0.6193 - val_val_loss: 2.2719 - val_val_accuracy: 0.9084 - val_val_iou_coef: 0.5902 - val_val_dice_coef: 0.7423 - val_val_f1_score: 0.7500 - val_val_aggregated_jaccard_index: 0.5927 - lr: 0.0010
# Epoch 8/150
# 88/88 [==============================] - ETA: 0s - loss: 2.0743 - accuracy: 0.8690 - iou_coef: 0.6153 - dice_coef: 0.7598 - f1_score: 0.7651 - aggregated_jaccard_index: 0.6238
# ✅ Saved improved backbone at epoch 8 with val_iou=0.6308
# 88/88 [==============================] - 16s 163ms/step - loss: 2.0728 - accuracy: 0.8690 - iou_coef: 0.6153 - dice_coef: 0.7598 - f1_score: 0.7651 - aggregated_jaccard_index: 0.6238 - val_val_loss: 1.9946 - val_val_accuracy: 0.9225 - val_val_iou_coef: 0.6308 - val_val_dice_coef: 0.7736 - val_val_f1_score: 0.7787 - val_val_aggregated_jaccard_index: 0.6306 - lr: 0.0010
# Epoch 9/150
# 88/88 [==============================] - 12s 119ms/step - loss: 2.0089 - accuracy: 0.8711 - iou_coef: 0.6179 - dice_coef: 0.7615 - f1_score: 0.7664 - aggregated_jaccard_index: 0.6275 - val_val_loss: 2.0519 - val_val_accuracy: 0.9072 - val_val_iou_coef: 0.6066 - val_val_dice_coef: 0.7547 - val_val_f1_score: 0.7611 - val_val_aggregated_jaccard_index: 0.6149 - lr: 0.0010
# Epoch 10/150
# 88/88 [==============================] - 12s 118ms/step - loss: 1.9470 - accuracy: 0.8716 - iou_coef: 0.6205 - dice_coef: 0.7636 - f1_score: 0.7682 - aggregated_jaccard_index: 0.6299 - val_val_loss: 1.9182 - val_val_accuracy: 0.9178 - val_val_iou_coef: 0.6273 - val_val_dice_coef: 0.7710 - val_val_f1_score: 0.7763 - val_val_aggregated_jaccard_index: 0.6283 - lr: 0.0010
# Epoch 11/150
# 88/88 [==============================] - 15s 153ms/step - loss: 1.8980 - accuracy: 0.8718 - iou_coef: 0.6214 - dice_coef: 0.7643 - f1_score: 0.7686 - aggregated_jaccard_index: 0.6304 - val_val_loss: 2.0292 - val_val_accuracy: 0.9003 - val_val_iou_coef: 0.5933 - val_val_dice_coef: 0.7444 - val_val_f1_score: 0.7498 - val_val_aggregated_jaccard_index: 0.6008 - lr: 0.0010
# Epoch 12/150
# 88/88 [==============================] - 12s 121ms/step - loss: 1.8337 - accuracy: 0.8732 - iou_coef: 0.6245 - dice_coef: 0.7668 - f1_score: 0.7708 - aggregated_jaccard_index: 0.6348 - val_val_loss: 1.9652 - val_val_accuracy: 0.9112 - val_val_iou_coef: 0.5992 - val_val_dice_coef: 0.7492 - val_val_f1_score: 0.7561 - val_val_aggregated_jaccard_index: 0.6043 - lr: 0.0010
# Epoch 13/150
# 88/88 [==============================] - 12s 123ms/step - loss: 1.7980 - accuracy: 0.8729 - iou_coef: 0.6243 - dice_coef: 0.7666 - f1_score: 0.7705 - aggregated_jaccard_index: 0.6326 - val_val_loss: 1.8269 - val_val_accuracy: 0.9163 - val_val_iou_coef: 0.6163 - val_val_dice_coef: 0.7625 - val_val_f1_score: 0.7688 - val_val_aggregated_jaccard_index: 0.6213 - lr: 0.0010
# Epoch 14/150
# 88/88 [==============================] - ETA: 0s - loss: 1.7376 - accuracy: 0.8742 - iou_coef: 0.6266 - dice_coef: 0.7683 - f1_score: 0.7721 - aggregated_jaccard_index: 0.6355
# ✅ Saved improved backbone at epoch 14 with val_iou=0.6550
# 88/88 [==============================] - 16s 129ms/step - loss: 1.7369 - accuracy: 0.8742 - iou_coef: 0.6266 - dice_coef: 0.7683 - f1_score: 0.7721 - aggregated_jaccard_index: 0.6355 - val_val_loss: 1.6076 - val_val_accuracy: 0.9283 - val_val_iou_coef: 0.6550 - val_val_dice_coef: 0.7915 - val_val_f1_score: 0.7959 - val_val_aggregated_jaccard_index: 0.6539 - lr: 0.0010
# Epoch 15/150
# 88/88 [==============================] - 12s 121ms/step - loss: 1.6808 - accuracy: 0.8754 - iou_coef: 0.6291 - dice_coef: 0.7703 - f1_score: 0.7739 - aggregated_jaccard_index: 0.6377 - val_val_loss: 1.7456 - val_val_accuracy: 0.9064 - val_val_iou_coef: 0.6110 - val_val_dice_coef: 0.7582 - val_val_f1_score: 0.7624 - val_val_aggregated_jaccard_index: 0.6186 - lr: 0.0010
# Epoch 16/150
# 88/88 [==============================] - 14s 144ms/step - loss: 1.6481 - accuracy: 0.8741 - iou_coef: 0.6269 - dice_coef: 0.7684 - f1_score: 0.7718 - aggregated_jaccard_index: 0.6368 - val_val_loss: 1.6202 - val_val_accuracy: 0.9283 - val_val_iou_coef: 0.6415 - val_val_dice_coef: 0.7808 - val_val_f1_score: 0.7841 - val_val_aggregated_jaccard_index: 0.6306 - lr: 0.0010
# Epoch 17/150
# 88/88 [==============================] - ETA: 0s - loss: 1.5911 - accuracy: 0.8754 - iou_coef: 0.6293 - dice_coef: 0.7704 - f1_score: 0.7737 - aggregated_jaccard_index: 0.6383
# ✅ Saved improved backbone at epoch 17 with val_iou=0.6565
# 88/88 [==============================] - 10s 105ms/step - loss: 1.5954 - accuracy: 0.8754 - iou_coef: 0.6293 - dice_coef: 0.7704 - f1_score: 0.7737 - aggregated_jaccard_index: 0.6383 - val_val_loss: 1.4737 - val_val_accuracy: 0.9297 - val_val_iou_coef: 0.6565 - val_val_dice_coef: 0.7926 - val_val_f1_score: 0.7961 - val_val_aggregated_jaccard_index: 0.6562 - lr: 0.0010
# Epoch 18/150
# 88/88 [==============================] - 10s 105ms/step - loss: 1.5247 - accuracy: 0.8769 - iou_coef: 0.6342 - dice_coef: 0.7742 - f1_score: 0.7775 - aggregated_jaccard_index: 0.6429 - val_val_loss: 1.6612 - val_val_accuracy: 0.9007 - val_val_iou_coef: 0.6030 - val_val_dice_coef: 0.7523 - val_val_f1_score: 0.7556 - val_val_aggregated_jaccard_index: 0.6051 - lr: 0.0010
# Epoch 19/150
# 88/88 [==============================] - 14s 141ms/step - loss: 1.4786 - accuracy: 0.8777 - iou_coef: 0.6352 - dice_coef: 0.7749 - f1_score: 0.7780 - aggregated_jaccard_index: 0.6441 - val_val_loss: 1.3900 - val_val_accuracy: 0.9238 - val_val_iou_coef: 0.6521 - val_val_dice_coef: 0.7891 - val_val_f1_score: 0.7921 - val_val_aggregated_jaccard_index: 0.6589 - lr: 0.0010
# Epoch 20/150
# 88/88 [==============================] - 11s 107ms/step - loss: 1.4381 - accuracy: 0.8775 - iou_coef: 0.6353 - dice_coef: 0.7751 - f1_score: 0.7781 - aggregated_jaccard_index: 0.6438 - val_val_loss: 1.5347 - val_val_accuracy: 0.9066 - val_val_iou_coef: 0.6119 - val_val_dice_coef: 0.7592 - val_val_f1_score: 0.7638 - val_val_aggregated_jaccard_index: 0.6131 - lr: 0.0010
# Epoch 21/150
# 88/88 [==============================] - ETA: 0s - loss: 1.4023 - accuracy: 0.8764 - iou_coef: 0.6341 - dice_coef: 0.7742 - f1_score: 0.7770 - aggregated_jaccard_index: 0.6425
# ✅ Saved improved backbone at epoch 21 with val_iou=0.6660
# 88/88 [==============================] - 10s 104ms/step - loss: 1.4002 - accuracy: 0.8764 - iou_coef: 0.6341 - dice_coef: 0.7742 - f1_score: 0.7770 - aggregated_jaccard_index: 0.6425 - val_val_loss: 1.2792 - val_val_accuracy: 0.9328 - val_val_iou_coef: 0.6660 - val_val_dice_coef: 0.7995 - val_val_f1_score: 0.8029 - val_val_aggregated_jaccard_index: 0.6646 - lr: 0.0010
# Epoch 22/150
# 88/88 [==============================] - 14s 142ms/step - loss: 1.3398 - accuracy: 0.8784 - iou_coef: 0.6381 - dice_coef: 0.7771 - f1_score: 0.7798 - aggregated_jaccard_index: 0.6478 - val_val_loss: 1.2379 - val_val_accuracy: 0.9296 - val_val_iou_coef: 0.6632 - val_val_dice_coef: 0.7974 - val_val_f1_score: 0.8005 - val_val_aggregated_jaccard_index: 0.6670 - lr: 0.0010
# Epoch 23/150
# 88/88 [==============================] - 10s 104ms/step - loss: 1.3040 - accuracy: 0.8783 - iou_coef: 0.6380 - dice_coef: 0.7771 - f1_score: 0.7799 - aggregated_jaccard_index: 0.6461 - val_val_loss: 1.4123 - val_val_accuracy: 0.9266 - val_val_iou_coef: 0.6232 - val_val_dice_coef: 0.7656 - val_val_f1_score: 0.7679 - val_val_aggregated_jaccard_index: 0.6046 - lr: 0.0010
# Epoch 24/150
# 88/88 [==============================] - ETA: 0s - loss: 1.2530 - accuracy: 0.8796 - iou_coef: 0.6410 - dice_coef: 0.7794 - f1_score: 0.7821 - aggregated_jaccard_index: 0.6500
# ✅ Saved improved backbone at epoch 24 with val_iou=0.6682
# 88/88 [==============================] - 11s 107ms/step - loss: 1.2521 - accuracy: 0.8796 - iou_coef: 0.6410 - dice_coef: 0.7794 - f1_score: 0.7821 - aggregated_jaccard_index: 0.6500 - val_val_loss: 1.1472 - val_val_accuracy: 0.9285 - val_val_iou_coef: 0.6682 - val_val_dice_coef: 0.8011 - val_val_f1_score: 0.8039 - val_val_aggregated_jaccard_index: 0.6708 - lr: 0.0010
# Epoch 25/150
# 88/88 [==============================] - 14s 149ms/step - loss: 1.2267 - accuracy: 0.8792 - iou_coef: 0.6390 - dice_coef: 0.7779 - f1_score: 0.7806 - aggregated_jaccard_index: 0.6463 - val_val_loss: 1.1530 - val_val_accuracy: 0.9256 - val_val_iou_coef: 0.6581 - val_val_dice_coef: 0.7938 - val_val_f1_score: 0.7971 - val_val_aggregated_jaccard_index: 0.6586 - lr: 0.0010
# Epoch 26/150
# 88/88 [==============================] - 12s 120ms/step - loss: 1.1661 - accuracy: 0.8803 - iou_coef: 0.6431 - dice_coef: 0.7810 - f1_score: 0.7836 - aggregated_jaccard_index: 0.6516 - val_val_loss: 1.1181 - val_val_accuracy: 0.9241 - val_val_iou_coef: 0.6593 - val_val_dice_coef: 0.7946 - val_val_f1_score: 0.7976 - val_val_aggregated_jaccard_index: 0.6580 - lr: 0.0010
# Epoch 27/150
# 88/88 [==============================] - ETA: 0s - loss: 1.1212 - accuracy: 0.8821 - iou_coef: 0.6465 - dice_coef: 0.7836 - f1_score: 0.7863 - aggregated_jaccard_index: 0.6547
# ✅ Saved improved backbone at epoch 27 with val_iou=0.6915
# 88/88 [==============================] - 12s 120ms/step - loss: 1.1217 - accuracy: 0.8821 - iou_coef: 0.6465 - dice_coef: 0.7836 - f1_score: 0.7863 - aggregated_jaccard_index: 0.6547 - val_val_loss: 0.9708 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.6915 - val_val_dice_coef: 0.8176 - val_val_f1_score: 0.8201 - val_val_aggregated_jaccard_index: 0.6919 - lr: 0.0010
# Epoch 28/150
# 88/88 [==============================] - 15s 158ms/step - loss: 1.0828 - accuracy: 0.8817 - iou_coef: 0.6462 - dice_coef: 0.7833 - f1_score: 0.7858 - aggregated_jaccard_index: 0.6545 - val_val_loss: 0.9658 - val_val_accuracy: 0.9338 - val_val_iou_coef: 0.6822 - val_val_dice_coef: 0.8111 - val_val_f1_score: 0.8129 - val_val_aggregated_jaccard_index: 0.6837 - lr: 0.0010
# Epoch 29/150
# 88/88 [==============================] - 12s 118ms/step - loss: 1.0419 - accuracy: 0.8821 - iou_coef: 0.6480 - dice_coef: 0.7847 - f1_score: 0.7872 - aggregated_jaccard_index: 0.6568 - val_val_loss: 1.0157 - val_val_accuracy: 0.9219 - val_val_iou_coef: 0.6589 - val_val_dice_coef: 0.7943 - val_val_f1_score: 0.7970 - val_val_aggregated_jaccard_index: 0.6570 - lr: 0.0010
# Epoch 30/150
# 88/88 [==============================] - 12s 119ms/step - loss: 1.0065 - accuracy: 0.8834 - iou_coef: 0.6495 - dice_coef: 0.7860 - f1_score: 0.7885 - aggregated_jaccard_index: 0.6574 - val_val_loss: 0.9901 - val_val_accuracy: 0.9199 - val_val_iou_coef: 0.6532 - val_val_dice_coef: 0.7902 - val_val_f1_score: 0.7918 - val_val_aggregated_jaccard_index: 0.6542 - lr: 0.0010
# Epoch 31/150
# 88/88 [==============================] - 15s 160ms/step - loss: 0.9822 - accuracy: 0.8816 - iou_coef: 0.6458 - dice_coef: 0.7830 - f1_score: 0.7852 - aggregated_jaccard_index: 0.6537 - val_val_loss: 0.9568 - val_val_accuracy: 0.9202 - val_val_iou_coef: 0.6562 - val_val_dice_coef: 0.7924 - val_val_f1_score: 0.7946 - val_val_aggregated_jaccard_index: 0.6538 - lr: 0.0010
# Epoch 32/150
# 88/88 [==============================] - 12s 122ms/step - loss: 0.9299 - accuracy: 0.8842 - iou_coef: 0.6522 - dice_coef: 0.7880 - f1_score: 0.7904 - aggregated_jaccard_index: 0.6600 - val_val_loss: 0.8469 - val_val_accuracy: 0.9356 - val_val_iou_coef: 0.6807 - val_val_dice_coef: 0.8100 - val_val_f1_score: 0.8120 - val_val_aggregated_jaccard_index: 0.6814 - lr: 0.0010
# Epoch 33/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.8997 - accuracy: 0.8843 - iou_coef: 0.6519 - dice_coef: 0.7877 - f1_score: 0.7900 - aggregated_jaccard_index: 0.6591 - val_val_loss: 0.9544 - val_val_accuracy: 0.9282 - val_val_iou_coef: 0.6373 - val_val_dice_coef: 0.7777 - val_val_f1_score: 0.7799 - val_val_aggregated_jaccard_index: 0.6266 - lr: 0.0010
# Epoch 34/150
# 88/88 [==============================] - 16s 125ms/step - loss: 0.8650 - accuracy: 0.8843 - iou_coef: 0.6526 - dice_coef: 0.7883 - f1_score: 0.7905 - aggregated_jaccard_index: 0.6603 - val_val_loss: 0.8527 - val_val_accuracy: 0.9342 - val_val_iou_coef: 0.6645 - val_val_dice_coef: 0.7977 - val_val_f1_score: 0.7998 - val_val_aggregated_jaccard_index: 0.6537 - lr: 0.0010
# Epoch 35/150
# 88/88 [==============================] - ETA: 0s - loss: 0.8356 - accuracy: 0.8845 - iou_coef: 0.6514 - dice_coef: 0.7874 - f1_score: 0.7896 - aggregated_jaccard_index: 0.6590
# ✅ Saved improved backbone at epoch 35 with val_iou=0.7008
# 88/88 [==============================] - 12s 121ms/step - loss: 0.8374 - accuracy: 0.8845 - iou_coef: 0.6514 - dice_coef: 0.7874 - f1_score: 0.7896 - aggregated_jaccard_index: 0.6590 - val_val_loss: 0.7123 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7008 - val_val_dice_coef: 0.8240 - val_val_f1_score: 0.8261 - val_val_aggregated_jaccard_index: 0.6998 - lr: 0.0010
# Epoch 36/150
# 88/88 [==============================] - 15s 160ms/step - loss: 0.7998 - accuracy: 0.8849 - iou_coef: 0.6536 - dice_coef: 0.7890 - f1_score: 0.7911 - aggregated_jaccard_index: 0.6609 - val_val_loss: 0.9768 - val_val_accuracy: 0.8885 - val_val_iou_coef: 0.5998 - val_val_dice_coef: 0.7483 - val_val_f1_score: 0.7505 - val_val_aggregated_jaccard_index: 0.5849 - lr: 0.0010
# Epoch 37/150
# 88/88 [==============================] - 11s 108ms/step - loss: 0.7672 - accuracy: 0.8856 - iou_coef: 0.6556 - dice_coef: 0.7905 - f1_score: 0.7926 - aggregated_jaccard_index: 0.6627 - val_val_loss: 0.6974 - val_val_accuracy: 0.9324 - val_val_iou_coef: 0.6864 - val_val_dice_coef: 0.8140 - val_val_f1_score: 0.8162 - val_val_aggregated_jaccard_index: 0.6838 - lr: 0.0010
# Epoch 38/150
# 88/88 [==============================] - 10s 104ms/step - loss: 0.7331 - accuracy: 0.8861 - iou_coef: 0.6564 - dice_coef: 0.7911 - f1_score: 0.7932 - aggregated_jaccard_index: 0.6643 - val_val_loss: 0.7334 - val_val_accuracy: 0.9361 - val_val_iou_coef: 0.6633 - val_val_dice_coef: 0.7969 - val_val_f1_score: 0.7989 - val_val_aggregated_jaccard_index: 0.6532 - lr: 0.0010
# Epoch 39/150
# 88/88 [==============================] - 14s 144ms/step - loss: 0.7042 - accuracy: 0.8865 - iou_coef: 0.6571 - dice_coef: 0.7916 - f1_score: 0.7938 - aggregated_jaccard_index: 0.6642 - val_val_loss: 0.6192 - val_val_accuracy: 0.9382 - val_val_iou_coef: 0.6946 - val_val_dice_coef: 0.8198 - val_val_f1_score: 0.8218 - val_val_aggregated_jaccard_index: 0.6959 - lr: 0.0010
# Epoch 40/150
# 88/88 [==============================] - 10s 102ms/step - loss: 0.6795 - accuracy: 0.8860 - iou_coef: 0.6560 - dice_coef: 0.7908 - f1_score: 0.7929 - aggregated_jaccard_index: 0.6634 - val_val_loss: 0.5984 - val_val_accuracy: 0.9363 - val_val_iou_coef: 0.6920 - val_val_dice_coef: 0.8180 - val_val_f1_score: 0.8191 - val_val_aggregated_jaccard_index: 0.6942 - lr: 0.0010
# Epoch 41/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.6456 - accuracy: 0.8872 - iou_coef: 0.6593 - dice_coef: 0.7933 - f1_score: 0.7953 - aggregated_jaccard_index: 0.6671 - val_val_loss: 0.7133 - val_val_accuracy: 0.9077 - val_val_iou_coef: 0.6281 - val_val_dice_coef: 0.7715 - val_val_f1_score: 0.7739 - val_val_aggregated_jaccard_index: 0.6241 - lr: 0.0010
# Epoch 42/150
# 88/88 [==============================] - 14s 144ms/step - loss: 0.6299 - accuracy: 0.8850 - iou_coef: 0.6547 - dice_coef: 0.7898 - f1_score: 0.7917 - aggregated_jaccard_index: 0.6610 - val_val_loss: 0.5607 - val_val_accuracy: 0.9374 - val_val_iou_coef: 0.6878 - val_val_dice_coef: 0.8150 - val_val_f1_score: 0.8174 - val_val_aggregated_jaccard_index: 0.6893 - lr: 0.0010
# Epoch 43/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.5942 - accuracy: 0.8874 - iou_coef: 0.6596 - dice_coef: 0.7935 - f1_score: 0.7955 - aggregated_jaccard_index: 0.6673 - val_val_loss: 0.5258 - val_val_accuracy: 0.9403 - val_val_iou_coef: 0.6951 - val_val_dice_coef: 0.8201 - val_val_f1_score: 0.8217 - val_val_aggregated_jaccard_index: 0.6961 - lr: 0.0010
# Epoch 44/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.5670 - accuracy: 0.8879 - iou_coef: 0.6610 - dice_coef: 0.7945 - f1_score: 0.7964 - aggregated_jaccard_index: 0.6691 - val_val_loss: 0.5297 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.6843 - val_val_dice_coef: 0.8125 - val_val_f1_score: 0.8146 - val_val_aggregated_jaccard_index: 0.6806 - lr: 0.0010
# Epoch 45/150
# 88/88 [==============================] - ETA: 0s - loss: 0.5410 - accuracy: 0.8889 - iou_coef: 0.6627 - dice_coef: 0.7958 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6707
# ✅ Saved improved backbone at epoch 45 with val_iou=0.7009
# 88/88 [==============================] - 14s 143ms/step - loss: 0.5419 - accuracy: 0.8889 - iou_coef: 0.6627 - dice_coef: 0.7958 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6707 - val_val_loss: 0.4774 - val_val_accuracy: 0.9429 - val_val_iou_coef: 0.7009 - val_val_dice_coef: 0.8241 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.6996 - lr: 0.0010
# Epoch 46/150
# 88/88 [==============================] - 11s 105ms/step - loss: 0.5167 - accuracy: 0.8887 - iou_coef: 0.6634 - dice_coef: 0.7963 - f1_score: 0.7982 - aggregated_jaccard_index: 0.6711 - val_val_loss: 0.4839 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.6850 - val_val_dice_coef: 0.8130 - val_val_f1_score: 0.8145 - val_val_aggregated_jaccard_index: 0.6824 - lr: 0.0010
# Epoch 47/150
# 88/88 [==============================] - 10s 106ms/step - loss: 0.4956 - accuracy: 0.8889 - iou_coef: 0.6629 - dice_coef: 0.7959 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6710 - val_val_loss: 0.4788 - val_val_accuracy: 0.9375 - val_val_iou_coef: 0.6781 - val_val_dice_coef: 0.8080 - val_val_f1_score: 0.8093 - val_val_aggregated_jaccard_index: 0.6718 - lr: 0.0010
# Epoch 48/150
# 88/88 [==============================] - 14s 144ms/step - loss: 0.4782 - accuracy: 0.8886 - iou_coef: 0.6622 - dice_coef: 0.7954 - f1_score: 0.7972 - aggregated_jaccard_index: 0.6691 - val_val_loss: 0.5286 - val_val_accuracy: 0.9082 - val_val_iou_coef: 0.6366 - val_val_dice_coef: 0.7774 - val_val_f1_score: 0.7788 - val_val_aggregated_jaccard_index: 0.6276 - lr: 0.0010
# Epoch 49/150
# 88/88 [==============================] - 11s 108ms/step - loss: 0.4534 - accuracy: 0.8895 - iou_coef: 0.6655 - dice_coef: 0.7978 - f1_score: 0.7996 - aggregated_jaccard_index: 0.6720 - val_val_loss: 0.4077 - val_val_accuracy: 0.9365 - val_val_iou_coef: 0.6952 - val_val_dice_coef: 0.8202 - val_val_f1_score: 0.8224 - val_val_aggregated_jaccard_index: 0.6957 - lr: 0.0010
# Epoch 50/150
# 88/88 [==============================] - 11s 113ms/step - loss: 0.4331 - accuracy: 0.8907 - iou_coef: 0.6670 - dice_coef: 0.7990 - f1_score: 0.8008 - aggregated_jaccard_index: 0.6731 - val_val_loss: 0.3874 - val_val_accuracy: 0.9381 - val_val_iou_coef: 0.6962 - val_val_dice_coef: 0.8209 - val_val_f1_score: 0.8223 - val_val_aggregated_jaccard_index: 0.6980 - lr: 0.0010
# Epoch 51/150
# 88/88 [==============================] - 15s 152ms/step - loss: 0.4145 - accuracy: 0.8897 - iou_coef: 0.6655 - dice_coef: 0.7979 - f1_score: 0.7996 - aggregated_jaccard_index: 0.6725 - val_val_loss: 0.3760 - val_val_accuracy: 0.9355 - val_val_iou_coef: 0.6924 - val_val_dice_coef: 0.8182 - val_val_f1_score: 0.8193 - val_val_aggregated_jaccard_index: 0.6936 - lr: 0.0010
# Epoch 52/150
# 88/88 [==============================] - 55s 613ms/step - loss: 0.3945 - accuracy: 0.8906 - iou_coef: 0.6671 - dice_coef: 0.7991 - f1_score: 0.8008 - aggregated_jaccard_index: 0.6737 - val_val_loss: 0.3540 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.6971 - val_val_dice_coef: 0.8215 - val_val_f1_score: 0.8226 - val_val_aggregated_jaccard_index: 0.6983 - lr: 0.0010
# Epoch 53/150
# 88/88 [==============================] - ETA: 0s - loss: 0.3757 - accuracy: 0.8911 - iou_coef: 0.6685 - dice_coef: 0.8001 - f1_score: 0.8018 - aggregated_jaccard_index: 0.6759
# ✅ Saved improved backbone at epoch 53 with val_iou=0.7055
# 88/88 [==============================] - 27s 291ms/step - loss: 0.3754 - accuracy: 0.8911 - iou_coef: 0.6685 - dice_coef: 0.8001 - f1_score: 0.8018 - aggregated_jaccard_index: 0.6759 - val_val_loss: 0.3296 - val_val_accuracy: 0.9423 - val_val_iou_coef: 0.7055 - val_val_dice_coef: 0.8273 - val_val_f1_score: 0.8291 - val_val_aggregated_jaccard_index: 0.7061 - lr: 0.0010
# Epoch 54/150
# 88/88 [==============================] - 25s 264ms/step - loss: 0.3587 - accuracy: 0.8915 - iou_coef: 0.6691 - dice_coef: 0.8006 - f1_score: 0.8023 - aggregated_jaccard_index: 0.6764 - val_val_loss: 0.3609 - val_val_accuracy: 0.9248 - val_val_iou_coef: 0.6711 - val_val_dice_coef: 0.8030 - val_val_f1_score: 0.8044 - val_val_aggregated_jaccard_index: 0.6660 - lr: 0.0010
# Epoch 55/150
# 88/88 [==============================] - 11s 106ms/step - loss: 0.3460 - accuracy: 0.8903 - iou_coef: 0.6670 - dice_coef: 0.7990 - f1_score: 0.8006 - aggregated_jaccard_index: 0.6739 - val_val_loss: 0.3122 - val_val_accuracy: 0.9360 - val_val_iou_coef: 0.6957 - val_val_dice_coef: 0.8206 - val_val_f1_score: 0.8220 - val_val_aggregated_jaccard_index: 0.6959 - lr: 0.0010
# Epoch 56/150
# 88/88 [==============================] - ETA: 0s - loss: 0.3247 - accuracy: 0.8925 - iou_coef: 0.6712 - dice_coef: 0.8021 - f1_score: 0.8037 - aggregated_jaccard_index: 0.6793
# ✅ Saved improved backbone at epoch 56 with val_iou=0.7085
# 88/88 [==============================] - 11s 106ms/step - loss: 0.3249 - accuracy: 0.8925 - iou_coef: 0.6712 - dice_coef: 0.8021 - f1_score: 0.8037 - aggregated_jaccard_index: 0.6793 - val_val_loss: 0.2850 - val_val_accuracy: 0.9422 - val_val_iou_coef: 0.7085 - val_val_dice_coef: 0.8294 - val_val_f1_score: 0.8309 - val_val_aggregated_jaccard_index: 0.7093 - lr: 0.0010
# Epoch 57/150
# 88/88 [==============================] - 14s 142ms/step - loss: 0.3135 - accuracy: 0.8921 - iou_coef: 0.6703 - dice_coef: 0.8014 - f1_score: 0.8031 - aggregated_jaccard_index: 0.6768 - val_val_loss: 0.2864 - val_val_accuracy: 0.9353 - val_val_iou_coef: 0.6942 - val_val_dice_coef: 0.8195 - val_val_f1_score: 0.8204 - val_val_aggregated_jaccard_index: 0.6949 - lr: 0.0010
# Epoch 58/150
# 88/88 [==============================] - 11s 108ms/step - loss: 0.2997 - accuracy: 0.8921 - iou_coef: 0.6708 - dice_coef: 0.8018 - f1_score: 0.8034 - aggregated_jaccard_index: 0.6774 - val_val_loss: 0.2681 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.7002 - val_val_dice_coef: 0.8237 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7011 - lr: 0.0010
# Epoch 59/150
# 88/88 [==============================] - 11s 106ms/step - loss: 0.2820 - accuracy: 0.8932 - iou_coef: 0.6737 - dice_coef: 0.8040 - f1_score: 0.8056 - aggregated_jaccard_index: 0.6804 - val_val_loss: 0.2626 - val_val_accuracy: 0.9365 - val_val_iou_coef: 0.6929 - val_val_dice_coef: 0.8186 - val_val_f1_score: 0.8202 - val_val_aggregated_jaccard_index: 0.6941 - lr: 0.0010
# Epoch 60/150
# 88/88 [==============================] - 14s 148ms/step - loss: 0.2712 - accuracy: 0.8927 - iou_coef: 0.6718 - dice_coef: 0.8026 - f1_score: 0.8042 - aggregated_jaccard_index: 0.6787 - val_val_loss: 0.2436 - val_val_accuracy: 0.9399 - val_val_iou_coef: 0.7012 - val_val_dice_coef: 0.8243 - val_val_f1_score: 0.8264 - val_val_aggregated_jaccard_index: 0.7028 - lr: 0.0010
# Epoch 61/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.2587 - accuracy: 0.8932 - iou_coef: 0.6735 - dice_coef: 0.8038 - f1_score: 0.8054 - aggregated_jaccard_index: 0.6803 - val_val_loss: 0.2392 - val_val_accuracy: 0.9365 - val_val_iou_coef: 0.6936 - val_val_dice_coef: 0.8190 - val_val_f1_score: 0.8204 - val_val_aggregated_jaccard_index: 0.6949 - lr: 0.0010
# Epoch 62/150
# 88/88 [==============================] - 11s 106ms/step - loss: 0.2457 - accuracy: 0.8940 - iou_coef: 0.6754 - dice_coef: 0.8052 - f1_score: 0.8067 - aggregated_jaccard_index: 0.6823 - val_val_loss: 0.2291 - val_val_accuracy: 0.9362 - val_val_iou_coef: 0.6932 - val_val_dice_coef: 0.8188 - val_val_f1_score: 0.8199 - val_val_aggregated_jaccard_index: 0.6945 - lr: 0.0010
# Epoch 63/150
# 88/88 [==============================] - 14s 143ms/step - loss: 0.2359 - accuracy: 0.8932 - iou_coef: 0.6731 - dice_coef: 0.8035 - f1_score: 0.8050 - aggregated_jaccard_index: 0.6800 - val_val_loss: 0.2083 - val_val_accuracy: 0.9423 - val_val_iou_coef: 0.7083 - val_val_dice_coef: 0.8292 - val_val_f1_score: 0.8307 - val_val_aggregated_jaccard_index: 0.7087 - lr: 0.0010
# Epoch 64/150
# 88/88 [==============================] - 11s 108ms/step - loss: 0.2230 - accuracy: 0.8946 - iou_coef: 0.6773 - dice_coef: 0.8065 - f1_score: 0.8081 - aggregated_jaccard_index: 0.6841 - val_val_loss: 0.2106 - val_val_accuracy: 0.9414 - val_val_iou_coef: 0.6953 - val_val_dice_coef: 0.8202 - val_val_f1_score: 0.8214 - val_val_aggregated_jaccard_index: 0.6920 - lr: 0.0010
# Epoch 65/150
# 88/88 [==============================] - 12s 124ms/step - loss: 0.2148 - accuracy: 0.8938 - iou_coef: 0.6747 - dice_coef: 0.8046 - f1_score: 0.8062 - aggregated_jaccard_index: 0.6818 - val_val_loss: 0.1988 - val_val_accuracy: 0.9411 - val_val_iou_coef: 0.6976 - val_val_dice_coef: 0.8219 - val_val_f1_score: 0.8230 - val_val_aggregated_jaccard_index: 0.6960 - lr: 0.0010
# Epoch 66/150
# 88/88 [==============================] - ETA: 0s - loss: 0.2056 - accuracy: 0.8939 - iou_coef: 0.6749 - dice_coef: 0.8048 - f1_score: 0.8063 - aggregated_jaccard_index: 0.6815
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 88/88 [==============================] - 15s 162ms/step - loss: 0.2058 - accuracy: 0.8939 - iou_coef: 0.6749 - dice_coef: 0.8048 - f1_score: 0.8063 - aggregated_jaccard_index: 0.6815 - val_val_loss: 0.2007 - val_val_accuracy: 0.9307 - val_val_iou_coef: 0.6859 - val_val_dice_coef: 0.8135 - val_val_f1_score: 0.8146 - val_val_aggregated_jaccard_index: 0.6808 - lr: 0.0010
# Epoch 67/150
# 88/88 [==============================] - 13s 129ms/step - loss: 0.1987 - accuracy: 0.8949 - iou_coef: 0.6783 - dice_coef: 0.8073 - f1_score: 0.8088 - aggregated_jaccard_index: 0.6846 - val_val_loss: 0.1917 - val_val_accuracy: 0.9344 - val_val_iou_coef: 0.6933 - val_val_dice_coef: 0.8189 - val_val_f1_score: 0.8198 - val_val_aggregated_jaccard_index: 0.6925 - lr: 1.0000e-04
# Epoch 68/150
# 88/88 [==============================] - 12s 126ms/step - loss: 0.1970 - accuracy: 0.8961 - iou_coef: 0.6798 - dice_coef: 0.8083 - f1_score: 0.8098 - aggregated_jaccard_index: 0.6855 - val_val_loss: 0.1885 - val_val_accuracy: 0.9360 - val_val_iou_coef: 0.6965 - val_val_dice_coef: 0.8211 - val_val_f1_score: 0.8220 - val_val_aggregated_jaccard_index: 0.6961 - lr: 1.0000e-04
# Epoch 69/150
# 88/88 [==============================] - 16s 132ms/step - loss: 0.1949 - accuracy: 0.8963 - iou_coef: 0.6812 - dice_coef: 0.8093 - f1_score: 0.8109 - aggregated_jaccard_index: 0.6873 - val_val_loss: 0.1835 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7012 - val_val_dice_coef: 0.8244 - val_val_f1_score: 0.8259 - val_val_aggregated_jaccard_index: 0.7026 - lr: 1.0000e-04
# Epoch 70/150
# 88/88 [==============================] - 13s 130ms/step - loss: 0.1940 - accuracy: 0.8964 - iou_coef: 0.6812 - dice_coef: 0.8094 - f1_score: 0.8109 - aggregated_jaccard_index: 0.6869 - val_val_loss: 0.1831 - val_val_accuracy: 0.9383 - val_val_iou_coef: 0.7014 - val_val_dice_coef: 0.8245 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7018 - lr: 1.0000e-04
# Epoch 71/150
# 88/88 [==============================] - 16s 166ms/step - loss: 0.1935 - accuracy: 0.8964 - iou_coef: 0.6811 - dice_coef: 0.8093 - f1_score: 0.8108 - aggregated_jaccard_index: 0.6874 - val_val_loss: 0.1832 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.7000 - val_val_dice_coef: 0.8235 - val_val_f1_score: 0.8243 - val_val_aggregated_jaccard_index: 0.7002 - lr: 1.0000e-04
# Epoch 72/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.1923 - accuracy: 0.8970 - iou_coef: 0.6820 - dice_coef: 0.8099 - f1_score: 0.8115 - aggregated_jaccard_index: 0.6877 - val_val_loss: 0.1822 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.7003 - val_val_dice_coef: 0.8237 - val_val_f1_score: 0.8248 - val_val_aggregated_jaccard_index: 0.7004 - lr: 1.0000e-04
# Epoch 73/150
# 88/88 [==============================] - 11s 112ms/step - loss: 0.1905 - accuracy: 0.8969 - iou_coef: 0.6823 - dice_coef: 0.8101 - f1_score: 0.8117 - aggregated_jaccard_index: 0.6879 - val_val_loss: 0.1797 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7021 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8264 - val_val_aggregated_jaccard_index: 0.7030 - lr: 1.0000e-04
# Epoch 74/150
# 88/88 [==============================] - 16s 166ms/step - loss: 0.1886 - accuracy: 0.8971 - iou_coef: 0.6830 - dice_coef: 0.8106 - f1_score: 0.8122 - aggregated_jaccard_index: 0.6894 - val_val_loss: 0.1788 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7020 - val_val_dice_coef: 0.8249 - val_val_f1_score: 0.8253 - val_val_aggregated_jaccard_index: 0.7029 - lr: 1.0000e-04
# Epoch 75/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.1893 - accuracy: 0.8969 - iou_coef: 0.6823 - dice_coef: 0.8101 - f1_score: 0.8117 - aggregated_jaccard_index: 0.6879 - val_val_loss: 0.1778 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7025 - val_val_dice_coef: 0.8253 - val_val_f1_score: 0.8262 - val_val_aggregated_jaccard_index: 0.7030 - lr: 1.0000e-04
# Epoch 76/150
# 88/88 [==============================] - ETA: 0s - loss: 0.1866 - accuracy: 0.8972 - iou_coef: 0.6840 - dice_coef: 0.8113 - f1_score: 0.8128 - aggregated_jaccard_index: 0.6895
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 88/88 [==============================] - 11s 112ms/step - loss: 0.1865 - accuracy: 0.8972 - iou_coef: 0.6840 - dice_coef: 0.8113 - f1_score: 0.8128 - aggregated_jaccard_index: 0.6895 - val_val_loss: 0.1783 - val_val_accuracy: 0.9378 - val_val_iou_coef: 0.7002 - val_val_dice_coef: 0.8237 - val_val_f1_score: 0.8245 - val_val_aggregated_jaccard_index: 0.7006 - lr: 1.0000e-04
# Epoch 77/150
# 88/88 [==============================] - 15s 119ms/step - loss: 0.1852 - accuracy: 0.8976 - iou_coef: 0.6844 - dice_coef: 0.8117 - f1_score: 0.8133 - aggregated_jaccard_index: 0.6907 - val_val_loss: 0.1772 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.7016 - val_val_dice_coef: 0.8246 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7023 - lr: 1.0000e-05
# Epoch 78/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.1852 - accuracy: 0.8974 - iou_coef: 0.6842 - dice_coef: 0.8116 - f1_score: 0.8131 - aggregated_jaccard_index: 0.6904 - val_val_loss: 0.1766 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7024 - val_val_dice_coef: 0.8252 - val_val_f1_score: 0.8265 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 79/150
# 88/88 [==============================] - 15s 158ms/step - loss: 0.1849 - accuracy: 0.8974 - iou_coef: 0.6843 - dice_coef: 0.8116 - f1_score: 0.8131 - aggregated_jaccard_index: 0.6907 - val_val_loss: 0.1768 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7019 - val_val_dice_coef: 0.8248 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.7026 - lr: 1.0000e-05
# Epoch 80/150
# 88/88 [==============================] - 12s 125ms/step - loss: 0.1853 - accuracy: 0.8973 - iou_coef: 0.6840 - dice_coef: 0.8114 - f1_score: 0.8130 - aggregated_jaccard_index: 0.6902 - val_val_loss: 0.1764 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7023 - val_val_dice_coef: 0.8251 - val_val_f1_score: 0.8264 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 81/150
# 88/88 [==============================] - 12s 126ms/step - loss: 0.1865 - accuracy: 0.8969 - iou_coef: 0.6826 - dice_coef: 0.8103 - f1_score: 0.8119 - aggregated_jaccard_index: 0.6882 - val_val_loss: 0.1772 - val_val_accuracy: 0.9383 - val_val_iou_coef: 0.7008 - val_val_dice_coef: 0.8241 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7016 - lr: 1.0000e-05
# Epoch 82/150
# 88/88 [==============================] - 15s 156ms/step - loss: 0.1854 - accuracy: 0.8976 - iou_coef: 0.6839 - dice_coef: 0.8113 - f1_score: 0.8129 - aggregated_jaccard_index: 0.6901 - val_val_loss: 0.1758 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7028 - val_val_dice_coef: 0.8255 - val_val_f1_score: 0.8267 - val_val_aggregated_jaccard_index: 0.7037 - lr: 1.0000e-05
# Epoch 83/150
# 88/88 [==============================] - 11s 113ms/step - loss: 0.1852 - accuracy: 0.8977 - iou_coef: 0.6840 - dice_coef: 0.8114 - f1_score: 0.8129 - aggregated_jaccard_index: 0.6901 - val_val_loss: 0.1760 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7025 - val_val_dice_coef: 0.8252 - val_val_f1_score: 0.8264 - val_val_aggregated_jaccard_index: 0.7033 - lr: 1.0000e-05
# Epoch 84/150
# 88/88 [==============================] - 12s 123ms/step - loss: 0.1864 - accuracy: 0.8971 - iou_coef: 0.6822 - dice_coef: 0.8101 - f1_score: 0.8117 - aggregated_jaccard_index: 0.6881 - val_val_loss: 0.1760 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7022 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8262 - val_val_aggregated_jaccard_index: 0.7030 - lr: 1.0000e-05
# Epoch 85/150
# 88/88 [==============================] - 16s 164ms/step - loss: 0.1844 - accuracy: 0.8979 - iou_coef: 0.6845 - dice_coef: 0.8117 - f1_score: 0.8133 - aggregated_jaccard_index: 0.6912 - val_val_loss: 0.1754 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7029 - val_val_dice_coef: 0.8255 - val_val_f1_score: 0.8266 - val_val_aggregated_jaccard_index: 0.7038 - lr: 1.0000e-05
# Epoch 86/150
# 88/88 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.8978 - iou_coef: 0.6847 - dice_coef: 0.8118 - f1_score: 0.8134 - aggregated_jaccard_index: 0.6906
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1e-05.
# 88/88 [==============================] - 12s 124ms/step - loss: 0.1843 - accuracy: 0.8978 - iou_coef: 0.6847 - dice_coef: 0.8118 - f1_score: 0.8134 - aggregated_jaccard_index: 0.6906 - val_val_loss: 0.1758 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7022 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8259 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 87/150
# 88/88 [==============================] - 15s 162ms/step - loss: 0.1848 - accuracy: 0.8973 - iou_coef: 0.6838 - dice_coef: 0.8112 - f1_score: 0.8128 - aggregated_jaccard_index: 0.6894 - val_val_loss: 0.1757 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.7022 - val_val_dice_coef: 0.8251 - val_val_f1_score: 0.8262 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 88/150
# 88/88 [==============================] - 12s 126ms/step - loss: 0.1842 - accuracy: 0.8976 - iou_coef: 0.6844 - dice_coef: 0.8116 - f1_score: 0.8133 - aggregated_jaccard_index: 0.6909 - val_val_loss: 0.1758 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.7018 - val_val_dice_coef: 0.8248 - val_val_f1_score: 0.8259 - val_val_aggregated_jaccard_index: 0.7027 - lr: 1.0000e-05
# Epoch 89/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.1845 - accuracy: 0.8979 - iou_coef: 0.6847 - dice_coef: 0.8119 - f1_score: 0.8134 - aggregated_jaccard_index: 0.6906 - val_val_loss: 0.1759 - val_val_accuracy: 0.9387 - val_val_iou_coef: 0.7017 - val_val_dice_coef: 0.8247 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.7024 - lr: 1.0000e-05
# Epoch 90/150
# 88/88 [==============================] - 15s 161ms/step - loss: 0.1854 - accuracy: 0.8968 - iou_coef: 0.6825 - dice_coef: 0.8103 - f1_score: 0.8118 - aggregated_jaccard_index: 0.6875 - val_val_loss: 0.1753 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.7021 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.7032 - lr: 1.0000e-05
# Epoch 91/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.1838 - accuracy: 0.8976 - iou_coef: 0.6845 - dice_coef: 0.8117 - f1_score: 0.8133 - aggregated_jaccard_index: 0.6907 - val_val_loss: 0.1748 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.7028 - val_val_dice_coef: 0.8255 - val_val_f1_score: 0.8265 - val_val_aggregated_jaccard_index: 0.7038 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# =========================================================
# CONFIG
# =========================================================

IMG_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/images"
MSK_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/masks"

img_size   = 256
batch_size = 13

AUTOTUNE = tf.data.AUTOTUNE

# =========================================================
# SAFE FILE COLLECTION
# =========================================================
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted([
    p for p in glob(os.path.join(IMG_DIR, "*"))
    if valid_name(p)
])

mask_paths = sorted([
    p for p in glob(os.path.join(MSK_DIR, "*"))
    if valid_name(p)
])

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# =========================================================
# SAFETY CHECK
# =========================================================
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == \
       [stem(p) for p in mask_paths], \
       "Image-mask filename mismatch"

# =========================================================
# NUMPY LOADER
# =========================================================
def _load_numpy(img_path, mask_path):

    img_path  = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    # ── IMAGE ─────────────────────────────────────────────
    img = Image.open(img_path).convert("RGB")
    img = img.resize((img_size, img_size), Image.BILINEAR)
    img = np.array(img, dtype=np.float32) / 255.0

    # ── MASK ──────────────────────────────────────────────
    mask = Image.open(mask_path).convert("L")
    mask = mask.resize((img_size, img_size), Image.NEAREST)
    mask = np.array(mask, dtype=np.float32)

    # Binary mask
    mask = (mask > 127).astype(np.float32)

    # Add channel dim → [H, W, 1]
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

# =========================================================
# TF WRAPPER
#
# SnakeUNet has ONE output: "segmentation"
# Return (img, mask) directly — no dict, no dummy tensors.
# =========================================================
def load_image_mask(img_path, mask_path):

    img, mask = tf.py_function(
        _load_numpy,
        [img_path, mask_path],
        [tf.float32, tf.float32],
    )

    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])

    # Single-output model → target is just the mask
    return img, mask

# =========================================================
# DATASET
# =========================================================
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

# =========================================================
# DEBUG
# =========================================================
print(
    "Test batches:",
    tf.data.experimental.cardinality(test_dataset).numpy()
)

# =========================================================
# SANITY CHECK
# =========================================================
for batch_images, batch_masks in test_dataset.take(1):
    print("\nImages shape :", batch_images.shape)   # (4, 256, 256, 3)
    print("Masks shape  :", batch_masks.shape)      # (4, 256, 256, 1)
# Out:
# Images found: 14
# Masks found : 14
# Test batches: 2
#
# Images shape : (13, 256, 256, 3)
# Masks shape  : (13, 256, 256, 1)

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.7027
# Mean Dice Coefficient: 0.8240
# Mean AJI:              0.7025
# Mean Accuracy:         0.9215
# Mean F1 Score:         0.8237
