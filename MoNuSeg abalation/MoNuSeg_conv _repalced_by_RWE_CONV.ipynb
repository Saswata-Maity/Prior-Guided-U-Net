# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-24 04:58:04.244845: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-24 04:58:04.271030: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-24 04:58:04.271104: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-24 04:58:04.272771: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-24 04:58:04.288455: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-24 04:58:05.329231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-24 04:58:07.642100: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:07.834846: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:07.834881: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = layers.MaxPooling2D(pool_size=2)(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = layers.MaxPooling2D(pool_size=2)(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = layers.MaxPooling2D(pool_size=2)(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = layers.MaxPooling2D(pool_size=2)(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-24 04:58:07.902369: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:07.902429: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:07.902443: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:08.132250: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:08.132290: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:08.132296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-24 04:58:08.132307: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-24 04:58:08.132318: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-24 04:58:08.132336: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)         0         ['activation[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['max_pooling2d[0][0]']
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['activation_1[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['max_pooling2d_1[0][0]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 128)          0         ['activation_2[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['max_pooling2d_2[0][0]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 16, 16, 256)          0         ['activation_3[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['max_pooling2d_3[0][0]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['activation_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 32, 32, 256)          0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 64, 64, 128)          0         ['activation_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_1[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_2[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['activation[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 1)          33        ['add_3[0][0]']
#
# ==================================================================================================
# Total params: 2832618 (10.81 MB)
# Trainable params: 2829930 (10.80 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../MONUSEG_DATA/aug_tune/images/*.png"))
train_mask_paths = sorted(glob("../MONUSEG_DATA/aug_tune/masks/*.png"))
val_img_paths   = sorted(glob("../MONUSEG_DATA/val/images/*.png"))
val_mask_paths  = sorted(glob("../MONUSEG_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# --- Loader ---
def load_image_mask(img_path, mask_path):
    img = np.array(Image.open(img_path.numpy().decode("utf-8")).convert("RGB").resize((img_size, img_size))) / 255.0
    mask = np.array(Image.open(mask_path.numpy().decode("utf-8")).convert("L").resize((img_size, img_size)))
    mask = (mask > 127).astype(np.float32)[..., None]  # binarize mask
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(load_image_mask, [img_path, mask_path], [tf.float32, tf.float32])
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# --- Build train & validation datasets ---
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", len(list(train_dataset)))
print("Validation batches:", len(list(val_dataset)))
# Out:
# Train images: 350
# Train masks: 350
# Val images: 2
# Val masks: 2
# 2026-09-24 04:58:08.729582: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 88
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-24 04:58:13.170185: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-24 04:58:14.843782: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-24 04:58:14.974377: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-24 04:58:17.339078: I external/local_xla/xla/service/service.cc:168] XLA service 0x7a55e62d6a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-24 04:58:17.339114: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-24 04:58:17.345173: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1790225897.400800   10433 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 [==============================] - ETA: 0s - loss: 3.4293 - accuracy: 0.7540 - iou_coef: 0.4694 - dice_coef: 0.6321 - f1_score: 0.6505 - aggregated_jaccard_index: 0.4851
# ✅ Saved improved backbone at epoch 1 with val_iou=0.3678
# 88/88 [==============================] - 20s 106ms/step - loss: 3.4208 - accuracy: 0.7540 - iou_coef: 0.4694 - dice_coef: 0.6321 - f1_score: 0.6505 - aggregated_jaccard_index: 0.4851 - val_val_loss: 4.1637 - val_val_accuracy: 0.8054 - val_val_iou_coef: 0.3678 - val_val_dice_coef: 0.5339 - val_val_f1_score: 0.6034 - val_val_aggregated_jaccard_index: 0.3866 - lr: 0.0010
# Epoch 2/150
# 88/88 [==============================] - ETA: 0s - loss: 2.8721 - accuracy: 0.8162 - iou_coef: 0.5378 - dice_coef: 0.6953 - f1_score: 0.7092 - aggregated_jaccard_index: 0.5525
# ✅ Saved improved backbone at epoch 2 with val_iou=0.5774
# 88/88 [==============================] - 11s 107ms/step - loss: 2.8686 - accuracy: 0.8162 - iou_coef: 0.5378 - dice_coef: 0.6953 - f1_score: 0.7092 - aggregated_jaccard_index: 0.5525 - val_val_loss: 2.6484 - val_val_accuracy: 0.9181 - val_val_iou_coef: 0.5774 - val_val_dice_coef: 0.7316 - val_val_f1_score: 0.7577 - val_val_aggregated_jaccard_index: 0.5693 - lr: 0.0010
# Epoch 3/150
# 88/88 [==============================] - 7s 71ms/step - loss: 2.6299 - accuracy: 0.8386 - iou_coef: 0.5659 - dice_coef: 0.7195 - f1_score: 0.7306 - aggregated_jaccard_index: 0.5774 - val_val_loss: 2.7565 - val_val_accuracy: 0.9037 - val_val_iou_coef: 0.5488 - val_val_dice_coef: 0.7086 - val_val_f1_score: 0.7178 - val_val_aggregated_jaccard_index: 0.5463 - lr: 0.0010
# Epoch 4/150
# 88/88 [==============================] - 7s 71ms/step - loss: 2.4671 - accuracy: 0.8512 - iou_coef: 0.5812 - dice_coef: 0.7322 - f1_score: 0.7414 - aggregated_jaccard_index: 0.5924 - val_val_loss: 2.5601 - val_val_accuracy: 0.9091 - val_val_iou_coef: 0.5709 - val_val_dice_coef: 0.7268 - val_val_f1_score: 0.7334 - val_val_aggregated_jaccard_index: 0.5682 - lr: 0.0010
# Epoch 5/150
# 88/88 [==============================] - 7s 71ms/step - loss: 2.3676 - accuracy: 0.8564 - iou_coef: 0.5912 - dice_coef: 0.7402 - f1_score: 0.7478 - aggregated_jaccard_index: 0.6000 - val_val_loss: 2.5246 - val_val_accuracy: 0.8936 - val_val_iou_coef: 0.5610 - val_val_dice_coef: 0.7174 - val_val_f1_score: 0.7288 - val_val_aggregated_jaccard_index: 0.5748 - lr: 0.0010
# Epoch 6/150
# 88/88 [==============================] - 10s 105ms/step - loss: 2.2649 - accuracy: 0.8602 - iou_coef: 0.5986 - dice_coef: 0.7464 - f1_score: 0.7532 - aggregated_jaccard_index: 0.6078 - val_val_loss: 2.4815 - val_val_accuracy: 0.8883 - val_val_iou_coef: 0.5603 - val_val_dice_coef: 0.7178 - val_val_f1_score: 0.7269 - val_val_aggregated_jaccard_index: 0.5676 - lr: 0.0010
# Epoch 7/150
# 88/88 [==============================] - 7s 72ms/step - loss: 2.2036 - accuracy: 0.8636 - iou_coef: 0.6011 - dice_coef: 0.7484 - f1_score: 0.7546 - aggregated_jaccard_index: 0.6114 - val_val_loss: 2.3938 - val_val_accuracy: 0.8903 - val_val_iou_coef: 0.5639 - val_val_dice_coef: 0.7194 - val_val_f1_score: 0.7263 - val_val_aggregated_jaccard_index: 0.5795 - lr: 0.0010
# Epoch 8/150
# 88/88 [==============================] - ETA: 0s - loss: 2.1287 - accuracy: 0.8643 - iou_coef: 0.6058 - dice_coef: 0.7522 - f1_score: 0.7576 - aggregated_jaccard_index: 0.6150
# ✅ Saved improved backbone at epoch 8 with val_iou=0.6119
# 88/88 [==============================] - 7s 71ms/step - loss: 2.1270 - accuracy: 0.8643 - iou_coef: 0.6058 - dice_coef: 0.7522 - f1_score: 0.7576 - aggregated_jaccard_index: 0.6150 - val_val_loss: 2.1616 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.6119 - val_val_dice_coef: 0.7576 - val_val_f1_score: 0.7621 - val_val_aggregated_jaccard_index: 0.5963 - lr: 0.0010
# Epoch 9/150
# 88/88 [==============================] - ETA: 0s - loss: 2.0484 - accuracy: 0.8679 - iou_coef: 0.6106 - dice_coef: 0.7557 - f1_score: 0.7607 - aggregated_jaccard_index: 0.6204
# ✅ Saved improved backbone at epoch 9 with val_iou=0.6521
# 88/88 [==============================] - 7s 72ms/step - loss: 2.0494 - accuracy: 0.8679 - iou_coef: 0.6106 - dice_coef: 0.7557 - f1_score: 0.7607 - aggregated_jaccard_index: 0.6204 - val_val_loss: 1.8176 - val_val_accuracy: 0.9255 - val_val_iou_coef: 0.6521 - val_val_dice_coef: 0.7894 - val_val_f1_score: 0.7932 - val_val_aggregated_jaccard_index: 0.6551 - lr: 0.0010
# Epoch 10/150
# 88/88 [==============================] - 8s 82ms/step - loss: 1.9787 - accuracy: 0.8690 - iou_coef: 0.6149 - dice_coef: 0.7591 - f1_score: 0.7637 - aggregated_jaccard_index: 0.6246 - val_val_loss: 1.8291 - val_val_accuracy: 0.9209 - val_val_iou_coef: 0.6408 - val_val_dice_coef: 0.7809 - val_val_f1_score: 0.7843 - val_val_aggregated_jaccard_index: 0.6462 - lr: 0.0010
# Epoch 11/150
# 88/88 [==============================] - ETA: 0s - loss: 1.9249 - accuracy: 0.8700 - iou_coef: 0.6175 - dice_coef: 0.7614 - f1_score: 0.7657 - aggregated_jaccard_index: 0.6266
# ✅ Saved improved backbone at epoch 11 with val_iou=0.6541
# 88/88 [==============================] - 12s 87ms/step - loss: 1.9226 - accuracy: 0.8700 - iou_coef: 0.6175 - dice_coef: 0.7614 - f1_score: 0.7657 - aggregated_jaccard_index: 0.6266 - val_val_loss: 1.7284 - val_val_accuracy: 0.9295 - val_val_iou_coef: 0.6541 - val_val_dice_coef: 0.7908 - val_val_f1_score: 0.7954 - val_val_aggregated_jaccard_index: 0.6564 - lr: 0.0010
# Epoch 12/150
# 88/88 [==============================] - 9s 84ms/step - loss: 1.8563 - accuracy: 0.8716 - iou_coef: 0.6208 - dice_coef: 0.7640 - f1_score: 0.7679 - aggregated_jaccard_index: 0.6312 - val_val_loss: 2.2324 - val_val_accuracy: 0.8782 - val_val_iou_coef: 0.5445 - val_val_dice_coef: 0.7033 - val_val_f1_score: 0.7089 - val_val_aggregated_jaccard_index: 0.5597 - lr: 0.0010
# Epoch 13/150
# 88/88 [==============================] - 9s 86ms/step - loss: 1.8244 - accuracy: 0.8709 - iou_coef: 0.6197 - dice_coef: 0.7629 - f1_score: 0.7668 - aggregated_jaccard_index: 0.6285 - val_val_loss: 1.7898 - val_val_accuracy: 0.9210 - val_val_iou_coef: 0.6259 - val_val_dice_coef: 0.7698 - val_val_f1_score: 0.7740 - val_val_aggregated_jaccard_index: 0.6284 - lr: 0.0010
# Epoch 14/150
# 88/88 [==============================] - 12s 121ms/step - loss: 1.7549 - accuracy: 0.8735 - iou_coef: 0.6239 - dice_coef: 0.7662 - f1_score: 0.7700 - aggregated_jaccard_index: 0.6329 - val_val_loss: 1.7208 - val_val_accuracy: 0.9150 - val_val_iou_coef: 0.6262 - val_val_dice_coef: 0.7696 - val_val_f1_score: 0.7736 - val_val_aggregated_jaccard_index: 0.6351 - lr: 0.0010
# Epoch 15/150
# 88/88 [==============================] - 9s 86ms/step - loss: 1.6986 - accuracy: 0.8745 - iou_coef: 0.6267 - dice_coef: 0.7684 - f1_score: 0.7720 - aggregated_jaccard_index: 0.6355 - val_val_loss: 1.7017 - val_val_accuracy: 0.9112 - val_val_iou_coef: 0.6202 - val_val_dice_coef: 0.7649 - val_val_f1_score: 0.7680 - val_val_aggregated_jaccard_index: 0.6304 - lr: 0.0010
# Epoch 16/150
# 88/88 [==============================] - 9s 85ms/step - loss: 1.6549 - accuracy: 0.8743 - iou_coef: 0.6267 - dice_coef: 0.7682 - f1_score: 0.7716 - aggregated_jaccard_index: 0.6368 - val_val_loss: 1.5524 - val_val_accuracy: 0.9270 - val_val_iou_coef: 0.6477 - val_val_dice_coef: 0.7861 - val_val_f1_score: 0.7893 - val_val_aggregated_jaccard_index: 0.6505 - lr: 0.0010
# Epoch 17/150
# 88/88 [==============================] - 9s 86ms/step - loss: 1.6066 - accuracy: 0.8752 - iou_coef: 0.6282 - dice_coef: 0.7695 - f1_score: 0.7728 - aggregated_jaccard_index: 0.6373 - val_val_loss: 1.4852 - val_val_accuracy: 0.9264 - val_val_iou_coef: 0.6520 - val_val_dice_coef: 0.7892 - val_val_f1_score: 0.7916 - val_val_aggregated_jaccard_index: 0.6569 - lr: 0.0010
# Epoch 18/150
# 88/88 [==============================] - 12s 121ms/step - loss: 1.5270 - accuracy: 0.8778 - iou_coef: 0.6350 - dice_coef: 0.7749 - f1_score: 0.7782 - aggregated_jaccard_index: 0.6435 - val_val_loss: 1.6325 - val_val_accuracy: 0.9042 - val_val_iou_coef: 0.6078 - val_val_dice_coef: 0.7557 - val_val_f1_score: 0.7586 - val_val_aggregated_jaccard_index: 0.6145 - lr: 0.0010
# Epoch 19/150
# 88/88 [==============================] - 9s 87ms/step - loss: 1.4906 - accuracy: 0.8777 - iou_coef: 0.6344 - dice_coef: 0.7743 - f1_score: 0.7774 - aggregated_jaccard_index: 0.6433 - val_val_loss: 1.3981 - val_val_accuracy: 0.9231 - val_val_iou_coef: 0.6509 - val_val_dice_coef: 0.7880 - val_val_f1_score: 0.7901 - val_val_aggregated_jaccard_index: 0.6597 - lr: 0.0010
# Epoch 20/150
# 88/88 [==============================] - 9s 87ms/step - loss: 1.4490 - accuracy: 0.8777 - iou_coef: 0.6351 - dice_coef: 0.7750 - f1_score: 0.7781 - aggregated_jaccard_index: 0.6430 - val_val_loss: 1.4337 - val_val_accuracy: 0.9164 - val_val_iou_coef: 0.6327 - val_val_dice_coef: 0.7744 - val_val_f1_score: 0.7776 - val_val_aggregated_jaccard_index: 0.6420 - lr: 0.0010
# Epoch 21/150
# 88/88 [==============================] - ETA: 0s - loss: 1.3964 - accuracy: 0.8784 - iou_coef: 0.6379 - dice_coef: 0.7772 - f1_score: 0.7801 - aggregated_jaccard_index: 0.6462
# ✅ Saved improved backbone at epoch 21 with val_iou=0.6562
# 88/88 [==============================] - 12s 122ms/step - loss: 1.3943 - accuracy: 0.8784 - iou_coef: 0.6379 - dice_coef: 0.7772 - f1_score: 0.7801 - aggregated_jaccard_index: 0.6462 - val_val_loss: 1.3066 - val_val_accuracy: 0.9274 - val_val_iou_coef: 0.6562 - val_val_dice_coef: 0.7921 - val_val_f1_score: 0.7949 - val_val_aggregated_jaccard_index: 0.6626 - lr: 0.0010
# Epoch 22/150
# 88/88 [==============================] - 9s 87ms/step - loss: 1.3342 - accuracy: 0.8806 - iou_coef: 0.6422 - dice_coef: 0.7804 - f1_score: 0.7833 - aggregated_jaccard_index: 0.6515 - val_val_loss: 1.3330 - val_val_accuracy: 0.9197 - val_val_iou_coef: 0.6375 - val_val_dice_coef: 0.7779 - val_val_f1_score: 0.7818 - val_val_aggregated_jaccard_index: 0.6483 - lr: 0.0010
# Epoch 23/150
# 88/88 [==============================] - ETA: 0s - loss: 1.3064 - accuracy: 0.8798 - iou_coef: 0.6405 - dice_coef: 0.7791 - f1_score: 0.7819 - aggregated_jaccard_index: 0.6488
# ✅ Saved improved backbone at epoch 23 with val_iou=0.6624
# 88/88 [==============================] - 9s 87ms/step - loss: 1.3039 - accuracy: 0.8798 - iou_coef: 0.6405 - dice_coef: 0.7791 - f1_score: 0.7819 - aggregated_jaccard_index: 0.6488 - val_val_loss: 1.2040 - val_val_accuracy: 0.9288 - val_val_iou_coef: 0.6624 - val_val_dice_coef: 0.7965 - val_val_f1_score: 0.7989 - val_val_aggregated_jaccard_index: 0.6705 - lr: 0.0010
# Epoch 24/150
# 88/88 [==============================] - ETA: 0s - loss: 1.2489 - accuracy: 0.8818 - iou_coef: 0.6453 - dice_coef: 0.7828 - f1_score: 0.7856 - aggregated_jaccard_index: 0.6540
# ✅ Saved improved backbone at epoch 24 with val_iou=0.6758
# 88/88 [==============================] - 8s 76ms/step - loss: 1.2481 - accuracy: 0.8818 - iou_coef: 0.6453 - dice_coef: 0.7828 - f1_score: 0.7856 - aggregated_jaccard_index: 0.6540 - val_val_loss: 1.1250 - val_val_accuracy: 0.9315 - val_val_iou_coef: 0.6758 - val_val_dice_coef: 0.8065 - val_val_f1_score: 0.8091 - val_val_aggregated_jaccard_index: 0.6800 - lr: 0.0010
# Epoch 25/150
# 88/88 [==============================] - ETA: 0s - loss: 1.2297 - accuracy: 0.8806 - iou_coef: 0.6411 - dice_coef: 0.7794 - f1_score: 0.7822 - aggregated_jaccard_index: 0.6487
# ✅ Saved improved backbone at epoch 25 with val_iou=0.6956
# 88/88 [==============================] - 11s 106ms/step - loss: 1.2295 - accuracy: 0.8806 - iou_coef: 0.6411 - dice_coef: 0.7794 - f1_score: 0.7822 - aggregated_jaccard_index: 0.6487 - val_val_loss: 1.0251 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.6956 - val_val_dice_coef: 0.8205 - val_val_f1_score: 0.8239 - val_val_aggregated_jaccard_index: 0.6980 - lr: 0.0010
# Epoch 26/150
# 88/88 [==============================] - 7s 71ms/step - loss: 1.1678 - accuracy: 0.8822 - iou_coef: 0.6460 - dice_coef: 0.7830 - f1_score: 0.7856 - aggregated_jaccard_index: 0.6545 - val_val_loss: 1.1824 - val_val_accuracy: 0.9164 - val_val_iou_coef: 0.6392 - val_val_dice_coef: 0.7798 - val_val_f1_score: 0.7815 - val_val_aggregated_jaccard_index: 0.6435 - lr: 0.0010
# Epoch 27/150
# 88/88 [==============================] - 8s 73ms/step - loss: 1.1322 - accuracy: 0.8828 - iou_coef: 0.6465 - dice_coef: 0.7836 - f1_score: 0.7862 - aggregated_jaccard_index: 0.6550 - val_val_loss: 1.0237 - val_val_accuracy: 0.9305 - val_val_iou_coef: 0.6750 - val_val_dice_coef: 0.8058 - val_val_f1_score: 0.8079 - val_val_aggregated_jaccard_index: 0.6800 - lr: 0.0010
# Epoch 28/150
# 88/88 [==============================] - 9s 86ms/step - loss: 1.0792 - accuracy: 0.8843 - iou_coef: 0.6510 - dice_coef: 0.7870 - f1_score: 0.7895 - aggregated_jaccard_index: 0.6594 - val_val_loss: 1.1492 - val_val_accuracy: 0.9106 - val_val_iou_coef: 0.6284 - val_val_dice_coef: 0.7717 - val_val_f1_score: 0.7739 - val_val_aggregated_jaccard_index: 0.6305 - lr: 0.0010
# Epoch 29/150
# 88/88 [==============================] - 12s 119ms/step - loss: 1.0411 - accuracy: 0.8844 - iou_coef: 0.6523 - dice_coef: 0.7880 - f1_score: 0.7904 - aggregated_jaccard_index: 0.6609 - val_val_loss: 0.9668 - val_val_accuracy: 0.9290 - val_val_iou_coef: 0.6738 - val_val_dice_coef: 0.8050 - val_val_f1_score: 0.8074 - val_val_aggregated_jaccard_index: 0.6768 - lr: 0.0010
# Epoch 30/150
# 88/88 [==============================] - 9s 87ms/step - loss: 1.0076 - accuracy: 0.8855 - iou_coef: 0.6532 - dice_coef: 0.7888 - f1_score: 0.7913 - aggregated_jaccard_index: 0.6608 - val_val_loss: 1.2708 - val_val_accuracy: 0.8808 - val_val_iou_coef: 0.5683 - val_val_dice_coef: 0.7248 - val_val_f1_score: 0.7263 - val_val_aggregated_jaccard_index: 0.5672 - lr: 0.0010
# Epoch 31/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.9845 - accuracy: 0.8837 - iou_coef: 0.6495 - dice_coef: 0.7858 - f1_score: 0.7881 - aggregated_jaccard_index: 0.6572 - val_val_loss: 1.0171 - val_val_accuracy: 0.9136 - val_val_iou_coef: 0.6313 - val_val_dice_coef: 0.7736 - val_val_f1_score: 0.7755 - val_val_aggregated_jaccard_index: 0.6395 - lr: 0.0010
# Epoch 32/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.9353 - accuracy: 0.8859 - iou_coef: 0.6546 - dice_coef: 0.7898 - f1_score: 0.7921 - aggregated_jaccard_index: 0.6625 - val_val_loss: 0.8140 - val_val_accuracy: 0.9376 - val_val_iou_coef: 0.6929 - val_val_dice_coef: 0.8184 - val_val_f1_score: 0.8204 - val_val_aggregated_jaccard_index: 0.6984 - lr: 0.0010
# Epoch 33/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.9015 - accuracy: 0.8863 - iou_coef: 0.6559 - dice_coef: 0.7908 - f1_score: 0.7930 - aggregated_jaccard_index: 0.6630 - val_val_loss: 0.8255 - val_val_accuracy: 0.9330 - val_val_iou_coef: 0.6774 - val_val_dice_coef: 0.8074 - val_val_f1_score: 0.8091 - val_val_aggregated_jaccard_index: 0.6845 - lr: 0.0010
# Epoch 34/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.8658 - accuracy: 0.8868 - iou_coef: 0.6570 - dice_coef: 0.7916 - f1_score: 0.7939 - aggregated_jaccard_index: 0.6644 - val_val_loss: 0.7813 - val_val_accuracy: 0.9350 - val_val_iou_coef: 0.6838 - val_val_dice_coef: 0.8120 - val_val_f1_score: 0.8141 - val_val_aggregated_jaccard_index: 0.6897 - lr: 0.0010
# Epoch 35/150
# 88/88 [==============================] - ETA: 0s - loss: 0.8368 - accuracy: 0.8867 - iou_coef: 0.6559 - dice_coef: 0.7907 - f1_score: 0.7929 - aggregated_jaccard_index: 0.6632
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 88/88 [==============================] - 9s 85ms/step - loss: 0.8383 - accuracy: 0.8867 - iou_coef: 0.6559 - dice_coef: 0.7907 - f1_score: 0.7929 - aggregated_jaccard_index: 0.6632 - val_val_loss: 0.9829 - val_val_accuracy: 0.8957 - val_val_iou_coef: 0.5981 - val_val_dice_coef: 0.7485 - val_val_f1_score: 0.7503 - val_val_aggregated_jaccard_index: 0.5978 - lr: 0.0010
# Epoch 36/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.8111 - accuracy: 0.8877 - iou_coef: 0.6600 - dice_coef: 0.7939 - f1_score: 0.7961 - aggregated_jaccard_index: 0.6667 - val_val_loss: 0.7582 - val_val_accuracy: 0.9319 - val_val_iou_coef: 0.6818 - val_val_dice_coef: 0.8107 - val_val_f1_score: 0.8131 - val_val_aggregated_jaccard_index: 0.6852 - lr: 1.0000e-04
# Epoch 37/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.8016 - accuracy: 0.8895 - iou_coef: 0.6633 - dice_coef: 0.7963 - f1_score: 0.7986 - aggregated_jaccard_index: 0.6699 - val_val_loss: 0.7591 - val_val_accuracy: 0.9310 - val_val_iou_coef: 0.6806 - val_val_dice_coef: 0.8099 - val_val_f1_score: 0.8119 - val_val_aggregated_jaccard_index: 0.6837 - lr: 1.0000e-04
# Epoch 38/150
# 88/88 [==============================] - ETA: 0s - loss: 0.7948 - accuracy: 0.8895 - iou_coef: 0.6632 - dice_coef: 0.7963 - f1_score: 0.7985 - aggregated_jaccard_index: 0.6708
# ✅ Saved improved backbone at epoch 38 with val_iou=0.6956
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7944 - accuracy: 0.8895 - iou_coef: 0.6632 - dice_coef: 0.7963 - f1_score: 0.7985 - aggregated_jaccard_index: 0.6708 - val_val_loss: 0.7184 - val_val_accuracy: 0.9369 - val_val_iou_coef: 0.6956 - val_val_dice_coef: 0.8204 - val_val_f1_score: 0.8220 - val_val_aggregated_jaccard_index: 0.6990 - lr: 1.0000e-04
# Epoch 39/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7934 - accuracy: 0.8895 - iou_coef: 0.6631 - dice_coef: 0.7960 - f1_score: 0.7983 - aggregated_jaccard_index: 0.6700 - val_val_loss: 0.7161 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.6949 - val_val_dice_coef: 0.8199 - val_val_f1_score: 0.8215 - val_val_aggregated_jaccard_index: 0.6992 - lr: 1.0000e-04
# Epoch 40/150
# 88/88 [==============================] - 12s 119ms/step - loss: 0.7918 - accuracy: 0.8894 - iou_coef: 0.6624 - dice_coef: 0.7956 - f1_score: 0.7979 - aggregated_jaccard_index: 0.6695 - val_val_loss: 0.7841 - val_val_accuracy: 0.9255 - val_val_iou_coef: 0.6676 - val_val_dice_coef: 0.8006 - val_val_f1_score: 0.8020 - val_val_aggregated_jaccard_index: 0.6700 - lr: 1.0000e-04
# Epoch 41/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7826 - accuracy: 0.8901 - iou_coef: 0.6647 - dice_coef: 0.7974 - f1_score: 0.7996 - aggregated_jaccard_index: 0.6720 - val_val_loss: 0.7582 - val_val_accuracy: 0.9292 - val_val_iou_coef: 0.6764 - val_val_dice_coef: 0.8069 - val_val_f1_score: 0.8083 - val_val_aggregated_jaccard_index: 0.6793 - lr: 1.0000e-04
# Epoch 42/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7823 - accuracy: 0.8898 - iou_coef: 0.6645 - dice_coef: 0.7973 - f1_score: 0.7995 - aggregated_jaccard_index: 0.6702 - val_val_loss: 0.7708 - val_val_accuracy: 0.9268 - val_val_iou_coef: 0.6693 - val_val_dice_coef: 0.8018 - val_val_f1_score: 0.8034 - val_val_aggregated_jaccard_index: 0.6732 - lr: 1.0000e-04
# Epoch 43/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7739 - accuracy: 0.8906 - iou_coef: 0.6660 - dice_coef: 0.7983 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6732 - val_val_loss: 0.7277 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6852 - val_val_dice_coef: 0.8131 - val_val_f1_score: 0.8145 - val_val_aggregated_jaccard_index: 0.6898 - lr: 1.0000e-04
# Epoch 44/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.7708 - accuracy: 0.8907 - iou_coef: 0.6655 - dice_coef: 0.7979 - f1_score: 0.8001 - aggregated_jaccard_index: 0.6732 - val_val_loss: 0.7561 - val_val_accuracy: 0.9282 - val_val_iou_coef: 0.6732 - val_val_dice_coef: 0.8046 - val_val_f1_score: 0.8063 - val_val_aggregated_jaccard_index: 0.6766 - lr: 1.0000e-04
# Epoch 45/150
# 88/88 [==============================] - ETA: 0s - loss: 0.7678 - accuracy: 0.8907 - iou_coef: 0.6652 - dice_coef: 0.7977 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6732
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7693 - accuracy: 0.8907 - iou_coef: 0.6652 - dice_coef: 0.7977 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6732 - val_val_loss: 0.7398 - val_val_accuracy: 0.9302 - val_val_iou_coef: 0.6787 - val_val_dice_coef: 0.8085 - val_val_f1_score: 0.8103 - val_val_aggregated_jaccard_index: 0.6821 - lr: 1.0000e-04
# Epoch 46/150
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7651 - accuracy: 0.8901 - iou_coef: 0.6655 - dice_coef: 0.7979 - f1_score: 0.8001 - aggregated_jaccard_index: 0.6727 - val_val_loss: 0.7351 - val_val_accuracy: 0.9310 - val_val_iou_coef: 0.6805 - val_val_dice_coef: 0.8098 - val_val_f1_score: 0.8118 - val_val_aggregated_jaccard_index: 0.6839 - lr: 1.0000e-05
# Epoch 47/150
# 88/88 [==============================] - 9s 88ms/step - loss: 0.7615 - accuracy: 0.8908 - iou_coef: 0.6666 - dice_coef: 0.7987 - f1_score: 0.8009 - aggregated_jaccard_index: 0.6742 - val_val_loss: 0.7253 - val_val_accuracy: 0.9326 - val_val_iou_coef: 0.6841 - val_val_dice_coef: 0.8123 - val_val_f1_score: 0.8144 - val_val_aggregated_jaccard_index: 0.6879 - lr: 1.0000e-05
# Epoch 48/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.7721 - accuracy: 0.8897 - iou_coef: 0.6637 - dice_coef: 0.7965 - f1_score: 0.7987 - aggregated_jaccard_index: 0.6704 - val_val_loss: 0.7287 - val_val_accuracy: 0.9320 - val_val_iou_coef: 0.6826 - val_val_dice_coef: 0.8113 - val_val_f1_score: 0.8132 - val_val_aggregated_jaccard_index: 0.6864 - lr: 1.0000e-05
# Epoch 49/150
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7685 - accuracy: 0.8904 - iou_coef: 0.6651 - dice_coef: 0.7976 - f1_score: 0.7998 - aggregated_jaccard_index: 0.6715 - val_val_loss: 0.7327 - val_val_accuracy: 0.9313 - val_val_iou_coef: 0.6808 - val_val_dice_coef: 0.8100 - val_val_f1_score: 0.8119 - val_val_aggregated_jaccard_index: 0.6846 - lr: 1.0000e-05
# Epoch 50/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7696 - accuracy: 0.8904 - iou_coef: 0.6653 - dice_coef: 0.7979 - f1_score: 0.8000 - aggregated_jaccard_index: 0.6715 - val_val_loss: 0.7266 - val_val_accuracy: 0.9322 - val_val_iou_coef: 0.6829 - val_val_dice_coef: 0.8115 - val_val_f1_score: 0.8132 - val_val_aggregated_jaccard_index: 0.6871 - lr: 1.0000e-05
# Epoch 51/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.7695 - accuracy: 0.8899 - iou_coef: 0.6640 - dice_coef: 0.7968 - f1_score: 0.7990 - aggregated_jaccard_index: 0.6707 - val_val_loss: 0.7314 - val_val_accuracy: 0.9314 - val_val_iou_coef: 0.6810 - val_val_dice_coef: 0.8101 - val_val_f1_score: 0.8120 - val_val_aggregated_jaccard_index: 0.6849 - lr: 1.0000e-05
# Epoch 52/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7644 - accuracy: 0.8905 - iou_coef: 0.6655 - dice_coef: 0.7980 - f1_score: 0.8002 - aggregated_jaccard_index: 0.6723 - val_val_loss: 0.7215 - val_val_accuracy: 0.9329 - val_val_iou_coef: 0.6849 - val_val_dice_coef: 0.8129 - val_val_f1_score: 0.8147 - val_val_aggregated_jaccard_index: 0.6890 - lr: 1.0000e-05
# Epoch 53/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7638 - accuracy: 0.8904 - iou_coef: 0.6653 - dice_coef: 0.7978 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6728 - val_val_loss: 0.7201 - val_val_accuracy: 0.9330 - val_val_iou_coef: 0.6855 - val_val_dice_coef: 0.8133 - val_val_f1_score: 0.8150 - val_val_aggregated_jaccard_index: 0.6894 - lr: 1.0000e-05
# Epoch 54/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7647 - accuracy: 0.8905 - iou_coef: 0.6653 - dice_coef: 0.7978 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6727 - val_val_loss: 0.7242 - val_val_accuracy: 0.9323 - val_val_iou_coef: 0.6836 - val_val_dice_coef: 0.8120 - val_val_f1_score: 0.8136 - val_val_aggregated_jaccard_index: 0.6876 - lr: 1.0000e-05
# Epoch 55/150
# 88/88 [==============================] - ETA: 0s - loss: 0.7649 - accuracy: 0.8907 - iou_coef: 0.6655 - dice_coef: 0.7979 - f1_score: 0.8002 - aggregated_jaccard_index: 0.6721
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1e-05.
# 88/88 [==============================] - 12s 119ms/step - loss: 0.7658 - accuracy: 0.8907 - iou_coef: 0.6655 - dice_coef: 0.7979 - f1_score: 0.8002 - aggregated_jaccard_index: 0.6721 - val_val_loss: 0.7218 - val_val_accuracy: 0.9328 - val_val_iou_coef: 0.6845 - val_val_dice_coef: 0.8126 - val_val_f1_score: 0.8147 - val_val_aggregated_jaccard_index: 0.6884 - lr: 1.0000e-05
# Epoch 56/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7578 - accuracy: 0.8914 - iou_coef: 0.6671 - dice_coef: 0.7991 - f1_score: 0.8013 - aggregated_jaccard_index: 0.6752 - val_val_loss: 0.7287 - val_val_accuracy: 0.9315 - val_val_iou_coef: 0.6816 - val_val_dice_coef: 0.8106 - val_val_f1_score: 0.8124 - val_val_aggregated_jaccard_index: 0.6854 - lr: 1.0000e-05
# Epoch 57/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7672 - accuracy: 0.8901 - iou_coef: 0.6645 - dice_coef: 0.7972 - f1_score: 0.7993 - aggregated_jaccard_index: 0.6714 - val_val_loss: 0.7182 - val_val_accuracy: 0.9333 - val_val_iou_coef: 0.6856 - val_val_dice_coef: 0.8134 - val_val_f1_score: 0.8154 - val_val_aggregated_jaccard_index: 0.6897 - lr: 1.0000e-05
# Epoch 58/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7667 - accuracy: 0.8907 - iou_coef: 0.6653 - dice_coef: 0.7978 - f1_score: 0.8000 - aggregated_jaccard_index: 0.6721 - val_val_loss: 0.7261 - val_val_accuracy: 0.9319 - val_val_iou_coef: 0.6823 - val_val_dice_coef: 0.8111 - val_val_f1_score: 0.8129 - val_val_aggregated_jaccard_index: 0.6862 - lr: 1.0000e-05
# Epoch 59/150
# 88/88 [==============================] - 12s 122ms/step - loss: 0.7585 - accuracy: 0.8907 - iou_coef: 0.6665 - dice_coef: 0.7987 - f1_score: 0.8009 - aggregated_jaccard_index: 0.6733 - val_val_loss: 0.7243 - val_val_accuracy: 0.9323 - val_val_iou_coef: 0.6829 - val_val_dice_coef: 0.8115 - val_val_f1_score: 0.8137 - val_val_aggregated_jaccard_index: 0.6869 - lr: 1.0000e-05
# Epoch 60/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7589 - accuracy: 0.8909 - iou_coef: 0.6662 - dice_coef: 0.7985 - f1_score: 0.8007 - aggregated_jaccard_index: 0.6733 - val_val_loss: 0.7261 - val_val_accuracy: 0.9316 - val_val_iou_coef: 0.6820 - val_val_dice_coef: 0.8108 - val_val_f1_score: 0.8124 - val_val_aggregated_jaccard_index: 0.6860 - lr: 1.0000e-05
# Epoch 61/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7655 - accuracy: 0.8902 - iou_coef: 0.6646 - dice_coef: 0.7973 - f1_score: 0.7994 - aggregated_jaccard_index: 0.6715 - val_val_loss: 0.7161 - val_val_accuracy: 0.9333 - val_val_iou_coef: 0.6860 - val_val_dice_coef: 0.8137 - val_val_f1_score: 0.8155 - val_val_aggregated_jaccard_index: 0.6901 - lr: 1.0000e-05
# Epoch 62/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.7595 - accuracy: 0.8911 - iou_coef: 0.6666 - dice_coef: 0.7988 - f1_score: 0.8010 - aggregated_jaccard_index: 0.6737 - val_val_loss: 0.7197 - val_val_accuracy: 0.9328 - val_val_iou_coef: 0.6846 - val_val_dice_coef: 0.8127 - val_val_f1_score: 0.8148 - val_val_aggregated_jaccard_index: 0.6884 - lr: 1.0000e-05
# Epoch 63/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7593 - accuracy: 0.8907 - iou_coef: 0.6655 - dice_coef: 0.7980 - f1_score: 0.8001 - aggregated_jaccard_index: 0.6728 - val_val_loss: 0.7173 - val_val_accuracy: 0.9330 - val_val_iou_coef: 0.6852 - val_val_dice_coef: 0.8131 - val_val_f1_score: 0.8147 - val_val_aggregated_jaccard_index: 0.6894 - lr: 1.0000e-05
# Epoch 64/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7574 - accuracy: 0.8911 - iou_coef: 0.6669 - dice_coef: 0.7990 - f1_score: 0.8012 - aggregated_jaccard_index: 0.6743 - val_val_loss: 0.7183 - val_val_accuracy: 0.9328 - val_val_iou_coef: 0.6846 - val_val_dice_coef: 0.8127 - val_val_f1_score: 0.8145 - val_val_aggregated_jaccard_index: 0.6888 - lr: 1.0000e-05
# Epoch 65/150
# 88/88 [==============================] - 9s 86ms/step - loss: 0.7577 - accuracy: 0.8910 - iou_coef: 0.6662 - dice_coef: 0.7985 - f1_score: 0.8006 - aggregated_jaccard_index: 0.6738 - val_val_loss: 0.7204 - val_val_accuracy: 0.9326 - val_val_iou_coef: 0.6838 - val_val_dice_coef: 0.8121 - val_val_f1_score: 0.8145 - val_val_aggregated_jaccard_index: 0.6877 - lr: 1.0000e-05
# Epoch 66/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.7608 - accuracy: 0.8908 - iou_coef: 0.6659 - dice_coef: 0.7983 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6728 - val_val_loss: 0.7177 - val_val_accuracy: 0.9329 - val_val_iou_coef: 0.6848 - val_val_dice_coef: 0.8128 - val_val_f1_score: 0.8149 - val_val_aggregated_jaccard_index: 0.6887 - lr: 1.0000e-05
# Epoch 67/150
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7662 - accuracy: 0.8901 - iou_coef: 0.6641 - dice_coef: 0.7969 - f1_score: 0.7990 - aggregated_jaccard_index: 0.6710 - val_val_loss: 0.7145 - val_val_accuracy: 0.9332 - val_val_iou_coef: 0.6859 - val_val_dice_coef: 0.8136 - val_val_f1_score: 0.8154 - val_val_aggregated_jaccard_index: 0.6899 - lr: 1.0000e-05
# Epoch 68/150
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7674 - accuracy: 0.8899 - iou_coef: 0.6633 - dice_coef: 0.7963 - f1_score: 0.7985 - aggregated_jaccard_index: 0.6698 - val_val_loss: 0.7153 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6854 - val_val_dice_coef: 0.8133 - val_val_f1_score: 0.8151 - val_val_aggregated_jaccard_index: 0.6895 - lr: 1.0000e-05
# Epoch 69/150
# 88/88 [==============================] - 9s 87ms/step - loss: 0.7596 - accuracy: 0.8905 - iou_coef: 0.6654 - dice_coef: 0.7979 - f1_score: 0.8001 - aggregated_jaccard_index: 0.6725 - val_val_loss: 0.7124 - val_val_accuracy: 0.9335 - val_val_iou_coef: 0.6864 - val_val_dice_coef: 0.8139 - val_val_f1_score: 0.8157 - val_val_aggregated_jaccard_index: 0.6906 - lr: 1.0000e-05
# Epoch 70/150
# 88/88 [==============================] - 12s 89ms/step - loss: 0.7603 - accuracy: 0.8905 - iou_coef: 0.6652 - dice_coef: 0.7977 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6717 - val_val_loss: 0.7221 - val_val_accuracy: 0.9319 - val_val_iou_coef: 0.6825 - val_val_dice_coef: 0.8112 - val_val_f1_score: 0.8130 - val_val_aggregated_jaccard_index: 0.6863 - lr: 1.0000e-05
# Epoch 71/150
# 88/88 [==============================] - 8s 73ms/step - loss: 0.7609 - accuracy: 0.8908 - iou_coef: 0.6659 - dice_coef: 0.7983 - f1_score: 0.8004 - aggregated_jaccard_index: 0.6729 - val_val_loss: 0.7179 - val_val_accuracy: 0.9326 - val_val_iou_coef: 0.6840 - val_val_dice_coef: 0.8122 - val_val_f1_score: 0.8142 - val_val_aggregated_jaccard_index: 0.6880 - lr: 1.0000e-05
# Epoch 72/150
# 88/88 [==============================] - 9s 85ms/step - loss: 0.7622 - accuracy: 0.8909 - iou_coef: 0.6654 - dice_coef: 0.7978 - f1_score: 0.7999 - aggregated_jaccard_index: 0.6722 - val_val_loss: 0.7218 - val_val_accuracy: 0.9318 - val_val_iou_coef: 0.6823 - val_val_dice_coef: 0.8110 - val_val_f1_score: 0.8129 - val_val_aggregated_jaccard_index: 0.6862 - lr: 1.0000e-05
# Epoch 73/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.7577 - accuracy: 0.8908 - iou_coef: 0.6661 - dice_coef: 0.7983 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6725 - val_val_loss: 0.7184 - val_val_accuracy: 0.9324 - val_val_iou_coef: 0.6834 - val_val_dice_coef: 0.8118 - val_val_f1_score: 0.8139 - val_val_aggregated_jaccard_index: 0.6875 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# =========================================================
# CONFIG
# =========================================================

IMG_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/images"
MSK_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/masks"

img_size   = 256
batch_size = 4

AUTOTUNE = tf.data.AUTOTUNE

# =========================================================
# SAFE FILE COLLECTION
# =========================================================
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted([
    p for p in glob(os.path.join(IMG_DIR, "*"))
    if valid_name(p)
])

mask_paths = sorted([
    p for p in glob(os.path.join(MSK_DIR, "*"))
    if valid_name(p)
])

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# =========================================================
# SAFETY CHECK
# =========================================================
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == \
       [stem(p) for p in mask_paths], \
       "Image-mask filename mismatch"

# =========================================================
# NUMPY LOADER
# =========================================================
def _load_numpy(img_path, mask_path):

    img_path  = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    # ── IMAGE ─────────────────────────────────────────────
    img = Image.open(img_path).convert("RGB")
    img = img.resize((img_size, img_size), Image.BILINEAR)
    img = np.array(img, dtype=np.float32) / 255.0

    # ── MASK ──────────────────────────────────────────────
    mask = Image.open(mask_path).convert("L")
    mask = mask.resize((img_size, img_size), Image.NEAREST)
    mask = np.array(mask, dtype=np.float32)

    # Binary mask
    mask = (mask > 127).astype(np.float32)

    # Add channel dim → [H, W, 1]
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

# =========================================================
# TF WRAPPER
#
# SnakeUNet has ONE output: "segmentation"
# Return (img, mask) directly — no dict, no dummy tensors.
# =========================================================
def load_image_mask(img_path, mask_path):

    img, mask = tf.py_function(
        _load_numpy,
        [img_path, mask_path],
        [tf.float32, tf.float32],
    )

    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])

    # Single-output model → target is just the mask
    return img, mask

# =========================================================
# DATASET
# =========================================================
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)
# =========================================================
# SANITY CHECK
# =========================================================
for batch_images, batch_masks in test_dataset.take(1):
    print("\nImages shape :", batch_images.shape)   # (4, 256, 256, 3)
    print("Masks shape  :", batch_masks.shape)      # (4, 256, 256, 1)
# Out:
# Images found: 14
# Masks found : 14
#
# Images shape : (4, 256, 256, 3)
# Masks shape  : (4, 256, 256, 1)

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.6499
# Mean Dice Coefficient: 0.7859
# Mean AJI:              0.6577
# Mean Accuracy:         0.8986
# Mean F1 Score:         0.7897
