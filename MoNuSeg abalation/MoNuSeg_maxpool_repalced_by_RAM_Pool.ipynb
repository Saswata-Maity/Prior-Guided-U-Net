# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 17:18:13.019148: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 17:18:13.051067: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 17:18:13.051116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 17:18:13.054052: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 17:18:13.063828: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 17:18:13.624127: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 17:18:14.498197: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.548651: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.548684: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = GeodesicDownsample2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = GeodesicDownsample2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = GeodesicDownsample2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = GeodesicDownsample2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 17:18:14.597187: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.597247: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.597263: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.873181: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.873220: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.873227: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 17:18:14.873237: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 17:18:14.873248: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 17:18:14.873268: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  geodesic_downsample2d (Geo  (None, 128, 128, 32)         32        ['activation[0][0]']
#  desicDownsample2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['geodesic_downsample2d[0][0]'
#                                                                     ]
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_1 (G  (None, 64, 64, 64)           64        ['activation_1[0][0]']
#  eodesicDownsample2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['geodesic_downsample2d_1[0][0
#                                                                     ]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_2 (G  (None, 32, 32, 128)          128       ['activation_2[0][0]']
#  eodesicDownsample2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['geodesic_downsample2d_2[0][0
#                                                                     ]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_3 (G  (None, 16, 16, 256)          256       ['activation_3[0][0]']
#  eodesicDownsample2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['geodesic_downsample2d_3[0][0
#                                                                     ]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['activation_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 32, 32, 256)          0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 64, 64, 128)          0         ['activation_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_1[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_2[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['activation[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 1)          33        ['add_3[0][0]']
#
# ==================================================================================================
# Total params: 2833098 (10.81 MB)
# Trainable params: 2830410 (10.80 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../MONUSEG_DATA/aug_tune/images/*.png"))
train_mask_paths = sorted(glob("../MONUSEG_DATA/aug_tune/masks/*.png"))
val_img_paths   = sorted(glob("../MONUSEG_DATA/val/images/*.png"))
val_mask_paths  = sorted(glob("../MONUSEG_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# --- Loader ---
def load_image_mask(img_path, mask_path):
    img = np.array(Image.open(img_path.numpy().decode("utf-8")).convert("RGB").resize((img_size, img_size))) / 255.0
    mask = np.array(Image.open(mask_path.numpy().decode("utf-8")).convert("L").resize((img_size, img_size)))
    mask = (mask > 127).astype(np.float32)[..., None]  # binarize mask
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(load_image_mask, [img_path, mask_path], [tf.float32, tf.float32])
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# --- Build train & validation datasets ---
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", len(list(train_dataset)))
print("Validation batches:", len(list(val_dataset)))
# Out:
# Train images: 350
# Train masks: 350
# Val images: 2
# Val masks: 2
# 2026-09-20 17:18:15.614731: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 88
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-20 17:18:21.225566: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 17:18:23.426307: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 17:18:23.617441: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 17:18:26.071139: I external/local_xla/xla/service/service.cc:168] XLA service 0x75d29a1d4830 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 17:18:26.071199: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 17:18:26.083624: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789924706.141920   11846 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 88/88 [==============================] - ETA: 0s - loss: 3.4647 - accuracy: 0.7462 - iou_coef: 0.4641 - dice_coef: 0.6250 - f1_score: 0.6374 - aggregated_jaccard_index: 0.4819
# ✅ Saved improved backbone at epoch 1 with val_iou=0.3089
# 88/88 [==============================] - 27s 167ms/step - loss: 3.4559 - accuracy: 0.7462 - iou_coef: 0.4641 - dice_coef: 0.6250 - f1_score: 0.6374 - aggregated_jaccard_index: 0.4819 - val_val_loss: 4.6096 - val_val_accuracy: 0.7235 - val_val_iou_coef: 0.3089 - val_val_dice_coef: 0.4695 - val_val_f1_score: 0.5219 - val_val_aggregated_jaccard_index: 0.3227 - lr: 0.0010
# Epoch 2/150
# 88/88 [==============================] - ETA: 0s - loss: 2.8319 - accuracy: 0.8178 - iou_coef: 0.5444 - dice_coef: 0.7007 - f1_score: 0.7129 - aggregated_jaccard_index: 0.5598
# ✅ Saved improved backbone at epoch 2 with val_iou=0.4930
# 88/88 [==============================] - 10s 103ms/step - loss: 2.8287 - accuracy: 0.8178 - iou_coef: 0.5444 - dice_coef: 0.7007 - f1_score: 0.7129 - aggregated_jaccard_index: 0.5598 - val_val_loss: 3.1701 - val_val_accuracy: 0.8756 - val_val_iou_coef: 0.4930 - val_val_dice_coef: 0.6570 - val_val_f1_score: 0.6969 - val_val_aggregated_jaccard_index: 0.5130 - lr: 0.0010
# Epoch 3/150
# 88/88 [==============================] - ETA: 0s - loss: 2.5914 - accuracy: 0.8419 - iou_coef: 0.5727 - dice_coef: 0.7249 - f1_score: 0.7353 - aggregated_jaccard_index: 0.5846
# ✅ Saved improved backbone at epoch 3 with val_iou=0.5879
# 88/88 [==============================] - 10s 103ms/step - loss: 2.5918 - accuracy: 0.8419 - iou_coef: 0.5727 - dice_coef: 0.7249 - f1_score: 0.7353 - aggregated_jaccard_index: 0.5846 - val_val_loss: 2.4989 - val_val_accuracy: 0.9165 - val_val_iou_coef: 0.5879 - val_val_dice_coef: 0.7405 - val_val_f1_score: 0.7569 - val_val_aggregated_jaccard_index: 0.5875 - lr: 0.0010
# Epoch 4/150
# 88/88 [==============================] - ETA: 0s - loss: 2.4263 - accuracy: 0.8549 - iou_coef: 0.5877 - dice_coef: 0.7375 - f1_score: 0.7464 - aggregated_jaccard_index: 0.5996
# ✅ Saved improved backbone at epoch 4 with val_iou=0.6033
# 88/88 [==============================] - 14s 148ms/step - loss: 2.4263 - accuracy: 0.8549 - iou_coef: 0.5877 - dice_coef: 0.7375 - f1_score: 0.7464 - aggregated_jaccard_index: 0.5996 - val_val_loss: 2.3156 - val_val_accuracy: 0.9109 - val_val_iou_coef: 0.6033 - val_val_dice_coef: 0.7520 - val_val_f1_score: 0.7630 - val_val_aggregated_jaccard_index: 0.6124 - lr: 0.0010
# Epoch 5/150
# 88/88 [==============================] - 10s 102ms/step - loss: 2.3213 - accuracy: 0.8607 - iou_coef: 0.5988 - dice_coef: 0.7463 - f1_score: 0.7536 - aggregated_jaccard_index: 0.6083 - val_val_loss: 2.3236 - val_val_accuracy: 0.9084 - val_val_iou_coef: 0.5954 - val_val_dice_coef: 0.7459 - val_val_f1_score: 0.7543 - val_val_aggregated_jaccard_index: 0.6038 - lr: 0.0010
# Epoch 6/150
# 88/88 [==============================] - 10s 102ms/step - loss: 2.2325 - accuracy: 0.8638 - iou_coef: 0.6042 - dice_coef: 0.7509 - f1_score: 0.7574 - aggregated_jaccard_index: 0.6138 - val_val_loss: 2.2747 - val_val_accuracy: 0.9115 - val_val_iou_coef: 0.5971 - val_val_dice_coef: 0.7475 - val_val_f1_score: 0.7561 - val_val_aggregated_jaccard_index: 0.6031 - lr: 0.0010
# Epoch 7/150
# 88/88 [==============================] - ETA: 0s - loss: 2.1764 - accuracy: 0.8659 - iou_coef: 0.6059 - dice_coef: 0.7520 - f1_score: 0.7578 - aggregated_jaccard_index: 0.6160
# ✅ Saved improved backbone at epoch 7 with val_iou=0.6085
# 88/88 [==============================] - 14s 141ms/step - loss: 2.1788 - accuracy: 0.8659 - iou_coef: 0.6059 - dice_coef: 0.7520 - f1_score: 0.7578 - aggregated_jaccard_index: 0.6160 - val_val_loss: 2.1440 - val_val_accuracy: 0.9083 - val_val_iou_coef: 0.6085 - val_val_dice_coef: 0.7561 - val_val_f1_score: 0.7615 - val_val_aggregated_jaccard_index: 0.6163 - lr: 0.0010
# Epoch 8/150
# 88/88 [==============================] - ETA: 0s - loss: 2.0966 - accuracy: 0.8672 - iou_coef: 0.6124 - dice_coef: 0.7574 - f1_score: 0.7624 - aggregated_jaccard_index: 0.6212
# ✅ Saved improved backbone at epoch 8 with val_iou=0.6488
# 88/88 [==============================] - 11s 107ms/step - loss: 2.0954 - accuracy: 0.8672 - iou_coef: 0.6124 - dice_coef: 0.7574 - f1_score: 0.7624 - aggregated_jaccard_index: 0.6212 - val_val_loss: 1.9001 - val_val_accuracy: 0.9282 - val_val_iou_coef: 0.6488 - val_val_dice_coef: 0.7870 - val_val_f1_score: 0.7925 - val_val_aggregated_jaccard_index: 0.6477 - lr: 0.0010
# Epoch 9/150
# 88/88 [==============================] - 10s 103ms/step - loss: 2.0310 - accuracy: 0.8697 - iou_coef: 0.6151 - dice_coef: 0.7593 - f1_score: 0.7641 - aggregated_jaccard_index: 0.6245 - val_val_loss: 1.9600 - val_val_accuracy: 0.9158 - val_val_iou_coef: 0.6251 - val_val_dice_coef: 0.7690 - val_val_f1_score: 0.7741 - val_val_aggregated_jaccard_index: 0.6320 - lr: 0.0010
# Epoch 10/150
# 88/88 [==============================] - 13s 138ms/step - loss: 1.9619 - accuracy: 0.8709 - iou_coef: 0.6187 - dice_coef: 0.7621 - f1_score: 0.7664 - aggregated_jaccard_index: 0.6282 - val_val_loss: 1.8793 - val_val_accuracy: 0.9193 - val_val_iou_coef: 0.6332 - val_val_dice_coef: 0.7753 - val_val_f1_score: 0.7801 - val_val_aggregated_jaccard_index: 0.6376 - lr: 0.0010
# Epoch 11/150
# 88/88 [==============================] - 10s 102ms/step - loss: 1.9169 - accuracy: 0.8707 - iou_coef: 0.6193 - dice_coef: 0.7626 - f1_score: 0.7666 - aggregated_jaccard_index: 0.6284 - val_val_loss: 2.0558 - val_val_accuracy: 0.8981 - val_val_iou_coef: 0.5892 - val_val_dice_coef: 0.7410 - val_val_f1_score: 0.7452 - val_val_aggregated_jaccard_index: 0.5978 - lr: 0.0010
# Epoch 12/150
# 88/88 [==============================] - 10s 102ms/step - loss: 1.8475 - accuracy: 0.8724 - iou_coef: 0.6231 - dice_coef: 0.7657 - f1_score: 0.7695 - aggregated_jaccard_index: 0.6332 - val_val_loss: 2.1746 - val_val_accuracy: 0.8837 - val_val_iou_coef: 0.5570 - val_val_dice_coef: 0.7146 - val_val_f1_score: 0.7192 - val_val_aggregated_jaccard_index: 0.5680 - lr: 0.0010
# Epoch 13/150
# 88/88 [==============================] - ETA: 0s - loss: 1.8216 - accuracy: 0.8714 - iou_coef: 0.6215 - dice_coef: 0.7644 - f1_score: 0.7680 - aggregated_jaccard_index: 0.6296
# ✅ Saved improved backbone at epoch 13 with val_iou=0.6494
# 88/88 [==============================] - 10s 101ms/step - loss: 1.8207 - accuracy: 0.8714 - iou_coef: 0.6215 - dice_coef: 0.7644 - f1_score: 0.7680 - aggregated_jaccard_index: 0.6296 - val_val_loss: 1.6605 - val_val_accuracy: 0.9256 - val_val_iou_coef: 0.6494 - val_val_dice_coef: 0.7872 - val_val_f1_score: 0.7912 - val_val_aggregated_jaccard_index: 0.6553 - lr: 0.0010
# Epoch 14/150
# 88/88 [==============================] - ETA: 0s - loss: 1.7580 - accuracy: 0.8733 - iou_coef: 0.6239 - dice_coef: 0.7662 - f1_score: 0.7697 - aggregated_jaccard_index: 0.6330
# ✅ Saved improved backbone at epoch 14 with val_iou=0.6578
# 88/88 [==============================] - 14s 104ms/step - loss: 1.7586 - accuracy: 0.8733 - iou_coef: 0.6239 - dice_coef: 0.7662 - f1_score: 0.7697 - aggregated_jaccard_index: 0.6330 - val_val_loss: 1.5973 - val_val_accuracy: 0.9292 - val_val_iou_coef: 0.6578 - val_val_dice_coef: 0.7936 - val_val_f1_score: 0.7970 - val_val_aggregated_jaccard_index: 0.6578 - lr: 0.0010
# Epoch 15/150
# 88/88 [==============================] - 10s 103ms/step - loss: 1.7030 - accuracy: 0.8741 - iou_coef: 0.6263 - dice_coef: 0.7681 - f1_score: 0.7714 - aggregated_jaccard_index: 0.6351 - val_val_loss: 1.5774 - val_val_accuracy: 0.9239 - val_val_iou_coef: 0.6491 - val_val_dice_coef: 0.7870 - val_val_f1_score: 0.7899 - val_val_aggregated_jaccard_index: 0.6552 - lr: 0.0010
# Epoch 16/150
# 88/88 [==============================] - 10s 101ms/step - loss: 1.6604 - accuracy: 0.8738 - iou_coef: 0.6261 - dice_coef: 0.7678 - f1_score: 0.7709 - aggregated_jaccard_index: 0.6360 - val_val_loss: 1.8204 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.6094 - val_val_dice_coef: 0.7540 - val_val_f1_score: 0.7567 - val_val_aggregated_jaccard_index: 0.5875 - lr: 0.0010
# Epoch 17/150
# 88/88 [==============================] - 14s 142ms/step - loss: 1.6123 - accuracy: 0.8747 - iou_coef: 0.6274 - dice_coef: 0.7689 - f1_score: 0.7720 - aggregated_jaccard_index: 0.6366 - val_val_loss: 1.5302 - val_val_accuracy: 0.9276 - val_val_iou_coef: 0.6466 - val_val_dice_coef: 0.7853 - val_val_f1_score: 0.7884 - val_val_aggregated_jaccard_index: 0.6452 - lr: 0.0010
# Epoch 18/150
# 88/88 [==============================] - 10s 102ms/step - loss: 1.5430 - accuracy: 0.8762 - iou_coef: 0.6319 - dice_coef: 0.7724 - f1_score: 0.7754 - aggregated_jaccard_index: 0.6407 - val_val_loss: 1.6682 - val_val_accuracy: 0.9004 - val_val_iou_coef: 0.6041 - val_val_dice_coef: 0.7532 - val_val_f1_score: 0.7552 - val_val_aggregated_jaccard_index: 0.6056 - lr: 0.0010
# Epoch 19/150
# 88/88 [==============================] - ETA: 0s - loss: 1.5014 - accuracy: 0.8764 - iou_coef: 0.6324 - dice_coef: 0.7728 - f1_score: 0.7756 - aggregated_jaccard_index: 0.6412
# ✅ Saved improved backbone at epoch 19 with val_iou=0.6713
# 88/88 [==============================] - 10s 103ms/step - loss: 1.5003 - accuracy: 0.8764 - iou_coef: 0.6324 - dice_coef: 0.7728 - f1_score: 0.7756 - aggregated_jaccard_index: 0.6412 - val_val_loss: 1.3324 - val_val_accuracy: 0.9304 - val_val_iou_coef: 0.6713 - val_val_dice_coef: 0.8033 - val_val_f1_score: 0.8059 - val_val_aggregated_jaccard_index: 0.6727 - lr: 0.0010
# Epoch 20/150
# 88/88 [==============================] - 14s 141ms/step - loss: 1.4583 - accuracy: 0.8765 - iou_coef: 0.6328 - dice_coef: 0.7732 - f1_score: 0.7760 - aggregated_jaccard_index: 0.6411 - val_val_loss: 1.3963 - val_val_accuracy: 0.9238 - val_val_iou_coef: 0.6481 - val_val_dice_coef: 0.7864 - val_val_f1_score: 0.7904 - val_val_aggregated_jaccard_index: 0.6481 - lr: 0.0010
# Epoch 21/150
# 88/88 [==============================] - 10s 103ms/step - loss: 1.4091 - accuracy: 0.8765 - iou_coef: 0.6343 - dice_coef: 0.7744 - f1_score: 0.7771 - aggregated_jaccard_index: 0.6429 - val_val_loss: 1.3929 - val_val_accuracy: 0.9172 - val_val_iou_coef: 0.6340 - val_val_dice_coef: 0.7757 - val_val_f1_score: 0.7792 - val_val_aggregated_jaccard_index: 0.6409 - lr: 0.0010
# Epoch 22/150
# 88/88 [==============================] - 10s 103ms/step - loss: 1.3615 - accuracy: 0.8771 - iou_coef: 0.6352 - dice_coef: 0.7749 - f1_score: 0.7775 - aggregated_jaccard_index: 0.6445 - val_val_loss: 1.2700 - val_val_accuracy: 0.9328 - val_val_iou_coef: 0.6630 - val_val_dice_coef: 0.7972 - val_val_f1_score: 0.8003 - val_val_aggregated_jaccard_index: 0.6588 - lr: 0.0010
# Epoch 23/150
# 88/88 [==============================] - 13s 137ms/step - loss: 1.3218 - accuracy: 0.8775 - iou_coef: 0.6356 - dice_coef: 0.7752 - f1_score: 0.7778 - aggregated_jaccard_index: 0.6438 - val_val_loss: 1.2768 - val_val_accuracy: 0.9309 - val_val_iou_coef: 0.6529 - val_val_dice_coef: 0.7897 - val_val_f1_score: 0.7927 - val_val_aggregated_jaccard_index: 0.6461 - lr: 0.0010
# Epoch 24/150
# 88/88 [==============================] - 10s 105ms/step - loss: 1.2680 - accuracy: 0.8789 - iou_coef: 0.6393 - dice_coef: 0.7782 - f1_score: 0.7806 - aggregated_jaccard_index: 0.6482 - val_val_loss: 1.3541 - val_val_accuracy: 0.9062 - val_val_iou_coef: 0.6129 - val_val_dice_coef: 0.7599 - val_val_f1_score: 0.7627 - val_val_aggregated_jaccard_index: 0.6177 - lr: 0.0010
# Epoch 25/150
# 88/88 [==============================] - 10s 103ms/step - loss: 1.2517 - accuracy: 0.8775 - iou_coef: 0.6340 - dice_coef: 0.7740 - f1_score: 0.7765 - aggregated_jaccard_index: 0.6423 - val_val_loss: 1.1232 - val_val_accuracy: 0.9276 - val_val_iou_coef: 0.6691 - val_val_dice_coef: 0.8017 - val_val_f1_score: 0.8043 - val_val_aggregated_jaccard_index: 0.6693 - lr: 0.0010
# Epoch 26/150
# 88/88 [==============================] - ETA: 0s - loss: 1.1926 - accuracy: 0.8786 - iou_coef: 0.6388 - dice_coef: 0.7775 - f1_score: 0.7799 - aggregated_jaccard_index: 0.6475
# ✅ Saved improved backbone at epoch 26 with val_iou=0.6744
# 88/88 [==============================] - 13s 137ms/step - loss: 1.1898 - accuracy: 0.8786 - iou_coef: 0.6388 - dice_coef: 0.7775 - f1_score: 0.7799 - aggregated_jaccard_index: 0.6475 - val_val_loss: 1.0695 - val_val_accuracy: 0.9299 - val_val_iou_coef: 0.6744 - val_val_dice_coef: 0.8056 - val_val_f1_score: 0.8078 - val_val_aggregated_jaccard_index: 0.6746 - lr: 0.0010
# Epoch 27/150
# 88/88 [==============================] - ETA: 0s - loss: 1.1451 - accuracy: 0.8801 - iou_coef: 0.6417 - dice_coef: 0.7799 - f1_score: 0.7823 - aggregated_jaccard_index: 0.6505
# ✅ Saved improved backbone at epoch 27 with val_iou=0.6845
# 88/88 [==============================] - 10s 104ms/step - loss: 1.1456 - accuracy: 0.8801 - iou_coef: 0.6417 - dice_coef: 0.7799 - f1_score: 0.7823 - aggregated_jaccard_index: 0.6505 - val_val_loss: 1.0150 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.6845 - val_val_dice_coef: 0.8126 - val_val_f1_score: 0.8147 - val_val_aggregated_jaccard_index: 0.6798 - lr: 0.0010
# Epoch 28/150
# 88/88 [==============================] - 10s 106ms/step - loss: 1.1003 - accuracy: 0.8805 - iou_coef: 0.6431 - dice_coef: 0.7809 - f1_score: 0.7831 - aggregated_jaccard_index: 0.6518 - val_val_loss: 1.0961 - val_val_accuracy: 0.9178 - val_val_iou_coef: 0.6445 - val_val_dice_coef: 0.7838 - val_val_f1_score: 0.7859 - val_val_aggregated_jaccard_index: 0.6455 - lr: 0.0010
# Epoch 29/150
# 88/88 [==============================] - 13s 139ms/step - loss: 1.0594 - accuracy: 0.8809 - iou_coef: 0.6455 - dice_coef: 0.7828 - f1_score: 0.7850 - aggregated_jaccard_index: 0.6543 - val_val_loss: 1.0270 - val_val_accuracy: 0.9216 - val_val_iou_coef: 0.6567 - val_val_dice_coef: 0.7928 - val_val_f1_score: 0.7950 - val_val_aggregated_jaccard_index: 0.6559 - lr: 0.0010
# Epoch 30/150
# 88/88 [==============================] - ETA: 0s - loss: 1.0261 - accuracy: 0.8819 - iou_coef: 0.6451 - dice_coef: 0.7827 - f1_score: 0.7849 - aggregated_jaccard_index: 0.6530
# ✅ Saved improved backbone at epoch 30 with val_iou=0.6889
# 88/88 [==============================] - 11s 106ms/step - loss: 1.0275 - accuracy: 0.8819 - iou_coef: 0.6451 - dice_coef: 0.7827 - f1_score: 0.7849 - aggregated_jaccard_index: 0.6530 - val_val_loss: 0.8969 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.6889 - val_val_dice_coef: 0.8158 - val_val_f1_score: 0.8180 - val_val_aggregated_jaccard_index: 0.6873 - lr: 0.0010
# Epoch 31/150
# 88/88 [==============================] - 11s 116ms/step - loss: 1.0066 - accuracy: 0.8793 - iou_coef: 0.6403 - dice_coef: 0.7788 - f1_score: 0.7809 - aggregated_jaccard_index: 0.6484 - val_val_loss: 1.0239 - val_val_accuracy: 0.9120 - val_val_iou_coef: 0.6308 - val_val_dice_coef: 0.7735 - val_val_f1_score: 0.7755 - val_val_aggregated_jaccard_index: 0.6336 - lr: 0.0010
# Epoch 32/150
# 88/88 [==============================] - 15s 154ms/step - loss: 0.9514 - accuracy: 0.8823 - iou_coef: 0.6470 - dice_coef: 0.7840 - f1_score: 0.7862 - aggregated_jaccard_index: 0.6552 - val_val_loss: 0.8542 - val_val_accuracy: 0.9375 - val_val_iou_coef: 0.6821 - val_val_dice_coef: 0.8110 - val_val_f1_score: 0.8137 - val_val_aggregated_jaccard_index: 0.6805 - lr: 0.0010
# Epoch 33/150
# 88/88 [==============================] - 10s 105ms/step - loss: 0.9205 - accuracy: 0.8821 - iou_coef: 0.6468 - dice_coef: 0.7838 - f1_score: 0.7859 - aggregated_jaccard_index: 0.6545 - val_val_loss: 0.8169 - val_val_accuracy: 0.9367 - val_val_iou_coef: 0.6825 - val_val_dice_coef: 0.8113 - val_val_f1_score: 0.8134 - val_val_aggregated_jaccard_index: 0.6838 - lr: 0.0010
# Epoch 34/150
# 88/88 [==============================] - 10s 105ms/step - loss: 0.8824 - accuracy: 0.8829 - iou_coef: 0.6487 - dice_coef: 0.7852 - f1_score: 0.7873 - aggregated_jaccard_index: 0.6565 - val_val_loss: 0.8921 - val_val_accuracy: 0.9349 - val_val_iou_coef: 0.6545 - val_val_dice_coef: 0.7900 - val_val_f1_score: 0.7925 - val_val_aggregated_jaccard_index: 0.6411 - lr: 0.0010
# Epoch 35/150
# 88/88 [==============================] - ETA: 0s - loss: 0.8536 - accuracy: 0.8825 - iou_coef: 0.6469 - dice_coef: 0.7839 - f1_score: 0.7859 - aggregated_jaccard_index: 0.6547
# ✅ Saved improved backbone at epoch 35 with val_iou=0.6947
# 88/88 [==============================] - 13s 138ms/step - loss: 0.8553 - accuracy: 0.8825 - iou_coef: 0.6469 - dice_coef: 0.7839 - f1_score: 0.7859 - aggregated_jaccard_index: 0.6547 - val_val_loss: 0.7305 - val_val_accuracy: 0.9370 - val_val_iou_coef: 0.6947 - val_val_dice_coef: 0.8198 - val_val_f1_score: 0.8219 - val_val_aggregated_jaccard_index: 0.6948 - lr: 0.0010
# Epoch 36/150
# 88/88 [==============================] - 10s 102ms/step - loss: 0.8178 - accuracy: 0.8829 - iou_coef: 0.6485 - dice_coef: 0.7852 - f1_score: 0.7872 - aggregated_jaccard_index: 0.6562 - val_val_loss: 0.8047 - val_val_accuracy: 0.9196 - val_val_iou_coef: 0.6568 - val_val_dice_coef: 0.7928 - val_val_f1_score: 0.7944 - val_val_aggregated_jaccard_index: 0.6531 - lr: 0.0010
# Epoch 37/150
# 88/88 [==============================] - ETA: 0s - loss: 0.7846 - accuracy: 0.8834 - iou_coef: 0.6498 - dice_coef: 0.7860 - f1_score: 0.7879 - aggregated_jaccard_index: 0.6573
# ✅ Saved improved backbone at epoch 37 with val_iou=0.6972
# 88/88 [==============================] - 10s 105ms/step - loss: 0.7865 - accuracy: 0.8834 - iou_coef: 0.6498 - dice_coef: 0.7860 - f1_score: 0.7879 - aggregated_jaccard_index: 0.6573 - val_val_loss: 0.6699 - val_val_accuracy: 0.9379 - val_val_iou_coef: 0.6972 - val_val_dice_coef: 0.8216 - val_val_f1_score: 0.8229 - val_val_aggregated_jaccard_index: 0.6978 - lr: 0.0010
# Epoch 38/150
# 88/88 [==============================] - 13s 138ms/step - loss: 0.7507 - accuracy: 0.8838 - iou_coef: 0.6510 - dice_coef: 0.7870 - f1_score: 0.7889 - aggregated_jaccard_index: 0.6592 - val_val_loss: 0.7906 - val_val_accuracy: 0.9318 - val_val_iou_coef: 0.6444 - val_val_dice_coef: 0.7821 - val_val_f1_score: 0.7840 - val_val_aggregated_jaccard_index: 0.6285 - lr: 0.0010
# Epoch 39/150
# 88/88 [==============================] - 10s 101ms/step - loss: 0.7225 - accuracy: 0.8841 - iou_coef: 0.6514 - dice_coef: 0.7871 - f1_score: 0.7891 - aggregated_jaccard_index: 0.6591 - val_val_loss: 0.6461 - val_val_accuracy: 0.9350 - val_val_iou_coef: 0.6833 - val_val_dice_coef: 0.8118 - val_val_f1_score: 0.8138 - val_val_aggregated_jaccard_index: 0.6858 - lr: 0.0010
# Epoch 40/150
# 88/88 [==============================] - 10s 102ms/step - loss: 0.6989 - accuracy: 0.8833 - iou_coef: 0.6489 - dice_coef: 0.7854 - f1_score: 0.7874 - aggregated_jaccard_index: 0.6565 - val_val_loss: 0.6085 - val_val_accuracy: 0.9356 - val_val_iou_coef: 0.6879 - val_val_dice_coef: 0.8150 - val_val_f1_score: 0.8167 - val_val_aggregated_jaccard_index: 0.6919 - lr: 0.0010
# Epoch 41/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.6609 - accuracy: 0.8850 - iou_coef: 0.6538 - dice_coef: 0.7891 - f1_score: 0.7910 - aggregated_jaccard_index: 0.6621 - val_val_loss: 0.6774 - val_val_accuracy: 0.9162 - val_val_iou_coef: 0.6435 - val_val_dice_coef: 0.7831 - val_val_f1_score: 0.7848 - val_val_aggregated_jaccard_index: 0.6442 - lr: 0.0010
# Epoch 42/150
# 88/88 [==============================] - 13s 104ms/step - loss: 0.6411 - accuracy: 0.8839 - iou_coef: 0.6513 - dice_coef: 0.7873 - f1_score: 0.7892 - aggregated_jaccard_index: 0.6575 - val_val_loss: 0.6241 - val_val_accuracy: 0.9320 - val_val_iou_coef: 0.6608 - val_val_dice_coef: 0.7956 - val_val_f1_score: 0.7977 - val_val_aggregated_jaccard_index: 0.6564 - lr: 0.0010
# Epoch 43/150
# 88/88 [==============================] - 10s 102ms/step - loss: 0.6064 - accuracy: 0.8856 - iou_coef: 0.6552 - dice_coef: 0.7902 - f1_score: 0.7920 - aggregated_jaccard_index: 0.6633 - val_val_loss: 0.5384 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.6919 - val_val_dice_coef: 0.8179 - val_val_f1_score: 0.8194 - val_val_aggregated_jaccard_index: 0.6908 - lr: 0.0010
# Epoch 44/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.5800 - accuracy: 0.8861 - iou_coef: 0.6561 - dice_coef: 0.7908 - f1_score: 0.7926 - aggregated_jaccard_index: 0.6643 - val_val_loss: 0.5573 - val_val_accuracy: 0.9368 - val_val_iou_coef: 0.6743 - val_val_dice_coef: 0.8050 - val_val_f1_score: 0.8063 - val_val_aggregated_jaccard_index: 0.6661 - lr: 0.0010
# Epoch 45/150
# 88/88 [==============================] - 13s 137ms/step - loss: 0.5584 - accuracy: 0.8862 - iou_coef: 0.6556 - dice_coef: 0.7904 - f1_score: 0.7923 - aggregated_jaccard_index: 0.6641 - val_val_loss: 0.5223 - val_val_accuracy: 0.9386 - val_val_iou_coef: 0.6805 - val_val_dice_coef: 0.8096 - val_val_f1_score: 0.8115 - val_val_aggregated_jaccard_index: 0.6739 - lr: 0.0010
# Epoch 46/150
# 88/88 [==============================] - 10s 102ms/step - loss: 0.5311 - accuracy: 0.8859 - iou_coef: 0.6568 - dice_coef: 0.7914 - f1_score: 0.7931 - aggregated_jaccard_index: 0.6647 - val_val_loss: 0.5054 - val_val_accuracy: 0.9384 - val_val_iou_coef: 0.6776 - val_val_dice_coef: 0.8075 - val_val_f1_score: 0.8097 - val_val_aggregated_jaccard_index: 0.6700 - lr: 0.0010
# Epoch 47/150
# 88/88 [==============================] - ETA: 0s - loss: 0.5090 - accuracy: 0.8866 - iou_coef: 0.6570 - dice_coef: 0.7914 - f1_score: 0.7932 - aggregated_jaccard_index: 0.6652
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 88/88 [==============================] - 10s 103ms/step - loss: 0.5080 - accuracy: 0.8866 - iou_coef: 0.6570 - dice_coef: 0.7914 - f1_score: 0.7932 - aggregated_jaccard_index: 0.6652 - val_val_loss: 0.5869 - val_val_accuracy: 0.9284 - val_val_iou_coef: 0.6233 - val_val_dice_coef: 0.7648 - val_val_f1_score: 0.7664 - val_val_aggregated_jaccard_index: 0.6018 - lr: 0.0010
# Epoch 48/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8866 - iou_coef: 0.6585 - dice_coef: 0.7925 - f1_score: 0.7942 - aggregated_jaccard_index: 0.6654
# ✅ Saved improved backbone at epoch 48 with val_iou=0.6986
# 88/88 [==============================] - 13s 137ms/step - loss: 0.4966 - accuracy: 0.8866 - iou_coef: 0.6585 - dice_coef: 0.7925 - f1_score: 0.7942 - aggregated_jaccard_index: 0.6654 - val_val_loss: 0.4402 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.6986 - val_val_dice_coef: 0.8225 - val_val_f1_score: 0.8240 - val_val_aggregated_jaccard_index: 0.6994 - lr: 1.0000e-04
# Epoch 49/150
# 88/88 [==============================] - 10s 104ms/step - loss: 0.4910 - accuracy: 0.8881 - iou_coef: 0.6609 - dice_coef: 0.7943 - f1_score: 0.7961 - aggregated_jaccard_index: 0.6679 - val_val_loss: 0.4399 - val_val_accuracy: 0.9374 - val_val_iou_coef: 0.6972 - val_val_dice_coef: 0.8216 - val_val_f1_score: 0.8230 - val_val_aggregated_jaccard_index: 0.6983 - lr: 1.0000e-04
# Epoch 50/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.8885 - iou_coef: 0.6618 - dice_coef: 0.7951 - f1_score: 0.7969 - aggregated_jaccard_index: 0.6683
# ✅ Saved improved backbone at epoch 50 with val_iou=0.6989
# 88/88 [==============================] - 10s 104ms/step - loss: 0.4887 - accuracy: 0.8885 - iou_coef: 0.6618 - dice_coef: 0.7951 - f1_score: 0.7969 - aggregated_jaccard_index: 0.6683 - val_val_loss: 0.4349 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.6989 - val_val_dice_coef: 0.8228 - val_val_f1_score: 0.8246 - val_val_aggregated_jaccard_index: 0.7004 - lr: 1.0000e-04
# Epoch 51/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4863 - accuracy: 0.8881 - iou_coef: 0.6606 - dice_coef: 0.7942 - f1_score: 0.7959 - aggregated_jaccard_index: 0.6679
# ✅ Saved improved backbone at epoch 51 with val_iou=0.7020
# 88/88 [==============================] - 13s 139ms/step - loss: 0.4863 - accuracy: 0.8881 - iou_coef: 0.6606 - dice_coef: 0.7942 - f1_score: 0.7959 - aggregated_jaccard_index: 0.6679 - val_val_loss: 0.4288 - val_val_accuracy: 0.9399 - val_val_iou_coef: 0.7020 - val_val_dice_coef: 0.8249 - val_val_f1_score: 0.8258 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-04
# Epoch 52/150
# 88/88 [==============================] - 10s 105ms/step - loss: 0.4811 - accuracy: 0.8887 - iou_coef: 0.6622 - dice_coef: 0.7954 - f1_score: 0.7972 - aggregated_jaccard_index: 0.6692 - val_val_loss: 0.4393 - val_val_accuracy: 0.9356 - val_val_iou_coef: 0.6931 - val_val_dice_coef: 0.8187 - val_val_f1_score: 0.8200 - val_val_aggregated_jaccard_index: 0.6948 - lr: 1.0000e-04
# Epoch 53/150
# 88/88 [==============================] - 10s 103ms/step - loss: 0.4776 - accuracy: 0.8890 - iou_coef: 0.6629 - dice_coef: 0.7959 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6706 - val_val_loss: 0.4283 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.6990 - val_val_dice_coef: 0.8228 - val_val_f1_score: 0.8246 - val_val_aggregated_jaccard_index: 0.7010 - lr: 1.0000e-04
# Epoch 54/150
# 88/88 [==============================] - 13s 134ms/step - loss: 0.4752 - accuracy: 0.8892 - iou_coef: 0.6629 - dice_coef: 0.7959 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6708 - val_val_loss: 0.4451 - val_val_accuracy: 0.9331 - val_val_iou_coef: 0.6873 - val_val_dice_coef: 0.8147 - val_val_f1_score: 0.8161 - val_val_aggregated_jaccard_index: 0.6881 - lr: 1.0000e-04
# Epoch 55/150
# 88/88 [==============================] - 10s 100ms/step - loss: 0.4756 - accuracy: 0.8888 - iou_coef: 0.6624 - dice_coef: 0.7955 - f1_score: 0.7973 - aggregated_jaccard_index: 0.6693 - val_val_loss: 0.4404 - val_val_accuracy: 0.9337 - val_val_iou_coef: 0.6890 - val_val_dice_coef: 0.8158 - val_val_f1_score: 0.8172 - val_val_aggregated_jaccard_index: 0.6899 - lr: 1.0000e-04
# Epoch 56/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.8901 - iou_coef: 0.6648 - dice_coef: 0.7973 - f1_score: 0.7991 - aggregated_jaccard_index: 0.6732
# ✅ Saved improved backbone at epoch 56 with val_iou=0.7022
# 88/88 [==============================] - 11s 116ms/step - loss: 0.4675 - accuracy: 0.8901 - iou_coef: 0.6648 - dice_coef: 0.7973 - f1_score: 0.7991 - aggregated_jaccard_index: 0.6732 - val_val_loss: 0.4185 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7022 - val_val_dice_coef: 0.8250 - val_val_f1_score: 0.8265 - val_val_aggregated_jaccard_index: 0.7035 - lr: 1.0000e-04
# Epoch 57/150
# 88/88 [==============================] - 15s 162ms/step - loss: 0.4709 - accuracy: 0.8889 - iou_coef: 0.6624 - dice_coef: 0.7956 - f1_score: 0.7974 - aggregated_jaccard_index: 0.6695 - val_val_loss: 0.4173 - val_val_accuracy: 0.9400 - val_val_iou_coef: 0.7014 - val_val_dice_coef: 0.8245 - val_val_f1_score: 0.8257 - val_val_aggregated_jaccard_index: 0.7030 - lr: 1.0000e-04
# Epoch 58/150
# 88/88 [==============================] - 12s 119ms/step - loss: 0.4689 - accuracy: 0.8891 - iou_coef: 0.6630 - dice_coef: 0.7960 - f1_score: 0.7977 - aggregated_jaccard_index: 0.6701 - val_val_loss: 0.4155 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7009 - val_val_dice_coef: 0.8241 - val_val_f1_score: 0.8256 - val_val_aggregated_jaccard_index: 0.7028 - lr: 1.0000e-04
# Epoch 59/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4606 - accuracy: 0.8898 - iou_coef: 0.6648 - dice_coef: 0.7974 - f1_score: 0.7992 - aggregated_jaccard_index: 0.6720 - val_val_loss: 0.4212 - val_val_accuracy: 0.9370 - val_val_iou_coef: 0.6953 - val_val_dice_coef: 0.8203 - val_val_f1_score: 0.8220 - val_val_aggregated_jaccard_index: 0.6974 - lr: 1.0000e-04
# Epoch 60/150
# 88/88 [==============================] - 15s 154ms/step - loss: 0.4592 - accuracy: 0.8897 - iou_coef: 0.6645 - dice_coef: 0.7971 - f1_score: 0.7989 - aggregated_jaccard_index: 0.6717 - val_val_loss: 0.4136 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.6997 - val_val_dice_coef: 0.8233 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7013 - lr: 1.0000e-04
# Epoch 61/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.4611 - accuracy: 0.8890 - iou_coef: 0.6627 - dice_coef: 0.7958 - f1_score: 0.7976 - aggregated_jaccard_index: 0.6700 - val_val_loss: 0.4125 - val_val_accuracy: 0.9410 - val_val_iou_coef: 0.7002 - val_val_dice_coef: 0.8237 - val_val_f1_score: 0.8247 - val_val_aggregated_jaccard_index: 0.7005 - lr: 1.0000e-04
# Epoch 62/150
# 88/88 [==============================] - 12s 122ms/step - loss: 0.4548 - accuracy: 0.8901 - iou_coef: 0.6654 - dice_coef: 0.7978 - f1_score: 0.7996 - aggregated_jaccard_index: 0.6726 - val_val_loss: 0.4072 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.7010 - val_val_dice_coef: 0.8242 - val_val_f1_score: 0.8262 - val_val_aggregated_jaccard_index: 0.7029 - lr: 1.0000e-04
# Epoch 63/150
# 88/88 [==============================] - 15s 121ms/step - loss: 0.4520 - accuracy: 0.8899 - iou_coef: 0.6647 - dice_coef: 0.7973 - f1_score: 0.7991 - aggregated_jaccard_index: 0.6721 - val_val_loss: 0.4104 - val_val_accuracy: 0.9380 - val_val_iou_coef: 0.6970 - val_val_dice_coef: 0.8214 - val_val_f1_score: 0.8227 - val_val_aggregated_jaccard_index: 0.6993 - lr: 1.0000e-04
# Epoch 64/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4496 - accuracy: 0.8901 - iou_coef: 0.6656 - dice_coef: 0.7980 - f1_score: 0.7998 - aggregated_jaccard_index: 0.6728 - val_val_loss: 0.4136 - val_val_accuracy: 0.9359 - val_val_iou_coef: 0.6930 - val_val_dice_coef: 0.8186 - val_val_f1_score: 0.8201 - val_val_aggregated_jaccard_index: 0.6955 - lr: 1.0000e-04
# Epoch 65/150
# 88/88 [==============================] - 15s 157ms/step - loss: 0.4474 - accuracy: 0.8901 - iou_coef: 0.6649 - dice_coef: 0.7975 - f1_score: 0.7992 - aggregated_jaccard_index: 0.6727 - val_val_loss: 0.4010 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7013 - val_val_dice_coef: 0.8244 - val_val_f1_score: 0.8256 - val_val_aggregated_jaccard_index: 0.7030 - lr: 1.0000e-04
# Epoch 66/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4464 - accuracy: 0.8898 - iou_coef: 0.6648 - dice_coef: 0.7974 - f1_score: 0.7992 - aggregated_jaccard_index: 0.6718
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4471 - accuracy: 0.8898 - iou_coef: 0.6648 - dice_coef: 0.7974 - f1_score: 0.7992 - aggregated_jaccard_index: 0.6718 - val_val_loss: 0.3987 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.7014 - val_val_dice_coef: 0.8245 - val_val_f1_score: 0.8260 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-04
# Epoch 67/150
# 88/88 [==============================] - 12s 118ms/step - loss: 0.4468 - accuracy: 0.8897 - iou_coef: 0.6644 - dice_coef: 0.7971 - f1_score: 0.7988 - aggregated_jaccard_index: 0.6713 - val_val_loss: 0.3997 - val_val_accuracy: 0.9390 - val_val_iou_coef: 0.7004 - val_val_dice_coef: 0.8238 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7022 - lr: 1.0000e-05
# Epoch 68/150
# 88/88 [==============================] - 15s 156ms/step - loss: 0.4476 - accuracy: 0.8894 - iou_coef: 0.6636 - dice_coef: 0.7964 - f1_score: 0.7981 - aggregated_jaccard_index: 0.6701 - val_val_loss: 0.3982 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7014 - val_val_dice_coef: 0.8245 - val_val_f1_score: 0.8263 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 69/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4442 - accuracy: 0.8899 - iou_coef: 0.6650 - dice_coef: 0.7974 - f1_score: 0.7992 - aggregated_jaccard_index: 0.6722 - val_val_loss: 0.3974 - val_val_accuracy: 0.9402 - val_val_iou_coef: 0.7018 - val_val_dice_coef: 0.8248 - val_val_f1_score: 0.8260 - val_val_aggregated_jaccard_index: 0.7036 - lr: 1.0000e-05
# Epoch 70/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4450 - accuracy: 0.8897 - iou_coef: 0.6646 - dice_coef: 0.7972 - f1_score: 0.7989 - aggregated_jaccard_index: 0.6710 - val_val_loss: 0.3984 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7007 - val_val_dice_coef: 0.8240 - val_val_f1_score: 0.8255 - val_val_aggregated_jaccard_index: 0.7028 - lr: 1.0000e-05
# Epoch 71/150
# 88/88 [==============================] - 15s 157ms/step - loss: 0.4450 - accuracy: 0.8900 - iou_coef: 0.6652 - dice_coef: 0.7977 - f1_score: 0.7994 - aggregated_jaccard_index: 0.6723 - val_val_loss: 0.3997 - val_val_accuracy: 0.9389 - val_val_iou_coef: 0.6995 - val_val_dice_coef: 0.8232 - val_val_f1_score: 0.8250 - val_val_aggregated_jaccard_index: 0.7017 - lr: 1.0000e-05
# Epoch 72/150
# 88/88 [==============================] - 12s 119ms/step - loss: 0.4451 - accuracy: 0.8903 - iou_coef: 0.6653 - dice_coef: 0.7977 - f1_score: 0.7994 - aggregated_jaccard_index: 0.6720 - val_val_loss: 0.3984 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7004 - val_val_dice_coef: 0.8238 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7025 - lr: 1.0000e-05
# Epoch 73/150
# 88/88 [==============================] - 15s 155ms/step - loss: 0.4436 - accuracy: 0.8900 - iou_coef: 0.6652 - dice_coef: 0.7976 - f1_score: 0.7993 - aggregated_jaccard_index: 0.6716 - val_val_loss: 0.3986 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.7000 - val_val_dice_coef: 0.8235 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7022 - lr: 1.0000e-05
# Epoch 74/150
# 88/88 [==============================] - 12s 118ms/step - loss: 0.4406 - accuracy: 0.8905 - iou_coef: 0.6663 - dice_coef: 0.7985 - f1_score: 0.8003 - aggregated_jaccard_index: 0.6737 - val_val_loss: 0.3976 - val_val_accuracy: 0.9397 - val_val_iou_coef: 0.7007 - val_val_dice_coef: 0.8240 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7028 - lr: 1.0000e-05
# Epoch 75/150
# 88/88 [==============================] - 12s 119ms/step - loss: 0.4432 - accuracy: 0.8905 - iou_coef: 0.6661 - dice_coef: 0.7983 - f1_score: 0.8001 - aggregated_jaccard_index: 0.6726 - val_val_loss: 0.3974 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7006 - val_val_dice_coef: 0.8239 - val_val_f1_score: 0.8257 - val_val_aggregated_jaccard_index: 0.7027 - lr: 1.0000e-05
# Epoch 76/150
# 88/88 [==============================] - ETA: 0s - loss: 0.4391 - accuracy: 0.8908 - iou_coef: 0.6679 - dice_coef: 0.7997 - f1_score: 0.8014 - aggregated_jaccard_index: 0.6742
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1e-05.
# 88/88 [==============================] - 15s 157ms/step - loss: 0.4388 - accuracy: 0.8908 - iou_coef: 0.6679 - dice_coef: 0.7997 - f1_score: 0.8014 - aggregated_jaccard_index: 0.6742 - val_val_loss: 0.3976 - val_val_accuracy: 0.9395 - val_val_iou_coef: 0.7002 - val_val_dice_coef: 0.8237 - val_val_f1_score: 0.8255 - val_val_aggregated_jaccard_index: 0.7024 - lr: 1.0000e-05
# Epoch 77/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4387 - accuracy: 0.8908 - iou_coef: 0.6672 - dice_coef: 0.7991 - f1_score: 0.8009 - aggregated_jaccard_index: 0.6743 - val_val_loss: 0.3981 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.6997 - val_val_dice_coef: 0.8233 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7019 - lr: 1.0000e-05
# Epoch 78/150
# 88/88 [==============================] - 11s 117ms/step - loss: 0.4387 - accuracy: 0.8905 - iou_coef: 0.6671 - dice_coef: 0.7991 - f1_score: 0.8008 - aggregated_jaccard_index: 0.6740 - val_val_loss: 0.3963 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.7012 - val_val_dice_coef: 0.8243 - val_val_f1_score: 0.8256 - val_val_aggregated_jaccard_index: 0.7031 - lr: 1.0000e-05
# Epoch 79/150
# 88/88 [==============================] - 15s 156ms/step - loss: 0.4373 - accuracy: 0.8908 - iou_coef: 0.6675 - dice_coef: 0.7993 - f1_score: 0.8010 - aggregated_jaccard_index: 0.6748 - val_val_loss: 0.3990 - val_val_accuracy: 0.9385 - val_val_iou_coef: 0.6988 - val_val_dice_coef: 0.8227 - val_val_f1_score: 0.8245 - val_val_aggregated_jaccard_index: 0.7009 - lr: 1.0000e-05
# Epoch 80/150
# 88/88 [==============================] - 12s 118ms/step - loss: 0.4390 - accuracy: 0.8904 - iou_coef: 0.6668 - dice_coef: 0.7988 - f1_score: 0.8006 - aggregated_jaccard_index: 0.6739 - val_val_loss: 0.3970 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.7001 - val_val_dice_coef: 0.8236 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7023 - lr: 1.0000e-05
# Epoch 81/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4424 - accuracy: 0.8896 - iou_coef: 0.6645 - dice_coef: 0.7971 - f1_score: 0.7989 - aggregated_jaccard_index: 0.6710 - val_val_loss: 0.3973 - val_val_accuracy: 0.9393 - val_val_iou_coef: 0.6995 - val_val_dice_coef: 0.8232 - val_val_f1_score: 0.8251 - val_val_aggregated_jaccard_index: 0.7019 - lr: 1.0000e-05
# Epoch 82/150
# 88/88 [==============================] - 15s 162ms/step - loss: 0.4391 - accuracy: 0.8907 - iou_coef: 0.6666 - dice_coef: 0.7987 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6737 - val_val_loss: 0.3964 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7001 - val_val_dice_coef: 0.8236 - val_val_f1_score: 0.8253 - val_val_aggregated_jaccard_index: 0.7024 - lr: 1.0000e-05
# Epoch 83/150
# 88/88 [==============================] - 12s 118ms/step - loss: 0.4392 - accuracy: 0.8907 - iou_coef: 0.6668 - dice_coef: 0.7988 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6735 - val_val_loss: 0.3954 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.7008 - val_val_dice_coef: 0.8240 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7029 - lr: 1.0000e-05
# Epoch 84/150
# 88/88 [==============================] - 12s 119ms/step - loss: 0.4414 - accuracy: 0.8901 - iou_coef: 0.6650 - dice_coef: 0.7975 - f1_score: 0.7993 - aggregated_jaccard_index: 0.6718 - val_val_loss: 0.3963 - val_val_accuracy: 0.9395 - val_val_iou_coef: 0.6997 - val_val_dice_coef: 0.8233 - val_val_f1_score: 0.8252 - val_val_aggregated_jaccard_index: 0.7022 - lr: 1.0000e-05
# Epoch 85/150
# 88/88 [==============================] - 15s 123ms/step - loss: 0.4369 - accuracy: 0.8909 - iou_coef: 0.6672 - dice_coef: 0.7991 - f1_score: 0.8008 - aggregated_jaccard_index: 0.6748 - val_val_loss: 0.3962 - val_val_accuracy: 0.9392 - val_val_iou_coef: 0.6996 - val_val_dice_coef: 0.8232 - val_val_f1_score: 0.8251 - val_val_aggregated_jaccard_index: 0.7020 - lr: 1.0000e-05
# Epoch 86/150
# 88/88 [==============================] - 11s 117ms/step - loss: 0.4373 - accuracy: 0.8907 - iou_coef: 0.6668 - dice_coef: 0.7989 - f1_score: 0.8006 - aggregated_jaccard_index: 0.6737 - val_val_loss: 0.3969 - val_val_accuracy: 0.9388 - val_val_iou_coef: 0.6989 - val_val_dice_coef: 0.8228 - val_val_f1_score: 0.8246 - val_val_aggregated_jaccard_index: 0.7014 - lr: 1.0000e-05
# Epoch 87/150
# 88/88 [==============================] - 15s 154ms/step - loss: 0.4374 - accuracy: 0.8905 - iou_coef: 0.6668 - dice_coef: 0.7989 - f1_score: 0.8006 - aggregated_jaccard_index: 0.6733 - val_val_loss: 0.3948 - val_val_accuracy: 0.9395 - val_val_iou_coef: 0.7007 - val_val_dice_coef: 0.8240 - val_val_f1_score: 0.8256 - val_val_aggregated_jaccard_index: 0.7027 - lr: 1.0000e-05
# Epoch 88/150
# 88/88 [==============================] - 12s 122ms/step - loss: 0.4359 - accuracy: 0.8907 - iou_coef: 0.6676 - dice_coef: 0.7995 - f1_score: 0.8012 - aggregated_jaccard_index: 0.6748 - val_val_loss: 0.3949 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7004 - val_val_dice_coef: 0.8238 - val_val_f1_score: 0.8254 - val_val_aggregated_jaccard_index: 0.7025 - lr: 1.0000e-05
# Epoch 89/150
# 88/88 [==============================] - 12s 121ms/step - loss: 0.4363 - accuracy: 0.8911 - iou_coef: 0.6680 - dice_coef: 0.7998 - f1_score: 0.8015 - aggregated_jaccard_index: 0.6747 - val_val_loss: 0.3952 - val_val_accuracy: 0.9391 - val_val_iou_coef: 0.7000 - val_val_dice_coef: 0.8235 - val_val_f1_score: 0.8250 - val_val_aggregated_jaccard_index: 0.7021 - lr: 1.0000e-05
# Epoch 90/150
# 88/88 [==============================] - 15s 155ms/step - loss: 0.4406 - accuracy: 0.8895 - iou_coef: 0.6640 - dice_coef: 0.7968 - f1_score: 0.7985 - aggregated_jaccard_index: 0.6700 - val_val_loss: 0.3942 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.7005 - val_val_dice_coef: 0.8239 - val_val_f1_score: 0.8253 - val_val_aggregated_jaccard_index: 0.7027 - lr: 1.0000e-05
# Epoch 91/150
# 88/88 [==============================] - 12s 120ms/step - loss: 0.4362 - accuracy: 0.8905 - iou_coef: 0.6668 - dice_coef: 0.7988 - f1_score: 0.8005 - aggregated_jaccard_index: 0.6740 - val_val_loss: 0.3939 - val_val_accuracy: 0.9399 - val_val_iou_coef: 0.7006 - val_val_dice_coef: 0.8239 - val_val_f1_score: 0.8255 - val_val_aggregated_jaccard_index: 0.7028 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# =========================================================
# CONFIG
# =========================================================

IMG_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/images"
MSK_DIR = "../MONUSEG_DATA/MoNuSeg_2025_Testing/masks"

img_size   = 256
batch_size = 13

AUTOTUNE = tf.data.AUTOTUNE

# =========================================================
# SAFE FILE COLLECTION
# =========================================================
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted([
    p for p in glob(os.path.join(IMG_DIR, "*"))
    if valid_name(p)
])

mask_paths = sorted([
    p for p in glob(os.path.join(MSK_DIR, "*"))
    if valid_name(p)
])

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# =========================================================
# SAFETY CHECK
# =========================================================
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == \
       [stem(p) for p in mask_paths], \
       "Image-mask filename mismatch"

# =========================================================
# NUMPY LOADER
# =========================================================
def _load_numpy(img_path, mask_path):

    img_path  = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    # ── IMAGE ─────────────────────────────────────────────
    img = Image.open(img_path).convert("RGB")
    img = img.resize((img_size, img_size), Image.BILINEAR)
    img = np.array(img, dtype=np.float32) / 255.0

    # ── MASK ──────────────────────────────────────────────
    mask = Image.open(mask_path).convert("L")
    mask = mask.resize((img_size, img_size), Image.NEAREST)
    mask = np.array(mask, dtype=np.float32)

    # Binary mask
    mask = (mask > 127).astype(np.float32)

    # Add channel dim → [H, W, 1]
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

# =========================================================
# TF WRAPPER
#
# SnakeUNet has ONE output: "segmentation"
# Return (img, mask) directly — no dict, no dummy tensors.
# =========================================================
def load_image_mask(img_path, mask_path):

    img, mask = tf.py_function(
        _load_numpy,
        [img_path, mask_path],
        [tf.float32, tf.float32],
    )

    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])

    # Single-output model → target is just the mask
    return img, mask

# =========================================================
# DATASET
# =========================================================
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=AUTOTUNE)
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

# =========================================================
# DEBUG
# =========================================================
print(
    "Test batches:",
    tf.data.experimental.cardinality(test_dataset).numpy()
)

# =========================================================
# SANITY CHECK
# =========================================================
for batch_images, batch_masks in test_dataset.take(1):
    print("\nImages shape :", batch_images.shape)   # (4, 256, 256, 3)
    print("Masks shape  :", batch_masks.shape)      # (4, 256, 256, 1)
# Out:
# Images found: 14
# Masks found : 14
# Test batches: 2
#
# Images shape : (13, 256, 256, 3)
# Masks shape  : (13, 256, 256, 1)

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.6992
# Mean Dice Coefficient: 0.8218
# Mean AJI:              0.6992
# Mean Accuracy:         0.9191
# Mean F1 Score:         0.8215
