# %%
import os
os.environ["TF_XLA_FLAGS"] = "--tf_xla_auto_jit=0"
os.environ.pop("XLA_FLAGS", None)

import tensorflow as tf
tf.config.optimizer.set_jit(False)

# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TF: 2.20.0
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ----------------------------
# PriorGuidedUpsample2D:
# UpSampling2D-based upsampling + Learnable prior fusion (NO pixelwise maximum)
# ----------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGuidedUpsample2D(layers.Layer):
    """
    UpSampling2D upsampling everywhere (replaces PixelShuffleResize for features/skip and optionally priors)
    PLUS learnable prior fusion:

      GAP(pred) + GAP(prior) -> Dense -> Dense(1) -> project back (B,1,1,1) gate
      fused = gate*prior + (1-gate)*pred
      then DepthwiseConv(act) -> PointwiseConv to produce final map (B,H,W,1)

    Priors influence ONLY the structure maps (center/boundary), then those modulate features as before.
    """

    def __init__(
        self,
        scale=2,
        filters=64,
        method="bilinear",
        attention_kernel=3,
        use_structure_heads=True,
        n_centers=8,
        center_sharpness=9.0,
        boundary_suppress=0.4,
        learnable_temperature=True,
        learnable_prior_resize=True,
        # prior-fusion settings
        prior_fusion_hidden_ratio=4,  # hidden = filters//ratio
        **kwargs,
    ):
        super().__init__(**kwargs)
        self.scale = int(scale)
        self.filters = int(filters)
        self.method = method
        self.attention_kernel = int(attention_kernel)
        self.use_structure_heads = bool(use_structure_heads)
        self.n_centers = int(n_centers)
        self.center_sharpness = float(center_sharpness)
        self.boundary_suppress = float(boundary_suppress)
        self.learnable_temperature = bool(learnable_temperature)

        self.learnable_prior_resize = bool(learnable_prior_resize)
        self.prior_fusion_hidden_ratio = int(prior_fusion_hidden_ratio)

        # ---------------- Projection & Attention ----------------
        self.proj_high = layers.Conv2D(filters, 1, padding="same", activation="selu", name="proj_high")
        self.proj_base = layers.Conv2D(filters, 1, padding="same", activation="linear", name="proj_base")
        self.skip_proj = layers.Conv2D(filters, 1, padding="same", use_bias=False, name="skip_proj")

        self.attention_head = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(attention_kernel, padding="same", activation="selu", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="spatial_attention",
        )

        # ---------------- UpSampling2D-based upsamplers ----------------
        self.up_feat = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_feat")
        self.up_feat_refine = tf.keras.Sequential(
            [
                layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                layers.Conv2D(filters, 1, padding="same", activation="selu"),
            ],
            name="up_feat_refine",
        )

        if self.learnable_prior_resize:
            self.up_prior = layers.UpSampling2D(size=(self.scale, self.scale), interpolation=self.method, name="up_prior")
            self.up_prior_refine = tf.keras.Sequential(
                [
                    layers.DepthwiseConv2D(3, padding="same", use_bias=False),
                    layers.Conv2D(1, 1, padding="same", activation="selu"),
                ],
                name="up_prior_refine",
            )
        else:
            self.up_prior = None
            self.up_prior_refine = None

        # ---------------- Learned fusion scale ----------------
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(1.0), trainable=True, name="alpha_weight"
        )
        self.beta_weight = self.add_weight(
            shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True, name="beta_weight"
        )

        # ---------------- Final projection (refinement step removed) ----------------
        self.final = layers.Conv2D(filters, 1, padding="same", activation="selu", name="final_head")

        # ---------------- Structural Heads ----------------
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding="same", use_bias=True)
        self.center_proj = layers.Conv2D(filters, 1, padding="same", activation=None)

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding="same", use_bias=False, name="laplace_dw")
        self.boundary_refine = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_refine",
        )
        self.boundary_gate_net = tf.keras.Sequential(
            [
                layers.Conv2D(filters // 2, 3, padding="same", activation="selu"),
                layers.Conv2D(1, 1, padding="same", activation="sigmoid"),
            ],
            name="boundary_gate_net",
        )

        self.boundary_gate_scalar = None
        self.center_temp = None
        self.center_sigma = None

        # ---------------- Learnable prior fusion blocks (CENTER) ----------------
        hid = max(4, filters // self.prior_fusion_hidden_ratio)

        self.center_gap = layers.GlobalAveragePooling2D(name="center_prior_gap")
        self.center_fc1 = layers.Dense(hid, activation="selu", name="center_prior_fc1")
        self.center_gate = layers.Dense(1, activation="sigmoid", name="center_prior_gate")  # scalar gate

        self.center_dw = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="center_prior_dw")
        self.center_pw = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="center_prior_pw")

        # ---------------- Learnable prior fusion blocks (BOUNDARY) ----------------
        self.boundary_gap = layers.GlobalAveragePooling2D(name="boundary_prior_gap")
        self.boundary_fc1 = layers.Dense(hid, activation="selu", name="boundary_prior_fc1")
        self.boundary_gate = layers.Dense(1, activation="sigmoid", name="boundary_prior_gate")  # scalar gate

        self.boundary_dw2 = layers.DepthwiseConv2D(3, padding="same", activation="selu", name="boundary_prior_dw")
        self.boundary_pw2 = layers.Conv2D(1, 1, padding="same", activation="sigmoid", name="boundary_prior_pw")

    # ---------------- Fusion scale initialization ----------------
    def _init_fusion_scale(self, shape, dtype):
        init = tf.keras.initializers.HeNormal(seed=54)
        w = init(shape=shape, dtype=dtype)
        return tf.clip_by_value(w, 0.0, 1.0)

    # ---------------- Build ----------------
    def build(self, input_shape):
        if not isinstance(input_shape, (list, tuple)) or len(input_shape) not in [2, 4]:
            raise ValueError(
                "PriorGuidedUpsample2D expects [low_res, skip_res] or "
                "[low_res, skip_res, prior_centers, prior_boundaries] inputs."
            )

        fusion_scale_init = self._init_fusion_scale((1, 1, 1, self.filters), tf.float32)
        self.fusion_scale = tf.Variable(
            initial_value=fusion_scale_init, trainable=True, name="fusion_scale", dtype=tf.float32
        )

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True,
            name="boundary_gate_scalar",
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True,
                name="center_temperature",
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness, dtype=tf.float32)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="center_sigma",
        )

        super().build(input_shape)

    # ---------------- Learnable upsample-to-target helper ----------------
    def _upsample_to(self, x, up_layer, refine, target_h, target_w):
        x = up_layer(x)
        if refine is not None:
            x = refine(x)
        # exact match by crop/pad (non-interpolating) for odd input sizes
        x = tf.image.resize_with_crop_or_pad(x, target_h, target_w)
        return x

    # ---------------- Learnable fusion (replaces pixelwise maximum) ----------------
    def _learnable_fuse_prior(self, pred_map, prior_map, gap, fc1, gate_fc, dw, pw):
        """
        pred_map/prior_map: (B,H,W,1)
        gate: scalar per-sample from GAP(pred)+GAP(prior)
        fused map refined by DWConv(act)+PWConv(sigmoid)
        """
        g_pred = gap(pred_map)   # (B,1) effectively after GAP; in TF it's (B,)
        g_prior = gap(prior_map)

        g = tf.concat([g_pred, g_prior], axis=-1)  # (B,2)
        h = fc1(g)
        gate = gate_fc(h)                          # (B,1)
        gate = tf.reshape(gate, [-1, 1, 1, 1])     # project back (broadcast)

        fused = gate * prior_map + (1.0 - gate) * pred_map
        fused = dw(fused)
        fused = pw(fused)
        return fused

    # ---------------- GMM-based Center & Boundary ----------------
    def _compute_soft_centers_gmm(self, feat, prior_centers=None, prior_boundaries=None):
        center_map, boundary_map = self._compute_centers_boundaries(feat)
        target_h, target_w = tf.shape(center_map)[1], tf.shape(center_map)[2]

        # --- learnable prior alignment + learnable fusion (NO tf.maximum) ---
        if prior_centers is not None:
            if self.up_prior is not None:
                prior_centers_up = self._upsample_to(
                    prior_centers, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_centers_up = tf.image.resize(prior_centers, (target_h, target_w), method="bilinear")
            prior_centers_up = tf.clip_by_value(prior_centers_up, 0.0, 1.0)

            center_map = self._learnable_fuse_prior(
                center_map, prior_centers_up,
                self.center_gap, self.center_fc1, self.center_gate,
                self.center_dw, self.center_pw
            )

        if prior_boundaries is not None:
            if self.up_prior is not None:
                prior_boundaries_up = self._upsample_to(
                    prior_boundaries, self.up_prior, self.up_prior_refine, target_h, target_w
                )
            else:
                prior_boundaries_up = tf.image.resize(prior_boundaries, (target_h, target_w), method="bilinear")
            prior_boundaries_up = tf.clip_by_value(prior_boundaries_up, 0.0, 1.0)

            boundary_map = self._learnable_fuse_prior(
                boundary_map, prior_boundaries_up,
                self.boundary_gap, self.boundary_fc1, self.boundary_gate,
                self.boundary_dw2, self.boundary_pw2
            )

        return center_map, boundary_map

    def _compute_centers_boundaries(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]

        proj_feat = self.center_proj(feat)
        H, W, C = tf.shape(proj_feat)[1], tf.shape(proj_feat)[2], tf.shape(proj_feat)[3]
        feat_flat = tf.reshape(proj_feat, [B, H * W, C])

        logits = self.assign_logits(proj_feat)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A_flat = tf.nn.softmax(logits_flat, axis=-1)

        A_flat_t = tf.transpose(A_flat, [0, 2, 1])
        denom = tf.reduce_sum(A_flat_t, axis=-1, keepdims=True) + eps
        prototypes = tf.matmul(A_flat_t, feat_flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])

        feat_exp = tf.expand_dims(feat_flat, 2)
        proto_exp = tf.expand_dims(prototypes, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_norm = tf.nn.l2_normalize(feat_flat, axis=-1)
        proto_norm = tf.nn.l2_normalize(prototypes, axis=-1)
        sim = tf.matmul(feat_norm, proto_norm, transpose_b=True)

        weighted_sim = resp * sim
        per_pixel_strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)

        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(per_pixel_strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)
        global_gate = tf.sigmoid(self.boundary_gate_scalar)
        boundary_map = refined_boundary * spatial_gate * global_gate * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ---------------- Forward ----------------
    def call(self, inputs, training=None):
        if len(inputs) == 2:
            low_res, skip_res = inputs
            prior_centers, prior_boundaries = None, None
        elif len(inputs) == 4:
            low_res, skip_res, prior_centers, prior_boundaries = inputs
        else:
            raise ValueError("Expected 2 or 4 inputs: [low_res, skip_res] optionally with priors.")

        high_proj = self.proj_high(low_res)
        base_proj = self.proj_base(low_res)
        alpha = self.attention_head(tf.concat([low_res, high_proj, base_proj], axis=-1))
        fused_low = alpha * high_proj + (1.0 - alpha) * base_proj

        target_h = tf.shape(low_res)[1] * self.scale
        target_w = tf.shape(low_res)[2] * self.scale

        # UpSampling2D-based upsampling (features + skip)
        upsampled = self._upsample_to(fused_low, self.up_feat, self.up_feat_refine, target_h, target_w)
        skip_proj = self.skip_proj(skip_res)
        skip_up = self._upsample_to(skip_proj, self.up_feat, self.up_feat_refine, target_h, target_w)

        fused = (upsampled + skip_up) * self.fusion_scale
        refined = fused

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(refined, prior_centers, prior_boundaries)
            refined = refined * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            out = self.final(refined)
            return out, center_map, boundary_map

        out = self.final(refined)
        return out

    # ---------------- Config ----------------
    def get_config(self):
        cfg = super().get_config()
        cfg.update(
            {
                "scale": self.scale,
                "filters": self.filters,
                "method": self.method,
                "attention_kernel": self.attention_kernel,
                "use_structure_heads": self.use_structure_heads,
                "n_centers": self.n_centers,
                "center_sharpness": self.center_sharpness,
                "boundary_suppress": self.boundary_suppress,
                "learnable_temperature": self.learnable_temperature,
                "learnable_prior_resize": self.learnable_prior_resize,
                "prior_fusion_hidden_ratio": self.prior_fusion_hidden_ratio,
            }
        )
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
import tensorflow as tf
from tensorflow.keras import layers
import tensorflow.keras.backend as K

# --- 1. Combined Dice + IoU Loss ---
def dice_iou_loss(y_true, y_pred, smooth=1e-5):
    # Flatten
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    
    # Calculate Intersection and Union
    intersection = K.sum(y_true_f * y_pred_f)
    sum_ = K.sum(y_true_f) + K.sum(y_pred_f)
    
    # Dice
    dice = (2. * intersection + smooth) / (sum_ + smooth)
    dice_loss = 1.0 - dice
    
    # IoU (Jaccard)
    iou = (intersection + smooth) / (sum_ - intersection + smooth)
    iou_loss = 1.0 - iou
    
    # Total combined loss
    return dice_loss + iou_loss

# --- 2. Single Conv Block Helper ---
def single_conv_block(x, filters, kernel_size=3, padding="same", activation="relu"):
    """
    Standard UNet single convolution block: 1 Conv2D -> BatchNorm -> ReLU
    """
    x = layers.Conv2D(filters, kernel_size, padding=padding, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation(activation)(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base



# ---------------------------------------------------------
# PriorGeneratingDownsample2D
#
# Changes from the original:
#   1. No more GatedSpatialAttention refinement step.
#   2. No more separate `refine_feat` input tensor. The skip
#      branch is now an average-pooled version of `in_feat`
#      itself, computed inside the layer with tf.nn.avg_pool2d
#      using the same pool_size as the geodesic downsampler.
#   3. call() now takes a single tensor `in_feat` instead of
#      a (in_feat, refine_feat) tuple, and build() expects a
#      single input_shape instead of a tuple of shapes.
#
# This layer produces the `center_map` / `boundary_map` priors
# (alongside the downsampled features) that PriorGuidedUpsample2D
# later consumes as `prior_centers` / `prior_boundaries`.
# ---------------------------------------------------------
@tf.keras.utils.register_keras_serializable(package="Custom")
class PriorGeneratingDownsample2D(layers.Layer):

    def __init__(self,
                 pool_size=2,
                 filters=64,
                 attention_kernel=3,
                 use_structure_heads=True,
                 n_centers=8,
                 center_sharpness=9.0,
                 boundary_suppress=0.4,
                 learnable_temperature=True,
                 **kwargs):

        super().__init__(**kwargs)

        self.pool_size = pool_size
        self.filters = filters
        self.attention_kernel = attention_kernel
        self.use_structure_heads = use_structure_heads
        self.n_centers = n_centers
        self.center_sharpness = center_sharpness
        self.boundary_suppress = boundary_suppress
        self.learnable_temperature = learnable_temperature

        # Replace pooling with geodesic kernel
        self.geo_pool = GeodesicDownsample2D(pool_size=pool_size)

        # Projections
        self.proj_high = layers.Conv2D(filters, 1, padding='same', activation='selu')
        self.proj_base = layers.Conv2D(filters, 1, padding='same')
        self.skip_proj = layers.Conv2D(filters, 1, padding='same')

        # Spatial attention
        self.attention_head = tf.keras.Sequential([
            layers.DepthwiseConv2D(attention_kernel, padding='same', activation='selu'),
            layers.Conv2D(filters, 1, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

        # Fusion scale
        self.fusion_scale = None
        self.alpha_weight = self.add_weight(shape=(1,), initializer='ones', trainable=True)
        self.beta_weight = self.add_weight(shape=(1,), initializer=tf.keras.initializers.Constant(0.5), trainable=True)

        # Final projection (refinement step removed)
        self.final = layers.Conv2D(filters, 3, padding='same', activation='selu')

        # Structure heads
        self.assign_logits = layers.Conv2D(self.n_centers, 1, padding='same')
        self.center_proj = layers.Conv2D(filters, 1, padding='same')

        self.boundary_depthwise = layers.DepthwiseConv2D(3, padding='same')
        self.boundary_refine = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])
        self.boundary_gate_net = tf.keras.Sequential([
            layers.Conv2D(filters // 2, 3, padding='same', activation='selu'),
            layers.Conv2D(1, 1, padding='same', activation='sigmoid')
        ])

    def build(self, input_shape):
        # input_shape is now a single tensor shape (in_feat only)
        _, _, _, C = input_shape

        fusion_scale_init = tf.keras.initializers.HeNormal(seed=54)(shape=(1, 1, 1, self.filters))
        self.fusion_scale = tf.Variable(fusion_scale_init, trainable=True, name='fusion_scale')

        self.boundary_gate_scalar = self.add_weight(
            shape=(1,),
            initializer=tf.keras.initializers.Constant(1.0 - self.boundary_suppress),
            trainable=True
        )

        if self.learnable_temperature:
            self.center_temp = self.add_weight(
                shape=(1,),
                initializer=tf.keras.initializers.Constant(self.center_sharpness),
                trainable=True
            )
        else:
            self.center_temp = tf.constant(self.center_sharpness)

        self.center_sigma = self.add_weight(
            shape=(self.n_centers,),
            initializer='ones',
            trainable=True
        )

        super().build(input_shape)

    # ------------------------------------------------------
    # GMM structural mask logic (unchanged)
    # ------------------------------------------------------
    def _compute_soft_centers_gmm(self, feat):
        eps = 1e-9
        B = tf.shape(feat)[0]
        proj = self.center_proj(feat)
        H = tf.shape(proj)[1]
        W = tf.shape(proj)[2]
        C = tf.shape(proj)[3]

        flat = tf.reshape(proj, [B, H * W, C])
        logits = self.assign_logits(proj)
        logits_flat = tf.reshape(logits, [B, H * W, self.n_centers])
        A = tf.nn.softmax(logits_flat, axis=-1)
        A_t = tf.transpose(A, [0, 2, 1])
        denom = tf.reduce_sum(A_t, axis=-1, keepdims=True) + eps
        proto = tf.matmul(A_t, flat) / denom

        sigma = tf.reshape(tf.maximum(self.center_sigma, 1e-6), [1, 1, self.n_centers, 1])
        feat_exp = tf.expand_dims(flat, 2)
        proto_exp = tf.expand_dims(proto, 1)
        diff_sq = tf.reduce_sum((feat_exp - proto_exp) ** 2, axis=-1)
        gauss = tf.exp(-diff_sq / (2.0 * (sigma[..., 0] ** 2) + eps))
        resp = gauss / (tf.reduce_sum(gauss, axis=-1, keepdims=True) + eps)

        feat_n = tf.nn.l2_normalize(flat, axis=-1)
        proto_n = tf.nn.l2_normalize(proto, axis=-1)
        sim = tf.matmul(feat_n, proto_n, transpose_b=True)

        weighted_sim = resp * sim
        strength = tf.reduce_max(weighted_sim, axis=-1, keepdims=True)
        sharpness = tf.maximum(self.center_temp, 1e-3)
        sharp = tf.pow(tf.nn.relu(strength) + eps, sharpness)
        max_img = tf.reduce_max(sharp, axis=[1, 2], keepdims=True) + eps
        center_map = sharp / max_img
        center_map = tf.reshape(center_map, [B, H, W, 1])

        resp_map = tf.reshape(tf.reduce_max(resp, axis=-1, keepdims=True), [B, H, W, 1])
        lap = self.boundary_depthwise(feat)
        lap_abs = tf.reduce_mean(tf.abs(lap), axis=-1, keepdims=True)
        refined_boundary = self.boundary_refine(lap_abs)
        spatial_gate = self.boundary_gate_net(feat)

        boundary_map = refined_boundary * spatial_gate * tf.sigmoid(self.boundary_gate_scalar) * resp_map
        boundary_map = tf.clip_by_value(boundary_map, 0.0, 1.0)

        return tf.clip_by_value(center_map, 0.0, 1.0), boundary_map

    # ------------------------------------------------------
    # Forward path with geodesic pooling
    #
    # `in_feat` is now the ONLY input. The skip branch is
    # derived internally via average pooling of `in_feat`
    # (replacing the old separate `refine_feat` argument),
    # and the GatedSpatialAttention refinement step has been
    # removed entirely — the merged features flow straight
    # into the structure heads / final projection.
    # ------------------------------------------------------
    def call(self, in_feat):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        pooled = self.geo_pool(in_feat)

        # Average-pooled skip branch, derived directly from in_feat
        pooled_ref = tf.nn.avg_pool2d(
            in_feat,
            ksize=[1, ph, pw, 1],
            strides=[1, ph, pw, 1],
            padding='SAME'
        )

        if tf.shape(pooled_ref)[1] != tf.shape(pooled)[1] or tf.shape(pooled_ref)[2] != tf.shape(pooled)[2]:
            pooled_ref = tf.image.resize(pooled_ref, tf.shape(pooled)[1:3], method='bilinear')

        high = self.proj_high(pooled)
        base = self.proj_base(pooled)
        alpha = self.attention_head(tf.concat([pooled, high, base], axis=-1))
        fused = alpha * high + (1 - alpha) * base

        skip = self.skip_proj(pooled_ref)
        fused = (fused + skip) * self.fusion_scale

        if self.use_structure_heads:
            center_map, boundary_map = self._compute_soft_centers_gmm(fused)
            fused = fused * (self.alpha_weight + center_map) - boundary_map * self.beta_weight
            return self.final(fused), center_map, boundary_map

        return self.final(fused)

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            'pool_size': self.pool_size,
            'filters': self.filters,
            'attention_kernel': self.attention_kernel,
            'use_structure_heads': self.use_structure_heads,
            'n_centers': self.n_centers,
            'center_sharpness': self.center_sharpness,
            'boundary_suppress': self.boundary_suppress,
            'learnable_temperature': self.learnable_temperature
        })
        return cfg

# %%
import tensorflow as tf
from tensorflow.keras import layers, regularizers

def split_branch_block(x, filters, dilation_rate=2, l2=1e-4, l1=1e-5):
    c = x.shape[-1]
    assert c % 4 == 0

    reg_k = regularizers.L2(l2)
    reg_b = regularizers.L1(l1)

    # -------------------------------------------------
    # Channel Split + gate
    # -------------------------------------------------
    splits = tf.split(x, num_or_size_splits=4, axis=-1)

    gate_logits = layers.GlobalAveragePooling2D()(x)
    gate_logits = layers.Dense(
        4,
        use_bias=True,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gate_logits)
    gates = layers.Activation("softmax")(gate_logits)

    gated_splits = [
        splits[i] * gates[:, i][:, None, None, None]
        for i in range(4)
    ]

    fpb = filters // 4  # filters per branch, target channel count for every branch

    # -------------------------------------------------
    # Multi-branch convolutions
    # -------------------------------------------------
    b1 = layers.Conv2D(
        fpb, 3, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[0])

    b2 = layers.Conv2D(
        fpb, 3, padding="same",
        dilation_rate=dilation_rate,
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[1])

    # depthwise preserves input channel count (c//4), so project with a
    # pointwise conv to fpb after each depthwise so shapes match for concat
    b3 = layers.DepthwiseConv2D(
        3, padding="same",
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[2])
    b3 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b3)

    b4 = layers.DepthwiseConv2D(
        3, padding="same",
        dilation_rate=dilation_rate,
        depthwise_regularizer=reg_k,
        bias_regularizer=reg_b
    )(gated_splits[3])
    b4 = layers.Conv2D(
        fpb, 1, padding="same",
        kernel_regularizer=reg_k,
        bias_regularizer=reg_b
    )(b4)

    add_1 = layers.Add()([b1, b4])   # fpb channels
    add_2 = layers.Add()([b2, b3])   # fpb channels
    out = layers.Concatenate()([add_1, add_2])  # filters // 2 channels
    return out

# %%
def build_normal_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = single_conv_block(inputs, base_filters)
    
    p1 = layers.MaxPooling2D(pool_size=(2, 2))(f1)
    p1 = layers.Dropout(0.05)(p1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = single_conv_block(p1, base_filters * 2)
    
    p2 = layers.MaxPooling2D(pool_size=(2, 2))(f2)
    p2 = layers.Dropout(0.15)(p2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = single_conv_block(p2, base_filters * 4)
    
    p3 = layers.MaxPooling2D(pool_size=(2, 2))(f3)
    p3 = layers.Dropout(0.2)(p3)

    # -------- Level 4 --------
    f4 = single_conv_block(p3, base_filters * 8)
    
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(f4)
    p4 = layers.Dropout(0.25)(p4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = single_conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # ===================== Decoder =====================

    # -------- Up 4 --------
    # 1. Upsample
    d4 = layers.UpSampling2D(size=(2, 2))(f5)
    
    # 2. Dropouts exactly as specified
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    
    # 3. Conv block reduces channels to match f4 (base_filters * 8)
    d4 = single_conv_block(d4, base_filters * 8)
    
    # 4. Residual Add
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=(2, 2))(d4)
    
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    
    d3 = single_conv_block(d3, base_filters * 4)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=(2, 2))(d3)
    
    d2 = single_conv_block(d2, base_filters * 2)
    d2 = layers.Dropout(0.22)(d2)
    
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=(2, 2))(d2)
    
    d1 = single_conv_block(d1, base_filters)
    d1 = layers.Dropout(0.24)(d1)
    
    d1 = layers.Add()([f1, d1])

    # ===================== Output =====================
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid", name="segmentation_output")(d1)

    model = tf.keras.Model(inputs=inputs, outputs=outputs, name="Normal_UNet_Add_Upsample")

    return model

# %%
# Create the Normal UNet model
model = build_normal_unet(input_shape=(256, 256, 3), base_filters=32, num_classes=1)

# Compile using your new Dice+IoU single loss
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=dice_iou_loss, 
    metrics=['accuracy']
)

# See the summary of your new network
model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789720694.604516      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1789720694.607327      58 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "Normal_UNet_Add_Upsample"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 256, 256,  │        896 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ activation[0][0]  │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128, 128,  │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout    │ (None, 128, 128,  │          0 │ dropout[0][0]     │
# │ (GaussianDropout)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │     18,496 │ gaussian_dropout… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 64, 64,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_1  │ (None, 64, 64,    │          0 │ dropout_1[0][0]   │
# │ (GaussianDropout)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │     73,856 │ gaussian_dropout… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ activation_2[0][… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 32, 32,    │          0 │ max_pooling2d_2[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │    295,168 │ dropout_2[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 16, 16,    │          0 │ max_pooling2d_3[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_2  │ (None, 16, 16,    │          0 │ dropout_3[0][0]   │
# │ (GaussianDropout)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │    885,120 │ gaussian_dropout… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      1,536 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 16, 16,    │          0 │ activation_4[0][… │
# │ (SpatialDropout2D)  │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_3  │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (GaussianDropout)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 32, 32,    │          0 │ gaussian_dropout… │
# │ (UpSampling2D)      │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 32, 32,    │          0 │ up_sampling2d[0]… │
# │                     │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_4  │ (None, 32, 32,    │          0 │ dropout_4[0][0]   │
# │ (GaussianDropout)   │ 384)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │    884,992 │ gaussian_dropout… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ activation_3[0][… │
# │                     │ 256)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 64, 64,    │          0 │ add[0][0]         │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gaussian_dropout_5  │ (None, 64, 64,    │          0 │ up_sampling2d_1[… │
# │ (GaussianDropout)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 64, 64,    │          0 │ gaussian_dropout… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │    295,040 │ dropout_5[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ activation_2[0][… │
# │                     │ 128)              │            │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 128, 128,  │          0 │ add_1[0][0]       │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 128, 128,  │     73,792 │ up_sampling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 128, 128,  │          0 │ activation_7[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 128, 128,  │          0 │ activation_1[0][… │
# │                     │ 64)               │            │ dropout_6[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 256, 256,  │          0 │ add_2[0][0]       │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 256, 256,  │     18,464 │ up_sampling2d_3[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 256, 256,  │          0 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 256, 256,  │          0 │ activation[0][0], │
# │                     │ 32)               │            │ dropout_7[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ segmentation_output │ (None, 256, 256,  │         33 │ add_3[0][0]       │
# │ (Conv2D)            │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,551,233 (9.73 MB)
#  Trainable params: 2,548,545 (9.72 MB)
#  Non-trainable params: 2,688 (10.50 KB)

# %%
# unet_canvas_full.py
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation + Structural (Center/Boundary) loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU
        L_struct = λ_center * CenterAlignment + λ_boundary * BoundaryAlignment

    NOTE: the BCE term (and its weight l1), the canvas consistency
    loss (fg/bg per-pixel-squared-error penalty, and its weights
    lambda_fg/lambda_bg), and the patchwise discriminator loss
    (cosine + SSIM patch error, lambda_patchdisc) have been removed.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {
                "l2": 3.0, "l3": 4.5,
                "lambda_center": 8.5, "lambda_boundary": 6.5
            }

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")
        self.lambda_center = tf.Variable(init_lambdas["lambda_center"], trainable=True, dtype=tf.float32, name="lambda_center")
        self.lambda_boundary = tf.Variable(init_lambdas["lambda_boundary"], trainable=True, dtype=tf.float32, name="lambda_boundary")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [
            self.l2, self.l3,
            self.lambda_center, self.lambda_boundary
        ]

    def call(self, y_true_tuple, y_pred_tuple):
        """
        Args:
            y_true_tuple: (y_true_seg, y_true_center, y_true_boundary)
            y_pred_tuple: (y_pred_seg, y_pred_center, y_pred_boundary)
        """
        if not isinstance(y_true_tuple, (list, tuple)) or not isinstance(y_pred_tuple, (list, tuple)):
            raise ValueError("Expected tuples: (y_true_seg, y_true_center, y_true_boundary) and (y_pred_seg, y_pred_center, y_pred_boundary)")

        y_true, y_true_center, y_true_boundary = map(tf.cast, y_true_tuple, [tf.float32]*3)
        y_pred, y_pred_center, y_pred_boundary = map(tf.cast, y_pred_tuple, [tf.float32]*3)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        # --- Structural Center/Boundary ---
        lam_c, lam_b = tf.nn.softplus(self.lambda_center), tf.nn.softplus(self.lambda_boundary)
        center_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_center, y_pred_center))
        boundary_loss = tf.reduce_mean(tf.keras.losses.binary_crossentropy(y_true_boundary, y_pred_boundary))
        overlap = tf.reduce_mean(y_pred_center * y_pred_boundary)
        struct_overlap = 1.0 - overlap
        struct_loss = lam_c * center_loss + lam_b * boundary_loss + 0.5 * struct_overlap

        return seg_loss + struct_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy()),
                "lambda_center": float(self.lambda_center.numpy()),
                "lambda_boundary": float(self.lambda_boundary.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/aug_tune/images/*.png"))
train_mask_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/aug_tune/masks/*.png"))

val_img_paths = sorted(
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/val/images/*.png") +
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/val/images/*.tif") +
    glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/val/images/*.tiff")
)
val_mask_paths = sorted(glob("/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/val/masks/*.png"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -------------------------------------------------------
# SAFETY CHECK
# -------------------------------------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in train_img_paths] == [stem(p) for p in train_mask_paths], \
    "❌ Train image-mask mismatch"

assert [stem(p) for p in val_img_paths] == [stem(p) for p in val_mask_paths], \
    "❌ Val image-mask mismatch"

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0

    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )

    mask = (mask > 127.5).astype(np.float32)[..., None]
    return img, mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 350
# Train masks: 350
# Val images: 2
# Val masks: 2
# Training batches: 88
# Validation batches: 1

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in [
            "l2", "l3",
            "lambda_center", "lambda_boundary"
        ]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            outputs = self.backbone(x, training=True)

            if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
                y_pred, centers, boundaries = outputs
            else:
                raise ValueError("Backbone must return (y_pred, centers, boundaries)")

            last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
            last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

            loss = self.loss_fn(
                (y_true, y_true, y_true),
                (y_pred, last_center, last_boundary)
            )

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        outputs = self.backbone(x, training=False)

        if isinstance(outputs, (list, tuple)) and len(outputs) == 3:
            y_pred, centers, boundaries = outputs
        else:
            raise ValueError("Backbone must return (y_pred, centers, boundaries)")

        last_center = centers[-1] if isinstance(centers, (list, tuple)) else centers
        last_boundary = boundaries[-1] if isinstance(boundaries, (list, tuple)) else boundaries

        loss = self.loss_fn(
            (y_true, y_true, y_true),
            (y_pred, last_center, last_boundary)
        )

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
from datetime import datetime
from tensorflow.keras.optimizers import AdamW

# 1️⃣ Optimizer
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 2️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 3️⃣ Compile Model (Directly compiles the UNet model)
model.compile(
    optimizer=optimizer, 
    loss=dice_iou_loss,       # Using the single loss function we defined
    metrics=metrics_list
)

# 4️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveModelCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            # Since there is no StructTrainer wrapper, self.model is the backbone itself
            self.model.save(self.save_path)
            print(f"\n✅ Saved improved model at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_model = SaveModelCallback("normal_unet.keras")

# 5️⃣ Training
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, save_model],
    verbose=1
)
print("\n🎯 Training complete. Model saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-18 08:38:33.560138: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:33.777777: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:36.197231: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:36.534517: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:36.922084: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:37.135581: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:37.432528: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:37.646295: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:38.816678: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:38.976688: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:39.624789: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:38:39.920636: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1789720736.773505     131 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 86/88 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7605 - aggregated_jaccard_index: 0.4420 - dice_coef: 0.5867 - f1_score: 0.6227 - iou_coef: 0.4260 - loss: 0.9606
# 2026-09-18 08:39:05.492201: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:05.710336: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:07.461968: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:07.788840: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:08.171785: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:08.384453: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:08.679054: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:08.892920: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:10.108930: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:10.268030: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:10.858828: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:39:11.148181: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.7616 - aggregated_jaccard_index: 0.4434 - dice_coef: 0.5881 - f1_score: 0.6240 - iou_coef: 0.4275 - loss: 0.9578
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_val_iou_coef` which is not available. Available metrics are: accuracy,aggregated_jaccard_index,dice_coef,f1_score,iou_coef,loss,val_accuracy,val_aggregated_jaccard_index,val_dice_coef,val_f1_score,val_iou_coef,val_loss
#   current = self.get_monitor_value(logs)
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/callback_list.py:171: UserWarning: Learning rate reduction is conditioned on metric `val_val_iou_coef` which is not available. Available metrics are: accuracy,aggregated_jaccard_index,dice_coef,f1_score,iou_coef,loss,val_accuracy,val_aggregated_jaccard_index,val_dice_coef,val_f1_score,val_iou_coef,val_loss,learning_rate.
#   callback.on_epoch_end(epoch, logs)
# ✅ Saved improved model at epoch 1 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 70s 349ms/step - accuracy: 0.8069 - aggregated_jaccard_index: 0.5042 - dice_coef: 0.6496 - f1_score: 0.6818 - iou_coef: 0.4896 - loss: 0.8379 - val_accuracy: 0.8983 - val_aggregated_jaccard_index: 0.3400 - val_dice_coef: 0.5102 - val_f1_score: 0.6567 - val_iou_coef: 0.3426 - val_loss: 1.1479 - learning_rate: 0.0010
# Epoch 2/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8547 - aggregated_jaccard_index: 0.5785 - dice_coef: 0.7193 - f1_score: 0.7409 - iou_coef: 0.5659 - loss: 0.6938
# ✅ Saved improved model at epoch 2 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8563 - aggregated_jaccard_index: 0.5826 - dice_coef: 0.7237 - f1_score: 0.7428 - iou_coef: 0.5709 - loss: 0.6881 - val_accuracy: 0.9213 - val_aggregated_jaccard_index: 0.4802 - val_dice_coef: 0.6583 - val_f1_score: 0.7392 - val_iou_coef: 0.4920 - val_loss: 0.8626 - learning_rate: 0.0010
# Epoch 3/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8664 - aggregated_jaccard_index: 0.6018 - dice_coef: 0.7417 - f1_score: 0.7570 - iou_coef: 0.5926 - loss: 0.6529
# ✅ Saved improved model at epoch 3 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8649 - aggregated_jaccard_index: 0.6048 - dice_coef: 0.7440 - f1_score: 0.7580 - iou_coef: 0.5956 - loss: 0.6476 - val_accuracy: 0.8502 - val_aggregated_jaccard_index: 0.4781 - val_dice_coef: 0.6384 - val_f1_score: 0.6695 - val_iou_coef: 0.4695 - val_loss: 0.8798 - learning_rate: 0.0010
# Epoch 4/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8704 - aggregated_jaccard_index: 0.6183 - dice_coef: 0.7565 - f1_score: 0.7679 - iou_coef: 0.6108 - loss: 0.6228
# ✅ Saved improved model at epoch 4 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8684 - aggregated_jaccard_index: 0.6161 - dice_coef: 0.7542 - f1_score: 0.7649 - iou_coef: 0.6083 - loss: 0.6276 - val_accuracy: 0.9060 - val_aggregated_jaccard_index: 0.6040 - val_dice_coef: 0.7502 - val_f1_score: 0.7594 - val_iou_coef: 0.6003 - val_loss: 0.6438 - learning_rate: 0.0010
# Epoch 5/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8739 - aggregated_jaccard_index: 0.6261 - dice_coef: 0.7598 - f1_score: 0.7695 - iou_coef: 0.6154 - loss: 0.6101
# ✅ Saved improved model at epoch 5 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.8721 - aggregated_jaccard_index: 0.6254 - dice_coef: 0.7594 - f1_score: 0.7685 - iou_coef: 0.6150 - loss: 0.6112 - val_accuracy: 0.9153 - val_aggregated_jaccard_index: 0.6235 - val_dice_coef: 0.7668 - val_f1_score: 0.7769 - val_iou_coef: 0.6218 - val_loss: 0.6088 - learning_rate: 0.0010
# Epoch 6/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.8749 - aggregated_jaccard_index: 0.6315 - dice_coef: 0.7657 - f1_score: 0.7739 - iou_coef: 0.6226 - loss: 0.6004
# ✅ Saved improved model at epoch 6 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.8747 - aggregated_jaccard_index: 0.6332 - dice_coef: 0.7665 - f1_score: 0.7742 - iou_coef: 0.6241 - loss: 0.5972 - val_accuracy: 0.9281 - val_aggregated_jaccard_index: 0.6653 - val_dice_coef: 0.7987 - val_f1_score: 0.8040 - val_iou_coef: 0.6649 - val_loss: 0.5357 - learning_rate: 0.0010
# Epoch 7/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8751 - aggregated_jaccard_index: 0.6380 - dice_coef: 0.7705 - f1_score: 0.7778 - iou_coef: 0.6290 - loss: 0.5888
# ✅ Saved improved model at epoch 7 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8774 - aggregated_jaccard_index: 0.6399 - dice_coef: 0.7726 - f1_score: 0.7795 - iou_coef: 0.6317 - loss: 0.5856 - val_accuracy: 0.9284 - val_aggregated_jaccard_index: 0.6675 - val_dice_coef: 0.8016 - val_f1_score: 0.8066 - val_iou_coef: 0.6689 - val_loss: 0.5319 - learning_rate: 0.0010
# Epoch 8/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8756 - aggregated_jaccard_index: 0.6432 - dice_coef: 0.7768 - f1_score: 0.7829 - iou_coef: 0.6374 - loss: 0.5781
# ✅ Saved improved model at epoch 8 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8778 - aggregated_jaccard_index: 0.6410 - dice_coef: 0.7740 - f1_score: 0.7801 - iou_coef: 0.6336 - loss: 0.5829 - val_accuracy: 0.9240 - val_aggregated_jaccard_index: 0.6565 - val_dice_coef: 0.7937 - val_f1_score: 0.7983 - val_iou_coef: 0.6579 - val_loss: 0.5509 - learning_rate: 0.0010
# Epoch 9/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8806 - aggregated_jaccard_index: 0.6524 - dice_coef: 0.7809 - f1_score: 0.7864 - iou_coef: 0.6429 - loss: 0.5630
# ✅ Saved improved model at epoch 9 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.8797 - aggregated_jaccard_index: 0.6441 - dice_coef: 0.7759 - f1_score: 0.7815 - iou_coef: 0.6363 - loss: 0.5767 - val_accuracy: 0.9260 - val_aggregated_jaccard_index: 0.6662 - val_dice_coef: 0.7995 - val_f1_score: 0.8034 - val_iou_coef: 0.6660 - val_loss: 0.5341 - learning_rate: 0.0010
# Epoch 10/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8801 - aggregated_jaccard_index: 0.6490 - dice_coef: 0.7803 - f1_score: 0.7857 - iou_coef: 0.6419 - loss: 0.5680
# ✅ Saved improved model at epoch 10 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.8805 - aggregated_jaccard_index: 0.6472 - dice_coef: 0.7783 - f1_score: 0.7835 - iou_coef: 0.6393 - loss: 0.5708 - val_accuracy: 0.9418 - val_aggregated_jaccard_index: 0.6969 - val_dice_coef: 0.8197 - val_f1_score: 0.8237 - val_iou_coef: 0.6946 - val_loss: 0.4824 - learning_rate: 0.0010
# Epoch 11/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8815 - aggregated_jaccard_index: 0.6477 - dice_coef: 0.7791 - f1_score: 0.7841 - iou_coef: 0.6405 - loss: 0.5708
# ✅ Saved improved model at epoch 11 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8809 - aggregated_jaccard_index: 0.6486 - dice_coef: 0.7789 - f1_score: 0.7838 - iou_coef: 0.6403 - loss: 0.5698 - val_accuracy: 0.9319 - val_aggregated_jaccard_index: 0.6826 - val_dice_coef: 0.8095 - val_f1_score: 0.8117 - val_iou_coef: 0.6801 - val_loss: 0.5063 - learning_rate: 0.0010
# Epoch 12/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8796 - aggregated_jaccard_index: 0.6507 - dice_coef: 0.7821 - f1_score: 0.7868 - iou_coef: 0.6439 - loss: 0.5645
# ✅ Saved improved model at epoch 12 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8824 - aggregated_jaccard_index: 0.6538 - dice_coef: 0.7838 - f1_score: 0.7885 - iou_coef: 0.6464 - loss: 0.5607 - val_accuracy: 0.9360 - val_aggregated_jaccard_index: 0.6924 - val_dice_coef: 0.8160 - val_f1_score: 0.8191 - val_iou_coef: 0.6892 - val_loss: 0.4900 - learning_rate: 0.0010
# Epoch 13/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8833 - aggregated_jaccard_index: 0.6575 - dice_coef: 0.7845 - f1_score: 0.7889 - iou_coef: 0.6474 - loss: 0.5540
# ✅ Saved improved model at epoch 13 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8837 - aggregated_jaccard_index: 0.6559 - dice_coef: 0.7851 - f1_score: 0.7895 - iou_coef: 0.6482 - loss: 0.5565 - val_accuracy: 0.9391 - val_aggregated_jaccard_index: 0.6921 - val_dice_coef: 0.8157 - val_f1_score: 0.8184 - val_iou_coef: 0.6888 - val_loss: 0.4913 - learning_rate: 0.0010
# Epoch 14/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8843 - aggregated_jaccard_index: 0.6456 - dice_coef: 0.7786 - f1_score: 0.7829 - iou_coef: 0.6394 - loss: 0.5734
# ✅ Saved improved model at epoch 14 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8846 - aggregated_jaccard_index: 0.6558 - dice_coef: 0.7859 - f1_score: 0.7902 - iou_coef: 0.6492 - loss: 0.5565 - val_accuracy: 0.9211 - val_aggregated_jaccard_index: 0.6566 - val_dice_coef: 0.7915 - val_f1_score: 0.7937 - val_iou_coef: 0.6549 - val_loss: 0.5508 - learning_rate: 0.0010
# Epoch 15/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8846 - aggregated_jaccard_index: 0.6593 - dice_coef: 0.7877 - f1_score: 0.7919 - iou_coef: 0.6515 - loss: 0.5502
# ✅ Saved improved model at epoch 15 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.8854 - aggregated_jaccard_index: 0.6596 - dice_coef: 0.7882 - f1_score: 0.7923 - iou_coef: 0.6522 - loss: 0.5493 - val_accuracy: 0.9400 - val_aggregated_jaccard_index: 0.7007 - val_dice_coef: 0.8238 - val_f1_score: 0.8257 - val_iou_coef: 0.7004 - val_loss: 0.4752 - learning_rate: 0.0010
# Epoch 16/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8850 - aggregated_jaccard_index: 0.6698 - dice_coef: 0.7958 - f1_score: 0.7996 - iou_coef: 0.6627 - loss: 0.5320
# ✅ Saved improved model at epoch 16 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8860 - aggregated_jaccard_index: 0.6628 - dice_coef: 0.7903 - f1_score: 0.7942 - iou_coef: 0.6552 - loss: 0.5441 - val_accuracy: 0.9383 - val_aggregated_jaccard_index: 0.6974 - val_dice_coef: 0.8213 - val_f1_score: 0.8233 - val_iou_coef: 0.6968 - val_loss: 0.4810 - learning_rate: 0.0010
# Epoch 17/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8856 - aggregated_jaccard_index: 0.6573 - dice_coef: 0.7871 - f1_score: 0.7907 - iou_coef: 0.6507 - loss: 0.5533
# ✅ Saved improved model at epoch 17 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8869 - aggregated_jaccard_index: 0.6627 - dice_coef: 0.7911 - f1_score: 0.7948 - iou_coef: 0.6562 - loss: 0.5441 - val_accuracy: 0.9415 - val_aggregated_jaccard_index: 0.7068 - val_dice_coef: 0.8257 - val_f1_score: 0.8280 - val_iou_coef: 0.7032 - val_loss: 0.4663 - learning_rate: 0.0010
# Epoch 18/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8885 - aggregated_jaccard_index: 0.6646 - dice_coef: 0.7927 - f1_score: 0.7963 - iou_coef: 0.6583 - loss: 0.5403
# ✅ Saved improved model at epoch 18 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8881 - aggregated_jaccard_index: 0.6658 - dice_coef: 0.7936 - f1_score: 0.7972 - iou_coef: 0.6595 - loss: 0.5382 - val_accuracy: 0.9444 - val_aggregated_jaccard_index: 0.7107 - val_dice_coef: 0.8291 - val_f1_score: 0.8316 - val_iou_coef: 0.7082 - val_loss: 0.4590 - learning_rate: 0.0010
# Epoch 19/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8891 - aggregated_jaccard_index: 0.6641 - dice_coef: 0.7920 - f1_score: 0.7955 - iou_coef: 0.6574 - loss: 0.5418
# ✅ Saved improved model at epoch 19 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8880 - aggregated_jaccard_index: 0.6658 - dice_coef: 0.7932 - f1_score: 0.7966 - iou_coef: 0.6590 - loss: 0.5380 - val_accuracy: 0.9377 - val_aggregated_jaccard_index: 0.6999 - val_dice_coef: 0.8217 - val_f1_score: 0.8247 - val_iou_coef: 0.6975 - val_loss: 0.4769 - learning_rate: 0.0010
# Epoch 20/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8878 - aggregated_jaccard_index: 0.6762 - dice_coef: 0.7998 - f1_score: 0.8032 - iou_coef: 0.6683 - loss: 0.5211
# ✅ Saved improved model at epoch 20 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8882 - aggregated_jaccard_index: 0.6670 - dice_coef: 0.7945 - f1_score: 0.7978 - iou_coef: 0.6607 - loss: 0.5359 - val_accuracy: 0.9305 - val_aggregated_jaccard_index: 0.6819 - val_dice_coef: 0.8113 - val_f1_score: 0.8133 - val_iou_coef: 0.6826 - val_loss: 0.5072 - learning_rate: 0.0010
# Epoch 21/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8895 - aggregated_jaccard_index: 0.6754 - dice_coef: 0.8002 - f1_score: 0.8034 - iou_coef: 0.6685 - loss: 0.5222
# ✅ Saved improved model at epoch 21 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8903 - aggregated_jaccard_index: 0.6713 - dice_coef: 0.7975 - f1_score: 0.8008 - iou_coef: 0.6648 - loss: 0.5295 - val_accuracy: 0.9426 - val_aggregated_jaccard_index: 0.7112 - val_dice_coef: 0.8278 - val_f1_score: 0.8307 - val_iou_coef: 0.7063 - val_loss: 0.4595 - learning_rate: 0.0010
# Epoch 22/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8879 - aggregated_jaccard_index: 0.6675 - dice_coef: 0.7943 - f1_score: 0.7975 - iou_coef: 0.6605 - loss: 0.5353
# ✅ Saved improved model at epoch 22 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8895 - aggregated_jaccard_index: 0.6705 - dice_coef: 0.7966 - f1_score: 0.7996 - iou_coef: 0.6635 - loss: 0.5300 - val_accuracy: 0.9437 - val_aggregated_jaccard_index: 0.7122 - val_dice_coef: 0.8301 - val_f1_score: 0.8323 - val_iou_coef: 0.7097 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 23/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8894 - aggregated_jaccard_index: 0.6747 - dice_coef: 0.7990 - f1_score: 0.8020 - iou_coef: 0.6668 - loss: 0.5237
# ✅ Saved improved model at epoch 23 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8908 - aggregated_jaccard_index: 0.6735 - dice_coef: 0.7987 - f1_score: 0.8018 - iou_coef: 0.6665 - loss: 0.5249 - val_accuracy: 0.9447 - val_aggregated_jaccard_index: 0.7103 - val_dice_coef: 0.8298 - val_f1_score: 0.8321 - val_iou_coef: 0.7091 - val_loss: 0.4595 - learning_rate: 0.0010
# Epoch 24/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8911 - aggregated_jaccard_index: 0.6723 - dice_coef: 0.7973 - f1_score: 0.8003 - iou_coef: 0.6645 - loss: 0.5275
# ✅ Saved improved model at epoch 24 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8910 - aggregated_jaccard_index: 0.6741 - dice_coef: 0.7990 - f1_score: 0.8019 - iou_coef: 0.6668 - loss: 0.5239 - val_accuracy: 0.9447 - val_aggregated_jaccard_index: 0.7139 - val_dice_coef: 0.8309 - val_f1_score: 0.8334 - val_iou_coef: 0.7108 - val_loss: 0.4541 - learning_rate: 0.0010
# Epoch 25/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8909 - aggregated_jaccard_index: 0.6730 - dice_coef: 0.7980 - f1_score: 0.8008 - iou_coef: 0.6659 - loss: 0.5260
# ✅ Saved improved model at epoch 25 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8916 - aggregated_jaccard_index: 0.6759 - dice_coef: 0.8000 - f1_score: 0.8028 - iou_coef: 0.6684 - loss: 0.5217 - val_accuracy: 0.9429 - val_aggregated_jaccard_index: 0.6996 - val_dice_coef: 0.8239 - val_f1_score: 0.8247 - val_iou_coef: 0.7006 - val_loss: 0.4769 - learning_rate: 0.0010
# Epoch 26/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8930 - aggregated_jaccard_index: 0.6803 - dice_coef: 0.8039 - f1_score: 0.8066 - iou_coef: 0.6737 - loss: 0.5129
# ✅ Saved improved model at epoch 26 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8917 - aggregated_jaccard_index: 0.6757 - dice_coef: 0.8012 - f1_score: 0.8041 - iou_coef: 0.6699 - loss: 0.5210 - val_accuracy: 0.9296 - val_aggregated_jaccard_index: 0.6838 - val_dice_coef: 0.8069 - val_f1_score: 0.8080 - val_iou_coef: 0.6767 - val_loss: 0.5063 - learning_rate: 0.0010
# Epoch 27/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8951 - aggregated_jaccard_index: 0.6747 - dice_coef: 0.7999 - f1_score: 0.8026 - iou_coef: 0.6681 - loss: 0.5225
# ✅ Saved improved model at epoch 27 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8922 - aggregated_jaccard_index: 0.6757 - dice_coef: 0.8008 - f1_score: 0.8036 - iou_coef: 0.6694 - loss: 0.5211 - val_accuracy: 0.9409 - val_aggregated_jaccard_index: 0.7089 - val_dice_coef: 0.8256 - val_f1_score: 0.8268 - val_iou_coef: 0.7032 - val_loss: 0.4638 - learning_rate: 0.0010
# Epoch 28/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8913 - aggregated_jaccard_index: 0.6798 - dice_coef: 0.8039 - f1_score: 0.8067 - iou_coef: 0.6735 - loss: 0.5137
# ✅ Saved improved model at epoch 28 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8937 - aggregated_jaccard_index: 0.6797 - dice_coef: 0.8034 - f1_score: 0.8062 - iou_coef: 0.6730 - loss: 0.5142 - val_accuracy: 0.9443 - val_aggregated_jaccard_index: 0.7182 - val_dice_coef: 0.8331 - val_f1_score: 0.8349 - val_iou_coef: 0.7141 - val_loss: 0.4469 - learning_rate: 0.0010
# Epoch 29/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8925 - aggregated_jaccard_index: 0.6815 - dice_coef: 0.8042 - f1_score: 0.8067 - iou_coef: 0.6741 - loss: 0.5108
# ✅ Saved improved model at epoch 29 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.8932 - aggregated_jaccard_index: 0.6792 - dice_coef: 0.8039 - f1_score: 0.8065 - iou_coef: 0.6735 - loss: 0.5143 - val_accuracy: 0.9247 - val_aggregated_jaccard_index: 0.6683 - val_dice_coef: 0.8007 - val_f1_score: 0.8027 - val_iou_coef: 0.6677 - val_loss: 0.5305 - learning_rate: 0.0010
# Epoch 30/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8947 - aggregated_jaccard_index: 0.6773 - dice_coef: 0.8020 - f1_score: 0.8047 - iou_coef: 0.6710 - loss: 0.5184
# ✅ Saved improved model at epoch 30 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8937 - aggregated_jaccard_index: 0.6792 - dice_coef: 0.8038 - f1_score: 0.8064 - iou_coef: 0.6734 - loss: 0.5144 - val_accuracy: 0.9435 - val_aggregated_jaccard_index: 0.7151 - val_dice_coef: 0.8328 - val_f1_score: 0.8346 - val_iou_coef: 0.7135 - val_loss: 0.4511 - learning_rate: 0.0010
# Epoch 31/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8952 - aggregated_jaccard_index: 0.6787 - dice_coef: 0.8027 - f1_score: 0.8053 - iou_coef: 0.6719 - loss: 0.5159
# ✅ Saved improved model at epoch 31 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.8949 - aggregated_jaccard_index: 0.6837 - dice_coef: 0.8071 - f1_score: 0.8097 - iou_coef: 0.6780 - loss: 0.5075 - val_accuracy: 0.9300 - val_aggregated_jaccard_index: 0.6811 - val_dice_coef: 0.8094 - val_f1_score: 0.8111 - val_iou_coef: 0.6798 - val_loss: 0.5086 - learning_rate: 0.0010
# Epoch 32/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8920 - aggregated_jaccard_index: 0.6823 - dice_coef: 0.8061 - f1_score: 0.8086 - iou_coef: 0.6766 - loss: 0.5094
# ✅ Saved improved model at epoch 32 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8950 - aggregated_jaccard_index: 0.6835 - dice_coef: 0.8066 - f1_score: 0.8090 - iou_coef: 0.6772 - loss: 0.5071 - val_accuracy: 0.9364 - val_aggregated_jaccard_index: 0.6997 - val_dice_coef: 0.8209 - val_f1_score: 0.8222 - val_iou_coef: 0.6963 - val_loss: 0.4774 - learning_rate: 0.0010
# Epoch 33/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8946 - aggregated_jaccard_index: 0.6810 - dice_coef: 0.8045 - f1_score: 0.8070 - iou_coef: 0.6745 - loss: 0.5115
# ✅ Saved improved model at epoch 33 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.8955 - aggregated_jaccard_index: 0.6840 - dice_coef: 0.8069 - f1_score: 0.8093 - iou_coef: 0.6777 - loss: 0.5067 - val_accuracy: 0.9423 - val_aggregated_jaccard_index: 0.7070 - val_dice_coef: 0.8266 - val_f1_score: 0.8282 - val_iou_coef: 0.7045 - val_loss: 0.4658 - learning_rate: 0.0010
# Epoch 34/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8967 - aggregated_jaccard_index: 0.6846 - dice_coef: 0.8077 - f1_score: 0.8101 - iou_coef: 0.6788 - loss: 0.5055
# ✅ Saved improved model at epoch 34 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8960 - aggregated_jaccard_index: 0.6864 - dice_coef: 0.8083 - f1_score: 0.8108 - iou_coef: 0.6798 - loss: 0.5029 - val_accuracy: 0.9314 - val_aggregated_jaccard_index: 0.6868 - val_dice_coef: 0.8107 - val_f1_score: 0.8116 - val_iou_coef: 0.6819 - val_loss: 0.4998 - learning_rate: 0.0010
# Epoch 35/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8960 - aggregated_jaccard_index: 0.6882 - dice_coef: 0.8095 - f1_score: 0.8120 - iou_coef: 0.6815 - loss: 0.4993
# ✅ Saved improved model at epoch 35 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8953 - aggregated_jaccard_index: 0.6839 - dice_coef: 0.8071 - f1_score: 0.8095 - iou_coef: 0.6780 - loss: 0.5060 - val_accuracy: 0.9397 - val_aggregated_jaccard_index: 0.7037 - val_dice_coef: 0.8255 - val_f1_score: 0.8263 - val_iou_coef: 0.7029 - val_loss: 0.4702 - learning_rate: 0.0010
# Epoch 36/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8943 - aggregated_jaccard_index: 0.6854 - dice_coef: 0.8092 - f1_score: 0.8115 - iou_coef: 0.6807 - loss: 0.5036
# ✅ Saved improved model at epoch 36 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8976 - aggregated_jaccard_index: 0.6891 - dice_coef: 0.8111 - f1_score: 0.8135 - iou_coef: 0.6835 - loss: 0.4975 - val_accuracy: 0.9442 - val_aggregated_jaccard_index: 0.6985 - val_dice_coef: 0.8241 - val_f1_score: 0.8248 - val_iou_coef: 0.7008 - val_loss: 0.4785 - learning_rate: 0.0010
# Epoch 37/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8963 - aggregated_jaccard_index: 0.6905 - dice_coef: 0.8114 - f1_score: 0.8137 - iou_coef: 0.6840 - loss: 0.4956
# ✅ Saved improved model at epoch 37 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.8971 - aggregated_jaccard_index: 0.6884 - dice_coef: 0.8106 - f1_score: 0.8129 - iou_coef: 0.6828 - loss: 0.4980 - val_accuracy: 0.9333 - val_aggregated_jaccard_index: 0.6934 - val_dice_coef: 0.8126 - val_f1_score: 0.8143 - val_iou_coef: 0.6850 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 38/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8983 - aggregated_jaccard_index: 0.6916 - dice_coef: 0.8134 - f1_score: 0.8156 - iou_coef: 0.6869 - loss: 0.4935
# ✅ Saved improved model at epoch 38 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8976 - aggregated_jaccard_index: 0.6888 - dice_coef: 0.8113 - f1_score: 0.8136 - iou_coef: 0.6838 - loss: 0.4982 - val_accuracy: 0.9389 - val_aggregated_jaccard_index: 0.6992 - val_dice_coef: 0.8247 - val_f1_score: 0.8262 - val_iou_coef: 0.7018 - val_loss: 0.4780 - learning_rate: 0.0010
# Epoch 39/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8956 - aggregated_jaccard_index: 0.6877 - dice_coef: 0.8089 - f1_score: 0.8110 - iou_coef: 0.6807 - loss: 0.5016
# ✅ Saved improved model at epoch 39 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8977 - aggregated_jaccard_index: 0.6902 - dice_coef: 0.8116 - f1_score: 0.8138 - iou_coef: 0.6844 - loss: 0.4954 - val_accuracy: 0.9357 - val_aggregated_jaccard_index: 0.6986 - val_dice_coef: 0.8209 - val_f1_score: 0.8222 - val_iou_coef: 0.6962 - val_loss: 0.4791 - learning_rate: 0.0010
# Epoch 40/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8992 - aggregated_jaccard_index: 0.6918 - dice_coef: 0.8130 - f1_score: 0.8152 - iou_coef: 0.6860 - loss: 0.4929
# ✅ Saved improved model at epoch 40 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.8993 - aggregated_jaccard_index: 0.6938 - dice_coef: 0.8143 - f1_score: 0.8165 - iou_coef: 0.6880 - loss: 0.4894 - val_accuracy: 0.9383 - val_aggregated_jaccard_index: 0.7058 - val_dice_coef: 0.8240 - val_f1_score: 0.8250 - val_iou_coef: 0.7008 - val_loss: 0.4681 - learning_rate: 0.0010
# Epoch 41/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9003 - aggregated_jaccard_index: 0.6920 - dice_coef: 0.8132 - f1_score: 0.8152 - iou_coef: 0.6863 - loss: 0.4925
# ✅ Saved improved model at epoch 41 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.8997 - aggregated_jaccard_index: 0.6951 - dice_coef: 0.8152 - f1_score: 0.8172 - iou_coef: 0.6893 - loss: 0.4875 - val_accuracy: 0.9355 - val_aggregated_jaccard_index: 0.6992 - val_dice_coef: 0.8177 - val_f1_score: 0.8193 - val_iou_coef: 0.6920 - val_loss: 0.4803 - learning_rate: 0.0010
# Epoch 42/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8986 - aggregated_jaccard_index: 0.6942 - dice_coef: 0.8139 - f1_score: 0.8160 - iou_coef: 0.6874 - loss: 0.4894
# ✅ Saved improved model at epoch 42 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8984 - aggregated_jaccard_index: 0.6924 - dice_coef: 0.8134 - f1_score: 0.8155 - iou_coef: 0.6868 - loss: 0.4922 - val_accuracy: 0.9302 - val_aggregated_jaccard_index: 0.6846 - val_dice_coef: 0.8081 - val_f1_score: 0.8094 - val_iou_coef: 0.6784 - val_loss: 0.5045 - learning_rate: 0.0010
# Epoch 43/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9031 - aggregated_jaccard_index: 0.6956 - dice_coef: 0.8151 - f1_score: 0.8171 - iou_coef: 0.6892 - loss: 0.4863
# ✅ Saved improved model at epoch 43 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8995 - aggregated_jaccard_index: 0.6941 - dice_coef: 0.8148 - f1_score: 0.8168 - iou_coef: 0.6887 - loss: 0.4886 - val_accuracy: 0.9449 - val_aggregated_jaccard_index: 0.7104 - val_dice_coef: 0.8306 - val_f1_score: 0.8318 - val_iou_coef: 0.7103 - val_loss: 0.4590 - learning_rate: 0.0010
# Epoch 44/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9038 - aggregated_jaccard_index: 0.6984 - dice_coef: 0.8174 - f1_score: 0.8195 - iou_coef: 0.6924 - loss: 0.4818
# ✅ Saved improved model at epoch 44 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9009 - aggregated_jaccard_index: 0.6983 - dice_coef: 0.8172 - f1_score: 0.8192 - iou_coef: 0.6922 - loss: 0.4819 - val_accuracy: 0.9377 - val_aggregated_jaccard_index: 0.7061 - val_dice_coef: 0.8214 - val_f1_score: 0.8220 - val_iou_coef: 0.6975 - val_loss: 0.4699 - learning_rate: 0.0010
# Epoch 45/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8985 - aggregated_jaccard_index: 0.6973 - dice_coef: 0.8173 - f1_score: 0.8193 - iou_coef: 0.6922 - loss: 0.4837
# ✅ Saved improved model at epoch 45 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9005 - aggregated_jaccard_index: 0.6967 - dice_coef: 0.8168 - f1_score: 0.8189 - iou_coef: 0.6916 - loss: 0.4846 - val_accuracy: 0.9392 - val_aggregated_jaccard_index: 0.7095 - val_dice_coef: 0.8270 - val_f1_score: 0.8282 - val_iou_coef: 0.7051 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 46/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9013 - aggregated_jaccard_index: 0.6992 - dice_coef: 0.8185 - f1_score: 0.8204 - iou_coef: 0.6939 - loss: 0.4804
# ✅ Saved improved model at epoch 46 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9017 - aggregated_jaccard_index: 0.7006 - dice_coef: 0.8194 - f1_score: 0.8214 - iou_coef: 0.6953 - loss: 0.4775 - val_accuracy: 0.9403 - val_aggregated_jaccard_index: 0.7052 - val_dice_coef: 0.8240 - val_f1_score: 0.8248 - val_iou_coef: 0.7008 - val_loss: 0.4695 - learning_rate: 0.0010
# Epoch 47/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8985 - aggregated_jaccard_index: 0.6973 - dice_coef: 0.8182 - f1_score: 0.8201 - iou_coef: 0.6935 - loss: 0.4832
# ✅ Saved improved model at epoch 47 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9015 - aggregated_jaccard_index: 0.6993 - dice_coef: 0.8187 - f1_score: 0.8206 - iou_coef: 0.6942 - loss: 0.4800 - val_accuracy: 0.9422 - val_aggregated_jaccard_index: 0.7140 - val_dice_coef: 0.8299 - val_f1_score: 0.8309 - val_iou_coef: 0.7094 - val_loss: 0.4544 - learning_rate: 0.0010
# Epoch 48/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9027 - aggregated_jaccard_index: 0.7035 - dice_coef: 0.8217 - f1_score: 0.8235 - iou_coef: 0.6985 - loss: 0.4726
# ✅ Saved improved model at epoch 48 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9023 - aggregated_jaccard_index: 0.7009 - dice_coef: 0.8197 - f1_score: 0.8216 - iou_coef: 0.6957 - loss: 0.4776 - val_accuracy: 0.9359 - val_aggregated_jaccard_index: 0.6968 - val_dice_coef: 0.8173 - val_f1_score: 0.8182 - val_iou_coef: 0.6913 - val_loss: 0.4835 - learning_rate: 0.0010
# Epoch 49/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8994 - aggregated_jaccard_index: 0.6963 - dice_coef: 0.8171 - f1_score: 0.8190 - iou_coef: 0.6916 - loss: 0.4846
# ✅ Saved improved model at epoch 49 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9018 - aggregated_jaccard_index: 0.7002 - dice_coef: 0.8196 - f1_score: 0.8215 - iou_coef: 0.6956 - loss: 0.4789 - val_accuracy: 0.9418 - val_aggregated_jaccard_index: 0.7103 - val_dice_coef: 0.8292 - val_f1_score: 0.8296 - val_iou_coef: 0.7083 - val_loss: 0.4594 - learning_rate: 0.0010
# Epoch 50/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9010 - aggregated_jaccard_index: 0.7048 - dice_coef: 0.8229 - f1_score: 0.8248 - iou_coef: 0.7002 - loss: 0.4706
# ✅ Saved improved model at epoch 50 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.9031 - aggregated_jaccard_index: 0.7033 - dice_coef: 0.8217 - f1_score: 0.8236 - iou_coef: 0.6985 - loss: 0.4727 - val_accuracy: 0.9387 - val_aggregated_jaccard_index: 0.7063 - val_dice_coef: 0.8247 - val_f1_score: 0.8258 - val_iou_coef: 0.7019 - val_loss: 0.4668 - learning_rate: 0.0010
# Epoch 51/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9036 - aggregated_jaccard_index: 0.7040 - dice_coef: 0.8217 - f1_score: 0.8235 - iou_coef: 0.6985 - loss: 0.4720
# ✅ Saved improved model at epoch 51 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9027 - aggregated_jaccard_index: 0.7029 - dice_coef: 0.8213 - f1_score: 0.8230 - iou_coef: 0.6979 - loss: 0.4742 - val_accuracy: 0.9422 - val_aggregated_jaccard_index: 0.7172 - val_dice_coef: 0.8296 - val_f1_score: 0.8307 - val_iou_coef: 0.7093 - val_loss: 0.4509 - learning_rate: 0.0010
# Epoch 52/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9037 - aggregated_jaccard_index: 0.7047 - dice_coef: 0.8225 - f1_score: 0.8242 - iou_coef: 0.6999 - loss: 0.4706
# ✅ Saved improved model at epoch 52 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9032 - aggregated_jaccard_index: 0.7032 - dice_coef: 0.8215 - f1_score: 0.8232 - iou_coef: 0.6983 - loss: 0.4729 - val_accuracy: 0.9376 - val_aggregated_jaccard_index: 0.7041 - val_dice_coef: 0.8220 - val_f1_score: 0.8228 - val_iou_coef: 0.6980 - val_loss: 0.4712 - learning_rate: 0.0010
# Epoch 53/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9013 - aggregated_jaccard_index: 0.7032 - dice_coef: 0.8221 - f1_score: 0.8238 - iou_coef: 0.6991 - loss: 0.4735
# ✅ Saved improved model at epoch 53 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9026 - aggregated_jaccard_index: 0.7032 - dice_coef: 0.8211 - f1_score: 0.8229 - iou_coef: 0.6977 - loss: 0.4740 - val_accuracy: 0.9391 - val_aggregated_jaccard_index: 0.7111 - val_dice_coef: 0.8250 - val_f1_score: 0.8257 - val_iou_coef: 0.7027 - val_loss: 0.4615 - learning_rate: 0.0010
# Epoch 54/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9017 - aggregated_jaccard_index: 0.7046 - dice_coef: 0.8230 - f1_score: 0.8249 - iou_coef: 0.7004 - loss: 0.4707
# ✅ Saved improved model at epoch 54 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9037 - aggregated_jaccard_index: 0.7049 - dice_coef: 0.8227 - f1_score: 0.8245 - iou_coef: 0.6999 - loss: 0.4704 - val_accuracy: 0.9382 - val_aggregated_jaccard_index: 0.6619 - val_dice_coef: 0.8027 - val_f1_score: 0.8032 - val_iou_coef: 0.6712 - val_loss: 0.5382 - learning_rate: 0.0010
# Epoch 55/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9043 - aggregated_jaccard_index: 0.7070 - dice_coef: 0.8236 - f1_score: 0.8253 - iou_coef: 0.7012 - loss: 0.4669
# ✅ Saved improved model at epoch 55 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9044 - aggregated_jaccard_index: 0.7075 - dice_coef: 0.8243 - f1_score: 0.8260 - iou_coef: 0.7023 - loss: 0.4668 - val_accuracy: 0.9281 - val_aggregated_jaccard_index: 0.6779 - val_dice_coef: 0.8048 - val_f1_score: 0.8053 - val_iou_coef: 0.6736 - val_loss: 0.5149 - learning_rate: 0.0010
# Epoch 56/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9042 - aggregated_jaccard_index: 0.7051 - dice_coef: 0.8225 - f1_score: 0.8242 - iou_coef: 0.6998 - loss: 0.4708
# ✅ Saved improved model at epoch 56 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9046 - aggregated_jaccard_index: 0.7070 - dice_coef: 0.8241 - f1_score: 0.8258 - iou_coef: 0.7020 - loss: 0.4672 - val_accuracy: 0.9408 - val_aggregated_jaccard_index: 0.7044 - val_dice_coef: 0.8236 - val_f1_score: 0.8243 - val_iou_coef: 0.7003 - val_loss: 0.4707 - learning_rate: 0.0010
# Epoch 57/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9052 - aggregated_jaccard_index: 0.7011 - dice_coef: 0.8196 - f1_score: 0.8214 - iou_coef: 0.6955 - loss: 0.4773
# ✅ Saved improved model at epoch 57 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9052 - aggregated_jaccard_index: 0.7091 - dice_coef: 0.8253 - f1_score: 0.8271 - iou_coef: 0.7037 - loss: 0.4636 - val_accuracy: 0.9444 - val_aggregated_jaccard_index: 0.7190 - val_dice_coef: 0.8335 - val_f1_score: 0.8346 - val_iou_coef: 0.7147 - val_loss: 0.4459 - learning_rate: 0.0010
# Epoch 58/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9049 - aggregated_jaccard_index: 0.7128 - dice_coef: 0.8286 - f1_score: 0.8302 - iou_coef: 0.7084 - loss: 0.4568
# ✅ Saved improved model at epoch 58 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9058 - aggregated_jaccard_index: 0.7105 - dice_coef: 0.8271 - f1_score: 0.8287 - iou_coef: 0.7063 - loss: 0.4615 - val_accuracy: 0.9417 - val_aggregated_jaccard_index: 0.7153 - val_dice_coef: 0.8314 - val_f1_score: 0.8318 - val_iou_coef: 0.7116 - val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 59/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9054 - aggregated_jaccard_index: 0.7077 - dice_coef: 0.8245 - f1_score: 0.8263 - iou_coef: 0.7026 - loss: 0.4661
# ✅ Saved improved model at epoch 59 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9057 - aggregated_jaccard_index: 0.7098 - dice_coef: 0.8265 - f1_score: 0.8281 - iou_coef: 0.7053 - loss: 0.4619 - val_accuracy: 0.9439 - val_aggregated_jaccard_index: 0.7186 - val_dice_coef: 0.8341 - val_f1_score: 0.8354 - val_iou_coef: 0.7155 - val_loss: 0.4458 - learning_rate: 0.0010
# Epoch 60/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9061 - aggregated_jaccard_index: 0.7127 - dice_coef: 0.8285 - f1_score: 0.8301 - iou_coef: 0.7084 - loss: 0.4572
# ✅ Saved improved model at epoch 60 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9060 - aggregated_jaccard_index: 0.7105 - dice_coef: 0.8269 - f1_score: 0.8285 - iou_coef: 0.7060 - loss: 0.4614 - val_accuracy: 0.9466 - val_aggregated_jaccard_index: 0.7240 - val_dice_coef: 0.8379 - val_f1_score: 0.8388 - val_iou_coef: 0.7211 - val_loss: 0.4367 - learning_rate: 0.0010
# Epoch 61/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9031 - aggregated_jaccard_index: 0.7091 - dice_coef: 0.8249 - f1_score: 0.8266 - iou_coef: 0.7033 - loss: 0.4641
# ✅ Saved improved model at epoch 61 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9059 - aggregated_jaccard_index: 0.7113 - dice_coef: 0.8266 - f1_score: 0.8282 - iou_coef: 0.7056 - loss: 0.4600 - val_accuracy: 0.9450 - val_aggregated_jaccard_index: 0.7188 - val_dice_coef: 0.8339 - val_f1_score: 0.8346 - val_iou_coef: 0.7153 - val_loss: 0.4458 - learning_rate: 0.0010
# Epoch 62/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9098 - aggregated_jaccard_index: 0.7129 - dice_coef: 0.8284 - f1_score: 0.8300 - iou_coef: 0.7082 - loss: 0.4568
# ✅ Saved improved model at epoch 62 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9074 - aggregated_jaccard_index: 0.7145 - dice_coef: 0.8297 - f1_score: 0.8313 - iou_coef: 0.7101 - loss: 0.4540 - val_accuracy: 0.9403 - val_aggregated_jaccard_index: 0.7134 - val_dice_coef: 0.8287 - val_f1_score: 0.8300 - val_iou_coef: 0.7078 - val_loss: 0.4554 - learning_rate: 0.0010
# Epoch 63/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9062 - aggregated_jaccard_index: 0.7150 - dice_coef: 0.8292 - f1_score: 0.8309 - iou_coef: 0.7094 - loss: 0.4534
# ✅ Saved improved model at epoch 63 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9077 - aggregated_jaccard_index: 0.7149 - dice_coef: 0.8298 - f1_score: 0.8314 - iou_coef: 0.7102 - loss: 0.4534 - val_accuracy: 0.9376 - val_aggregated_jaccard_index: 0.7053 - val_dice_coef: 0.8227 - val_f1_score: 0.8237 - val_iou_coef: 0.6991 - val_loss: 0.4693 - learning_rate: 0.0010
# Epoch 64/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9084 - aggregated_jaccard_index: 0.7174 - dice_coef: 0.8311 - f1_score: 0.8327 - iou_coef: 0.7123 - loss: 0.4494
# ✅ Saved improved model at epoch 64 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9075 - aggregated_jaccard_index: 0.7139 - dice_coef: 0.8293 - f1_score: 0.8310 - iou_coef: 0.7096 - loss: 0.4553 - val_accuracy: 0.9455 - val_aggregated_jaccard_index: 0.7181 - val_dice_coef: 0.8348 - val_f1_score: 0.8350 - val_iou_coef: 0.7165 - val_loss: 0.4464 - learning_rate: 0.0010
# Epoch 65/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9083 - aggregated_jaccard_index: 0.7144 - dice_coef: 0.8305 - f1_score: 0.8320 - iou_coef: 0.7112 - loss: 0.4541
# ✅ Saved improved model at epoch 65 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9078 - aggregated_jaccard_index: 0.7147 - dice_coef: 0.8300 - f1_score: 0.8316 - iou_coef: 0.7105 - loss: 0.4536 - val_accuracy: 0.9452 - val_aggregated_jaccard_index: 0.7220 - val_dice_coef: 0.8361 - val_f1_score: 0.8373 - val_iou_coef: 0.7185 - val_loss: 0.4402 - learning_rate: 0.0010
# Epoch 66/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9087 - aggregated_jaccard_index: 0.7143 - dice_coef: 0.8300 - f1_score: 0.8317 - iou_coef: 0.7105 - loss: 0.4542
# ✅ Saved improved model at epoch 66 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9086 - aggregated_jaccard_index: 0.7176 - dice_coef: 0.8316 - f1_score: 0.8332 - iou_coef: 0.7128 - loss: 0.4485 - val_accuracy: 0.9341 - val_aggregated_jaccard_index: 0.6944 - val_dice_coef: 0.8158 - val_f1_score: 0.8172 - val_iou_coef: 0.6891 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 67/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9082 - aggregated_jaccard_index: 0.7200 - dice_coef: 0.8334 - f1_score: 0.8349 - iou_coef: 0.7155 - loss: 0.4449
# ✅ Saved improved model at epoch 67 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9089 - aggregated_jaccard_index: 0.7175 - dice_coef: 0.8318 - f1_score: 0.8333 - iou_coef: 0.7132 - loss: 0.4486 - val_accuracy: 0.9374 - val_aggregated_jaccard_index: 0.7050 - val_dice_coef: 0.8224 - val_f1_score: 0.8232 - val_iou_coef: 0.6987 - val_loss: 0.4700 - learning_rate: 0.0010
# Epoch 68/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9096 - aggregated_jaccard_index: 0.7219 - dice_coef: 0.8338 - f1_score: 0.8353 - iou_coef: 0.7161 - loss: 0.4416
# ✅ Saved improved model at epoch 68 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9092 - aggregated_jaccard_index: 0.7191 - dice_coef: 0.8326 - f1_score: 0.8340 - iou_coef: 0.7142 - loss: 0.4464 - val_accuracy: 0.9446 - val_aggregated_jaccard_index: 0.7020 - val_dice_coef: 0.8261 - val_f1_score: 0.8267 - val_iou_coef: 0.7038 - val_loss: 0.4726 - learning_rate: 0.0010
# Epoch 69/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9100 - aggregated_jaccard_index: 0.7210 - dice_coef: 0.8341 - f1_score: 0.8356 - iou_coef: 0.7165 - loss: 0.4432
# ✅ Saved improved model at epoch 69 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9097 - aggregated_jaccard_index: 0.7202 - dice_coef: 0.8340 - f1_score: 0.8355 - iou_coef: 0.7163 - loss: 0.4442 - val_accuracy: 0.9468 - val_aggregated_jaccard_index: 0.7251 - val_dice_coef: 0.8379 - val_f1_score: 0.8380 - val_iou_coef: 0.7211 - val_loss: 0.4352 - learning_rate: 0.0010
# Epoch 70/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9073 - aggregated_jaccard_index: 0.7213 - dice_coef: 0.8342 - f1_score: 0.8356 - iou_coef: 0.7167 - loss: 0.4427
# ✅ Saved improved model at epoch 70 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9091 - aggregated_jaccard_index: 0.7190 - dice_coef: 0.8328 - f1_score: 0.8343 - iou_coef: 0.7146 - loss: 0.4464 - val_accuracy: 0.9395 - val_aggregated_jaccard_index: 0.7095 - val_dice_coef: 0.8277 - val_f1_score: 0.8285 - val_iou_coef: 0.7062 - val_loss: 0.4610 - learning_rate: 0.0010
# Epoch 71/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9125 - aggregated_jaccard_index: 0.7215 - dice_coef: 0.8345 - f1_score: 0.8361 - iou_coef: 0.7170 - loss: 0.4422
# ✅ Saved improved model at epoch 71 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9096 - aggregated_jaccard_index: 0.7198 - dice_coef: 0.8335 - f1_score: 0.8349 - iou_coef: 0.7156 - loss: 0.4453 - val_accuracy: 0.9350 - val_aggregated_jaccard_index: 0.6944 - val_dice_coef: 0.8163 - val_f1_score: 0.8179 - val_iou_coef: 0.6899 - val_loss: 0.4872 - learning_rate: 0.0010
# Epoch 72/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9097 - aggregated_jaccard_index: 0.7200 - dice_coef: 0.8335 - f1_score: 0.8350 - iou_coef: 0.7157 - loss: 0.4452
# ✅ Saved improved model at epoch 72 with val_iou=0.0000
# ...
# Epoch 124/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9178 - aggregated_jaccard_index: 0.7462 - dice_coef: 0.8519 - f1_score: 0.8527 - iou_coef: 0.7430 - loss: 0.4009
# ✅ Saved improved model at epoch 124 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9187 - aggregated_jaccard_index: 0.7436 - dice_coef: 0.8505 - f1_score: 0.8514 - iou_coef: 0.7409 - loss: 0.4050 - val_accuracy: 0.9457 - val_aggregated_jaccard_index: 0.7223 - val_dice_coef: 0.8360 - val_f1_score: 0.8367 - val_iou_coef: 0.7183 - val_loss: 0.4404 - learning_rate: 0.0010
# Epoch 125/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9181 - aggregated_jaccard_index: 0.7417 - dice_coef: 0.8492 - f1_score: 0.8502 - iou_coef: 0.7390 - loss: 0.4083
# ✅ Saved improved model at epoch 125 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9192 - aggregated_jaccard_index: 0.7455 - dice_coef: 0.8513 - f1_score: 0.8522 - iou_coef: 0.7422 - loss: 0.4017 - val_accuracy: 0.9435 - val_aggregated_jaccard_index: 0.7192 - val_dice_coef: 0.8329 - val_f1_score: 0.8331 - val_iou_coef: 0.7139 - val_loss: 0.4458 - learning_rate: 0.0010
# Epoch 126/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9190 - aggregated_jaccard_index: 0.7441 - dice_coef: 0.8505 - f1_score: 0.8514 - iou_coef: 0.7409 - loss: 0.4042
# ✅ Saved improved model at epoch 126 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9194 - aggregated_jaccard_index: 0.7460 - dice_coef: 0.8518 - f1_score: 0.8527 - iou_coef: 0.7429 - loss: 0.4012 - val_accuracy: 0.9400 - val_aggregated_jaccard_index: 0.7103 - val_dice_coef: 0.8260 - val_f1_score: 0.8261 - val_iou_coef: 0.7039 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 127/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9210 - aggregated_jaccard_index: 0.7472 - dice_coef: 0.8526 - f1_score: 0.8535 - iou_coef: 0.7442 - loss: 0.3994
# ✅ Saved improved model at epoch 127 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9196 - aggregated_jaccard_index: 0.7468 - dice_coef: 0.8522 - f1_score: 0.8531 - iou_coef: 0.7435 - loss: 0.3998 - val_accuracy: 0.9421 - val_aggregated_jaccard_index: 0.7115 - val_dice_coef: 0.8288 - val_f1_score: 0.8291 - val_iou_coef: 0.7078 - val_loss: 0.4583 - learning_rate: 0.0010
# Epoch 128/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9217 - aggregated_jaccard_index: 0.7518 - dice_coef: 0.8545 - f1_score: 0.8554 - iou_coef: 0.7470 - loss: 0.3917
# ✅ Saved improved model at epoch 128 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9199 - aggregated_jaccard_index: 0.7478 - dice_coef: 0.8523 - f1_score: 0.8532 - iou_coef: 0.7437 - loss: 0.3980 - val_accuracy: 0.9350 - val_aggregated_jaccard_index: 0.6979 - val_dice_coef: 0.8163 - val_f1_score: 0.8170 - val_iou_coef: 0.6902 - val_loss: 0.4828 - learning_rate: 0.0010
# Epoch 129/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9184 - aggregated_jaccard_index: 0.7488 - dice_coef: 0.8537 - f1_score: 0.8545 - iou_coef: 0.7457 - loss: 0.3967
# ✅ Saved improved model at epoch 129 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9199 - aggregated_jaccard_index: 0.7469 - dice_coef: 0.8528 - f1_score: 0.8537 - iou_coef: 0.7445 - loss: 0.3994 - val_accuracy: 0.9392 - val_aggregated_jaccard_index: 0.7064 - val_dice_coef: 0.8253 - val_f1_score: 0.8258 - val_iou_coef: 0.7027 - val_loss: 0.4664 - learning_rate: 0.0010
# Epoch 130/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9224 - aggregated_jaccard_index: 0.7501 - dice_coef: 0.8548 - f1_score: 0.8557 - iou_coef: 0.7475 - loss: 0.3942
# ✅ Saved improved model at epoch 130 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9203 - aggregated_jaccard_index: 0.7492 - dice_coef: 0.8536 - f1_score: 0.8545 - iou_coef: 0.7457 - loss: 0.3961 - val_accuracy: 0.9431 - val_aggregated_jaccard_index: 0.7155 - val_dice_coef: 0.8317 - val_f1_score: 0.8322 - val_iou_coef: 0.7120 - val_loss: 0.4511 - learning_rate: 0.0010
# Epoch 131/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9212 - aggregated_jaccard_index: 0.7521 - dice_coef: 0.8553 - f1_score: 0.8561 - iou_coef: 0.7482 - loss: 0.3912
# ✅ Saved improved model at epoch 131 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9197 - aggregated_jaccard_index: 0.7476 - dice_coef: 0.8525 - f1_score: 0.8533 - iou_coef: 0.7440 - loss: 0.3986 - val_accuracy: 0.9426 - val_aggregated_jaccard_index: 0.7155 - val_dice_coef: 0.8304 - val_f1_score: 0.8306 - val_iou_coef: 0.7102 - val_loss: 0.4522 - learning_rate: 0.0010
# Epoch 132/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9230 - aggregated_jaccard_index: 0.7520 - dice_coef: 0.8555 - f1_score: 0.8563 - iou_coef: 0.7484 - loss: 0.3912
# ✅ Saved improved model at epoch 132 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9201 - aggregated_jaccard_index: 0.7478 - dice_coef: 0.8528 - f1_score: 0.8536 - iou_coef: 0.7444 - loss: 0.3983 - val_accuracy: 0.9432 - val_aggregated_jaccard_index: 0.7112 - val_dice_coef: 0.8291 - val_f1_score: 0.8297 - val_iou_coef: 0.7082 - val_loss: 0.4587 - learning_rate: 0.0010
# Epoch 133/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9191 - aggregated_jaccard_index: 0.7470 - dice_coef: 0.8526 - f1_score: 0.8534 - iou_coef: 0.7441 - loss: 0.3995
# ✅ Saved improved model at epoch 133 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - accuracy: 0.9198 - aggregated_jaccard_index: 0.7477 - dice_coef: 0.8526 - f1_score: 0.8534 - iou_coef: 0.7442 - loss: 0.3984 - val_accuracy: 0.9427 - val_aggregated_jaccard_index: 0.7171 - val_dice_coef: 0.8323 - val_f1_score: 0.8328 - val_iou_coef: 0.7130 - val_loss: 0.4487 - learning_rate: 0.0010
# Epoch 134/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9206 - aggregated_jaccard_index: 0.7469 - dice_coef: 0.8519 - f1_score: 0.8528 - iou_coef: 0.7431 - loss: 0.3999
# ✅ Saved improved model at epoch 134 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9205 - aggregated_jaccard_index: 0.7490 - dice_coef: 0.8536 - f1_score: 0.8545 - iou_coef: 0.7457 - loss: 0.3963 - val_accuracy: 0.9425 - val_aggregated_jaccard_index: 0.7169 - val_dice_coef: 0.8317 - val_f1_score: 0.8316 - val_iou_coef: 0.7120 - val_loss: 0.4492 - learning_rate: 0.0010
# Epoch 135/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9175 - aggregated_jaccard_index: 0.7475 - dice_coef: 0.8521 - f1_score: 0.8529 - iou_coef: 0.7433 - loss: 0.3987
# ✅ Saved improved model at epoch 135 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9201 - aggregated_jaccard_index: 0.7485 - dice_coef: 0.8535 - f1_score: 0.8543 - iou_coef: 0.7454 - loss: 0.3973 - val_accuracy: 0.9447 - val_aggregated_jaccard_index: 0.7180 - val_dice_coef: 0.8345 - val_f1_score: 0.8346 - val_iou_coef: 0.7161 - val_loss: 0.4465 - learning_rate: 0.0010
# Epoch 136/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9185 - aggregated_jaccard_index: 0.7478 - dice_coef: 0.8524 - f1_score: 0.8533 - iou_coef: 0.7439 - loss: 0.3985
# ✅ Saved improved model at epoch 136 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9209 - aggregated_jaccard_index: 0.7504 - dice_coef: 0.8547 - f1_score: 0.8555 - iou_coef: 0.7473 - loss: 0.3941 - val_accuracy: 0.9433 - val_aggregated_jaccard_index: 0.7163 - val_dice_coef: 0.8317 - val_f1_score: 0.8316 - val_iou_coef: 0.7120 - val_loss: 0.4505 - learning_rate: 0.0010
# Epoch 137/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9203 - aggregated_jaccard_index: 0.7482 - dice_coef: 0.8540 - f1_score: 0.8548 - iou_coef: 0.7461 - loss: 0.3973
# ✅ Saved improved model at epoch 137 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9207 - aggregated_jaccard_index: 0.7495 - dice_coef: 0.8545 - f1_score: 0.8553 - iou_coef: 0.7470 - loss: 0.3959 - val_accuracy: 0.9420 - val_aggregated_jaccard_index: 0.7125 - val_dice_coef: 0.8292 - val_f1_score: 0.8292 - val_iou_coef: 0.7084 - val_loss: 0.4566 - learning_rate: 0.0010
# Epoch 138/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9212 - aggregated_jaccard_index: 0.7507 - dice_coef: 0.8545 - f1_score: 0.8553 - iou_coef: 0.7469 - loss: 0.3934
# ✅ Saved improved model at epoch 138 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9211 - aggregated_jaccard_index: 0.7506 - dice_coef: 0.8546 - f1_score: 0.8554 - iou_coef: 0.7472 - loss: 0.3934 - val_accuracy: 0.9379 - val_aggregated_jaccard_index: 0.7014 - val_dice_coef: 0.8216 - val_f1_score: 0.8221 - val_iou_coef: 0.6973 - val_loss: 0.4750 - learning_rate: 0.0010
# Epoch 139/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9221 - aggregated_jaccard_index: 0.7511 - dice_coef: 0.8552 - f1_score: 0.8559 - iou_coef: 0.7479 - loss: 0.3928
# ✅ Saved improved model at epoch 139 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9207 - aggregated_jaccard_index: 0.7501 - dice_coef: 0.8544 - f1_score: 0.8552 - iou_coef: 0.7468 - loss: 0.3945 - val_accuracy: 0.9377 - val_aggregated_jaccard_index: 0.7021 - val_dice_coef: 0.8221 - val_f1_score: 0.8226 - val_iou_coef: 0.6981 - val_loss: 0.4738 - learning_rate: 0.0010
# Epoch 140/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9221 - aggregated_jaccard_index: 0.7554 - dice_coef: 0.8574 - f1_score: 0.8582 - iou_coef: 0.7515 - loss: 0.3858
# ✅ Saved improved model at epoch 140 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9212 - aggregated_jaccard_index: 0.7515 - dice_coef: 0.8551 - f1_score: 0.8559 - iou_coef: 0.7480 - loss: 0.3923 - val_accuracy: 0.9431 - val_aggregated_jaccard_index: 0.7148 - val_dice_coef: 0.8306 - val_f1_score: 0.8308 - val_iou_coef: 0.7104 - val_loss: 0.4529 - learning_rate: 0.0010
# Epoch 141/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9189 - aggregated_jaccard_index: 0.7509 - dice_coef: 0.8547 - f1_score: 0.8555 - iou_coef: 0.7474 - loss: 0.3932
# ✅ Saved improved model at epoch 141 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9210 - aggregated_jaccard_index: 0.7503 - dice_coef: 0.8549 - f1_score: 0.8557 - iou_coef: 0.7476 - loss: 0.3940 - val_accuracy: 0.9448 - val_aggregated_jaccard_index: 0.7184 - val_dice_coef: 0.8330 - val_f1_score: 0.8339 - val_iou_coef: 0.7140 - val_loss: 0.4471 - learning_rate: 0.0010
# Epoch 142/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9219 - aggregated_jaccard_index: 0.7485 - dice_coef: 0.8531 - f1_score: 0.8539 - iou_coef: 0.7450 - loss: 0.3971
# ✅ Saved improved model at epoch 142 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 8s 53ms/step - accuracy: 0.9208 - aggregated_jaccard_index: 0.7497 - dice_coef: 0.8539 - f1_score: 0.8547 - iou_coef: 0.7462 - loss: 0.3942 - val_accuracy: 0.9416 - val_aggregated_jaccard_index: 0.7127 - val_dice_coef: 0.8286 - val_f1_score: 0.8290 - val_iou_coef: 0.7075 - val_loss: 0.4568 - learning_rate: 0.0010
# Epoch 143/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9218 - aggregated_jaccard_index: 0.7486 - dice_coef: 0.8536 - f1_score: 0.8545 - iou_coef: 0.7456 - loss: 0.3966
# ✅ Saved improved model at epoch 143 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9209 - aggregated_jaccard_index: 0.7505 - dice_coef: 0.8546 - f1_score: 0.8554 - iou_coef: 0.7472 - loss: 0.3935 - val_accuracy: 0.9416 - val_aggregated_jaccard_index: 0.7132 - val_dice_coef: 0.8292 - val_f1_score: 0.8296 - val_iou_coef: 0.7084 - val_loss: 0.4558 - learning_rate: 0.0010
# Epoch 144/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9225 - aggregated_jaccard_index: 0.7556 - dice_coef: 0.8572 - f1_score: 0.8580 - iou_coef: 0.7511 - loss: 0.3854
# ✅ Saved improved model at epoch 144 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9214 - aggregated_jaccard_index: 0.7520 - dice_coef: 0.8554 - f1_score: 0.8561 - iou_coef: 0.7483 - loss: 0.3914 - val_accuracy: 0.9434 - val_aggregated_jaccard_index: 0.7119 - val_dice_coef: 0.8294 - val_f1_score: 0.8297 - val_iou_coef: 0.7086 - val_loss: 0.4575 - learning_rate: 0.0010
# Epoch 145/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9242 - aggregated_jaccard_index: 0.7550 - dice_coef: 0.8574 - f1_score: 0.8583 - iou_coef: 0.7515 - loss: 0.3865
# ✅ Saved improved model at epoch 145 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9212 - aggregated_jaccard_index: 0.7519 - dice_coef: 0.8552 - f1_score: 0.8560 - iou_coef: 0.7481 - loss: 0.3917 - val_accuracy: 0.9396 - val_aggregated_jaccard_index: 0.7079 - val_dice_coef: 0.8255 - val_f1_score: 0.8261 - val_iou_coef: 0.7030 - val_loss: 0.4644 - learning_rate: 0.0010
# Epoch 146/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9236 - aggregated_jaccard_index: 0.7490 - dice_coef: 0.8539 - f1_score: 0.8548 - iou_coef: 0.7462 - loss: 0.3962
# ✅ Saved improved model at epoch 146 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9212 - aggregated_jaccard_index: 0.7508 - dice_coef: 0.8550 - f1_score: 0.8558 - iou_coef: 0.7478 - loss: 0.3937 - val_accuracy: 0.9399 - val_aggregated_jaccard_index: 0.7102 - val_dice_coef: 0.8259 - val_f1_score: 0.8259 - val_iou_coef: 0.7037 - val_loss: 0.4613 - learning_rate: 0.0010
# Epoch 147/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9211 - aggregated_jaccard_index: 0.7501 - dice_coef: 0.8542 - f1_score: 0.8551 - iou_coef: 0.7467 - loss: 0.3943
# ✅ Saved improved model at epoch 147 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9210 - aggregated_jaccard_index: 0.7507 - dice_coef: 0.8548 - f1_score: 0.8556 - iou_coef: 0.7475 - loss: 0.3931 - val_accuracy: 0.9432 - val_aggregated_jaccard_index: 0.7180 - val_dice_coef: 0.8311 - val_f1_score: 0.8316 - val_iou_coef: 0.7114 - val_loss: 0.4487 - learning_rate: 0.0010
# Epoch 148/150
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9220 - aggregated_jaccard_index: 0.7500 - dice_coef: 0.8547 - f1_score: 0.8554 - iou_coef: 0.7473 - loss: 0.3947
# ✅ Saved improved model at epoch 148 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9211 - aggregated_jaccard_index: 0.7512 - dice_coef: 0.8554 - f1_score: 0.8561 - iou_coef: 0.7483 - loss: 0.3930 - val_accuracy: 0.9450 - val_aggregated_jaccard_index: 0.7115 - val_dice_coef: 0.8310 - val_f1_score: 0.8314 - val_iou_coef: 0.7109 - val_loss: 0.4573 - learning_rate: 0.0010
# Epoch 149/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9221 - aggregated_jaccard_index: 0.7568 - dice_coef: 0.8587 - f1_score: 0.8595 - iou_coef: 0.7535 - loss: 0.3835
# ✅ Saved improved model at epoch 149 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9218 - aggregated_jaccard_index: 0.7539 - dice_coef: 0.8565 - f1_score: 0.8572 - iou_coef: 0.7500 - loss: 0.3885 - val_accuracy: 0.9439 - val_aggregated_jaccard_index: 0.7112 - val_dice_coef: 0.8297 - val_f1_score: 0.8302 - val_iou_coef: 0.7090 - val_loss: 0.4583 - learning_rate: 0.0010
# Epoch 150/150
# 87/88 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9223 - aggregated_jaccard_index: 0.7524 - dice_coef: 0.8563 - f1_score: 0.8570 - iou_coef: 0.7497 - loss: 0.3906
# ✅ Saved improved model at epoch 150 with val_iou=0.0000
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.9215 - aggregated_jaccard_index: 0.7519 - dice_coef: 0.8557 - f1_score: 0.8565 - iou_coef: 0.7489 - loss: 0.3913 - val_accuracy: 0.9465 - val_aggregated_jaccard_index: 0.7190 - val_dice_coef: 0.8354 - val_f1_score: 0.8358 - val_iou_coef: 0.7174 - val_loss: 0.4448 - learning_rate: 0.0010
#
# 🎯 Training complete. Model saved and ready for inference.

# %%
###### from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# -----------------------------
# CONFIG
# -----------------------------
IMG_DIR = "/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/MoNuSeg_2025_Testing/images"
MSK_DIR = "/kaggle/input/datasets/kartikmaity/tnbcmonusegcpm17kumarcryonuseg-augmentation-datase/MONUSEG_DATA/MONUSEG_DATA/MoNuSeg_2025_Testing/masks"
img_size = 256
batch_size = 31

# -----------------------------
# COLLECT PATHS (SAFE)
# -----------------------------
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted(
    [p for p in glob(os.path.join(IMG_DIR, "*")) if valid_name(p)]
)

mask_paths = sorted(
    [p for p in glob(os.path.join(MSK_DIR, "*")) if valid_name(p)]
)

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# -----------------------------
# SAFETY CHECK (CRITICAL)
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

assert [stem(p) for p in image_paths] == [stem(p) for p in mask_paths], \
    "❌ Image–mask filename mismatch"

# -----------------------------
# NUMPY LOADER
# -----------------------------
def _load_numpy(img_path, mask_path):
    img_path = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    img = Image.open(img_path).convert("RGB").resize(
        (img_size, img_size), Image.BILINEAR
    )

    mask = Image.open(mask_path).convert("L").resize(
        (img_size, img_size), Image.NEAREST
    )

    img = np.array(img, dtype=np.float32) / 255.0
    mask = (np.array(mask) > 127.5).astype(np.float32)[..., None]

    return img, mask

# -----------------------------
# TF WRAPPER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASET
# -----------------------------
test_dataset = (
    tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    .map(load_image_mask, num_parallel_calls=tf.data.AUTOTUNE)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Validation batches:", tf.data.experimental.cardinality(test_dataset).numpy())
# Out:
# Images found: 14
# Masks found : 14
# Validation batches: 1

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import label2rgb
from tensorflow.keras.optimizers import AdamW
import os

# ---------------------------------------------------------
# 1️⃣ Import custom layers and metrics (must match training)
# ---------------------------------------------------------
custom_objects = {
    "IoUMetric": IoUMetric,
    "DiceMetric": DiceMetric,
    "F1Metric": F1Metric,
    "AJIMetric": AJIMetric,
    "dice_iou_loss": dice_iou_loss # Make sure to include our custom loss here!
}

# ---------------------------------------------------------
# 2️⃣ Load model
# ---------------------------------------------------------
# Using Kaggle's working directory. Adjust if you saved it elsewhere.
model_path = "/kaggle/working/normal_unet.keras" if os.path.exists("/kaggle/working/") else "./normal_unet.keras"

model = tf.keras.models.load_model(
    model_path,
    custom_objects=custom_objects,
    compile=False, 
    safe_mode=False
)

# Optional: compile with metrics for evaluation
model.compile(
    optimizer=AdamW(1e-4),
    loss=dice_iou_loss,
    metrics=[IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()]
)

# ---------------------------------------------------------
# 3️⃣ Inference + Save Visualizations
# ---------------------------------------------------------
save_dir = "/kaggle/working/results" if os.path.exists("/kaggle/working/") else "./results"
os.makedirs(save_dir, exist_ok=True)

sample_idx = 0  # global counter for filenames

for batch_idx, (images, masks) in enumerate(test_dataset):
    # Model forward pass - standard UNet returns only y_pred
    y_pred = model(images, training=False)

    preds_bin = tf.cast(y_pred > 0.5, tf.float32)
    batch_size = images.shape[0]

    # Convert masks
    if len(masks.shape) == 4 and masks.shape[-1] > 1:
        masks_label = tf.argmax(masks, axis=-1)
    else:
        masks_label = tf.squeeze(masks, axis=-1)

    if preds_bin.shape[-1] > 1:
        preds_label = tf.argmax(preds_bin, axis=-1)
    else:
        preds_label = tf.squeeze(preds_bin, axis=-1)

    # -------------------------
    # Save all samples in batch
    # -------------------------
    for i in range(batch_size):
        sample_idx += 1  # keep global sample numbering

        # 3 subplots since we removed center/boundary maps
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))

        img_np = images[i].numpy()
        pred_np = preds_label[i].numpy()
        mask_np = masks_label[i].numpy()

        # 1️⃣ Original image
        axes[0].imshow(img_np)
        axes[0].set_title("Original Image")
        axes[0].axis("off")

        # 2️⃣ Predicted segmentation
        axes[1].imshow(label2rgb(pred_np, bg_label=0))
        axes[1].set_title("Predicted Segmentation")
        axes[1].axis("off")

        # 3️⃣ Ground truth
        axes[2].imshow(label2rgb(mask_np, bg_label=0))
        axes[2].set_title("Ground Truth")
        axes[2].axis("off")

        plt.tight_layout()

        save_path = os.path.join(save_dir, f"sample_{sample_idx:04d}.png")
        plt.savefig(save_path, dpi=150, bbox_inches="tight")
        plt.close(fig)

        print(f"✅ Saved {save_path}")

print(f"\n🎯 All {sample_idx} test images processed and saved to '{save_dir}'")
# Out:
# ✅ Saved /kaggle/working/results/sample_0001.png
# ✅ Saved /kaggle/working/results/sample_0002.png
# ✅ Saved /kaggle/working/results/sample_0003.png
# ✅ Saved /kaggle/working/results/sample_0004.png
# ✅ Saved /kaggle/working/results/sample_0005.png
# ✅ Saved /kaggle/working/results/sample_0006.png
# ✅ Saved /kaggle/working/results/sample_0007.png
# ✅ Saved /kaggle/working/results/sample_0008.png
# ✅ Saved /kaggle/working/results/sample_0009.png
# ✅ Saved /kaggle/working/results/sample_0010.png
# ✅ Saved /kaggle/working/results/sample_0011.png
# ✅ Saved /kaggle/working/results/sample_0012.png
# ✅ Saved /kaggle/working/results/sample_0013.png
# ✅ Saved /kaggle/working/results/sample_0014.png
#
# 🎯 All 14 test images processed and saved to '/kaggle/working/results'

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# 2026-09-18 08:58:11.280054: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-09-18 08:58:11.516987: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# ===== Segmentation Evaluation =====
# Mean IoU:              0.6336
# Mean Dice Coefficient: 0.7748
# Mean AJI:              0.6332
# Mean Accuracy:         0.9009
# Mean F1 Score:         0.7746
