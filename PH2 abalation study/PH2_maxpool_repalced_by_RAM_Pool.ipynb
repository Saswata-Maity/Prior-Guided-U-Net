# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# 2026-09-20 08:53:01.457029: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-09-20 08:53:01.477347: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-09-20 08:53:01.477378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-09-20 08:53:01.478088: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-09-20 08:53:01.482383: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-09-20 08:53:02.029009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# TF: 2.15.1
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# 2026-09-20 08:53:02.888198: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:02.927875: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:02.927909: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.

# %%
import tensorflow as tf
from tensorflow.keras import layers

@tf.keras.utils.register_keras_serializable(package="Custom")
class RadialWaveEvolutionaryConv(layers.Layer):

    def __init__(self,
                 num_patches=4,
                 num_feature_maps=32,
                 kernel_size=3,
                 **kwargs):
        super().__init__(**kwargs)
        self.num_patches = num_patches
        self.num_feature_maps = num_feature_maps
        self.kernel_size = kernel_size

    def build(self, input_shape):

        _, H, W, C = input_shape

        self.H = H
        self.W = W

        self.patch_h = H // self.num_patches
        self.patch_w = W // self.num_patches

        # Decision projection
        self.decision_filters = self.add_weight(
            shape=(C, self.num_feature_maps),
            initializer=tf.keras.initializers.GlorotNormal(),
            trainable=True,
            name="decision_space_filters"
        )

        # Convolution kernel
        self.gaussian_kernel = self.add_weight(
            shape=(self.kernel_size,
                   self.kernel_size,
                   C,
                   self.num_feature_maps),
            initializer=tf.keras.initializers.HeNormal(),
            trainable=True,
            name="gaussian_mutation_kernel"
        )

        # Learnable sigma (no user input)
        self.sigma = self.add_weight(
            shape=(),
            initializer=tf.keras.initializers.Constant(0.1),
            trainable=True,
            name="wave_sigma"
        )

        super().build(input_shape)

    # --------------------------------------------------
    # Pareto (tanh, batch-safe)
    # --------------------------------------------------
    def soft_pareto_score(self, objectives):
        # [B, N, M]

        f_i = tf.expand_dims(objectives, axis=2)  # [B, N, 1, M]
        f_j = tf.expand_dims(objectives, axis=1)  # [B, 1, N, M]

        domination = 0.5 * (1.0 + tf.nn.tanh(f_j - f_i))

        domination = tf.clip_by_value(domination, 1e-6, 1.0)

        domination_prod = tf.reduce_prod(domination, axis=-1)  # [B, N, N]

        score = tf.reduce_sum(domination_prod, axis=-1)  # [B, N]

        return score

    # --------------------------------------------------
    # Call
    # --------------------------------------------------
    def call(self, inputs):

        B = tf.shape(inputs)[0]
        C = tf.shape(inputs)[-1]

        # Patch extraction
        patches = tf.image.extract_patches(
            images=inputs,
            sizes=[1, self.patch_h, self.patch_w, 1],
            strides=[1, self.patch_h, self.patch_w, 1],
            rates=[1, 1, 1, 1],
            padding="VALID"
        )

        num_total_patches = self.num_patches * self.num_patches
        patch_area = self.patch_h * self.patch_w

        patches = tf.reshape(
            patches,
            [B, num_total_patches, patch_area, C]
        )

        patches_mean = tf.reduce_mean(patches, axis=2)  # [B, N, C]

        # Objectives
        objectives = tf.matmul(patches_mean, self.decision_filters)  # [B, N, M]

        # Pareto
        pareto_score = self.soft_pareto_score(objectives)

        weights = tf.nn.softmax(-pareto_score, axis=-1)
        weights = tf.expand_dims(weights, -1)

        weighted_objectives = objectives * weights

        # Radial wave
        center = tf.reduce_mean(weighted_objectives, axis=1, keepdims=True)

        radial_distance = tf.norm(weighted_objectives - center, axis=-1)

        sigma = tf.nn.softplus(self.sigma) + 1e-6

        wave = tf.math.special.bessel_j0(radial_distance)
        decay = tf.exp(- (radial_distance ** 2) / (2.0 * sigma ** 2))

        wave = wave * decay  # [B, N]

        # Expand to spatial
        wave = tf.reshape(wave, [B, self.num_patches, self.num_patches, 1])

        wave = tf.image.resize(
            wave,
            size=(self.H, self.W),
            method="nearest"
        )

        # Convolution
        conv_out = tf.nn.conv2d(
            inputs,
            self.gaussian_kernel,
            strides=1,
            padding="SAME"
        )

        return conv_out * wave

    def get_config(self):
        config = super().get_config()
        config.update({
            "num_patches": self.num_patches,
            "num_feature_maps": self.num_feature_maps,
            "kernel_size": self.kernel_size
        })
        return config

# %%
def conv_block(x,
               filters,
               kernel_size=3,
               activation="tanh",
               padding="same",
               decoder=False,
               num_patches=4,
               overlap_ratio=0.02,
               use_overlap=False,
               dilation_rate=2):
        x1 = RadialWaveEvolutionaryConv(
            num_patches=num_patches,
            num_feature_maps=filters,
            kernel_size=kernel_size
        )(x)

        x1 = layers.BatchNormalization()(x1)
        x1 = layers.Activation(activation)(x1)

        return x1

# %%
import tensorflow as tf
from tensorflow.keras import layers

# ---------------------------------------------------------
# Geodesic Kernel Downsampler
# ---------------------------------------------------------

@tf.keras.utils.register_keras_serializable(package="Custom")
class GeodesicDownsample2D(layers.Layer):
    """
    Riemannian geodesic pooling via iterative intrinsic mean computation
    with a learnable diagonal metric and configurable robust weighting
    kernels (Huber, Tukey, Cauchy, Geman-McClure).
    """

    def __init__(
        self,
        pool_size=2,
        geo_iters=3,
        geo_temp=1.0,
        robust_kernel="huber",
        tukey_c=4.685,
        huber_delta=1.0,
        cauchy_alpha=1.0,
        geman_lambda=1.0,
        **kwargs
    ):
        super().__init__(**kwargs)
        self.pool_size = pool_size
        self.geo_iters = geo_iters
        self.geo_temp = geo_temp
        self.robust_kernel = robust_kernel.lower()

        # kernel params
        self.huber_delta = huber_delta
        self.tukey_c = tukey_c
        self.cauchy_alpha = cauchy_alpha
        self.geman_lambda = geman_lambda

    def build(self, input_shape):
        c = input_shape[-1]
        self.metric_raw = self.add_weight(
            shape=(c,),
            initializer=tf.keras.initializers.Constant(1.0),
            trainable=True,
            name="metric_diag_unconstrained"
        )
        super().build(input_shape)

    # ---------------- robust weighting functions ----------------
    def _robust_weights(self, dist_sq):
        eps = 1e-9

        if self.robust_kernel == "huber":
            delta = self.huber_delta
            mask = dist_sq <= delta**2
            w_quad = 1.0
            w_lin = delta / (tf.sqrt(dist_sq) + eps)
            return tf.where(mask, w_quad, w_lin)

        if self.robust_kernel == "tukey":
            c = self.tukey_c
            mask = dist_sq <= c**2
            z = dist_sq / (c**2 + eps)
            w = (1 - z)**2
            return tf.where(mask, w, tf.zeros_like(dist_sq))

        if self.robust_kernel == "cauchy":
            a = self.cauchy_alpha
            return 1.0 / (1.0 + dist_sq / (a**2) + eps)

        if self.robust_kernel == "geman":
            lam = self.geman_lambda
            return 1.0 / ((1.0 + dist_sq / (lam + eps))**2)

        return tf.nn.softmax(-dist_sq, axis=-1)

    # ---------------- main pooling routine ----------------
    def call(self, x):
        if isinstance(self.pool_size, int):
            ph = pw = self.pool_size
        else:
            ph, pw = self.pool_size

        b, h, w, c = tf.unstack(tf.shape(x))
        pad_h = tf.math.floormod(-h, ph)
        pad_w = tf.math.floormod(-w, pw)
        x_pad = tf.pad(x, [[0,0],[0,pad_h],[0,pad_w],[0,0]])

        Hp = tf.shape(x_pad)[1] // ph
        Wp = tf.shape(x_pad)[2] // pw

        ksizes = [1, ph, pw, 1]
        strides = [1, ph, pw, 1]
        patches = tf.image.extract_patches(
            images=x_pad,
            sizes=ksizes,
            strides=strides,
            rates=[1,1,1,1],
            padding="VALID"
        )

        P = ph * pw
        patches = tf.reshape(patches, [b, Hp, Wp, P, c])

        metric = tf.nn.softplus(self.metric_raw) + 1e-6
        mean = tf.reduce_mean(patches, axis=3)

        for _ in range(self.geo_iters):
            diff = patches - tf.expand_dims(mean, axis=3)
            dist_sq = tf.reduce_sum(diff * diff * tf.reshape(metric, [1,1,1,1,c]), axis=-1)
            w = self._robust_weights(dist_sq)
            w = tf.nn.softmax(w / self.geo_temp, axis=-1)
            w = tf.expand_dims(w, axis=-1)
            mean = tf.reduce_sum(patches * w, axis=3)

        return mean

    def get_config(self):
        base = super().get_config()
        base.update({
            "pool_size": self.pool_size,
            "geo_iters": self.geo_iters,
            "geo_temp": self.geo_temp,
            "robust_kernel": self.robust_kernel,
            "tukey_c": self.tukey_c,
            "huber_delta": self.huber_delta,
            "cauchy_alpha": self.cauchy_alpha,
            "geman_lambda": self.geman_lambda
        })
        return base

# %%
def build_prior_guided_unet(input_shape=(256, 256, 3), base_filters=64, num_classes=1):
    inputs = layers.Input(shape=input_shape)

    # ===================== Encoder =====================

    # -------- Level 1 --------
    f1 = conv_block(inputs, base_filters)
    s1 = GeodesicDownsample2D()(f1)

    p1 = layers.Dropout(0.05)(s1)
    p1 = layers.GaussianDropout(0.1)(p1)

    # -------- Level 2 --------
    f2 = conv_block(p1, base_filters * 2)
    s2 = GeodesicDownsample2D()(f2)

    p2 = layers.Dropout(0.15)(s2)
    p2 = layers.GaussianDropout(0.2)(p2)

    # -------- Level 3 --------
    f3 = conv_block(p2, base_filters * 4)
    s3 = GeodesicDownsample2D()(f3)

    p3 = layers.Dropout(0.2)(s3)

    # -------- Level 4 --------
    f4 = conv_block(p3, base_filters * 8)
    s4 = GeodesicDownsample2D()(f4)

    p4 = layers.Dropout(0.25)(s4)
    p4 = layers.GaussianDropout(0.2)(p4)

    # -------- Bottleneck --------
    f5 = conv_block(p4, base_filters * 12)
    f5 = layers.SpatialDropout2D(0.2)(f5)
    f5 = layers.GaussianDropout(0.1)(f5)

    # -------- Up 4 --------
    d4 = layers.UpSampling2D(size=2, interpolation="bilinear")(f5)
    d4 = layers.Dropout(0.05)(d4)
    d4 = layers.GaussianDropout(0.18)(d4)
    d4 = conv_block(d4, base_filters * 8, decoder=True)
    d4 = layers.Add()([f4, d4])

    # -------- Up 3 --------
    d3 = layers.UpSampling2D(size=2, interpolation="bilinear")(d4)
    d3 = layers.GaussianDropout(0.18)(d3)
    d3 = layers.Dropout(0.1)(d3)
    d3 = conv_block(d3, base_filters * 4, decoder=True)
    d3 = layers.Add()([f3, d3])

    # -------- Up 2 --------
    d2 = layers.UpSampling2D(size=2, interpolation="bilinear")(d3)
    d2 = conv_block(d2, base_filters * 2, decoder=True)
    d2 = layers.Dropout(0.22)(d2)
    d2 = layers.Add()([f2, d2])

    # -------- Up 1 --------
    d1 = layers.UpSampling2D(size=2, interpolation="bilinear")(d2)
    d1 = conv_block(d1, base_filters, decoder=True)
    d1 = layers.Dropout(0.24)(d1)

    # ===================== Output =====================
    fused = layers.Add()([f1, d1])
    outputs = layers.Conv2D(num_classes, 1, activation="sigmoid")(fused)

    model = tf.keras.Model(
        inputs,
        outputs,
        name="ResidualUNet_Deep5_UpSampling"
    )

    return model

# %%
model = build_prior_guided_unet(input_shape=(256,256, 3), base_filters=32)
model.summary()
# Out:
# 2026-09-20 08:53:04.137744: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.137827: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.137849: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.383056: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.383120: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.383128: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2026-09-20 08:53:04.383142: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2026-09-20 08:53:04.383157: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2026-09-20 08:53:04.383183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13685 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "ResidualUNet_Deep5_UpSampling"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         961       ['input_1[0][0]']
#  onv (RadialWaveEvolutionar
#  yConv)
#
#  batch_normalization (Batch  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  Normalization)                                                     v[0][0]']
#
#  activation (Activation)     (None, 256, 256, 32)         0         ['batch_normalization[0][0]']
#
#  geodesic_downsample2d (Geo  (None, 128, 128, 32)         32        ['activation[0][0]']
#  desicDownsample2D)
#
#  dropout (Dropout)           (None, 128, 128, 32)         0         ['geodesic_downsample2d[0][0]'
#                                                                     ]
#
#  gaussian_dropout (Gaussian  (None, 128, 128, 32)         0         ['dropout[0][0]']
#  Dropout)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         20481     ['gaussian_dropout[0][0]']
#  onv_1 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_1[0][0]']
#
#  activation_1 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_1 (G  (None, 64, 64, 64)           64        ['activation_1[0][0]']
#  eodesicDownsample2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)           0         ['geodesic_downsample2d_1[0][0
#                                                                     ]']
#
#  gaussian_dropout_1 (Gaussi  (None, 64, 64, 64)           0         ['dropout_1[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          81921     ['gaussian_dropout_1[0][0]']
#  onv_2 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_2 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_2[0][0]']
#
#  activation_2 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_2 (G  (None, 32, 32, 128)          128       ['activation_2[0][0]']
#  eodesicDownsample2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)          0         ['geodesic_downsample2d_2[0][0
#                                                                     ]']
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          327681    ['dropout_2[0][0]']
#  onv_3 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_3 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_3[0][0]']
#
#  activation_3 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  geodesic_downsample2d_3 (G  (None, 16, 16, 256)          256       ['activation_3[0][0]']
#  eodesicDownsample2D)
#
#  dropout_3 (Dropout)         (None, 16, 16, 256)          0         ['geodesic_downsample2d_3[0][0
#                                                                     ]']
#
#  gaussian_dropout_2 (Gaussi  (None, 16, 16, 256)          0         ['dropout_3[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 16, 16, 384)          983041    ['gaussian_dropout_2[0][0]']
#  onv_4 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_4 (Bat  (None, 16, 16, 384)          1536      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_4[0][0]']
#
#  activation_4 (Activation)   (None, 16, 16, 384)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  spatial_dropout2d (Spatial  (None, 16, 16, 384)          0         ['activation_4[0][0]']
#  Dropout2D)
#
#  gaussian_dropout_3 (Gaussi  (None, 16, 16, 384)          0         ['spatial_dropout2d[0][0]']
#  anDropout)
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 384)          0         ['gaussian_dropout_3[0][0]']
#  D)
#
#  dropout_4 (Dropout)         (None, 32, 32, 384)          0         ['up_sampling2d[0][0]']
#
#  gaussian_dropout_4 (Gaussi  (None, 32, 32, 384)          0         ['dropout_4[0][0]']
#  anDropout)
#
#  radial_wave_evolutionary_c  (None, 32, 32, 256)          983041    ['gaussian_dropout_4[0][0]']
#  onv_5 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_5 (Bat  (None, 32, 32, 256)          1024      ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_5[0][0]']
#
#  activation_5 (Activation)   (None, 32, 32, 256)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  add (Add)                   (None, 32, 32, 256)          0         ['activation_3[0][0]',
#                                                                      'activation_5[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 256)          0         ['add[0][0]']
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 256)          0         ['up_sampling2d_1[0][0]']
#  anDropout)
#
#  dropout_5 (Dropout)         (None, 64, 64, 256)          0         ['gaussian_dropout_5[0][0]']
#
#  radial_wave_evolutionary_c  (None, 64, 64, 128)          327681    ['dropout_5[0][0]']
#  onv_6 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_6 (Bat  (None, 64, 64, 128)          512       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_6[0][0]']
#
#  activation_6 (Activation)   (None, 64, 64, 128)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  add_1 (Add)                 (None, 64, 64, 128)          0         ['activation_2[0][0]',
#                                                                      'activation_6[0][0]']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 128)        0         ['add_1[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 128, 128, 64)         81921     ['up_sampling2d_2[0][0]']
#  onv_7 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_7 (Bat  (None, 128, 128, 64)         256       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_7[0][0]']
#
#  activation_7 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 128, 128, 64)         0         ['activation_7[0][0]']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_1[0][0]',
#                                                                      'dropout_6[0][0]']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 64)         0         ['add_2[0][0]']
#  g2D)
#
#  radial_wave_evolutionary_c  (None, 256, 256, 32)         20481     ['up_sampling2d_3[0][0]']
#  onv_8 (RadialWaveEvolution
#  aryConv)
#
#  batch_normalization_8 (Bat  (None, 256, 256, 32)         128       ['radial_wave_evolutionary_con
#  chNormalization)                                                   v_8[0][0]']
#
#  activation_8 (Activation)   (None, 256, 256, 32)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dropout_7 (Dropout)         (None, 256, 256, 32)         0         ['activation_8[0][0]']
#
#  add_3 (Add)                 (None, 256, 256, 32)         0         ['activation[0][0]',
#                                                                      'dropout_7[0][0]']
#
#  conv2d (Conv2D)             (None, 256, 256, 1)          33        ['add_3[0][0]']
#
# ==================================================================================================
# Total params: 2833098 (10.81 MB)
# Trainable params: 2830410 (10.80 MB)
# Non-trainable params: 2688 (10.50 KB)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import register_keras_serializable
from tensorflow.keras import backend as K

# -----------------------------
# Optional imports / fallbacks
# -----------------------------
try:
    from tensorflow.keras.optimizers import AdamW
except Exception:
    AdamW = tf.keras.optimizers.Adam  # fallback to Adam if AdamW not present

# -----------------------------
# Metrics & simple losses
# -----------------------------
@register_keras_serializable(package="Custom")
def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    denominator = tf.reduce_sum(y_true + y_pred, axis=[1,2,3])
    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

@register_keras_serializable(package="Custom")
def dice_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - dice_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def iou_coef(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1,2,3])
    iou = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou)

@register_keras_serializable(package="Custom")
def iou_loss(y_true, y_pred, smooth=1e-6):
    return 1.0 - iou_coef(y_true, y_pred, smooth)

@register_keras_serializable(package="Custom")
def aggregated_jaccard_index(y_true, y_pred, smooth=1e-6):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true + y_pred - y_true * y_pred, axis=[1, 2, 3])
    jaccard = (intersection + smooth) / (union + smooth)

    weights = tf.reduce_sum(y_true, axis=[1, 2, 3]) + smooth
    weighted_mean = tf.reduce_sum(jaccard * weights) / tf.reduce_sum(weights)
    return weighted_mean

@register_keras_serializable(package="Custom")
def f1_score(y_true, y_pred, threshold=0.5, smooth=1e-7):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > threshold, tf.float32)

    true_pos = tf.reduce_sum(y_true * y_pred, axis=[1,2,3])
    predicted_pos = tf.reduce_sum(y_pred, axis=[1,2,3])
    possible_pos = tf.reduce_sum(y_true, axis=[1,2,3])

    precision = (true_pos + smooth) / (predicted_pos + smooth)
    recall = (true_pos + smooth) / (possible_pos + smooth)
    f1 = 2 * (precision * recall) / (precision + recall + smooth)
    return tf.reduce_mean(f1)

# %%
# -----------------------------
# Serializable metrics wrappers
# -----------------------------
@register_keras_serializable(package="Custom")
class IoUMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="iou_coef"):
        super().__init__(iou_coef, name=name)

@register_keras_serializable(package="Custom")
class DiceMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="dice_coef"):
        super().__init__(dice_coef, name=name)

@register_keras_serializable(package="Custom")
class F1Metric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="f1_score"):
        super().__init__(f1_score, name=name)

@register_keras_serializable(package="Custom")
class AJIMetric(tf.keras.metrics.MeanMetricWrapper):
    def __init__(self, name="aggregated_jaccard_index"):
        super().__init__(aggregated_jaccard_index, name=name)

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

# -----------------------------
# Simplified LambdaLogger callback
# -----------------------------
@register_keras_serializable(package="Custom")
class LambdaLogger(tf.keras.callbacks.Callback):
    def __init__(self, writer=None):
        super().__init__()
        self.writer = writer

    def on_epoch_end(self, epoch, logs=None):
        if not hasattr(self.model, "lambda1"):
            return

        # Fetch softplus-transformed adaptive weights
        l1 = tf.nn.softplus(self.model.lambda1).numpy()
        l2 = tf.nn.softplus(self.model.lambda2).numpy()
        l3 = tf.nn.softplus(self.model.lambda3).numpy()
        lfg = tf.nn.softplus(self.model.lambda_fg).numpy()
        lbg = tf.nn.softplus(self.model.lambda_bg).numpy()

        # Print clean epoch summary
        msg = (f"Epoch {epoch+1}: λ1={l1:.4f}, λ2={l2:.4f}, λ3={l3:.4f}, "
               f"λ_fg={lfg:.4f}, λ_bg={lbg:.4f}")
        print(msg)

        # Log to TensorBoard if writer is available
        if self.writer is not None:
            with self.writer.as_default():
                tf.summary.scalar("lambda1", l1, step=epoch)
                tf.summary.scalar("lambda2", l2, step=epoch)
                tf.summary.scalar("lambda3", l3, step=epoch)
                tf.summary.scalar("lambda_fg", lfg, step=epoch)
                tf.summary.scalar("lambda_bg", lbg, step=epoch)
                self.writer.flush()

    def get_config(self):
        return {"writer": None}

# %%
import tensorflow as tf
from tensorflow.keras.utils import register_keras_serializable

@register_keras_serializable(package="Custom")
class HyperStructuralLoss(tf.keras.losses.Loss):
    """
    Segmentation loss with learnable λ weights.

    Components:
        L_seg = λ2 * Dice + λ3 * IoU

    NOTE: the BCE term, the canvas consistency loss, the patchwise
    discriminator loss, and the center/boundary structural loss
    have all been removed. Only Dice + IoU remain.
    """
    def __init__(self, init_lambdas=None, name="hyper_structural_loss"):
        super().__init__(name=name)
        if init_lambdas is None:
            init_lambdas = {"l2": 3.0, "l3": 4.5}

        # Learnable λ variables
        self.l2 = tf.Variable(init_lambdas["l2"], trainable=True, dtype=tf.float32, name="l2")
        self.l3 = tf.Variable(init_lambdas["l3"], trainable=True, dtype=tf.float32, name="l3")

        # Explicitly expose trainable weights for TensorFlow
        self._trainable_weights = [self.l2, self.l3]

    def call(self, y_true, y_pred):
        """
        Args:
            y_true: ground-truth segmentation mask
            y_pred: predicted segmentation mask
        """
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        # --- Segmentation Loss ---
        L2, L3 = tf.nn.softplus(self.l2), tf.nn.softplus(self.l3)
        intersection = tf.reduce_sum(y_true * y_pred)
        dice = 1.0 - (2.0 * intersection + 1e-6) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + 1e-6)
        union = tf.reduce_sum(y_true + y_pred) - intersection
        iou = 1.0 - (intersection + 1e-6) / (union + 1e-6)
        seg_loss = L2 * dice + L3 * iou

        return seg_loss

    def get_config(self):
        cfg = super().get_config()
        cfg.update({
            "init_lambdas": {
                "l2": float(self.l2.numpy()),
                "l3": float(self.l3.numpy())
            }
        })
        return cfg

# %%
from tensorflow.keras.optimizers import AdamW
from datetime import datetime

# %%
import tensorflow as tf
from glob import glob
from PIL import Image
import numpy as np
import os

# Parameters
img_size = 256
batch_size = 4

# Paths
train_img_paths = sorted(glob("../dataset_split/augmented_train/images/*.png"))
train_mask_paths = sorted(glob("../dataset_split/augmented_train/masks/*.png"))

val_img_paths = sorted(
    glob("../dataset_split/val/images/*.png") +
    glob("../dataset_split/val/images/*.tif") +
    glob("../dataset_split/val/images/*.bmp")
)
val_mask_paths = sorted(glob("../dataset_split/val/masks/*.bmp"))

print("Train images:", len(train_img_paths))
print("Train masks:", len(train_mask_paths))
print("Val images:", len(val_img_paths))
print("Val masks:", len(val_mask_paths))

# -----------------------------
# STEM HELPERS
# -----------------------------
def stem(p):
    return os.path.splitext(os.path.basename(p))[0]

def mask_stem(p):
    s = os.path.splitext(os.path.basename(p))[0]
    return s.replace("_lesion", "")  # adjust if your suffix differs (case/hyphen)

# -----------------------------
# ALIGN TRAIN PAIRS BY STEM
# -----------------------------
train_img_dict = {stem(p): p for p in train_img_paths}
train_mask_dict = {mask_stem(p): p for p in train_mask_paths}

train_common = sorted(set(train_img_dict) & set(train_mask_dict))
train_missing_masks = set(train_img_dict) - set(train_mask_dict)
train_missing_imgs = set(train_mask_dict) - set(train_img_dict)

if train_missing_masks:
    print(f"⚠️ {len(train_missing_masks)} train images have no matching mask, e.g.:", list(train_missing_masks)[:5])
if train_missing_imgs:
    print(f"⚠️ {len(train_missing_imgs)} train masks have no matching image, e.g.:", list(train_missing_imgs)[:5])

train_img_paths = [train_img_dict[s] for s in train_common]
train_mask_paths = [train_mask_dict[s] for s in train_common]

assert len(train_img_paths) == len(train_mask_paths) == len(train_common), "❌ Train alignment failed"
print("✅ Aligned train pairs:", len(train_common))

# -----------------------------
# ALIGN VAL PAIRS BY STEM
# -----------------------------
val_img_dict = {stem(p): p for p in val_img_paths}
val_mask_dict = {mask_stem(p): p for p in val_mask_paths}

val_common = sorted(set(val_img_dict) & set(val_mask_dict))
val_missing_masks = set(val_img_dict) - set(val_mask_dict)
val_missing_imgs = set(val_mask_dict) - set(val_img_dict)

if val_missing_masks:
    print(f"⚠️ {len(val_missing_masks)} val images have no matching mask, e.g.:", list(val_missing_masks)[:5])
if val_missing_imgs:
    print(f"⚠️ {len(val_missing_imgs)} val masks have no matching image, e.g.:", list(val_missing_imgs)[:5])

val_img_paths = [val_img_dict[s] for s in val_common]
val_mask_paths = [val_mask_dict[s] for s in val_common]

assert len(val_img_paths) == len(val_mask_paths) == len(val_common), "❌ Val alignment failed"
print("✅ Aligned val pairs:", len(val_common))

# -----------------------------
# LOADER
# -----------------------------
def load_image_mask(img_path, mask_path):
    img = np.array(
        Image.open(img_path.numpy().decode("utf-8"))
        .convert("RGB")
        .resize((img_size, img_size), Image.BILINEAR)
    ) / 255.0
    mask = np.array(
        Image.open(mask_path.numpy().decode("utf-8"))
        .convert("L")
        .resize((img_size, img_size), Image.NEAREST)
    )
    mask = (mask > 127).astype(np.float32)[..., None]
    return img.astype(np.float32), mask

def tf_load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        load_image_mask, [img_path, mask_path], [tf.float32, tf.float32]
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    return img, mask

# -----------------------------
# DATASETS
# -----------------------------
train_dataset = (
    tf.data.Dataset.from_tensor_slices((train_img_paths, train_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .shuffle(buffer_size=len(train_img_paths), seed=42)
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

val_dataset = (
    tf.data.Dataset.from_tensor_slices((val_img_paths, val_mask_paths))
    .map(tf_load_image_mask, num_parallel_calls=tf.data.AUTOTUNE).cache()
    .batch(batch_size)
    .prefetch(tf.data.AUTOTUNE)
)

print("Training batches:", tf.data.experimental.cardinality(train_dataset).numpy())
print("Validation batches:", tf.data.experimental.cardinality(val_dataset).numpy())
# Out:
# Train images: 720
# Train masks: 720
# Val images: 16
# Val masks: 16
# ✅ Aligned train pairs: 720
# ✅ Aligned val pairs: 16
# 2026-09-20 08:53:28.124718: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# Training batches: 180
# Validation batches: 4

# %%
class StructTrainer(tf.keras.Model):
    def __init__(self, backbone, loss_fn, optimizer, metrics):
        super().__init__()
        self.backbone = backbone
        self.loss_fn = loss_fn
        self.optimizer = optimizer
        self.metrics_list = metrics

        # Expose learnable λ weights for monitoring
        for key in ["l2", "l3"]:
            setattr(self, key, getattr(loss_fn, key))

    def compile(self):
        super().compile(optimizer=self.optimizer)

    def train_step(self, data):
        x, y_true = data
        with tf.GradientTape() as tape:
            y_pred = self.backbone(x, training=True)
            loss = self.loss_fn(y_true, y_pred)

        grads = tape.gradient(loss, self.backbone.trainable_variables + self.loss_fn._trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.backbone.trainable_variables + self.loss_fn._trainable_weights))

        logs = {"loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[m.name] = m.result()
        return logs

    def test_step(self, data):
        x, y_true = data
        y_pred = self.backbone(x, training=False)
        loss = self.loss_fn(y_true, y_pred)

        logs = {"val_loss": loss}
        for m in self.metrics_list:
            m.update_state(y_true, y_pred)
            logs[f"val_{m.name}"] = m.result()
        return logs

# %%
optimizer = AdamW(learning_rate=1e-3, weight_decay=1e-10)

# 3️⃣ Metrics
metrics_list = [
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    #tf.keras.metrics.MeanIoU(num_classes=2, name="iou"),
    IoUMetric(), DiceMetric(), F1Metric(), AJIMetric()
]

# 4️⃣ Loss
loss_fn = HyperStructuralLoss()
ll=LambdaLogger()
# 5️⃣ Trainer
seg_model = StructTrainer(model, loss_fn, optimizer, metrics_list)
seg_model.compile()

# 6️⃣ Callbacks
log_dir = "./logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
writer = tf.summary.create_file_writer(log_dir)
lambda_logger = LambdaLogger(writer=writer)

early_stp = tf.keras.callbacks.EarlyStopping(
    monitor='val_val_iou_coef', patience=35, mode='max', restore_best_weights=True
)

lr_callback = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_val_iou_coef', mode='max', factor=0.1, patience=10, min_lr=1e-5, verbose=1
)

tb = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

class SaveBackboneCallback(tf.keras.callbacks.Callback):
    def __init__(self, save_path):
        super().__init__()
        self.save_path = save_path
        self.best_iou = 0.0

    def on_epoch_end(self, epoch, logs=None):
        val_iou = logs.get("val_val_iou_coef", 0)
        if val_iou >= self.best_iou:
            self.best_iou = val_iou
            self.model.backbone.save(self.save_path)
            print(f"\n✅ Saved improved backbone at epoch {epoch+1} with val_iou={val_iou:.4f}")

save_backbone = SaveBackboneCallback("prior_gided_unet.keras")

# 7️⃣ Training
history = seg_model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=150,
    callbacks=[early_stp, lr_callback, tb, lambda_logger, save_backbone],batch_size=4,
    verbose=1
)
print("\n🎯 Training complete. Backbone saved and ready for inference.")
# Out:
# Epoch 1/150
# 2026-09-20 08:53:35.847341: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inResidualUNet_Deep5_UpSampling/spatial_dropout2d/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2026-09-20 08:53:40.576351: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2026-09-20 08:53:40.715593: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2026-09-20 08:53:45.535548: I external/local_xla/xla/service/service.cc:168] XLA service 0x7e0c072fe4b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-09-20 08:53:45.535587: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Ti, Compute Capability 8.9
# 2026-09-20 08:53:45.539052: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1789894425.591797   28546 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 180/180 [==============================] - ETA: 0s - loss: 2.9413 - accuracy: 0.7764 - iou_coef: 0.5382 - dice_coef: 0.6739 - f1_score: 0.6793 - aggregated_jaccard_index: 0.6000
# ✅ Saved improved backbone at epoch 1 with val_iou=0.5029
# 180/180 [==============================] - 38s 110ms/step - loss: 2.9393 - accuracy: 0.7764 - iou_coef: 0.5382 - dice_coef: 0.6739 - f1_score: 0.6793 - aggregated_jaccard_index: 0.6000 - val_val_loss: 3.3835 - val_val_accuracy: 0.8063 - val_val_iou_coef: 0.5029 - val_val_dice_coef: 0.6578 - val_val_f1_score: 0.6744 - val_val_aggregated_jaccard_index: 0.5187 - lr: 0.0010
# Epoch 2/150
# 180/180 [==============================] - ETA: 0s - loss: 2.5490 - accuracy: 0.8176 - iou_coef: 0.5748 - dice_coef: 0.7080 - f1_score: 0.7122 - aggregated_jaccard_index: 0.6191
# ✅ Saved improved backbone at epoch 2 with val_iou=0.5853
# 180/180 [==============================] - 24s 133ms/step - loss: 2.5475 - accuracy: 0.8176 - iou_coef: 0.5748 - dice_coef: 0.7080 - f1_score: 0.7122 - aggregated_jaccard_index: 0.6191 - val_val_loss: 2.1643 - val_val_accuracy: 0.8262 - val_val_iou_coef: 0.5853 - val_val_dice_coef: 0.7222 - val_val_f1_score: 0.7378 - val_val_aggregated_jaccard_index: 0.6486 - lr: 0.0010
# Epoch 3/150
# 180/180 [==============================] - ETA: 0s - loss: 2.1755 - accuracy: 0.8518 - iou_coef: 0.6238 - dice_coef: 0.7451 - f1_score: 0.7506 - aggregated_jaccard_index: 0.6560
# ✅ Saved improved backbone at epoch 3 with val_iou=0.6792
# 180/180 [==============================] - 25s 139ms/step - loss: 2.1739 - accuracy: 0.8518 - iou_coef: 0.6238 - dice_coef: 0.7451 - f1_score: 0.7506 - aggregated_jaccard_index: 0.6560 - val_val_loss: 2.2118 - val_val_accuracy: 0.8896 - val_val_iou_coef: 0.6792 - val_val_dice_coef: 0.8004 - val_val_f1_score: 0.8083 - val_val_aggregated_jaccard_index: 0.6553 - lr: 0.0010
# Epoch 4/150
# 180/180 [==============================] - ETA: 0s - loss: 1.7155 - accuracy: 0.8867 - iou_coef: 0.7000 - dice_coef: 0.8054 - f1_score: 0.8109 - aggregated_jaccard_index: 0.7107
# ✅ Saved improved backbone at epoch 4 with val_iou=0.7037
# 180/180 [==============================] - 23s 127ms/step - loss: 1.7186 - accuracy: 0.8867 - iou_coef: 0.7000 - dice_coef: 0.8054 - f1_score: 0.8109 - aggregated_jaccard_index: 0.7107 - val_val_loss: 2.2631 - val_val_accuracy: 0.9030 - val_val_iou_coef: 0.7037 - val_val_dice_coef: 0.8186 - val_val_f1_score: 0.8212 - val_val_aggregated_jaccard_index: 0.6930 - lr: 0.0010
# Epoch 5/150
# 180/180 [==============================] - ETA: 0s - loss: 1.4791 - accuracy: 0.8981 - iou_coef: 0.7289 - dice_coef: 0.8263 - f1_score: 0.8306 - aggregated_jaccard_index: 0.7412
# ✅ Saved improved backbone at epoch 5 with val_iou=0.7604
# 180/180 [==============================] - 24s 136ms/step - loss: 1.4766 - accuracy: 0.8981 - iou_coef: 0.7289 - dice_coef: 0.8263 - f1_score: 0.8306 - aggregated_jaccard_index: 0.7412 - val_val_loss: 1.8479 - val_val_accuracy: 0.9147 - val_val_iou_coef: 0.7604 - val_val_dice_coef: 0.8583 - val_val_f1_score: 0.8617 - val_val_aggregated_jaccard_index: 0.7446 - lr: 0.0010
# Epoch 6/150
# 180/180 [==============================] - ETA: 0s - loss: 1.3971 - accuracy: 0.9004 - iou_coef: 0.7412 - dice_coef: 0.8362 - f1_score: 0.8399 - aggregated_jaccard_index: 0.7433
# ✅ Saved improved backbone at epoch 6 with val_iou=0.8041
# 180/180 [==============================] - 25s 141ms/step - loss: 1.4050 - accuracy: 0.9004 - iou_coef: 0.7412 - dice_coef: 0.8362 - f1_score: 0.8399 - aggregated_jaccard_index: 0.7433 - val_val_loss: 1.3794 - val_val_accuracy: 0.9307 - val_val_iou_coef: 0.8041 - val_val_dice_coef: 0.8882 - val_val_f1_score: 0.8917 - val_val_aggregated_jaccard_index: 0.7916 - lr: 0.0010
# Epoch 7/150
# 180/180 [==============================] - 21s 118ms/step - loss: 1.2774 - accuracy: 0.9054 - iou_coef: 0.7504 - dice_coef: 0.8436 - f1_score: 0.8471 - aggregated_jaccard_index: 0.7540 - val_val_loss: 1.6377 - val_val_accuracy: 0.8648 - val_val_iou_coef: 0.6818 - val_val_dice_coef: 0.7943 - val_val_f1_score: 0.7969 - val_val_aggregated_jaccard_index: 0.7318 - lr: 0.0010
# Epoch 8/150
# 180/180 [==============================] - 22s 111ms/step - loss: 1.1813 - accuracy: 0.9109 - iou_coef: 0.7669 - dice_coef: 0.8555 - f1_score: 0.8583 - aggregated_jaccard_index: 0.7605 - val_val_loss: 1.2488 - val_val_accuracy: 0.8924 - val_val_iou_coef: 0.7507 - val_val_dice_coef: 0.8439 - val_val_f1_score: 0.8450 - val_val_aggregated_jaccard_index: 0.7695 - lr: 0.0010
# Epoch 9/150
# 180/180 [==============================] - 22s 121ms/step - loss: 1.1198 - accuracy: 0.9110 - iou_coef: 0.7628 - dice_coef: 0.8525 - f1_score: 0.8551 - aggregated_jaccard_index: 0.7632 - val_val_loss: 1.1118 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.7887 - val_val_dice_coef: 0.8751 - val_val_f1_score: 0.8785 - val_val_aggregated_jaccard_index: 0.7917 - lr: 0.0010
# Epoch 10/150
# 180/180 [==============================] - 20s 110ms/step - loss: 1.0746 - accuracy: 0.9107 - iou_coef: 0.7682 - dice_coef: 0.8562 - f1_score: 0.8586 - aggregated_jaccard_index: 0.7663 - val_val_loss: 1.0576 - val_val_accuracy: 0.9208 - val_val_iou_coef: 0.7771 - val_val_dice_coef: 0.8657 - val_val_f1_score: 0.8671 - val_val_aggregated_jaccard_index: 0.8014 - lr: 0.0010
# Epoch 11/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.9777 - accuracy: 0.9158 - iou_coef: 0.7746 - dice_coef: 0.8617 - f1_score: 0.8640 - aggregated_jaccard_index: 0.7734 - val_val_loss: 1.2121 - val_val_accuracy: 0.8978 - val_val_iou_coef: 0.7691 - val_val_dice_coef: 0.8561 - val_val_f1_score: 0.8576 - val_val_aggregated_jaccard_index: 0.7799 - lr: 0.0010
# Epoch 12/150
# 180/180 [==============================] - ETA: 0s - loss: 0.9295 - accuracy: 0.9159 - iou_coef: 0.7789 - dice_coef: 0.8639 - f1_score: 0.8662 - aggregated_jaccard_index: 0.7747
# ✅ Saved improved backbone at epoch 12 with val_iou=0.8169
# 180/180 [==============================] - 22s 121ms/step - loss: 0.9301 - accuracy: 0.9159 - iou_coef: 0.7789 - dice_coef: 0.8639 - f1_score: 0.8662 - aggregated_jaccard_index: 0.7747 - val_val_loss: 1.0286 - val_val_accuracy: 0.9352 - val_val_iou_coef: 0.8169 - val_val_dice_coef: 0.8951 - val_val_f1_score: 0.8970 - val_val_aggregated_jaccard_index: 0.8048 - lr: 0.0010
# Epoch 13/150
# 180/180 [==============================] - 20s 109ms/step - loss: 0.9069 - accuracy: 0.9131 - iou_coef: 0.7707 - dice_coef: 0.8579 - f1_score: 0.8602 - aggregated_jaccard_index: 0.7724 - val_val_loss: 0.9628 - val_val_accuracy: 0.9341 - val_val_iou_coef: 0.8055 - val_val_dice_coef: 0.8893 - val_val_f1_score: 0.8914 - val_val_aggregated_jaccard_index: 0.8099 - lr: 0.0010
# Epoch 14/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.8256 - accuracy: 0.9177 - iou_coef: 0.7810 - dice_coef: 0.8668 - f1_score: 0.8688 - aggregated_jaccard_index: 0.7782 - val_val_loss: 0.6644 - val_val_accuracy: 0.9340 - val_val_iou_coef: 0.8002 - val_val_dice_coef: 0.8854 - val_val_f1_score: 0.8875 - val_val_aggregated_jaccard_index: 0.8180 - lr: 0.0010
# Epoch 15/150
# 180/180 [==============================] - 20s 110ms/step - loss: 0.7299 - accuracy: 0.9218 - iou_coef: 0.7927 - dice_coef: 0.8746 - f1_score: 0.8769 - aggregated_jaccard_index: 0.7925 - val_val_loss: 0.6875 - val_val_accuracy: 0.9370 - val_val_iou_coef: 0.8121 - val_val_dice_coef: 0.8933 - val_val_f1_score: 0.8955 - val_val_aggregated_jaccard_index: 0.8189 - lr: 0.0010
# Epoch 16/150
# 180/180 [==============================] - ETA: 0s - loss: 0.6905 - accuracy: 0.9228 - iou_coef: 0.7963 - dice_coef: 0.8768 - f1_score: 0.8788 - aggregated_jaccard_index: 0.7935
# ✅ Saved improved backbone at epoch 16 with val_iou=0.8191
# 180/180 [==============================] - 22s 122ms/step - loss: 0.6931 - accuracy: 0.9228 - iou_coef: 0.7963 - dice_coef: 0.8768 - f1_score: 0.8788 - aggregated_jaccard_index: 0.7935 - val_val_loss: 0.6419 - val_val_accuracy: 0.9396 - val_val_iou_coef: 0.8191 - val_val_dice_coef: 0.8972 - val_val_f1_score: 0.8982 - val_val_aggregated_jaccard_index: 0.8282 - lr: 0.0010
# Epoch 17/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.6391 - accuracy: 0.9247 - iou_coef: 0.7968 - dice_coef: 0.8780 - f1_score: 0.8803 - aggregated_jaccard_index: 0.7970 - val_val_loss: 0.7170 - val_val_accuracy: 0.9320 - val_val_iou_coef: 0.8104 - val_val_dice_coef: 0.8899 - val_val_f1_score: 0.8906 - val_val_aggregated_jaccard_index: 0.8117 - lr: 0.0010
# Epoch 18/150
# 180/180 [==============================] - 20s 110ms/step - loss: 0.6153 - accuracy: 0.9241 - iou_coef: 0.7918 - dice_coef: 0.8739 - f1_score: 0.8760 - aggregated_jaccard_index: 0.7921 - val_val_loss: 0.6454 - val_val_accuracy: 0.9364 - val_val_iou_coef: 0.8136 - val_val_dice_coef: 0.8937 - val_val_f1_score: 0.8962 - val_val_aggregated_jaccard_index: 0.8152 - lr: 0.0010
# Epoch 19/150
# 180/180 [==============================] - 24s 132ms/step - loss: 0.5778 - accuracy: 0.9244 - iou_coef: 0.7987 - dice_coef: 0.8788 - f1_score: 0.8807 - aggregated_jaccard_index: 0.7931 - val_val_loss: 0.5237 - val_val_accuracy: 0.9336 - val_val_iou_coef: 0.7914 - val_val_dice_coef: 0.8809 - val_val_f1_score: 0.8821 - val_val_aggregated_jaccard_index: 0.7993 - lr: 0.0010
# Epoch 20/150
# 180/180 [==============================] - 25s 139ms/step - loss: 0.5113 - accuracy: 0.9282 - iou_coef: 0.8072 - dice_coef: 0.8844 - f1_score: 0.8864 - aggregated_jaccard_index: 0.8060 - val_val_loss: 0.8210 - val_val_accuracy: 0.9280 - val_val_iou_coef: 0.7999 - val_val_dice_coef: 0.8824 - val_val_f1_score: 0.8832 - val_val_aggregated_jaccard_index: 0.7772 - lr: 0.0010
# Epoch 21/150
# 180/180 [==============================] - 23s 125ms/step - loss: 0.4770 - accuracy: 0.9285 - iou_coef: 0.8045 - dice_coef: 0.8834 - f1_score: 0.8853 - aggregated_jaccard_index: 0.8048 - val_val_loss: 0.8753 - val_val_accuracy: 0.9172 - val_val_iou_coef: 0.7624 - val_val_dice_coef: 0.8592 - val_val_f1_score: 0.8600 - val_val_aggregated_jaccard_index: 0.7390 - lr: 0.0010
# Epoch 22/150
# 180/180 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.9293 - iou_coef: 0.8073 - dice_coef: 0.8849 - f1_score: 0.8867 - aggregated_jaccard_index: 0.8074
# ✅ Saved improved backbone at epoch 22 with val_iou=0.8209
# 180/180 [==============================] - 25s 139ms/step - loss: 0.4478 - accuracy: 0.9293 - iou_coef: 0.8073 - dice_coef: 0.8849 - f1_score: 0.8867 - aggregated_jaccard_index: 0.8074 - val_val_loss: 0.4695 - val_val_accuracy: 0.9372 - val_val_iou_coef: 0.8209 - val_val_dice_coef: 0.8974 - val_val_f1_score: 0.8991 - val_val_aggregated_jaccard_index: 0.8207 - lr: 0.0010
# Epoch 23/150
# 180/180 [==============================] - 25s 137ms/step - loss: 0.3988 - accuracy: 0.9329 - iou_coef: 0.8150 - dice_coef: 0.8912 - f1_score: 0.8934 - aggregated_jaccard_index: 0.8131 - val_val_loss: 0.7094 - val_val_accuracy: 0.9244 - val_val_iou_coef: 0.7833 - val_val_dice_coef: 0.8723 - val_val_f1_score: 0.8740 - val_val_aggregated_jaccard_index: 0.7640 - lr: 0.0010
# Epoch 24/150
# 180/180 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.9316 - iou_coef: 0.8123 - dice_coef: 0.8896 - f1_score: 0.8915 - aggregated_jaccard_index: 0.8125
# ✅ Saved improved backbone at epoch 24 with val_iou=0.8260
# 180/180 [==============================] - 22s 124ms/step - loss: 0.3741 - accuracy: 0.9316 - iou_coef: 0.8123 - dice_coef: 0.8896 - f1_score: 0.8915 - aggregated_jaccard_index: 0.8125 - val_val_loss: 0.3360 - val_val_accuracy: 0.9405 - val_val_iou_coef: 0.8260 - val_val_dice_coef: 0.8990 - val_val_f1_score: 0.9000 - val_val_aggregated_jaccard_index: 0.8346 - lr: 0.0010
# Epoch 25/150
# 180/180 [==============================] - 24s 136ms/step - loss: 0.3549 - accuracy: 0.9307 - iou_coef: 0.8099 - dice_coef: 0.8873 - f1_score: 0.8892 - aggregated_jaccard_index: 0.8092 - val_val_loss: 0.4599 - val_val_accuracy: 0.9071 - val_val_iou_coef: 0.7628 - val_val_dice_coef: 0.8523 - val_val_f1_score: 0.8544 - val_val_aggregated_jaccard_index: 0.7949 - lr: 0.0010
# Epoch 26/150
# 180/180 [==============================] - 25s 139ms/step - loss: 0.3237 - accuracy: 0.9317 - iou_coef: 0.8107 - dice_coef: 0.8877 - f1_score: 0.8894 - aggregated_jaccard_index: 0.8140 - val_val_loss: 0.2998 - val_val_accuracy: 0.9403 - val_val_iou_coef: 0.8245 - val_val_dice_coef: 0.9015 - val_val_f1_score: 0.9034 - val_val_aggregated_jaccard_index: 0.8207 - lr: 0.0010
# Epoch 27/150
# 180/180 [==============================] - 25s 138ms/step - loss: 0.2993 - accuracy: 0.9319 - iou_coef: 0.8120 - dice_coef: 0.8886 - f1_score: 0.8905 - aggregated_jaccard_index: 0.8136 - val_val_loss: 0.2600 - val_val_accuracy: 0.9376 - val_val_iou_coef: 0.8138 - val_val_dice_coef: 0.8937 - val_val_f1_score: 0.8951 - val_val_aggregated_jaccard_index: 0.8221 - lr: 0.0010
# Epoch 28/150
# 180/180 [==============================] - 23s 126ms/step - loss: 0.2622 - accuracy: 0.9354 - iou_coef: 0.8202 - dice_coef: 0.8947 - f1_score: 0.8964 - aggregated_jaccard_index: 0.8215 - val_val_loss: 0.2825 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.8198 - val_val_dice_coef: 0.8963 - val_val_f1_score: 0.8970 - val_val_aggregated_jaccard_index: 0.8249 - lr: 0.0010
# Epoch 29/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.2437 - accuracy: 0.9354 - iou_coef: 0.8201 - dice_coef: 0.8950 - f1_score: 0.8967 - aggregated_jaccard_index: 0.8209 - val_val_loss: 0.2787 - val_val_accuracy: 0.9377 - val_val_iou_coef: 0.8148 - val_val_dice_coef: 0.8939 - val_val_f1_score: 0.8948 - val_val_aggregated_jaccard_index: 0.8165 - lr: 0.0010
# Epoch 30/150
# 180/180 [==============================] - 19s 107ms/step - loss: 0.2258 - accuracy: 0.9353 - iou_coef: 0.8196 - dice_coef: 0.8944 - f1_score: 0.8965 - aggregated_jaccard_index: 0.8220 - val_val_loss: 0.2515 - val_val_accuracy: 0.9352 - val_val_iou_coef: 0.8037 - val_val_dice_coef: 0.8888 - val_val_f1_score: 0.8895 - val_val_aggregated_jaccard_index: 0.8017 - lr: 0.0010
# Epoch 31/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.2013 - accuracy: 0.9372 - iou_coef: 0.8258 - dice_coef: 0.8985 - f1_score: 0.9003 - aggregated_jaccard_index: 0.8266 - val_val_loss: 0.2031 - val_val_accuracy: 0.9373 - val_val_iou_coef: 0.8206 - val_val_dice_coef: 0.8994 - val_val_f1_score: 0.9009 - val_val_aggregated_jaccard_index: 0.8134 - lr: 0.0010
# Epoch 32/150
# 180/180 [==============================] - 22s 123ms/step - loss: 0.1890 - accuracy: 0.9374 - iou_coef: 0.8236 - dice_coef: 0.8969 - f1_score: 0.8989 - aggregated_jaccard_index: 0.8269 - val_val_loss: 0.2543 - val_val_accuracy: 0.9325 - val_val_iou_coef: 0.8052 - val_val_dice_coef: 0.8887 - val_val_f1_score: 0.8894 - val_val_aggregated_jaccard_index: 0.7908 - lr: 0.0010
# Epoch 33/150
# 180/180 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9372 - iou_coef: 0.8236 - dice_coef: 0.8971 - f1_score: 0.8991 - aggregated_jaccard_index: 0.8250
# ✅ Saved improved backbone at epoch 33 with val_iou=0.8352
# 180/180 [==============================] - 19s 105ms/step - loss: 0.1740 - accuracy: 0.9372 - iou_coef: 0.8236 - dice_coef: 0.8971 - f1_score: 0.8991 - aggregated_jaccard_index: 0.8250 - val_val_loss: 0.1502 - val_val_accuracy: 0.9447 - val_val_iou_coef: 0.8352 - val_val_dice_coef: 0.9087 - val_val_f1_score: 0.9105 - val_val_aggregated_jaccard_index: 0.8314 - lr: 0.0010
# Epoch 34/150
# 180/180 [==============================] - 22s 123ms/step - loss: 0.1576 - accuracy: 0.9391 - iou_coef: 0.8246 - dice_coef: 0.8979 - f1_score: 0.9000 - aggregated_jaccard_index: 0.8270 - val_val_loss: 0.1403 - val_val_accuracy: 0.9407 - val_val_iou_coef: 0.8228 - val_val_dice_coef: 0.9004 - val_val_f1_score: 0.9018 - val_val_aggregated_jaccard_index: 0.8262 - lr: 0.0010
# Epoch 35/150
# 180/180 [==============================] - 19s 103ms/step - loss: 0.1475 - accuracy: 0.9380 - iou_coef: 0.8264 - dice_coef: 0.8990 - f1_score: 0.9008 - aggregated_jaccard_index: 0.8255 - val_val_loss: 0.1882 - val_val_accuracy: 0.9394 - val_val_iou_coef: 0.8254 - val_val_dice_coef: 0.9026 - val_val_f1_score: 0.9042 - val_val_aggregated_jaccard_index: 0.8109 - lr: 0.0010
# Epoch 36/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.1296 - accuracy: 0.9396 - iou_coef: 0.8309 - dice_coef: 0.9021 - f1_score: 0.9040 - aggregated_jaccard_index: 0.8321 - val_val_loss: 0.1630 - val_val_accuracy: 0.9344 - val_val_iou_coef: 0.8064 - val_val_dice_coef: 0.8897 - val_val_f1_score: 0.8904 - val_val_aggregated_jaccard_index: 0.8018 - lr: 0.0010
# Epoch 37/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.1178 - accuracy: 0.9409 - iou_coef: 0.8328 - dice_coef: 0.9039 - f1_score: 0.9060 - aggregated_jaccard_index: 0.8348 - val_val_loss: 0.0941 - val_val_accuracy: 0.9373 - val_val_iou_coef: 0.8024 - val_val_dice_coef: 0.8843 - val_val_f1_score: 0.8860 - val_val_aggregated_jaccard_index: 0.8310 - lr: 0.0010
# Epoch 38/150
# 180/180 [==============================] - 19s 104ms/step - loss: 0.1072 - accuracy: 0.9419 - iou_coef: 0.8344 - dice_coef: 0.9043 - f1_score: 0.9063 - aggregated_jaccard_index: 0.8365 - val_val_loss: 0.1256 - val_val_accuracy: 0.9266 - val_val_iou_coef: 0.8132 - val_val_dice_coef: 0.8871 - val_val_f1_score: 0.8891 - val_val_aggregated_jaccard_index: 0.8228 - lr: 0.0010
# Epoch 39/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0987 - accuracy: 0.9421 - iou_coef: 0.8344 - dice_coef: 0.9047 - f1_score: 0.9067 - aggregated_jaccard_index: 0.8380 - val_val_loss: 0.1037 - val_val_accuracy: 0.9398 - val_val_iou_coef: 0.8289 - val_val_dice_coef: 0.9035 - val_val_f1_score: 0.9045 - val_val_aggregated_jaccard_index: 0.8268 - lr: 0.0010
# Epoch 40/150
# 180/180 [==============================] - 19s 105ms/step - loss: 0.0897 - accuracy: 0.9427 - iou_coef: 0.8335 - dice_coef: 0.9038 - f1_score: 0.9057 - aggregated_jaccard_index: 0.8390 - val_val_loss: 0.0787 - val_val_accuracy: 0.9445 - val_val_iou_coef: 0.8226 - val_val_dice_coef: 0.9003 - val_val_f1_score: 0.9029 - val_val_aggregated_jaccard_index: 0.8379 - lr: 0.0010
# Epoch 41/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0823 - accuracy: 0.9439 - iou_coef: 0.8382 - dice_coef: 0.9074 - f1_score: 0.9095 - aggregated_jaccard_index: 0.8395 - val_val_loss: 0.0967 - val_val_accuracy: 0.9321 - val_val_iou_coef: 0.8089 - val_val_dice_coef: 0.8893 - val_val_f1_score: 0.8918 - val_val_aggregated_jaccard_index: 0.8167 - lr: 0.0010
# Epoch 42/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0717 - accuracy: 0.9469 - iou_coef: 0.8442 - dice_coef: 0.9111 - f1_score: 0.9127 - aggregated_jaccard_index: 0.8494 - val_val_loss: 0.0866 - val_val_accuracy: 0.9403 - val_val_iou_coef: 0.8198 - val_val_dice_coef: 0.8995 - val_val_f1_score: 0.9022 - val_val_aggregated_jaccard_index: 0.8184 - lr: 0.0010
# Epoch 43/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0678 - accuracy: 0.9452 - iou_coef: 0.8415 - dice_coef: 0.9093 - f1_score: 0.9112 - aggregated_jaccard_index: 0.8457
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 180/180 [==============================] - 19s 105ms/step - loss: 0.0678 - accuracy: 0.9452 - iou_coef: 0.8415 - dice_coef: 0.9093 - f1_score: 0.9112 - aggregated_jaccard_index: 0.8457 - val_val_loss: 0.0675 - val_val_accuracy: 0.9431 - val_val_iou_coef: 0.8271 - val_val_dice_coef: 0.9044 - val_val_f1_score: 0.9053 - val_val_aggregated_jaccard_index: 0.8216 - lr: 0.0010
# Epoch 44/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0575 - accuracy: 0.9516 - iou_coef: 0.8567 - dice_coef: 0.9195 - f1_score: 0.9210 - aggregated_jaccard_index: 0.8616
# ✅ Saved improved backbone at epoch 44 with val_iou=0.8436
# 180/180 [==============================] - 23s 126ms/step - loss: 0.0574 - accuracy: 0.9516 - iou_coef: 0.8567 - dice_coef: 0.9195 - f1_score: 0.9210 - aggregated_jaccard_index: 0.8616 - val_val_loss: 0.0550 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8436 - val_val_dice_coef: 0.9137 - val_val_f1_score: 0.9144 - val_val_aggregated_jaccard_index: 0.8390 - lr: 1.0000e-04
# Epoch 45/150
# 180/180 [==============================] - 19s 108ms/step - loss: 0.0556 - accuracy: 0.9540 - iou_coef: 0.8622 - dice_coef: 0.9232 - f1_score: 0.9246 - aggregated_jaccard_index: 0.8652 - val_val_loss: 0.0581 - val_val_accuracy: 0.9473 - val_val_iou_coef: 0.8418 - val_val_dice_coef: 0.9124 - val_val_f1_score: 0.9130 - val_val_aggregated_jaccard_index: 0.8372 - lr: 1.0000e-04
# Epoch 46/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0566 - accuracy: 0.9521 - iou_coef: 0.8574 - dice_coef: 0.9201 - f1_score: 0.9217 - aggregated_jaccard_index: 0.8615 - val_val_loss: 0.0636 - val_val_accuracy: 0.9454 - val_val_iou_coef: 0.8389 - val_val_dice_coef: 0.9109 - val_val_f1_score: 0.9113 - val_val_aggregated_jaccard_index: 0.8312 - lr: 1.0000e-04
# Epoch 47/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0576 - accuracy: 0.9508 - iou_coef: 0.8556 - dice_coef: 0.9187 - f1_score: 0.9201 - aggregated_jaccard_index: 0.8595 - val_val_loss: 0.0663 - val_val_accuracy: 0.9443 - val_val_iou_coef: 0.8357 - val_val_dice_coef: 0.9088 - val_val_f1_score: 0.9094 - val_val_aggregated_jaccard_index: 0.8281 - lr: 1.0000e-04
# Epoch 48/150
# 180/180 [==============================] - 19s 107ms/step - loss: 0.0538 - accuracy: 0.9535 - iou_coef: 0.8612 - dice_coef: 0.9223 - f1_score: 0.9238 - aggregated_jaccard_index: 0.8661 - val_val_loss: 0.0567 - val_val_accuracy: 0.9473 - val_val_iou_coef: 0.8407 - val_val_dice_coef: 0.9112 - val_val_f1_score: 0.9123 - val_val_aggregated_jaccard_index: 0.8400 - lr: 1.0000e-04
# Epoch 49/150
# 180/180 [==============================] - 23s 125ms/step - loss: 0.0536 - accuracy: 0.9532 - iou_coef: 0.8620 - dice_coef: 0.9232 - f1_score: 0.9247 - aggregated_jaccard_index: 0.8656 - val_val_loss: 0.0563 - val_val_accuracy: 0.9457 - val_val_iou_coef: 0.8379 - val_val_dice_coef: 0.9099 - val_val_f1_score: 0.9104 - val_val_aggregated_jaccard_index: 0.8352 - lr: 1.0000e-04
# Epoch 50/150
# 180/180 [==============================] - 19s 108ms/step - loss: 0.0541 - accuracy: 0.9530 - iou_coef: 0.8600 - dice_coef: 0.9216 - f1_score: 0.9231 - aggregated_jaccard_index: 0.8640 - val_val_loss: 0.0547 - val_val_accuracy: 0.9473 - val_val_iou_coef: 0.8418 - val_val_dice_coef: 0.9120 - val_val_f1_score: 0.9134 - val_val_aggregated_jaccard_index: 0.8408 - lr: 1.0000e-04
# Epoch 51/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0526 - accuracy: 0.9537 - iou_coef: 0.8611 - dice_coef: 0.9227 - f1_score: 0.9244 - aggregated_jaccard_index: 0.8654 - val_val_loss: 0.0524 - val_val_accuracy: 0.9462 - val_val_iou_coef: 0.8351 - val_val_dice_coef: 0.9083 - val_val_f1_score: 0.9093 - val_val_aggregated_jaccard_index: 0.8344 - lr: 1.0000e-04
# Epoch 52/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0522 - accuracy: 0.9536 - iou_coef: 0.8616 - dice_coef: 0.9227 - f1_score: 0.9243 - aggregated_jaccard_index: 0.8650 - val_val_loss: 0.0490 - val_val_accuracy: 0.9460 - val_val_iou_coef: 0.8320 - val_val_dice_coef: 0.9065 - val_val_f1_score: 0.9076 - val_val_aggregated_jaccard_index: 0.8330 - lr: 1.0000e-04
# Epoch 53/150
# 180/180 [==============================] - 20s 110ms/step - loss: 0.0515 - accuracy: 0.9534 - iou_coef: 0.8599 - dice_coef: 0.9218 - f1_score: 0.9234 - aggregated_jaccard_index: 0.8658 - val_val_loss: 0.0492 - val_val_accuracy: 0.9485 - val_val_iou_coef: 0.8427 - val_val_dice_coef: 0.9128 - val_val_f1_score: 0.9139 - val_val_aggregated_jaccard_index: 0.8409 - lr: 1.0000e-04
# Epoch 54/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9539 - iou_coef: 0.8620 - dice_coef: 0.9230 - f1_score: 0.9245 - aggregated_jaccard_index: 0.8676
# Epoch 54: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0501 - accuracy: 0.9539 - iou_coef: 0.8620 - dice_coef: 0.9230 - f1_score: 0.9245 - aggregated_jaccard_index: 0.8676 - val_val_loss: 0.0551 - val_val_accuracy: 0.9436 - val_val_iou_coef: 0.8279 - val_val_dice_coef: 0.9041 - val_val_f1_score: 0.9047 - val_val_aggregated_jaccard_index: 0.8268 - lr: 1.0000e-04
# Epoch 55/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9544 - iou_coef: 0.8649 - dice_coef: 0.9247 - f1_score: 0.9260 - aggregated_jaccard_index: 0.8692
# ✅ Saved improved backbone at epoch 55 with val_iou=0.8437
# 180/180 [==============================] - 20s 109ms/step - loss: 0.0492 - accuracy: 0.9544 - iou_coef: 0.8649 - dice_coef: 0.9247 - f1_score: 0.9260 - aggregated_jaccard_index: 0.8692 - val_val_loss: 0.0486 - val_val_accuracy: 0.9485 - val_val_iou_coef: 0.8437 - val_val_dice_coef: 0.9133 - val_val_f1_score: 0.9144 - val_val_aggregated_jaccard_index: 0.8422 - lr: 1.0000e-05
# Epoch 56/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0495 - accuracy: 0.9553 - iou_coef: 0.8660 - dice_coef: 0.9258 - f1_score: 0.9271 - aggregated_jaccard_index: 0.8676
# ✅ Saved improved backbone at epoch 56 with val_iou=0.8452
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0494 - accuracy: 0.9553 - iou_coef: 0.8660 - dice_coef: 0.9258 - f1_score: 0.9271 - aggregated_jaccard_index: 0.8676 - val_val_loss: 0.0473 - val_val_accuracy: 0.9489 - val_val_iou_coef: 0.8452 - val_val_dice_coef: 0.9142 - val_val_f1_score: 0.9154 - val_val_aggregated_jaccard_index: 0.8435 - lr: 1.0000e-05
# Epoch 57/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0495 - accuracy: 0.9542 - iou_coef: 0.8639 - dice_coef: 0.9242 - f1_score: 0.9257 - aggregated_jaccard_index: 0.8676 - val_val_loss: 0.0489 - val_val_accuracy: 0.9478 - val_val_iou_coef: 0.8429 - val_val_dice_coef: 0.9128 - val_val_f1_score: 0.9138 - val_val_aggregated_jaccard_index: 0.8407 - lr: 1.0000e-05
# Epoch 58/150
# 180/180 [==============================] - 19s 107ms/step - loss: 0.0482 - accuracy: 0.9553 - iou_coef: 0.8662 - dice_coef: 0.9259 - f1_score: 0.9275 - aggregated_jaccard_index: 0.8708 - val_val_loss: 0.0478 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8438 - val_val_dice_coef: 0.9134 - val_val_f1_score: 0.9143 - val_val_aggregated_jaccard_index: 0.8416 - lr: 1.0000e-05
# Epoch 59/150
# 180/180 [==============================] - 21s 117ms/step - loss: 0.0486 - accuracy: 0.9558 - iou_coef: 0.8665 - dice_coef: 0.9260 - f1_score: 0.9274 - aggregated_jaccard_index: 0.8703 - val_val_loss: 0.0479 - val_val_accuracy: 0.9483 - val_val_iou_coef: 0.8446 - val_val_dice_coef: 0.9139 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8421 - lr: 1.0000e-05
# Epoch 60/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0480 - accuracy: 0.9559 - iou_coef: 0.8670 - dice_coef: 0.9261 - f1_score: 0.9276 - aggregated_jaccard_index: 0.8714 - val_val_loss: 0.0479 - val_val_accuracy: 0.9472 - val_val_iou_coef: 0.8406 - val_val_dice_coef: 0.9114 - val_val_f1_score: 0.9123 - val_val_aggregated_jaccard_index: 0.8395 - lr: 1.0000e-05
# Epoch 61/150
# 180/180 [==============================] - 20s 112ms/step - loss: 0.0491 - accuracy: 0.9555 - iou_coef: 0.8646 - dice_coef: 0.9246 - f1_score: 0.9261 - aggregated_jaccard_index: 0.8693 - val_val_loss: 0.0493 - val_val_accuracy: 0.9472 - val_val_iou_coef: 0.8424 - val_val_dice_coef: 0.9125 - val_val_f1_score: 0.9134 - val_val_aggregated_jaccard_index: 0.8403 - lr: 1.0000e-05
# Epoch 62/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0479 - accuracy: 0.9563 - iou_coef: 0.8677 - dice_coef: 0.9266 - f1_score: 0.9281 - aggregated_jaccard_index: 0.8713 - val_val_loss: 0.0465 - val_val_accuracy: 0.9486 - val_val_iou_coef: 0.8443 - val_val_dice_coef: 0.9137 - val_val_f1_score: 0.9150 - val_val_aggregated_jaccard_index: 0.8429 - lr: 1.0000e-05
# Epoch 63/150
# 180/180 [==============================] - 20s 109ms/step - loss: 0.0494 - accuracy: 0.9542 - iou_coef: 0.8648 - dice_coef: 0.9244 - f1_score: 0.9260 - aggregated_jaccard_index: 0.8676 - val_val_loss: 0.0473 - val_val_accuracy: 0.9485 - val_val_iou_coef: 0.8446 - val_val_dice_coef: 0.9139 - val_val_f1_score: 0.9150 - val_val_aggregated_jaccard_index: 0.8426 - lr: 1.0000e-05
# Epoch 64/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0463 - accuracy: 0.9572 - iou_coef: 0.8684 - dice_coef: 0.9273 - f1_score: 0.9288 - aggregated_jaccard_index: 0.8746
# ✅ Saved improved backbone at epoch 64 with val_iou=0.8456
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0462 - accuracy: 0.9572 - iou_coef: 0.8684 - dice_coef: 0.9273 - f1_score: 0.9288 - aggregated_jaccard_index: 0.8746 - val_val_loss: 0.0468 - val_val_accuracy: 0.9488 - val_val_iou_coef: 0.8456 - val_val_dice_coef: 0.9145 - val_val_f1_score: 0.9156 - val_val_aggregated_jaccard_index: 0.8434 - lr: 1.0000e-05
# Epoch 65/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0486 - accuracy: 0.9546 - iou_coef: 0.8646 - dice_coef: 0.9245 - f1_score: 0.9260 - aggregated_jaccard_index: 0.8686 - val_val_loss: 0.0479 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8436 - val_val_dice_coef: 0.9134 - val_val_f1_score: 0.9142 - val_val_aggregated_jaccard_index: 0.8410 - lr: 1.0000e-05
# Epoch 66/150
# 180/180 [==============================] - 20s 109ms/step - loss: 0.0485 - accuracy: 0.9550 - iou_coef: 0.8638 - dice_coef: 0.9240 - f1_score: 0.9254 - aggregated_jaccard_index: 0.8698 - val_val_loss: 0.0492 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8445 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9147 - val_val_aggregated_jaccard_index: 0.8424 - lr: 1.0000e-05
# Epoch 67/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0485 - accuracy: 0.9547 - iou_coef: 0.8626 - dice_coef: 0.9234 - f1_score: 0.9248 - aggregated_jaccard_index: 0.8692
# ✅ Saved improved backbone at epoch 67 with val_iou=0.8458
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0486 - accuracy: 0.9547 - iou_coef: 0.8626 - dice_coef: 0.9234 - f1_score: 0.9248 - aggregated_jaccard_index: 0.8692 - val_val_loss: 0.0481 - val_val_accuracy: 0.9486 - val_val_iou_coef: 0.8458 - val_val_dice_coef: 0.9147 - val_val_f1_score: 0.9155 - val_val_aggregated_jaccard_index: 0.8429 - lr: 1.0000e-05
# Epoch 68/150
# 180/180 [==============================] - 20s 109ms/step - loss: 0.0493 - accuracy: 0.9535 - iou_coef: 0.8626 - dice_coef: 0.9235 - f1_score: 0.9249 - aggregated_jaccard_index: 0.8663 - val_val_loss: 0.0478 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8445 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9147 - val_val_aggregated_jaccard_index: 0.8423 - lr: 1.0000e-05
# Epoch 69/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0479 - accuracy: 0.9562 - iou_coef: 0.8677 - dice_coef: 0.9267 - f1_score: 0.9281 - aggregated_jaccard_index: 0.8701 - val_val_loss: 0.0487 - val_val_accuracy: 0.9470 - val_val_iou_coef: 0.8408 - val_val_dice_coef: 0.9115 - val_val_f1_score: 0.9124 - val_val_aggregated_jaccard_index: 0.8392 - lr: 1.0000e-05
# Epoch 70/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0481 - accuracy: 0.9549 - iou_coef: 0.8650 - dice_coef: 0.9248 - f1_score: 0.9264 - aggregated_jaccard_index: 0.8695 - val_val_loss: 0.0471 - val_val_accuracy: 0.9483 - val_val_iou_coef: 0.8444 - val_val_dice_coef: 0.9137 - val_val_f1_score: 0.9148 - val_val_aggregated_jaccard_index: 0.8425 - lr: 1.0000e-05
# Epoch 71/150
# 180/180 [==============================] - 20s 110ms/step - loss: 0.0483 - accuracy: 0.9543 - iou_coef: 0.8648 - dice_coef: 0.9247 - f1_score: 0.9261 - aggregated_jaccard_index: 0.8685 - val_val_loss: 0.0477 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8441 - val_val_dice_coef: 0.9136 - val_val_f1_score: 0.9146 - val_val_aggregated_jaccard_index: 0.8418 - lr: 1.0000e-05
# Epoch 72/150
# 180/180 [==============================] - 22s 123ms/step - loss: 0.0485 - accuracy: 0.9552 - iou_coef: 0.8649 - dice_coef: 0.9250 - f1_score: 0.9266 - aggregated_jaccard_index: 0.8683 - val_val_loss: 0.0477 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8435 - val_val_dice_coef: 0.9132 - val_val_f1_score: 0.9143 - val_val_aggregated_jaccard_index: 0.8414 - lr: 1.0000e-05
# Epoch 73/150
# 180/180 [==============================] - 20s 111ms/step - loss: 0.0470 - accuracy: 0.9564 - iou_coef: 0.8662 - dice_coef: 0.9257 - f1_score: 0.9272 - aggregated_jaccard_index: 0.8720 - val_val_loss: 0.0494 - val_val_accuracy: 0.9476 - val_val_iou_coef: 0.8428 - val_val_dice_coef: 0.9127 - val_val_f1_score: 0.9140 - val_val_aggregated_jaccard_index: 0.8405 - lr: 1.0000e-05
# Epoch 74/150
# 180/180 [==============================] - 22s 124ms/step - loss: 0.0484 - accuracy: 0.9551 - iou_coef: 0.8654 - dice_coef: 0.9252 - f1_score: 0.9267 - aggregated_jaccard_index: 0.8685 - val_val_loss: 0.0469 - val_val_accuracy: 0.9484 - val_val_iou_coef: 0.8443 - val_val_dice_coef: 0.9136 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8433 - lr: 1.0000e-05
# Epoch 75/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0468 - accuracy: 0.9558 - iou_coef: 0.8656 - dice_coef: 0.9251 - f1_score: 0.9267 - aggregated_jaccard_index: 0.8719 - val_val_loss: 0.0475 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8432 - val_val_dice_coef: 0.9131 - val_val_f1_score: 0.9140 - val_val_aggregated_jaccard_index: 0.8408 - lr: 1.0000e-05
# Epoch 76/150
# 180/180 [==============================] - 19s 106ms/step - loss: 0.0469 - accuracy: 0.9564 - iou_coef: 0.8678 - dice_coef: 0.9268 - f1_score: 0.9283 - aggregated_jaccard_index: 0.8715 - val_val_loss: 0.0456 - val_val_accuracy: 0.9486 - val_val_iou_coef: 0.8441 - val_val_dice_coef: 0.9136 - val_val_f1_score: 0.9148 - val_val_aggregated_jaccard_index: 0.8426 - lr: 1.0000e-05
# Epoch 77/150
# 180/180 [==============================] - ETA: 0s - loss: 0.0478 - accuracy: 0.9551 - iou_coef: 0.8647 - dice_coef: 0.9244 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8696
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1e-05.
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0477 - accuracy: 0.9551 - iou_coef: 0.8647 - dice_coef: 0.9244 - f1_score: 0.9259 - aggregated_jaccard_index: 0.8696 - val_val_loss: 0.0469 - val_val_accuracy: 0.9483 - val_val_iou_coef: 0.8444 - val_val_dice_coef: 0.9139 - val_val_f1_score: 0.9149 - val_val_aggregated_jaccard_index: 0.8416 - lr: 1.0000e-05
# Epoch 78/150
# 180/180 [==============================] - 19s 108ms/step - loss: 0.0465 - accuracy: 0.9559 - iou_coef: 0.8668 - dice_coef: 0.9261 - f1_score: 0.9277 - aggregated_jaccard_index: 0.8717 - val_val_loss: 0.0460 - val_val_accuracy: 0.9484 - val_val_iou_coef: 0.8443 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9148 - val_val_aggregated_jaccard_index: 0.8421 - lr: 1.0000e-05
# Epoch 79/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0472 - accuracy: 0.9560 - iou_coef: 0.8666 - dice_coef: 0.9260 - f1_score: 0.9277 - aggregated_jaccard_index: 0.8696 - val_val_loss: 0.0472 - val_val_accuracy: 0.9477 - val_val_iou_coef: 0.8424 - val_val_dice_coef: 0.9125 - val_val_f1_score: 0.9136 - val_val_aggregated_jaccard_index: 0.8406 - lr: 1.0000e-05
# Epoch 80/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0459 - accuracy: 0.9567 - iou_coef: 0.8677 - dice_coef: 0.9267 - f1_score: 0.9280 - aggregated_jaccard_index: 0.8733 - val_val_loss: 0.0462 - val_val_accuracy: 0.9483 - val_val_iou_coef: 0.8440 - val_val_dice_coef: 0.9136 - val_val_f1_score: 0.9146 - val_val_aggregated_jaccard_index: 0.8417 - lr: 1.0000e-05
# Epoch 81/150
# 180/180 [==============================] - 19s 107ms/step - loss: 0.0460 - accuracy: 0.9573 - iou_coef: 0.8681 - dice_coef: 0.9271 - f1_score: 0.9287 - aggregated_jaccard_index: 0.8730 - val_val_loss: 0.0450 - val_val_accuracy: 0.9482 - val_val_iou_coef: 0.8430 - val_val_dice_coef: 0.9129 - val_val_f1_score: 0.9139 - val_val_aggregated_jaccard_index: 0.8419 - lr: 1.0000e-05
# Epoch 82/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0465 - accuracy: 0.9564 - iou_coef: 0.8667 - dice_coef: 0.9261 - f1_score: 0.9276 - aggregated_jaccard_index: 0.8710 - val_val_loss: 0.0443 - val_val_accuracy: 0.9493 - val_val_iou_coef: 0.8454 - val_val_dice_coef: 0.9144 - val_val_f1_score: 0.9157 - val_val_aggregated_jaccard_index: 0.8441 - lr: 1.0000e-05
# Epoch 83/150
# 180/180 [==============================] - 19s 106ms/step - loss: 0.0462 - accuracy: 0.9563 - iou_coef: 0.8675 - dice_coef: 0.9265 - f1_score: 0.9281 - aggregated_jaccard_index: 0.8719 - val_val_loss: 0.0443 - val_val_accuracy: 0.9489 - val_val_iou_coef: 0.8445 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9150 - val_val_aggregated_jaccard_index: 0.8433 - lr: 1.0000e-05
# Epoch 84/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0470 - accuracy: 0.9552 - iou_coef: 0.8650 - dice_coef: 0.9249 - f1_score: 0.9264 - aggregated_jaccard_index: 0.8712 - val_val_loss: 0.0436 - val_val_accuracy: 0.9490 - val_val_iou_coef: 0.8446 - val_val_dice_coef: 0.9138 - val_val_f1_score: 0.9151 - val_val_aggregated_jaccard_index: 0.8440 - lr: 1.0000e-05
# Epoch 85/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0485 - accuracy: 0.9528 - iou_coef: 0.8625 - dice_coef: 0.9231 - f1_score: 0.9245 - aggregated_jaccard_index: 0.8654 - val_val_loss: 0.0462 - val_val_accuracy: 0.9482 - val_val_iou_coef: 0.8440 - val_val_dice_coef: 0.9135 - val_val_f1_score: 0.9145 - val_val_aggregated_jaccard_index: 0.8423 - lr: 1.0000e-05
# Epoch 86/150
# 180/180 [==============================] - 19s 107ms/step - loss: 0.0452 - accuracy: 0.9560 - iou_coef: 0.8678 - dice_coef: 0.9264 - f1_score: 0.9278 - aggregated_jaccard_index: 0.8741 - val_val_loss: 0.0467 - val_val_accuracy: 0.9475 - val_val_iou_coef: 0.8425 - val_val_dice_coef: 0.9126 - val_val_f1_score: 0.9133 - val_val_aggregated_jaccard_index: 0.8403 - lr: 1.0000e-05
# Epoch 87/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0468 - accuracy: 0.9560 - iou_coef: 0.8670 - dice_coef: 0.9260 - f1_score: 0.9274 - aggregated_jaccard_index: 0.8707 - val_val_loss: 0.0460 - val_val_accuracy: 0.9477 - val_val_iou_coef: 0.8424 - val_val_dice_coef: 0.9125 - val_val_f1_score: 0.9134 - val_val_aggregated_jaccard_index: 0.8411 - lr: 1.0000e-05
# Epoch 88/150
# 180/180 [==============================] - 19s 104ms/step - loss: 0.0465 - accuracy: 0.9562 - iou_coef: 0.8679 - dice_coef: 0.9269 - f1_score: 0.9284 - aggregated_jaccard_index: 0.8699 - val_val_loss: 0.0444 - val_val_accuracy: 0.9487 - val_val_iou_coef: 0.8441 - val_val_dice_coef: 0.9135 - val_val_f1_score: 0.9148 - val_val_aggregated_jaccard_index: 0.8434 - lr: 1.0000e-05
# Epoch 89/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0458 - accuracy: 0.9564 - iou_coef: 0.8663 - dice_coef: 0.9257 - f1_score: 0.9271 - aggregated_jaccard_index: 0.8717 - val_val_loss: 0.0451 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8424 - val_val_dice_coef: 0.9124 - val_val_f1_score: 0.9136 - val_val_aggregated_jaccard_index: 0.8415 - lr: 1.0000e-05
# Epoch 90/150
# 180/180 [==============================] - 22s 121ms/step - loss: 0.0464 - accuracy: 0.9560 - iou_coef: 0.8664 - dice_coef: 0.9258 - f1_score: 0.9273 - aggregated_jaccard_index: 0.8703 - val_val_loss: 0.0455 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8427 - val_val_dice_coef: 0.9126 - val_val_f1_score: 0.9139 - val_val_aggregated_jaccard_index: 0.8418 - lr: 1.0000e-05
# Epoch 91/150
# 180/180 [==============================] - 19s 104ms/step - loss: 0.0453 - accuracy: 0.9562 - iou_coef: 0.8669 - dice_coef: 0.9261 - f1_score: 0.9277 - aggregated_jaccard_index: 0.8735 - val_val_loss: 0.0443 - val_val_accuracy: 0.9486 - val_val_iou_coef: 0.8436 - val_val_dice_coef: 0.9132 - val_val_f1_score: 0.9144 - val_val_aggregated_jaccard_index: 0.8428 - lr: 1.0000e-05
# Epoch 92/150
# 180/180 [==============================] - 24s 133ms/step - loss: 0.0466 - accuracy: 0.9542 - iou_coef: 0.8654 - dice_coef: 0.9251 - f1_score: 0.9266 - aggregated_jaccard_index: 0.8691 - val_val_loss: 0.0451 - val_val_accuracy: 0.9483 - val_val_iou_coef: 0.8437 - val_val_dice_coef: 0.9132 - val_val_f1_score: 0.9143 - val_val_aggregated_jaccard_index: 0.8426 - lr: 1.0000e-05
# Epoch 93/150
# 180/180 [==============================] - 25s 138ms/step - loss: 0.0459 - accuracy: 0.9555 - iou_coef: 0.8663 - dice_coef: 0.9259 - f1_score: 0.9273 - aggregated_jaccard_index: 0.8708 - val_val_loss: 0.0448 - val_val_accuracy: 0.9480 - val_val_iou_coef: 0.8429 - val_val_dice_coef: 0.9127 - val_val_f1_score: 0.9136 - val_val_aggregated_jaccard_index: 0.8417 - lr: 1.0000e-05
# Epoch 94/150
# 180/180 [==============================] - 22s 124ms/step - loss: 0.0446 - accuracy: 0.9577 - iou_coef: 0.8690 - dice_coef: 0.9277 - f1_score: 0.9291 - aggregated_jaccard_index: 0.8750 - val_val_loss: 0.0475 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8438 - val_val_dice_coef: 0.9131 - val_val_f1_score: 0.9146 - val_val_aggregated_jaccard_index: 0.8433 - lr: 1.0000e-05
# Epoch 95/150
# 180/180 [==============================] - 25s 140ms/step - loss: 0.0446 - accuracy: 0.9562 - iou_coef: 0.8684 - dice_coef: 0.9273 - f1_score: 0.9288 - aggregated_jaccard_index: 0.8743 - val_val_loss: 0.0449 - val_val_accuracy: 0.9475 - val_val_iou_coef: 0.8413 - val_val_dice_coef: 0.9119 - val_val_f1_score: 0.9128 - val_val_aggregated_jaccard_index: 0.8405 - lr: 1.0000e-05
# Epoch 96/150
# 180/180 [==============================] - 25s 140ms/step - loss: 0.0460 - accuracy: 0.9548 - iou_coef: 0.8654 - dice_coef: 0.9249 - f1_score: 0.9263 - aggregated_jaccard_index: 0.8710 - val_val_loss: 0.0455 - val_val_accuracy: 0.9475 - val_val_iou_coef: 0.8422 - val_val_dice_coef: 0.9124 - val_val_f1_score: 0.9132 - val_val_aggregated_jaccard_index: 0.8406 - lr: 1.0000e-05
# Epoch 97/150
# 180/180 [==============================] - 20s 109ms/step - loss: 0.0444 - accuracy: 0.9570 - iou_coef: 0.8697 - dice_coef: 0.9280 - f1_score: 0.9294 - aggregated_jaccard_index: 0.8741 - val_val_loss: 0.0451 - val_val_accuracy: 0.9479 - val_val_iou_coef: 0.8426 - val_val_dice_coef: 0.9127 - val_val_f1_score: 0.9135 - val_val_aggregated_jaccard_index: 0.8415 - lr: 1.0000e-05
# Epoch 98/150
# 180/180 [==============================] - 21s 119ms/step - loss: 0.0458 - accuracy: 0.9561 - iou_coef: 0.8680 - dice_coef: 0.9266 - f1_score: 0.9281 - aggregated_jaccard_index: 0.8724 - val_val_loss: 0.0466 - val_val_accuracy: 0.9475 - val_val_iou_coef: 0.8422 - val_val_dice_coef: 0.9123 - val_val_f1_score: 0.9133 - val_val_aggregated_jaccard_index: 0.8413 - lr: 1.0000e-05
# Epoch 99/150
# 180/180 [==============================] - 22s 120ms/step - loss: 0.0450 - accuracy: 0.9566 - iou_coef: 0.8671 - dice_coef: 0.9264 - f1_score: 0.9280 - aggregated_jaccard_index: 0.8725 - val_val_loss: 0.0456 - val_val_accuracy: 0.9472 - val_val_iou_coef: 0.8408 - val_val_dice_coef: 0.9115 - val_val_f1_score: 0.9125 - val_val_aggregated_jaccard_index: 0.8398 - lr: 1.0000e-05
# Epoch 100/150
# 180/180 [==============================] - 19s 105ms/step - loss: 0.0440 - accuracy: 0.9572 - iou_coef: 0.8694 - dice_coef: 0.9278 - f1_score: 0.9293 - aggregated_jaccard_index: 0.8746 - val_val_loss: 0.0446 - val_val_accuracy: 0.9481 - val_val_iou_coef: 0.8435 - val_val_dice_coef: 0.9132 - val_val_f1_score: 0.9141 - val_val_aggregated_jaccard_index: 0.8421 - lr: 1.0000e-05
# Epoch 101/150
# 180/180 [==============================] - 22s 122ms/step - loss: 0.0433 - accuracy: 0.9588 - iou_coef: 0.8718 - dice_coef: 0.9294 - f1_score: 0.9309 - aggregated_jaccard_index: 0.8761 - val_val_loss: 0.0419 - val_val_accuracy: 0.9492 - val_val_iou_coef: 0.8450 - val_val_dice_coef: 0.9141 - val_val_f1_score: 0.9152 - val_val_aggregated_jaccard_index: 0.8441 - lr: 1.0000e-05
# Epoch 102/150
# 180/180 [==============================] - 19s 104ms/step - loss: 0.0446 - accuracy: 0.9565 - iou_coef: 0.8672 - dice_coef: 0.9264 - f1_score: 0.9279 - aggregated_jaccard_index: 0.8732 - val_val_loss: 0.0434 - val_val_accuracy: 0.9477 - val_val_iou_coef: 0.8413 - val_val_dice_coef: 0.9119 - val_val_f1_score: 0.9128 - val_val_aggregated_jaccard_index: 0.8406 - lr: 1.0000e-05
#
# 🎯 Training complete. Backbone saved and ready for inference.

# %%
from glob import glob
import os
import tensorflow as tf
import numpy as np
from PIL import Image

# =========================================================
# CONFIG
# =========================================================
IMG_DIR = "../dataset_split/test/images"
MSK_DIR = "../dataset_split/test/masks"
img_size   = 256
batch_size = 38
AUTOTUNE = tf.data.AUTOTUNE

# =========================================================
# SAFE FILE COLLECTION
# =========================================================
def valid_name(p):
    return "Zone" not in os.path.basename(p)

image_paths = sorted([
    p for p in glob(os.path.join(IMG_DIR, "*"))
    if valid_name(p)
])
mask_paths = sorted([
    p for p in glob(os.path.join(MSK_DIR, "*"))
    if valid_name(p)
])

print("Images found:", len(image_paths))
print("Masks found :", len(mask_paths))

# =========================================================
# STEM HELPERS
# Masks are named "<imagename>_lesion.<ext>", so strip that
# suffix to recover the shared base name.
# =========================================================
MASK_SUFFIX = "_lesion"

def image_stem(p):
    return os.path.splitext(os.path.basename(p))[0]

def mask_stem(p):
    name = os.path.splitext(os.path.basename(p))[0]
    if name.endswith(MASK_SUFFIX):
        name = name[: -len(MASK_SUFFIX)]
    return name

# =========================================================
# PAIR IMAGES WITH MASKS BY BASE NAME
# (robust to any ordering mismatch, not just sorted-order luck)
# =========================================================
mask_lookup = {mask_stem(p): p for p in mask_paths}

paired_images = []
paired_masks = []
missing = []

for img_p in image_paths:
    key = image_stem(img_p)
    if key in mask_lookup:
        paired_images.append(img_p)
        paired_masks.append(mask_lookup[key])
    else:
        missing.append(img_p)

if missing:
    raise AssertionError(
        f"{len(missing)} image(s) have no matching mask, e.g.: {missing[:5]}"
    )

image_paths = paired_images
mask_paths = paired_masks

print("Paired samples:", len(image_paths))

# =========================================================
# NUMPY LOADER
# =========================================================
def _load_numpy(img_path, mask_path):
    img_path  = img_path.numpy().decode("utf-8")
    mask_path = mask_path.numpy().decode("utf-8")

    # -----------------------------------------------------
    # IMAGE
    # -----------------------------------------------------
    img = Image.open(img_path).convert("RGB")
    img = img.resize(
        (img_size, img_size),
        Image.BILINEAR,
    )
    img = np.array(img, dtype=np.float32) / 255.0

    # -----------------------------------------------------
    # MASK
    # -----------------------------------------------------
    mask = Image.open(mask_path).convert("L")
    mask = mask.resize(
        (img_size, img_size),
        Image.NEAREST,
    )
    mask = np.array(mask, dtype=np.float32)

    # Binary mask
    mask = (mask > 127).astype(np.float32)
    # Add channel dim
    mask = np.expand_dims(mask, axis=-1)

    return img, mask

# =========================================================
# TF WRAPPER
# =========================================================
def load_image_mask(img_path, mask_path):
    img, mask = tf.py_function(
        _load_numpy,
        [img_path, mask_path],
        [tf.float32, tf.float32],
    )
    img.set_shape([img_size, img_size, 3])
    mask.set_shape([img_size, img_size, 1])
    targets = {
        "segmentation": mask
    }
    return img, targets

# =========================================================
# DATASET
# =========================================================
test_dataset = (
    tf.data.Dataset
    .from_tensor_slices((image_paths, mask_paths))
    .map(
        load_image_mask,
        num_parallel_calls=AUTOTUNE,
    )
    .batch(batch_size)
    .prefetch(AUTOTUNE)
)

# =========================================================
# DEBUG
# =========================================================
print(
    "Test batches:",
    tf.data.experimental.cardinality(test_dataset).numpy()
)

# =========================================================
# OPTIONAL SANITY CHECK
# =========================================================
for batch_images, batch_targets in test_dataset.take(1):
    print("\nImages Shape:")
    print(batch_images.shape)
    print("\nSegmentation Shape:")
    print(batch_targets["segmentation"].shape)
# Out:
# Images found: 40
# Masks found : 40
# Paired samples: 40
# Test batches: 2
#
# Images Shape:
# (38, 256, 256, 3)
#
# Segmentation Shape:
# (38, 256, 256, 1)

# %%
import numpy as np
from sklearn.metrics import f1_score as sk_f1_score, accuracy_score

# --- Initialize metric lists ---
ious, dices, accuracies, f1s, ajis = [], [], [], [], []

# --- Evaluation Loop ---
for imgs, masks in test_dataset:
    # Forward pass
    masks = masks["segmentation"]  # (B, 256, 256, 1)

    preds = model.predict(imgs, verbose=0)

    # Handle multi-output model (segmentation, centers, boundaries)
    if isinstance(preds, (list, tuple)):
        seg_preds = preds[0]       # segmentation output
        # center_maps = preds[1]   # not used for metrics
        # boundary_maps = preds[2] # not used for metrics
    else:
        seg_preds = preds

    # --- Threshold segmentation ---
    preds_bin = (seg_preds > 0.5).astype("float32")

    # --- Convert tensors to numpy safely ---
    masks_np = masks.numpy() if isinstance(masks, tf.Tensor) else masks
    preds_np = preds_bin.astype(np.float32)

    # Ensure shapes match
    if masks_np.shape != preds_np.shape:
        preds_np = tf.image.resize(preds_np, masks_np.shape[1:3]).numpy()

    # --- Flatten for sklearn metrics ---
    masks_flat = masks_np.reshape(-1)
    preds_flat = preds_np.reshape(-1)

    # --- Ensure binary (for safety) ---
    masks_flat = np.round(masks_flat).astype(int)
    preds_flat = np.round(preds_flat).astype(int)

    # --- Tensor-based Metrics ---
    iou_val = iou_coef(masks_np, preds_np).numpy()
    dice_val = dice_coef(masks_np, preds_np).numpy()
    aji_val = aggregated_jaccard_index(masks_np, preds_np).numpy()

    ious.append(iou_val)
    dices.append(dice_val)
    ajis.append(aji_val)

    # --- Classical sklearn metrics ---
    acc = accuracy_score(masks_flat, preds_flat)
    f1 = sk_f1_score(masks_flat, preds_flat, zero_division=1)

    accuracies.append(acc)
    f1s.append(f1)

# --- Compute mean metrics ---
mean_iou = np.mean(ious)
mean_dice = np.mean(dices)
mean_aji = np.mean(ajis)
mean_accuracy = np.mean(accuracies)
mean_f1 = np.mean(f1s)

# --- Print results ---
print("\n===== Segmentation Evaluation =====")
print(f"Mean IoU:              {mean_iou:.4f}")
print(f"Mean Dice Coefficient: {mean_dice:.4f}")
print(f"Mean AJI:              {mean_aji:.4f}")
print(f"Mean Accuracy:         {mean_accuracy:.4f}")
print(f"Mean F1 Score:         {mean_f1:.4f}")
# Out:
# ===== Segmentation Evaluation =====
# Mean IoU:              0.9140
# Mean Dice Coefficient: 0.9545
# Mean AJI:              0.9189
# Mean Accuracy:         0.9766
# Mean F1 Score:         0.9576
